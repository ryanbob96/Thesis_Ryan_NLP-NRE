# %%
#PDF Miner (PDF Scraping)
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.layout import LAParams
from pdfminer.converter import HTMLConverter, TextConverter, XMLConverter
from io import StringIO
from pdfminer.pdfpage import PDFPage


#PyPDF2 (PDF Scraping)
import PyPDF2 as pypdf


#OCR
import pdf2image
import cv2
import pytesseract
pytesseract.pytesseract.tesseract_cmd=r'C:\Program Files\Tesseract-OCR\tesseract.exe'


#NLP Preprocessing
import nltk
import re
import regex
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer


#NLP Processing TensorFLow
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

#NLP Processing Spacy
import spacy
spc = spacy.load("en_core_web_lg")
# spc.add_pipe('sentencizer')

#Model Training and Evaluation
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

#Basic
import numpy as np
import pandas as pd
import pickle
import glob
import os
import docker
import string

pc = '!"#$%&\'()*+,-./:;<=>?@[\]^_`{|}~'
# Out:
# C:\Users\Ryan Bobby A\anaconda3\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %% [markdown]
# # Data Input

# %%
pdf_path = 'C:/Users/Ryan Bobby A/Documents/RWTH AACHEN/KULIAH/THESIS_BISMILLAH/Thesis Progress/PDF Data/1-s2.0-0168962286900114-main.pdf'

# %% [markdown]
# # PyPDF2

# %%
text_pypdf = []
with open(pdf_path,'rb') as pdffile:
    reader = pypdf.PdfFileReader(pdffile)
    for i in range(len(reader.pages)):
        page = reader.pages[i]
        text_pypdf.append(page.extract_text())

# %%
text_pypdf_join = ' '.join(text_pypdf)
text_pypdf_join
# Out:
# 'ORIGINAL ARTICLE\n\nPermeability distribution in the Lahendong geothermal ﬁeld:\n\nA blind fault captured by thermal–hydraulic simulation\nMaren Brehme1\n•\nGuido Blo\n¨\ncher1\n•\nMauro Cacace1\n•\nYustin Kamah2\n•\n\nMartin Sauter3\n•\nGu\n¨\nnter Zimmermann1\n\nReceived: 24 November 2015 / Accepted: 4 July 2016 / Published online: 19 July 2016\n\n\n/C211\n\nSpringer-Verlag Berlin Heidelberg 2016\n\nAbstract\nSubsurface ﬂuid ﬂow of reservoirs in active\n\ntectonic regions is mainly controlled by permeability of\n\nfault zones. Therefore, the characterization of fault zones is\nan important step toward performance assessment of a\n\nreservoir. The ﬂuid ﬂow is controlled also by pressure and\n\ntemperature conditions. In this context, we simulated\npressure and temperature ﬁelds to elaborate on the inﬂu-\n\nence of permeability on subsurface ﬂuid ﬂow in the\n\nLahendong geothermal reservoir. Thermal–hydraulic sim-\nulation is performed using a ﬁnite element approach.\n\nAdjusting the permeability through 370 different cases,\n\nmodeling results converged to the observed data within a\nmisﬁt range of 0–7 %. The best ﬁtting models identiﬁed a\n\ndeep-seated fault that has previously not been traced at the\n\nsurface. Simulated temperature distribution suggests a\nprominent convective heat ﬂow, driven by an upward\n\nmigrating and SW–NE oriented ﬂuid ﬂow. This hydraulic\n\ngradient causes a pressure drop along the reservoir. High-\npressure patterns are used to constrain recharge areas, in\n\naddition to inﬁltration measurements. Discharge ﬂow\n\noccurs from SW to NE migrating also upward toward the\n\nhot springs. In that frame, thermal–hydraulic simulations\n\nidentiﬁed previously unresolved subsurface faults, which\nnow allow a better understanding of the subsurface per-\n\nmeability and its inﬂuence on ﬂuid ﬂow.\n\n\nKeywords\n\nPermeable faults\n/C1\nHydrogeology\n/C1\nFluid ﬂow\n/C1\n\n\nGeothermal ﬁeld management\n\n/C1\nReservoir engineering\n/C1\n\n\nPressure drop\n\nIntroduction\n\nGeothermal energy is an essential component to supply\nfuture energy demands. It requires developing new\n\ngeothermal sites and improving the performance of exist-\ning systems to satisfy continuously growing demand. The\n\nproductivity of a geothermal ﬁeld mainly depends on\n\nsubsurface ﬂuid ﬂow, which in active tectonic regions is\ncontrolled by permeability of fault zones (Moeck\n2014). In\n\nthat frame, the primary focus is on locating and charac-\n\nterizing faulted areas in geothermal ﬁelds. This study\nemploys numerical modeling to allocate and quantify\n\npermeability anisotropies and discontinuities, e.g., faults, in\n\norder to understand their inﬂuence on subsurface ﬂuid ﬂow\nin geothermal reservoirs.\n\nNumerical models have been increasingly used to\n\nunderstand the setup and productivity of geothermal sys-\n\ntems. A general overview of geothermal models has been\n\ngiven by O’Sullivan et al. (\n2001). Additionally, there are\n\nseveral sites exemplifying similar characteristics as in\n\nLahendong. The underground movement of hot and cold\n\nﬂuids has been modeled for geothermal ﬁelds in New\nZealand (Kaya et al.\n2014). The Kakkonda geothermal site,\n\ne.g., consists of two reservoirs at various depths with dif-\n\nferent ﬂuid properties. There, results from ﬂuid ﬂow\nanalysis show the importance of fractures for ﬂuid transport\n\nenhancing the recharge or discharge in the reservoir\n&\n\nMaren Brehme\n\nbrehme@gfz-potsdam.de\n1Helmholtz Centre Potsdam – GFZ German Research Centre\n\nfor Geosciences, Telegrafenberg, 14473 Potsdam, Germany\n2Upstream Technology Center Pertamina, Jl. Medan Merdeka\nTimur no. 6, Jakarta, Indonesia\n3Applied Geology, University of Go\n¨\nttingen,\n\nGoldschmidtstraße. 3, 37077 Go\n¨\nttingen, Germany\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n123\nEnviron Earth Sci (2016) 75:1088\n\nDOI 10.1007/s12665-016-5878-9 (McGuinness et al.1995). Generally, faults acting aspreferential ﬂuid path  ...

# %% [markdown]
# # PDFMiner

# %%
def get_pdf_file_content_Text(path_to_pdf):
    
    '''
    path_to_pdf: is the parameter that will give access to the PDF File 
    we want to extract the content.
    '''
    
    '''
    PDFResourceManager is used to store shared resources such as fonts or images that 
    we might encounter in the files. 
    '''
    
    resource_manager = PDFResourceManager(caching=True)
    
    '''
    create a string object that will contain the final text the representation of the pdf. 
    '''
    out_text = StringIO()
    
    '''
    UTF-8 is one of the most commonly used encodings, and Python often defaults to using it.
    In our case, we are going to specify in order to avoid some encoding errors.
    '''
    codec = 'utf-8'
    
    """
    LAParams is the object containing the Layout parameters with a certain default value. 
    """
    laParams = LAParams(line_overlap=0.3, detect_vertical=True)
    
    '''
    Create a TextConverter Object, taking :
    - ressource_manager,
    - out_text 
    - layout parameters.
    '''
    text_converter = TextConverter(resource_manager, out_text, laparams=laParams)
    fp = open(path_to_pdf, 'rb')
    
    '''
    Create a PDF interpreter object taking: 
    - ressource_manager 
    - text_converter
    '''
    interpreter = PDFPageInterpreter(resource_manager, text_converter)

    '''
    We are going to process the content of each page of the original PDF File
    '''
    try:
        for page in PDFPage.get_pages(fp, pagenos=set(), maxpages=0, password="", caching=True, check_extractable=True):
            interpreter.process_page(page)
    except:
        for page in PDFPage.get_pages(fp, pagenos=set(), maxpages=0, password=b"", caching=True, check_extractable=True):
            interpreter.process_page(page)

#Considering Vertical Written
#         if page.mediabox[2] - page.mediabox[0] > page.mediabox[3] - page.mediabox[1]:
#             orientation = 'Landscape'
#         else:
#             orientation = 'Portrait'

    '''
    Retrieve the entire contents of the “file” at any time 
    before the StringIO object’s close() method is called.
    '''
    text = out_text.getvalue()

    '''
    Closing all the ressources we previously opened
    '''
    fp.close()
    text_converter.close()
    out_text.close()
    
    '''
    Return the final variable containing all the text of the PDF
    '''
    return text

# %%
pdf_path = 'C:/Users/Ryan Bobby A/Documents/RWTH AACHEN/KULIAH/THESIS_BISMILLAH/Thesis Progress/PDF Data//90s/petroj%2F38.10.1359.pdf'

# %%
text_pdfmine = get_pdf_file_content_Text(pdf_path)

# %%
text_pdfmine
# Out:
# '(cid:74)(cid:79)(cid:85)(cid:82)(cid:78)(cid:65)(cid:76) (cid:79)(cid:70) (cid:80)(cid:69)(cid:84)(cid:82)(cid:79)(cid:76)(cid:79)(cid:71)(cid:89)\n\n(cid:86)(cid:79)(cid:76)(cid:85)(cid:77)(cid:69) (cid:51)(cid:56)\n\n(cid:78)(cid:85)(cid:77)(cid:66)(cid:69)(cid:82) (cid:49)(cid:48)\n\n(cid:80)(cid:65)(cid:71)(cid:69)(cid:83) (cid:49)(cid:51)(cid:53)(cid:57)(cid:177)(cid:49)(cid:51)(cid:57)(cid:48)\n\n(cid:49)(cid:57)(cid:57)(cid:55)\n\n(cid:80)(cid:101)(cid:116)(cid:114)(cid:111)(cid:103)(cid:101)(cid:110)(cid:101)(cid:115)(cid:105)(cid:115) (cid:111)(cid:102) (cid:81)(cid:117)(cid:97)(cid:116)(cid:101)(cid:114)(cid:110)(cid:97)(cid:114)(cid:121) (cid:73)(cid:110)(cid:116)(cid:114)(cid:97)(cid:112)(cid:108)(cid:97)(cid:116)(cid:101)\n(cid:86)(cid:111)(cid:108)(cid:99)(cid:97)(cid:110)(cid:105)(cid:115)(cid:109)(cid:44) (cid:83)(cid:97)(cid:110)(cid:97)(cid:39)(cid:97)(cid:44) (cid:89)(cid:101)(cid:109)(cid:101)(cid:110)(cid:58) (cid:73)(cid:109)(cid:112)(cid:108)(cid:105)(cid:99)(cid:97)(cid:116)(cid:105)(cid:111)(cid:110)(cid:115) (cid:102)(cid:111)(cid:114)\n(cid:80)(cid:108)(cid:117)(cid:109)(cid:101)(cid:177)(cid:76)(cid:105)(cid:116)(cid:104)(cid:111)(cid:115)(cid:112)(cid:104)(cid:101)(cid:114)(cid:101) (cid:73)(cid:110)(cid:116)(cid:101)(cid:114)(cid:97)(cid:99)(cid:116)(cid:105)(cid:111)(cid:110) (cid:97)(cid:110)(cid:100) (cid:80)(cid:111)(cid:108)(cid:121)(cid:98)(cid:97)(cid:114)(cid:
cid:50)\n\n(cid:81)(cid:117)(cid:97)(cid:116)(cid:101)(cid:114)(cid:110)(cid:97)(cid:114)(cid:121) (cid:105)(cid:110)(cid:116)(cid:114)(cid:97)(cid:112)(cid:108)(cid:97)(cid:116)(cid:101) (cid:118)(cid:111)(cid:108)(cid:99)(cid:97)(cid:110)(cid:105)(cid:115)(cid:109) (cid:110)(cid:101)(cid:97)(cid:114) (cid:83)(cid:97)(cid:110)(cid:97)(cid:39)(cid:97)(cid:44) (cid:119)(cid:101)(cid:115)(cid:116)(cid:101)(cid:114)(cid:110) (cid:89)(cid:101)(cid:109)(cid:101)(cid:110)(cid:44)\n(cid:112)(cid: ...

# %%
def cidToChar(cidx):
    return chr(int(re.findall(r'\(cid\:(\d+)\)',cidx)[0]) + 29)

for x in text_pdfmine.split('\n'):
    if x != '' and x != '(cid:3)':
        abc = re.findall(r'\(cid\:\d+\)',x)
    if len(abc) > 0:
        for cid in abc: x=x.replace(cid, cidToChar(cid))
    print(repr(x).strip("'"))
# Out:
# glrok^i lc mbqolildv
#
# slirjb PU
#
# krj_bo NM
#
# m^dbp NPRVÎNPVM
#
# NVVT
#
# m\x82\x91\x8f\x8c\x84\x82\x8b\x82\x90\x86\x90 \x8c\x83 n\x92~\x91\x82\x8f\x8b~\x8f\x96 f\x8b\x91\x8f~\x8d\x89~\x91\x82
# s\x8c\x89\x80~\x8b\x86\x90\x8aI p~\x8b~D~I v\x82\x8a\x82\x8bW f\x8a\x8d\x89\x86\x80~\x91\x86\x8c\x8b\x90 \x83\x8c\x8f
# m\x89\x92\x8a\x82Îi\x86\x91\x85\x8c\x90\x8d\x85\x82\x8f\x82 f\x8b\x91\x82\x8f~\x80\x91\x86\x8c\x8b ~\x8b\x81 m\x8c\x89\x96\x7f~\x8f\x86\x80
# j\x82\x89\x91 e\x96\x7f\x8f\x86\x81\x86\x97~\x91\x86\x8c\x8b
#
# gK ^K _^hbo∗I jK ^K jbkwfbpI jK cK qefoit^ii ^ka
# `K dK j^`meboplk
#
# abm^oqjbkq lc dblildvI olv^i eliilt^v rkfsbopfqv lc ilkalkI bde^jI qtOM MbuI rh
#
# ob`bfsba g^kr^ov OI NVVTX obsfpba qvmbp`ofmq ^``bmqba grkb NPI NVVT
#
# fkqolar`qflk
#
# \x91\x8f~\x8b\x90\x86\x91\x86\x8c\x8b~\x89
#
# OMSm\x7fLOMQm\x7f=NUÑVPÎNUÑMRX
#
# ♥NUl=+RÑO
#
# n\x92~\x91\x82\x8f\x8b~\x8f\x96 \x86\x8b\x91\x8f~\x8d\x89~\x91\x82 \x93\x8c\x89\x80~\x8b\x86\x90\x8a \x8b\x82~\x8f p~\x8b~D~I \x94\x82\x90\x91\x82\x8f\x8b v\x82\x8a\x82\x8bI
# \x93~\x89\x92\x82 \x81\x82\x91\x82\x8f\x8a\x86\x8b\x82\x81 \x8c\x8b \x91\x85\x86\x90 \x89\x86\x8b\x82 \x83\x8c\x8f \x91\x85\x82 k_pOU \x8e\x92~\x8f\x91\x97
# ~\x8b\x81 \x80\x89\x86\x8b\x8c\x8d\x96\x8f\x8c\x95\x82\x8b\x82 E\x80\x8d\x95F \x8d\x85\x82\x8b\x8c\x80\x8f\x96\x90\x91\x90K e\x8c\x94\x82\x93\x82\x8fI
# \x91\x85\x82
# \x90\x91~\x8b\x81~\x8f\x81 \x7f\x96 \x89~\x90\x82\x8f \x85\x82~\x91\x86\x8b\x84 ~\x8b p` \x8c\x89\x86\x93\x86\x8b\x82 ~\x8b\x81 k_pOU \x8e\x92~\x8f\x91\x97
#
# mbqoldo^mev
#
# NPSO
#
# \x0c_^hbo \x82\x91 ~\x89K
#
# nr^qbok^ov fkqo^mi^qb sli`^kfpj fk vbjbk
#
# UP
# NTN
# UP
# VMÑS
# VÑM
# TSÑR
# TVT
# NMTN
# STÑM
# POO
# NMÑM
# OVÑU
# UM
# NRP
# NO
# POÑN
#
# Q
#
# O
#
# R
#
# OUÑO
# ROÑV
# OOÑT
# OVÑV
# OÑT
# OUÑR
# OMP
# ONO
# NPÑU
# RMT
#
# NÑO
# NSÑM
# PNV
# TM
# TT
# OVÑT
# OOT
# PQN
# NTO
#
# PO
# RV
# OT
# PTÑU
# PÑM
# OUÑS
# OUP
# OSU
# NSÑV
# QPT
#
# NÑT
# NSÑT
# VO
# UP
# SN
# OQÑV
# NUM
# ORP
# NQR
#
# POÑQ
# TNÑU
# PSÑP
# OSÑS
# QÑS
# RNÑV
# NTR
# PUT
# OQÑT
# RPO
#
# NÑV
# NSÑM
# QON
# TS
# SP
# OTÑS
# OPT
# OSN
# NSN
#
# RQ
# NOP
# SO
# QNÑT
# UÑP
# UNÑU
# PRN
# SSV
# QOÑV
# RVV
#
# PÑR
# OMÑM
# NOM
# NMM
# OP
# NOÑV
# SV
#
# S
#
# NO
#
# QUÑM
# NMVÑM
# RRÑM
# POÑT
# SÑS
# TPÑN
# OQR
# SNQ
# PRÑM
# SVS
#
# QÑN
# NUÑP
# PMU
# VN
# OS
# NSÑR
# NRN
#
# T
#
# NM
#
# PPÑQ
# SSÑV
# POÑM
# PPÑT
# PÑR
# PRÑQ
# OOR
# PUO
# ONÑM
# QVT
#
# OÑU
# NUÑR
# RV
# US
# PV
# OSÑP
# OPN
# NON
# RN
#
# PQÑQ
# TMÑQ
# PPÑN
# PPÑN
# QÑO
# PVÑO
# OTR
# PNM
# NVÑR
# RQP
#
# OÑR
# NRÑT
# QNS
# TR
# RV
# OSÑU
# NVT
# PQT
# NPQ
#
# OUÑO
# RVÑQ
# OVÑQ
# OUÑO
# PÑR
# PVÑR
# NUP
# PPO
# ONÑN
# RVP
#
# OÑN
# NTÑR
# QNT
# TR
# RQ
# OQÑV
# ONT
# NVM
# NON
#
# QM
# UM
# QM
# NNÑPS
# NSÑO
# QSÑR
#
# NÑST
# MÑRU
#
# VVÑQP
# MÑSQ
# MÑNTQ
# NÑVT
# NÑMTR
# PÑQO
# VÑTT
# TÑQS
# NMÑUR
# NSÑO
# QTÑU
#
# MÑMU
# MÑQT
#
# VVÑVQ
# MÑRR
# MÑOMO
# OÑOR
# NÑMPT
# QÑMT
# UÑVS
# RÑQM
# NNÑVP
# NSÑV
# QUÑT
#
# −MÑSN
# MÑRN
#
# NMMÑMM
# MÑSU
# MÑOMV
# NÑVM
# MÑUVR
# QÑRP
# TÑVS
# SÑQO
# NOÑNP
# NSÑS
# QUÑS
#
# −MÑRQ
# MÑRS
#
# −MÑSN
# MÑRU
#
# −MÑPQ
# MÑRU
#
# VVÑTN
# MÑRS
# MÑNUQ
# OÑON
# MÑVUT
# QÑQO
# UÑQO
# TÑTR
# NNÑVS
# NSÑR
# QSÑU
#
# VVÑUP
# MÑRU
# MÑNUM
# OÑNT
# NÑMQO
# QÑPR
# UÑVM
# TÑTU
# NNÑOP
# NSÑQ
# QTÑO
#
# VVÑRO
# MÑRS
# MÑNUR
# OÑPP
# MÑUSR
# PÑVV
# VÑQT
# UÑOU
# NNÑVS
# NSÑN
# QRÑU
#
# k\x81
# `\x82
# i~
#
# v
#
# q\x85
# k\x7f
# w\x8f
# _~
# o\x7f
# p\x8f
# m\x7f
# d~
# `\x89
# w\x8b
# `\x92
# p\x80
#
# s
#
# `\x8f
# k\x86
#
# K
#
# \x8a
# K
# \x8d
# K
# \x8d
#
# ilfE\x94\x91BF
# \x8a\x84J\x8b\x8cK
#
# q\x8c\x91~\x89
# mOlR
# j\x8bl
# q\x86lO
# hOl
# k~Ol
# `~l
# j\x84l
# c\x82OlP
# ^\x89OlP
# p\x86lO
# \x91B
#
# \x94
#
# g_OPS
#
# g_OPR
#
# g_OPQ
#
# g_OPP
#
# g_ONN
#
# g_ONM
#
# g_OMV
#
# g_QO
#
# g_QN
#
# g_QM
#
# g_PT
#
# g_PS
#
# g_PP
#
# g_PM
#
# g_OV
#
# p~\x8a\x8d\x89\x82\x8b\x8cKW
#
# q~\x7f\x89\x82NWj~\x87\x8c\x8f~\x8b\x81\x91\x8f~\x80\x82\x82\x89\x82\x8a\x82\x8b\x91\x81~\x91~\x83\x8c\x8fn\x92~\x91\x82\x8f\x8b~\x8f\x96\x86\x8b\x91\x8f~\x8d\x89~\x91\x82\x93\x8c\x89\x80~\x8b\x86\x80\x8f\x8c\x80\x88\x90Ip~\x8b~D~I\x94\x82\x90\x91\x82\x8f\x8bv\x82\x8a\x82\x8b
#
# NPSP
#
# \x0cglrok^i lc mbqolildv
#
# slirjb PU
#
# krj_bo NM
#
# l`ql_bo NVVT
#
# QM
# UP
# QM
# OVÑN
# PÑU
# RMÑQ
# ONN
# PVV
# OOÑT
# UTT
#
# OÑU
# NTÑN
# RPS
# UU
# RV
# OQÑT
# OMO
# NUQ
# NNU
#
# PQ
# SS
# PN
# PNÑM
# PÑM
# PQÑU
# NUS
# MÑNUR
# OÑNM
# NÑMVS
# QÑPQ
# UÑRN
# TÑNN
# NNÑQO
# NSÑS
# QTÑV
#
# MÑMP
# MÑRS
#
# VVÑUT
# MÑSN
# MÑNTV
# OÑNN
# NÑMVR
# QÑSR
# UÑRP
# TÑQO
# NNÑQT
# NSÑQ
# QTÑQ
#
# −MÑOU
# MÑRU
#
# NMMÑNO
# MÑRR
# MÑNTT
# OÑRO
# MÑVMP
# QÑNR
# VÑQU
# UÑOT
# NNÑVO
# NSÑP
# QRÑV
#
# MÑOO
# MÑRV
#
# VVÑUT
# MÑRO
# MÑNTV
# OÑOO
# MÑVSQ
# QÑNO
# VÑMR
# UÑQT
# NNÑQS
# NSÑO
# QSÑT
#
# PQ
# SU
# PP
# PMÑV
# PÑN
# QNÑR
# OOU
# PQU
# ONÑN
# SVM
#
# OÑP
# NRÑS
# PSM
# TS
# RM
# OPÑQ
# NUR
# NQN
# VQ
#
# −MÑOS
# MÑRR
#
# VVÑUS
# MÑRT
# MÑNUT
# OÑOQ
# NÑMUP
# QÑQS
# UÑOS
# TÑNN
# NNÑTM
# NSÑT
# QTÑS
#
# k\x81
# `\x82
# i~
#
# v
#
# q\x85
# k\x7f
# w\x8f
# _~
# o\x7f
# p\x8f
# m\x7f
# d~
# `\x89
# w\x8b
# `\x92
# p\x80
#
# s
#
# `\x8f
# k\x86
#
# K
#
# \x8a
# K
# \x8d
# K
# \x8d
#
# ilfE\x94\x91BF
# \x8a\x84J\x8b\x8cK
#
# q\x8c\x91~\x89
# mOlR
# j\x8bl
# q\x86lO
# hOl
# k~Ol
# `~l
# j\x84l
# c\x82OlP
# ^\x89OlP
# p\x86lO
# \x91B
#
# \x94
#
# j\x82~\x8b
#
# g_PON
#
# g_OQP
#
# g_OQM
#
# g_OPU
#
# g_OPT
#
# g_OPO
#
# g_ONO
#
# g_QQ
#
# g_QP
#
# g_PV
#
# g_PU
#
# g_PR
#
# g_PQ
#
# g_PO
#
# p~\x8a\x8d\x89\x82\x8b\x8cKW
#
# q~\x7f\x89\x82NW\x80\x8c\x8b\x91\x86\x8b\x92\x82\x81
#
# NPSR
#
# \x0cglrok^i lc mbqolildv
#
# slirjb PU
#
# krj_bo NM
#
# l`ql_bo NVVT
#
# í
#
# í
#
# í
#
# í
#
# MÑTMPOU
#
# í
#
# í
#
# í
#
# í
#
# RÑPQ
# PTÑO
# QÑP
# PUÑSTR
# NRÑRST
# NUÑTRS
# QÑPT
# MÑRNOUTMí
# MÑTMPSM
# MÑPP
# OÑOT
# OÑSO
# QÑTM
# RÑSN
# NÑVS
# SÑNQ
# POÑQ
# TNÑU
# PSÑP
# MÑVRR
#
# í
#
# í
#
# í
#
# í
#
# í
#
# í
#
# í
#
# í
#
# í
#
# í
#
# í
#
# RQÑM
# UÑO
# PUÑUMU
# NRÑSMP
# NUÑTOT
# RÑNN
# MÑRNOVMU
# MÑTMPRO
#
# í
#
# í
#
# í
#
# í
#
# í
#
# í
#
# í
#
# í
#
# í
#
# í
#
#
# \x0c

# %%
# #Auto Read PDF
# all_extracted_text={}
# path='C:/Users/Ryan Bobby A/Documents/RWTH AACHEN/KULIAH/THESIS_BISMILLAH/Thesis Progress/PDF Data/00s/'
# for i,filename in enumerate(glob.glob(os.path.join(path, '*.pdf'))):
#     try:
#         all_extracted_text[re.search(r'(\w+).pdf$',filename).group(1) +'_'+ str(i)] = get_pdf_file_content_Text(filename).lower()
#     except:
#         pass

# %%
# all_extracted_text.keys()

# %%
# all_extracted_text

# %% [markdown]
# ## Data Preprocessing (Conditioning, Stop Words, Stemmer)

# %% [markdown]
# ## Pre-Processing 1 : Regex Conditioning for Scientific Text

# %%
# def prepro1(text.lower()):
#     #Punctuation of '-' because make a newline 
#     text_punew = re.sub(r'(-\n)','',text)
    
#     #Remove spacing n dot '\n' & '•'
#     text_punew_spdo = re.sub(r'[\n•]', ' ', text_punew)
    
#     #Germany alphabetic umlaut
#     text_punew_spdo_ger = re.sub(r'(?<=[OoUuAa])(¨)','e',text_punew_spdo)
    
#     #Over-Spacing
#     text_punew_spdo_ger_ovsp = re.sub(r'(\s)(?=\s+)','',text_punew_spdo_ger)
    
#     #Revise et al. + lower
#     text_punew_spdo_ger_ovsp_etal = re.sub(r'et al.','et al',text_punew_spdo_ger_ovsp)
    
#     #Eliminate fig and table
#     text_punew_spdo_ger_ovsp_etal = re.sub(r'ﬁ','fi',text_punew_spdo_ger_ovsp_etal)
#     text_punew_spdo_ger_ovsp_etal_fig = re.sub(r'(table|tables|figure|figures|fig?.|figs.)\s+(\d+|\d+.)', '', text_punew_spdo_ger_ovsp_etal)
    
#     #Eliminate email
#     text_punew_spdo_ger_ovsp_etal_fig_emai = regex.sub(r'\b[\w-.]+?@\w+?.\w+[\w\.\-]+\b','',text_punew_spdo_ger_ovsp_etal_fig)
    
#     #Eliminate website
#     text_punew_spdo_ger_ovsp_etal_fig_emai_web = regex.sub(r'\b?(http?s://|www|http?s://www).[\w\W\s]+.\w+[\w\.-/]+','',text_punew_spdo_ger_ovsp_etal_fig_emai)

# %%
#Punctuation of '-' because make a newline 
text_punew = re.sub(r'(-\n?\s)','',text_pdfmine.lower())
text_punew
# Out:
# '(cid:74)(cid:79)(cid:85)(cid:82)(cid:78)(cid:65)(cid:76) (cid:79)(cid:70) (cid:80)(cid:69)(cid:84)(cid:82)(cid:79)(cid:76)(cid:79)(cid:71)(cid:89)\n\n(cid:86)(cid:79)(cid:76)(cid:85)(cid:77)(cid:69) (cid:51)(cid:56)\n\n(cid:78)(cid:85)(cid:77)(cid:66)(cid:69)(cid:82) (cid:49)(cid:48)\n\n(cid:80)(cid:65)(cid:71)(cid:69)(cid:83) (cid:49)(cid:51)(cid:53)(cid:57)(cid:177)(cid:49)(cid:51)(cid:57)(cid:48)\n\n(cid:49)(cid:57)(cid:57)(cid:55)\n\n(cid:80)(cid:101)(cid:116)(cid:114)(cid:111)(cid:103)(cid:101)(cid:110)(cid:101)(cid:115)(cid:105)(cid:115) (cid:111)(cid:102) (cid:81)(cid:117
and a younger calcalkaline composite association (u2) involving a mafic cumulate sequence and granodiorite to leucomonzogranite. both types of granite are accompanied by mafic units that were noncogenetic with surrounding granitic melts. traceelement calculations indicate that a primitive liquid of monzodioritic composition gave rise to the ut mgk granite by fractional crystallization, amphibole and titanite playing a major role, which, with increasing crystallization, gave decreasing ree contents without a strong negative eu anomaly. the u2 calcalkaline suite was formed by fractional crystallization involving feldspar and lreerich minerals, i.e. monazite, from a liquid of monzogranitic composition. field and petrographical data identify magma mingling in both ut and u2, between mafic and silicic rocks, but geochemical data only indicate how magmamixing processes led to u2 granodiorite. geochemical modelling shows that a single protolith of calculated graywacke composition yielded the two associations under different melting conditions: the highmgk monzodiorite melt was formed after partial melting of a 30% nonmodal batch of granulitefacies metamorphic protolith (low ph20 ), but the calcalkaline monzogranite was formed by the same process in an amphibolitefacies source of similar composition (higher pn2o )the primitive granite magmas of both associations show the same crustal characteristics, i.e.: sri = 0.7060.707; end (t) = 4.3 to 2.2 and $180 = + 7 to + 8%0. this provides evidence that the composition of both u l and u2 granite melts probably was controlled by physicochemical fusion rather than protolithcomposition parameters. the u1 ultrapotassic mafic rock is thought to be of mantle origin, i.e. a deep source containing phlogopite ( + garnet). zone refining led to a significant increase of incompatible traceelement contents during ascent of the magma. mantlecrust interaction lowered the la/yb and 143nd/144nd ratios, but the atsr/a%r ratio increased. nevertheless, interaction with associated ul mgk granite was not important and the crustal component is thought to be different from the associated granitic magma. in u2, the mafic cumulate sequence, clearly of mantle origin, has emorb ca 00092541/94/$07.00 © 1994 elsevier science b.v. all rights reserved ssdi 00092541 (93)e0262r \x0c174 a. cocherie et al. / chemical geology 115 (i 994) 173211 characteristics and seems the result of 10% nonmodal partial melting of a heterogeneous mantle of spinel or amphibole peridotite without garnet. some interaction occurred with the associated granitic melt. the emorb character of the mafic rock indicates that a large part of the batholith, and at least the u2 magmatic a ...

# %%
#Germany alphabetic umlaut
text_punew_spdo_ger = re.sub(r'(?<=[OoUuAa])(¨)','e',text_punew_spdo)
text_punew_spdo_ger
# Out:
# 'elsevier chemical geology 115 (1994) 173211 chemical geology i~clcl}ivt; isotope geoscience crust and mantle contributions to granite genesis an example from the variscan batholith of corsica, france, studied by traceelement and ndsroisotope systematics a. cocherie", ph. rossi", a.m. fouillac", ph. vidal b ab.r.g.m., service g~ologique national, b.p. 6009, f45060 orleans cedex 2, france bc.n.r.s., u.a. no. i0, 5, rue kessler, f63038 clermontferrand cedex, france (received march 3, 1993; revision accepted december 20, 1993) abstract the corsican batholith, formed during the variscan orogeny, was studied with particular emphasis on the respective roles played by crustaland mantlederived material in granite genesis. majorand traceelement data identify: the various types of magma and their genetic relationships; the magmatic processes that gave rise to the observed rocks; and the primitive liquids. osrndisotope systematics constrain the origin of primitive liquids. traceelement models provide data on the various source materials and their possible geodynamic setting. the evolution of two main calcalkaline plutonic associations is compared: an older highmgk association (u~) with both ultrapotassic mafic and silicic rocks, the latter ranging from monzonite to leucosyenogranite, and a younger calcalkaline composite association (u2) involving a mafic cumulate sequence and granodiorite to leucomonzogranite. both types of granite are accompanied by mafic units that were noncogenetic with surrounding granitic melts. traceelement calculations indicate that a primitive liquid of monzodioritic composition gave rise to the ut mgk granite by fractional crystallization, amphibole and titanite playing a major role, which, with increasing crystallization, gave decreasing ree contents without a strong negative eu anomaly. the u2 calcalkaline suite was formed by fractional crystallization involving feldspar and lreerich minerals, i.e. monazite, from a liquid of monzogranitic composition. field and petrographical data identify magma mingling in both ut and u2, between mafic and silicic rocks, but geochemical data only indicate how magmamixing processes led to u2 granodiorite. geochemical modelling shows that a single protolith of calculated graywacke composition yielded the two associations under different melting conditions: the highmgk monzodiorite melt was formed after partial melting of a 30% nonmodal batch of granulitefacies metamorphic protolith (low ph20 ), but the calcalkaline monzogranite was formed by the same process in an amphibolitefacies source of similar composition (higher pn2o )the primitive granite magmas of both associations show the same crustal characteristics, i.e.: sri = 0.7060.707; end (t) = 4.3 to 2.2 and $180 = + 7 to + 8%0. this provides evidence that the composition of both u l and u2 granite melts probably was controlled by physicochemical fusion rather than protolithcomposition parameters. the u1 ultrapotassic mafic rock is thought to be of mantle origin, i.e. a deep source containing phlogopite ( + garnet). zone refining led to a significant increase of incompatible traceelement contents during ascent of the magma. mantlecrust interaction lowered the la/yb and 143nd/144nd ratios, but the atsr/a%r ratio increased. nevertheless, interaction with associated ul mgk granite was not important and the crustal component is thought to be different from the associated granitic magma. in u2, the mafic cumulate sequence, clearly of mantle origin, has emorb ca 00092541/94/$07.00 © 1994 elsevier science b.v. all rights reserved ssdi 00092541 (93)e0262r \x0c174 a. cocherie et al. / chemical geology 115 (i 994) 173211 characteristics and seems the result of 10% nonmodal partial melting of a heterogeneous mantle of spinel or amphibole peridotite without garnet. some interaction occurred with the associated granitic melt. the emorb character of the mafic rock indicates that a large part of the batholith, and at least the u2 magmatic a ...

# %%
#Over-Spacing
text_punew_spdo_ger_ovsp = re.sub(r'(\s)(?=\s+)','',text_punew_spdo_ger)
text_punew_spdo_ger_ovsp
# Out:
# 'elsevier chemical geology 115 (1994) 173211 chemical geology i~clcl}ivt; isotope geoscience crust and mantle contributions to granite genesis an example from the variscan batholith of corsica, france, studied by traceelement and ndsroisotope systematics a. cocherie", ph. rossi", a.m. fouillac", ph. vidal b ab.r.g.m., service g~ologique national, b.p. 6009, f45060 orleans cedex 2, france bc.n.r.s., u.a. no. i0, 5, rue kessler, f63038 clermontferrand cedex, france (received march 3, 1993; revision accepted december 20, 1993) abstract the corsican batholith, formed during the variscan orogeny, was studied with particular emphasis on the respective roles played by crustaland mantlederived material in granite genesis. majorand traceelement data identify: the various types of magma and their genetic relationships; the magmatic processes that gave rise to the observed rocks; and the primitive liquids. osrndisotope systematics constrain the origin of primitive liquids. traceelement models provide data on the various source materials and their possible geodynamic setting. the evolution of two main calcalkaline plutonic associations is compared: an older highmgk association (u~) with both ultrapotassic mafic and silicic rocks, the latter ranging from monzonite to leucosyenogranite, and a younger calcalkaline composite association (u2) involving a mafic cumulate sequence and granodiorite to leucomonzogranite. both types of granite are accompanied by mafic units that were noncogenetic with surrounding granitic melts. traceelement calculations indicate that a primitive liquid of monzodioritic composition gave rise to the ut mgk granite by fractional crystallization, amphibole and titanite playing a major role, which, with increasing crystallization, gave decreasing ree contents without a strong negative eu anomaly. the u2 calcalkaline suite was formed by fractional crystallization involving feldspar and lreerich minerals, i.e. monazite, from a liquid of monzogranitic composition. field and petrographical data identify magma mingling in both ut and u2, between mafic and silicic rocks, but geochemical data only indicate how magmamixing processes led to u2 granodiorite. geochemical modelling shows that a single protolith of calculated graywacke composition yielded the two associations under different melting conditions: the highmgk monzodiorite melt was formed after partial melting of a 30% nonmodal batch of granulitefacies metamorphic protolith (low ph20 ), but the calcalkaline monzogranite was formed by the same process in an amphibolitefacies source of similar composition (higher pn2o )the primitive granite magmas of both associations show the same crustal characteristics, i.e.: sri = 0.7060.707; end (t) = 4.3 to 2.2 and $180 = + 7 to + 8%0. this provides evidence that the composition of both u l and u2 granite melts probably was controlled by physicochemical fusion rather than protolithcomposition parameters. the u1 ultrapotassic mafic rock is thought to be of mantle origin, i.e. a deep source containing phlogopite ( + garnet). zone refining led to a significant increase of incompatible traceelement contents during ascent of the magma. mantlecrust interaction lowered the la/yb and 143nd/144nd ratios, but the atsr/a%r ratio increased. nevertheless, interaction with associated ul mgk granite was not important and the crustal component is thought to be different from the associated granitic magma. in u2, the mafic cumulate sequence, clearly of mantle origin, has emorb ca 00092541/94/$07.00 © 1994 elsevier science b.v. all rights reserved ssdi 00092541 (93)e0262r\x0c174 a. cocherie et al. / chemical geology 115 (i 994) 173211 characteristics and seems the result of 10% nonmodal partial melting of a heterogeneous mantle of spinel or amphibole peridotite without garnet. some interaction occurred with the associated granitic melt. the emorb character of the mafic rock indicates that a large part of the batholith, and at least the u2 magmatic as ...

# %%
#Revise et al. + lower
text_punew_spdo_ger_ovsp_etal = regex.sub(r'(\w+\s+et al.)','',text_punew_spdo_ger_ovsp)
text_punew_spdo_ger_ovsp_etal
# Out:
# 'elsevier chemical geology 115 (1994) 173211 chemical geology i~clcl}ivt; isotope geoscience crust and mantle contributions to granite genesis an example from the variscan batholith of corsica, france, studied by traceelement and ndsroisotope systematics a. cocherie", ph. rossi", a.m. fouillac", ph. vidal b ab.r.g.m., service g~ologique national, b.p. 6009, f45060 orleans cedex 2, france bc.n.r.s., u.a. no. i0, 5, rue kessler, f63038 clermontferrand cedex, france (received march 3, 1993; revision accepted december 20, 1993) abstract the corsican batholith, formed during the variscan orogeny, was studied with particular emphasis on the respective roles played by crustaland mantlederived material in granite genesis. majorand traceelement data identify: the various types of magma and their genetic relationships; the magmatic processes that gave rise to the observed rocks; and the primitive liquids. osrndisotope systematics constrain the origin of primitive liquids. traceelement models provide data on the various source materials and their possible geodynamic setting. the evolution of two main calcalkaline plutonic associations is compared: an older highmgk association (u~) with both ultrapotassic mafic and silicic rocks, the latter ranging from monzonite to leucosyenogranite, and a younger calcalkaline composite association (u2) involving a mafic cumulate sequence and granodiorite to leucomonzogranite. both types of granite are accompanied by mafic units that were noncogenetic with surrounding granitic melts. traceelement calculations indicate that a primitive liquid of monzodioritic composition gave rise to the ut mgk granite by fractional crystallization, amphibole and titanite playing a major role, which, with increasing crystallization, gave decreasing ree contents without a strong negative eu anomaly. the u2 calcalkaline suite was formed by fractional crystallization involving feldspar and lreerich minerals, i.e. monazite, from a liquid of monzogranitic composition. field and petrographical data identify magma mingling in both ut and u2, between mafic and silicic rocks, but geochemical data only indicate how magmamixing processes led to u2 granodiorite. geochemical modelling shows that a single protolith of calculated graywacke composition yielded the two associations under different melting conditions: the highmgk monzodiorite melt was formed after partial melting of a 30% nonmodal batch of granulitefacies metamorphic protolith (low ph20 ), but the calcalkaline monzogranite was formed by the same process in an amphibolitefacies source of similar composition (higher pn2o )the primitive granite magmas of both associations show the same crustal characteristics, i.e.: sri = 0.7060.707; end (t) = 4.3 to 2.2 and $180 = + 7 to + 8%0. this provides evidence that the composition of both u l and u2 granite melts probably was controlled by physicochemical fusion rather than protolithcomposition parameters. the u1 ultrapotassic mafic rock is thought to be of mantle origin, i.e. a deep source containing phlogopite ( + garnet). zone refining led to a significant increase of incompatible traceelement contents during ascent of the magma. mantlecrust interaction lowered the la/yb and 143nd/144nd ratios, but the atsr/a%r ratio increased. nevertheless, interaction with associated ul mgk granite was not important and the crustal component is thought to be different from the associated granitic magma. in u2, the mafic cumulate sequence, clearly of mantle origin, has emorb ca 00092541/94/$07.00 © 1994 elsevier science b.v. all rights reserved ssdi 00092541 (93)e0262r\x0c174 a.  / chemical geology 115 (i 994) 173211 characteristics and seems the result of 10% nonmodal partial melting of a heterogeneous mantle of spinel or amphibole peridotite without garnet. some interaction occurred with the associated granitic melt. the emorb character of the mafic rock indicates that a large part of the batholith, and at least the u2 magmatic association, was  ...

# %%
#Eliminate fig and table
text_punew_spdo_ger_ovsp_etal = re.sub(r'ﬁ','fi',text_punew_spdo_ger_ovsp_etal)
text_punew_spdo_ger_ovsp_etal_fig = re.sub(r'(table|tables|figure|figures|fig?.|figs.)\s+(\d+|\d+.)', '', text_punew_spdo_ger_ovsp_etal)
text_punew_spdo_ger_ovsp_etal_fig
# Out:
# 'elsevier chemical geology 115 (1994) 173211 chemical geology i~clcl}ivt; isotope geoscience crust and mantle contributions to granite genesis an example from the variscan batholith of corsica, france, studied by traceelement and ndsroisotope systematics a. cocherie", ph. rossi", a.m. fouillac", ph. vidal b ab.r.g.m., service g~ologique national, b.p. 6009, f45060 orleans cedex 2, france bc.n.r.s., u.a. no. i0, 5, rue kessler, f63038 clermontferrand cedex, france (received march 3, 1993; revision accepted december 20, 1993) abstract the corsican batholith, formed during the variscan orogeny, was studied with particular emphasis on the respective roles played by crustaland mantlederived material in granite genesis. majorand traceelement data identify: the various types of magma and their genetic relationships; the magmatic processes that gave rise to the observed rocks; and the primitive liquids. osrndisotope systematics constrain the origin of primitive liquids. traceelement models provide data on the various source materials and their possible geodynamic setting. the evolution of two main calcalkaline plutonic associations is compared: an older highmgk association (u~) with both ultrapotassic mafic and silicic rocks, the latter ranging from monzonite to leucosyenogranite, and a younger calcalkaline composite association (u2) involving a mafic cumulate sequence and granodiorite to leucomonzogranite. both types of granite are accompanied by mafic units that were noncogenetic with surrounding granitic melts. traceelement calculations indicate that a primitive liquid of monzodioritic composition gave rise to the ut mgk granite by fractional crystallization, amphibole and titanite playing a major role, which, with increasing crystallization, gave decreasing ree contents without a strong negative eu anomaly. the u2 calcalkaline suite was formed by fractional crystallization involving feldspar and lreerich minerals, i.e. monazite, from a liquid of monzogranitic composition. field and petrographical data identify magma mingling in both ut and u2, between mafic and silicic rocks, but geochemical data only indicate how magmamixing processes led to u2 granodiorite. geochemical modelling shows that a single protolith of calculated graywacke composition yielded the two associations under different melting conditions: the highmgk monzodiorite melt was formed after partial melting of a 30% nonmodal batch of granulitefacies metamorphic protolith (low ph20 ), but the calcalkaline monzogranite was formed by the same process in an amphibolitefacies source of similar composition (higher pn2o )the primitive granite magmas of both associations show the same crustal characteristics, i.e.: sri = 0.7060.707; end (t) = 4.3 to 2.2 and $180 = + 7 to + 8%0. this provides evidence that the composition of both u l and u2 granite melts probably was controlled by physicochemical fusion rather than protolithcomposition parameters. the u1 ultrapotassic mafic rock is thought to be of mantle origin, i.e. a deep source containing phlogopite ( + garnet). zone refining led to a significant increase of incompatible traceelement contents during ascent of the magma. mantlecrust interaction lowered the la/yb and 143nd/144nd ratios, but the atsr/a%r ratio increased. nevertheless, interaction with associated ul mgk granite was not important and the crustal component is thought to be different from the associated granitic magma. in u2, the mafic cumulate sequence, clearly of mantle origin, has emorb ca 00092541/94/$07.00 © 1994 elsevier science b.v. all rights reserved ssdi 00092541 (93)e0262r\x0c174 a.  / chemical geology 115 (i 994) 173211 characteristics and seems the result of 10% nonmodal partial melting of a heterogeneous mantle of spinel or amphibole peridotite without garnet. some interaction occurred with the associated granitic melt. the emorb character of the mafic rock indicates that a large part of the batholith, and at least the u2 magmatic association, was  ...

# %%
#Eliminate email
text_punew_spdo_ger_ovsp_etal_fig_emai = regex.sub(r'\b[\w-.]+?@\w+?.\w+[\w\.\-]+\b','',text_punew_spdo_ger_ovsp_etal_fig)
text_punew_spdo_ger_ovsp_etal_fig_emai
# Out:
# 'elsevier chemical geology 115 (1994) 173211 chemical geology i~clcl}ivt; isotope geoscience crust and mantle contributions to granite genesis an example from the variscan batholith of corsica, france, studied by traceelement and ndsroisotope systematics a. cocherie", ph. rossi", a.m. fouillac", ph. vidal b ab.r.g.m., service g~ologique national, b.p. 6009, f45060 orleans cedex 2, france bc.n.r.s., u.a. no. i0, 5, rue kessler, f63038 clermontferrand cedex, france (received march 3, 1993; revision accepted december 20, 1993) abstract the corsican batholith, formed during the variscan orogeny, was studied with particular emphasis on the respective roles played by crustaland mantlederived material in granite genesis. majorand traceelement data identify: the various types of magma and their genetic relationships; the magmatic processes that gave rise to the observed rocks; and the primitive liquids. osrndisotope systematics constrain the origin of primitive liquids. traceelement models provide data on the various source materials and their possible geodynamic setting. the evolution of two main calcalkaline plutonic associations is compared: an older highmgk association (u~) with both ultrapotassic mafic and silicic rocks, the latter ranging from monzonite to leucosyenogranite, and a younger calcalkaline composite association (u2) involving a mafic cumulate sequence and granodiorite to leucomonzogranite. both types of granite are accompanied by mafic units that were noncogenetic with surrounding granitic melts. traceelement calculations indicate that a primitive liquid of monzodioritic composition gave rise to the ut mgk granite by fractional crystallization, amphibole and titanite playing a major role, which, with increasing crystallization, gave decreasing ree contents without a strong negative eu anomaly. the u2 calcalkaline suite was formed by fractional crystallization involving feldspar and lreerich minerals, i.e. monazite, from a liquid of monzogranitic composition. field and petrographical data identify magma mingling in both ut and u2, between mafic and silicic rocks, but geochemical data only indicate how magmamixing processes led to u2 granodiorite. geochemical modelling shows that a single protolith of calculated graywacke composition yielded the two associations under different melting conditions: the highmgk monzodiorite melt was formed after partial melting of a 30% nonmodal batch of granulitefacies metamorphic protolith (low ph20 ), but the calcalkaline monzogranite was formed by the same process in an amphibolitefacies source of similar composition (higher pn2o )the primitive granite magmas of both associations show the same crustal characteristics, i.e.: sri = 0.7060.707; end (t) = 4.3 to 2.2 and $180 = + 7 to + 8%0. this provides evidence that the composition of both u l and u2 granite melts probably was controlled by physicochemical fusion rather than protolithcomposition parameters. the u1 ultrapotassic mafic rock is thought to be of mantle origin, i.e. a deep source containing phlogopite ( + garnet). zone refining led to a significant increase of incompatible traceelement contents during ascent of the magma. mantlecrust interaction lowered the la/yb and 143nd/144nd ratios, but the atsr/a%r ratio increased. nevertheless, interaction with associated ul mgk granite was not important and the crustal component is thought to be different from the associated granitic magma. in u2, the mafic cumulate sequence, clearly of mantle origin, has emorb ca 00092541/94/$07.00 © 1994 elsevier science b.v. all rights reserved ssdi 00092541 (93)e0262r\x0c174 a.  / chemical geology 115 (i 994) 173211 characteristics and seems the result of 10% nonmodal partial melting of a heterogeneous mantle of spinel or amphibole peridotite without garnet. some interaction occurred with the associated granitic melt. the emorb character of the mafic rock indicates that a large part of the batholith, and at least the u2 magmatic association, was  ...

# %%
#Eliminate website
text_punew_spdo_ger_ovsp_etal_fig_emai_web = regex.sub(r'\b?(http?s://|www|http?s://www).[\w\W\s]+.\w+[\w\.-/]+','',text_punew_spdo_ger_ovsp_etal_fig_emai)
text_punew_spdo_ger_ovsp_etal_fig_emai_web
# Out:
# 'elsevier chemical geology 115 (1994) 173211 chemical geology i~clcl}ivt; isotope geoscience crust and mantle contributions to granite genesis an example from the variscan batholith of corsica, france, studied by traceelement and ndsroisotope systematics a. cocherie", ph. rossi", a.m. fouillac", ph. vidal b ab.r.g.m., service g~ologique national, b.p. 6009, f45060 orleans cedex 2, france bc.n.r.s., u.a. no. i0, 5, rue kessler, f63038 clermontferrand cedex, france (received march 3, 1993; revision accepted december 20, 1993) abstract the corsican batholith, formed during the variscan orogeny, was studied with particular emphasis on the respective roles played by crustaland mantlederived material in granite genesis. majorand traceelement data identify: the various types of magma and their genetic relationships; the magmatic processes that gave rise to the observed rocks; and the primitive liquids. osrndisotope systematics constrain the origin of primitive liquids. traceelement models provide data on the various source materials and their possible geodynamic setting. the evolution of two main calcalkaline plutonic associations is compared: an older highmgk association (u~) with both ultrapotassic mafic and silicic rocks, the latter ranging from monzonite to leucosyenogranite, and a younger calcalkaline composite association (u2) involving a mafic cumulate sequence and granodiorite to leucomonzogranite. both types of granite are accompanied by mafic units that were noncogenetic with surrounding granitic melts. traceelement calculations indicate that a primitive liquid of monzodioritic composition gave rise to the ut mgk granite by fractional crystallization, amphibole and titanite playing a major role, which, with increasing crystallization, gave decreasing ree contents without a strong negative eu anomaly. the u2 calcalkaline suite was formed by fractional crystallization involving feldspar and lreerich minerals, i.e. monazite, from a liquid of monzogranitic composition. field and petrographical data identify magma mingling in both ut and u2, between mafic and silicic rocks, but geochemical data only indicate how magmamixing processes led to u2 granodiorite. geochemical modelling shows that a single protolith of calculated graywacke composition yielded the two associations under different melting conditions: the highmgk monzodiorite melt was formed after partial melting of a 30% nonmodal batch of granulitefacies metamorphic protolith (low ph20 ), but the calcalkaline monzogranite was formed by the same process in an amphibolitefacies source of similar composition (higher pn2o )the primitive granite magmas of both associations show the same crustal characteristics, i.e.: sri = 0.7060.707; end (t) = 4.3 to 2.2 and $180 = + 7 to + 8%0. this provides evidence that the composition of both u l and u2 granite melts probably was controlled by physicochemical fusion rather than protolithcomposition parameters. the u1 ultrapotassic mafic rock is thought to be of mantle origin, i.e. a deep source containing phlogopite ( + garnet). zone refining led to a significant increase of incompatible traceelement contents during ascent of the magma. mantlecrust interaction lowered the la/yb and 143nd/144nd ratios, but the atsr/a%r ratio increased. nevertheless, interaction with associated ul mgk granite was not important and the crustal component is thought to be different from the associated granitic magma. in u2, the mafic cumulate sequence, clearly of mantle origin, has emorb ca 00092541/94/$07.00 © 1994 elsevier science b.v. all rights reserved ssdi 00092541 (93)e0262r\x0c174 a.  / chemical geology 115 (i 994) 173211 characteristics and seems the result of 10% nonmodal partial melting of a heterogeneous mantle of spinel or amphibole peridotite without garnet. some interaction occurred with the associated granitic melt. the emorb character of the mafic rock indicates that a large part of the batholith, and at least the u2 magmatic association, was  ...

# %% [markdown]
# ## Pre-Processing 2 : Sentences with Conditioning, Stemmer / Lemmatizer,  & Stopwords

# %%
#Splitted into sentences by Spacy
spc_text = spc(text_punew_spdo_ger_ovsp_etal_fig_emai_web)

#Prep []
prepro1 = []
col_intro = []
stop_ack_stc = []
stop_ref_stc = []
name = []
pca = '!"#$%&\*+/:;<=>?@[\]^_`{|}~'
pattern_comb = regex.compile(r'([a-z]+[\d]+|\d+[a-z]+|\d+[{}]+|[a-z]+[{}]+|[{}]+[a-z]+|[{}]+[\d]+)'.format(pca,pca,pca,pca))

#list all name
for i in spc_text.ents:
    if i.label_.lower() == 'person':
        name.append(i.text)

#List of Sentences with lemmatization
for i,j in enumerate(spc_text.sents):    
    #Eliminate word - number - punc-chars combination
    sent_lem = regex.sub(pattern_comb,'',j.lemma_)
    
    #delete name
    try:
        sent_lem = regex.sub(r",*(\s*\b(?:{}))\b".format("|".join(name)),'',sent_lem)
    except:
        pass
    
    prepro1.append(sent_lem)
    
    if bool(re.search('(acknowledgments|acknowledgment)',sent_lem)) == True:
        stop_ack_stc.append(i)
        
    if bool(re.search('(references|reference)',sent_lem)) == True:
        stop_ref_stc.append(i)
        
    elif bool(re.search('(introduction)',sent_lem)) == True:
        col_intro.append(i)

#Cut parts before Introduction and after the acknowledgments or references
if len(stop_ack_stc) == 0:
    prepro1 = prepro1[col_intro[0]:stop_ref_stc[-1]]
else:
    prepro1 = prepro1[col_intro[0]:stop_ack_stc[-1]]
    
#All results
brute_result = prepro1

# %%
prepro1
# Out:
# ['introduction the variscan orogenesis be characterize by the emplacement of huge volume of felsic magma of various composition, whose origin be still strongly debate.',
#  'reference to mesozoic or cenozoic and presentday mountain chain, such the coast range batholith or the himalaya, provide neithersatisfactory model of tectonic setting, nor suitable explanation for the production and emplacement of such huge volume of granite.',
#  'the calcalkaline trend, use to characterize magmatic suite or association, be base on specific proportion of gabbrodiorite, tonalitegranodiorite and granite inbatholith, e.g., in the active margin batholith of peru these proportion be 35 (pitcher, 1979).',
#  'in the variscan batholith of corsica, however, they be   82 (, 1980).',
#  'such contrast proportion suggest different source or melting process.',
#  'furthermore, significant outcrop of mgkenriched granitoid or ultrapotassicmafic rock be find in the " southwestern branch of the variscan orogen, where they be visible in certain external crystalline massif of the alps (banzet, 1987 ).',
#  'similar pluton to the one find in northwestern corsica, have be describe from other part of variscan europe, e.g., the bauon massif (southern  pagel and leterrier,  pagel, 1982 ) and the bohemian massif (, 1984), but their relationship (time of emplacement, composition of source) with " calcalkaline trend remain to be clarify.',
#  'the aim of the present paper be to provide well constraint forgenetic model of the variscan batholith find in corsica, france, and sardinia, italy, and describe by rossi and cocherie ( 1991 ).',
#  'consider the chemical evolution of the magmas produce in this batholith well their isotopic composition, it be possible to  ( 1 ) the various type of magmatic  (2) the magmatic  (3) the nature of initial  (4) the  and (5) the existence of any inherit isotopic zonation or heterogeneity.',
#  'this should clarify the respective play by rework of continental crust and by input of mantlederived material.',
#  'the variscan batholith of corsica besuitable target because of the existence of excellent outcrop of granite and associate mafic rock.',
#  'sampling be base on detailed field and petrographic study by  ( 1981 ).',
#  '2.',
#  'geological set the genesis of mediterranean calcalkalic plutonic association be first study in the es and in the corsicansardinian batholith through field, petrography and majorelement geochemistry.',
#  'most of this be centre around two hypothesis.',
#  'the first (,  marre, 1973) assume that mafic and silicic rock both result from the differentiation ofmafic magma.',
#  'the second hypothesis (leterrier,  debon, 1980) favour mix between mantlederived and crustal component, and be base on traceelement (fourcade and gre,  ,  , 1991 ) and isotopegeochemistry (gre and,   ,  , 1988 )  these provide evidence for crustal anatexis in the formation of granitoid rock and for mix between mantlederived magma and crustal material in the genesis of mafic body.',
#  'the variscan batholith of corsica consist of pluton with distinct mineralogical and petrographic characteristic.',
#  'each unit be study by the inverse geochemical approach (see appendix b ) through trace element (cocherie, 1986 ), before use isotope geochemistry.',
#  'this\x0ca. / chemical geology 115 (1994) 173211 175 proach favour the observation of datum to identify the genetic process that link the various sample belong tosingle unit, determine any genetic link between sample and examine the possible relationship between different unit.',
#  'isotope datum constrain the model, especially in the search for source material.',
#  'mineralogical and traceelement study (,  rossi and cocherie, 1991 ) of and silicic intrusion into the corsican calcalkaline batholith, indicate that granite unit represent batch of crustal anatexis.',
#  'this dearly show that cumulate rock of the suite be produce by fractional crystallization of magma of mantle origin.',
#  'in addition, hybridization phenomenon be observe between the two endmember (cocherie,  , 1991 ).',
#  'this lead rossi and chevremont (1987) to qualify suchplutonic association a  , suggestdistinction from calcalkaline rock relate to active margin.',
#  'the corsicasardinia batholith ( ) resuite from the successive intrusion of three magmatic association, ,  and , between middle carboniferous and middle permian time.',
#  'summarize mineralogical datum on the rock use for geochemical discussion be give in appendix  detailed petrographic and mineralogical datum be available in rossi (1986), and rossi and cocherie ( 1991 ).',
#  'the early u t mgk plutonic association be compose of biotiteamphiboleclinopyroxenekfeldsparmegacrystbeare monzonite to biotitesyenogranite, associate with ultrapotassic (, 1987) rock that form <  of the association.',
#  'contact between and silicic mgk rock be invariably plastic and show the same internal structure.',
#  'the mafic body generally doexceed 500 length and be commonly group in swarm.',
#  'rare lamprophyre dyke crosscut the metamorphic basement near  intrusion may be relate to such ultrak rock.',
#  'the  association, emplace withns foliation trend during horizontal ew shortening of the basement (laporte, 1987), be date (, 1992) 322 ___ 12 ma by z°° zircon with  0',
#  ' ',
#  'I I 10 ~',
#  '  4 q  1 77 .',
#  'geological sketch map of the corsican batholith.',
#  'I    palaeozoic   mgk granitoid (vertical stripe) and ultrapotassic (black patch)  4 =  granodiorite and (orient crosse indicate trend of flow structure); and ultramafic   volcanic rock (andesite, dacite and rhyolite);  alkalic volcanic  u 3 alkalic plutonic  postbatholithic formation .',
#  'the stepwiseevaporation method (zem).',
#  'the ui pluton be intrude by the  volcanicplutonic calcalkaline  .',
#  'the u I and  association be both cut by  alkaline volcanicplutonic intrusion, but these last intrusion willbe discuss here.',
#  '176 a.  / chemical geology 115 (1994) 173211 the  volcanicplutonic association be compose of both mafic and silicic body.',
#  'plutonic rock outcrop widely and rare volcanicrock roof pendant in the batholith, occur in nw corsica.',
#  'intermediate to acidic plutonicrock composition range from mafic microgranular enclavebeare granodiorite, show evidence of felsicmafic mingle phenomenon, to monzogranire and leucomonzogranite associate with ultramafic complex ().',
#  ' intrusion be control by nwse structure and give age from 9 ma ( cocherie, 1984) to 305 _+ 12 ma ( , 1993 ).',
#  'they be crosscut by leucomonzogranite pluton, extend over several kilometre and control 050°trend structure with age of 290 _+ 6 ( cocherie, 1984) to  20 ma ( , 1993).',
#  ' rocks of the  calcalkaline association occur enclave, septum or ultramafic complex () up to 15 km size, and consist of cumulate of peridotitic, troctolitic and gabbronoritic  noncumulate range in composition from gabbronorite and olivine norite to diorite.',
#  'the young intrusion be date around 278 ma ( ,   , 1992 ).',
#  'field, petrological and geochronological evidence indicatelink between plutonic and volcanic rock, the be regard magma chamber relate to andesite (, 1992).',
#  'dacite, date  11 to 288 _+ 13 ma ( , 1993 ) and with identical geochemical pattern granodiorite of which it must be consider the volcanic equivalent, be crosscut by leucomonzogranite.',
#  '3.',
#  'analytical method major element be determine by inductively couple plasma atomic emission spectrometry (icpaes) the c.r.p.g.',
#  '(nancy), use the  (1976) method.',
#  'trace element, include tb, be analyse by instrumental neutron activation (inaa) accord to the method describe by  (1973) and  (1980), use epithermal neutron flux withcd filter and irradiation flux of 2.5.1014 n cm 2 s 1.',
#  'for the rareearth element (ree), apart from tb usethermal and epithermal neutron flux of 1014 n cm 2 s 1.',
#  'the ree of most sample be determine withradiochemical procedure, involve the separation of reegroup after dissolve the irradiate powdered rock (, 1973).',
#  'all inaa be do the p. siie laboratory (cen saclay).',
#  'rb and isotope datum be determine the caess rennes.',
#  'age and initial ratio calculation assume absolute error on measure  of _+ 0.0002 (much high individual analytical error) andrelative error on the  ratio of _+  (analytical  , 1980).',
#  'sm and nd isotope datum be determine the university of clermontferrand (  (1987).',
#  'la jolla standard givend ratio of 0.511858 + 0.000009 ().',
#  '160 ratio be measure b.r.g.m.',
#  '(odtan) after gas extraction by routine  technique ( and mayeda, 1963).',
#  'the average reproducibility of isotope analysis be well .0.',
#  'singlezircon date by zem be do onfinnigan ® mat 261 mass spectrometer b.r.g.m.',
#  '(odtan), use analytical technique describe by  ( 1992 ) 4.',
#  'definition of ui and  unit, use major and trace element all majorand traceelement analysis of  and u 2 rock be available either in  and 2, or in  (1984).',
#  'the cnk ratio of 1.11. wholerock acidic sample of both u l and  association characterize their slight peraluminous bulk composition (shand, 1927).',
#  'oxide trend be plot in ; they enablefairly clear distinction between  and  sample, except for rock with  content of > , whose composition be close to minimum melt in the granite system.',
#  'it be interesting to that  leucocratic granite havemuch low and co content similar  ui rock ().',
#  'moreover, the fe content of\x0ca.  / chemical geology 115 (I 994) 173211 177 biotite, which be low in  (0.5) in u 2 (xf¢ ,~ 0.80.9), be another effective discriminating criterion (rossi and chevremont, 1987).',
#  'contrast trend in the lowsilicacontent range of both  and  unit emphasize the play by mineral fractionation indicate by textural evidence (rossi, 1986).',
#  '4.1.',
#  'mgk association of  rock major element display smooth variation that fit rather straight line in projection (harker, 1909), suggestlinkage between and silicic endmember.',
#  'the fairly constant alkali sum be control by both ferromagnesian mineral and kfeldspar, whose abundance respectively decrease and increase from the to acidic apex.',
#  'covariance of this ratio with  ni strongly suggest that enrichment in  be primary (, 1990).',
#  ' and  trend be relate to fractionation of accessory mineral such apatite or titanite.',
#  'the  ratio in rock characterize highto ultrapotassic composition (, 1987 ).',
#  ' be rich in alkali, mgo and , and poor in cao and the  association, and be compare to classical highk calcalkaline plutonic ".',
#  'traceelement distribution of the two suite indicate that ui mgk plutonism be characterize by enrichment in transition metal (sc, cr, co, ni) and by high concentration of largeion lithophile element ( rb, cs, st) well high content of element with small highly charge (u, th, ta, hf).',
#  'with increase , the u i association showstrong decrease of so, cr, co, ni, st, hfand content, whereas rb and th slightly increase towards the leucocratic facie.',
#  'for example, the co vs. th and vs. rb variation in  clearly indicate the particular location of the corsican mgk field, which mostly include the representative point of mgk " bohemian plutonism (coeherie and rossi, 1991 ) and be far from the  calcalkaline field.',
#  'all sample (), include rock, exhibit strong ree fractionation ( 36).',
#  'most pattern haveweakly negative eu anomaly (  0.75 ).',
#  'the total ree content be generally high and decrease from to acidic rock (lree 100665 ppm), withhigh average value in rock (450 ppm) andquite " average value in mgk granitoid rock (200 ppm).',
#  'the more siliceous the sample, the more concave be their heavy ree (hree) distribution pattern.',
#  'traceelement datum for rocks of the ui mgk association show great similarity with datum from calcalkaline lamprophyre with high ree, rb and ba concentration.',
#  '4.2.',
#  'u 2 acidic and intermediate rock u 2 granodiorite show two type of ree pattern (a) withconstant zree of 150  (1) more acidic granodiorite (, 1984) have strongly fractionate pattern ( yb ~ 25 ), but less for mgk granitoid rock, and no eu anomaly be see.',
#  '(2) more intermediate granodiorite have less fractionated light ree (lree) pattern, more hreeenriched pattern andnegative eu anomaly.',
#  'less acidic granodiorite have the most pronounce eu anomaly, which be unusual compare with the general differentiation trend of granitic magma accord tofractional crystallization  this point will be discuss in section 7.4.',
#  ' showregular variation in ree distributionfunction of  content (b).',
#  'the lree pattern be fractionate, but no eu anomaly appear for the less siliceous (see clb 13); this pattern be similar to that of highly siliceous granodiorite (see pr 7 and clb 10).',
#  'rather flat ree pattern with low lree andstrongly negative eu anomaly characterize leucocratic body (e.g., clb 63).',
#  ' present, most author (cocherie,  fourcade and gre, 198  ,  gromet and silver,  mittlefehtdt and miller,  , 1984) recognize that accessory phase (e.g., allanite, monazite) probably trap the lree during late stage of differentiation.',
#  ',,_ , ,',
#  'o ',
#  'o e .',
#  "a' ~ g o & ~",
#  'g ~',
#  "a ~ ~ m'  oo  to bo d  o ~    bo",
#  'o u,~',
#  'o  , 4  oo  o,, 4 bo',
#  'bo oo bo o   m b.,  ~~ bo  o _',
#  "~~ 0   i'~ ',.a",
#  'I,o I I,o _ ~~ .',
#  " 0 ,4 ,4  4 go oo I',.)",
#  '~',
#  ' I I ~',
#  '_',
#  '  :.4 o',
#  '  4 ~ kid .',
#  'o  bb oooooooo    oo  o n o 0  0 I  o 8 0 0 4 oo £ I',
#  'i,o oo  I,o ox ~  t,o oo 0 ~ j 0 .)',
#  '~',
#  '@@ ..j oo 00',
#  '00 t,~',
#  'ix.)',
#  ' eb  I  \x0c180 a.  / chemical geology 115 (1994) 173211  major(in % oxide) and traceelement ppm) concentration in  association and metamorphose rock of corsica peridotite troctolites pc 6 pc 7 pc 4 pc 5 p 6 p 1 532 clb 72 clb 77 clb 76 clb 78  40.40 45.30 47.00 48.00 45.00 48.20 47.20 74.63 74.74 74.80 75.43  10.40 22.30 26.10 15.30 14.40 16.70 18.10 13.34 13.27 12.82 13.4411.64 7.09 4.19 11.67 15.17 11.32 I 1.32 2.28 2.25 2.81 2.03 mno 0.17 0.10 0.06 0.20 0.25 0.20 0.15 0.04 0.05 0.07 0.05 mgo 26.60 10.60 6.35 7.00 7.40 7.10 8.11 0.19 0.25 0.31 0.22 cao 4.75 11.00 12.55 10.20 12.0 9.50 11.90 1.35 1.43 1.47 1.40  0.75 1.70 2.15 3.10 2.90 2.75 1.38 2.86 2.77 3.00 2.55 1(20 0.07 0.10 0.07 0.55 0.25 0.65 0.29 4.90 4.95 4.06 5.02  0.48 0.20 0.25 2.00 1.95 1.70 0.81 0.18 0.16 0.24 0.16  0.06 0.03 0.04 0.25 0.35 0.45 0.06 ....',
#  'o\'.oo ...I 0 oo ~ ".o \', 0 ..I  I\'.) 0 .~)',
#  'ch  ~ ~ ~ ',
#  '~ :, l,,  0 ,..)~',
#  'oc w .=. ta  r ~',
#  'I m oo\x0c182 a. / chemical geology 115 (1994) 173211 14.00 12.00 10.00 ~= 6.oo u. 6.00 4.00 2.00 0.00 16.00 × k × × ...×~.. × ×x × ×',
#  'I I ×x 12.00 ×x 10.00 x xx,~ x',
#  'lie',
#  'x',
#  'x 4.00 2.00 0,00',
#  'I I 25.00 20.00 o  10.00 / 5.00 + 8.00 o 6.00 x xx  x x °oo el x x x x x x ~ x  x x ,~',
#  'b I 45,00 50.00',
#  'I I xx× ,~  ,~ ~ ;× ooo el',
#  'x ... ,,"  x',
#  "x x xx go xx x x ××× × x x x x x x'x'~ xx x",
#  '× x',
#  'x ×xx 12.00 10.00 6.00 6.00 4,00 2.00 0.00 1.80 1.60 1.40 1.20 1.00 0.80 0,60 0.40 0.20 0.00 2.50 2,00 1.50 p 1,00 0.50 0.00 40.00',
#  'I I eo',
#  'x x xx x x ~ x',
#  "xk ?,'ri xx × x  x",
#  'x x ×%,× ix xx',
#  'o I " 0,00',
#  'l I',
#  '40.00 55.00 60.00 65.00 70.00 75,00 45.00 60,00',
#  ' b I 55.00 60.00',
#  ' 65.00 70.00 75.00 .',
#  'plot of some major oxide against  (solid circle = u, mgk calcalkaline plutonic  crosse = u 2 composite calcalkaline plutonic association).',
#  'source of (1980) and this   ( 1984 ); and laporte ( 1987 ).',
#  '4.3.',
#  ' mafic rock textural evidence of mainly olivine or plagioclase cumulative process in and ultramafic rock (,  rossi, 1986) be emphasize by the contrast disposition of cloud of major oxide, with cao indicate the dominant of plagioclase fractionation ().',
#  'troctolite showslightly fractionated pattern withwelldevelope positive eu anomaly ( 3 ) very low concentration level, correspond to the modal composition of such rock that mainly consist of cumulate plagioclase (a).',
#  'gabbronorite, also of cumulative origin, have low ree concentration ( 3040 ppm) withvery weak positive eu anomaly.',
#  'the least differentiate gabbro, correspond to primary magma, havehigh ree content ( 7090 ppm) the cumulate, no orweak negative eu anomaly, and slightly lreeenriche pattern (and b).',
#  'the other rocks (gabbro and diorite) be consider differentiate of this cogenetic suite (cocherie, 1986); they generally shownegative eu anomaly and ree enrichment.',
#  'however, detailed traceelement investigation show exception to this general cogenetic evolutionary  some rock of nearly equal initial liquid composition have high hree content well slight enrichment of other incompatible element (e.g., ta).',
#  'this may reflectheterogeneity of the mantle sourcepoint that will be discuss in more detail in section 7.2.',
#  "gabbro considerproduct ofprimary melt,\x0ca. / chemical geology 115 (1994) 173211 183 1001 I '",
#  'I mgk I',
#  'o ( \\ mgk / o . ~',
#  "¢ \\ ,la. 3 v / '/ c°ca'~/' t'~'.",
#  'I I  th  \' I \' I 1000  .. corsica "~ \\o.',
#  '~',
#  '\\ o 100 cot ,~~ b. leu¢01',
#  '~',
#  "orsica'~,~ 10 , I , ;, , 10 100  .",
#  'a. logarithmic plot of co (ppm) against th (ppm).',
#  'b. logarithmic plot ofsr (ppm) against rb (ppm).',
#  'u, mgk rock be compare withsimilar association outcropping in bohemia and with the  calcalkaline association from the corsican batholith.',
#  'range in composition (major and trace element, see ree pattern on b) from  basalt (,  ,  , 1987) to tholeiitic basalt (jakes and,  ,  culler and graf, 1984).',
#  'traceelement pattern clearly define the various group of rock define by field and petrographic study.',
#  'their contrast distribution docontradict any hypothesis of formation from different source for silicic and endmember composition.',
#  'however, the gap in intermediate composition, observe around   in u,, and between  and   in  trend (), berelate to undersample, but could indicate that the end member of each association have different origin.',
#  'isotope composition should beuseful tool for well definition of possible protolith origin. 5.',
#  'isotope data the, nd and o isotope datum be list in .',
#  '5.1.',
#  ' isotope data monzodioritemonzogranite sample from the  mgk association define wholerock regression line (a), which correspond to age of 297 _+ 8 ma and initial ratio of 0.7071 + 0.0002.',
#  'in spite of the low mswd ( 1.6), the wholerock regression age cannot be consider the age of the u, unit, since give average age of 12 ma (, 1992), which agree with field evidence (marre and rossi, 1981 ).',
#  'the regression line ofbe considermixing line between withlow ',
#  '( ,~ 1 ) and young leucocratic that be emplace somewhat later and havehigh  (> 3).',
#  'acidmarie interaction would have give old age, since the less radiogenic component have low and initial ratio, which that this type of interaction be consider insignificant.',
#  'five of the six syenomonzonite plot onhave low agecorrecte (322 ma)  ratio, range from 0.7046 to 0.7064, and thus fall below the isochron, whereas the sixth (0.7081 ) plot above it.',
#  'this indicate that the rock must be consider noncogenetic with the granite.',
#  'twelve sample from the  calcalkaline association defineregression line (, 1992) yield age of 312 _+ 9 ma and initial  ratio of 0.0.0004.',
#  'this age be interpret the time of emplacement of the calcalkaline suite, and be support bysinglezircon age determination ( 12  , 1993).',
#  'the leucocratic that crosscut, provide another regression line (, 1992) giveyoung age of 6 ma and initial ratio of 0.0.0011.',
#  'singlezircon date by step\x0c184 a.  / chemical geology 115 (1994) 173211 100 (u to  \\10 I iiiiiiiiii ~\'"',
#  '~: ......',
#  'k 5',
#  'I I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'ci',
#  'I I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  '|',
#  'I',
#  'I  I',
#  'I I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I lace nd smeu tb yblu',
#  'I I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  't',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I lace nd smeu tb yb er yblu .',
#  'representative chondritenormalize ree pattern of mgk  (a) basic rock (syenomonzonite); and (b) and c) monzodiorite to.',
#  '100 t._ to ',
#  ' t.d 0 r,I I',
#  'I I',
#  'l',
#  'I',
#  'I',
#  'I',
#  'l',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I a. ......... ....',
#  'I I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I lace nd smeugdtb yblu lace nd smeugdtb yblu .',
#  'representative chondritenormalize ree pattern of the  calcalkaline suite.',
#  'a. granodiorite consist of two group of  one (clb 10, pr 7) with no eu anomaly, and the other (clb 28, clb 21) withnegative eu anomaly.',
#  'b. variation from to leucocratic lead to decrease lree and increase hree content, with increasingly negative eu anomaly.',
#  'wise pb evaporation on leucomonzogranite of northern corsica (, 1993) give age of  20 ma, indicate that emplacement of this huge granite batholith may have take least 10 ma.',
#  'the representative point ( 13 sample) of  granodiorite dodefine isochron most lie slightly above the reference isochron (b) and some have low  ratio.',
#  'nevertheless, all acidic granitoid rock displayrather constant initial ratio around 0.7065, which be significantly less radiogenic other european hercynian plutonic rock, e.g., the es (,  ,  , 1994) or sardinia (,  cochefie,  , 1992) rock from the  calcalkaline complex be plot in c. some plot scatter around the reference isochron, whereas troctolite and some gabbro be far below it, thus\x0ca.  chemical geology 115 (1994) 173211 185',
#  'I I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I I  ~"',
#  'x,, °\'x "\'x. "~"...n,_ ..............',
#  '~,  ° .',
#  'x . _ "~"\' 10  :pc l, 0',
#  ' l.j I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  't',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  't',
#  'n',
#  '..',
#  '~',
#  '"~~  s I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'ii lace nd smeucadtb yb .',
#  'representative chondritenormalize ree pattern of basic rock associate with the  calcalkaline suite.',
#  'a. solid line and full cumulate (pc 4, 532, p 6); circle = gabbro correspond topossible initial melt (clb 7); gabbro (clb 5) and diorite (clb 30) correspond to differentiated  double line = peridotite (pc 6).',
#  'b. three possible initial melt of gabbroic composition.',
#  'indicatedifferent origin for these rock from that of acidic granitoid rock.',
#  '5.2.',
#  'smnd isotope datum although two isochron be obtain use the method on u 2 granitoid rock, no  vs. nd isochron be.',
#  'this may be due to absence of isotopic homogenization of nd isotope on the scale of the batholith, but be also partly due to the relatively young age of the granitoid complex and the narrow range of variation of nd ratio, compare to the range of ratio.',
#  'field relationship andsmnd isochron from one of the (fozzanopeloso) lead  (1992) to calculate young age between 285 and 263 ma, which agree with the  zem age determine by  (1992).',
#  'the datum be show on a (865)i vs. end(t) diagram ( ).',
#  'two group be  most sample indicatecrustal origin, but some rocks show mantle affinity.',
#  'moreover, it bepossible to distinguish between  and  granitic rock on suchdiagram.',
#  '5.3.',
#  'oxygen isotope datum  and u 2 rock give similar sovalue, range from + 5.1 to + 8.0 for u 2 and from .9 to .0 for  mgk.',
#  'for acidic rock, these value be slightly low those of common rocktype of the same composition in other variscan intrusion (, 1986).',
#  ' rock showregular increase of 6180 from .1 to . rock, .4 to . granodiorite, + 7.4 to + 8. and + 8.4 to + 8.9 leucomonzogranite.',
#  'the lack of gap between and acidic rock suggest eithercogenetic relationship between and silicic rock, i.e. the latter deriving from the former, or that hybridization process bridge the gap between each endmember.',
#  'the isotope fractionation observe between and acidic term (o) be too large to be only the result of fractional  this be clearly show on , where wholerock  be plot against  content usedifferentiation index.',
#  'the trend be compare to that observe for the oceanic ascension island, south atlantic, wherefractionation trend of < 1.o be considergood estimate of o isotope behaviour accompany fractional crystallization (weiss et., 1987).',
#  'the difference between these two fractionation trend be too large to be attribute to temperature difference between plutonic and volcanic process.',
#  'these result imply that the  association be create by two different magma batch.',
#  'the high  of some rock sample (+ 7.0 to + 7.o) be explain by isotopic contamination of magma by crustal  indeed rock occur enclave within acidic pluton, and  granodiorite show evidence of magmatic interaction give rather low aovalue (.4 to .6°).',
#  'the nature of the interaction process will be discuss in section 7.4.',
#  '70   the isotopic composition ofsr, nd and o and concentration ofrb, sm and nd in the variscan calcalkaline rock () of western corsica and in the variscan  highmgk granitoid and associate rocks (age 322 + 12 ma) sample rb sm nd nd  tdm  (ppm) (ppm) (a) (ppm) (ppm) (a) t ( vs. smow)',
#  'a.  chemical geology 115 (1994) 173211 189 0218 0214 0210 0.726 0222 0.718 0 314.',
#  '0.710 0.706 0',
#  '0.706 0.712  0 31( 020( ( j / (a) ..',
#  '0.0002  ?" I I I 0',
#  'I 2 3',
#  'I I',
#  'I I  /',
#  '31 I / / "" (b) @ 0.7074.',
#  '," I I',
#  'I',
#  'I',
#  'I 1 2 3 /~ 5 s r 0.706',
#  'I 0.~',
#  'I',
#  'I 0 (c)',
#  'I I',
#  'I',
#  'I',
#  'I',
#  'I 0.4 0.8 1.2 s r the u 1 mgk association doshow the same regular trend the u 2 calcalkaline composite association ( ); within ui the  of syenomonzonite range from + 5.9 to + 6.0, but the value for monzodiorite and (.9 to .0) overlap with those of syenomonzonite.',
#  'with the exception of contaminate and hybridize sample, the rock in both  and  have low jlsovalue (.1 to + 6.5°  + 5.9 to + 6.o) that be typical ofmantle origin.',
#  'variscan plutonic rock from previous study (,  fourcade,  , 1994) show high value for such rock.',
#  'similarly, the  leucomonzogranite havenarrow range of aovalue (.4 to .oo)that be significantly low that of variscan twomica granite (, 1980).',
#  'fig.',
#  ' show different trend for and o isotope datum.',
#  'trend " (differentiation) may correspond to fractional crystallization of acidic magma of monzogranitic composition () and trend .m."',
#  '(mixing) mainly correspond to rock.',
#  'both trend show increase of the initial ratio well increase sovalue, which indicate crustal contamination with possible assimilation during fractional crystallization ofmantlederived magma ( and, 1986) or direct acidbasic hybridization.',
#  'this underline the narrow range of variation in iso.',
#  ' vs. plot of corsican variscan granitoid rock.',
#  'a. isochron for the  mgk suite, use only granite sample ( diamond).',
#  'basic rock (solid diamond) dodefine isochron.',
#  'b. no isochron be for granodiorite of the  association.',
#  'two group of rock be  one withnarrow range in variation of ratio, definecorrelation line with indicative age (298 ma); the other, compose of three sample fall above the reference isochron ( 312 ma), could representmixing line (see text for discussion ).',
#  'c. distribution of basic rock of the  association in the diagram, compare to the reference isochron (312 ma).',
#  'isochron for  granitoid rock be from  (1992)\x0c190 a.  / chemical geology 115 (1994)  ~ t÷4 nd   ,, " \\ 2 o 6 t 0303 0..',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  '~',
#  'hafic rock <~',
#  'oranitoid \\',
#  'I',
#  'I mg k (u 1) hafic rock I e granodiorite I',
#  'x monzogranifes caicalkatine o leucocratic rock () o',
#  'o  ~ <"',
#  'o I I',
#  '0.705 0.706',
#  'I I',
#  'I I 0.707 0.708 0.709 0.710 (87)i .',
#  ' (t) (end the assume t age) against the initial ratio.',
#  'most point cluster round (t) = 3',
#  'and (/) I = 0.7060.707.',
#  'five mafic rock plot near the  .',
#  'despite assimilation or contamination, the correspond magma showmantle origin.',
#  'the ratio of the   have be calculate age of 300 ma, usepresentday isotope composition of 0.70478 and ratio of 0.025.',
#  'pyrenean datum be from  (1984) for the rigut and from  ( 1988 ) for the trois seigneur pluton.',
#  'sardinian datum be from  (1992).',
#  '10 6180 (%°) 9',
#  'I I',
#  'I o .,\'"',
#  'x @  .o\'" @ .°.',
#  "°°°.'",
#  '*  x ..."',
#  '0',
#  'e..e. .........',
#  '~',
#  'ension',
#  'I',
#  'I',
#  'I',
#  '50 60 70 si 02 80 .',
#  'wholerock sovalue vs. 02 content for calcalkaline rock ( association) from corsica.',
#  'the evolution trend of ascension volcanic rock be plot for comparison (, 1987 ).',
#  'tope datum for all rock type, and the contrast value for corsican and pyrenean granitoid rock (, 1980).',
#  'thuslarge mantle contribution to mafic magma be much more evident for corsica for the es, where the trend doextrapolate to endmember with mantletype value (, 1986).',
#  'isotope datum indicate that  and uz, the mafic rock be mantlederived and acidic rock be crustalderive fromsource with the same isotope composition.',
#  'intermediate  granodiorite could be the result of mix process.',
#  'thus the southern variscan realmclear isotopic zonation appear from corsica to the es, whose origin will be discuss infurther section.',
#  '6.',
#  'the  mgk association let consider, for the  association, the genetic relationship between various magma, the process involve (see appendix b), and the characteristic and origin of the primary liquid.',
#  "several question arise concern these comag\x0ca. / chemical geology 115 (1994) 173211 191 /' ' 'c ()i f ii 0.0. 0. 0.7021",
#  'I I',
#  'I I I 5 6 7 8 9 10 11 o (%°) .',
#  'sro diagram for all analyse rock (same symbol in  ) the suite indicatemantle affinity, althoughcrustal contamination trend (cm) appear the large arrow correspond to the evolution of  mafic rock from corsica, showgeneral trend of mixingcontamination from initial magma of mantle origin the narrow isotopic range of variation for the granite, withweak increase  for the most differentiate rock (trend d).',
#  'field h',
#  'and I correspond to typical granite and associate rock, respectively, from the nres (st.  cocherie, 1984).',
#  'matic acid and rocks (and cocherie, 1991): ( 1 ) do genetic link exist between all mgk rock suggest by chemical mineral datum but out by isotope ',
#  '(2) what, if any, be the magmatic process that lead to the association of rock describe ',
#  '(3) be it possible to identify the source (s) of the initial magma and, if not, what be the ',
#  'majorand traceelement datum indicate similar geochemical characteristic for all rock of the mgk association, i.e. high mg, co, cr and ni concentration, high content of incompatible element (, rb, lree, th, u, hf, etc.), and rather strong ree fractionation without large eu anomaly.',
#  'decrease ree content correlate with increase  content.',
#  'mineral composition vary only slightly from to felsic rocktype (,  laporte, 1987).',
#  'all these fact pointgenetic link between all ui rock, include the mafic one.',
#  'however, isotope datum out suchgenetic  (a the isochron diagram, the ultrak mafic rock doplot on the isochron line use only the acidic rock (a): the rocks definelinear correlation that intersect the  most representative point plot under the isochron, but one be locate above it.',
#  'this correlation line be interpretmixing line betweenmantle endmember andcrustal component that be distinct from the felsic mgksuite protolith.',
#  '(b) smnd datum lead to the same conclusion.',
#  'the end(t) of felsic rock havenarrow range of variation ( 3.3 to 2.5 ) whereas the end (t) of maric rock range from 5.0 to + 0.7, suggest mix between mantlederived material andcrustal component, different from the crustal source of felsic magma.',
#  '(c) for two the value be .0 and .o.',
#  'the low value (+ 6. sample k 22) be think to indicate isotopic disequilibrium, ornonmagmatic equilibrium temperature, but mineralogical study point equilibrium.',
#  'value of mgk mafic rock be below . provide evidence for the noncogenetic character of mafic and felsic rock in the ui mgk association.',
#  "isotope datum distinguish least two group of sample on each side of the compositional gap see in harker's projection ().",
#  'the gap for acid rock yield mix line, whereas the other group, mainly compose of rock, give scatter isotope value.',
#  'the and nd isotope characteristic of all  mgk granite, range from monzodiorite ( ) to leucosyenogranite ( ) indicatepossible cogenetic suite, which will be test by traceelement calculation.',
#  '6. i.  ultrak mafic rock the data point of mafic  mgk rock be scatter in both rbsrisochron (a) and srnd () diagram, suggestmixing process between two endmember consist of mantlederived material andcrustal component.',
#  'accord to isotope datum, the crustal component appear to be  and , compare to  mgk granite.',
#  'thus,\x0c192 a. / chemical geology 115 (1994) 173211 the crustal endmember docontribute to the magma that give to the mgk acidic rock.',
#  'additional evidence be provide by the ree pattern of sample k 18 (a), which appear to be the most contaminate sample with respect to and nd isotope.',
#  'its ree fractionation be similar to that of normal detrital sedimentary rock (wildeman and haskin,  , 1984), and different from that of mgk granite (b and c) which show great hree fractionation.',
#  'the 20 and the yb ratio varyfunction of the importance of the crustal component show on the isochron (a); they decrease with increase sri and with decrease ¢nd(t).',
#  'in other, the high  and lree content seem characteristic ofprimary mantlederived magma, butofcrustal component.',
#  '(1987) already suggest that magma mixing or assimilation of silicarich crustal material bethe cause of k enrichment in igneous rock.',
#  'spiderdiagram plot of the  ultrak rock identify they lamprophyre ( ).',
#  '(1987 ) also question the origin of such highly potassic mantlederived present, several model have be proposehigh degree of crystal fractionation ( and yoder, 1967 ); zone refining (harris and, 1989); extremely small degree of partial melting of garnetperidotite mantle material (sun and,  , 1979 ); fusion ofmetasomatize mantle source ( and bell,  hawkesworth and,  wass and rogers,  windom and boettcher,  , ,  , 1987 ); or leaching of wall rock and enrichment of incompatible element during ascent of the melt (, 1983 ).',
#  'finally (1989) have propose that melt fraction small 0. can separate from a  mantie  the metasomatize layer which small melt fraction accumulate, remelt low temperature either through adiabatic decompression crust be stretch, or throughtemperature increase cause byhot plume, give strongly potassic magma.',
#  "illlillllllllllllll  l ~ 100 .'~'es",
#  ' ,, ci.b',
#  '. 0 ~~"~~" _ ÷,, , , "+~ \'\' ~\' , ..x ~\'~  / d / o. o / \\o',
#  '\\ / 0. I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'j',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I srbbath uta k lacesr p ndsmzrhf euti tbyb .',
#  'traceelement abundance in gabbro sample k 25 and clb 24, representative of primitive mafic magma associate with  and  granite, respectively.',
#  'primitive mantle normalize value be from and (1989).',
#  'the sequence of element be base on the order of decrease incompatibility in oceanic basalt.',
#  'datum be compare to value for average nmorb and emorb (sun and, 1989), and average calcalkaline lamprophyre estimate by rock (1987).',
#  'in our opinion it be difficult to imagine that fluid actcarrier for various chemical element, i.e. lree, k, rb, cs, hf, th, u, ta and ba ( ).',
#  ' propose by  (1983 ) consider that, if metasomatic fluid really be involve, their major would be to favour the melting process without produce extensive change in the general chemistry of melt product.',
#  'the production of ultrak mafic rock fromzonerefine process fit well with traceelement and isotope datum from corsican  mafic rock.',
#  'during the first hypothetical stagephlogopite (_+ garnet )bear source melt ~  depth.',
#  'the magma inducezonerefine process in the traverse mantle, lead tosignificant increase of incompatibleelement content, whereas the isotopic characteristic of the melt remain of mantle affinity,\x0ca.  / chemical geology 115 (I 994) 173211 193 despite the increase in and nd concentration.',
#  'insecond stage, this enrich magma interact with the base of the crust, lead to lower yb, high and low nd ratio.',
#  'interaction, i.e. contamination or assimilation during crystal fractionation, with the associate  mgk felsic rock doseem to be the major process involve.',
#  '6.3.',
#  'fractional crystallization of  acidic rockdiscussion of the relationship between mgk granite, use traceelement datum, first need identification of the magmatic process involve, after which the petrogenetic model (mineral proportion in equilibrium with liquid, rate of evolution of the magmatic process) be quantify, use traceelement and especially ree pattern.',
#  'the last all mgkgranite, be strongly fractionate compare to talcalkaline ( and 5 ).',
#  '  increase, zree decrease from ~ 300 to 100 ppm do and ba content, whereas the eu anomaly be fairly constant (0.75) be the rb content around 200 ppm.',
#  'use loglog diagram (co vs. th or vs.and b), it be see that compatibleelement concentration (co) decrease sharply while incompatible element (th, rb) increase only moderately.',
#  'these datum agree with fractional crystallization frommonzodioritic toleucosyenogranitic magma, rather magma mixing or partial melting.',
#  'in , five ree (la, sm, eu, tb, yb) rb have be plot against onloglog scale.',
#  'except for yb, the correlation be fairly good, with average correlation coefficient of 0.88.',
#  'this provide additional evidence for fractional crystallization the process for explain the geochemical trend from monzonitic to syenogranitic composition.',
#  'the correlation also indicate that distribution coefficient (d) remain constant, suggestfirst approximation, that the proportion of crystallize solid phase begreatly modify during magmatic evolution.',
#  'use simultaneous modelling of ree, rb and ba test the fractional crystallization model for ree, after which try to identify the mineral proportion of cumulate phase and calculate the extent of the fractional crystallization process.',
#  'our calculate concentration ofrb and ba in the evolve liquid fit well with the analyse sample (heavy line in  ), use 1 ,  and  for biotite, plagioclase and kfeldspar, respectively.',
#  'on the other hand, it be well know that ree be also control by amphibole and accessory apatite, zircon, auanite, titanite, etc.; in our case see that titanite also play important during crystallization.',
#  'calculate ree concentration obtain with  of amphibole and  of titanite lead to ree pattern ( ) that be very similar to the experimental datum of b and c. initial concentration in the primitive liquid of monzodioritic composition (lo in ) be select use the correlation diagram of .',
#  'the traceelement content of the u I initial liquid of monzodioritic composition now have be well define and, support by isotope datum, will be use to study the origin of primary acidic magma.',
#  '6.4.',
#  'magma mixing in the  association.',
#  'summarize the geochemical and mineral chemical datum on u 1 rock lead to a  the existence of maficfelsic interaction within the  association, lead torock of intermediate composition, be support by field evidence of mix process and by the occurrence of microgranular enclave of ultrapotassic composition in monzonite to monzogranodiorite.',
#  'however, the isotope datum suggestgap  ( 1 )mantlederived ultrapotassic  and (2)felsic magma of crustal origin, show no significant interaction with the magma.',
#  '7.',
#  'the  calcalkaline association 7.1.',
#  ' rock about forty sample belong to the  calcalkaline association be collect in var\x0c194 a. / chemical geology 115 (1994) 173211 1000   100',
#  'I I , ,,I, I .',
#  '4.j  5 10',
#  'sm  I I , iii',
#  'I I srl / 0.5 1  srl j $$ , ,I, 0.1 0.2 05 tb  500 200 100 , ,,1 ........ , : ....... , "";\': v ..\'"',
#  '\\  .......',
#  'I , ,,,\',1 , I I" , ......',
#  'I , ,, "~\'20 10005 1 yb 2 200 500 ba 100  1000 500 200 100 .',
#  'plot of ree, rb and ba against onloglog scale, for u t highmgk granite.',
#  'calculate correlation line (fine line) be show, suggestonestage crystallization process.',
#  ' that only rb behave incompatible element, whereas all other decrease with increase crystallization.',
#  'the heavy line, obtain from the calculate model (), fit well with the fine statistical line.',
#  'I !',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I 100  l. e',
#  'o ri',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'I',
#  'l',
#  'I',
#  'I',
#  'I',
#  'I .',
#  'calculate ree pattern for  mgk granite ().',
#  'ree concentration of the initial liquid (lo for  1 ) have be graphically estimate with the loglog diagram of .',
#  'ious location ( ofpila canale, levie, roccapina,  or small mafic septum).',
#  'all sample be analyse for major and trace element, and also ree (cocherie,  , 1984), but the time it be unclear whether there be several mantle or crustal source.',
#  'the inverse geochemical method (appendix b), use traceelement datum in loglog diagram (cocherie, 1986), have demonstrate that most of this variation result from fractional crystallization the point representative of liquid fall nearstraight line characteristic of suchprocess.',
#  'method for graphic determination of bulkdistribution coefficient d for compatible (cr, ni) and incompatible or hygromagmatophile (u, rb, cs, ta, hf, th, la) element be describe elsewhere (,  ,  cocherie, 1986), use the covariance between the fourteen possible pair of element.',
# ...
#  'show two model for the melting of rock withgraywacke composition, (ci) bedry initial assemblage (granulite ) and (  )hydrous assemblage (amphibolite facie).',
#  'the good fit be obtain for  partial melting in both case (granulite and amphibolite facie):and b show the calculated and experimental ree datum, respectively.',
#  'similar calculation be do for rb and ba ( ), and the two set of value perfectly agree.',
#  'however, there bediscrepancy between calculate and eu value for the amphibolitefacies model, and their concentration in analyse sample.',
#  'two explanation be  either much more plagioclase be present in the initial source, or the partition coefficient k liq for and eu ( 1.42 and 0.69, respec. ) be underestimate.',
#  'with high kdvalue of 5.4 and 1.9, which be realistic for granitic melt accord to arth (1976), calculate datum would agree with experimental concentration.',
#  'possible source, i.e.high tlow p granulitic paragneiss (libourel, 1985 ), be analyse for trace element (table i ); the rb and ree analysis be compare with the model graywacke source ().',
#  'the ree pattern of corsican granulite definefield close to the ree pattern of graywacke, except for their high hree content ( ).',
#  ' melt in granulite facie, such paragneiss could givemonzodioritic liquid, and melt in amphibolite facie would lead tomonzogranitic liquid.',
#  ' previously suggest (cocherie and rossi, 1991 ), the composition of  and  granite appear to be\x0c204 a.  / chemical geology 115 (1994) 173211  traceelement calculation usenonmodal batch partial melting model to produce the initial granitic liquid of u 1 and  composition kd gneiss co granulitic model amphibolite facie model orthogarnet apatite do',
#  "p cl lo  p'  lo pyroxene (0.3) (0.3) clb 13 rb 0.0027 0.0085 41 63 0.058 0.136 198 170 0.752 0.485 69 91 0.0085 0.015 245 222 0.963 1.852 313 550 0.533 0.383 309 0.0029 0.017 451 588 0.861 2.268 1223 1500 0.661 0.436 708 647 la 0.10 (0.30) (30.0) 43.4 34 0.209 0.168 74.1 70 0.651 0.259 38.9 38.4 ce 0.15 0.35 34.7 70.7 68 0.177 0.120 154 160 0.717 0.276 72.8 69.3 nd 0.22 0.53 57.1 32 0.160 0.061 72.5 65 1.012 0.332 26.4 24.4 sm 0.27 2.66 62.8 5.73 5.8 0.222 0.055 11.5 11 1.223 0.434 4.16 4.18 eu 0.17 1.50 30.4 1.80 0.95 0.471 0.637 1.63 2 0.837 0.386 0.93 0.87 gd 0.34 10.5 56.3 4.55 0.415 0.046 6.50 7.5 1.545 0.672 2.77 3.18 tb (0.40) (18.0) 52.0 1.63 0.74 0.603 0.042 0.83 1 1.406 0.541 0.48 0.51 yb 0.86 39.9 23.9 5.49 2.45 1.176 0.025 1.67 2.2 1.277 0.490 1.71 1.83 0.90 29.6 20.2 0.91 0.41 0.924 0.027 0.34 0.33 1.164 0.520 0.32 0.33 partition coefficient, take from arth ( 1976); those for plagioclase, kfeldspar, biotite and amphibole be list in ; interpolate value be in bracket.",
#  ' correspond to the average value of corsican granulitic paragneiss ().',
#  'co',
#  '= traceelement concentration of the initial solid source material (average concentration of quartzrich and quartzintermediate and mclennan, 1985 ).',
#  'corsican granulitic gneiss be compare with the select traceelement concentration (see text for explanation ).',
#  'do = bulk distribution coefficient for the dry initial assemblage (qz,  ,  kfs,  opx, 15. gt, 2., 0.).',
#  ' bulk distribution coefficient correspond to the follow proportion of mineral contribute to the  qz,  ,  kfs, .',
#  ' calculate traceelement content of the melt accord to the dry model compare with the lo content of the primitive monzodiorite melt ().',
#  ", p'  distribution coefficient calculate with the follow mineral  qz,  ,  bio,  amph,  gt,  and qz,  ,  bio,  amph, .",
#  '  traceelement content of the melt accord to the hydrous model compare with the lo clb 13 content of the primitive melt.',
#  'more likely control by physicochemical fusion parameter by composition of the protolith.',
#  '8.2.',
#  'age of the granite source material the possible source involve in granitoidmagma genesis havegraywacke composition (63   ppm).',
#  'this lead to ratio of 0.82, which be compare to that obtain from average rb and content of corsican granulitic gneiss (rb = 41  245 ratio of 0.48).',
#  'about 322 ma ago (i.e. the ut age) the initial ratio be close to 0.707.',
#  'if considertwostage model, the protolith be derive fromdepletedtype mantle withsri of 0.7028, the average age of the source material be calculate to be ~ 800 + 100 ma, base on ratio of 0.48 or 0.82.',
#  'this beminimum age, because acidbasic magma interaction may have lower the initial ratio of the granite.',
#  'inherit zircon from continental crust find in  gabbro of the peloso cmu give age of 1000 ma (, 1992), which agree with such calculation.',
#  'this strontium model age be compare with the nd model age ( ).',
#  'for each analyse sample, the evolution line be from 0300 ma in the f(t) diagram.',
#  ' list in , the average end(t) be close to 3.5, t be the assume granite age.',
#  'use the average nd ratio of the granulitic paragneiss, take representative of the source protolith calculate the nd ratio (0.115), which providemodel for the time evolution of the  its intercept with the deplete mantle (d.m.) growth curve givemodel age of ~ 1100 ma.',
#  'this age be close to the calculate t age ( ) of each individual sample the  nd ratio of the rock in question be similar to those of assume source rock.',
#  'there be no significant difference between nd and model age, because the evolution band for deplete mantle in the end (t) diagram be very wide.',
#  'the estimate age of the protolith thus be consider close to 1000 ma.',
#  ' that discuss\x0ca.  / chemical geology 115 (1994) 173211 205 ,',
#  '  .0',
#  '.6',
#  'I I',
#  'I',
#  'I',
#  'I',
#  'I 6 "" mgk granitoids :" talcalkaline .....',
#  'monzogranifes 0 200 400 600 800 1000 t (ha) .',
#  'end vs. t diagram for 4 basic rock and 12 granitoid rock.',
#  'use  = 0.115 previously define for the source material (; ) obtainmodel age around 1100 ma near the tdm (), calculate for each individual sample insofar the nd ratio be similar in analyse sample and the protolith.',
#  'the basic rock associate with the  association take rootfar from the mantle evolution trend (pc 4, lm 169, clb 24).',
#  ' that olwinerich rock of peridotite composition (pc 6) shownegative slope.',
#  'this evolution be rare and link to the high  ratio (0.2549), much high that of the chur ratio (0.1967).',
#  'its chondritenormalized ree pattern be plot in a. by arndt and goldstein ( 1987)iall nd model age be necessarily  , because they representmixture of material derive from the mantle various time, correspond to major orogenic event.',
#  '8.3.',
#  'comparison between corsican, sardinian and batholiths before the oligocenemiocene oceanization in the western mediterranean region, continuous variscan crust exist between corsica, sardinia and the es the possibility to investigatelarge section of the variscan orogenic belt.',
#  'geochemical datum on pyrenean variscan pluton be summarize in  (1984) and cocherie and autran (1994).',
#  'it be see that the calcalkaline geochemical trend of pyrenean pluton be similar to those of the budduso massif in northeastern sardinia (cocherie,  , 1989 ) and those of the corsican  unit discuss here.',
#  'the otherwise uniform geochemical behaviour of the hercynian pluton in corsica, sardinia and the pyrrnre, beconfirm by, nd and o isotope datum.',
#  'for sardinia, the initial ratio of 0.7096 from the budduso massif (cocherie, 1984) be close to the unpublished value cite by  ( 1983 ) from the sarrabus massif (0.70920.7098), and those for the bono intrusive complex (0.70730. , 1992 ).',
#  'these initial ratio fall between those from corsica (0.707) and the es (0.711 ) ().',
#  'the  show similar geochemical trend in rock ofgranodioritic to monzogranitic  average  scatter from .o for corsican granite to + 9.o for pyrenean granite, with intermediate value of .o for sardinia (, 1983).',
#  'similar evolution from corsica to the es be see consider smnd isotope datum.',
#  'end(t) increase from average value of 5.6 for the pyrenean rigut pluton ( , 1984), 6.2 for the trois seigneur massif (, 1988 ) and 5.6 for granodiorite from the bono complex in sardinia (, 1992), to 3. the corsican batholith.',
#  'type granite remain very similar throughout the variscan chain from corsicasardinia to the es, frompetrological, mineralogical and majorand traceelement geochemistry point of view.',
#  'broadscale zoning, reveal by isotope, be inherit from deep source of the granite.',
#  'such regional isotope zonation indicate that batholith be generate along boundary of the eastern " and western " terrane (rossi and cocherie, 1991 ); granite of the corsican batholith\x0c206 a.  / chemical geology 115 (1994) 173211 would belong to the first terrane, and granite in sardinia and the pyrrnre to the second one. 9.',
#  'conclusion our on the corsican batholith and other pluton of the southern realm of the variscan chain, have lead to insight into variscan continental growth through the origin and emplacement of socalled " plutonic association.',
#  'successively emplace  and  magmatic association be the result of mixing of noncogenetic mafic and silicic magma.',
#  'two different type of mantle be melt to give mafic   " ultrak magma result from fusion ofphlogopite ( _ garnet) metasomatize mantle andsecond stagezonerefine process lead to significant increase of incompatible traceelement content.',
#  'finally, the magma interact with the base of the crust, lead to lower yb and nd, and high  ratio in the melt.',
#  ' " magma result from nonmodal partial melting ofspinel or amphibolite lherzolitic mantle.',
#  'primitive silicic magma of both  and  have similar relatively low  ratio (0.7060.707) well low  ( to ) and high end(t) (4.3 to 2.2) value.',
#  'they derive from the same continental source that melt under different condition of fusion, lead to different initial liquid, i.e. monzodioritic for  and monzogranitic for .',
#  'this emphasize the importance of fluid content and pt melting condition anatexis of continental crust be involve in the generation of granitic melt.',
#  'intermediate rock (granodiorite both  and  result from mix of preexist rock of mafic and silicic composition.',
#  'isotope and majorand traceelement geochemistry support evidence of mix process in , but in  the and silicic endmember be completely blend.',
#  'microgranular enclave of intermediate to acid rock of each association the shape of undisrupted bubble of mafic magma chemically equilibrate insilicic environment, remain " remnant of such process.',
#  'such magma of intermediate composition bridge the gap between mafic and silicic endmember.',
#  'in suchcase, the   that be obtain be quite different from the calcalkaline trend of american coastal batholith, which be relate to subduction beneathcontinental margin and result from fractional crystallization ofbasalt source.',
#  'this example from variscan plutonism show that unconsidered use of the term " can be misleading.',
#  'isotopic constraint give estimate age for the protolith of ~ 1 ga, and indicate that the corsican protolith be young the sardinian and pyrenean batholith, provide evidence for crustalaccretion process.',
#  'the major difference between the two assume mantle source that yield mafic ul and  magma agree with progressive uplift of the asthenosphere, i.elithosphere under extensional stress.',
#  'this lead to melting ofdeep phlogopite (garnet)  mantle around 322 ma to melt of the shallow garnetfree spinel lherzolitic  mantle ( 312280 ma), and finally to the  alkaline volcanicplutonic episode (280250 ma).',
#  'this constrain the emplacement of the last part of  calcalkalic plutonism to postcollisional crustalthinning condition.',
#  'acknowledgement thank a. autran for helpful discussion and suggestion.',
#  ' be acknowledge for nd analysis.',
#  ' be also grateful to the  des sciences de la  of the p. siie laboratory (saclay, france) and to the caess of rennes (france), where respectively trace element and isotope be analyse byc.c. and ph.r.',
#  'thank the.r.s., centre de recherches sur la synthrse et la chimie des minrraux, laboratory orlran, where part of the study be carry out.',
#  ' thank very much the two anonymous reviewer who help to improve the first version of the manuscript.',
#  'this be b.r.g.m.',
#  'contribution no.  the be financially support byb.r.g.m.',
#  'research grant.',
#  'a.  / chemical geology 115 (1994) 173211 207 appendixm petrographical and mineralogical datum on ui and u 2 rock analytical datumpresent in  and 2 be available in  (1984) and rossi and cocherie ( 1991 ).',
#  'precise sample location be give in rossi (1986).',
#  'modal composition for sample be indicate by asterisk (*).',
#  ' association intermediate to acid rock havetypical mineralogical  abundant apatite and zircon early  augite clinopyroxene surround by actinolitic hornblende (up to composition); caplagioclase (omonzonite to osyenogranite); barich  foxyre mgtibiotite (0.50); ilmenite be the most abundant  sulphide and macroscopic titanite be ubiquitous.',
#  'ultrapotassic rock (melasyenite to melamonzonite) display some common characteristic throughout the different    be crdiopside to augite clinopyroxene, caplagioclase, foxyre mgtibiotite, and rare relic of phlogopitic mica.',
#  'ilmenite, commonly surround by sphene, be the most abundant  magnetite be scarce.',
#  'of particular interest be the occurrence of crspinel in micaceous aggregate, which could represent relic of olivine.',
#  'sulphide be ubiquitous.',
#  'apatite and zircon be the early mineral.',
#  'the systematic presence of actinolitic hornblende be characteristic of such rock.',
#  'typically secondary biotite be different in habit, such those that occur in mineral crack or aggregate.',
#  'the early mineral  zircon, thorite, allanite, apatite, sphene and sulphide (pyrrhotite + chalcopyrite + exsolution of pentlandite) and oxide (ilmenite and futile with exsolution of ilmenite).',
#  '(k 1, k 5, k 6, k 4, k ): plagioclase , kfeldspar , quartz , biotite , magnesian hornblendeamphibole with relict crdiopside , apatite , ilmenite and titanite .',
#  ' association intermediate to acid granodiorite, plagioclase be oamphibole and biotite (both with 0.50.7) nearly everywhere occur together  magnetite, allanite, apatite and titanite be accessory.',
#  'amphibole be rare in.',
#  'the composition of biotitebeare leucomonzogranite be close to thermal minimum in the   almandinespessartine garnet occur accessory phase.',
#  'ultramafic and mafic  peridotite (pc ) haveheteradcumulate texture, cumulate olivine  (); intercumulus clinopyroxene partly replace by pargasitic hornblende, plagioclase (o), crspinel, ilmenite, magnetite and sulphide.',
#  'troctolite (pc 4, pc 7, lm ): mesocumulate texture, plagioclase  (78), olivine  (foso), orthopyroxene, clinopyroxene.',
#  'gabbro (assume liquid composition, pc 5, clb ): texture of orthocumulate, plagioclase  (65), olivine  (s), clinopyroxene , orthopyroxene , brown amphibole , ilmenite, magnetite, green spinel and sulphide.',
#  'gabbronorite (p 6): orthocumulate texture, plagioclase (), olivine (), orthopyroxene, clinopyroxene, poikilitic brown hornblende, apatite, ilmenite, biotite.',
#  'gabbronorite (p 1): cumulate texture show strong igneous lamination, plagioclase (), orthopyroxene (proportion equivalent to plagioclase), clinopyroxene, poikilitic brown hornblende and biotite, apatite, quartz.',
#  'orthopyroxenebeare granodiorite (clb 27): mediumto coarsegrained texture, plagioclase  (o), kfeldspar , quartz , orthopyroxene , clinopyroxene  etch by green amphibole , biotite and opaque .',
#  'norite (pv 532, clb 18, clb ): heteradcumulate texture, cumulate olivine  (t), cumulative plagioclase  (), poikilitic orthopyroxene , heteradcumulate pargasitic hornblende  partly replace relict clinopyroxene , ilmenite, magnetite, sulphide, green spinel.',
#  'gabbro (clb 5, clb ): coarsegrained texture, plagioclase  (relict core , large rim  ), magnesian hornblende  include relict orthopyroxene, biotite , itmenite, magnetite.',
#  ...]

# %%
#Read the file Stopwords
gist_file = open("gist_stopwords.txt", "r")
try:
    content = gist_file.read()
    stopwords = content.split(",")
finally:
    gist_file.close()

prepro2=[]

#Pattern for Remove Citation
pattern1 = regex.compile(r'\(([\w\s\d{}]+)\)'.format(pc))

#Pattern for Apply the Stopwords
pattern2 = r",*(\s*\b(?:{}))\b".format("|".join(stopwords))

#Pattern for unused space first n last
pattern3 = regex.compile(r'((^\s+)(?=.)|(?<=.)(\s+$))')

#Pattern for Apply over-space
pattern4 = regex.compile(r'(\s)(?=\s+)')

#Pattern Additional compiler
pattern_add = regex.compile(r'(\x01|\x0c|\s[a-z]\s|°|^\b(\w\s)|)')

#Pattern for combined word and number
for i,j in enumerate(prepro1):
    if bool(regex.search(pattern1,j)) == True:
        if bool(regex.search(r'\d',regex.search(pattern1,j).group())) == True:
            try:
                prepro2.append(re.sub(regex.findall(pattern1,j)[0],'',j))
            except:
                prepro2.append(j)
        else:
            prepro2.append(j)
    else:
        prepro2.append(j)
    
    #With Removing number and punctuations    
    layer = regex.sub(r'(\d|[^A-Za-z\s]|[^\P{P}]+)',' ',re.sub(pattern2,'', prepro2[i])) 
    
    layer = regex.sub(pattern3,'',layer)
    
    layer = regex.sub(pattern4,'',layer)
    
    prepro2[i] = regex.sub(pattern_add,'',layer)

#Final filtering for less than three words sentence
d = lambda y : None if len(y.split(' '))<=4 else y
prepro2 = list(filter(d, prepro2))

# %%
prepro2
# Out:
# ['introduction variscan orogenesis characterize emplacement huge volume felsic magma composition origin debate',
#  'reference mesozoic cenozoic presentday mountain chain coast range batholith himalaya provide neithersatisfactory model tectonic setting suitable explanation production emplacement huge volume granite',
#  'calcalkaline trend characterize magmatic suite association base specific proportion gabbrodiorite tonalitegranodiorite granite inbatholith active margin batholith peru proportion',
#  'contrast proportion source melting process',
#  'outcrop mgkenriched granitoid ultrapotassicmafic rock southwestern branch variscan orogen visible external crystalline massif alps',
#  'pluton northwestern corsica variscan europe bauon massif southern pagel leterrier pagel bohemian massif relationship time emplacement composition source calcalkaline trend remain clarify',
#  'aim paper provide constraint forgenetic model variscan batholith corsica france sardinia italy rossi cocherie',
#  'chemical evolution magmas produce batholith isotopic composition type magmatic magmatic nature initial existence inherit isotopic zonation heterogeneity',
#  'clarify respective play rework continental crust input mantlederived material',
#  'variscan batholith corsica besuitable target existence excellent outcrop granite associate mafic rock',
#  'sampling base detailed field petrographic study',
#  'geological set genesis mediterranean calcalkalic plutonic association study corsicansardinian batholith field petrography majorelement geochemistry',
#  'assume mafic silicic rock result differentiation ofmafic magma',
#  'hypothesis leterrier debon favour mix mantlederived crustal component base traceelement fourcade gre isotopegeochemistry gre provide evidence crustal anatexis formation granitoid rock mix mantlederived magma crustal material genesis mafic body',
#  'variscan batholith corsica consist pluton distinct mineralogical petrographic characteristic',
#  'unit study inverse geochemical approach appendix trace element cocherie isotope geochemistry',
#  'chemical geology proach favour observation datum identify genetic process link sample belong tosingle unit determine genetic link sample examine relationship unit',
#  'isotope datum constrain model search source material',
#  'mineralogical traceelement study silicic intrusion corsican calcalkaline batholith granite unit represent batch crustal anatexis',
#  'dearly cumulate rock suite produce fractional crystallization magma mantle origin',
#  'addition hybridization phenomenon observe endmember',
#  'lead rossi chevremont qualify suchplutonic association suggestdistinction calcalkaline rock relate active margin',
#  'corsicasardinia batholith resuite successive intrusion magmatic association middle carboniferous middle permian time',
#  'summarize mineralogical datum rock geochemical discussion appendix detailed petrographic mineralogical datum rossi rossi cocherie',
#  'early mgk plutonic association compose biotiteamphiboleclinopyroxenekfeldsparmegacrystbeare monzonite biotitesyenogranite associate ultrapotassic rock form association',
#  'contact silicic mgk rock invariably plastic internal structure',
#  'mafic body generally doexceed length commonly group swarm',
#  'rare lamprophyre dyke crosscut metamorphic basement intrusion relate ultrak rock',
#  'association emplace withns foliation trend horizontal ew shortening basement laporte zircon',
#  'geological sketch map corsican batholith',
#  'palaeozoic mgk granitoid vertical stripe ultrapotassic black patch granodiorite orient crosse trend flow structure ultramafic volcanic rock andesite dacite rhyolite alkalic volcanic alkalic plutonic postbatholithic formation',
#  'association cut alkaline volcanicplutonic intrusion intrusion willbe discuss',
#  'chemical geology volcanicplutonic association compose mafic silicic body',
#  'plutonic rock outcrop rare volcanicrock roof pendant batholith occur nw corsica',
#  'intermediate acidic plutonicrock composition range mafic microgranular enclavebeare granodiorite evidence felsicmafic mingle phenomenon monzogranire leucomonzogranite associate ultramafic complex',
#  'intrusion control nwse structure age cocherie',
#  'crosscut leucomonzogranite pluton extend kilometre control trend structure age cocherie',
#  'rocks calcalkaline association occur enclave septum ultramafic complex size consist cumulate peridotitic troctolitic gabbronoritic noncumulate range composition gabbronorite olivine norite diorite',
#  'field petrological geochronological evidence indicatelink plutonic volcanic rock regard magma chamber relate andesite',
#  'dacite identical geochemical pattern granodiorite volcanic equivalent crosscut leucomonzogranite',
#  'analytical method major element determine inductively couple plasma atomic emission spectrometry icpaes',
#  'trace element include analyse instrumental neutron activation inaa accord method epithermal neutron flux withcd filter irradiation flux',
#  'rareearth element ree usethermal epithermal neutron flux',
#  'ree sample determine withradiochemical procedure involve separation reegroup dissolve irradiate powdered rock',
#  'inaa siie laboratory cen saclay',
#  'rb isotope datum determine caess rennes',
#  'age initial ratio calculation assume absolute error measure high individual analytical error andrelative error ratio analytical',
#  'isotope datum determine university clermontferrand',
#  'odtan gas extraction routine technique mayeda',
#  'singlezircon zem onfinnigan mat mass spectrometer',
#  'definition unit major trace element majorand traceelement analysis rock',
#  'cnk ratio wholerock acidic sample association characterize slight peraluminous bulk composition',
#  'oxide trend plot enablefairly clear distinction sample rock content composition close minimum melt granite',
#  'interesting leucocratic granite havemuch low content rock',
#  'fe content chemical geology I biotite low effective discriminating criterion rossi chevremont',
#  'contrast trend lowsilicacontent range unit emphasize play mineral fractionation textural evidence',
#  'mgk association rock major element display smooth variation fit straight projection suggestlinkage silicic endmember',
#  'fairly constant alkali sum control ferromagnesian mineral kfeldspar abundance decrease increase acidic apex',
#  'trend relate fractionation accessory mineral apatite titanite',
#  'ratio rock characterize highto ultrapotassic composition',
#  'rich alkali mgo poor cao association compare classical highk calcalkaline plutonic',
#  'traceelement distribution suite mgk plutonism characterize enrichment transition metal high concentration largeion lithophile element rb high content element small highly charge ta hf',
#  'increase association showstrong decrease hfand content rb increase leucocratic facie',
#  'rb variation location corsican mgk field include representative point mgk bohemian plutonism calcalkaline field',
#  'sample include rock exhibit strong ree fractionation',
#  'total ree content generally high decrease acidic rock lree ppm withhigh average rock ppm andquite average mgk granitoid rock ppm',
#  'siliceous sample concave heavy ree hree distribution pattern',
#  'traceelement datum rocks mgk association great similarity datum calcalkaline lamprophyre high ree rb concentration',
#  'acidic intermediate rock granodiorite type ree pattern withconstant zree acidic granodiorite fractionate pattern yb mgk granitoid rock anomaly',
#  'intermediate granodiorite fractionated light ree lree pattern hreeenriched pattern andnegative anomaly',
#  'acidic granodiorite pronounce anomaly unusual compare general differentiation trend granitic magma accord tofractional crystallization point discuss',
#  'showregular variation ree distributionfunction content',
#  'lree pattern fractionate anomaly siliceous clb pattern highly siliceous granodiorite clb',
#  'flat ree pattern low lree andstrongly negative anomaly characterize leucocratic body',
#  'author cocherie fourcade gre gromet silver mittlefehtdt miller recognize accessory phase allanite monazite trap lree late stage differentiation',
#  'eb I chemical geology major oxide traceelement ppm concentration association metamorphose rock corsica peridotite troctolites clb clb clb clb I mno mgo cao',
#  'ree yb ta hf loi loss interpolate',
#  'total fe bzreetotal ree content interpolate',
#  'mafic rock textural evidence olivine plagioclase cumulative process ultramafic rock rossi emphasize contrast disposition cloud major oxide cao dominant plagioclase fractionation',
#  'troctolite showslightly fractionated pattern withwelldevelope positive anomaly low concentration level correspond modal composition rock consist cumulate plagioclase',
#  'gabbronorite cumulative origin low ree concentration withvery weak positive anomaly',
#  'differentiate gabbro correspond primary magma havehigh ree content ppm cumulate orweak negative anomaly lreeenriche pattern',
#  'rocks gabbro diorite differentiate cogenetic suite cocherie generally shownegative anomaly ree enrichment',
#  'detailed traceelement investigation exception general cogenetic evolutionary rock equal initial liquid composition high hree content slight enrichment incompatible element ta',
#  'gabbro considerproduct ofprimary melt chemical geology I',
#  'logarithmic plot ofsr ppm rb ppm',
#  'mgk rock compare withsimilar association outcropping bohemia calcalkaline association corsican batholith',
#  'range composition major trace element ree pattern basalt tholeiitic basalt jakes culler graf',
#  'traceelement pattern define group rock define field petrographic study',
#  'contrast distribution docontradict hypothesis formation source silicic endmember composition',
#  'gap intermediate composition observe trend berelate undersample member association origin',
#  'isotope composition beuseful tool definition protolith origin',
#  'isotope data isotope datum list',
#  'isotope data monzodioritemonzogranite sample mgk association define wholerock regression correspond age initial ratio',
#  'spite low mswd wholerock regression age age unit average age agree field evidence marre rossi',
#  'acidmarie interaction age radiogenic component low initial ratio type interaction insignificant',
#  'syenomonzonite plot onhave low agecorrecte ratio range fall isochron sixth plot',
#  'sample calcalkaline association defineregression yield age initial ratio',
#  'age interpret time emplacement calcalkaline suite support bysinglezircon age determination',
#  'leucocratic crosscut provide regression giveyoung age initial ratio',
#  'singlezircon step chemical geology I iiiiiiiiii',
#  'representative chondritenormalize ree pattern mgk basic rock syenomonzonite monzodiorite',
#  'lace smeugdtb yblu lace smeugdtb yblu',
#  'representative chondritenormalize ree pattern calcalkaline suite',
#  'granodiorite consist group clb anomaly clb clb withnegative anomaly',
#  'variation leucocratic lead decrease lree increase hree content increasingly negative anomaly',
#  'wise pb evaporation leucomonzogranite northern corsica age emplacement huge granite batholith',
#  'representative point sample granodiorite dodefine isochron lie reference isochron low ratio',
#  'acidic granitoid rock displayrather constant initial ratio radiogenic european hercynian plutonic rock sardinia cochefie rock calcalkaline complex plot plot scatter reference isochron troctolite gabbro chemical geology',
#  'representative chondritenormalize ree pattern basic rock associate calcalkaline suite',
#  'solid cumulate circle gabbro correspond topossible initial melt clb gabbro clb diorite clb correspond differentiated double peridotite',
#  'indicatedifferent origin rock acidic granitoid rock',
#  'smnd isotope datum isochron method granitoid rock isochron',
#  'absence isotopic homogenization isotope scale batholith partly young age granitoid complex narrow range variation ratio compare range ratio',
#  'field relationship andsmnd isochron fozzanopeloso lead calculate young age agree zem age determine',
#  'group sample indicatecrustal origin rocks mantle affinity',
#  'bepossible distinguish granitic rock suchdiagram',
#  'oxygen isotope datum rock sovalue range mgk',
#  'acidic rock low common rocktype composition variscan intrusion',
#  'rock showregular increase rock granodiorite leucomonzogranite',
#  'lack gap acidic rock eithercogenetic relationship silicic rock deriving hybridization process bridge gap endmember',
#  'isotope fractionation observe acidic term large result fractional wholerock plot content usedifferentiation',
#  'trend compare observe oceanic ascension island south atlantic wherefractionation trend considergood estimate isotope behaviour accompany fractional crystallization',
#  'difference fractionation trend large attribute temperature difference plutonic volcanic process',
#  'result imply association create magma batch',
#  'high rock sample explain isotopic contamination magma crustal rock occur enclave acidic pluton granodiorite evidence magmatic interaction low aovalue',
#  'isotopic composition ofsr concentration ofrb variscan calcalkaline rock western corsica variscan highmgk granitoid associate rocks age sample rb tdm ppm ppm ppm ppm smow',
#  'calcalkaline rock western assume granodiorite assume clb clb',
#  'clb clb clb clb clb clb bleucocratic age clb clb clb clb clb clb clb clb mafic suite assume age lm clb clb clb pv clb clb clb clb clb clb clb',
#  'continue sample rb smp ppm ppm ppm ppm tdm smow variscan highmgk granitoid associate mafic rock age I',
#  'parameter calculation deplete mantle model age ekd wasserburg nua wasserburg tdm calculate accord depaolo',
#  'mgk association doshow regular trend calcalkaline composite association syenomonzonite range monzodiorite overlap syenomonzonite',
#  'exception contaminate hybridize sample rock low jlsovalue typical ofmantle origin',
#  'variscan plutonic rock previous study high rock',
#  'leucomonzogranite havenarrow range aovalue low variscan twomica granite',
#  'trend differentiation correspond fractional crystallization acidic magma monzogranitic composition trend',
#  'trend increase initial ratio increase sovalue crustal contamination assimilation fractional crystallization ofmantlederived magma direct acidbasic hybridization',
#  'underline narrow range variation iso',
#  'plot corsican variscan granitoid rock',
#  'isochron mgk suite granite sample diamond',
#  'basic rock solid diamond dodefine isochron',
#  'group rock withnarrow range variation ratio definecorrelation indicative age compose sample fall reference isochron representmixing text discussion',
#  'distribution basic rock association diagram compare reference isochron',
#  'isochron granitoid rock chemical geology',
#  'hafic rock I granodiorite I',
#  'assimilation contamination correspond magma showmantle origin',
#  'ratio calculate age usepresentday isotope composition ratio',
#  'pyrenean datum rigut trois seigneur pluton',
#  'wholerock sovalue content calcalkaline rock association corsica',
#  'evolution trend ascension volcanic rock plot comparison',
#  'tope datum rock type contrast corsican pyrenean granitoid rock',
#  'thuslarge mantle contribution mafic magma evident corsica trend doextrapolate endmember mantletype',
#  'isotope datum uz mafic rock mantlederived acidic rock crustalderive fromsource isotope composition',
#  'intermediate granodiorite result mix process',
#  'southern variscan realmclear isotopic zonation corsica origin discuss infurther',
#  'mgk association association genetic relationship magma process involve appendix characteristic origin primary liquid',
#  'question concern comag chemical geology',
#  'sro diagram analyse rock symbol suite indicatemantle affinity althoughcrustal contamination trend large arrow correspond evolution mafic rock corsica showgeneral trend mixingcontamination initial magma mantle origin narrow isotopic range variation granite withweak increase differentiate rock trend',
#  'correspond typical granite associate rock nres',
#  'matic acid rocks cocherie genetic link exist mgk rock chemical mineral datum isotope',
#  'magmatic process lead association rock',
#  'majorand traceelement datum geochemical characteristic rock mgk association high concentration high content incompatible element rb lree hf strong ree fractionation large anomaly',
#  'decrease ree content correlate increase content',
#  'mineral composition vary felsic rocktype',
#  'fact pointgenetic link rock include mafic',
#  'isotope datum suchgenetic isochron diagram ultrak mafic rock doplot isochron acidic rock rocks definelinear correlation intersect representative point plot isochron locate',
#  'correlation interpretmixing betweenmantle endmember andcrustal component distinct felsic mgksuite protolith',
#  'felsic rock havenarrow range variation maric rock range mix mantlederived material andcrustal component crustal source felsic magma',
#  'low sample isotopic disequilibrium ornonmagmatic equilibrium temperature mineralogical study point equilibrium',
#  'mgk mafic rock provide evidence noncogenetic character mafic felsic rock mgk association',
#  'isotope datum distinguish group sample compositional gap harker projection',
#  'gap acid rock yield mix group compose rock scatter isotope',
#  'isotope characteristic mgk granite range monzodiorite leucosyenogranite indicatepossible cogenetic suite test traceelement calculation',
#  'ultrak mafic rock data point mafic mgk rock scatter rbsrisochron srnd diagram suggestmixing process endmember consist mantlederived material andcrustal component',
#  'accord isotope datum crustal component compare mgk granite',
#  'chemical geology crustal endmember docontribute magma mgk acidic rock',
#  'additional evidence provide ree pattern sample contaminate sample respect isotope',
#  'ree fractionation normal detrital sedimentary rock wildeman haskin mgk granite great hree fractionation',
#  'yb ratio varyfunction crustal component isochron decrease increase sri decrease',
#  'high lree content characteristic ofprimary mantlederived magma butofcrustal component',
#  'magma mixing assimilation silicarich crustal material bethe enrichment igneous rock',
#  'spiderdiagram plot ultrak rock identify lamprophyre',
#  'question origin highly potassic mantlederived model proposehigh degree crystal fractionation yoder zone refining harris extremely small degree partial melting garnetperidotite mantle material sun fusion ofmetasomatize mantle source bell hawkesworth wass rogers windom boettcher leaching wall rock enrichment incompatible element ascent melt',
#  'finally propose melt fraction small separate mantie metasomatize layer small melt fraction accumulate remelt low temperature adiabatic decompression crust stretch throughtemperature increase byhot plume potassic magma',
#  'srbbath uta lacesr ndsmzrhf euti tbyb',
#  'traceelement abundance gabbro sample clb representative primitive mafic magma associate granite',
#  'sequence element base order decrease incompatibility oceanic basalt',
#  'datum compare average nmorb emorb sun average calcalkaline lamprophyre estimate rock',
#  'opinion difficult imagine fluid actcarrier chemical element lree rb hf ta',
#  'propose metasomatic fluid involve major favour melting process produce extensive change general chemistry melt product',
#  'production ultrak mafic rock fromzonerefine process fit traceelement isotope datum corsican mafic rock',
#  'hypothetical stagephlogopite garnet bear source melt depth',
#  'magma inducezonerefine process traverse mantle lead tosignificant increase incompatibleelement content isotopic characteristic melt remain mantle affinity chemical geology increase concentration',
#  'insecond stage enrich magma interact base crust lead lower yb high low ratio',
#  'interaction contamination assimilation crystal fractionation associate mgk felsic rock doseem major process involve',
#  'fractional crystallization acidic rockdiscussion relationship mgk granite traceelement datum identification magmatic process involve petrogenetic model mineral proportion equilibrium liquid rate evolution magmatic process quantify traceelement ree pattern',
#  'increase zree decrease ppm content anomaly fairly constant rb content ppm',
#  'loglog diagram compatibleelement concentration decrease sharply incompatible element rb increase moderately',
#  'datum agree fractional crystallization frommonzodioritic toleucosyenogranitic magma magma mixing partial melting',
#  'ree yb rb plot onloglog scale',
#  'yb correlation fairly good average correlation coefficient',
#  'provide additional evidence fractional crystallization process explain geochemical trend monzonitic syenogranitic composition',
#  'correlation distribution coefficient remain constant suggestfirst approximation proportion crystallize solid phase begreatly modify magmatic evolution',
#  'simultaneous modelling ree rb test fractional crystallization model ree identify mineral proportion cumulate phase calculate extent fractional crystallization process',
#  'calculate concentration ofrb evolve liquid fit analyse sample heavy biotite plagioclase kfeldspar',
#  'hand ree control amphibole accessory apatite zircon auanite titanite case titanite play crystallization',
#  'calculate ree concentration amphibole titanite lead ree pattern experimental datum initial concentration primitive liquid monzodioritic composition select correlation diagram',
#  'traceelement content I initial liquid monzodioritic composition define support isotope datum study origin primary acidic magma',
#  'summarize geochemical mineral chemical datum rock lead existence maficfelsic interaction association lead torock intermediate composition support field evidence mix process occurrence microgranular enclave ultrapotassic composition monzonite monzogranodiorite',
#  'isotope datum suggestgap mantlederived ultrapotassic felsic magma crustal origin interaction magma',
#  'rock sample belong calcalkaline association collect var chemical geology',
#  'plot ree rb onloglog scale highmgk granite',
#  'calculate correlation fine suggestonestage crystallization process',
#  'rb behave incompatible element decrease increase crystallization',
#  'heavy calculate model fit fine statistical',
#  'calculate ree pattern mgk granite',
#  'ree concentration initial liquid graphically estimate loglog diagram',
#  'ious location ofpila canale levie roccapina small mafic septum',
#  'sample analyse major trace element ree time unclear mantle crustal source',
#  'inverse geochemical method appendix traceelement datum loglog diagram cocherie demonstrate variation result fractional crystallization point representative liquid fall nearstraight characteristic suchprocess',
#  'method graphic determination bulkdistribution coefficient compatible incompatible hygromagmatophile rb ta hf element cocherie covariance fourteen pair element',
#  'pila canale select quantitative study large size wide variety composition range troctolite diorite sample plot onstraight onlog log ta diagram',
#  'range composition gabbro diorite cumulative troctolite cumulative texture considerpure cumulate',
#  'texture location diagram cumulate equilibrium fractionated highly fractionated liquid',
#  'point plot scatter cumulative liquidevolution chemical geology traceelement model calculation fractional crystallization useprimitive liquid monzodioritic composition produce mgk association kd plagiokfeldbioamphititaclase spar rite bole rb gd yb kd individual partition coefficient study element empirically determine measure concentration separated biotite amphibole plagioclase concentration rock',
#  'calcalkaline granitoid association range composition diorite granodiorite',
#  'dcalculate bulk distribution coefficient respective proportion crystallize plagioclase kfeldspar biotite amphibole titanite',
#  'initial concentration primitive monzodiorite infer correlation diagram',
#  'liquid concentration accord rayleigh distillation law',
#  'concentration compare sample concentration list',
#  'accessory mineral chromite playmajor concentration',
#  'consideration inverse geochemical approach hypothesis bulkdistribution coefficient phase equilibrium liquid',
#  'knowledge bulk dvalue rb ta hf concentration differentiated melt enable calculation degree fractional crystallization',
#  'calculate fvalue correspond tohigh degree crystallization',
#  'cumulate remain equilibrium evolve melt liquid question cogenetic',
#  'test model base conventional ree systematic',
#  'ree concentration melt calculate determine fractionalcrystallization model rayleigh distillation law ree content identify pure cumulate',
#  'identify ree content initial liquid evaluate degree fractional crystallization order compare calculate loglog diagram',
#  'calculation dorequireknowledge partition coefficient analyse cumulate assume representative instantaneous solid phase equilibrium evolve liquid',
#  'accord kind cumulate troctolite low hygromagmatophileelement content transitionelement enrichment gabbronorite gabbro low transitionmetal content',
#  'logarithmic plot ta basic rock associate association variscan batholith corsica',
#  'trend symbol correspond rock representative ofmelt pila canale solid symbol represent cumulate',
#  'cumulate rock plot trend compose cumulate mineral interstitial mineral representative melt equilibrium',
#  'ree pattern plot threestage fractionalcrystallization model accord rayleigh law summarize',
#  'calculate initial liquid fit composition ofgabbro clb rossi initial melt basis field petrological datum',
#  'calculate crystallization close determine trace element inverse approach',
#  'ree calculation loglog diagram demonstrate mafic rock regard suite evolve accord tofractionalcrystallization process',
#  'isotope heterogeneous gabbro troctolite diorite',
#  'fractionalcrystallization process afc ree content diorite clb high compare granite considerresult afc process',
#  'afc process involve assimilate material doderive granite magma',
#  'crustal fluid interact mafic magma fractional crystallization',
#  'solidify liquid gabbro primitive cumulate troctolite retain primitive isotopic character evolve magma diorite interact duringmuch long period crustal fluid',
#  'kind interaction doseem disturb majorand traceelement geochemistry',
#  'origin mafic rock point mafic rock calcalkaline association origin nature source material degree homogeneity source material tectonic environment time magma emplacement',
#  'scheme threestage fractionalcrystallization model liquid cumulate',
#  'gabbro diorite clb chemical geology ree calculate liquid mafic suite accord tofractional crystallization model clb clb',
#  'gd yb calculate lovalue compare analyse rock clb text explanation',
#  'interpolate bracket traceelement calculation usenonmodal batch partial melting model shaw produce mantlederived liquid correspond mafic suite kd mauna loa amphibole spinel mantle flow clb lherzolite iherzolite shaw olivclinoorthoamphispinel',
#  'ine pyroxpyroxbole ene ene rb',
#  'gd yb partition coefficient arth extrapolate bracket concern spinel kay gast',
#  'clb sample corsican mafic suite representative primitive liquid',
#  'calculate traceelement concentration inmantle amphibole opx cpx amph solid phase involve melt opx amph',
#  'traceelement concentration inmantle spinel opx cpx solid phase contribute melt opx cpx',
#  'srndoisotope datum mafic rock indicatejuvenile origin time batholith formation',
#  'age correct diagram contaminated mafic sample plotfar mantle reference field',
#  'isotopic point view impossible choose juvenile lowercrustal material direct partial melting mantle source',
#  'alternative reject traceelement datum chemical geology fractional crystallization model calculate traceelement composition primitive liquid monzogranitic composition kd clb plagiokfeldmona clase spar zite rb gd yb kd partition coefficient plagioclase kfeldspar arth monazite correspond ratio analyse monazite leucocratic yb ppm average content rock',
#  'clb analyse primitive monzogranitic liquid',
#  'calculate bulk distribution coefficient respective proportion crystallize plagioclase kfeldspar monazite',
#  'calculate bulk distribution coefficient respective proportion crystallize plagioclase kfeldspar monazite',
#  'liquid calculate accord rayleigh distillation law',
#  'twostage model lead tobulk crystallization',
#  'calculate concentration fit average concentration measure differentiated sample leucocratic sample respec',
#  'initial liquid clb low rb content ppm low ree content withslightly fractionated ree pattern chondrite chondrite twostage model involve partial melting mantle follow bysecond partial melting solidify melt high incompatibleelement concentration',
#  'partial melting garnetlherzolite easily reject view experimentally determine ree pattern initial liquid calculate pattern initial liquid becausegarnet residue partial melting lead liquid hreedepleted pattern',
#  'experimental green tholeiitic basalt form equilibrium residual garnet',
#  'mantlesource assemblage giveliquid tholeiitic calcalkaline composition amphibole lherzolite spinel lherzolite',
#  'type source assemblage test calculate ree rb content ofpossible mantle assume chondritic abundance trace element mantle calculate primary magma',
#  'melt amphibole lherzolite spinel lherzolite calculation traceelement concentration lead fiat ree pattern chondrite rb compatible mantle material shaw',
#  'traceelement datum dosuffice choose mantle source assemblage',
#  'large variation hree content sample plot chemical geology mantle heterogeneity hree',
#  'geochemical datum compare rocks presentday volcanism',
#  'resemble tholeiitic islandarc basalt western sunda volcanic arc indonesia content ree pattern flat islandarc rock case',
#  'ta ratio geochemical tool remain constant magmatic fusion crystallization incompatible element behaviour',
#  'ratio characterize source material tectonic environment magmarie process',
#  'gabbro identify clb havelow ta ratio typical extensional tectonic area spread ridge intraplate magmatism',
#  'high ta ratio relate convergentplate tectonic environment subduction zone',
#  'study tholeiitic basalt dredge midatlantic ridge basic rock',
#  'tholeiitic basalt enrich incompatible trace element compare tholeiitic midocean ridge basalt morb associate alkali olivine basalt',
#  'regard result vertical heterogeneity mantle composition',
#  'tholeiitic oceanisland basalt eruption ofmauna loa hawaii incompatibleelement abundance',
#  'accord thhfta diagram rock analogous enriched morb',
#  'summary datum absence ofsubduction zone tectonic environment uz plutonism agree palinspastic reconstruction',
#  'rock tholeiitic composition enrich incompatible element regard oceanfloor basalt compare etype morb oceanisland basalt produce nonmodal partial melting ofheterogeneous mantle spinel amphibole peridotite garnet condition asthenospheric ascent',
#  'leucomonzogranite granitic rock contrast mafic suite characteristic trend loglog diagram',
#  'explanation granite body begenetically link isotope datum indicatecogenetic differentiation unidentified magmatic process poor interelement diagram clustering representative point isochron indicaterather large interval ree ta rb incompatible acidic melt basic dvalue approach exceed compatible element dvalue close',
#  'withhigh degree differentiation magmatic process variation concentration slight',
#  'geochemical argument leucomonzogranite derive loglog diagram log log rb general negative trend observe decrease compatibleelement content associate withrather moderate increase incompatibleelement content',
#  'betypical variation trend element pair fractional crystallization ofmagmatic suite',
#  'homogeneous isotope sri increase acceptable forsuite rock relate throughhigh degree fractional crystallization',
#  'degree ofree fractionation vary highly lreeenriched pattern anomaly rock clb leucomonzogranite fiat normalize pattern huge negative anomaly',
#  'decrease concentration relate increase content feldspar magmatic differentiation initial monzogranitic melt',
#  'calculate ree pattern calcalkaline granite',
#  'twostage fractional crystallization model involve feldspar monazite fit datum',
#  'decrease associate increase concentration rb imply crystallization kfeldspar mica',
#  'large increase hree concentration quartz crystallization order reduce hree bulk distribution coefficient',
#  'primitive monzogranitic melt havecomposition close granite',
#  'crystallization major phase qz kfs besufficient account lree accessory lreeenriche phase allanite monazite accompany major phase',
#  'accessory acttrap lree lead todecrease lree content increase crystallization',
#  'twostage fractional crystallization model involve rb ree concentration compare calculate concentration residual liquid observe concentration calcalkaline granite',
#  'direct calculation method estimate follow parameter select primitive liquid clb low content weak negative anomaly compare order calculate bulk distribution coefficient individual partition coefficient mineral involve magmatic differentiation',
#  'calculate liquid concentration stage close average concentration sampie differentiate increase rb hree decrease lree compare primitive',
#  'stage lead leucocratic liquid compare average leucocratic sample',
#  'previous trend traceelement content confirm calculate ree pattern',
#  'monzograniteleucomonzogranite association considersuite evolve accord tofractionalcrystallization model initial liquid monzogranitic composition',
#  'granodiorite byproduct magma mixing decipher origin rock intermediate composition granodiorite bridge gap mafic acidic endmember crucial interpret genesis calcalkaline association',
#  'isotope datum mafic rock origin mantlederived magma acidic crustalderived material',
#  'existence ofstatistical gap trend correspond granodioritic composition emphasize key place rock interpretation ofplutonic association',
#  'acidicmafic mingle zone granodiorite observe field corsica rossi mingle mixing study sardinia conclude origin microgranular mafic enclave granodiorite seek mix mafic silicic magma',
#  'discuss suchsuite rock intermediate composition characterize strong geochemical heterogeneity',
#  'essential nature origin mixing batch define accurately order place constraint genesis rock intermediate composition chemical geology association',
#  'corsican suited purpose good exposure mafic rock permit detailed investigation nature endmember',
#  'traceelement loglog diagram rb relationship granodiorite tight clustering representative point',
#  'diagram granodiorite point dofit alongsingle isochron',
#  'group rock group roughly plot reference isochron high model initial ratio group rock clb plot onstraight withmuch low initial ratio age inconsistent field relationship',
#  'trend define granodiorite representative point close isochron high sio traceelement content ree clb theyso primitive monzogranitic liquid',
#  'shape anomaly level ree abundance differentiate clb',
#  'group acidic geochemical characteristic specific ree pattern clb high hree content andpronounce negative anomaly typical highly differentiate rock',
#  'major traceelement isotope feature providepicture inconsistent withdirect common origin group granodiorite',
#  'group andlow model initial ratio interpretresult mixing mafic silicic endmember',
#  'I I I I I',
#  'group represent sample plot alongmixing endmember differentiate basic rock crystallize monzogranitic melt lead tomixing pseudoisochron',
#  'group consist sample cluster differentiated definefractional crystallization trend agreement calculate isochron',
#  'plot association mix trend granodiorite highly differentiated magma',
#  'test suchhypothesis initial ratio endmember bevery prefer presentday diagram yieldmixing sample link bymixing process bernardgriffith scharbert',
#  'providecurve forsuite rock evolve differentiation',
#  'emphasize test rb content remain constant entire rock suite case plot bemathematically straight',
#  'case rb concentration increase accord sequence dioritic monzogranitic clb',
#  'representative point group granodiorite clb yieldpseudoisochron givemixing endmember narrow field mafic rock differentiated monzogranitic magma correspond high ratio isochron',
#  'representative point granodiorite group definesmall field close fractionalcrystallization trend confirm great similarity group granodiorite differentiated',
#  'test involvesimple binary diagram require element large variation case mixing magma lead tostraight type curve accord magmatic process involve',
#  'variation diagram granodioritic magma result ofmixing process differentiated melt mafic suite monzogranitic magma differentiation stage leucomonzogranitic stage',
#  'field structural consideration granodiorite group couldhave intrusive comparable chemical mineral composition style textural disequilibrium group microgranular mafic enclave interpret quench inclusion mafic magma suffer extensive disaggregation reequilibration',
#  'group plot close reference isochron slight contamination mafic magma acquire isotopic homogeneity plot infield traceelement composition close',
#  'group doachieve isotope homogeneity mafic material involve',
#  'group batch magma chill stage mix intrusive unit',
#  'source granite ratio granitoidrock composition indicatesingle source raise question chemical geology',
#  'calculate ree pattern granitoid rock accord tononmodal batch partialmelting model',
#  'liquid obtainfunction metamorphic high mgk liquid granulite calcalkaline liquid high pmo condition',
#  'calculate ree pattern compare initial liquid analyse rock sample clb',
#  'corsican granulitic paragneiss regard representative ofpossible protolith',
#  'idea partial melting traceelement content resuite magma depend percentage residual phase feldspar biotite rb amphibole garnet ree',
#  'solid source orsingle successively undergo metamorphic event high pressure low hydrous condition',
#  'arth granite melt produce partial melting graywacketype rock',
#  'precambrian wildeman haskin arth archaean wildeman condie',
#  'lree rock vary ppm lree fractionated pattern hree fractionated enrich pattern withnegative anomaly decrease decrease total ree content',
#  'average ree pattern quartzrich quartzintermediate graywacke representative average reedistribution pattern solid source',
#  'model melting rock withgraywacke composition bedry initial assemblage granulite hydrous assemblage amphibolite facie',
#  'good fit partial melting case granulite amphibolite facie calculated experimental ree datum',
#  'calculation rb set perfectly agree',
#  'bediscrepancy calculate amphibolitefacies model concentration analyse sample',
#  'explanation plagioclase initial source partition coefficient liq underestimate',
#  'high kdvalue realistic granitic melt accord arth calculate datum agree experimental concentration',
#  'source high tlow granulitic paragneiss libourel analyse trace element table rb ree analysis compare model graywacke source',
#  'ree pattern corsican granulite definefield close ree pattern graywacke high hree content',
#  'melt granulite facie paragneiss givemonzodioritic liquid melt amphibolite facie lead tomonzogranitic liquid',
#  'cocherie rossi composition granite chemical geology traceelement calculation usenonmodal batch partial melting model produce initial granitic liquid composition kd gneiss granulitic model amphibolite facie model orthogarnet apatite',
#  'pyroxene clb rb gd yb partition coefficient arth plagioclase kfeldspar biotite amphibole list interpolate bracket',
#  'correspond average corsican granulitic paragneiss',
#  'traceelement concentration initial solid source material',
#  'corsican granulitic gneiss compare select traceelement concentration text explanation',
#  'bulk distribution coefficient dry initial assemblage',
#  'bulk distribution coefficient correspond follow proportion mineral contribute qz kfs',
#  'calculate traceelement content melt accord dry model compare content primitive monzodiorite melt',
#  'distribution coefficient calculate follow mineral qz bio amph gt qz bio amph',
#  'traceelement content melt accord hydrous model compare clb content primitive melt',
#  'control physicochemical fusion parameter composition protolith',
#  'age granite source material source involve granitoidmagma genesis havegraywacke composition',
#  'lead ratio compare average rb content corsican granulitic gneiss',
#  'ago age initial ratio close',
#  'considertwostage model protolith derive fromdepletedtype mantle withsri average age source material calculate base ratio',
#  'beminimum age acidbasic magma interaction lower initial ratio granite',
#  'inherit zircon continental crust gabbro peloso cmu age agree calculation',
#  'strontium model age compare model age',
#  'list average close assume granite age',
#  'average ratio granulitic paragneiss representative source protolith calculate ratio providemodel time evolution intercept deplete mantle growth curve givemodel age',
#  'age close calculate age individual sample ratio rock question assume source rock',
#  'difference model age evolution band deplete mantle diagram wide',
#  'diagram basic rock granitoid rock',
#  'define source material obtainmodel age tdm calculate individual sample ratio analyse sample protolith',
#  'basic rock associate association rootfar mantle evolution trend',
#  'olwinerich rock peridotite composition shownegative slope',
#  'evolution rare link high ratio high chur ratio',
#  'chondritenormalized ree pattern plot arndt goldstein iall model age representmixture material derive mantle time correspond major orogenic event',
#  'comparison corsican sardinian batholiths oligocenemiocene oceanization western mediterranean region continuous variscan crust exist corsica sardinia possibility investigatelarge variscan orogenic belt',
#  'geochemical datum pyrenean variscan pluton summarize cocherie autran',
#  'calcalkaline geochemical trend pyrenean pluton budduso massif northeastern sardinia corsican unit discuss',
#  'uniform geochemical behaviour hercynian pluton corsica sardinia pyrrnre beconfirm isotope datum',
#  'sardinia initial ratio budduso massif cocherie close unpublished cite sarrabus massif bono intrusive complex',
#  'geochemical trend rock ofgranodioritic monzogranitic average scatter corsican granite pyrenean granite intermediate sardinia',
#  'evolution corsica smnd isotope datum',
#  'increase average pyrenean rigut pluton trois seigneur massif granodiorite bono complex sardinia corsican batholith',
#  'type granite remain variscan chain corsicasardinia frompetrological mineralogical majorand traceelement geochemistry point view',
#  'broadscale zoning reveal isotope inherit deep source granite',
#  'regional isotope zonation batholith generate boundary eastern western terrane rossi cocherie granite corsican batholith chemical geology belong terrane granite sardinia pyrrnre',
#  'conclusion corsican batholith pluton southern realm variscan chain lead insight variscan continental growth origin emplacement socalled plutonic association',
#  'successively emplace magmatic association result mixing noncogenetic mafic silicic magma',
#  'type mantle melt mafic ultrak magma result fusion ofphlogopite garnet metasomatize mantle andsecond stagezonerefine process lead increase incompatible traceelement content',
#  'finally magma interact base crust lead lower yb high ratio melt',
#  'magma result nonmodal partial melting ofspinel amphibolite lherzolitic mantle',
#  'primitive silicic magma low ratio low high',
#  'derive continental source melt condition fusion lead initial liquid monzodioritic monzogranitic',
#  'emphasize fluid content melting condition anatexis continental crust involve generation granitic melt',
#  'intermediate rock granodiorite result mix preexist rock mafic silicic composition',
#  'isotope majorand traceelement geochemistry support evidence mix process silicic endmember completely blend',
#  'microgranular enclave intermediate acid rock association shape undisrupted bubble mafic magma chemically equilibrate insilicic environment remain remnant process',
#  'magma intermediate composition bridge gap mafic silicic endmember',
#  'suchcase calcalkaline trend american coastal batholith relate subduction beneathcontinental margin result fractional crystallization ofbasalt source',
#  'variscan plutonism unconsidered term misleading',
#  'isotopic constraint estimate age protolith corsican protolith young sardinian pyrenean batholith provide evidence crustalaccretion process',
#  'major difference assume mantle source yield mafic ul magma agree progressive uplift asthenosphere elithosphere extensional stress',
#  'lead melting ofdeep phlogopite garnet mantle melt shallow garnetfree spinel lherzolitic mantle finally alkaline volcanicplutonic episode',
#  'constrain emplacement calcalkalic plutonism postcollisional crustalthinning condition',
#  'acknowledgement autran helpful discussion suggestion',
#  'grateful des sciences siie laboratory saclay france caess rennes france trace element isotope analyse byc',
#  'centre recherches sur synthrse chimie des minrraux laboratory orlran study carry',
#  'anonymous reviewer improve version manuscript',
#  'chemical geology appendixm petrographical mineralogical datum rock analytical datumpresent rossi cocherie',
#  'association intermediate acid rock havetypical mineralogical abundant apatite zircon early augite clinopyroxene surround actinolitic hornblende composition caplagioclase omonzonite osyenogranite barich foxyre mgtibiotite ilmenite abundant sulphide macroscopic titanite ubiquitous',
#  'ultrapotassic rock melasyenite melamonzonite display common characteristic crdiopside augite clinopyroxene caplagioclase foxyre mgtibiotite rare relic phlogopitic mica',
#  'ilmenite commonly surround sphene abundant magnetite scarce',
#  'occurrence crspinel micaceous aggregate represent relic olivine',
#  'systematic presence actinolitic hornblende characteristic rock',
#  'typically secondary biotite habit occur mineral crack aggregate',
#  'early mineral zircon thorite allanite apatite sphene sulphide pyrrhotite chalcopyrite exsolution pentlandite oxide ilmenite futile exsolution ilmenite',
#  'plagioclase kfeldspar quartz biotite magnesian hornblendeamphibole relict crdiopside apatite ilmenite titanite',
#  'association intermediate acid granodiorite plagioclase oamphibole biotite occur magnetite allanite apatite titanite accessory',
#  'composition biotitebeare leucomonzogranite close thermal minimum almandinespessartine garnet occur accessory phase',
#  'ultramafic mafic peridotite haveheteradcumulate texture cumulate olivine intercumulus clinopyroxene partly replace pargasitic hornblende plagioclase crspinel ilmenite magnetite sulphide',
#  'troctolite lm mesocumulate texture plagioclase olivine foso orthopyroxene clinopyroxene',
#  'gabbro assume liquid composition clb texture orthocumulate plagioclase olivine clinopyroxene orthopyroxene brown amphibole ilmenite magnetite green spinel sulphide',
#  'gabbronorite orthocumulate texture plagioclase olivine orthopyroxene clinopyroxene poikilitic brown hornblende apatite ilmenite biotite',
#  'gabbronorite cumulate texture strong igneous lamination plagioclase orthopyroxene proportion equivalent plagioclase clinopyroxene poikilitic brown hornblende biotite apatite quartz',
#  'orthopyroxenebeare granodiorite clb mediumto coarsegrained texture plagioclase kfeldspar quartz orthopyroxene clinopyroxene etch green amphibole biotite opaque',
#  'norite pv clb clb heteradcumulate texture cumulate olivine cumulative plagioclase poikilitic orthopyroxene heteradcumulate pargasitic hornblende partly replace relict clinopyroxene ilmenite magnetite sulphide green spinel',
#  'gabbro clb clb coarsegrained texture plagioclase relict core large rim magnesian hornblende include relict orthopyroxene biotite itmenite magnetite',
#  'gabbrodiorite diorite clb clb clb fineto mediumgraine texture plagioclase relict core anso ferrohornblende amphibole biotite quartz ilmenite magnetite',
#  'diorite clb clb fineto mediumgraine texture plagioclase relict core green amphibole poikilitic biotite poikilitic kfeldspar quartz apatite titanite ilmenite magnetite',
#  'appendix inverse geochemical approach direct geochemical approach trace element requirechoice magmatic model realistic fvalue weight fraction residual liquid bulkdistribution coefficient publish individual melt partition coefficient verification analyse rock fit predicted model parameter',
#  'suitable inverse approach examine datum distribution diagram order identify evolutionary process',
#  'cocherie evolutionary process easily identify plot traceelement couple dvalue',
#  'case fractional crystallization parameter evolutionary process determine graphically cocherie assumption concern initial magma proportion mineral equilibrium evolve melt',
#  'manner discuss source material primary liquid']

# %%
#Auto Read entities
dict_entities={}
path='C:/Users/Ryan Bobby A/Documents/RWTH AACHEN/KULIAH/THESIS_BISMILLAH/Thesis Progress/list_entities/'
for filename in glob.glob(os.path.join(path, '*.txt')):
    gist_file = open(filename, "r")
    try:
        content = gist_file.read().lower()
        dict_entities[re.search(r'(\w+).txt$',filename).group(1)] = content.split("\n")
    finally:
        gist_file.close()
dict_entities
# Out:
# {'list_chrono': ['precambrium',
#   'hadean',
#   'archean',
#   'eoarchean',
#   'paleoarchean',
#   'mesoarchean',
#   'neoarchean',
#   'proterozoic',
#   'paleoproterozoic',
#   'siderian',
#   'rhyacian',
#   'orosirian',
#   'satherian',
#   'mesoproterozoic',
#   'calymmian',
#   'ectasian',
#   'stenian',
#   'neoproterozoic',
#   'tonian',
#   'cryogenian',
#   'ediacaran',
#   'phanerozoic',
#   'paleozoic',
#   'cambrian',
#   'terreneuvian',
#   'fortunian',
#   'cambrian stage 2',
#   'cambrian series 2',
#   'cambrian stage 3',
#   'cambrian stage 4',
#   'cambrian series 3',
#   'cambrian stage 5',
#   'drumian',
#   'guzhangian',
#   'furongian',
#   'paibian',
#   'jingshanian',
#   'stage 10',
#   'ordovician',
#   'lower ordovician',
#   'tremadocian',
#   'floian',
#   'middle ordovician',
#   'dapingian',
#   'darriwilian',
#   'upper ordovician',
#   'sandbian',
#   'katian',
#   'hirnantian',
#   'silurian',
#   'llandovery',
#   'rhuddanian',
#   'aeronian',
#   'telychian',
#   'wenlock',
#   'sheinwoodian',
#   'homerian',
#   'ludlow',
#   'gorstian',
#   'ludfordian',
#   'pridoli',
#   'devonian',
#   'lower devonian',
#   'lochkovian',
#   'pragian',
#   'emsian',
#   'middle devonian',
#   'eifelian',
#   'givetian',
#   'upper devonian',
#   'frasnian',
#   'famennian',
#   'carboniferous',
#   'mississippian',
#   'lower mississippian',
#   'tournaisian',
#   'middle mississippian',
#   'visean',
#   'upper mississippian',
#   'serpukhovian',
#   'pennsylvanian',
#   'lower pennsylvanian',
#   'bashkirian',
#   'middle pennsylvanian',
#   'moscovian',
#   'upper pennsylvanian',
#   'kasimovian',
#   'gzhelian',
#   'permian',
#   'cisuralian',
#   'asselian',
#   'sakmarian',
#   'artinskian',
#   'kungurian',
#   'guadalupian',
#   'roadian',
#   'wordian',
#   'capitanian',
#   'lopingian',
#   'wuchiapingian',
#   'changhsingian',
#   'mesozoic',
#   'triassic',
#   'lower triassic',
#   'induan',
#   'olenekian',
#   'middle triassic',
#   'anisian',
#   'ladinian',
#   'upper triassic',
#   'carnian',
#   'norian',
#   'rhaetian',
#   'jurassic',
#   'lower jurassic',
#   'hettangian',
#   'sinemurian',
#   'pliensbachian',
#   'toarcian',
#   'middle jurassic',
#   'alenian',
#   'bajocian',
#   'bathonian',
#   'callovian',
#   'upper jurassic',
#   'oxfordian',
#   'kimmeridgian',
#   'tithonian',
#   'cretaceous',
#   'lower cretaceous',
#   'berriasian',
#   'valanginian',
#   'hauterivian',
#   'barremian',
#   'aptian',
#   'albian',
#   'upper cretaceous',
#   'cenomanian',
#   'turonian',
#   'coniacian',
#   'santonian',
#   'campanian',
#   'maastrichtian',
#   'cenozoic',
#   'paleogene',
#   'paleocene',
#   'danian',
#   'selandian',
#   'thanetian',
#   'eocene',
#   'ypresian',
#   'lutetian',
#   'bartonian',
#   'priabonian',
#   'oligocene',
#   'rupelian',
#   'chattian',
#   'neogene',
#   'miocene',
#   'aquitanian',
#   'burdigalian',
#   'langhian',
#   'serravallian',
#   'tortonian',
#   'messinian',
#   'pliocene',
#   'zanclean',
#   'piacenzian',
#   'quaternary',
#   'pleistocene',
#   'gelasian ',
#   'calabrian ',
#   'middle pleistocene',
#   'upper pleistocene',
#   'holocene'],
#  'list_countries': ['afghanistan',
#   'aland islands',
#   'albania',
#   'algeria',
#   'american samoa',
#   'andorra',
#   'angola',
#   'anguilla',
#   'antarctica',
#   'antigua and barbuda',
#   'argentina',
#   'armenia',
#   'aruba',
#   'australia',
#   'austria',
#   'azerbaijan',
#   'bahamas',
#   'bahrain',
#   'bangladesh',
#   'barbados',
#   'belarus',
#   'belgium',
#   'belize',
#   'benin',
#   'bermuda',
#   'bhutan',
#   'bolivia, plurinational state of',
#   'bonaire, sint eustatius and saba',
#   'bosnia and herzegovina',
#   'botswana',
#   'bouvet island',
#   'brazil',
#   'british indian ocean territory',
#   'brunei darussalam',
#   'bulgaria',
#   'burkina faso',
#   'burundi',
#   'cambodia',
#   'cameroon',
#   'canada',
#   'cape verde',
#   'cayman islands',
#   'central african republic',
#   'chad',
#   'chile',
#   'china',
#   'christmas island',
#   'cocos (keeling) islands',
#   'colombia',
#   'comoros',
#   'congo',
#   'congo, the democratic republic of the',
#   'cook islands',
#   'costa rica',
#   "côte d'ivoire",
#   'croatia',
#   'cuba',
#   'curaçao',
#   'cyprus',
#   'czech republic',
#   'denmark',
#   'djibouti',
#   'dominica',
#   'dominican republic',
#   'ecuador',
#   'egypt',
#   'el salvador',
#   'equatorial guinea',
#   'eritrea',
#   'estonia',
#   'ethiopia',
#   'falkland islands (malvinas)',
#   'faroe islands',
#   'fiji',
#   'finland',
#   'france',
#   'french guiana',
#   'french polynesia',
#   'french southern territories',
#   'gabon',
#   'gambia',
#   'georgia',
#   'germany',
#   'ghana',
#   'gibraltar',
#   'greece',
#   'greenland',
#   'grenada',
#   'guadeloupe',
#   'guam',
#   'guatemala',
#   'guernsey',
#   'guinea',
#   'guinea-bissau',
#   'guyana',
#   'haiti',
#   'heard island and mcdonald islands',
#   'holy see (vatican city state)',
#   'honduras',
#   'hong kong',
#   'hungary',
#   'iceland',
#   'india',
#   'indonesia',
#   'iran, islamic republic of',
#   'iraq',
#   'ireland',
#   'isle of man',
#   'israel',
#   'italy',
#   'jamaica',
#   'japan',
#   'jersey',
#   'jordan',
#   'kazakhstan',
#   'kenya',
#   'kiribati',
#   "korea, democratic people's republic of",
#   'korea, republic of',
#   'kuwait',
#   'kyrgyzstan',
#   "lao people's democratic republic",
#   'latvia',
#   'lebanon',
#   'lesotho',
#   'liberia',
#   'libya',
#   'liechtenstein',
#   'lithuania',
#   'luxembourg',
#   'macao',
#   'macedonia, republic of',
#   'madagascar',
#   'malawi',
#   'malaysia',
#   'maldives',
#   'mali',
#   'malta',
#   'marshall islands',
#   'martinique',
#   'mauritania',
#   'mauritius',
#   'mayotte',
#   'mexico',
#   'micronesia, federated states of',
#   'moldova, republic of',
#   'monaco',
#   'mongolia',
#   'montenegro',
#   'montserrat',
#   'morocco',
#   'mozambique',
#   'myanmar',
#   'namibia',
#   'nauru',
#   'nepal',
#   'netherlands',
#   'new caledonia',
#   'new zealand',
#   'nicaragua',
#   'niger',
#   'nigeria',
#   'niue',
#   'norfolk island',
#   'northern mariana islands',
#   'norway',
#   'oman',
#   'pakistan',
#   'palau',
#   'palestinian territory, occupied',
#   'panama',
#   'papua new guinea',
#   'paraguay',
#   'peru',
#   'philippines',
#   'pitcairn',
#   'poland',
#   'portugal',
#   'puerto rico',
#   'qatar',
#   'réunion',
#   'romania',
#   'russian federation',
#   'rwanda',
#   'saint barthélemy',
#   'saint helena, ascension and tristan da cunha',
#   'saint kitts and nevis',
#   'saint lucia',
#   'saint martin (french part)',
#   'saint pierre and miquelon',
#   'saint vincent and the grenadines',
#   'samoa',
#   'san marino',
#   'sao tome and principe',
#   'saudi arabia',
#   'senegal',
#   'serbia',
#   'seychelles',
#   'sierra leone',
#   'singapore',
#   'sint maarten (dutch part)',
#   'slovakia',
#   'slovenia',
#   'solomon islands',
#   'somalia',
#   'south africa',
#   'south georgia and the south sandwich islands',
#   'spain',
#   'sri lanka',
#   'sudan',
#   'suriname',
#   'south sudan',
#   'svalbard and jan mayen',
#   'swaziland',
#   'sweden',
#   'switzerland',
#   'syrian arab republic',
#   'taiwan, province of china',
#   'tajikistan',
#   'tanzania, united republic of',
#   'thailand',
#   'timor-leste',
#   'togo',
#   'tokelau',
#   'tonga',
#   'trinidad and tobago',
#   'tunisia',
#   'turkey',
#   'turkmenistan',
#   'turks and caicos islands',
#   'tuvalu',
#   'uganda',
#   'ukraine',
#   'united arab emirates',
#   'united kingdom',
#   'united states',
#   'united states minor outlying islands',
#   'uruguay',
#   'uzbekistan',
#   'vanuatu',
#   'venezuela, bolivarian republic of',
#   'viet nam',
#   'virgin islands, british',
#   'virgin islands, u.s.',
#   'wallis and futuna',
#   'yemen',
#   'zambia',
#   'zimbabwe'],
#  'list_eon': ['precambrium', 'phanerozoic', 'archaean', 'proterozoic'],
#  'list_era': ['hadean',
#   'archean',
#   'proterozoic',
#   'paleozoic',
#   'mesozoic',
#   'cenozoic'],
#  'list_geolocation': ['southern urals',
#   'kuznetsk alatau',
#   'berikul region',
#   'klyuchovsky volcano',
#   'kamchatka',
#   'rockport',
#   'belokurikhinsky massif',
#   'altai',
#   'val verde',
#   'porterville',
#   'frederick',
#   'maryland',
#   'westerly',
#   'westfield',
#   'peninsula station',
#   'ont.',
#   'vinal haven',
#   'maine',
#   'barre',
#   'farm doornspruit',
#   'sylmar',
#   'french creek',
#   'stillwater igneous complex',
#   'new glasgow',
#   'mellen',
#   'pilansberg',
#   'balsam gap',
#   'allentown',
#   'bethlehem',
#   'nazareth',
#   'pennsylvania',
#   'pelham',
#   'proctor',
#   'solnhofen',
#   'offshore louisiana',
#   'texas',
#   'kyushu',
#   'mie',
#   'aichi',
#   'kyoto',
#   'oklahoma',
#   'fukushima',
#   'colorado',
#   'iwate',
#   'utah',
#   'wyoming',
#   'hokkaido',
#   'oregon',
#   'twin sisters mountain',
#   'madneuli',
#   'shaori reservoir',
#   'akhalkalaki highlands',
#   'karatsu',
#   'ichinomegata',
#   'horoman',
#   'chiatura',
#   'central asia',
#   'dzirula massif',
#   'jraber',
#   'upper rhine graben',
#   'black forest',
#   'vosges',
#   'upper rhine graben',
#   'koytas',
#   'kandygatay mts.',
#   'kalbinsky massif',
#   'shindinsky massif',
#   'southwest german molasse basin',
#   'south arne',
#   'north sea',
#   'near freiburg',
#   'black forest',
#   'near offenburg',
#   'tyger-tysh ridge',
#   'ulen-tuimsky massif',
#   'uybatsky massif',
#   'karymsky volcano',
#   'kamtchatka',
#   'mid-atlantic ocean ridge',
#   'hawaii',
#   'cerro prieto',
#   'mexicali',
#   'ohio',
#   'kentucky',
#   'west virginia',
#   'idaho',
#   'higo metamorphic belt',
#   'hadaki metamorphic belt',
#   'beni bouchera massif (beni bouzere)',
#   'ivrea zone',
#   'lofoten-vesteralen region',
#   'austvagoya',
#   'langoya',
#   'salem',
#   'mysore',
#   'pallavaram',
#   'madras',
#   'chennai',
#   'tamil nadu',
#   'podili',
#   'kurnool',
#   'andhra pradesh',
#   'vinukonda',
#   'guntur',
#   'vijayawada',
#   'kondapalli',
#   'hyderabad',
#   'yellandalpad',
#   'yellandu',
#   'manditog',
#   'waltair',
#   'visakhapatnam',
#   'maharashtra',
#   'talchir',
#   'chaibasa',
#   'bundelkhand',
#   'south uttar',
#   'north madhya pradesh',
#   'bihar',
#   'kishengarh',
#   'rajasthan',
#   'rajputana',
#   'shahabad',
#   'sujarghar',
#   'halemaumau',
#   'hawaii island',
#   'hualai flow',
#   'india',
#   'maui island',
#   'salt lake crater',
#   'oahu island',
#   'honolulu',
#   'kauai',
#   'molokai or niihau island',
#   'scotland',
#   'sendai',
#   'miyagi prefecture',
#   'hagino',
#   'yamagata prefecture',
#   'nishimonai',
#   'akita prefecture',
#   'tanohata',
#   'iwate prefecture',
#   'transvaal',
#   'usa',
#   'south africa',
#   'hengill',
#   'nesja-vellir',
#   'krafla',
#   'kazakhstan',
#   'caucasus',
#   'pavlovsk',
#   'reunion island',
#   'oskoletsk',
#   'voronezh anteclise',
#   'saltykov',
#   'voronezh massif',
#   'north karelia',
#   'sakhalin island',
#   'mamonov complex',
#   'voronezh massif',
#   'gorky oblast',
#   'oblast of nishni novgorod',
#   'south ural mountains',
#   'ussr far east',
#   'ural',
#   'monchegorsk',
#   'kola peninsula',
#   'pechenga',
#   'seychelles',
#   'gegam plateau',
#   'bezumskiy ridge',
#   'sikhote-alin-ridge',
#   'gorky complex',
#   'udzha river',
#   'indian ocean ridge',
#   'indian ocean island',
#   'referred to as gondwana island',
#   'armenia',
#   'borisov volcano',
#   'baikal region',
#   'avachinsk volcano',
#   'lake baikal',
#   'obnazhennaya formation',
#   'southeast corner of þingvallavatn',
#   'surtsey',
#   'heimaey',
#   'reykjanes',
#   'sandfell',
#   'þrengsli',
#   'vigdísarvelli',
#   'tófubruna hyaloclastited',
#   'vigdísarvellir',
#   'reykjanes',
#   'krísuvík road',
#   'silfurberg',
#   'north of kögunarhóll',
#   'ingólfsfjall quarry',
#   'votuklettar-threngsli',
#   'slightly west of votuklettar',
#   'hyaloclastite',
#   'north of tindafjalla',
#   'west of kirkjufellsós',
#   'raudhnukar',
#   'bláfjalla',
#   'hafnarfjardar',
#   'west',
#   'hveradalaskálinn',
#   'dómadalur',
#   'þjórsárholt',
#   'vörðufell',
#   'hellisskarð',
#   'hengill',
#   'fossá',
#   'krókagiljabrún',
#   'lambafitjahraun',
#   'valahnúkar',
#   'valahnúkar on dómadalsroute',
#   'gaukshöfdi',
#   'idntaeknistofnun',
#   'hyaloclastite',
#   'reykholt',
#   'mosfellsbaer',
#   'reykholt biskupstungur',
#   'thjorsárdalur',
#   'miðfell',
#   'dolerite',
#   'kollafjordur',
#   'laugardalshellir',
#   'stora dímon',
#   'arnarfell',
#   'skefilsfjoll eldri',
#   'skefilsfjoll yngri',
#   'meðalfell',
#   'baejargil',
#   'blákollur',
#   'iceland',
#   'helgafell',
#   'arnarthufa',
#   'vifilfell',
#   'awibengkok',
#   'groß schönebeck',
#   'geitafell volcano',
#   'krafla',
#   'volcano',
#   'evrona',
#   'gerofit',
#   'ora',
#   'samar',
#   'zihor',
#   'well sinaf-1',
#   'tamardol',
#   'well ramon-1',
#   'well avdat-1',
#   'en yorq',
#   'hevyon',
#   'ghareb',
#   'avnon',
#   'mishash',
#   'nezer',
#   'shivta',
#   'well maka-36',
#   'menuha',
#   'tamar',
#   'well hmch-1',
#   'well hm-1',
#   'taqiye',
#   'well daya-1',
#   'well hltza-2',
#   'well hzrm-1',
#   'well bshev-1',
#   'well gurim-3',
#   'well zhrd-8',
#   'well zohar-1',
#   'well dshet-1',
#   'well hlz-2',
#   'well hlz-37',
#   'well negba-1',
#   'karnei-hitin volcano',
#   'weiss-kaul',
#   'west of rümelingen',
#   'belvaux',
#   'giele botter',
#   'profile kinett',
#   'east of moutfort',
#   'rebierg',
#   'züschschiefer',
#   'kirchberg',
#   'grouft',
#   'wasserbillig vormann',
#   'mersch',
#   'ell',
#   'rosswinkel',
#   'everlange',
#   'wartenstein',
#   'martelange',
#   'ingeldorf',
#   'radelange',
#   'reisdorf',
#   'stolzemburg',
#   'schüttburg',
#   'mirwart',
#   'ardennes',
#   'clerf',
#   'berlé',
#   'wiltz',
#   'sainthubert',
#   'villé',
#   'oignies',
#   'la gleize',
#   'bihain',
#   'fépin',
#   'meuville',
#   'colanhan',
#   'lierneux',
#   'les plattes',
#   'hour',
#   'grand halleux',
#   'wanne',
#   'la venne',
#   'spa',
#   'solwaster',
#   'belleaux',
#   'east pacific rise',
#   'schwerin',
#   'neubrandenburg',
#   'stralsund',
#   'pan-african damara',
#   'alps',
#   'lachlan fold belt',
#   'namaqua mobile belt',
#   'jequié',
#   'penokean orogen',
#   'jequie complex',
#   'new hampshire',
#   'galicia-tras-os-montes zone',
#   'naraku batholith',
#   'mount isa',
#   'superior province',
#   'canadian shield',
#   'variscan batholith of corsica',
#   'taiwan volcanic zone',
#   'zimbabwe',
#   'tethyan neyriz opholite complex',
#   'coso volcanic field',
#   'westasturian-leonese',
#   'norris creek',
#   'tarenga shale',
#   'biritish caledonian',
#   'burnside',
#   'pine creek',
#   'mount webb',
#   'arunta inlier',
#   'idaho batholith',
#   'variscan crust',
#   'corsica',
#   'njiri',
#   'dharwar craton',
#   'central african plateau',
#   'oulmès metamorphic aureole',
#   'sonhat basin',
#   'son valley',
#   'warrego',
#   'tennant creek',
#   'dawson',
#   'continental crust',
#   'sybella batholith',
#   'vosges',
#   'schwarzwald',
#   'bear lake',
#   'karnataka',
#   'sierra la primavera',
#   'sybella batholith',
#   'kong oscar fjord',
#   'tinemaha granodiorite',
#   'st. malo',
#   'provencal basin',
#   'langtang valley',
#   'natawahunan lake',
#   'damara belt',
#   'central-iberian zone',
#   'merced peak',
#   'cauchon lake',
#   'singhbhum trust belt',
#   'hidden bay pluton',
#   'sierra nevada batholith',
#   'turku area',
#   'chemehuevi mountains',
#   'shellenbarger lake',
#   'kaapvaal craton',
#   'kalkadoon',
#   'timber knob',
#   'betics',
#   'alpujárrides',
#   'red peak',
#   'southwark',
#   'arunta inlier',
#   'tennant creekt',
#   'kimberlite pipes',
#   'chintalapudi basin',
#   'godavari valley',
#   'trois segneurs massif',
#   'post peak',
#   'paperbark',
#   'kimberley',
#   'vredefort structure',
#   'bodrum volcanic complex',
#   'grandhalleux',
#   'kolar schist belt',
#   'west african kimberlites',
#   'ossa morena zone',
#   'westasturian-leonese zone',
#   'querigut complex',
#   'maláguides',
#   'belén',
#   'cordón tucúaro',
#   'iberian range',
#   'moresby strait area',
#   'oxford lake',
#   'shaler pluton',
#   'sally downs',
#   'kimberley',
#   'central eastern china',
#   'closepet granite',
#   'southwestern alaska',
#   'comte',
#   'strona valley',
#   'samrée',
#   'quebrada tajamar',
#   'gulf of mexico basin',
#   'nevado-filábrides',
#   'eastern virunga province',
#   'eastern australia',
#   'quebrada choja',
#   'urals',
#   'vivero massif',
#   'captains bay pluton',
#   'manaslu granite',
#   'arita',
#   'pam lin island',
#   'st. andrew strait',
#   'basotu',
#   'grenville province',
#   'jackass lakes',
#   'minarets complex',
#   'etendeka region',
#   'santa rosa de tastil',
#   'arcot-pallavaram',
#   'pyrenees',
#   'limpopo belt',
#   'trans-hudson orogen',
#   'tehachapi mts',
#   'salar de navidad',
#   'ochaquí',
#   'lamrômenil',
#   'longido',
#   'ghanzi-chobe fold belt',
#   'cantabrian zone',
#   'ebolowa area',
#   'ntem complex',
#   'pingo pingo',
#   'salar de diablillos',
#   'utik lake',
#   'sao paulo',
#   'cananéia-iguape lagoon',
#   'tuluman island',
#   'finger bay pluton',
#   'kirn',
#   'namaqua-natal belt',
#   'nanking',
#   'dodoma',
#   'kerguelen plateau',
#   'voisey bay',
#   'iowa',
#   'bp-1',
#   'bp-2',
#   'verril canyon',
#   'mic mac',
#   'bp-3',
#   'ne volcanic province',
#   'spain',
#   'kansas c',
#   'choschas',
#   'south atlantic',
#   'solya',
#   'bp-4',
#   'bp-5',
#   'sierra de macón',
#   'sinuyu',
#   'east african rift',
#   'merapi volcano',
#   'kansas',
#   'pikwitonei',
#   'sachigo',
#   'charmuria limestone',
#   'sierra nevada',
#   'plagidac',
#   'mississauga',
#   'champua thrust belt',
#   'logan canyon',
#   'kansas',
#   'cordón chinquilchoro',
#   'dawson canyon',
#   'kaiserstuhl',
#   'pacific ocean',
#   'kagalaska pluton',
#   'kanyemba',
#   'peninsula de mejillones',
#   'northern apennines',
#   'kastamonu',
#   'sesia–lanzo zone',
#   'redwig',
#   'tanlu fault',
#   'pikwitonei lake',
#   'garua harbour',
#   'mohican',
#   'renco',
#   'santa lucia mts',
#   'aleutian islands',
#   'paraná-etendeka province',
#   'jericho kimberlite pipe',
#   'zagros suture zone',
#   'sierra limón verde',
#   'banquereau',
#   'morbs & oibs',
#   'andean',
#   'goulet lake',
#   'saitoco',
#   'mount garbuna',
#   'new britain',
#   'columbia river basalt',
#   'mount welcker',
#   'luzon',
#   'holili',
#   'lau ridge',
#   'sugarloaf pluton',
#   'chinese peak',
#   "sana'a-amran volcanic field",
#   'garove island',
#   'lesser antilles',
#   'cordón de lila',
#   'nelson river',
#   'peninsula de majillones',
#   'abenaki',
#   'aleutian',
#   'bagana volcano',
#   'lolobau island',
#   'cape reilnitz',
#   'aleutian arc',
#   'sulu range',
#   'pikwitonei river',
#   'limpopo belt',
#   'atlantic ocean',
#   'kansa pathar',
#   'cascades',
#   'central america',
#   'kermadec',
#   'niuatoputapu',
#   'scotia',
#   'boninites',
#   'big creek',
#   'caribbean-columbian oceanic plateau',
#   'marianas',
#   'piñón oceanic plateau',
#   'late',
#   'burntwood river',
#   'cape hoskins volcanoes',
#   'ontong java plateau',
#   'deep sea drilling',
#   'site',
#   'mid ocean ridge',
#   'indian ocean',
#   'jijicao',
#   'xinchang',
#   'cuitzeo lake ',
#   'quinceo-tetillas',
#   'guadalajara',
#   'cuitzeo lake',
#   'los humeros geothermal field',
#   'ischia',
#   'solfatara',
#   'bolsena',
#   'vulsini volcanic zone',
#   'akranes',
#   'ferstikla',
#   'borgarfjarðarsveit',
#   'búlandshöfði',
#   'grundarfjarðarbær',
#   'gullbringusýsla',
#   'mfa-1',
#   'mfa-2',
#   'mfa-3',
#   'hafnarfjall',
#   'hoffell',
#   'dakeng',
#   'hrafnabjörg',
#   'hveragerði',
#   'innrihólmur',
#   'klafastaðir',
#   'kúludalsá',
#   'leirá',
#   'kolgrafir í eyrarsveit',
#   'leirár- og melahreppur',
#   'leirárdalur',
#   'demre',
#   'finike',
#   'mut',
#   'fethiye',
#   'korkuteli',
#   'meke',
#   'karaman',
#   'milas',
#   'yatagan',
#   'bucak',
#   'kolsuz',
#   'gödene',
#   'kilavuzkoy',
#   'ückapili',
#   'kavlaktepe',
#   'gümüsler',
#   'altinhisar',
#   'yesilburc',
#   'hazro',
#   'kemalpasa',
#   'ortaköy',
#   'bunyan',
#   'iscehisar',
#   'altintas',
#   'kozak',
#   'kaman',
#   'yildizeli',
#   'sögütalan',
#   'marmara island',
#   'porrino',
#   'mosfellsbær',
#   'lýsuhóll',
#   'reykjavík',
#   'seleyrargil',
#   'ytrihólmur',
#   'skilmannahreppur',
#   'þyrill',
#   'skorradalshreppur',
#   'stóra-drageyri',
#   'snæfellsbær',
#   'sandabotnaskarð',
#   'ek-105',
#   'kan-3',
#   'nc-99',
#   '98-46',
#   'ku5',
#   'mp-98',
#   'mp-101',
#   '98-78',
#   '98-89a',
#   '98-39',
#   '306i',
#   '316i',
#   '98-43b',
#   'ko2',
#   'klausturtunguhóll',
#   'western snókur',
#   'hafnarfjall caldera',
#   'leirárdalur',
#   'leirárdalur gully',
#   'east of klausturtunguhóll',
#   'nevada',
#   'north german basin',
#   'eulenflucht',
#   'groß buchholz',
#   'east of snókur',
#   'western canada sedimentary basin',
#   'alberta basin',
#   'well',
#   'hof trages',
#   'freigericht-somborn',
#   'lesesteine w stolzenberg',
#   'bad soden-salmünster',
#   'feldweg böschung',
#   'kinzig-stausee',
#   'ost',
#   'west',
#   'rothenberg',
#   'alzenau-kälberau',
#   '06-11-051-26w4',
#   'alter steinbruch',
#   'gap lake',
#   'alberta',
#   'canada',
#   'hohlweg rauher berg',
#   '15-23-036-10w5',
#   'grassi lakes',
#   'canmore',
#   'whitemans pond',
#   'maisenheimer hof',
#   'nigel peak',
#   'alberta canada',
#   'steinbruch ',
#   'niedermittlauer ',
#   'heiligenkopf',
#   'gelnhausen-meerholz',
#   'klosterruine',
#   'berg',
#   'gründau-breitenborn',
#   'steinbruch',
#   'schnepfenkopf',
#   'gelnhausen',
#   'kalkwerk firma hufgard',
#   'hösbach-rottenberg',
#   'kleiner aufschluss',
#   'freibad gelnhausen-roth',
#   'steinbruch',
#   'heiligenkopf',
#   'steinbruch',
#   'heinrichshöhe',
#   'lochmühle',
#   'biebergemünd-bieber',
#   'anschnitt b276',
#   'wächtersbach',
#   'altegrube',
#   'gelnhausen-höchst',
#   'steinbruch',
#   'altenhaßlau',
#   'linsengericht-altenhaßlau',
#   'steinbruch',
#   'nassbüchelbach',
#   'altenmittlau',
#   'anschnitt',
#   'kreuzung',
#   'burgfelsen',
#   'alzenau-burg',
#   'alzenau',
#   'steinbruch',
#   'gelnhausen-roth',
#   'steinbruch',
#   'neuenberg',
#   'penken',
#   'tauernfenster',
#   'nordrand',
#   'österreich',
#   'hohlweg',
#   'steinbrüche e bad orb',
#   'pfannköpfl',
#   'biebergemünd-kassel',
#   'tettensjoch',
#   'steinbruch kerkelberg',
#   'biebergemünd-roßbach',
#   'alter steinbruch am hirschberg',
#   'steinbruch wintersberg',
#   'bad orb',
#   'finkenberg',
#   'langenselbold',
#   'alter steinbruch herzberg',
#   'bahnhofstraße',
#   'alte tongrube',
#   'elsbach',
#   'alter kalksteinbruch',
#   'sonnenberg',
#   'gelnhausen-hailer',
#   'tongrube hailer',
#   'dornau am tuxbach',
#   'wasserfall am elsbach',
#   'altes kalkwerk firma ickes',
#   'elsalm',
#   'schraubenfall',
#   'acker auf dem mühlberg',
#   'langenselbold',
#   'steinbruch franzosenkopf',
#   'huckelheim',
#   'neuer steinbruch',
#   'sw hösbach-rottenberg',
#   'tuxer joch',
#   'weitental',
#   'lachtalscharte',
#   'schwarze pfanne',
#   'bahnhof mittelgründau',
#   'parkplatz hanauer straße',
#   'tongrube firma zeller',
#   'neuburg-ravolzhausen',
#   'tongrube bettenburger loch',
#   'schöneck-oberdorfelden',
#   '10-31-37-9w5',
#   'rosenthal',
#   'arbonne la foret',
#   'aura',
#   'sterbfritz',
#   'hessen',
#   'deutschland',
#   'piarere',
#   'te awamutu',
#   'waikat',
#   'waotu',
#   'cedar creek',
#   'mount tamborine',
#   'te puke',
#   'whakaari',
#   'the taupo volcanic zone',
#   'gonghe basin',
#   'zotzenbach',
#   'nieder-liebersbach',
#   'scharbach',
#   'campi flegrei',
#   'naples',
#   'caserta',
#   'monte san serverio',
#   'colli albani',
#   'mt. etna volcano',
#   'stromboli volcano',
#   'rhode island',
#   'bentheim',
#   'darley dale',
#   'seljadur',
#   'kirschhausen',
#   'wald-erlenbach',
#   'krumbach',
#   'bonsweiher',
#   'taupo',
#   'waihi',
#   'tauposees',
#   'papamoa',
#   'turangi',
#   'straßenaufschluss',
#   'pfalz',
#   'grabenschulter',
#   'oberrheingrabens',
#   'odenwald',
#   'grabenschulter',
#   'spessart',
#   'mainufer',
#   'triefnebachtales',
#   'kirchheimbolanden',
#   'tunnelbaustelle',
#   'widderstall',
#   'lhd4-653',
#   'lhd4-852',
#   'lhd4-1002',
#   'lhd4-2305',
#   'lhd5-603',
#   'lhd5-753',
#   'lhd5-1103',
#   'lhd5-1406',
#   'lhd5-1576',
#   'lhd1-2101',
#   'lhd1-501',
#   'lhd1-802',
#   'lhd1-1001',
#   'lhd1',
#   'lhd7-902',
#   'lhd7.8-1568',
#   'lhd7-1758',
#   'lhd2-302',
#   'lhd3-2203',
#   'mount st. helen',
#   'spine-forming eruption',
#   'mount meager volcano',
#   'cascade volcanic',
#   'st. augustine volcano',
#   'cinderblock lava',
#   'reykjanes',
#   'castle creek period',
#   'kid dome gulley',
#   'el zarco riverbed',
#   'kumamoto prefecture',
#   'mount etna volcano',
#   'rotokawa',
#   'volcán de colima',
#   'river harsit',
#   'kürtün dogankent',
#   'piesberg ',
#   'osnabrück',
#   'bruchsal',
#   'knittlingen',
#   'seebach',
#   'raumünzach',
#   'karlsruhe',
#   'wilferdingen',
#   'pforzheim',
#   'albersweiler',
#   'waldhambach',
#   'buntsandstein',
#   'göbel',
#   'palatinate forest',
#   'th18',
#   'tauhara geothermal field',
#   'thm12',
#   'thm19',
#   'thm14',
#   'thm18',
#   'thm17',
#   'thm13',
#   'kailash tila-2',
#   'bengal basin',
#   'titas-11',
#   'bakhrabad-10',
#   'shahbazpur-1',
#   'kwv-1',
#   'ecca pass',
#   'eastern cape',
#   'koksharovskoe plateau',
#   'ussr maritime region (primorskiy krai)',
#   'russian platform',
#   'lovozero formation',
#   'kurginsk formation',
#   'anabar bed',
#   'kimpersay massif',
#   'aldan',
#   'tanba belt',
#   'synnyr complex',
#   'khibiny mountains',
#   'caucasus',
#   'oboyansk',
#   'gorky region',
#   'nishni novgorod',
#   'oboyansk',
#   'nishni novgorod',
#   'escandorgue lava flow',
#   'lunas',
#   'dévés lava flow',
#   'senouire vallée',
#   'josat',
#   'norseman',
#   'broken hill',
#   'coolgardie',
#   'kalgoorlie',
#   'west-australien',
#   'south and west australia',
#   'heimersdorf',
#   'illfurth',
#   'michelbach',
#   'schweighouse',
#   'chalampe',
#   'staffelfelden',
#   'sainte croix en plaine',
#   'colmar-sud-1',
#   'muntzenheim',
#   'artzenheim',
#   'mackenheim',
#   'muttersholtz',
#   'saint-pierre r1',
#   'grunsbuhl',
#   'schaeffersheim',
#   'erstein',
#   'binnenweg',
#   'meistratzheim',
#   'eschau',
#   'lipsheim',
#   'holtzheim',
#   'cronenbourg',
#   'kilstett',
#   'schirrhein',
#   'schweighouse',
#   'moder',
#   'roeschwoog',
#   'rountzenheim',
#   'donau',
#   'soufflenheim',
#   'donau ',
#   'soufflenheim',
#   'beinheim',
#   'rohrlach',
#   'hitzeln',
#   'rittershoffen',
#   'oberbetschdorf',
#   'schaffhousse',
#   'kesseldorf',
#   'abwaender',
#   'reimerswiller',
#   'schelmenberg',
#   'soultzegs',
#   'knoeringue',
#   'steinsoultz',
#   'preuschdorf',
#   'soultz sous forêts',
#   'oberlauterbach',
#   'guckenberg',
#   'muenzfeld',
#   'neewiller nord',
#   'scheibenhard',
#   'marienbronn',
#   'niederlauterbach',
#   'salmbach',
#   'scheibenhard',
#   'niederlauterbach',
#   'niederlauterbach',
#   'pico da orizaba',
#   'miami',
#   'naples',
#   'west palm beach',
#   'tampa',
#   'plant city',
#   'beeville',
#   'orlando',
#   'daytona beach',
#   'san antonio',
#   'presidio',
#   'gainesville',
#   'apalachicola',
#   'transvaal',
#   'gerhardminnebron bore',
#   'dubbeldevei bore',
#   'dubbeldevlei bore',
#   ...],
#  'list_methods': ['longitude',
#   'decimaldegree.minutes',
#   'latitude',
#   'elevation',
#   'a.s.l.',
#   'radius',
#   'uncertainty',
#   'km',
#   'igsn',
#   'length',
#   'height',
#   'width',
#   'diameter',
#   'decimaldegrees.minutes',
#   'depth',
#   'md',
#   'tvd',
#   'petrography',
#   'stratigraphy',
#   'temperature',
#   'pressure',
#   'pa',
#   'saturating',
#   'saturation',
#   'sigma1',
#   'mpa',
#   'sigma2',
#   'sigma3',
#   'pore',
#   'strain',
#   'rate',
#   'kn/s',
#   'mpa/s',
#   'mm/s',
#   '1/s',
#   'value',
#   'grain',
#   'density',
#   'kg/m³',
#   'standard deviation',
#   'min',
#   'max',
#   'porosity',
#   'permeability',
#   'm²',
#   'thermal',
#   'conductivity',
#   'w/m·k',
#   'inhomogenity',
#   'specific heat capacity',
#   'heat',
#   'capacity',
#   'j/kg·k',
#   'volumetric',
#   'j/m³·k',
#   'diffusivity',
#   'm²/s',
#   'radiogenic',
#   'w/m³',
#   'p-wave',
#   'velocity',
#   'm/s',
#   'frequency',
#   'khz',
#   's-wave',
#   'dyn',
#   'youngs modulus',
#   'modulus',
#   'gpa',
#   'stat',
#   'shear',
#   'lame',
#   'cohesion',
#   'friction',
#   'coefficient',
#   'confining',
#   'porefluid',
#   'differential',
#   'stress',
#   'mean',
#   'compactive',
#   'yield',
#   'critical',
#   'onset',
#   'inelastic',
#   'hydrostatic',
#   'compaction',
#   'shear-enhanced',
#   'enhanced',
#   'poisson',
#   'ratio',
#   'dynamic',
#   'static',
#   'ucs',
#   'tensile',
#   'strength',
#   's/m',
#   'formation',
#   'resistivity',
#   'chronostratigraphy',
#   'sampling point',
#   'petrography',
#   'stratigraphy',
#   'grain density',
#   'bulk density',
#   'total porosity',
#   'effective porosity',
#   'apparent permeability',
#   'intrinsic permeability',
#   'bulk thermal conductivity',
#   'matrix thermal conductivity',
#   'specific heat capacity',
#   'volumetric heat capacity',
#   'thermal diffusivity',
#   'radiogenic heat production',
#   'p-wave velocity',
#   's-wave velocity',
#   'youngs modulus',
#   'shear modulus',
#   'bulk modulus',
#   'lamé modulus',
#   'cohesion',
#   'friction coefficient',
#   'triaxial experiments',
#   'poisson ratio',
#   'uniaxial compressive strength',
#   'tensile strength',
#   'electrical conductivity',
#   'magnetic susceptibility',
#   'quality indice geographic uncertatiny',
#   'qualitiy indice petrography',
#   'quality indice stratigraphy',
#   'qualitiy indice measurement conditions',
#   'quality indice measurement parameter',
#   'value quality index',
#   'class quality index'],
#  'list_petrography': ['consolidated',
#   'magmatic',
#   'plutonic',
#   'plutonic   field description',
#   'very quartz rich plutonic',
#   'quartz rich granitic plutonic',
#   'quartz rich plutonic',
#   'granitic plutonic',
#   'quartz bearing to foid bearing plutonic',
#   'syenitic plutonic',
#   'dioritic plutonic',
#   'gabbrotic plutonic',
#   'foid rich plutonic',
#   'foid syenitic plutonic',
#   'foid dioritic plutonic',
#   'foid gabbrodic plutonic',
#   'very foid rich plutonic foidolite',
#   'foidolitic plutonic',
#   'ultra mafic plutonic  ',
#   'plutonic    ',
#   'quartzolite  ',
#   'granite  ',
#   'alkali feldspar granite',
#   'syenogranite',
#   'monzogranite',
#   'granodiorite  ',
#   'tonalite  ',
#   'quartz alkali feldspar syenite  ',
#   'quartz syenite  ',
#   'quartz monzonite  ',
#   'quartz monzodiorite  ',
#   'quartz monzogabbro  ',
#   'quartz diorite  ',
#   'quartz gabbro  ',
#   'quartz anorthosite  ',
#   'alkali feldspar syenite  ',
#   'syenite  ',
#   'monzonite  ',
#   'monzodiorite  ',
#   'monzogabbro  ',
#   'diorite  ',
#   'gabbro  ',
#   'gabbronorite',
#   'norite',
#   'troctolite',
#   'olivine gabbro',
#   'olivine gabbronorite',
#   'olivine norite',
#   'orthopyroxene gabbro',
#   'clinopyroxene norite',
#   'hornblende gabbro',
#   'pyroxene hornblende gabbro',
#   'pyroxene hornblende gabbronorite',
#   'pyroxene hornblende norite',
#   'anorthosite  ',
#   'foid bearing alkali feldspar syenite  ',
#   'foid bearing syenite  ',
#   'foid bearing monzonite  ',
#   'foid bearing monzodiorite  ',
#   'foid bearing monzogabbro  ',
#   'foid bearing diorite  ',
#   'foid bearing gabbro  ',
#   'foid bearing anorthosite  ',
#   'foid syenite eg. nepheline syenite  ',
#   'malignite',
#   'shoncinite',
#   'foid monzosyenite  ',
#   'foid monzodiorite  ',
#   'foid monzogabbro  ',
#   'foid diorite  ',
#   'foid gabbro  ',
#   'nephelinolite  ',
#   'urtite',
#   'ijolite',
#   'melteigite',
#   'leucitolite  ',
#   'italite',
#   'fergustite',
#   'missourite',
#   'ultramafic plutonics',
#   'peridotite',
#   'dunite',
#   'harzburgite',
#   'lherzolite',
#   'wehrlite',
#   'pyroxene peridotite',
#   'pyroxene hornblende peridotite',
#   'hornblende peridotite',
#   'pyroxenite',
#   'orthopyroxenite',
#   'olivine orthopyroxenite',
#   'websterite',
#   'olivine websterite',
#   'klinopyroxenite',
#   'olivine klinopyroxenite',
#   'olivine pyroxenite',
#   'olivine hornblende pyroxenite',
#   'plagioclase bearing pyroxenite',
#   'plagioclase bearing hornblende pyroxenite',
#   'hornblendite',
#   'pyroxene hornblendite',
#   'olivine hornblendite',
#   'olivine pyroxene hornblendite',
#   'plagioclase bearing hornblendite',
#   'plagioclase bearing pyroxene hornblendite',
#   'ultramafic melilitic plutonic',
#   'melilolite',
#   'olivine melilitolite',
#   'pyroxene melilitolite',
#   'olivine pyroxene melilitolite',
#   'pyroxene olivine melililolite',
#   'carbonatite plutonic',
#   'calcite carbonatite  ',
#   'dolomite carbonatite  ',
#   'ferro carbonatite  ',
#   'charnockite plutonic',
#   'volcanic',
#   'volcanic  ',
#   'quartz rich volcanic',
#   'rhyolitic volcanic',
#   'dacitic volcanic',
#   'quartz to foid bearing volcanic',
#   'trachytic volcanic',
#   'latitic volcanic',
#   'basaltic volcanic',
#   'tholeiitic volcanic',
#   'olivine basaltic volcanic',
#   'alkali basaltic volcanic',
#   'andesitic volcanic',
#   'foid rich volcanic',
#   'phonolitic volcanic',
#   'tephritic volcanic',
#   'basanitic volcanic',
#   'very foid rich volcanic',
#   'foiditic volcanic',
#   'ultramafic volcanic  ',
#   'volcanic  normativ',
#   'alkali feldspar rhyolite  ',
#   'rhyolite  ',
#   'rhyodacite  ',
#   'dacite  ',
#   'obsidian',
#   'quartz alkali feldspar trachyte  ',
#   'quartz trachyte  ',
#   'alkali feldspar trachyte  ',
#   'trachyte  ',
#   'foid bearing alkali feldspar trachyte  ',
#   'foid bearing trachyte  ',
#   'quartz latite  ',
#   'latite  ',
#   'foid bearing latite  ',
#   'basalt  ',
#   'tholeitic basalt',
#   'olivine basalt',
#   'alkali basalt',
#   'alkali basalt amphibole bearing',
#   'leucobasalt  ',
#   'leuco alkali basalt',
#   'andesite  ',
#   'mela andesite  ',
#   'phonolite  ',
#   'tephritic phonolite  ',
#   'tephrite  ',
#   'phonolitic tephrite  ',
#   'basanite  ',
#   'limburgite',
#   'basanite analcim rich',
#   'basanite amphibole bearing',
#   'phonolitic basanite  ',
#   'phonolitic foidite  ',
#   'tephritic foidite  ',
#   'basanitic foidite  ',
#   'foidite  ',
#   'nephelinite  ',
#   'melilite nephelinite  ',
#   'analcimite  ',
#   'leucitite  ',
#   'ultramafic volcanic ',
#   'melilithite',
#   'olivine melilithite',
#   'melilithite bearing ultramafic',
#   'carbonatite',
#   'calcite carbonatite',
#   'dolomite carbonatite',
#   'ferro carbonatite',
#   'natro carbonatite',
#   'volcanic  ',
#   'acidic volcanic',
#   'intermediate volcanic',
#   'basic volcanics',
#   'ultra basic',
#   'sio oversaturated volcanic  ',
#   'rhyolite  ',
#   'comenditic rhyolite comendite',
#   'pantelleritic rhyolite pantellerite',
#   'trachydacite  ',
#   'dacite  ',
#   'high k dacite  ',
#   'medium k dacite  ',
#   'low k dacite  ',
#   'andesite  ',
#   'high k andesite  ',
#   'medium k andesite  ',
#   'low k andesite  ',
#   'basaltic andesite  ',
#   'high k basaltic andesite  ',
#   'medium k basaltic andesite  ',
#   'low k basaltic andesite  ',
#   'sio saturated volcanic  ',
#   'trachyte  ',
#   'trachite  ',
#   'peralkalic trachyte  ',
#   'comenditic trachyte  ',
#   'pantellitic trachyte  ',
#   'trachyandesite  ',
#   'benmoreite  ',
#   'latite  ',
#   'basaltic trachyandesite  ',
#   'mugearite  ',
#   'shoshonite  ',
#   'trachybasalt  ',
#   'hawaiite  ',
#   'k trachybasalt  ',
#   'sio saturated or slightly undersaturated volcanic  ',
#   'basalt  ',
#   'subalkali basalt  ',
#   'tholeitic basalt  ',
#   'high alumina basalt  ',
#   'alkali basalt  ',
#   'alkali olivine basalt  ',
#   'sio undersaturated volcanic  ',
#   'phonolite  ',
#   'tephri phonolite  ',
#   'phono tephrite  ',
#   'tephrite  ',
#   'basanite  ',
#   'picrobasalt  ',
#   'foidite  ',
#   'nephelinite  ',
#   'high mg volcanics  ',
#   'boninite  ',
#   'picritic volcanic  ',
#   'picrite  ',
#   'comatiite  ',
#   'meimechite  ',
#   'volcaniclastic',
#   'volcaniclastics  ',
#   'rhyolitic volcaniclast',
#   'dacitic volcaniclast',
#   'trachytic volcaniclast',
#   'andesitic volcaniclast',
#   'basaltic volcaniclast',
#   'alkali basaltic volcaniclast',
#   'tholeitic volcaniclast',
#   'phonolitic volcaniclast',
#   'tephritic volcaniclast',
#   'basanitic volcaniclast',
#   'foiditic volcaniclast',
#   'pyroclastics',
#   'pyroclastic undefined',
#   'ash tuff ',
#   'fine grained ash tuff',
#   'coarse grained ash tuff',
#   'crystal ash tuff',
#   'lapilli ash tuff',
#   'bomb ash tuff',
#   'block ash tuff',
#   'lapillistone',
#   'ash lapillistone',
#   'bomb lapillistone',
#   'block lapillistone',
#   'agglomerate',
#   'bomb tuff',
#   'lapilli bomb tuff',
#   'ash bomb tuff',
#   'agglutinate',
#   'pyroclastic breccia',
#   'block tuff',
#   'lapilli block tuff',
#   'ash block tuff',
#   'tuff breccia',
#   'lapilli tuff breccia',
#   'ash tuff breccia',
#   'air fall deposit consolidated',
#   'ash flow deposit consolidated',
#   'ignimbrite consolidated',
#   'ignimbrite welded',
#   'ignimbrite unwelded consolidated',
#   'surge deposit consolidated',
#   'peperite',
#   'pyroclastic rhyolitic',
#   'rhyolitic ash tuff',
#   'fine grained ash tuff rhyolitic',
#   'coarse grained ash tuff rhyolitic',
#   'rhyolitic crystal ash tuff',
#   'rhyolitic lapilli ash tuff',
#   'rhyolitic bomb ash tuff',
#   'rhyolitic block ash tuff',
#   'rhyolitic lapilli tuff',
#   'rhyolitic ash lapilli tuff',
#   'rhyolitic bomb lapilli tuff',
#   'rhyolitic block lapilli tuff',
#   'rhyolitic agglomerate',
#   'rhyolitic bomb tuff',
#   'rhyolitic lapilli bomb tuff',
#   'rhyolitic ash bomb tuff',
#   'rhyolitic agglutinate',
#   'pyroclastoc breccia rhyolitic',
#   'rhyolitic block tuff',
#   'rhyolitic lapilli block tuff',
#   'rhyolitic ash block tuff',
#   'rhyolitic tuff breccia',
#   'rhyolitic lapilli tuff breccia',
#   'rhyolitic ash tuff breccia',
#   'rhyolitic air fall deposit consolidated',
#   'rhyolitic ash flow deposit consolidated',
#   'rhyolitic ignimbrite consolidated',
#   'rhyolitic ignimbrite welded',
#   'rhyolitic ignimbrite unwelded consolidated',
#   'rhyolitic surge deposit',
#   'rhyolitic peperite',
#   'pyroclastic dacitic',
#   'dacitic ash tuff',
#   'fine grained ash tuff dacitic',
#   'coarse grained ash tuff dacitic',
#   'dacitic crystal ash tuff',
#   'dacitic lapilli ash tuff',
#   'dacitic bomb ash tuff',
#   'dacitic block ash tuff',
#   'dacitic lapilli tuff',
#   'dacitic ash lapilli tuff',
#   'dacitic bomb lapilli tuff',
#   'dacitic block lapilli tuff',
#   'dacitic agglomerate',
#   'dacitic bomb tuff',
#   'dacitic lapilli bomb tuff',
#   'dacitic ash bomb tuff',
#   'dacitic agglutinate',
#   'pyroclastic breccia dacitic',
#   'dacitic block tuff',
#   'dacitic lapilli block tuff',
#   'dacitic ash block tuff',
#   'dacitic tuff breccia',
#   'dacitic lapilli tuff breccia',
#   'dacitic ash tuff breccia',
#   'dacitic air fall deposit consolidated',
#   'dacitic ash flow deposit consolidated',
#   'dacitic ignimbrite consolidated',
#   'dacitic ignimbrite welded',
#   'dacitic ignimbrite unwelded consolidated',
#   'dacitic surge deposit consolidated',
#   'dacitic peperite',
#   'pyroclastic trachytic',
#   'trachytic ash tuff',
#   'fine grained trachytic ash tuff',
#   'coarse grained trachytic ash tuff',
#   'trachytic crystal ash tuff',
#   'trachytic lapilli ash tuff',
#   'trachytic bomb ash tuff',
#   'trachytic block ash tuff',
#   'trachytic lapilli tuff',
#   'trachytic ash lapilli tuff',
#   'trachytic bomb lapilli tuff',
#   'trachytic block lapilli tuff',
#   'trachytic agglomerate',
#   'trachytic bomb tuff',
#   'trachytic lapilli bomb tuff',
#   'trachytic ash bomb tuff',
#   'trachytic agglutinate',
#   'pyroclastic breccia trachytic',
#   'trachytic block tuff',
#   'trachytic lapilli block tuff',
#   'trachytic ash block tuff',
#   'trachytic tuff breccia',
#   'trachytic lapilli tuff breccia',
#   'trachytic ash tuff breccia',
#   'trachytic air fall deposit consolidated',
#   'trachytic ash flow deposit consolidated',
#   'trachytic ignimbrite consolidated',
#   'trachytic ignimbrite welded',
#   'trachytic ignimbrite unwelded consolidated',
#   'trachytic surge deposit consolidated',
#   'trachytic peperite',
#   'pyroclastic latitic ',
#   'latitic ash tuff',
#   'fine grained latitic ash tuff',
#   'coarse  grained latitic ash tuff',
#   'latitic crystal ash tuff',
#   'latitic lapilli ash tuff',
#   'latitic bomb ash tuff',
#   'latitic block ash tuff',
#   'latitic lapilli tuff',
#   'latitic ash lapilli tuff',
#   'latitic bomb lapilli tuff',
#   'latitic block lapilli tuff',
#   'latitic agglomerate',
#   'latitic bomb tuff',
#   'latitic lapilli bomb tuff',
#   'latitic ash bomb tuff',
#   'latitic aggglutinate',
#   'pyroclastic breccia latitic',
#   'latitic block tuff',
#   'latitic lapilli block tuff',
#   'latitic ash block tuff',
#   'latitic tuff breccia',
#   'latitic lapilli tuff breccia',
#   'latitic ash tuff breccia',
#   'latitic air flow deposit consolidated',
#   'latitic ash flow deposit consolidated',
#   'latitic ignimbrite consolidated',
#   'latitic ignimbrite welded',
#   'latitic ignimbrite unwelded consolidated',
#   'latitic surge deposit consolidated',
#   'latitic peperite',
#   'pyroclastic andesitic',
#   'andesitic ash tuff',
#   'fine grained andesitic ash tuff',
#   'coarse grained andesitic ash tuff',
#   'andesitic crystal ash tuff',
#   'andesitic lapilli ash tuff',
#   'andesitic bomb ash tuff',
#   'andesitic block ash tuff',
#   'andesitic lapilli tuff',
#   'andesitic ash lapilli tuff',
#   'andesitic bomb lapilli tuff',
#   'andesitic block lapilli tuff',
#   'andesitic agglomerate',
#   'andesitic bomb tuff',
#   'andesitic lapilli bomb tuff',
#   'andesitic ash bomb tuff',
#   'andesitic agglutinate',
#   'pyroclastic breccia andesitic',
#   'andesitic block tuff',
#   'andesitic lapilli block tuff',
#   'andesitic ash block tuff',
#   'andesitic tuff breccia',
#   'andesitic lapilli tuff breccia',
#   'andesitic ash tuff breccia',
#   'andesitic air flow deposit consolidated',
#   'andesitic ash flow deposit consolidated',
#   'andesitic ignimbrite consolidated',
#   'andesitic ignimbrite welded',
#   'andesitic ignimbrite unwelded consolidated',
#   'andesitic surge deposit consolidated',
#   'andesitic peperite',
#   'pyroclastic basaltic',
#   'basaltic ash tuff',
#   'fine grained ash tuff basaltic',
#   'coarse grained ah tuff basaltic',
#   'basaltic crystal ash tuff',
#   'basaltic lapilli ash tuff',
#   'basaltic bomb ash tuff',
#   'basaltic block ash tuff',
#   'basaltic lapilli tuff',
#   'basaltic crystal lapilli tuff',
#   'basaltic ash lapilli tuff',
#   'basaltic bomb lapilli tuff',
#   'basaltic block lapilli tuff',
#   'basaltic agglomerate',
#   'basaltic bomb tuff',
#   'basaltic lapilli bomb tuff',
#   'basaltic ash bomb tuff',
#   'basaltic agglutinate',
#   'pyroclastic breccia consolidated',
#   'basaltic block tuff',
#   'basaltic lapilli block tuff',
#   'basaltic ash block tuff',
#   'basaltic tuff breccia',
#   'basaltic lapilli tuff breccia',
#   'basaltic ash tuff breccia',
#   'basaltic air fall deposit consolidated',
#   'basaltic ash flow deposit consolidated',
#   'basaltic ignimbrite consolidated',
#   'basaltic surge deposit consolidated',
#   'basaltic peperite',
#   'pyroclastic phonolitic',
#   'phonolitic ash tuff',
#   'fine grained ash tuff phonolitic',
#   'coarse grained ash tuff phonolitic',
#   'phonolitic crystal ash tuff',
#   'phonolitic lapilli ash tuff',
#   'phonolitic bomb ash tuff',
#   'phonolitic block ash tuff',
#   'phonolitic lapilli tuff',
#   'phonlitic ash lapilli tuff',
#   'phonolitic bomb lapilli tuff',
#   'phonolitic block lapilli tuff',
#   'phonolitic agglomerate',
#   'phonolitic bomb tuff',
#   'phonolitic lapilli block tuff',
#   'phonolitic ash block tuff',
#   'phonolitic agglutinate',
#   'pyroclastic breccia phonolitic',
#   'phonolitic block tuff',
#   'phonolitic tuff breccia',
#   'phonolitic lapilli tuff breccia',
#   'phonolitic ash tuff breccia',
#   'phonolitic air fall deposit consolidated',
#   'phonolitic ash flow deposit consolidated',
#   'phonolitic ignimbrite consolidated',
#   'phonolitic ignimbrite welded',
#   'phonolitic ignimbrite unwelded consolidated',
#   'phonolitic surge deposit consolidated',
#   'phonolitic peperite',
#   'pyroclastic basanitic',
#   'basanitic ash tuff',
#   'fine  grained ash tuff basanitic',
#   'coarse grained ash tuff basanitic',
#   'basanitic crystall ash tuff',
#   'basanitic lapilli ash tuff',
#   'basanitic bomb ash tuff',
#   'basanitic block ash tuff',
#   'basanitic lapilli tuff',
#   'basanitic ash lapilli tuff',
#   'basanitic bomb lapilli tuff',
#   'basanitic block lapilli tuff',
#   'basanitic agglomerate',
#   'basanitic bomb tuff',
#   'basanitic lapilli bomb tuff',
#   'basanitic ash bomb tuff',
#   'basanitic agglutinate',
#   'pyroclastic breccia basanitic',
#   'basanitic block tuff',
#   'basanitic lapilli block tuff',
#   'basanitic ash block tuff',
#   'basanitic tuff breccia',
#   'basanitic lapilli tuff breccia',
#   'basanitic ash tuff breccia',
#   'basanitic air fall deposit consolidated',
#   'basanitic ash flow deposit consolidated',
#   'basanitic ignimbrite consolidated',
#   'basanitic ignimbrite unwelded consolidated',
#   'basanitic surhe deposit consolidated',
#   'basanitic peperite',
#   'autoclastic volcaniclast',
#   'top breccia',
#   'bottom breccia',
#   'tuffite',
#   'tuffaceous claystone',
#   'tuffaceous siltstone',
#   'tuffaceous sandstone',
#   'tuffaceous conglomerate',
#   'tuffaceous breccia',
#   'volcaniclastic sedimentary  ',
#   'volcaniclastic claystone',
#   'volcaniclastic siltstone',
#   'volcaniclastic sandstone',
#   'volcaniclastic conglomerate',
#   'volcaniclastic breccia',
#   'lahar consolidated',
#   'volcanic and volcaniclastic structureless',
#   'dyke ',
#   'dyke    ',
#   'quartz rich dyke',
#   'quartz bearing to foid bearing dyke',
#   'foid rich dyke',
#   'dolerite  ',
#   'lamprophyr  ',
#   'dyke   ',
#   'pegmatite granitoidic composition',
#   'quartz rich aplite',
#   'granite aplite',
#   'granodiorite aplite',
#   'tonalite aplite',
#   'dykes´ granite',
#   'dykes´ granodiorite',
#   'dykes´ tonalite',
#   'microgranite',
#   'microgranodiorite',
#   'microtonalite',
#   'granophyr',
#   'porphyritic granite',
#   'porphyritic granodiorite',
#   'porphyritic tonalite',
#   'pegmatite of nephelinitic composition',
#   'quartz bearing to quartz free aplite',
#   'syenite aplite',
#   'monzonite aplite',
#   'monzodiorite aplite',
#   'diorite aplite',
#   'gabbro aplite',
#   'dykes´ syenite',
#   'dykes´ monzonite',
#   'dykes´ monzodiorite',
#   'dykes´ diorite',
#   'dykes´ gabbro',
#   'microsyenite',
#   'micromonzonite',
#   'micromonzodiorite',
#   'microdiorite',
#   'microgabbro',
#   'porphyric syenite',
#   'porphyric monzonite',
#   'porphyric monzodiorite',
#   'porphyric diorite',
#   'porphyric gabbro',
#   'dolerite diabase',
#   'alkalibasaltic dolerite',
#   'leucite nepheline dolerite',
#   'theoleitic dolerite',
#   'fioditic dyke',
#   'lamprophyre',
#   'minette',
#   'kersanite',
#   'vogesite',
#   'spessartite',
#   'alkali lamprophyre',
#   'camptonite',
#   'sannaite',
#   'monchiquite',
#   'fourchite',
#   'ultrabasic alkali lamprophyr',
#   'quachitite',
#   'melilitic lamprophyr',
#   'alnoite',
#   'polzenite',
#   'lamprophyric carbonatic dyke',
#   'kimberlite',
#   'carbonatic kimberlite',
#   'hydrothermal gangue mineralization',
#   'quartz rich gangue mineralization',
#   'milky quartz mineral aggregate',
#   'capped quartz mineral aggregate',
#   'pseudomorphosic quartz mineral aggregate',
#   'carbonate rich gangue mineralization',
#   'calcite mineral aggregate',
#   'feldspar rich gangue mineralization',
#   'feldspar mineral aggregate',
#   'baryte rich gangue mineralization',
#   'baryte mineral aggregate',
#   'sulfide rich gangue mineralization',
#   'metamorphic',
#   'metamorphic after educt',
#   'meta sedimentary',
#   'meta pelite',
#   'hornfels',
#   'buchite',
#   'silicic',
#   'silicic schist',
#   'meta psammite',
#   'meta arkose',
#   'meta graywacke',
#   'meta psephite',
#   'meta conglomerate',
#   'meta igneous',
#   'meta plutonite',
#   'meta granite',
#   'meta granodiorite',
#   'meta diorite',
#   'meta gabbro',
#   'metamorphic dyke',
#   'meta aplite',
#   'garnet meta aplite',
#   'garnet turmaline meta aplite',
#   'meta pegmatite',
#   'meta dolerite',
#   'alkalibasaltic meta dolerite',
#   'tholeitic meta dolerite',
#   'meta volcanic',
#   'meta rhyolite',
#   'peralkaline meta rhyolite',
#   'meta rhyodacite',
#   'meta dacite',
#   'meta trachyte',
#   'meta basalt',
#   'meta basalt sorted',
#   'meta alkali basalt',
#   'tholeitic meta basalt',
#   'meta andesite',
#   'meta phonolite',
#   'meta basanite',
#   'meta pikrite',
#   'meta volcaniclastic',
#   'rhyolitic meta volcaniclastic',
#   'rhyodacitic meta volcaniclastic',
#   'dacitic meta volcaniclastic',
#   'trachytic meta volcaniclastic',
#   'andesitic meta volcaniclastic',
#   'basaltic meta volcaniclastic',
#   'alkali basaltic meta volcaniclastic',
#   'tholeitic meta volcaniclastic',
#   'phonolitic meta volcaniclastic',
#   'basanitic meta volcaniclastic',
#   'meta pyroclastic',
#   'rhyolitic meta pyroclastic',
#   'rhyodacitic meta pyroclastic',
#   'dacitic meta pyroclastic',
#   'trachytic meta pyroclastic',
#   'andesitic meta pyroclastic',
#   'basaltic meta pyroclastic',
#   'alkali basaltic meta pyroclastic',
#   'basanitic meta pyroclastic',
#   'meta tuffite',
#   'tuffitic meta pelite',
#   'tuffitic meta psammite',
#   'tuffitic meta conglomerate',
#   'autoclastic meta volcaniclastic',
#   'autoclastic hydroclastic meta volcaniclastic',
#   'pillow breccia',
#   'pillow fragment breccia',
#   'hydroclastic',
#   'volcaniclastic meta sedimentary  ',
#   'metamorphic after chemistry fabric mineral content',
#   'metacarbonate',
#   'marble',
#   'marble sorted',
#   'calcite marble',
#   'dolomite marble',
#   'carbonate silicate marble silica marble',
#   'metamorphic carbonate silicate',
#   'carbonate phyllite',
#   'carbonate silicate coarse',
#   'quartz rich metamorphic',
#   'quartzite',
#   'apatite quartzite',
#   'epidote quartzite',
#   'garnet quartzite',
#   'graphite quartzite',
#   'magnetite quartzite',
#   'muscovite quartzite',
#   'serictite quartzite',
#   'metafelsics',
#   'phyllite',
#   'albite phyllite',
#   'chloritoide phyllite',
#   'garnet albite phyllite',
#   'garnet phyllite',
#   'quartz phyllite',
#   'sericite phyllite',
#   'mica schist',
#   'albite mica schist',
#   'andalusite mica schist',
#   'apatite mica schist',
#   'biotite plagioclase mica schist',
#   'chlorite mica schist',
#   'garnet mica schist',
#   'graphite mica schist',
#   'muscovite chlorite mica schist',
#   'muscovite biotite mica schist two mica schist',
#   'sericite mica schist',
#   'staurolite biotite muscovite mica schist',
#   'gneiss',
#   'epidote hornblende plagioclase gneiss',
#   'albite gneiss',
#   'andalusite gneiss',
#   'biotite gneiss',
#   'biotite cordierit gneiss',
#   'biotite garnet gneiss',
#   'biotite plagioclase gneiss',
#   'biotite muscovite gneiss',
#   'biotite sillimanite gneiss',
#   'cordierit gneiss',
#   'disthene gneiss',
#   'disthene staurolite gneiss',
#   'disthene sillimanite gneiss',
#   'mica gneiss',
#   'garnet gneiss',
#   'garnet biotite gneiss',
#   'garnet cordierit sillimanite gneiss',
#   'garnet disthene gneiss',
#   'garnet disthene sillimanite gneiss',
#   'garnet disthene staurolite gneiss',
#   'garnet plagioclase gneis',
#   'graphite gneiss',
#   'hornblende biotite gneiss',
#   'muscovite gneiss',
#   'muscovite biotite gneiss',
#   'muscovite biotite garnet gneiss',
#   'muscovite garnet gneiss',
#   'pyroxene gneiss',
#   'quartz biotite plagioclase gneiss',
#   'staurolite garnet plagioclase gneiss',
#   'metafelsic granulite',
#   'granulite',
#   'granulite gneiss',
#   'charnockite metamorphic affinity',
#   'acidic to intermediate hornfels',
#   'andalusite hornfels',
#   'biotite hornblende plagioclase hornfels',
#   'cordierite hornels',
#   'coround hercynite hornfels',
#   'metamafics',
#   'greenschist',
#   'actinolite schist',
#   'prasinite',
#   'amphibolite',
#   'biotite amphibolite',
#   'biotite pyroxene amphibolite',
#   'diopside amphibolite',
#   'epidote amphibolite',
#   'garnet amphibolite',
#   'carbonate silicate amphibolite',
#   'zoisite amphibolite',
#   'eklogite amphibolite',
#   'metamafic granulite',
#   'eclogite',
#   'metamafic hornfels',
#   'meta ultramafic',
#   'chlorite actinolite schist',
#   'talcum schist',
#   'serpentinite',
#   'ultra mafic hornfels',
#   'olivine fels',
#   'tectonite',
#   'cataclast',
#   'fault breccia',
#   'melange',
#   'schist',
#   'slate slaty metamudstone',
#   'black shale',
#   'alum shale',
#   'ribbon slate',
#   'silty schist',
#   'mylonite',
#   'migmatite',
#   'anatexite',
#   'metatexite',
#   'diatexite',
#   'syntexite',
#   'sedimentary',
#   'siliciclastic sedimentary',
#   'sandstone pelite alternation',
#   'sandstone dominated sandstone pelite alternation',
#   'pelite dominated sandstone pelite alternation',
#   'pelite gypsum alternation',
#   'pelite dominated pelite gypsum alternation',
#   'gypsum dominated pelite gypsum alternation',
#   'pelite',
#   'silicate claystone',
#   'silicate siltstone',
#   'sapropelite',
#   'psammitearenite',
#   'arenite sandstone',
#   'fine sandstone',
#   'medium sandstone',
#   'coarse sandstone',
#   'quartz arenite',
#   'fine quartz arenite',
#   'medium quartz arenite',
#   'coarse quartz arenite',
#   'subfeldspatic arenite  feldspatic sandstone',
#   'fine subfeldspatic arenite',
#   'medium subfeldspatic arenite',
#   'coarse subfeldspatic arenite',
#   'feldspatic arenite',
#   'fine feldspatic arenite',
#   'medium feldspatic arenite',
#   'coarse feldspatic arenite',
#   'arkose',
#   'fine arkose',
#   'medium arkose',
#   'coarse arkose',
#   'sublitharenite',
#   'fine sublitharenite',
#   'medium sublitharenite',
#   'coarse sublitharenite',
#   'litharenite',
#   'fine litharenite',
#   'medium litharenite',
#   'coarse litharenite',
#   'lithic arenite',
#   'fine lithic arenite',
#   'medium lithic arenite',
#   'coarse lithic arenite',
#   'graywacke wacke',
#   'fine graywacke',
#   'medium graywacke',
#   'coarse graywacke',
#   'quartz wacke',
#   'fine quartz wacke',
#   'medium quartz wacke',
#   'coarse quartz wacke',
#   'feldspathic wacke',
#   'fine feldspethic wacke',
#   'medium feldspethic wacke',
#   'coarse feldspethic wacke',
#   'lithic wacke',
#   'fine lithic wacke',
#   'medium lithic wacke',
#   'coarse lithic wacke',
#   'psephite',
#   'conglomerate',
#   'pebbly conglomerate',
#   'fine pebble granule',
#   'medium to coarse pebble',
#   'very coarse pebble',
#   'cobbles',
#   'boulders',
#   'breccia',
#   'grus breccia',
#   'fine grus breccia',
#   'medium grus breccia',
#   'coarse grud breccia',
#   'debris breccia',
#   'block debris breccia',
#   'carbonatic sedimentary',
#   'carbonatic siliciclastic sedimentary',
#   'limestone marl alteration',
#   'limestone dominated limestone marl alteration',
#   'marl dominated limestone marl alteration',
#   'pelite marl alteration',
#   'pelite dominated pelite marl alteration',
#   'marol dominated pelite marl alteration',
#   'carbonate bearing siliciclastic',
#   'carbonate bearing claystone',
#   'carbonate bearing mudstone',
#   'carbonate bearing sandstone',
#   'carbonate bearing fine sandstone',
#   'carbonate bearing medium sandstone',
#   'carbonate bearing coarse sandstone',
#   'carbonate bearing conglomerate',
#   'carbonate bearing breccia',
#   'dolomite bearing siliciclastic',
#   'dolomite bearing claystone',
#   'dolomite bearing mudstone',
#   'dolomite bearing sandstone',
#   'dolomite bearing fine sandstone',
#   'dolomite bearing medium sandstone',
#   'dolomite bearing coarse sandstone',
#   'dolomite bearing conglomerate',
#   'dolomite bearing breccia',
#   'carbonatic siliciclastic',
#   'carbonatic claystone',
#   'carbonatic mudstone',
#   'carbonatic sandstone',
#   'carbonatic fine sandstone',
#   'carbonatic medium sandstone',
#   'carbonatic coarse sandstone',
#   'carbonatic conglomerate',
#   'carbonatic breccia',
#   'dolomitic siliciclastic',
#   'dolomitic claystone',
#   'dolomitic mudstone',
#   'dolomitic sandstone',
#   'dolomitic fine sandstone',
#   'dolomitic medium sandstone',
#   'dolomitic coarse sandstone',
#   'dolomitic conglomerate',
#   'dolomitic breccia',
#   'siliciclastic limestone',
#   'clayey limestone',
#   'muddy limestone',
#   'sandy limestone',
#   'fine sandy limestone',
#   'medium sandy limestone',
#   'coarse sandy limestone',
#   'conglomeratic limestone',
#   'brecciatic limestone',
#   'siliciclastic dolimite',
#   'clayey dolomite',
#   'muddy dolomite',
#   'sandy dolomite',
#   'fine sandy dolomite',
#   'medium sandy dolomite',
#   'coarse sandy dolomite',
#   'conglomeratic dolomite',
#   'brecciatic dolomite',
#   'clay lime composite',
#   'marly claystone',
#   'marl claystone',
#   'clay marl',
#   'marl',
#   'lime marl',
#   'dolomite marl',
#   'marl limestone',
#   'marl dolomite',
#   'marly limestone',
#   'marly dolomite',
#   'carbonate',
#   'clastic sedimentary carbonate',
#   'lutite',
#   'siltite',
#   'arenite',
#   'fine grained arenite',
#   'medium grained arenite',
#   'coarse grained arenite',
#   'ooidlothic',
#   'oncolithic',
#   'rudite',
#   'dolomite',
#   'dolomitic lutite',
#   'dolomitic siltite',
#   'dolomitic arenite',
#   'fine grained dolomitic arenite',
#   'medium grained dolomitic arenite',
#   'coarse grained dolomitic arenite',
#   'dolomitic rudite',
#   'limestone',
#   'calcitic lutite',
#   'calcitic siltite',
#   'calcitic arenite',
#   'fine grained calcitic arenite',
#   'medium grained calcitic arenite',
#   'coarse grained calcitic arenite',
#   'calcitic rudite',
#   'carbonate of dunham  and embry & klovan ',
#   'allothonous limestone',
#   'mud supported limestone',
#   'mudstone',
#   'wackstone',
#   ...],
#  'list_states': ['massachusetts',
#   'california',
#   'rhode island',
#   'vermont',
#   'transvaal',
#   'pennsylvania',
#   'montana',
#   'quebec',
#   'wisconsin',
#   'north carolina',
#   'bavaria',
#   'louisiana',
#   'texas',
#   'oklahoma',
#   'colorado',
#   'utah',
#   'wyoming',
#   'oregon',
#   'washington',
#   'kyushu',
#   'akita',
#   'hokkaido',
#   'atlantic ocean',
#   'hawaii',
#   'java',
#   'brandenburg',
#   'schleswig-holstein',
#   'western namibia',
#   'southeastern australia',
#   'western south africa',
#   'bahia',
#   'michigan',
#   'new hampshire',
#   'iberian peninsula',
#   'queensland',
#   'ontario',
#   'corsica',
#   'north taiwan',
#   'central',
#   'ávila',
#   'fars',
#   'inyo county',
#   'chhattisgarh',
#   'scotland',
#   'northern territory',
#   'central zimbabwe',
#   'idaho',
#   'singida',
#   'southern india',
#   'otjozondjupa',
#   'central zambia',
#   'khémisset',
#   'dawson strait',
#   'baden-württemberg',
#   'manitoba',
#   'karnataka',
#   'jalisco',
#   'east greenland',
#   'sierra nevada',
#   'bretagne',
#   'southern france',
#   'central northern nepal',
#   'karas',
#   'jharkand',
#   'alaska',
#   'southern finland',
#   'eastern south africa',
#   'scottland',
#   'andhra pradesh',
#   'pyrenees',
#   'western australia',
#   'central south africa',
#   'bodrum',
#   'parinacota',
#   'antofagasta',
#   'northeastern spain',
#   'moresby strait',
#   'central eastern china',
#   'ivrea-verbano',
#   'salta',
#   'virunga',
#   'eastern australia',
#   'tarapacá',
#   'khomas',
#   'vianden',
#   'western russia',
#   'galicia',
#   'central nepal',
#   'australia',
#   'bismarck archipelago',
#   'manyara',
#   'québec',
#   'erongo',
#   'tamil nadu',
#   'eastern canada',
#   'arusha',
#   'sud',
#   'iguape',
#   'rhineland-palatinate',
#   'north west',
#   'jiangsu',
#   'dodoma',
#   'heard island',
#   'mcdonald islands',
#   'labrador',
#   'iowa',
#   'banks peninsula, christchurch',
#   'nova scotia',
#   'garratoxa',
#   'kansas',
#   'tristan da cunha',
#   'gough',
#   'northern tanzania',
#   'chile & argentina',
#   'vogelsaug',
#   'mashonaland',
#   'apennines',
#   'kastamonu',
#   'piemonte',
#   'mutasa',
#   'oberbergau',
#   'ascension',
#   'masvingo',
#   'southern brazil',
#   'northwest territories',
#   'western iran',
#   'st. helena',
#   'kilimanjaro region',
#   'kunene',
#   'bouvet',
#   'viti levu, tavua',
#   'kamchatka',
#   "sana'a and amran",
#   'victoria',
#   'bougainville',
#   'norther pacific',
#   'new hebrides',
#   'kgalagadi',
#   'niuatoputapu',
#   'north-east',
#   'western cordillera',
#   'montechristi',
#   'new britain',
#   'santa isabel',
#   'malaita',
#   'gorgona island',
#   'gansu province',
#   'michoacán ',
#   'puebla',
#   'tushka',
#   'campanian',
#   'pozzuoli/ campanian',
#   'roman',
#   'red sea area',
#   'sinai',
#   'western desert',
#   'akranes',
#   'hvalfjarðarsveit',
#   'borgarbyggð',
#   'grundarfjörður',
#   'grundarfjarðarbær',
#   'gullbringusýsla',
#   'west tushka',
#   'hornafjörður',
#   'chelungpu fault',
#   'hvalfjarðarstrandarhreppur',
#   'hveragerði',
#   'antalya',
#   'icel',
#   'mugla',
#   'konya',
#   'burgur',
#   'nigde',
#   'diayarbakir',
#   'bursa',
#   'aksaray',
#   'kayseri',
#   'ayfonkarahisar',
#   'afyonkarahisar',
#   'kutahya',
#   'izmir',
#   'izmir or balikesir',
#   'kirsehir',
#   'sivas',
#   'marmara island',
#   'provinz pontevedra',
#   'mosfellsbær',
#   'snæfellsbær',
#   'reykjavík',
#   'skorradalshreppur',
#   'skútustaðahreppur',
#   'kerala',
#   'vesturland',
#   'nevada',
#   'north german basin',
#   'alberta',
#   'hessen',
#   'tirol',
#   'ile de france',
#   'campanian area',
#   'rome',
#   'sicily',
#   'messina',
#   'rhode island',
#   'niedersachsen',
#   'east midlands',
#   'south iceland',
#   'lahendong',
#   'washington state',
#   'british columbia',
#   'suðurnes',
#   'waikato',
#   'colima',
#   'jalisco ',
#   'giresun',
#   'gümüshane',
#   'lower saxonyniedersachsen',
#   'baden würtemberg',
#   'rheinland pfalz',
#   'bengal basin']}

# %% [markdown]
# ## NER Library

# %%
#Ready for NLP NER
ready_ner = {'text':[],'tag':[],'entity':[]}
for i in prepro2:
    for j in dict_entities:
        pattern = r"(\.*\b(?:{}))\b".format("|".join(dict_entities[j]))
        if bool(re.search(pattern, i)) == True:
            ready_ner['text'].append(i)
            ready_ner['tag'].append(re.search(pattern, i).group())
            ready_ner['entity'].append(re.search(r'list_(\w+)$',j).group(1))

# %%
ready_ner['text']
# Out:
# ['introduction variscan orogenesis characterize emplacement huge volume felsic magma composition origin debate',
#  'reference mesozoic cenozoic presentday mountain chain coast range batholith himalaya provide neithersatisfactory model tectonic setting suitable explanation production emplacement huge volume granite',
#  'reference mesozoic cenozoic presentday mountain chain coast range batholith himalaya provide neithersatisfactory model tectonic setting suitable explanation production emplacement huge volume granite',
#  'reference mesozoic cenozoic presentday mountain chain coast range batholith himalaya provide neithersatisfactory model tectonic setting suitable explanation production emplacement huge volume granite',
#  'calcalkaline trend characterize magmatic suite association base specific proportion gabbrodiorite tonalitegranodiorite granite inbatholith active margin batholith peru proportion',
#  'calcalkaline trend characterize magmatic suite association base specific proportion gabbrodiorite tonalitegranodiorite granite inbatholith active margin batholith peru proportion',
#  'outcrop mgkenriched granitoid ultrapotassicmafic rock southwestern branch variscan orogen visible external crystalline massif alps',
#  'outcrop mgkenriched granitoid ultrapotassicmafic rock southwestern branch variscan orogen visible external crystalline massif alps',
#  'pluton northwestern corsica variscan europe bauon massif southern pagel leterrier pagel bohemian massif relationship time emplacement composition source calcalkaline trend remain clarify',
#  'pluton northwestern corsica variscan europe bauon massif southern pagel leterrier pagel bohemian massif relationship time emplacement composition source calcalkaline trend remain clarify',
#  'pluton northwestern corsica variscan europe bauon massif southern pagel leterrier pagel bohemian massif relationship time emplacement composition source calcalkaline trend remain clarify',
#  'aim paper provide constraint forgenetic model variscan batholith corsica france sardinia italy rossi cocherie',
#  'aim paper provide constraint forgenetic model variscan batholith corsica france sardinia italy rossi cocherie',
#  'aim paper provide constraint forgenetic model variscan batholith corsica france sardinia italy rossi cocherie',
#  'chemical evolution magmas produce batholith isotopic composition type magmatic magmatic nature initial existence inherit isotopic zonation heterogeneity',
#  'clarify respective play rework continental crust input mantlederived material',
#  'variscan batholith corsica besuitable target existence excellent outcrop granite associate mafic rock',
#  'variscan batholith corsica besuitable target existence excellent outcrop granite associate mafic rock',
#  'variscan batholith corsica besuitable target existence excellent outcrop granite associate mafic rock',
#  'geological set genesis mediterranean calcalkalic plutonic association study corsicansardinian batholith field petrography majorelement geochemistry',
#  'geological set genesis mediterranean calcalkalic plutonic association study corsicansardinian batholith field petrography majorelement geochemistry',
#  'assume mafic silicic rock result differentiation ofmafic magma',
#  'hypothesis leterrier debon favour mix mantlederived crustal component base traceelement fourcade gre isotopegeochemistry gre provide evidence crustal anatexis formation granitoid rock mix mantlederived magma crustal material genesis mafic body',
#  'hypothesis leterrier debon favour mix mantlederived crustal component base traceelement fourcade gre isotopegeochemistry gre provide evidence crustal anatexis formation granitoid rock mix mantlederived magma crustal material genesis mafic body',
#  'variscan batholith corsica consist pluton distinct mineralogical petrographic characteristic',
#  'variscan batholith corsica consist pluton distinct mineralogical petrographic characteristic',
#  'mineralogical traceelement study silicic intrusion corsican calcalkaline batholith granite unit represent batch crustal anatexis',
#  'dearly cumulate rock suite produce fractional crystallization magma mantle origin',
#  'lead rossi chevremont qualify suchplutonic association suggestdistinction calcalkaline rock relate active margin',
#  'lead rossi chevremont qualify suchplutonic association suggestdistinction calcalkaline rock relate active margin',
#  'corsicasardinia batholith resuite successive intrusion magmatic association middle carboniferous middle permian time',
#  'corsicasardinia batholith resuite successive intrusion magmatic association middle carboniferous middle permian time',
#  'summarize mineralogical datum rock geochemical discussion appendix detailed petrographic mineralogical datum rossi rossi cocherie',
#  'early mgk plutonic association compose biotiteamphiboleclinopyroxenekfeldsparmegacrystbeare monzonite biotitesyenogranite associate ultrapotassic rock form association',
#  'contact silicic mgk rock invariably plastic internal structure',
#  'mafic body generally doexceed length commonly group swarm',
#  'mafic body generally doexceed length commonly group swarm',
#  'rare lamprophyre dyke crosscut metamorphic basement intrusion relate ultrak rock',
#  'palaeozoic mgk granitoid vertical stripe ultrapotassic black patch granodiorite orient crosse trend flow structure ultramafic volcanic rock andesite dacite rhyolite alkalic volcanic alkalic plutonic postbatholithic formation',
#  'palaeozoic mgk granitoid vertical stripe ultrapotassic black patch granodiorite orient crosse trend flow structure ultramafic volcanic rock andesite dacite rhyolite alkalic volcanic alkalic plutonic postbatholithic formation',
#  'chemical geology volcanicplutonic association compose mafic silicic body',
#  'plutonic rock outcrop rare volcanicrock roof pendant batholith occur nw corsica',
#  'plutonic rock outcrop rare volcanicrock roof pendant batholith occur nw corsica',
#  'plutonic rock outcrop rare volcanicrock roof pendant batholith occur nw corsica',
#  'intermediate acidic plutonicrock composition range mafic microgranular enclavebeare granodiorite evidence felsicmafic mingle phenomenon monzogranire leucomonzogranite associate ultramafic complex',
#  'rocks calcalkaline association occur enclave septum ultramafic complex size consist cumulate peridotitic troctolitic gabbronoritic noncumulate range composition gabbronorite olivine norite diorite',
#  'field petrological geochronological evidence indicatelink plutonic volcanic rock regard magma chamber relate andesite',
#  'dacite identical geochemical pattern granodiorite volcanic equivalent crosscut leucomonzogranite',
#  'ree sample determine withradiochemical procedure involve separation reegroup dissolve irradiate powdered rock',
#  'age initial ratio calculation assume absolute error measure high individual analytical error andrelative error ratio analytical',
#  'age initial ratio calculation assume absolute error measure high individual analytical error andrelative error ratio analytical',
#  'definition unit major trace element majorand traceelement analysis rock',
#  'cnk ratio wholerock acidic sample association characterize slight peraluminous bulk composition',
#  'cnk ratio wholerock acidic sample association characterize slight peraluminous bulk composition',
#  'oxide trend plot enablefairly clear distinction sample rock content composition close minimum melt granite',
#  'interesting leucocratic granite havemuch low content rock',
#  'fe content chemical geology I biotite low effective discriminating criterion rossi chevremont',
#  'contrast trend lowsilicacontent range unit emphasize play mineral fractionation textural evidence',
#  'mgk association rock major element display smooth variation fit straight projection suggestlinkage silicic endmember',
#  'fairly constant alkali sum control ferromagnesian mineral kfeldspar abundance decrease increase acidic apex',
#  'trend relate fractionation accessory mineral apatite titanite',
#  'ratio rock characterize highto ultrapotassic composition',
#  'ratio rock characterize highto ultrapotassic composition',
#  'rich alkali mgo poor cao association compare classical highk calcalkaline plutonic',
#  'traceelement distribution suite mgk plutonism characterize enrichment transition metal high concentration largeion lithophile element rb high content element small highly charge ta hf',
#  'sample include rock exhibit strong ree fractionation',
#  'total ree content generally high decrease acidic rock lree ppm withhigh average rock ppm andquite average mgk granitoid rock ppm',
#  'siliceous sample concave heavy ree hree distribution pattern',
#  'traceelement datum rocks mgk association great similarity datum calcalkaline lamprophyre high ree rb concentration',
#  'acidic intermediate rock granodiorite type ree pattern withconstant zree acidic granodiorite fractionate pattern yb mgk granitoid rock anomaly',
#  'intermediate granodiorite fractionated light ree lree pattern hreeenriched pattern andnegative anomaly',
#  'acidic granodiorite pronounce anomaly unusual compare general differentiation trend granitic magma accord tofractional crystallization point discuss',
#  'lree pattern fractionate anomaly siliceous clb pattern highly siliceous granodiorite clb',
#  'author cocherie fourcade gre gromet silver mittlefehtdt miller recognize accessory phase allanite monazite trap lree late stage differentiation',
#  'eb I chemical geology major oxide traceelement ppm concentration association metamorphose rock corsica peridotite troctolites clb clb clb clb I mno mgo cao',
#  'eb I chemical geology major oxide traceelement ppm concentration association metamorphose rock corsica peridotite troctolites clb clb clb clb I mno mgo cao',
#  'eb I chemical geology major oxide traceelement ppm concentration association metamorphose rock corsica peridotite troctolites clb clb clb clb I mno mgo cao',
#  'mafic rock textural evidence olivine plagioclase cumulative process ultramafic rock rossi emphasize contrast disposition cloud major oxide cao dominant plagioclase fractionation',
#  'troctolite showslightly fractionated pattern withwelldevelope positive anomaly low concentration level correspond modal composition rock consist cumulate plagioclase',
#  'gabbronorite cumulative origin low ree concentration withvery weak positive anomaly',
#  'differentiate gabbro correspond primary magma havehigh ree content ppm cumulate orweak negative anomaly lreeenriche pattern',
#  'rocks gabbro diorite differentiate cogenetic suite cocherie generally shownegative anomaly ree enrichment',
#  'detailed traceelement investigation exception general cogenetic evolutionary rock equal initial liquid composition high hree content slight enrichment incompatible element ta',
#  'gabbro considerproduct ofprimary melt chemical geology I',
#  'mgk rock compare withsimilar association outcropping bohemia calcalkaline association corsican batholith',
#  'range composition major trace element ree pattern basalt tholeiitic basalt jakes culler graf',
#  'traceelement pattern define group rock define field petrographic study',
#  'contrast distribution docontradict hypothesis formation source silicic endmember composition',
#  'contrast distribution docontradict hypothesis formation source silicic endmember composition',
#  'gap intermediate composition observe trend berelate undersample member association origin',
#  'isotope composition beuseful tool definition protolith origin',
#  'isotope data monzodioritemonzogranite sample mgk association define wholerock regression correspond age initial ratio',
#  'acidmarie interaction age radiogenic component low initial ratio type interaction insignificant',
#  'syenomonzonite plot onhave low agecorrecte ratio range fall isochron sixth plot',
#  'sample calcalkaline association defineregression yield age initial ratio',
#  'leucocratic crosscut provide regression giveyoung age initial ratio',
#  'representative chondritenormalize ree pattern mgk basic rock syenomonzonite monzodiorite',
#  'granodiorite consist group clb anomaly clb clb withnegative anomaly',
#  'variation leucocratic lead decrease lree increase hree content increasingly negative anomaly',
#  'variation leucocratic lead decrease lree increase hree content increasingly negative anomaly',
#  'wise pb evaporation leucomonzogranite northern corsica age emplacement huge granite batholith',
#  'wise pb evaporation leucomonzogranite northern corsica age emplacement huge granite batholith',
#  'wise pb evaporation leucomonzogranite northern corsica age emplacement huge granite batholith',
#  'representative point sample granodiorite dodefine isochron lie reference isochron low ratio',
#  'representative point sample granodiorite dodefine isochron lie reference isochron low ratio',
#  'acidic granitoid rock displayrather constant initial ratio radiogenic european hercynian plutonic rock sardinia cochefie rock calcalkaline complex plot plot scatter reference isochron troctolite gabbro chemical geology',
#  'acidic granitoid rock displayrather constant initial ratio radiogenic european hercynian plutonic rock sardinia cochefie rock calcalkaline complex plot plot scatter reference isochron troctolite gabbro chemical geology',
#  'representative chondritenormalize ree pattern basic rock associate calcalkaline suite',
#  'solid cumulate circle gabbro correspond topossible initial melt clb gabbro clb diorite clb correspond differentiated double peridotite',
#  'indicatedifferent origin rock acidic granitoid rock',
#  'smnd isotope datum isochron method granitoid rock isochron',
#  'absence isotopic homogenization isotope scale batholith partly young age granitoid complex narrow range variation ratio compare range ratio',
#  'field relationship andsmnd isochron fozzanopeloso lead calculate young age agree zem age determine',
#  'field relationship andsmnd isochron fozzanopeloso lead calculate young age agree zem age determine',
#  'group sample indicatecrustal origin rocks mantle affinity',
#  'bepossible distinguish granitic rock suchdiagram',
#  'oxygen isotope datum rock sovalue range mgk',
#  'acidic rock low common rocktype composition variscan intrusion',
#  'rock showregular increase rock granodiorite leucomonzogranite',
#  'lack gap acidic rock eithercogenetic relationship silicic rock deriving hybridization process bridge gap endmember',
#  'isotope fractionation observe acidic term large result fractional wholerock plot content usedifferentiation',
#  'trend compare observe oceanic ascension island south atlantic wherefractionation trend considergood estimate isotope behaviour accompany fractional crystallization',
#  'trend compare observe oceanic ascension island south atlantic wherefractionation trend considergood estimate isotope behaviour accompany fractional crystallization',
#  'difference fractionation trend large attribute temperature difference plutonic volcanic process',
#  'difference fractionation trend large attribute temperature difference plutonic volcanic process',
#  'high rock sample explain isotopic contamination magma crustal rock occur enclave acidic pluton granodiorite evidence magmatic interaction low aovalue',
#  'isotopic composition ofsr concentration ofrb variscan calcalkaline rock western corsica variscan highmgk granitoid associate rocks age sample rb tdm ppm ppm ppm ppm smow',
#  'isotopic composition ofsr concentration ofrb variscan calcalkaline rock western corsica variscan highmgk granitoid associate rocks age sample rb tdm ppm ppm ppm ppm smow',
#  'isotopic composition ofsr concentration ofrb variscan calcalkaline rock western corsica variscan highmgk granitoid associate rocks age sample rb tdm ppm ppm ppm ppm smow',
#  'calcalkaline rock western assume granodiorite assume clb clb',
#  'clb clb clb clb clb clb bleucocratic age clb clb clb clb clb clb clb clb mafic suite assume age lm clb clb clb pv clb clb clb clb clb clb clb',
#  'continue sample rb smp ppm ppm ppm ppm tdm smow variscan highmgk granitoid associate mafic rock age I',
#  'mgk association doshow regular trend calcalkaline composite association syenomonzonite range monzodiorite overlap syenomonzonite',
#  'exception contaminate hybridize sample rock low jlsovalue typical ofmantle origin',
#  'variscan plutonic rock previous study high rock',
#  'leucomonzogranite havenarrow range aovalue low variscan twomica granite',
#  'trend differentiation correspond fractional crystallization acidic magma monzogranitic composition trend',
#  'trend increase initial ratio increase sovalue crustal contamination assimilation fractional crystallization ofmantlederived magma direct acidbasic hybridization',
#  'plot corsican variscan granitoid rock',
#  'isochron mgk suite granite sample diamond',
#  'basic rock solid diamond dodefine isochron',
#  'group rock withnarrow range variation ratio definecorrelation indicative age compose sample fall reference isochron representmixing text discussion',
#  'group rock withnarrow range variation ratio definecorrelation indicative age compose sample fall reference isochron representmixing text discussion',
#  'distribution basic rock association diagram compare reference isochron',
#  'isochron granitoid rock chemical geology',
#  'hafic rock I granodiorite I',
#  'ratio calculate age usepresentday isotope composition ratio',
#  'ratio calculate age usepresentday isotope composition ratio',
#  'wholerock sovalue content calcalkaline rock association corsica',
#  'wholerock sovalue content calcalkaline rock association corsica',
#  'wholerock sovalue content calcalkaline rock association corsica',
#  'evolution trend ascension volcanic rock plot comparison',
#  'evolution trend ascension volcanic rock plot comparison',
#  'tope datum rock type contrast corsican pyrenean granitoid rock',
#  'thuslarge mantle contribution mafic magma evident corsica trend doextrapolate endmember mantletype',
#  'thuslarge mantle contribution mafic magma evident corsica trend doextrapolate endmember mantletype',
#  'thuslarge mantle contribution mafic magma evident corsica trend doextrapolate endmember mantletype',
#  'isotope datum uz mafic rock mantlederived acidic rock crustalderive fromsource isotope composition',
#  'intermediate granodiorite result mix process',
#  'southern variscan realmclear isotopic zonation corsica origin discuss infurther',
#  'southern variscan realmclear isotopic zonation corsica origin discuss infurther',
#  'sro diagram analyse rock symbol suite indicatemantle affinity althoughcrustal contamination trend large arrow correspond evolution mafic rock corsica showgeneral trend mixingcontamination initial magma mantle origin narrow isotopic range variation granite withweak increase differentiate rock trend',
#  'sro diagram analyse rock symbol suite indicatemantle affinity althoughcrustal contamination trend large arrow correspond evolution mafic rock corsica showgeneral trend mixingcontamination initial magma mantle origin narrow isotopic range variation granite withweak increase differentiate rock trend',
#  'sro diagram analyse rock symbol suite indicatemantle affinity althoughcrustal contamination trend large arrow correspond evolution mafic rock corsica showgeneral trend mixingcontamination initial magma mantle origin narrow isotopic range variation granite withweak increase differentiate rock trend',
#  'correspond typical granite associate rock nres',
#  'matic acid rocks cocherie genetic link exist mgk rock chemical mineral datum isotope',
#  'magmatic process lead association rock',
#  'magmatic process lead association rock',
#  'majorand traceelement datum geochemical characteristic rock mgk association high concentration high content incompatible element rb lree hf strong ree fractionation large anomaly',
#  'mineral composition vary felsic rocktype',
#  'fact pointgenetic link rock include mafic',
#  'isotope datum suchgenetic isochron diagram ultrak mafic rock doplot isochron acidic rock rocks definelinear correlation intersect representative point plot isochron locate',
#  'felsic rock havenarrow range variation maric rock range mix mantlederived material andcrustal component crustal source felsic magma',
#  'low sample isotopic disequilibrium ornonmagmatic equilibrium temperature mineralogical study point equilibrium',
#  'mgk mafic rock provide evidence noncogenetic character mafic felsic rock mgk association',
#  'gap acid rock yield mix group compose rock scatter isotope',
#  'gap acid rock yield mix group compose rock scatter isotope',
#  'isotope characteristic mgk granite range monzodiorite leucosyenogranite indicatepossible cogenetic suite test traceelement calculation',
#  'ultrak mafic rock data point mafic mgk rock scatter rbsrisochron srnd diagram suggestmixing process endmember consist mantlederived material andcrustal component',
#  'accord isotope datum crustal component compare mgk granite',
#  'chemical geology crustal endmember docontribute magma mgk acidic rock',
#  'ree fractionation normal detrital sedimentary rock wildeman haskin mgk granite great hree fractionation',
#  'yb ratio varyfunction crustal component isochron decrease increase sri decrease',
#  'high lree content characteristic ofprimary mantlederived magma butofcrustal component',
#  'magma mixing assimilation silicarich crustal material bethe enrichment igneous rock',
#  'spiderdiagram plot ultrak rock identify lamprophyre',
#  'question origin highly potassic mantlederived model proposehigh degree crystal fractionation yoder zone refining harris extremely small degree partial melting garnetperidotite mantle material sun fusion ofmetasomatize mantle source bell hawkesworth wass rogers windom boettcher leaching wall rock enrichment incompatible element ascent melt',
#  'finally propose melt fraction small separate mantie metasomatize layer small melt fraction accumulate remelt low temperature adiabatic decompression crust stretch throughtemperature increase byhot plume potassic magma',
#  'finally propose melt fraction small separate mantie metasomatize layer small melt fraction accumulate remelt low temperature adiabatic decompression crust stretch throughtemperature increase byhot plume potassic magma',
#  'traceelement abundance gabbro sample clb representative primitive mafic magma associate granite',
#  'sequence element base order decrease incompatibility oceanic basalt',
#  'datum compare average nmorb emorb sun average calcalkaline lamprophyre estimate rock',
#  'production ultrak mafic rock fromzonerefine process fit traceelement isotope datum corsican mafic rock',
#  'hypothetical stagephlogopite garnet bear source melt depth',
#  'hypothetical stagephlogopite garnet bear source melt depth',
#  'magma inducezonerefine process traverse mantle lead tosignificant increase incompatibleelement content isotopic characteristic melt remain mantle affinity chemical geology increase concentration',
#  'magma inducezonerefine process traverse mantle lead tosignificant increase incompatibleelement content isotopic characteristic melt remain mantle affinity chemical geology increase concentration',
#  'insecond stage enrich magma interact base crust lead lower yb high low ratio',
#  'insecond stage enrich magma interact base crust lead lower yb high low ratio',
#  'insecond stage enrich magma interact base crust lead lower yb high low ratio',
#  'interaction contamination assimilation crystal fractionation associate mgk felsic rock doseem major process involve',
#  'fractional crystallization acidic rockdiscussion relationship mgk granite traceelement datum identification magmatic process involve petrogenetic model mineral proportion equilibrium liquid rate evolution magmatic process quantify traceelement ree pattern',
#  'fractional crystallization acidic rockdiscussion relationship mgk granite traceelement datum identification magmatic process involve petrogenetic model mineral proportion equilibrium liquid rate evolution magmatic process quantify traceelement ree pattern',
#  'yb correlation fairly good average correlation coefficient',
#  'provide additional evidence fractional crystallization process explain geochemical trend monzonitic syenogranitic composition',
#  'correlation distribution coefficient remain constant suggestfirst approximation proportion crystallize solid phase begreatly modify magmatic evolution',
#  'correlation distribution coefficient remain constant suggestfirst approximation proportion crystallize solid phase begreatly modify magmatic evolution',
#  'simultaneous modelling ree rb test fractional crystallization model ree identify mineral proportion cumulate phase calculate extent fractional crystallization process',
#  'calculate concentration ofrb evolve liquid fit analyse sample heavy biotite plagioclase kfeldspar',
#  'hand ree control amphibole accessory apatite zircon auanite titanite case titanite play crystallization',
#  'calculate ree concentration amphibole titanite lead ree pattern experimental datum initial concentration primitive liquid monzodioritic composition select correlation diagram',
#  'calculate ree concentration amphibole titanite lead ree pattern experimental datum initial concentration primitive liquid monzodioritic composition select correlation diagram',
#  'traceelement content I initial liquid monzodioritic composition define support isotope datum study origin primary acidic magma',
#  'summarize geochemical mineral chemical datum rock lead existence maficfelsic interaction association lead torock intermediate composition support field evidence mix process occurrence microgranular enclave ultrapotassic composition monzonite monzogranodiorite',
#  'summarize geochemical mineral chemical datum rock lead existence maficfelsic interaction association lead torock intermediate composition support field evidence mix process occurrence microgranular enclave ultrapotassic composition monzonite monzogranodiorite',
#  'rock sample belong calcalkaline association collect var chemical geology',
#  'plot ree rb onloglog scale highmgk granite',
#  'calculate ree pattern mgk granite',
#  'ious location ofpila canale levie roccapina small mafic septum',
#  'method graphic determination bulkdistribution coefficient compatible incompatible hygromagmatophile rb ta hf element cocherie covariance fourteen pair element',
#  'pila canale select quantitative study large size wide variety composition range troctolite diorite sample plot onstraight onlog log ta diagram',
#  'range composition gabbro diorite cumulative troctolite cumulative texture considerpure cumulate',
#  'point plot scatter cumulative liquidevolution chemical geology traceelement model calculation fractional crystallization useprimitive liquid monzodioritic composition produce mgk association kd plagiokfeldbioamphititaclase spar rite bole rb gd yb kd individual partition coefficient study element empirically determine measure concentration separated biotite amphibole plagioclase concentration rock',
#  'point plot scatter cumulative liquidevolution chemical geology traceelement model calculation fractional crystallization useprimitive liquid monzodioritic composition produce mgk association kd plagiokfeldbioamphititaclase spar rite bole rb gd yb kd individual partition coefficient study element empirically determine measure concentration separated biotite amphibole plagioclase concentration rock',
#  'calcalkaline granitoid association range composition diorite granodiorite',
#  'dcalculate bulk distribution coefficient respective proportion crystallize plagioclase kfeldspar biotite amphibole titanite',
#  'dcalculate bulk distribution coefficient respective proportion crystallize plagioclase kfeldspar biotite amphibole titanite',
#  'initial concentration primitive monzodiorite infer correlation diagram',
#  'accessory mineral chromite playmajor concentration',
#  'consideration inverse geochemical approach hypothesis bulkdistribution coefficient phase equilibrium liquid',
#  'calculation dorequireknowledge partition coefficient analyse cumulate assume representative instantaneous solid phase equilibrium evolve liquid',
#  'accord kind cumulate troctolite low hygromagmatophileelement content transitionelement enrichment gabbronorite gabbro low transitionmetal content',
#  'logarithmic plot ta basic rock associate association variscan batholith corsica',
#  'logarithmic plot ta basic rock associate association variscan batholith corsica',
#  'logarithmic plot ta basic rock associate association variscan batholith corsica',
#  'trend symbol correspond rock representative ofmelt pila canale solid symbol represent cumulate',
#  'cumulate rock plot trend compose cumulate mineral interstitial mineral representative melt equilibrium',
#  'calculate initial liquid fit composition ofgabbro clb rossi initial melt basis field petrological datum',
#  'ree calculation loglog diagram demonstrate mafic rock regard suite evolve accord tofractionalcrystallization process',
#  'isotope heterogeneous gabbro troctolite diorite',
#  'fractionalcrystallization process afc ree content diorite clb high compare granite considerresult afc process',
#  'afc process involve assimilate material doderive granite magma',
#  'crustal fluid interact mafic magma fractional crystallization',
#  'solidify liquid gabbro primitive cumulate troctolite retain primitive isotopic character evolve magma diorite interact duringmuch long period crustal fluid',
#  'origin mafic rock point mafic rock calcalkaline association origin nature source material degree homogeneity source material tectonic environment time magma emplacement',
#  'gabbro diorite clb chemical geology ree calculate liquid mafic suite accord tofractional crystallization model clb clb',
#  'gd yb calculate lovalue compare analyse rock clb text explanation',
#  'interpolate bracket traceelement calculation usenonmodal batch partial melting model shaw produce mantlederived liquid correspond mafic suite kd mauna loa amphibole spinel mantle flow clb lherzolite iherzolite shaw olivclinoorthoamphispinel',
#  'gd yb partition coefficient arth extrapolate bracket concern spinel kay gast',
#  'clb sample corsican mafic suite representative primitive liquid',
#  'calculate traceelement concentration inmantle amphibole opx cpx amph solid phase involve melt opx amph',
#  'srndoisotope datum mafic rock indicatejuvenile origin time batholith formation',
#  'srndoisotope datum mafic rock indicatejuvenile origin time batholith formation',
#  'age correct diagram contaminated mafic sample plotfar mantle reference field',
#  'alternative reject traceelement datum chemical geology fractional crystallization model calculate traceelement composition primitive liquid monzogranitic composition kd clb plagiokfeldmona clase spar zite rb gd yb kd partition coefficient plagioclase kfeldspar arth monazite correspond ratio analyse monazite leucocratic yb ppm average content rock',
#  'alternative reject traceelement datum chemical geology fractional crystallization model calculate traceelement composition primitive liquid monzogranitic composition kd clb plagiokfeldmona clase spar zite rb gd yb kd partition coefficient plagioclase kfeldspar arth monazite correspond ratio analyse monazite leucocratic yb ppm average content rock',
#  'calculate bulk distribution coefficient respective proportion crystallize plagioclase kfeldspar monazite',
#  'calculate bulk distribution coefficient respective proportion crystallize plagioclase kfeldspar monazite',
#  'calculate bulk distribution coefficient respective proportion crystallize plagioclase kfeldspar monazite',
#  'calculate bulk distribution coefficient respective proportion crystallize plagioclase kfeldspar monazite',
#  'twostage model lead tobulk crystallization',
#  'twostage model lead tobulk crystallization',
#  'initial liquid clb low rb content ppm low ree content withslightly fractionated ree pattern chondrite chondrite twostage model involve partial melting mantle follow bysecond partial melting solidify melt high incompatibleelement concentration',
#  'partial melting garnetlherzolite easily reject view experimentally determine ree pattern initial liquid calculate pattern initial liquid becausegarnet residue partial melting lead liquid hreedepleted pattern',
#  'partial melting garnetlherzolite easily reject view experimentally determine ree pattern initial liquid calculate pattern initial liquid becausegarnet residue partial melting lead liquid hreedepleted pattern',
#  'experimental green tholeiitic basalt form equilibrium residual garnet',
#  'mantlesource assemblage giveliquid tholeiitic calcalkaline composition amphibole lherzolite spinel lherzolite',
#  'melt amphibole lherzolite spinel lherzolite calculation traceelement concentration lead fiat ree pattern chondrite rb compatible mantle material shaw',
#  'melt amphibole lherzolite spinel lherzolite calculation traceelement concentration lead fiat ree pattern chondrite rb compatible mantle material shaw',
#  'resemble tholeiitic islandarc basalt western sunda volcanic arc indonesia content ree pattern flat islandarc rock case',
#  'resemble tholeiitic islandarc basalt western sunda volcanic arc indonesia content ree pattern flat islandarc rock case',
#  'ta ratio geochemical tool remain constant magmatic fusion crystallization incompatible element behaviour',
#  'ta ratio geochemical tool remain constant magmatic fusion crystallization incompatible element behaviour',
#  'ratio characterize source material tectonic environment magmarie process',
#  'gabbro identify clb havelow ta ratio typical extensional tectonic area spread ridge intraplate magmatism',
#  'gabbro identify clb havelow ta ratio typical extensional tectonic area spread ridge intraplate magmatism',
#  'high ta ratio relate convergentplate tectonic environment subduction zone',
#  'high ta ratio relate convergentplate tectonic environment subduction zone',
#  'study tholeiitic basalt dredge midatlantic ridge basic rock',
#  'tholeiitic basalt enrich incompatible trace element compare tholeiitic midocean ridge basalt morb associate alkali olivine basalt',
#  'regard result vertical heterogeneity mantle composition',
#  'tholeiitic oceanisland basalt eruption ofmauna loa hawaii incompatibleelement abundance',
#  'tholeiitic oceanisland basalt eruption ofmauna loa hawaii incompatibleelement abundance',
#  'tholeiitic oceanisland basalt eruption ofmauna loa hawaii incompatibleelement abundance',
#  'accord thhfta diagram rock analogous enriched morb',
#  'rock tholeiitic composition enrich incompatible element regard oceanfloor basalt compare etype morb oceanisland basalt produce nonmodal partial melting ofheterogeneous mantle spinel amphibole peridotite garnet condition asthenospheric ascent',
#  'leucomonzogranite granitic rock contrast mafic suite characteristic trend loglog diagram',
#  'explanation granite body begenetically link isotope datum indicatecogenetic differentiation unidentified magmatic process poor interelement diagram clustering representative point isochron indicaterather large interval ree ta rb incompatible acidic melt basic dvalue approach exceed compatible element dvalue close',
#  'withhigh degree differentiation magmatic process variation concentration slight',
#  'homogeneous isotope sri increase acceptable forsuite rock relate throughhigh degree fractional crystallization',
#  'degree ofree fractionation vary highly lreeenriched pattern anomaly rock clb leucomonzogranite fiat normalize pattern huge negative anomaly',
#  'decrease concentration relate increase content feldspar magmatic differentiation initial monzogranitic melt',
#  'calculate ree pattern calcalkaline granite',
#  'twostage fractional crystallization model involve feldspar monazite fit datum',
#  'decrease associate increase concentration rb imply crystallization kfeldspar mica',
#  'large increase hree concentration quartz crystallization order reduce hree bulk distribution coefficient',
#  'large increase hree concentration quartz crystallization order reduce hree bulk distribution coefficient',
#  'primitive monzogranitic melt havecomposition close granite',
#  'accessory acttrap lree lead todecrease lree content increase crystallization',
#  'accessory acttrap lree lead todecrease lree content increase crystallization',
#  'twostage fractional crystallization model involve rb ree concentration compare calculate concentration residual liquid observe concentration calcalkaline granite',
#  'direct calculation method estimate follow parameter select primitive liquid clb low content weak negative anomaly compare order calculate bulk distribution coefficient individual partition coefficient mineral involve magmatic differentiation',
#  'direct calculation method estimate follow parameter select primitive liquid clb low content weak negative anomaly compare order calculate bulk distribution coefficient individual partition coefficient mineral involve magmatic differentiation',
#  'stage lead leucocratic liquid compare average leucocratic sample',
#  'stage lead leucocratic liquid compare average leucocratic sample',
#  'monzograniteleucomonzogranite association considersuite evolve accord tofractionalcrystallization model initial liquid monzogranitic composition',
#  'granodiorite byproduct magma mixing decipher origin rock intermediate composition granodiorite bridge gap mafic acidic endmember crucial interpret genesis calcalkaline association',
#  'isotope datum mafic rock origin mantlederived magma acidic crustalderived material',
#  'existence ofstatistical gap trend correspond granodioritic composition emphasize key place rock interpretation ofplutonic association',
#  'acidicmafic mingle zone granodiorite observe field corsica rossi mingle mixing study sardinia conclude origin microgranular mafic enclave granodiorite seek mix mafic silicic magma',
#  'acidicmafic mingle zone granodiorite observe field corsica rossi mingle mixing study sardinia conclude origin microgranular mafic enclave granodiorite seek mix mafic silicic magma',
#  'acidicmafic mingle zone granodiorite observe field corsica rossi mingle mixing study sardinia conclude origin microgranular mafic enclave granodiorite seek mix mafic silicic magma',
#  'discuss suchsuite rock intermediate composition characterize strong geochemical heterogeneity',
#  'essential nature origin mixing batch define accurately order place constraint genesis rock intermediate composition chemical geology association',
#  'corsican suited purpose good exposure mafic rock permit detailed investigation nature endmember',
#  'traceelement loglog diagram rb relationship granodiorite tight clustering representative point',
#  'diagram granodiorite point dofit alongsingle isochron',
#  'group rock group roughly plot reference isochron high model initial ratio group rock clb plot onstraight withmuch low initial ratio age inconsistent field relationship',
#  'group rock group roughly plot reference isochron high model initial ratio group rock clb plot onstraight withmuch low initial ratio age inconsistent field relationship',
#  'trend define granodiorite representative point close isochron high sio traceelement content ree clb theyso primitive monzogranitic liquid',
#  'group acidic geochemical characteristic specific ree pattern clb high hree content andpronounce negative anomaly typical highly differentiate rock',
#  'major traceelement isotope feature providepicture inconsistent withdirect common origin group granodiorite',
#  'group andlow model initial ratio interpretresult mixing mafic silicic endmember',
#  'group andlow model initial ratio interpretresult mixing mafic silicic endmember',
#  'group represent sample plot alongmixing endmember differentiate basic rock crystallize monzogranitic melt lead tomixing pseudoisochron',
#  'group represent sample plot alongmixing endmember differentiate basic rock crystallize monzogranitic melt lead tomixing pseudoisochron',
#  'plot association mix trend granodiorite highly differentiated magma',
#  'test suchhypothesis initial ratio endmember bevery prefer presentday diagram yieldmixing sample link bymixing process bernardgriffith scharbert',
#  'providecurve forsuite rock evolve differentiation',
#  'emphasize test rb content remain constant entire rock suite case plot bemathematically straight',
#  'case rb concentration increase accord sequence dioritic monzogranitic clb',
#  'representative point group granodiorite clb yieldpseudoisochron givemixing endmember narrow field mafic rock differentiated monzogranitic magma correspond high ratio isochron',
#  'representative point group granodiorite clb yieldpseudoisochron givemixing endmember narrow field mafic rock differentiated monzogranitic magma correspond high ratio isochron',
#  'representative point granodiorite group definesmall field close fractionalcrystallization trend confirm great similarity group granodiorite differentiated',
#  'test involvesimple binary diagram require element large variation case mixing magma lead tostraight type curve accord magmatic process involve',
#  'test involvesimple binary diagram require element large variation case mixing magma lead tostraight type curve accord magmatic process involve',
#  'variation diagram granodioritic magma result ofmixing process differentiated melt mafic suite monzogranitic magma differentiation stage leucomonzogranitic stage',
#  'field structural consideration granodiorite group couldhave intrusive comparable chemical mineral composition style textural disequilibrium group microgranular mafic enclave interpret quench inclusion mafic magma suffer extensive disaggregation reequilibration',
#  'group plot close reference isochron slight contamination mafic magma acquire isotopic homogeneity plot infield traceelement composition close',
#  'group doachieve isotope homogeneity mafic material involve',
#  'source granite ratio granitoidrock composition indicatesingle source raise question chemical geology',
#  'source granite ratio granitoidrock composition indicatesingle source raise question chemical geology',
#  'calculate ree pattern granitoid rock accord tononmodal batch partialmelting model',
#  'liquid obtainfunction metamorphic high mgk liquid granulite calcalkaline liquid high pmo condition',
#  'calculate ree pattern compare initial liquid analyse rock sample clb',
#  'idea partial melting traceelement content resuite magma depend percentage residual phase feldspar biotite rb amphibole garnet ree',
#  'solid source orsingle successively undergo metamorphic event high pressure low hydrous condition',
#  'solid source orsingle successively undergo metamorphic event high pressure low hydrous condition',
#  'arth granite melt produce partial melting graywacketype rock',
#  'precambrian wildeman haskin arth archaean wildeman condie',
#  'lree rock vary ppm lree fractionated pattern hree fractionated enrich pattern withnegative anomaly decrease decrease total ree content',
#  'average ree pattern quartzrich quartzintermediate graywacke representative average reedistribution pattern solid source',
#  'model melting rock withgraywacke composition bedry initial assemblage granulite hydrous assemblage amphibolite facie',
#  'good fit partial melting case granulite amphibolite facie calculated experimental ree datum',
#  'explanation plagioclase initial source partition coefficient liq underestimate',
#  'explanation plagioclase initial source partition coefficient liq underestimate',
#  'high kdvalue realistic granitic melt accord arth calculate datum agree experimental concentration',
#  'source high tlow granulitic paragneiss libourel analyse trace element table rb ree analysis compare model graywacke source',
#  'ree pattern corsican granulite definefield close ree pattern graywacke high hree content',
#  'melt granulite facie paragneiss givemonzodioritic liquid melt amphibolite facie lead tomonzogranitic liquid',
#  'melt granulite facie paragneiss givemonzodioritic liquid melt amphibolite facie lead tomonzogranitic liquid',
#  'cocherie rossi composition granite chemical geology traceelement calculation usenonmodal batch partial melting model produce initial granitic liquid composition kd gneiss granulitic model amphibolite facie model orthogarnet apatite',
#  'pyroxene clb rb gd yb partition coefficient arth plagioclase kfeldspar biotite amphibole list interpolate bracket',
#  'pyroxene clb rb gd yb partition coefficient arth plagioclase kfeldspar biotite amphibole list interpolate bracket',
#  'corsican granulitic gneiss compare select traceelement concentration text explanation',
#  'bulk distribution coefficient dry initial assemblage',
#  'bulk distribution coefficient correspond follow proportion mineral contribute qz kfs',
#  'bulk distribution coefficient correspond follow proportion mineral contribute qz kfs',
#  'calculate traceelement content melt accord dry model compare content primitive monzodiorite melt',
#  'distribution coefficient calculate follow mineral qz bio amph gt qz bio amph',
#  'distribution coefficient calculate follow mineral qz bio amph gt qz bio amph',
#  'control physicochemical fusion parameter composition protolith',
#  'age granite source material source involve granitoidmagma genesis havegraywacke composition',
#  'lead ratio compare average rb content corsican granulitic gneiss',
#  'lead ratio compare average rb content corsican granulitic gneiss',
#  'lead ratio compare average rb content corsican granulitic gneiss',
#  'ago age initial ratio close',
#  'considertwostage model protolith derive fromdepletedtype mantle withsri average age source material calculate base ratio',
#  'beminimum age acidbasic magma interaction lower initial ratio granite',
#  'beminimum age acidbasic magma interaction lower initial ratio granite',
#  'inherit zircon continental crust gabbro peloso cmu age agree calculation',
#  'inherit zircon continental crust gabbro peloso cmu age agree calculation',
#  'list average close assume granite age',
#  'average ratio granulitic paragneiss representative source protolith calculate ratio providemodel time evolution intercept deplete mantle growth curve givemodel age',
#  'age close calculate age individual sample ratio rock question assume source rock',
#  'age close calculate age individual sample ratio rock question assume source rock',
#  'diagram basic rock granitoid rock',
#  'define source material obtainmodel age tdm calculate individual sample ratio analyse sample protolith',
#  'basic rock associate association rootfar mantle evolution trend',
#  'olwinerich rock peridotite composition shownegative slope',
#  'evolution rare link high ratio high chur ratio',
#  'evolution rare link high ratio high chur ratio',
#  'comparison corsican sardinian batholiths oligocenemiocene oceanization western mediterranean region continuous variscan crust exist corsica sardinia possibility investigatelarge variscan orogenic belt',
#  'comparison corsican sardinian batholiths oligocenemiocene oceanization western mediterranean region continuous variscan crust exist corsica sardinia possibility investigatelarge variscan orogenic belt',
#  'uniform geochemical behaviour hercynian pluton corsica sardinia pyrrnre beconfirm isotope datum',
#  'uniform geochemical behaviour hercynian pluton corsica sardinia pyrrnre beconfirm isotope datum',
#  'sardinia initial ratio budduso massif cocherie close unpublished cite sarrabus massif bono intrusive complex',
#  'geochemical trend rock ofgranodioritic monzogranitic average scatter corsican granite pyrenean granite intermediate sardinia',
#  'evolution corsica smnd isotope datum',
#  'evolution corsica smnd isotope datum',
#  'increase average pyrenean rigut pluton trois seigneur massif granodiorite bono complex sardinia corsican batholith',
#  'type granite remain variscan chain corsicasardinia frompetrological mineralogical majorand traceelement geochemistry point view',
#  'broadscale zoning reveal isotope inherit deep source granite',
#  'regional isotope zonation batholith generate boundary eastern western terrane rossi cocherie granite corsican batholith chemical geology belong terrane granite sardinia pyrrnre',
#  'conclusion corsican batholith pluton southern realm variscan chain lead insight variscan continental growth origin emplacement socalled plutonic association',
#  'conclusion corsican batholith pluton southern realm variscan chain lead insight variscan continental growth origin emplacement socalled plutonic association',
#  'successively emplace magmatic association result mixing noncogenetic mafic silicic magma',
#  'type mantle melt mafic ultrak magma result fusion ofphlogopite garnet metasomatize mantle andsecond stagezonerefine process lead increase incompatible traceelement content',
#  'type mantle melt mafic ultrak magma result fusion ofphlogopite garnet metasomatize mantle andsecond stagezonerefine process lead increase incompatible traceelement content',
#  'finally magma interact base crust lead lower yb high ratio melt',
#  'finally magma interact base crust lead lower yb high ratio melt',
#  'finally magma interact base crust lead lower yb high ratio melt',
#  'magma result nonmodal partial melting ofspinel amphibolite lherzolitic mantle',
#  'primitive silicic magma low ratio low high',
#  'primitive silicic magma low ratio low high',
#  'derive continental source melt condition fusion lead initial liquid monzodioritic monzogranitic',
#  'derive continental source melt condition fusion lead initial liquid monzodioritic monzogranitic',
#  'emphasize fluid content melting condition anatexis continental crust involve generation granitic melt',
#  'emphasize fluid content melting condition anatexis continental crust involve generation granitic melt',
#  'intermediate rock granodiorite result mix preexist rock mafic silicic composition',
#  'isotope majorand traceelement geochemistry support evidence mix process silicic endmember completely blend',
#  'microgranular enclave intermediate acid rock association shape undisrupted bubble mafic magma chemically equilibrate insilicic environment remain remnant process',
#  'magma intermediate composition bridge gap mafic silicic endmember',
#  'major difference assume mantle source yield mafic ul magma agree progressive uplift asthenosphere elithosphere extensional stress',
#  'major difference assume mantle source yield mafic ul magma agree progressive uplift asthenosphere elithosphere extensional stress',
#  'lead melting ofdeep phlogopite garnet mantle melt shallow garnetfree spinel lherzolitic mantle finally alkaline volcanicplutonic episode',
#  'lead melting ofdeep phlogopite garnet mantle melt shallow garnetfree spinel lherzolitic mantle finally alkaline volcanicplutonic episode',
#  'grateful des sciences siie laboratory saclay france caess rennes france trace element isotope analyse byc',
#  'chemical geology appendixm petrographical mineralogical datum rock analytical datumpresent rossi cocherie',
#  'association intermediate acid rock havetypical mineralogical abundant apatite zircon early augite clinopyroxene surround actinolitic hornblende composition caplagioclase omonzonite osyenogranite barich foxyre mgtibiotite ilmenite abundant sulphide macroscopic titanite ubiquitous',
#  'ultrapotassic rock melasyenite melamonzonite display common characteristic crdiopside augite clinopyroxene caplagioclase foxyre mgtibiotite rare relic phlogopitic mica',
#  'ilmenite commonly surround sphene abundant magnetite scarce',
#  'occurrence crspinel micaceous aggregate represent relic olivine',
#  'systematic presence actinolitic hornblende characteristic rock',
#  'typically secondary biotite habit occur mineral crack aggregate',
#  'early mineral zircon thorite allanite apatite sphene sulphide pyrrhotite chalcopyrite exsolution pentlandite oxide ilmenite futile exsolution ilmenite',
#  'plagioclase kfeldspar quartz biotite magnesian hornblendeamphibole relict crdiopside apatite ilmenite titanite',
#  'association intermediate acid granodiorite plagioclase oamphibole biotite occur magnetite allanite apatite titanite accessory',
#  'composition biotitebeare leucomonzogranite close thermal minimum almandinespessartine garnet occur accessory phase',
#  'composition biotitebeare leucomonzogranite close thermal minimum almandinespessartine garnet occur accessory phase',
#  'ultramafic mafic peridotite haveheteradcumulate texture cumulate olivine intercumulus clinopyroxene partly replace pargasitic hornblende plagioclase crspinel ilmenite magnetite sulphide',
#  'troctolite lm mesocumulate texture plagioclase olivine foso orthopyroxene clinopyroxene',
#  'gabbro assume liquid composition clb texture orthocumulate plagioclase olivine clinopyroxene orthopyroxene brown amphibole ilmenite magnetite green spinel sulphide',
#  'gabbronorite orthocumulate texture plagioclase olivine orthopyroxene clinopyroxene poikilitic brown hornblende apatite ilmenite biotite',
#  'gabbronorite cumulate texture strong igneous lamination plagioclase orthopyroxene proportion equivalent plagioclase clinopyroxene poikilitic brown hornblende biotite apatite quartz',
#  'orthopyroxenebeare granodiorite clb mediumto coarsegrained texture plagioclase kfeldspar quartz orthopyroxene clinopyroxene etch green amphibole biotite opaque',
#  'norite pv clb clb heteradcumulate texture cumulate olivine cumulative plagioclase poikilitic orthopyroxene heteradcumulate pargasitic hornblende partly replace relict clinopyroxene ilmenite magnetite sulphide green spinel',
#  'gabbro clb clb coarsegrained texture plagioclase relict core large rim magnesian hornblende include relict orthopyroxene biotite itmenite magnetite',
#  'gabbrodiorite diorite clb clb clb fineto mediumgraine texture plagioclase relict core anso ferrohornblende amphibole biotite quartz ilmenite magnetite',
#  'diorite clb clb fineto mediumgraine texture plagioclase relict core green amphibole poikilitic biotite poikilitic kfeldspar quartz apatite titanite ilmenite magnetite',
#  'appendix inverse geochemical approach direct geochemical approach trace element requirechoice magmatic model realistic fvalue weight fraction residual liquid bulkdistribution coefficient publish individual melt partition coefficient verification analyse rock fit predicted model parameter',
#  'appendix inverse geochemical approach direct geochemical approach trace element requirechoice magmatic model realistic fvalue weight fraction residual liquid bulkdistribution coefficient publish individual melt partition coefficient verification analyse rock fit predicted model parameter',
#  'case fractional crystallization parameter evolutionary process determine graphically cocherie assumption concern initial magma proportion mineral equilibrium evolve melt']

# %%
ready_ner['tag']
# Out:
# ['sediment',
#  'site',
#  'sediment',
#  'heat',
#  'sediment',
#  'site',
#  'sediment',
#  'site',
#  'iguape',
#  'heat',
#  'petroleum',
#  'sediment',
#  'radiogenic',
#  'sediment',
#  'sediment',
#  'height',
#  'rock',
#  'ratio',
#  'sediment',
#  'height',
#  'sediment',
#  'heat',
#  'heat',
#  'rate',
#  'density',
#  'sediment',
#  'thermal',
#  'sand',
#  'silt',
#  'silt',
#  'sand',
#  'iguape',
#  'conductivity',
#  'carbonate',
#  'heat',
#  'classification',
#  'silt',
#  'sand',
#  'sand',
#  'coarse',
#  'sand',
#  'coarse',
#  'length',
#  'deposit',
#  'length',
#  'sediment',
#  'temperature',
#  'sediment',
#  'temperature',
#  'brown',
#  'iguape',
#  'sediment',
#  'ratio',
#  'sediment',
#  'ratio',
#  'sediment',
#  'standard deviation',
#  'ratio',
#  'ratio',
#  'sediment',
#  'sediment',
#  'radiogenic',
#  'sediment',
#  'heat',
#  'radiogenic',
#  'grain',
#  'grain',
#  'heat',
#  'sediment',
#  'radiogenic',
#  'rock',
#  'grain',
#  'sediment',
#  'heat',
#  'sediment',
#  'heat',
#  'heat',
#  'sediment',
#  'conductivity',
#  'standard deviation',
#  'sediment',
#  'conductivity',
#  'high',
#  'quartz',
#  'conductivity',
#  'sediment',
#  'brazil',
#  'usa',
#  'thermal']

# %%
ready_ner['entity']
# Out:
# ['petrography',
#  'geolocation',
#  'petrography',
#  'methods',
#  'petrography',
#  'geolocation',
#  'petrography',
#  'geolocation',
#  'states',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'petrography',
#  'methods',
#  'petrography',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'states',
#  'methods',
#  'petrography',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'methods',
#  'petrography',
#  'methods',
#  'petrography',
#  'methods',
#  'petrography',
#  'methods',
#  'petrography',
#  'states',
#  'petrography',
#  'methods',
#  'petrography',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'petrography',
#  'methods',
#  'petrography',
#  'methods',
#  'petrography',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'petrography',
#  'countries',
#  'geolocation',
#  'methods']
