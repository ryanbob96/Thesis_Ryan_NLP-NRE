# %% [markdown]
# # Modules for Scraping

# %%
#PDF Miner (PDF Scraping)
fro`m pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.layout import LAParams
from pdfminer.converter import HTMLConverter, TextConverter, XMLConverter
from io import StringIO
from pdfminer.pdfpage import PDFPage


#PyPDF2 (PDF Scraping)
import PyPDF2 as pypdf


#OCR
from pdf2image import convert_from_path
import cv2
import pytesseract
pytesseract.pytesseract.tesseract_cmd=r'Tesseract-OCR\tesseract.exe'


#NLP Preprocessing
import nltk
import re
import regex
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer


#NLP Processing TensorFLow
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

#NLP Processing Spacy
import spacy
import spacy_transformers
spc = spacy.load('en_core_web_trf')
# spc = spacy.load(en_core_web_lg)
# spc.add_pipe('sentencizer')

#Model Training and Evaluation
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

#Basic
import numpy as np
import pandas as pd
import pickle
import glob
import os
import docker
import string

pc = '!"#$%&\'()*+,-./:;<=>?@[\]^_`{|}~'

# %% [markdown]
# # Data Input for Scanned PDF

# %%
pdf_path = r"PDF Data/1920s/ajs.s5-7.38.81.pdf"

# %% [markdown]
# # OCR Tesseract

# %%
# Scanned PDF Read
def get_pdf_file_content_Text_ocr(pdf_path)
    #Convert pdf to images
    images = convert_from_path(pdf_path, 500,poppler_path=r'C:\Program Files\poppler-0.68.0\bin')
    output_path = 'ocr_out/'
    for i, image in enumerate(images):
        fname = output_path + 'image_'+str(i)+'.png'
        image.save(fname, "PNG")

    extracted_text = []
    #images to text
    for i,filename in enumerate(glob.glob(os.path.join(output_path, '*.png'))):
        try:
            img1 = cv2.imread(filename)
            extracted_text.append(pytesseract.image_to_string(img1))
            print('successful'+str(i))
        except:
            print('unsuccessful'+str(i))

    text = ' '.join(extracted_text)
    
    return text
# Out:
# successful0
# successful1
# successful2
# successful3
# successful4
# successful5
# successful6
# successful7
# successful8
# successful9
# successful10
# successful11
# successful12
# successful13
# successful14
# successful15
# successful16
# successful17
# successful18
# successful19
# successful20
# successful21

# %%
text_pdfmine = ' '.join(get_pdf_file_content_Text_ocr(pdf_path))
text_pdfmine
# Out:
# 'THE\n\nAMERICAN JOURNAL OF SCIENCE\n[FIFTH SERIES.]\n\n———_#oe\n\nArt, VI.—The Thermal Conductivity and Compressi-\nbility of several Rocks under High Pressures; by\nP. W. Brineman.\n\nINTRODUCTION.\n\nThe effect of pressure on the thermal conductivity of\nrocks has apparently never been determined, although a\nknowledge of it is important in calculating the thermal\nequilibrium of the earth’s crust. The only measure-\nments we have that can give any idea of the possible\ninfluence of hydrostatic pressure are on the effect of one-\nsided compression on the thermal conductivity of granite\nand marble.t It1is of course well known that a one-sided\ncompression need not be at all like a hydrostatic pres-\nsure in its effects, and the only conclusion that we can\ndraw from the experiments of Lees as applied to condi-\ntions within the crust of the earth is that the effect of\npressure is probably not very large. .\n\nIn connection with my work on the effect of high pres-\nsures on general physical properties of various sub-\nstances, I have recently been engaged in measuring the\nthermal conductivity of-a number of liquids up to 12000\nke/em?. Since the apparatus could be adapted without\nmuch trouble to measure the effect of pressure on the\nthermal conductivity of those solids whose conductivity\nis not too high, such as the rocks, I thought it of interest\nto make a few measurements from which at least the\ngeneral trend of the effects to be expected could be\ninferred. I have been encouraged in this attempt by\nthe interest and advice of Professor R. A. Daly, who also\nwas so kind as to obtain several of the materials for me.\nI also have to thank my assistant, Mr. H. B. Curry, for\nmaking many of the readings.\n\n1For references see the end of this article.\n\nAm. Jour. Scr.— Firtx Sreriss, Vou. VII, No. 388.—Frpsrvuary, 1924.\n6\n 82 P., W. Bridgman—Thermal Conductivity and\n\nIn addition to the thermal conductivity I have deter-\nmined the compressibility of the materials used. It was\ncomparatively easy to do this as the apparatus had\nalready been developed for another purpose. When I\nbegan these measurements the important paper of Adams\nand Williamson? on the compressibility of rocks had not\nappeared, and such questions as that of the change with\npressure of the compressibility of a rock had not received\nan answer. Since the appearance of that paper, my\ncompressibility results lose some of their novel interest,\nbut there are still a number of points in connection with\nthem which I think may suggest new lines of thought.\nIn the first place, I have measured the compressibility\nof several of my materials at two temperatures, neither\nvery high it is true, 30° and 75°, but nevertheless suffi-\nciently far apart to give an idea of the variation of\ncompressibility with temperature. This of course is\nimportant when applying results obtained in the labora-\ntory at room temperatures to actual conditions. The\nnecessary information can not be obtained from the\nresults of Adams and Williamson because their compres-\nsibilities were measured at only one temperature. In\nthe second place, my method, which measures the linear\nas opposed to the cubical compressibility, brings out the\nimportance of non-isotropy, as the measurements of\nAdams and Williamson on cubical compressibility can-\nnot do. I have found surprisingly large differences of\ncompressibility in different directions, and also entirelv\nunexpected and abnormal hysteresis relations. Both\nthese factors are of importance in calculating the velocity\nof propagation of earthquake waves or other deforma-\ntional effects in the earth’s crust.\n\nThermal Conductivity.\n\nThe Method.—The method used for measuring thermal\nconductivity is essentially the same as that used for\nliquids, and is deseribed in detail elsewhere;? a brief\nsummary here will suffice. The material whose conduc-\ntivity is to be measured is worked to the form of a cylin-\ndrical shell, whic ...

# %% [markdown]
# ## Group PDF Scraping for OCR method

# %%
# #Group Read OCR
# all_extracted_text={}
# folder_patj = 'PDF Data/1920s/'
# for i,filename in enumerate(glob.glob(os.path.join(folder_path, '*.pdf'))):
#     try:
#         all_extracted_text[re.search(r'(\w+).pdf$',filename).group(1) +'_'+ str(i)] = get_pdf_file_content_Text_ocr(filename).lower()
#     except:
#         pass

# %% [markdown]
# # Data Input for Normal PDF

# %%
pdf_path = 'PDF Data/10s/Brehme2016_Article_PermeabilityDistributionInTheL.pdf'

# %% [markdown]
# # PDFMiner

# %%
def get_pdf_file_content_Text(path_to_pdf):
    
    '''
    path_to_pdf: is the parameter that will give access to the PDF File 
    we want to extract the content.
    '''
    
    '''
    PDFResourceManager is used to store shared resources such as fonts or images that 
    we might encounter in the files. 
    '''
    
    resource_manager = PDFResourceManager(caching=True)
    
    '''
    create a string object that will contain the final text the representation of the pdf. 
    '''
    out_text = StringIO()
    
    '''
    UTF-8 is one of the most commonly used encodings, and Python often defaults to using it.
    In our case, we are going to specify in order to avoid some encoding errors.
    '''
    codec = 'utf-8'
    
    """
    LAParams is the object containing the Layout parameters with a certain default value. 
    """
    laParams = LAParams(line_overlap=0.3, detect_vertical=True)
    
    '''
    Create a TextConverter Object, taking :
    - ressource_manager,
    - out_text 
    - layout parameters.
    '''
    text_converter = TextConverter(resource_manager, out_text, laparams=laParams)
    fp = open(path_to_pdf, 'rb')
    
    '''
    Create a PDF interpreter object taking: 
    - ressource_manager 
    - text_converter
    '''
    interpreter = PDFPageInterpreter(resource_manager, text_converter)

    '''
    We are going to process the content of each page of the original PDF File
    '''
    try:
        for page in PDFPage.get_pages(fp, pagenos=set(), maxpages=0, password="", caching=True, check_extractable=True):
            interpreter.process_page(page)
    except:
        for page in PDFPage.get_pages(fp, pagenos=set(), maxpages=0, password=b"", caching=True, check_extractable=True):
            interpreter.process_page(page)

#Considering Vertical Written
#         if page.mediabox[2] - page.mediabox[0] > page.mediabox[3] - page.mediabox[1]:
#             orientation = 'Landscape'
#         else:
#             orientation = 'Portrait'

    '''
    Retrieve the entire contents of the “file” at any time 
    before the StringIO object’s close() method is called.
    '''
    text = out_text.getvalue()

    '''
    Closing all the ressources we previously opened
    '''
    fp.close()
    text_converter.close()
    out_text.close()
    
    '''
    Return the final variable containing all the text of the PDF
    '''
    return text

# %%
text_pdfmine = get_pdf_file_content_Text(pdf_path)
text_pdfmine
# Out:
# "european \n\nT\ne\nc\nr\no\nn\no\np\n~\nj\nw\nc\ns\n.\n \n1\n2\n8\n \n(\n1\n9\nX\n6\n)\n \n3\n3\n5\n-\n3\n5\n6\n \nE\nl\ns\ne\nv\ni\ne\nr\n \nS\nc\ni\ne\nn\nc\ne\n \nP\nu\nb\nl\ni\ns\nh\ne\nr\ns\n \nB\n.\nV\n.\n.\n \nA\nm\ns\nt\ne\nr\nd\na\nm\n \n-\n-\n \nP\nr\ni\nn\nt\ne\nd\n \ni\nn\n \nT\nh\ne\n \nN\ne\nt\nh\ne\nr\nl\na\nn\nd\ns\n \n3\n3\n5\n \nH\nE\nA\nT\n \nF\nL\nO\nW\n,\n \nH\nE\nA\nT\n \nP\nR\nO\nD\nU\nC\nT\nI\nO\nN\n \nA\nN\nD\n \nF\nI\nS\nS\nI\nO\nN\n \nT\nR\nA\nC\nK\n \nD\nA\nT\nA\n \nF\nR\nO\nM\n \nT\nH\nE\n \nH\nE\nR\nC\nY\nN\nI\nA\nN\n \nB\nA\nS\nE\nM\nE\nN\nT\n \nA\nR\nO\nU\nN\nD\n \nT\nH\nE\n \nP\nR\nO\nV\nE\nN\nC\nA\nL\n \nB\nA\nS\nI\nN\n \n(\nW\nE\nS\nT\nE\nR\nN\n \nM\nE\nD\nI\nT\nE\nR\nR\nA\nN\nE\nA\nN\n)\n \nF\n.\n \nL\nU\nC\nA\nZ\nE\nA\nU\n \n’\n \na\nn\nd\n \nD\n.\n \nM\nA\nI\nL\nH\nE\n \n’\n \n(\nR\ne\nc\ne\ni\nv\ne\nd\n \nD\ne\nc\ne\nm\nb\ne\nr\n \n3\n.\n \n1\n9\nX\n5\n;\n \na\nc\nc\ne\np\nt\ne\nd\n \nM\na\nr\nc\nh\n \n2\n1\n.\n \n1\n9\n8\n6\n)\n \ng\ne\no\nt\nr\na\nv\ne\nr\ns\ne\n \nA\nB\nS\nT\nR\nA\nC\nT\n \nL\nu\nc\na\nr\ne\na\nu\n.\n \nF\n.\n \na\nn\nd\n \nM\na\ni\nl\nh\ne\n.\n \nD\n.\n,\n \n1\n9\n8\n6\n.\n \nH\ne\na\nt\n \nf\nl\no\nw\n.\n \nh\ne\na\nt\n \np\nr\no\nd\nu\nc\nt\ni\no\nn\n \na\nn\nd\n \nf\ni\ns\ns\ni\no\nn\n \nt\nr\na\nc\nk\n \nd\na\nt\na\n \nf\nr\no\nm\n \nt\nh\ne\n \nH\ne\nr\nc\ny\nn\ni\na\nn\n \nb\na\ns\ne\nm\ne\nn\nt\n \na\nr\no\nu\nn\nd\n \nt\nh\ne\n \nP\nr\no\nv\ne\nn\nq\na\nl\n \nB\na\ns\ni\nn\n \n(\nW\ne\ns\nt\ne\nr\nn\n \nM\ne\nd\ni\nt\ne\nr\nr\na\nn\ne\na\nn\n)\n.\n \nI\nn\n:\n \nD\n.\nA\n.\n \nG\na\nl\ns\no\nn\n \na\nn\nd\n \nS\nt\n.\n \nM\nu\ne\nl\nl\ne\nr\n \n(\nE\nd\ni\nt\no\nr\ns\n)\n.\n \nT\nh\ne\n \nE\nu\nr\no\np\ne\na\nn\n \nG\ne\no\nt\nr\na\nv\ne\nr\ns\ne\n,\n \nP\na\nr\nt\n \n2\n.\n \nT\ne\nc\nr\no\nn\no\np\nh\ny\ns\nk\ns\n.\n \n1\n2\nX\n:\n \n3\n3\n5\n-\n3\n5\n6\n.\n \nI\nn\n \nt\nh\ne\n \nc\no\nm\np\nl\ne\nx\n \ns\nt\nr\nu\nc\nt\nu\nr\na\nl\n \nf\nr\na\nm\ne\nw\no\nr\nk\n \no\nf\n \nt\nh\ne\n \nW\ne\ns\nt\ne\nr\nn\n \nM\ne\nd\ni\nt\ne\nr\nr\na\nn\ne\na\nn\n.\n \nH\ne\nr\nc\ny\nn\ni\na\nn\n \na\nr\ne\na\ns\n \na\nr\ne\n \ne\nx\np\ne\nc\nt\ne\nd\n \nt\no\n \nb\ne\n \nt\nh\ne\nr\nm\na\nl\nl\ny\n \np\nr\ne\ns\ne\nr\nv\ne\nd\n \nf\nr\no\nm\n \nt\nh\ne\n \nr\ne\nc\ne\nn\nt\n \nt\ne\nc\nt\no\nn\ni\nc\n \ne\nv\no\nl\nu\nt\ni\no\nn\n.\n \nT\nh\ne\n \nt\nh\ne\nr\nm\na\nl\n \nr\ne\ng\ni\nm\ne\n \no\nf\n \nt\nh\ne\ns\ne\n \na\nr\ne\na\ns\n \nI\nS\n \ns\nt\nu\nd\ni\ne\nd\n \nu\ns\ni\nn\ng\n \nh\ne\na\nt\n \nf\nl\no\nw\n,\n \nh\ne\na\nt\n \np\nr\no\nd\nu\nc\nt\ni\no\nn\n \na\nn\nd\n \nt\nr\na\nc\nk\n \nd\na\nt\na\n.\n \nT\nh\ne\n \ns\nu\nr\nf\na\nc\ne\n \nh\ne\na\nt\n \nf\nl\no\nw\n \ni\ns\n \ns\ni\ng\nn\ni\nf\ni\nc\na\nn\nt\nl\ny\n \nh\ni\ng\nh\ne\nr\n \ni\nn\n \nC\no\nr\ns\ni\nc\na\n \n(\n7\n6\ni\n_\n \n1\n0\n \nm\nW\n \nm\ne\n \n2\n,\n \nt\nh\na\nn\n \ni\nn\n \nt\nh\ne\n \nM\na\nu\nr\ne\ns\n \na\nn\nd\n \nE\ns\nt\nC\nr\ne\nl\n \n(\n5\n8\n&\n2\n \nm\nW\n \nm\n-\nl\n)\n.\n \nN\ne\ni\nt\nh\ne\nr\n \nh\ne\na\nt\n \np\nr\no\nd\nu\nc\nt\ni\no\nn\n \nn\no\nr\n \ne\nr\no\ns\ni\no\nn\n \ns\nu\nb\ns\ne\nq\nu\ne\nn\nt\n \nt\no\n \nt\nh\ne\n \nA\nl\np\ni\nn\ne\n \no\nr\no\ng\ne\nn\ny\n \ni\nn\n \nC\no\nr\ns\ni\nc\na\n \nc\na\nn\n \ne\nx\np\nl\na\ni\nn\n \ns\nu\nc\nh\n \na\n \nd\ni\nf\nf\ne\nr\ne\nn\nc\ne\n.\n \nI\nt\n \ni\ns\n \ns\nu\ng\ng\ne\ns\nt\ne\nd\n \nt\nh\na\nt\n \na\n \nd\ne\ne\np\n \nt\nh\ne\nr\nm\na\nl\n \ns\no\nu\nr\nc\ne\n \nr\ne\nl\na\nt\ne\nd\n \nt\no\n \nt\nh\ne\n \na\ns\ny\nm\nm\ne\nt\nr\ni\nc\n \ne\nv\no\nl\nu\nt\ni\no\nn\n \no\nf\n \nt\nh\ne\n \nP\nr\no\nv\ne\nn\nq\na\nl\n \nb\na\ns\ni\nn\n \nc\no\nu\nl\nd\n \ne\nx\np\nl\na\ni\nn\n \nt\nh\ne\n \nh\ni\ng\nh\ne\nr\n \nh\ne\na\nt\n \nf\nl\no\nw\n \ni\nn\n \nC\no\nr\ns\ni\nc\na\n.\n \nA\n \nm\no\nd\ne\nl\n \no\nf\n \nt\nh\ne\nr\nm\na\nl\n \ns\nt\nr\nu\nc\nt\nu\nr\ne\n \nb\na\ns\ne\nd\n \no\nn\n \nt\nh\ne\n \np\nr\ne\ns\ne\nn\nt\n \nd\na\ny\n \nt\nh\ne\nr\nm\na\nl\n \nr\ne\ng\ni\nm\ne\n \no\nf\n \nt\nh\ne\n \nM\na\nu\nr\ne\ ...

# %% [markdown]
# ## Group PDF Scraping for normal method

# %%
# #Group Read PDF Miner
# all_extracted_text={}
# folder_path='PDF Data/10s/'
# for i,filename in enumerate(glob.glob(os.path.join(folder_path, '*.pdf'))):
#     try:
#         all_extracted_text[re.search(r'(\w+).pdf$',filename).group(1) +'_'+ str(i)] = get_pdf_file_content_Text(filename).lower()
#     except:
#         pass

# %% [markdown]
# ## Data Preprocessing (Conditioning, Stop Words, Stemmer)

# %% [markdown]
# ## Pre-Processing 1 : Regex Conditioning for Scientific Text

# %%
#Punctuation of '-' because make a newline 
text_punew = re.sub(r'(-\n?\s)','',text_pdfmine.lower())
text_punew
# Out:
# "european \n\nt\ne\nc\nr\no\nn\no\np\n~\nj\nw\nc\ns\n.\n \n1\n2\n8\n \n(\n1\n9\nx\n6\n)\n \n3\n3\n5\n3\n5\n6\n \ne\nl\ns\ne\nv\ni\ne\nr\n \ns\nc\ni\ne\nn\nc\ne\n \np\nu\nb\nl\ni\ns\nh\ne\nr\ns\n \nb\n.\nv\n.\n.\n \na\nm\ns\nt\ne\nr\nd\na\nm\n \n\np\nr\ni\nn\nt\ne\nd\n \ni\nn\n \nt\nh\ne\n \nn\ne\nt\nh\ne\nr\nl\na\nn\nd\ns\n \n3\n3\n5\n \nh\ne\na\nt\n \nf\nl\no\nw\n,\n \nh\ne\na\nt\n \np\nr\no\nd\nu\nc\nt\ni\no\nn\n \na\nn\nd\n \nf\ni\ns\ns\ni\no\nn\n \nt\nr\na\nc\nk\n \nd\na\nt\na\n \nf\nr\no\nm\n \nt\nh\ne\n \nh\ne\nr\nc\ny\nn\ni\na\nn\n \nb\na\ns\ne\nm\ne\nn\nt\n \na\nr\no\nu\nn\nd\n \nt\nh\ne\n \np\nr\no\nv\ne\nn\nc\na\nl\n \nb\na\ns\ni\nn\n \n(\nw\ne\ns\nt\ne\nr\nn\n \nm\ne\nd\ni\nt\ne\nr\nr\na\nn\ne\na\nn\n)\n \nf\n.\n \nl\nu\nc\na\nz\ne\na\nu\n \n’\n \na\nn\nd\n \nd\n.\n \nm\na\ni\nl\nh\ne\n \n’\n \n(\nr\ne\nc\ne\ni\nv\ne\nd\n \nd\ne\nc\ne\nm\nb\ne\nr\n \n3\n.\n \n1\n9\nx\n5\n;\n \na\nc\nc\ne\np\nt\ne\nd\n \nm\na\nr\nc\nh\n \n2\n1\n.\n \n1\n9\n8\n6\n)\n \ng\ne\no\nt\nr\na\nv\ne\nr\ns\ne\n \na\nb\ns\nt\nr\na\nc\nt\n \nl\nu\nc\na\nr\ne\na\nu\n.\n \nf\n.\n \na\nn\nd\n \nm\na\ni\nl\nh\ne\n.\n \nd\n.\n,\n \n1\n9\n8\n6\n.\n \nh\ne\na\nt\n \nf\nl\no\nw\n.\n \nh\ne\na\nt\n \np\nr\no\nd\nu\nc\nt\ni\no\nn\n \na\nn\nd\n \nf\ni\ns\ns\ni\no\nn\n \nt\nr\na\nc\nk\n \nd\na\nt\na\n \nf\nr\no\nm\n \nt\nh\ne\n \nh\ne\nr\nc\ny\nn\ni\na\nn\n \nb\na\ns\ne\nm\ne\nn\nt\n \na\nr\no\nu\nn\nd\n \nt\nh\ne\n \np\nr\no\nv\ne\nn\nq\na\nl\n \nb\na\ns\ni\nn\n \n(\nw\ne\ns\nt\ne\nr\nn\n \nm\ne\nd\ni\nt\ne\nr\nr\na\nn\ne\na\nn\n)\n.\n \ni\nn\n:\n \nd\n.\na\n.\n \ng\na\nl\ns\no\nn\n \na\nn\nd\n \ns\nt\n.\n \nm\nu\ne\nl\nl\ne\nr\n \n(\ne\nd\ni\nt\no\nr\ns\n)\n.\n \nt\nh\ne\n \ne\nu\nr\no\np\ne\na\nn\n \ng\ne\no\nt\nr\na\nv\ne\nr\ns\ne\n,\n \np\na\nr\nt\n \n2\n.\n \nt\ne\nc\nr\no\nn\no\np\nh\ny\ns\nk\ns\n.\n \n1\n2\nx\n:\n \n3\n3\n5\n3\n5\n6\n.\n \ni\nn\n \nt\nh\ne\n \nc\no\nm\np\nl\ne\nx\n \ns\nt\nr\nu\nc\nt\nu\nr\na\nl\n \nf\nr\na\nm\ne\nw\no\nr\nk\n \no\nf\n \nt\nh\ne\n \nw\ne\ns\nt\ne\nr\nn\n \nm\ne\nd\ni\nt\ne\nr\nr\na\nn\ne\na\nn\n.\n \nh\ne\nr\nc\ny\nn\ni\na\nn\n \na\nr\ne\na\ns\n \na\nr\ne\n \ne\nx\np\ne\nc\nt\ne\nd\n \nt\no\n \nb\ne\n \nt\nh\ne\nr\nm\na\nl\nl\ny\n \np\nr\ne\ns\ne\nr\nv\ne\nd\n \nf\nr\no\nm\n \nt\nh\ne\n \nr\ne\nc\ne\nn\nt\n \nt\ne\nc\nt\no\nn\ni\nc\n \ne\nv\no\nl\nu\nt\ni\no\nn\n.\n \nt\nh\ne\n \nt\nh\ne\nr\nm\na\nl\n \nr\ne\ng\ni\nm\ne\n \no\nf\n \nt\nh\ne\ns\ne\n \na\nr\ne\na\ns\n \ni\ns\n \ns\nt\nu\nd\ni\ne\nd\n \nu\ns\ni\nn\ng\n \nh\ne\na\nt\n \nf\nl\no\nw\n,\n \nh\ne\na\nt\n \np\nr\no\nd\nu\nc\nt\ni\no\nn\n \na\nn\nd\n \nt\nr\na\nc\nk\n \nd\na\nt\na\n.\n \nt\nh\ne\n \ns\nu\nr\nf\na\nc\ne\n \nh\ne\na\nt\n \nf\nl\no\nw\n \ni\ns\n \ns\ni\ng\nn\ni\nf\ni\nc\na\nn\nt\nl\ny\n \nh\ni\ng\nh\ne\nr\n \ni\nn\n \nc\no\nr\ns\ni\nc\na\n \n(\n7\n6\ni\n_\n \n1\n0\n \nm\nw\n \nm\ne\n \n2\n,\n \nt\nh\na\nn\n \ni\nn\n \nt\nh\ne\n \nm\na\nu\nr\ne\ns\n \na\nn\nd\n \ne\ns\nt\nc\nr\ne\nl\n \n(\n5\n8\n&\n2\n \nm\nw\n \nm\nl\n)\n.\n \nn\ne\ni\nt\nh\ne\nr\n \nh\ne\na\nt\n \np\nr\no\nd\nu\nc\nt\ni\no\nn\n \nn\no\nr\n \ne\nr\no\ns\ni\no\nn\n \ns\nu\nb\ns\ne\nq\nu\ne\nn\nt\n \nt\no\n \nt\nh\ne\n \na\nl\np\ni\nn\ne\n \no\nr\no\ng\ne\nn\ny\n \ni\nn\n \nc\no\nr\ns\ni\nc\na\n \nc\na\nn\n \ne\nx\np\nl\na\ni\nn\n \ns\nu\nc\nh\n \na\n \nd\ni\nf\nf\ne\nr\ne\nn\nc\ne\n.\n \ni\nt\n \ni\ns\n \ns\nu\ng\ng\ne\ns\nt\ne\nd\n \nt\nh\na\nt\n \na\n \nd\ne\ne\np\n \nt\nh\ne\nr\nm\na\nl\n \ns\no\nu\nr\nc\ne\n \nr\ne\nl\na\nt\ne\nd\n \nt\no\n \nt\nh\ne\n \na\ns\ny\nm\nm\ne\nt\nr\ni\nc\n \ne\nv\no\nl\nu\nt\ni\no\nn\n \no\nf\n \nt\nh\ne\n \np\nr\no\nv\ne\nn\nq\na\nl\n \nb\na\ns\ni\nn\n \nc\no\nu\nl\nd\n \ne\nx\np\nl\na\ni\nn\n \nt\nh\ne\n \nh\ni\ng\nh\ne\nr\n \nh\ne\na\nt\n \nf\nl\no\nw\n \ni\nn\n \nc\no\nr\ns\ni\nc\na\n.\n \na\n \nm\no\nd\ne\nl\n \no\nf\n \nt\nh\ne\nr\nm\na\nl\n \ns\nt\nr\nu\nc\nt\nu\nr\ne\n \nb\na\ns\ne\nd\n \no\nn\n \nt\nh\ne\n \np\nr\ne\ns\ne\nn\nt\n \nd\na\ny\n \nt\nh\ne\nr\nm\na\nl\n \nr\ne\ng\ni\nm\ne\n \no\nf\n \nt\nh\ne\n \nm\na\nu\nr\ne\ns\n \na\nn\nd\n ...

# %%
#Remove spacing n dot '\n' & '•'
if bool(regex.search(r'(?<=(\w\w))[\n•](?=(\w\w))',text_punew))==True:
    text_punew_spdo = re.sub(r'[\n•]', ' ', text_punew)
else:
    text_punew_spdo = re.sub(r'[\n•]', '', text_punew)

text_punew_spdo
# Out:
# "european tecronop~jwcs. 128 (19x6) 335356 elsevier science publishers b.v.. amsterdam printed in the netherlands 335 heat flow, heat production and fission track data from the hercynian basement around the provencal basin (western mediterranean) f. lucazeau ’ and d. mailhe ’ (received december 3. 19x5; accepted march 21. 1986) geotraverse abstract lucareau. f. and mailhe. d., 1986. heat flow. heat production and fission track data from the hercynian basement around the provenqal basin (western mediterranean). in: d.a. galson and st. mueller (editors). the european geotraverse, part 2. tecronophysks. 12x: 335356. in the complex structural framework of the western mediterranean. hercynian areas are expected to be thermally preserved from the recent tectonic evolution. the thermal regime of these areas is studied using heat flow, heat production and track data. the surface heat flow is significantly higher in corsica (76i_ 10 mw me 2, than in the maures and estcrel (58&2 mw ml). neither heat production nor erosion subsequent to the alpine orogeny in corsica can explain such a difference. it is suggested that a deep thermal source related to the asymmetric evolution of the provenqal basin could explain the higher heat flow in corsica. a model of thermal structure based on the present day thermal regime of the maures and estcrel is proposed for the stable hercynian crust in this area. the mantle heat flow is 2025 mw mm7 and the temperature at moho level is 375500°c. depending on the thermal parameter distribution with depth. introduction in the framework of european geotraverse (egt), geothermal studies have been undertaken in order to evaluate the surface heat flow and the temperature field within the lithosphere. the area the southern segment of the egt belongs to the western mediterranean domain where both alpine structures and young oceanic crust exist. in such a context, heat transfer is time dependent and evaluation of the temperature field requires thermal modelling of the transient processes (uplift and erosion, rifting’ and oceanic accretion, sedimentation, etc.). nevertheless. there exist few areas in the western mediterranean where hercynian basement outcrops, which could be used to obtain a reference thermal state for this modelling work. in this paper, interest is focused on the thermal regime of the 0040.ly51/x6/$03.50 ci 1986 elsevier science publishers b.v. \x0c0’ 5’ 10’ 15. 20. t i.. .__. _~_~ fig. 1. locations of the proven@ basin and the hercynian basement in the western mediterranean. crosses indicate the hercynian outcrops. shaded areas indicate the alpine erogenic zones. hercynian, outer parts of the provenqal basin (northwest mediterranean): maures and esterel in the southern part of france, and corsica and sardinia (fig. 1). the proven~al basin was formed during the oligocene by rifting of the continental lithosphere (bijuduval et al., 1978), and then by oceanic accretion which shifted the corsicasardinia block away from france (burrus, 1984). in this basin, the continental crust is progressively thinned to about 56 km (le douaran et al., 1984) whereas crustal thickness is normal in the maures (recq, 1970), in corsica (him and sapin, 1977) and in sardinia (egger et al., 1985). therefore, these areas were probably not affected by either alpine orogeny or continental rifting. the thermal regime of the hercynian crust is discussed using heat flow and heat production data from mauresesterel and corsica. fission track data are used to make sure that erosion processes have not perturbed the temperature field. a contour map of heat flow in the western mediterranean, resulting from a compilation of all existing data, is presented in the final discussion of the paper. also presented is a model for stable hercynian crust based on the presentday thermal regime of the maures and esterel. heat flow dpita in corsica, 11 data have been previously published by lesquer et al. (1983) and are gathered in this paper with nine  ...

# %%
#Germany alphabetic umlaut
text_punew_spdo_ger = re.sub(r'(?<=[oua])(¨)','e',text_punew_spdo)
text_punew_spdo_ger = re.sub(r'ß','ss',text_punew_spdo_ger)
text_punew_spdo_ger
# Out:
# "european tecronop~jwcs. 128 (19x6) 335356 elsevier science publishers b.v.. amsterdam printed in the netherlands 335 heat flow, heat production and fission track data from the hercynian basement around the provencal basin (western mediterranean) f. lucazeau ’ and d. mailhe ’ (received december 3. 19x5; accepted march 21. 1986) geotraverse abstract lucareau. f. and mailhe. d., 1986. heat flow. heat production and fission track data from the hercynian basement around the provenqal basin (western mediterranean). in: d.a. galson and st. mueller (editors). the european geotraverse, part 2. tecronophysks. 12x: 335356. in the complex structural framework of the western mediterranean. hercynian areas are expected to be thermally preserved from the recent tectonic evolution. the thermal regime of these areas is studied using heat flow, heat production and track data. the surface heat flow is significantly higher in corsica (76i_ 10 mw me 2, than in the maures and estcrel (58&2 mw ml). neither heat production nor erosion subsequent to the alpine orogeny in corsica can explain such a difference. it is suggested that a deep thermal source related to the asymmetric evolution of the provenqal basin could explain the higher heat flow in corsica. a model of thermal structure based on the present day thermal regime of the maures and estcrel is proposed for the stable hercynian crust in this area. the mantle heat flow is 2025 mw mm7 and the temperature at moho level is 375500°c. depending on the thermal parameter distribution with depth. introduction in the framework of european geotraverse (egt), geothermal studies have been undertaken in order to evaluate the surface heat flow and the temperature field within the lithosphere. the area the southern segment of the egt belongs to the western mediterranean domain where both alpine structures and young oceanic crust exist. in such a context, heat transfer is time dependent and evaluation of the temperature field requires thermal modelling of the transient processes (uplift and erosion, rifting’ and oceanic accretion, sedimentation, etc.). nevertheless. there exist few areas in the western mediterranean where hercynian basement outcrops, which could be used to obtain a reference thermal state for this modelling work. in this paper, interest is focused on the thermal regime of the 0040.ly51/x6/$03.50 ci 1986 elsevier science publishers b.v. \x0c0’ 5’ 10’ 15. 20. t i.. .__. _~_~ fig. 1. locations of the proven@ basin and the hercynian basement in the western mediterranean. crosses indicate the hercynian outcrops. shaded areas indicate the alpine erogenic zones. hercynian, outer parts of the provenqal basin (northwest mediterranean): maures and esterel in the southern part of france, and corsica and sardinia (fig. 1). the proven~al basin was formed during the oligocene by rifting of the continental lithosphere (bijuduval et al., 1978), and then by oceanic accretion which shifted the corsicasardinia block away from france (burrus, 1984). in this basin, the continental crust is progressively thinned to about 56 km (le douaran et al., 1984) whereas crustal thickness is normal in the maures (recq, 1970), in corsica (him and sapin, 1977) and in sardinia (egger et al., 1985). therefore, these areas were probably not affected by either alpine orogeny or continental rifting. the thermal regime of the hercynian crust is discussed using heat flow and heat production data from mauresesterel and corsica. fission track data are used to make sure that erosion processes have not perturbed the temperature field. a contour map of heat flow in the western mediterranean, resulting from a compilation of all existing data, is presented in the final discussion of the paper. also presented is a model for stable hercynian crust based on the presentday thermal regime of the maures and esterel. heat flow dpita in corsica, 11 data have been previously published by lesquer et al. (1983) and are gathered in this paper with nine  ...

# %%
#Over-Spacing
text_punew_spdo_ger_ovsp = re.sub(r'(\s)(?=\s+)','',text_punew_spdo_ger)
text_punew_spdo_ger_ovsp
# Out:
# "european tecronop~jwcs. 128 (19x6) 335356 elsevier science publishers b.v.. amsterdam printed in the netherlands 335 heat flow, heat production and fission track data from the hercynian basement around the provencal basin (western mediterranean) f. lucazeau ’ and d. mailhe ’ (received december 3. 19x5; accepted march 21. 1986) geotraverse abstract lucareau. f. and mailhe. d., 1986. heat flow. heat production and fission track data from the hercynian basement around the provenqal basin (western mediterranean). in: d.a. galson and st. mueller (editors). the european geotraverse, part 2. tecronophysks. 12x: 335356. in the complex structural framework of the western mediterranean. hercynian areas are expected to be thermally preserved from the recent tectonic evolution. the thermal regime of these areas is studied using heat flow, heat production and track data. the surface heat flow is significantly higher in corsica (76i_ 10 mw me 2, than in the maures and estcrel (58&2 mw ml). neither heat production nor erosion subsequent to the alpine orogeny in corsica can explain such a difference. it is suggested that a deep thermal source related to the asymmetric evolution of the provenqal basin could explain the higher heat flow in corsica. a model of thermal structure based on the present day thermal regime of the maures and estcrel is proposed for the stable hercynian crust in this area. the mantle heat flow is 2025 mw mm7 and the temperature at moho level is 375500°c. depending on the thermal parameter distribution with depth. introduction in the framework of european geotraverse (egt), geothermal studies have been undertaken in order to evaluate the surface heat flow and the temperature field within the lithosphere. the area the southern segment of the egt belongs to the western mediterranean domain where both alpine structures and young oceanic crust exist. in such a context, heat transfer is time dependent and evaluation of the temperature field requires thermal modelling of the transient processes (uplift and erosion, rifting’ and oceanic accretion, sedimentation, etc.). nevertheless. there exist few areas in the western mediterranean where hercynian basement outcrops, which could be used to obtain a reference thermal state for this modelling work. in this paper, interest is focused on the thermal regime of the 0040.ly51/x6/$03.50 ci 1986 elsevier science publishers b.v.\x0c0’ 5’ 10’ 15. 20. t i.. .__. _~_~ fig. 1. locations of the proven@ basin and the hercynian basement in the western mediterranean. crosses indicate the hercynian outcrops. shaded areas indicate the alpine erogenic zones. hercynian, outer parts of the provenqal basin (northwest mediterranean): maures and esterel in the southern part of france, and corsica and sardinia (fig. 1). the proven~al basin was formed during the oligocene by rifting of the continental lithosphere (bijuduval et al., 1978), and then by oceanic accretion which shifted the corsicasardinia block away from france (burrus, 1984). in this basin, the continental crust is progressively thinned to about 56 km (le douaran et al., 1984) whereas crustal thickness is normal in the maures (recq, 1970), in corsica (him and sapin, 1977) and in sardinia (egger et al., 1985). therefore, these areas were probably not affected by either alpine orogeny or continental rifting. the thermal regime of the hercynian crust is discussed using heat flow and heat production data from mauresesterel and corsica. fission track data are used to make sure that erosion processes have not perturbed the temperature field. a contour map of heat flow in the western mediterranean, resulting from a compilation of all existing data, is presented in the final discussion of the paper. also presented is a model for stable hercynian crust based on the presentday thermal regime of the maures and esterel. heat flow dpita in corsica, 11 data have been previously published by lesquer et al. (1983) and are gathered in this paper with nine n ...

# %%
#Revise et al. + lower
text_punew_spdo_ger_ovsp_etal = regex.sub(r'(\w+\s+et al.)','',text_punew_spdo_ger_ovsp)
text_punew_spdo_ger_ovsp_etal
# Out:
# "european tecronop~jwcs. 128 (19x6) 335356 elsevier science publishers b.v.. amsterdam printed in the netherlands 335 heat flow, heat production and fission track data from the hercynian basement around the provencal basin (western mediterranean) f. lucazeau ’ and d. mailhe ’ (received december 3. 19x5; accepted march 21. 1986) geotraverse abstract lucareau. f. and mailhe. d., 1986. heat flow. heat production and fission track data from the hercynian basement around the provenqal basin (western mediterranean). in: d.a. galson and st. mueller (editors). the european geotraverse, part 2. tecronophysks. 12x: 335356. in the complex structural framework of the western mediterranean. hercynian areas are expected to be thermally preserved from the recent tectonic evolution. the thermal regime of these areas is studied using heat flow, heat production and track data. the surface heat flow is significantly higher in corsica (76i_ 10 mw me 2, than in the maures and estcrel (58&2 mw ml). neither heat production nor erosion subsequent to the alpine orogeny in corsica can explain such a difference. it is suggested that a deep thermal source related to the asymmetric evolution of the provenqal basin could explain the higher heat flow in corsica. a model of thermal structure based on the present day thermal regime of the maures and estcrel is proposed for the stable hercynian crust in this area. the mantle heat flow is 2025 mw mm7 and the temperature at moho level is 375500°c. depending on the thermal parameter distribution with depth. introduction in the framework of european geotraverse (egt), geothermal studies have been undertaken in order to evaluate the surface heat flow and the temperature field within the lithosphere. the area the southern segment of the egt belongs to the western mediterranean domain where both alpine structures and young oceanic crust exist. in such a context, heat transfer is time dependent and evaluation of the temperature field requires thermal modelling of the transient processes (uplift and erosion, rifting’ and oceanic accretion, sedimentation, etc.). nevertheless. there exist few areas in the western mediterranean where hercynian basement outcrops, which could be used to obtain a reference thermal state for this modelling work. in this paper, interest is focused on the thermal regime of the 0040.ly51/x6/$03.50 ci 1986 elsevier science publishers b.v.\x0c0’ 5’ 10’ 15. 20. t i.. .__. _~_~ fig. 1. locations of the proven@ basin and the hercynian basement in the western mediterranean. crosses indicate the hercynian outcrops. shaded areas indicate the alpine erogenic zones. hercynian, outer parts of the provenqal basin (northwest mediterranean): maures and esterel in the southern part of france, and corsica and sardinia (fig. 1). the proven~al basin was formed during the oligocene by rifting of the continental lithosphere (, 1978), and then by oceanic accretion which shifted the corsicasardinia block away from france (burrus, 1984). in this basin, the continental crust is progressively thinned to about 56 km (le , 1984) whereas crustal thickness is normal in the maures (recq, 1970), in corsica (him and sapin, 1977) and in sardinia (, 1985). therefore, these areas were probably not affected by either alpine orogeny or continental rifting. the thermal regime of the hercynian crust is discussed using heat flow and heat production data from mauresesterel and corsica. fission track data are used to make sure that erosion processes have not perturbed the temperature field. a contour map of heat flow in the western mediterranean, resulting from a compilation of all existing data, is presented in the final discussion of the paper. also presented is a model for stable hercynian crust based on the presentday thermal regime of the maures and esterel. heat flow dpita in corsica, 11 data have been previously published by  (1983) and are gathered in this paper with nine new measurements. in mauresesterel, seven\x0cheat from 33 ...

# %%
#Eliminate fig and table
text_punew_spdo_ger_ovsp_etal = re.sub(r'ﬁ','fi',text_punew_spdo_ger_ovsp_etal)
text_punew_spdo_ger_ovsp_etal_fig = re.sub(r'(table|tables|figure|figures|fig.?|figs.)\s+(\d+|\d+.)', '', text_punew_spdo_ger_ovsp_etal)
text_punew_spdo_ger_ovsp_etal_fig
# Out:
# "european tecronop~jwcs. 128 (19x6) 335356 elsevier science publishers b.v.. amsterdam printed in the netherlands 335 heat flow, heat production and fission track data from the hercynian basement around the provencal basin (western mediterranean) f. lucazeau ’ and d. mailhe ’ (received december 3. 19x5; accepted march 21. 1986) geotraverse abstract lucareau. f. and mailhe. d., 1986. heat flow. heat production and fission track data from the hercynian basement around the provenqal basin (western mediterranean). in: d.a. galson and st. mueller (editors). the european geotraverse, part 2. tecronophysks. 12x: 335356. in the complex structural framework of the western mediterranean. hercynian areas are expected to be thermally preserved from the recent tectonic evolution. the thermal regime of these areas is studied using heat flow, heat production and track data. the surface heat flow is significantly higher in corsica (76i_ 10 mw me 2, than in the maures and estcrel (58&2 mw ml). neither heat production nor erosion subsequent to the alpine orogeny in corsica can explain such a difference. it is suggested that a deep thermal source related to the asymmetric evolution of the provenqal basin could explain the higher heat flow in corsica. a model of thermal structure based on the present day thermal regime of the maures and estcrel is proposed for the stable hercynian crust in this area. the mantle heat flow is 2025 mw mm7 and the temperature at moho level is 375500°c. depending on the thermal parameter distribution with depth. introduction in the framework of european geotraverse (egt), geothermal studies have been undertaken in order to evaluate the surface heat flow and the temperature field within the lithosphere. the area the southern segment of the egt belongs to the western mediterranean domain where both alpine structures and young oceanic crust exist. in such a context, heat transfer is time dependent and evaluation of the temperature field requires thermal modelling of the transient processes (uplift and erosion, rifting’ and oceanic accretion, sedimentation, etc.). nevertheless. there exist few areas in the western mediterranean where hercynian basement outcrops, which could be used to obtain a reference thermal state for this modelling work. in this paper, interest is focused on the thermal regime of the 0040.ly51/x6/$03.50 ci 1986 elsevier science publishers b.v.\x0c0’ 5’ 10’ 15. 20. t i.. .__. _~_~ . locations of the proven@ basin and the hercynian basement in the western mediterranean. crosses indicate the hercynian outcrops. shaded areas indicate the alpine erogenic zones. hercynian, outer parts of the provenqal basin (northwest mediterranean): maures and esterel in the southern part of france, and corsica and sardinia (). the proven~al basin was formed during the oligocene by rifting of the continental lithosphere (, 1978), and then by oceanic accretion which shifted the corsicasardinia block away from france (burrus, 1984). in this basin, the continental crust is progressively thinned to about 56 km (le , 1984) whereas crustal thickness is normal in the maures (recq, 1970), in corsica (him and sapin, 1977) and in sardinia (, 1985). therefore, these areas were probably not affected by either alpine orogeny or continental rifting. the thermal regime of the hercynian crust is discussed using heat flow and heat production data from mauresesterel and corsica. fission track data are used to make sure that erosion processes have not perturbed the temperature field. a contour map of heat flow in the western mediterranean, resulting from a compilation of all existing data, is presented in the final discussion of the paper. also presented is a model for stable hercynian crust based on the presentday thermal regime of the maures and esterel. heat flow dpita in corsica, 11 data have been previously published by  (1983) and are gathered in this paper with nine new measurements. in mauresesterel, seven\x0cheat from 337 new measur ...

# %%
#Eliminate email
text_punew_spdo_ger_ovsp_etal_fig_emai = regex.sub(r'\b[\w-.]+?@\w+?.\w+[\w\.\-]+\b','',text_punew_spdo_ger_ovsp_etal_fig)
text_punew_spdo_ger_ovsp_etal_fig_emai
# Out:
# "european tecronop~jwcs. 128 (19x6) 335356 elsevier science publishers b.v.. amsterdam printed in the netherlands 335 heat flow, heat production and fission track data from the hercynian basement around the provencal basin (western mediterranean) f. lucazeau ’ and d. mailhe ’ (received december 3. 19x5; accepted march 21. 1986) geotraverse abstract lucareau. f. and mailhe. d., 1986. heat flow. heat production and fission track data from the hercynian basement around the provenqal basin (western mediterranean). in: d.a. galson and st. mueller (editors). the european geotraverse, part 2. tecronophysks. 12x: 335356. in the complex structural framework of the western mediterranean. hercynian areas are expected to be thermally preserved from the recent tectonic evolution. the thermal regime of these areas is studied using heat flow, heat production and track data. the surface heat flow is significantly higher in corsica (76i_ 10 mw me 2, than in the maures and estcrel (58&2 mw ml). neither heat production nor erosion subsequent to the alpine orogeny in corsica can explain such a difference. it is suggested that a deep thermal source related to the asymmetric evolution of the provenqal basin could explain the higher heat flow in corsica. a model of thermal structure based on the present day thermal regime of the maures and estcrel is proposed for the stable hercynian crust in this area. the mantle heat flow is 2025 mw mm7 and the temperature at moho level is 375500°c. depending on the thermal parameter distribution with depth. introduction in the framework of european geotraverse (egt), geothermal studies have been undertaken in order to evaluate the surface heat flow and the temperature field within the lithosphere. the area the southern segment of the egt belongs to the western mediterranean domain where both alpine structures and young oceanic crust exist. in such a context, heat transfer is time dependent and evaluation of the temperature field requires thermal modelling of the transient processes (uplift and erosion, rifting’ and oceanic accretion, sedimentation, etc.). nevertheless. there exist few areas in the western mediterranean where hercynian basement outcrops, which could be used to obtain a reference thermal state for this modelling work. in this paper, interest is focused on the thermal regime of the 0040.ly51/x6/$03.50 ci 1986 elsevier science publishers b.v.\x0c0’ 5’ 10’ 15. 20. t i.. .__. _~_~ . locations of the proven@ basin and the hercynian basement in the western mediterranean. crosses indicate the hercynian outcrops. shaded areas indicate the alpine erogenic zones. hercynian, outer parts of the provenqal basin (northwest mediterranean): maures and esterel in the southern part of france, and corsica and sardinia (). the proven~al basin was formed during the oligocene by rifting of the continental lithosphere (, 1978), and then by oceanic accretion which shifted the corsicasardinia block away from france (burrus, 1984). in this basin, the continental crust is progressively thinned to about 56 km (le , 1984) whereas crustal thickness is normal in the maures (recq, 1970), in corsica (him and sapin, 1977) and in sardinia (, 1985). therefore, these areas were probably not affected by either alpine orogeny or continental rifting. the thermal regime of the hercynian crust is discussed using heat flow and heat production data from mauresesterel and corsica. fission track data are used to make sure that erosion processes have not perturbed the temperature field. a contour map of heat flow in the western mediterranean, resulting from a compilation of all existing data, is presented in the final discussion of the paper. also presented is a model for stable hercynian crust based on the presentday thermal regime of the maures and esterel. heat flow dpita in corsica, 11 data have been previously published by  (1983) and are gathered in this paper with nine new measurements. in mauresesterel, seven\x0cheat from 337 new measur ...

# %%
#Eliminate website
text_punew_spdo_ger_ovsp_etal_fig_emai_web = regex.sub(r'(http|https|ftp|ssh)://([\w_-]+(?:(?:\.[\w\s_-]+)+))([\w.,@?^=%&:/~+#-]*[\w@?^=%&/~+#-])?','',text_punew_spdo_ger_ovsp_etal_fig_emai)
text_punew_spdo_ger_ovsp_etal_fig_emai_web
# Out:
# "european tecronop~jwcs. 128 (19x6) 335356 elsevier science publishers b.v.. amsterdam printed in the netherlands 335 heat flow, heat production and fission track data from the hercynian basement around the provencal basin (western mediterranean) f. lucazeau ’ and d. mailhe ’ (received december 3. 19x5; accepted march 21. 1986) geotraverse abstract lucareau. f. and mailhe. d., 1986. heat flow. heat production and fission track data from the hercynian basement around the provenqal basin (western mediterranean). in: d.a. galson and st. mueller (editors). the european geotraverse, part 2. tecronophysks. 12x: 335356. in the complex structural framework of the western mediterranean. hercynian areas are expected to be thermally preserved from the recent tectonic evolution. the thermal regime of these areas is studied using heat flow, heat production and track data. the surface heat flow is significantly higher in corsica (76i_ 10 mw me 2, than in the maures and estcrel (58&2 mw ml). neither heat production nor erosion subsequent to the alpine orogeny in corsica can explain such a difference. it is suggested that a deep thermal source related to the asymmetric evolution of the provenqal basin could explain the higher heat flow in corsica. a model of thermal structure based on the present day thermal regime of the maures and estcrel is proposed for the stable hercynian crust in this area. the mantle heat flow is 2025 mw mm7 and the temperature at moho level is 375500°c. depending on the thermal parameter distribution with depth. introduction in the framework of european geotraverse (egt), geothermal studies have been undertaken in order to evaluate the surface heat flow and the temperature field within the lithosphere. the area the southern segment of the egt belongs to the western mediterranean domain where both alpine structures and young oceanic crust exist. in such a context, heat transfer is time dependent and evaluation of the temperature field requires thermal modelling of the transient processes (uplift and erosion, rifting’ and oceanic accretion, sedimentation, etc.). nevertheless. there exist few areas in the western mediterranean where hercynian basement outcrops, which could be used to obtain a reference thermal state for this modelling work. in this paper, interest is focused on the thermal regime of the 0040.ly51/x6/$03.50 ci 1986 elsevier science publishers b.v.\x0c0’ 5’ 10’ 15. 20. t i.. .__. _~_~ . locations of the proven@ basin and the hercynian basement in the western mediterranean. crosses indicate the hercynian outcrops. shaded areas indicate the alpine erogenic zones. hercynian, outer parts of the provenqal basin (northwest mediterranean): maures and esterel in the southern part of france, and corsica and sardinia (). the proven~al basin was formed during the oligocene by rifting of the continental lithosphere (, 1978), and then by oceanic accretion which shifted the corsicasardinia block away from france (burrus, 1984). in this basin, the continental crust is progressively thinned to about 56 km (le , 1984) whereas crustal thickness is normal in the maures (recq, 1970), in corsica (him and sapin, 1977) and in sardinia (, 1985). therefore, these areas were probably not affected by either alpine orogeny or continental rifting. the thermal regime of the hercynian crust is discussed using heat flow and heat production data from mauresesterel and corsica. fission track data are used to make sure that erosion processes have not perturbed the temperature field. a contour map of heat flow in the western mediterranean, resulting from a compilation of all existing data, is presented in the final discussion of the paper. also presented is a model for stable hercynian crust based on the presentday thermal regime of the maures and esterel. heat flow dpita in corsica, 11 data have been previously published by  (1983) and are gathered in this paper with nine new measurements. in mauresesterel, seven\x0cheat from 337 new measur ...

# %% [markdown]
# ## Pre-Processing 2 : Sentences with Conditioning, Stemmer / Lemmatizer,  & Stopwords

# %%
#Splitted into sentences by Spacy
spc_text = spc(text_punew_spdo_ger_ovsp_etal_fig_emai_web)

#Prep []
prepro1 = []
col_intro = []
stop_ack_stc = []
stop_ref_stc = []
name = []
pca = '!"#$%&\*+/:;<=>?@[\]^_`{|}~'
pattern_comb = regex.compile(r'([a-z]+[\d]+|\d+[a-z]+|\d+[{}]+|[a-z]+[{}]+|[{}]+[a-z]+|[{}]+[\d]+)'.format(pca,pca,pca,pca))

#list all name
for i in spc_text.ents:
    if i.label_.lower() == 'person':
        name.append(i.text)
    else:
        pass

#List of Sentences with lemmatization
for i,j in enumerate(spc_text.sents):
    
    #Eliminate word - number - punc-chars combination
    sent_lem = regex.sub(pattern_comb,'',j.lemma_)
    
    #delete name
    if len(name) != 0:
        try:
            sent_lem = regex.sub(r",*(\s*\b(?:{}))\b".format("|".join(name)),'',sent_lem)
        except:
            pass
    else:
        pass
    
    prepro1.append(sent_lem)
    
    #Serach for the start pf acknowledgements and references
    if bool(re.search('(acknowledgments|acknowledgment)',sent_lem)) == True:
        stop_ack_stc.append(i)
        
    if bool(re.search('(references|reference)',sent_lem)) == True:
        stop_ref_stc.append(i)
        
    elif bool(re.search('(introduction)',sent_lem)) == True:
        col_intro.append(i)

#Cut parts before Introduction and after the acknowledgments or references
try:
    if len(stop_ack_stc) == 0:
        try:
            prepro1 = prepro1[col_intro[0]:stop_ref_stc[-1]]
        except:
            prepro1 = prepro1[:stop_ref_stc[-1]]
    else:
        try:
            prepro1 = prepro1[col_intro[0]:stop_ack_stc[-1]]
        except:
            prepro1 = prepro1[:stop_ack_stc[-1]]
except:
    pass
    
#All results
brute_result = prepro1

# %%
prepro1
# Out:
# ['introduction in the framework of european geotraverse (egt), geothermal study have be undertake in order to evaluate the surface heat flow and the temperature field within the lithosphere.',
#  'the area the southern segment of the egt belong to the western mediterranean domain where both alpine structure and young oceanic crust exist.',
#  "in such a context, heat transfer be time dependent and evaluation of the temperature field require thermal modelling of the transient process (uplift and erosion, rifting' and oceanic accretion, sedimentation, etc.).",
#  'nevertheless.',
#  'there exist few area in the western mediterranean where hercynian basement outcrop, which could be use to obtain a reference thermal state for this modelling work.',
#  'in this paper, interest be focus on the thermal regime of the 0040.03.50 ci 1986 elsevier science publishers b.v',
#  '.',
#  "0'",
#  "5'",
#  "10' 15. 20.",
#  't i..',
#  '.',
#  '_',
#  '_.',
#  '_~_~ . location of the  basin and the hercynian basement in the western mediterranean.',
#  'crosse indicate the hercynian outcrop.',
#  'shaded area indicate the alpine erogenic zone.',
#  'hercynian, outer part of the provenqal basin (northwest mediterranean): maures and esterel in the southern part of france, and corsica and sardinia ().',
#  'the al basin be form during the oligocene by rifting of the continental lithosphere (, 1978), and then by oceanic accretion which shift the corsicasardinia block away from france (, 1984).',
#  'in this basin, the continental crust be progressively thin to about 56 km ( , 1984) whereas crustal thickness be normal in the maures (recq, 1970), in corsica ( and, 1977) and in sardinia (, 1985).',
#  'therefore, these area be probably not affect by either alpine orogeny or continental rifting.',
#  'the thermal regime of the hercynian crust be discuss use heat flow and heat production datum from mauresesterel and corsica.',
#  'fission track datum be use to make sure that erosion process have not perturb the temperature field.',
#  'a contour map of heat flow in the western mediterranean, result from a compilation of all exist datum, be present in the final discussion of the paper.',
#  'also present be a model for stable hercynian crust base on the presentday thermal regime of the maures and esterel.',
#  'heat flow dpita in corsica, 11 datum have be previously publish by  (1983) and be gather in this paper with nine new measurement.',
#  'in mauresesterel, seven\x0cheat from 337 new measurement be present.',
#  'temperature survey be carry out with a thermistor probe give a relative accuracy of o.ol”.',
#  'temperature profile be correct to account for topographic effect accord to the classical procedure (. 1981).',
#  'no other correction be apply to the datum.',
#  'conductivity measurement be make on watersaturated halfcore with a transient method of determination.',
#  'flow corsica all of the datum be obtain in shallow borehole drill for water resource.',
#  'but only unproductive borehole be use.',
#  'temperature profile be display in ; most of they have a curvature, which can be explain in some case by thermal conductivity contrast (partinello) or water circulation (casavecchie, lama 24 and luri 38).',
#  'in other borehole, there be no evidence for water circulation to explain this curvature.',
#  "however, for the most reliable datum (piattone, alata, lama 26) the variation of the thermal gradient within the borehole do not exceed 5° km '.",
#  "for all of the borehole in the hercynian basement, the standard deviation on the average gradient (24.5  ” km') be of the same order of magnitude.",
#  'this temoerature 12 4  10 20 30 40 thermal gradient i’km 1) depth(m) lama  .',
#  'temperature profile versus depth for the various borehole log in corsica.',
#  'temperature be represent use an arbitrary scale, one division represent one degree.',
#  'the value on the upper part of each profile represent the actual temperature at the depth for which the thermal log begin.',
#  'the star correspond to datum already publish by  (1983).',
#  'suggest that all of the datum be consistent despite the shallow depth and the uncertainty for individual value of thermal gradient.',
#  'none of these borehole have be cog and conductivity be estimate from measurement on surface sample.',
#  'heat flow value be present in .',
#  "the average value be 76 i 16 mw m-' for all of the datum and 76 f 10 mw m-* for borehole deep than 60 m.",
#  'this value be therefore representative of the surface heat flow in corsica, but local 338  heat flow datum from corsica * ______~.. locality long.',
#  'e lat.',
#  "n depth conducthermal heat flow ** tithology range tivity gradient ,,'.",
#  '(m) (w  \' ( "(\' \'/ km \')  m 2) north alpine corsica average heat flow = 82 & 12 mw m \' luri 38 a 9924\' 42”58\' 6590 2.45 38.4 luri 49 a 24\' \' 2075 2.45 20.6 south alpine corsica average heat flow = 8 1 f 19 mw m _ \' casavecchie \' 22 8 1070 2.42 20.1 ghisonaccia 23 41957\' 2070 4.0 h 15.6 average heat flow = 78 + 7 mw m \' novella a  035\' 3065 2.5 h 32.8 lama 26 \' 9\' 42034\' 30105 2.5 h 33.8 lama 24 a 9010\' 42”34\' 30120 2.9 27 osani area average heat flow =  2 mw rn\' partinelto \' 840\' 18\' 2090 2.5 \' 37 3.0 h 20 osani  38\' 9  3.0 \' 32.8 osani fl 39\' 19\' 3560 3.0 b 24.0 osani  38\' 42”19\' 15 52 1.4 " 66 3.6 b 20 ajuccio area average value = 64 + 3 mw m \' alata 45\' 41”58\' 1082 3.0 h 22.4 alata 2 8”45\' 41058\' 1548 3.0 h 31.2 truva a \' 8\' 1070 2.5 h 24.4 south ajaccio area average heat flow = 75 k 2 mw m\' face \' 41°37\'  3.0 h 17.6 urbalacone a \'  2045 2.9 24.8 piattone s 8054\' 41045\' 6091 3.0 h 24.0 sartene a 8959\' 41935\' 2565 3.0 h 25.6 bronco 50\' 41”46\' 3074 3.0 h 44.0 ct (mw mm \') _._ __ .94 94 schist 83 70 schist 111 loo schist 62 62 sandstone 89 84 flysch 103 71 spilite 75 78 granite 92 59 132 86 108 76 98 72 92 rhyolite granite granite granite carbon schist 56 67 gram te 92 94 granite 72 61 gabbro 53 60 granite 76 72 granite 72 72 granite 84 77 granite 148 132 granite * average heat flow value calculate only for borehofes deep than 60 m.',
#  '** uc = uncorrected  ci = correct for topographic effect.',
#  'a value previously publish by et a).',
#  '(1983).',
#  'b estimate value.',
#  '',
#  't ll 339 qo = ":, 2 i i qo : 75 f 2 osani  lt osani f 3\' qo, u\\',
#  'lama',
#  '26',
#  '.',
#  'qo = ',
#  'novella',
#  "'",
#  ' ]',
#  'urbalacon t \\ i i  .',
#  'estimate heat flow for different prownce of corsica.',
#  'superpose on the geological map.',
#  'ixge dot represent heat flow measurement.',
#  'star indicate horehole deep than 60 m use in the averaging.',
#  'i = posthercynian.',
#  '1 = hercynian granite of tenda (alpine corsica).',
#  '.?',
#  '= permian anorogenic granite.',
#  '4 = subalkaline granite.',
#  '5 = permian rhyolite.',
#  '6 = leucocratlc granite.',
#  '7 = talkalkaline granite.',
#  'x = metamorphic basement.',
#  'variation can be expect for the different structural unit ( and ).',
#  'alpine corsica, both on the mesozoic unit and on the hercynian unit of tenda.',
#  'have a slightly high heat flow (80 mw ).',
#  'on the other hand.',
#  'the ajaccio area be characterize by a low heat flow (64 mw m _ 2).',
#  '340 heat flow from the maures and i’;.stprel',
#  'in southern france, seven new datum be  two in the maures.',
#  'two in estcrel and three in the vicinity of the hercynian basement.',
#  'temperature profile be present in ; they be obviously more regular than those of corsica, and borehole be deep.',
#  'heat flow value be give in  and .',
#  'the two borehole from esterel (castelli and gratadis) have be drill for mining research in the permian rhyolite.',
#  "heat flow value obtain in these two borehole (respectively 56 and  mw mm') correspond to reliable datum accord to the egt criterion (depth great than 100 m, conductivity measurement on several core along the borehole, borehole free of water circulation, etc.).",
#  'the two borehole from the maure (ramatuelle and cogolin) be shallow and conductivity be estimate from surface sample, however,',
#  "heat flow value (respectively 61 and 59 mw 0 50 150 200 250  32 temperature ( arbitrary scale '\\ gratadls \\ (' kml) ?\\ '/ depth ) i casteill .",
#  'temperature profile versus depth for the various borehole log in maures and estcrel.',
#  'temperature be represent use an arbitrary scale, one division represent one degree.',
#  'the value on the upper part of each profile represent the actual temperature at the depth at which the thermal log begin.',
#  '',
#  'cogolin 17.6 gneish vtcinity of el-maures la clue  1  heat flow datum from mauresestcrel locality long.',
#  'e lat.',
#  "n depth conducthermal heat flow * lithology range tivity gradient ct (m) (w mm' ') ( '1 fzw (mw ) mm') maure.7 ramatuelle 34  2065 3.0 20.4 61 61 uchist 6”32 15' 2595 2.1 25.6 69 59 48 rel castelli 50' 28' 50250 1.9 32.0 62 58 pelite 2.1 22.0 rhyolite cratadis '  28' 30125 2.65 21.0 66 56 rhyolite 6”31' 43034' 100200 3.91 14.5 57 57 dolomite gardanne 5”17' 43030 ~ 2.36 24.5 61 58 limestone carte 7' 43”28  2.24 = 23 51 54 oil datum * uc = uncorrected  ct = correct for topographic effect.",
#  "'",
#  'estimate value.',
#  'la clue qo = 57 carces qo = : 1 j .',
#  'estimate heat flow from maure and esttrel.',
#  '1 = diorite, 7 = leucogranite, 3 = cordieritegranite, 4 = granitegneiss, 5 = metamorphic schist, gneiss and anatectic gneiss.',
#  '6 = esterellite.',
#  '',
#  '342 heat production datum surface  ld) be consistent with value obtain in esterel.',
#  'three other measurement have be obtain in the vicinity of the hercynian basement of provence and confirm value from the maures and esterel.',
#  'one of these datum () correspond to an oil exploration borehole, for which one bht measurement be available at the bottom and be correct for mud circulation effect.',
#  'the average value in this area (58 k 2 mw ) indicate that heat flow be close to the average european value (64 & 24 mw , and to value obtain in other stable hercynian province of europe (, 1979).',
#  'in continent, the thermal regime of the crust be closely related to the nature and distribution of heat source.',
#  'moreover, in some stable area of the world, a linear relationship exist between surface heat flow and surface heat production (, 1968).',
#  'therefore, it be important to study the surface heat production in order to evaluate the contribution of heat source to the surface heat flow.',
#  'heat production be late from uranium, thorium and potassium concentration accord to the work of (. 1968).',
#  'in the present work, new measurement from the maure and esterel be present and compare with previous result from corsica.',
#  'the hercynian basement outcropping in the maure and esttrel, mostly form by metamorphic rock, be different from the basement outcropping in corsica, mostly form by hercynian granite.',
#  'the mauresestcrel province be characterize by two paleozoic metamorphic unit, the maures in a southwestern position and the tanneron in a northeastern position ().',
#  'these two massif be separate by the permian volcanic and sedimentary unit of the estcrel.',
#  'the petrographic feature of the metamorphic basement have be study by (1983) and (1977).',
#  'the western part of the maures be mostly form by rnicaschist and twomica gneis intrude by cambrian granitegneiss.',
#  'the eastern part of the maures and the tanneron massif be form by other metamorphic rock, mostly anatectic gneiss.',
#  'also intrude by cambrian granitegneiss.',
#  'these two metamorphic domain be separate by a ns fault along which the hercynian granite of plan de la tour be situate ().',
#  'permian rhyolite correspond to the esttrel massif sensu stricto.',
#  'a granitic equivalent of these rhyolite be find as xenolith in the oligocene esttrellite (rnicrodiorite).',
#  'corsica be classically divide into two  alpine corsica on the western part of the island, which correspond to the abduction of a mesozoic unit during the middle cretaceous, and hercynian corsica on the western and southern part, form by the hercynian and permian granitic basement.',
#  'hercynian granite belong to two magmatic association, the talkalkaline and the subalkaline type.',
#  '',
#  '4 343 permian granite represent anorogenic type associate with the rhyolite in the northern part of the island, but not in the southern part.',
#  'this suggest that the level of erosion be increase from esterel (rhyolite outcrop and granite exist at deep level) to the north of corsica (both rhyolite and granite outcrop) and finally.',
#  'to the south of corsica (only granite exist) (bonnin and.',
#  '.',
#  '1977)',
#  '.',
#  'u. th and k concentration have be determine by epithermal neutron activation analysis (enaa) and compare, for a few sample.',
#  'to measurement obtain by gammaray spectrometry (grs); the difference be generally low than .',
#  'which be acceptable for this heat production study.',
#  'sample be representative of the different geological formation (), and result be present in / /  cenozoic  mesozoic kiiz permian',
#  '!',
#  ' stephanian i’+ hercyncan granite i /.i paleozoic basement i i f fault mediterranean sea n .',
#  'geological map of maures and esterel and location of sample analyze for u. th and k.\x0c heat production datum from maures- ) (ppm) (s) wv ) u method * standard 3.68 3.60 3.65 1.31 4.12 6. 3.15 1.93 0.60 0.55 3.30 1.74 3.12 0.98 0.95 3.20 3.23 i .80 3.17 2.86 2.07 4.26 3.33 1.78 6.09 6.18 6.00',
#  'grs',
#  'enaa',
#  'enaa',
#  'enaa',
#  'enaa',
#  'enaa grs enaa enaa enaa enaa enaa enaa enaa grs enaa enaa enaa enaa enaa 61 gsn gsn gsn gsn gsn 61 gsn gsn gsn gsn gsn gsn gsn 61 gsn gsn gsn gsn gsn enaa enaa gsn gsn 4.43 2.01 5.33 0.31 5.79 0.04 7.70 0.04 2.84 0.03 2.44 0.03 3.37 0.02 7.20 3.09 10.54 0.57 10.34 0.05 4.51 0.15 7.24 0.15 3.05 0.03 11.53 0.04 10.85 0.11 13.71 4.09 19.19 0.40 21.11 0.55 10.06 0.07 11.69 0.08 15.07 0.05 10.61 0.05 10.59 3.08 6.30 0.18 5.70 0.22 14.88 0.28 12.58 0.31 9.51 0.23 11.30 0.26 10.30 0.23 3.06 0.53 3.53 0.16 3.61 0.05 3.07 0.17 2.28 0.14 3.67 0.10 2.68 0.12 3.88 0.22 4.16 0.18 4.14 0.21 3.64 0.06 3.85 0.15 3.66 0.25 4.45 0.13 4.13 0.05 2.44 0.64 3.12 0.09 3.38 0.04 3.03 0.02 1.80 0.02 2.08 0.01 1.90 0.01 3.02 0.74 3.61 0.15 3.51 0.03 2.60 0.04 3.17 0.05 1.84 0.03 4.25 0.02 3.97 0.03 1.710.81 0.90 0.01 3.51 0.21 2.52 0.02 5.45 2.53 2.91 0.01 6.33 0.17 7.98 0.31 1.73 0.30 1.43 0.09 1.80 0.09 2.02 0.04 l.oq 0.43 0.58 0.01 1.55 0.06 1.43 0.02 6.19 0.73 5.44 0.54 5.89 0.01 6.27 0.01 7.15 0.02 17.49 6.61 11.28 0.06 25.12 0.05 20.85 0.02 12.7 0.06 4.80 2.67 4.79 0.17 7.58 0.14 1.19 0.06 5.64 0.24 3.34 0.57 2.70 0.02 4.08 0.01 3.25 0.01 3.33 0.02 3.64 0.08 3.71 0.03 3.56 0.04 22.14 1.10 22.91 0.50 21.36 0.38 3.79 3.79 0.06 3.78 0.21 2.91 0.08 2.99 0.04 2.83 0.04 granite gneiss average   gc 10  gc 16 granite average   ml 14 ml 15 ml 18 average ml 23  verage ml 16 ml 21 ml 22 ml 24 schist average  ml 11 344  with average value for each petrologic type',
#  '.',
#  'metamorphic rock be classify in two  metasedimentary rock (t, gneiss and anatectic gneiss) and granitegneiss.',
#  "the radiogenic content do not ficantly change with the grade of metamorphism for metasedimentary rock () and average heat production be 2.1 .7 pw m '.",
#  'graniteegneiss have a high average u content  thzk (jt,, kfu,  diorite rhyolite\x0c345  (continue) (ppm) thko,, (ppm) kkak (%) affj, (pw m-j) u method * standard average 3.22 1.14 13.95 4.69 2.91 0.73  3.34 0.21 22.43 0.46 4.75 0.20 3.66 0.10 20.43 0.37 4.03 0.10  gc 14 ml 10 ml 13    gc 11 gc 12 3.23 0.03 2.05 0.01 2.20 0.01 0.56 0.03 4.27 0.02 3.78 0.04 3.47 0.02 2.85 0.03 3.24 0.03 10.81 0.06 2.60 0.16 17.08 0.05 2.30 0.05 18.41 0.04 2.63 0.12 3.09 0.22 15.55 0.06 11.93 0.07 15.28 0.06 12.51 0.07 13.11 0.52 1.96 0.13 3.09 0.18 2.64 0. 3.07 0.13 3.45 0.04 1.67 0.04 4.96 0.03 18.37 0.08 3.93 0.21 2.13 0.63 2.95 0.07 2.82 0.04 1.87 0.02 1.99 0.01 2.15 0.01 0.56 0.02 2.53 0.02 2.10 0.01 2.30 0.01 1.98 0.01 1.95 0.04 3.00 0.02 average 3.16 0.25 11.27 2.79 3.32 1.02 2.20 0.60  ml 19 gc 1    gcx 3.46 0.02 6.03 0.34 4.85 0.11 4.65 0.03 2.35 0.02 4.00 0.02 2.86 0.09 4.13 0.04 12.55 0.04 2.21 0.10 2.02 0.01 19.31 0.40 3.88 0.17 3.34 0.09 15.87 0.27 3.50 0.06 10.65 0.32 4.20 0.08 7.60 0.04 13.99 0.22 1.52 0.03 4.66 0.05 8.44 0.20 3.50 0.09 2.75 0.04 2.39 0.03 1.31 0.01 2.50 0.02 1.69 0.03 9.77 0.07 3.67 0.15 2.14 0.02 4.62 6.70 5.58 3.35 x.33 x.37 5.52 3.64 3.16 4.40 4.39 4.05 3.70 3.03 3.63 3.20 3.21 2.29 3.23 3.50 2.95 2.37 gr enaa enaa enaa enaa enaa enaa enaa enaa enaa enaa enaa * gamma-ray  enaa = epithermal neutron activation analysis.',
#  '61 gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn 61 gsn gsn gsn gsn gsn gsn ufo, gnrlss annrectrc gnr,.s.s enaa enaa enaa enaa enaa grs enaa enaa grs = and consequently a high heat production (2.4 + 0.6 pw ).',
#  'in a similar work in the massif central (france) and (1981) have find value in the same range.',
#  'surface anatectic gneiss of the massif central have a heat production of 1.91 pw  whereas the same material erupt from a depth of 20 km during recent volcanism, have a heat production of 1.89 pw .',
#  'in other geological province of the world, similar consideration apply ( and,  , 1982).',
#  'granite of the maures and esterel be close to the leucogranite type of the massif central ( and, 1981) with low th and u value, characteristic of granite of crustal origin.',
#  'heat production of these granite be 3.0 k 0.7 p.w .',
#  'the sensu  massif of esttrel be form by permian rhyolite.',
#  'heat production of these rock be 3.3 + 0.6 pw .',
#  'finally, diorite have a low heat production (1.0 pw , and only represent small outcropping volume.',
#  '',
#  'ii. 0.085 0.015 0.080 0.109 0.114 0.085 0.093 0.070 0.105 0.154 0.114 0.044 0.040  sli i  i  i     li oi i i .~',
#  '_',
#  'or field of grain number 36. 4.7 41.65 7.8 40.22 6.6 40.45 4.5 41. 6.0 p 27.62 4.3 34.5 f 4.4 28. 4.1 98. 17.5 110.0 + 20.2 99. 18.3 85.1 + 13.1 117. 4.3 p 135.21 6.1 p 2.29 2.29 2.29 2.29 0.8074 0.8074 0.8074 0.8074 4.29 4.29 4.29 4.00 4.00 4.00 (ma) lo ( x 10’*) dose neutron 120 81 101 215 84 63 93 164 51 59 80 1.055 0.4886 0.6474 1.3 3.02 1.076 1.58 1.92 1.046 1.0678 2.238 507 10042 5694 track h 1.52 15.45 6.45 x cmz track induce 76 29 26 91 119 80 94 114 33 36 65 261 7252 4226 0.285 0.1487 0.1905 0.384 2.613 0.615 1.13 1.114 0.4061 0.4615 0.8695 0.54 7.67 3.68 apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite  (ns) (300) (290)',
#  'el (ns) d (ns) f (ns) (ns) d b (ns) ( (290) a (ns) ml 4 ml 6 ml 17 track \' (2) track fossit mineral sample * apatite fission track datum from the maures and estcrel (ml 17, ml 6 and ml 4) and from corsica (, 1986) \x0c(290) apatite 0.224 51 0.69 101 2.29 44. 7.6  0.072 (300) apatite 0.1445 31 0.4835 77 2.29 40. 8.8 i 0.096 f (ns) apatite 1.721 83 2.81 155 0.8074 29. 4.1 p i 0.093 h (ns) apatite 1.079 71 1.2  0.8074 43. 7.4 p  0.122 1 (ns) apatite 1.35 48 1.92 31 0.8074 33. 7.5 p  0.311 j (300) apatite 0.13 19 0.232 34 0.8074 29.25 7.6 i 0.174 p (ns) apatite 1.45 109 1.81 124 0.8074 38. 5.1 p  i 0.094 q (ns) apatite 2.51 151 2.65 153 0.8074 43. 5.0 p i 0.142 (ns) d apatite 2.264 165 2.44 143 0.8074 44. 5.2 p i 0.130 \' apatite 0.22 167 0.82 530 1.62 26. 2.3 p i 0.057 h f = 7.~" : 235 u,’= 7.252 _\': q =   . \' for  n = natural state, without laboratory annealing, 290 = one hour laboratory annealing at 290°.',
#  "300 = one hour laboratory annealing at . ' number of track actually count. '",
#  '[ = relative standard error of the mean for the inducedtrack count in apatite.',
#  "cl count by observer other than d.m. ' fish canyon age standard count at the same time as the sample.",
#  'p error calculate from the poisson relative standard error of mean.',
#  '348 previous heat production datum from cock these datum have be publish by  (1983), but it be interesting to recall their principal result in order to discuss heat flow datum.',
#  'the talcalkaline granite represent about threethird of the outcrop in hercynian corsica.',
#  'they be obviously deplete in uranium (1.9 f 0.7 ppm) as u be very high (7.3).',
#  "heat production be only 1.8 + 0.2 pw m '.",
#  'similar granite in the massif central have a high average uranium content (5.2 ppm) and a u ratio of about 4 ( and, 1981), consistent with the u expect for granite.',
#  'granite of corsica be therefore probably deplete because of some weathering process.',
#  'the leucocratic granite represent evolve member of the talkalkaline series.',
#  "they be enrich in uranium (u = 10.4 ppm) and have a high heat production (4.4 k 0.6 pw mm ').",
#  'the subalkali granite be enrich in uranium (7.6 ppm) and thorium (38 ppm).',
#  "they consequently have a high heat production (4.9 pw rn').",
#  'these value be close to the average value for similar granite in the massif central.',
#  'finally, the heat production of permian anorogenic granite vary from 3.0 to 5.3 pw mj.',
#  'apatite fission track (ft) datum fission track represent daughter product of the disintegration of  and can be use as a dating method.',
#  'the special feature of this method be that the closure of the system be strongly sensitive to temperature.',
#  'this closure temperature be a characteristic of mineral, and for apatite, be about 100°.',
#  'therefore, this could be an excellent indicator of paleogeothermal condition, as apatite ft age represent the last cooling below loo”, correspond to a depth of about 3 km.',
#  'in the present study, two set of datum be  measurement from corsica publish by (1986) together with zircon ft  three new apatite ft age from the maure and estcrel, simultaneously determine with the international standard fish canyon tuff complete the previous datum.',
#  'result be present in  and , in which corsica be draw in its preoligocene position.',
#  'more information about the method and reference can be find in (1986).',
#  'the alpine part of corsica be characterize by eoceneoligocene apatite ft age (4030 ma) whereas the northwest part of the island and the maure and estcrel give cretaceous age.',
#  ' (1986) and  (1986) interpret fission track datum in the eastern part of corsica assume differential erosion subsequent to the wellknown eocene compressional stage, with erosion rate of as high as 1 mm yri.',
#  'on the other hand, the western part of corsica, the maure and estcrel, and probably the region between they, have only be affect by the cretaceous phase of the alpine orogeny, as show by old apatite age.',
#  'this indicate that no erosional process occur between the middle cretaceous and the oligocene rifting.',
#  'there be no geological evidence for distention in this area before the\x0crole of heat production 349 .',
#  'apatite fission track datum in the maure and estcrel and in corsica.',
#  'the provenqal coastlme be in its presentday position whereas corsica have heen reptace in its supposed preoligocene position (after . 1984 and.',
#  '19841',
#  '.',
#  'oligocene.',
#  'therefore, except in alpine corsica, the thermal regime of the ilercynian crust at the onset of oligocene rifting be probably in equilibrium.',
#  "dlscussion result present in the previous section indicate that the surface heat flow be significantly low in the maures and estcrel(58 mw mz) than in corsica (76 mw rn').",
#  'moreover, previous work in sardinia (, 1982) have show that heat flow be generally low (58 + 15 mw m 2) except in the quaternary graben of campidano (127 + 43 mw ).',
#  'it be important to explain the origin of the high value in corsica in order to understand the thermal structure within and around the al basin.',
#  'heat production of granite in corsica present a wide range of value from 1.8 pw  to 5.3 pw mj.',
#  "the low boundary can be increase to about 3 pw m ' (value of similar granite in the massif central), since corsican talkalkaline granite be probably deplete in uranium.",
#  'the difference between surface heat flow could then be explain by 18 km more of talkalkaline granite or 6 km more of enrich granite in corsica, relative to the metamorphic basement in the\x0c350 mauresesterel.',
#  'this explanation be problematic, however, as surface granite be not associate with a heat flow anomaly in sardinia and as granite presumably exist as well at deep level in the maure and esterel.',
#  'it be more likely that the radiogenic heat contribution of the crust in these three area be roughly the same and that the heat flow anomaly of corsica have another origin.',
#  'role of erosion corsica have be affect by the alpine orogeny during two major  the middle cretaceous phase, which correspond to the abduction process, and the eocene phase, which correspond to the main tectonic compression.',
#  '(1986) attempt to derive erosion rate from combine fission track datum (zircon and apatite) and thermal modelling.',
#  "maximum erosion rate during the eocene phase be observe in alpine corsica and be less than 1 mm yr'.",
#  "at the present, this yield a maximum heat flow anomaly of less than 10 mw m', but for the erosion rate which prevail in central and western corsica, no increase in surface heat flow expect.",
#  'therefore, erosion could explain heat flow difference between alpine and hercynian corsica, but in no case the difference between corsica and the maures,  and sardinia.',
#  'a deepseated thermal anomaly.p',
#  'the formation of the provensal basin since the oligocene could have affect the thermal regime of corsica and increase the surface heat flow.',
#  'in order to investigate this possibility, it be necessary to gather heat flow datum for a wide domain than the hercynian outcrop.',
#  'available datum in the proveqal basin ( and and, 1986), in the tyrrhenian sea ( ,  , 1985), in sardinia (, 1982), in italy ( and , 1979), in france (, 1982) as well as datum present in this paper, have be use to draw a contour map of heat flow in the western mediterranean with an automatic method ().',
#  'datum have be preliminarily interpolate use a 250 km window because of the nonuniform datum distribution, and this map therefore only represent the regional trend.',
#  "the hercynian domain be characterize by a low heat flow (around 60 mw m ~ ' ), except in corsica.",
#  "within the  basin, there be a high heat flow anomaly (2 90 mw m') which extend from tuscany to the balearic basin.",
#  'this anomaly be not directly connect to the oceanic domain but more likely correspond to the margin of corsica and sardinia.',
#  'the gulf of lions be characterize by a low heat flow (6070 mw ) which can be explain by the blanket effect of the sediment, which absorb about  of the surface heat flow ( and douaran, 1985).',
#  'a major feature of this map be, therefore, the asymmetric distribution of heat flow within the proveqal basin.',
#  '',
#  " 44' 43' 42' 41' 40' 39' 38' ' 5' 6' 7'   10’ 8.",
#  'heat flow map of the provencal basin.',
#  "isovaluc be mw mm', large point correspond to new 1 measurement (uncorrected (uc) for sedimentation ): dl q,, =  10 mw rn' ( el al.. 1985): a q,,, = 24 mw mm' (. 5): b q,, =  mw m ~' (, 1985).",
#  "' q,,, = 71  mw rn' (, 1985); d q,, = 78 k 13 mw mm' (. 1985); e q,,,  mw m' (, 1985): f q,, 21 mw  ( 5):  q,,, 11 mm' (, 1985).",
#  'other geological and geophysical anomaly also indicate that the two opposite margin of this basin be different.',
#  '  (1984) have show use esp seismic refraction technique that the corsican margin be more extended than the.',
#  ' km. 352 provenqal margin.',
#  ' (1984), use combine result of esp survey and magnetic, propose an asymmetric model of oceanic accretion, with great apreading rate towards provence.',
#  'refraction seismic datum on land ( and , 1985) and gravity datum (. 1976) have show that the continental crust be 30 km thick beneath corsica and sardinia, but thin beneath the northwestern part of corsica to about 25 this support the observation 01  (1984) as do the asymmetric shape of bathymetry (. 1981) and the bouguer anomaly (, 1977), which indicate high extension on the corsican margin.',
#  'these different anomaly indicate an asymmetric structure of the al basin.',
#  '(1985) and and (1986) propose that a deepseated thermal anomaly be locate beneath the corsican  accord to the heat flow map (), this anomaly extend to tuscany and to the balearic basin and could be a residual thermal anomaly relate to the paleoridge.',
#  'this hypothesis could also explain how high relief in corsica (up to 3000 m) can be associate with a normal or thin crust.',
#  'on the other hand, it apparently contradict surfacewave study (, 1980), which predict a thick lithosphere in this area.',
#  'however, the high heat flow in corsica be a consequence of the recent evolution of the western mediterranean.',
#  'model of initial thermal state in previous section, it have be show that the hercynian crust around the provenqal basin, except in corsica, be characterize by a low heat flow (around 60 mw ). which probably correspond to the equilibrium value of the stable hercynian domain.',
#  'it be interesting to study what the possible contribution of the crust and of the mantle to this surface heat flow be, as it be necessary to estimate initial and boundary condition in thermal modelling.',
#  'the present day thermal state of the maure and esterel, where reliable heat flow and heat production datum be available, can be use for this estimate.',
#  'a possible way be to derive the crustal radioactivity distribution from seismic crustal reflector.',
#  ' (1979) suggest that heat production could exponentially depend on the pwave velocity.',
#  "in fact, however, upper crustal rock have a wide range of heat production value ( pw ) but pwave velocity range from only 6.0 to 6.4 km s'.",
#  'on the other hand, rock from the low crust have a narrow range of heat production value (0.10.3 pw  for basic rock and 1.01.5 pw m 3 for acidic rock) whereas pwave velocity range from 6.6 to 7.4 km.',
#  'few seismic datum be available in the maure and estcrel.',
#  'after recq (1970) crustal thicknfss be 2830 km along the coastline of the maure and increase northwards to 3436 km in the calcareous provence.',
#  "recent survey along the ligurian coastline (, 1985) and across the gulf of genova (, 1985) have show that the crust be form by two 15 km thick seismic\x0c(k = 353  the pwave velocity be 6.0 km s ' for the upper layer and 6.6 km s' for the low layer.",
#  'from seismic datum on the margin ( , 1984).',
#  "the continental crust be thin but the two layer structure be  at esp 225 (the close to the maure), the thickness of the stretch crust be 16 km with a pwave velocity of 6.1 km s ' in the 8 km thick upper crust and 7.6 km s' in the 8 km thick low layer.",
#  'this structure be similar to those observe in other part of the hercynian domain of france (, 1980).',
#  'especially in the outer part of the massif central ( and, 1973).',
#  'as there be strong evidence that hercynian structure continue from the massif central to the maures and esterel, information about the deep crust available in the massif central from xenolith carry up by the recent volcanism can be reasonably use in the maures and estcrel.',
#  'average heat production of the upper crust be estimate from surface rock.',
#  'accord to and (1974) this layer be form by a complex consist mainly of metamorphic rock, mix with granite in the upper part.',
#  'the bulk of the granite be difficult to evaluate.',
#  'enrich granite must generally be thin as they be not associate with a negative gravity anomaly or a high heat flow in either the massif central ( and, 1981) or corsica (this study).',
#  "on the other hand, thick granite have a low heat production of 3 pw m '.",
#  'therefore, compare to the metamorphic basement (2 pw mm ")',
#  '.',
#  "such granite contribute an additional 1 mw m' km' or less (due to lateral heat  jaupart. 1983) to surface heat flow.",
#  'for the purpose of this model, the effect of granite can be  heat production of the metamorphic basement, which be relatively uniform from the surface to deep level ( and, 1), be attribute to this upper part of the crust.',
#  "this part contribute about 30. 34 mw m ' to the surface heat flow assume average heat production be 22.25 pw m '.",
#  "in the low crust, average heat production range between 0.3 and 0.8 pw m ' ( and, 1981).",
#  "this correspond to a contribution of 512 mw m ' to the surface heat flow.",
#  "therefore, mantle heat flow beneath the stable hercynian crust range from 14 to 25 mw m'; this result be in agreement with global heat flow study which predict a mantle heat flow beneath stable province of about 2127 mw  (, 1980).",
#  "the average heat production of the crust be 1.1 to 1.5 pw mm'; this result can be compare to geochemical model which predict 0.5 to 1.0 pw  (appendix 1, jaupart and provost, 1985).",
#  'finally.',
#  "the temperature at the moho can be calculate on the basis of the distribution of heat  it range between 375° ( 3 w rn' '') and 450° ( 2.5 w rn'  ') assume a constant conductivity (k) in the crust.",
#  'and',
#  "between 420° 3 w m ' oc') and 500° (k = 2.5 w rn' '') assume that thermal conductivity decrease with increase temperature accord to the model of well (1980).",
#  'conclusion the thermal structure of the western mediterranean be difficult to understand as it represent the interaction of different time dependent process.',
#  'this part of the\x0cin 354 mediterranean sea be still evolve and thermal modelling be necessary to estimate the temperature field and the mantle heat flow, which be the final goal of thermal study in the egt programme.',
#  'this modelling work require the establishment of a reference thermal state in order to estimate initial and boundary condition.',
#  'in this paper, we have study the hercynian area outcrop around the  basin in order to propose a reference thermal state the western anean sea.',
#  'we believe that, except in corsica, these area be presently at thermal equilibrium.',
#  'the maure and esterel, where reliable heat flow and heat production datum be available, have be use to study the thermal state of the crust in an area expect to correspond to stationary condition.',
#  'the surface heat flow be about 60 mw  and the crustal heat contribution, estimate use seismic datum, range from 35 to 45 mw mm 2.',
#  "mantle heat flow be therefore 20  5 mw m ', which be in agreement with general consideration on stable tectonic province.",
#  'the temperature at the moho be 440 i 65°.',
#  'on the other hand, the hercynian batholith of corsica have be affect by the alpine orogeny and subsequent erosion, but also by a deepseated thermal anomaly evidence by different geological and geophysical anomaly.',
#  'the heat flow map for the western mediterranean, result from a compilation of all exist datum, reveal that this deepseated anomaly extend from tuscany to the balearic basin and could correspond to the paleoridge.',
#  'acknowledgement this work be financially support by  .',
#  'it would not have be possible without, who make I in corsica and provide we with valuable comment.',
#  'we also thank, who provide we with gneiss sample from tanneron.',
#  'iieat flow measurement have be make owe to the help of mr. from   des eaux de , mr., mr. from  departementale de i’agriculture de , and mr. and mr. from cogema.',
#  'we thank too and for provide gamma count facility at cfr, gif.',
#  'this paper be critically review by and another anonymous reviewer.',
#  ' critically read the second version of this paper.']

# %%
#Read the file Stopwords
gist_file = open("gist_stopwords.txt", "r")
try:
    content = gist_file.read()
    stopwords = content.split(",")
finally:
    gist_file.close()

prepro2=[]

#Pattern for Remove Citation
pattern1 = regex.compile(r'\(([\w\s\d{}]+)\)'.format(pc))

#Pattern for Apply the Stopwords
pattern2 = r",*(\s*\b(?:{}))\b".format("|".join(stopwords))

#Pattern for unused space first n last
pattern3 = regex.compile(r'((^\s+)(?=.)|(?<=.)(\s+$))')

#Pattern for Apply over-space
pattern4 = regex.compile(r'(\s)(?=\s+)')

#Pattern Additional compiler
pattern_add = regex.compile(r'(\x01|\x0c|\s[a-z]\s|°|^\b(\w\s)|I|)')

#Pattern for combined word and number
for i,j in enumerate(prepro1):
    if bool(regex.search(pattern1,j)) == True:
        if bool(regex.search(r'\d',regex.search(pattern1,j).group())) == True:
            try:
                layer = regex.findall(pattern1,j)
                if type(layer) == tuple:
                    layer = list(filter(None, [i for i in layer]))
                    prepro2.append(re.sub(layer[0],'',j))
                else:
                    prepro2.append(re.sub(regex.findall(pattern1,j)[0],'',j))
            except:
                prepro2.append(j)
        else:
            prepro2.append(j)
    else:
        prepro2.append(j)
    
    #Weird character of ﬂ
    layer = regex.sub(r'ﬂ','fl',prepro2[i])
    
    #With Removing number and punctuations    
    layer = regex.sub(r'(\d|[^A-Za-zöäüéíáúóðèñæýßôþ\s]|[^\P{P}]+)',' ',re.sub(pattern2,'', layer)) 
    
    #With Removing unused space first n las
    layer = regex.sub(pattern3,'',layer)
    
    #With Removing over-space
    layer = regex.sub(pattern4,'',layer)
    
    #With Removing Additional compiler
    prepro2[i] = regex.sub(pattern_add,'',layer)

#Final filtering for less than three words sentence
d = lambda y : None if len(y.split(' '))<=4 else y
prepro2 = list(filter(d, prepro2))

# %%
prepro2
# Out:
# ['introduction framework european geotraverse egt geothermal study undertake order evaluate surface heat flow temperature field lithosphere',
#  'area southern segment egt belong western mediterranean domain alpine structure young oceanic crust exist',
#  'context heat transfer time dependent evaluation temperature field require thermal modelling transient process uplift erosion rifting oceanic accretion sedimentation',
#  'exist area western mediterranean hercynian basement outcrop reference thermal state modelling work',
#  'paper focus thermal regime elsevier science publishers',
#  'location basin hercynian basement western mediterranean',
#  'shaded area alpine erogenic zone',
#  'hercynian outer provenqal basin northwest mediterranean maures esterel southern france corsica sardinia',
#  'basin form oligocene rifting continental lithosphere oceanic accretion shift corsicasardinia block france',
#  'basin continental crust progressively crustal thickness normal maures recq corsica sardinia',
#  'area affect alpine orogeny continental rifting',
#  'thermal regime hercynian crust discuss heat flow heat production datum mauresesterel corsica',
#  'fission track datum erosion process perturb temperature field',
#  'contour map heat flow western mediterranean result compilation exist datum final discussion paper',
#  'model stable hercynian crust base presentday thermal regime maures esterel',
#  'heat flow dpita corsica datum publish gather paper new measurement',
#  'temperature survey carry thermistor probe relative accuracy',
#  'temperature profile correct account topographic accord classical procedure',
#  'conductivity measurement watersaturated halfcore transient method determination',
#  'flow corsica datum shallow borehole drill water resource',
#  'temperature profile display curvature explain case thermal conductivity contrast partinello water circulation casavecchie lama luri',
#  'borehole evidence water circulation explain curvature',
#  'reliable datum variation thermal gradient borehole exceed',
#  'borehole hercynian basement standard deviation average gradient order magnitude',
#  'temoerature thermal gradient depth lama',
#  'temperature profile versus depth borehole log corsica',
#  'temperature represent arbitrary scale division represent degree',
#  'upper profile represent actual temperature depth thermal log',
#  'datum consistent shallow depth uncertainty individual thermal gradient',
#  'borehole cog conductivity estimate measurement surface sample',
#  'average mw datum mw borehole deep',
#  'representative surface heat flow corsica local heat flow datum corsica locality long',
#  'depth conducthermal heat flow tithology range tivity gradient',
#  'north alpine corsica average heat flow mw luri luri south alpine corsica average heat flow mw casavecchie ghisonaccia average heat flow mw novella lama lama osani area average heat flow mw partinelto osani osani osani ajuccio area average mw alata alata truva south ajaccio area average heat flow mw face urbalacone piattone sartene bronco mw mm schist schist loo schist sandstone flysch spilite granite rhyolite granite granite granite carbon schist gram granite gabbro granite granite granite granite granite average heat flow calculate borehofes deep',
#  'qo qo osani osani qo',
#  'estimate heat flow prownce corsica',
#  'ixge dot represent heat flow measurement',
#  'hercynian granite tenda alpine corsica',
#  'alpine corsica mesozoic unit hercynian unit tenda',
#  'ajaccio area characterize low heat flow',
#  'southern france new datum maures',
#  'temperature profile regular corsica borehole deep',
#  'borehole esterel castelli gratadis drill mining permian rhyolite',
#  'heat flow borehole mw mm correspond reliable datum accord egt criterion depth great conductivity measurement core borehole borehole free water circulation',
#  'borehole maure ramatuelle cogolin shallow conductivity estimate surface sample',
#  'heat flow mw temperature arbitrary scale gratadls kml depth casteill',
#  'temperature profile versus depth borehole log maures estcrel',
#  'temperature represent arbitrary scale division represent degree',
#  'upper profile represent actual temperature depth thermal log',
#  'cogolin gneish vtcinity maures clue heat flow datum mauresestcrel locality long',
#  'depth conducthermal heat flow lithology range tivity gradient mm fzw mw mm maure ramatuelle uchist rel castelli pelite rhyolite cratadis rhyolite dolomite gardanne limestone carte oil datum uc uncorrected correct topographic',
#  'estimate heat flow maure esttrel',
#  'diorite leucogranite cordieritegranite granitegneiss metamorphic schist gneiss anatectic gneiss',
#  'heat production datum surface ld consistent esterel',
#  'measurement vicinity hercynian basement provence confirm maures esterel',
#  'datum correspond oil exploration borehole bht measurement correct mud circulation',
#  'average area mw heat flow close average european mw stable hercynian province europe',
#  'continent thermal regime crust closely nature distribution heat source',
#  'stable area linear relationship exist surface heat flow surface heat production',
#  'study surface heat production order evaluate contribution heat source surface heat flow',
#  'heat production late uranium thorium potassium concentration accord work',
#  'work new measurement maure esterel compare previous result corsica',
#  'hercynian basement outcropping maure esttrel form metamorphic rock basement outcropping corsica form hercynian granite',
#  'mauresestcrel province characterize paleozoic metamorphic unit maures southwestern position tanneron northeastern position',
#  'massif separate permian volcanic sedimentary unit estcrel',
#  'petrographic feature metamorphic basement study',
#  'western maures form rnicaschist twomica gneis intrude cambrian granitegneiss',
#  'eastern maures tanneron massif form metamorphic rock anatectic gneiss',
#  'metamorphic domain separate fault hercynian granite plan tour situate',
#  'permian rhyolite correspond esttrel massif sensu stricto',
#  'granitic equivalent rhyolite xenolith oligocene esttrellite rnicrodiorite',
#  'corsica classically divide alpine corsica western island correspond abduction mesozoic unit middle cretaceous hercynian corsica western southern form hercynian permian granitic basement',
#  'hercynian granite belong magmatic association talkalkaline subalkaline type',
#  'permian granite represent anorogenic type associate rhyolite northern island southern',
#  'level erosion increase esterel rhyolite outcrop granite exist deep level north corsica rhyolite granite outcrop finally',
#  'south corsica granite exist bonnin',
#  'concentration determine epithermal neutron activation analysis enaa compare sample',
#  'measurement gammaray spectrometry grs difference generally low',
#  'sample representative geological formation result cenozoic mesozoic kiiz permian',
#  'stephanian hercyncan granite paleozoic basement fault mediterranean sea',
#  'geological map maures esterel location sample analyze heat production datum maures ppm wv method standard',
#  'enaa grs enaa enaa enaa enaa enaa enaa enaa grs enaa enaa enaa enaa enaa gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn enaa enaa gsn gsn granite gneiss average gc gc granite average average verage schist average average petrologic type',
#  'metamorphic rock classify metasedimentary rock gneiss anatectic gneiss granitegneiss',
#  'radiogenic content ficantly change grade metamorphism metasedimentary rock average heat production pw',
#  'graniteegneiss high average content thzk kfu diorite rhyolite continue ppm thko ppm kkak affj pw method standard average gc gc gc average gc gcx enaa enaa enaa enaa enaa enaa enaa enaa enaa enaa enaa gamma ray enaa epithermal neutron activation analysis',
#  'gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn ufo gnrlss annrectrc gnr enaa enaa enaa enaa enaa grs enaa enaa grs high heat production pw',
#  'work massif central france range',
#  'surface anatectic gneiss massif central heat production pw material erupt depth volcanism heat production pw',
#  'granite maures esterel close leucogranite type massif central low characteristic granite crustal origin',
#  'sensu massif esttrel form permian rhyolite',
#  'finally diorite low heat production pw represent small outcropping volume',
#  'field grain number dose neutron track cmz track induce apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite',
#  'track track fossit mineral sample apatite fission track datum maures estcrel corsica apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite natural state laboratory annealing hour laboratory annealing',
#  'hour laboratory annealing number track count',
#  'relative standard error inducedtrack count apatite',
#  'count observer fish canyon age standard count time sample',
#  'error calculate poisson relative standard error',
#  'previous heat production datum cock datum publish interesting recall principal result order discuss heat flow datum',
#  'talcalkaline granite represent threethird outcrop hercynian corsica',
#  'granite massif central high average uranium content ppm ratio consistent expect granite',
#  'granite corsica deplete weathering process',
#  'leucocratic granite represent evolve member talkalkaline series',
#  'enrich uranium ppm high heat production pw mm',
#  'subalkali granite enrich uranium ppm thorium ppm',
#  'close average granite massif central',
#  'finally heat production permian anorogenic granite vary pw mj',
#  'apatite fission track datum fission track represent daughter product disintegration dating method',
#  'special feature method closure sensitive temperature',
#  'closure temperature characteristic mineral apatite',
#  'excellent indicator paleogeothermal condition apatite age represent cooling loo correspond depth',
#  'study set datum measurement corsica publish zircon new apatite age maure estcrel simultaneously determine international standard fish canyon tuff complete previous datum',
#  'result corsica draw preoligocene position',
#  'alpine corsica characterize eoceneoligocene apatite age northwest island maure estcrel cretaceous age',
#  'interpret fission track datum eastern corsica assume differential erosion subsequent wellknown eocene compressional stage erosion rate high mm yri',
#  'hand western corsica maure estcrel region affect cretaceous phase alpine orogeny apatite age',
#  'erosional process occur middle cretaceous oligocene rifting',
#  'geological evidence distention arearole heat production',
#  'apatite fission track datum maure estcrel corsica',
#  'provenqal coastlme presentday position corsica heen reptace supposed preoligocene position',
#  'alpine corsica thermal regime ilercynian crust onset oligocene rifting equilibrium',
#  'dlscussion result previous surface heat flow low maures estcrel mw mz corsica mw',
#  'previous work sardinia heat flow generally low mw quaternary graben campidano mw',
#  'explain origin high corsica order understand thermal structure basin',
#  'heat production granite corsica wide range pw pw mj',
#  'low boundary increase pw granite massif central corsican talkalkaline granite deplete uranium',
#  'difference surface heat flow explain talkalkaline granite enrich granite corsica relative metamorphic basement mauresesterel',
#  'explanation problematic surface granite associate heat flow anomaly sardinia granite exist deep level maure esterel',
#  'radiogenic heat contribution crust area roughly heat flow anomaly corsica origin',
#  'role erosion corsica affect alpine orogeny major middle cretaceous phase correspond abduction process eocene phase correspond main tectonic compression',
#  'attempt derive erosion rate combine fission track datum zircon apatite thermal modelling',
#  'maximum erosion rate eocene phase observe alpine corsica mm',
#  'yield maximum heat flow anomaly mw erosion rate prevail central western corsica increase surface heat flow expect',
#  'erosion explain heat flow difference alpine hercynian corsica case difference corsica maures sardinia',
#  'formation provensal basin oligocene affect thermal regime corsica increase surface heat flow',
#  'order investigate possibility gather heat flow datum wide domain hercynian outcrop',
#  'datum proveqal basin tyrrhenian sea sardinia italy france datum paper draw contour map heat flow western mediterranean automatic method',
#  'datum preliminarily interpolate window nonuniform datum distribution map represent regional trend',
#  'hercynian domain characterize low heat flow corsica',
#  'basin high heat flow anomaly extend tuscany balearic basin',
#  'anomaly directly connect oceanic domain correspond margin corsica sardinia',
#  'gulf lions characterize low heat flow mw explain blanket sediment absorb surface heat flow douaran',
#  'major feature map asymmetric distribution heat flow proveqal basin',
#  'heat flow map provencal basin',
#  'isovaluc mw mm large point correspond new measurement uncorrected uc sedimentation mw mw mm mw',
#  'mw mw mm mw mw mm',
#  'geological geophysical anomaly opposite margin basin',
#  'esp seismic refraction technique corsican margin extended',
#  'combine result esp survey magnetic propose asymmetric model oceanic accretion great apreading rate provence',
#  'refraction seismic datum land gravity datum continental crust thick beneath corsica sardinia beneath northwestern corsica support observation asymmetric shape bathymetry bouguer anomaly high extension corsican margin',
#  'propose deepseated thermal anomaly locate beneath corsican accord heat flow map anomaly extend tuscany balearic basin residual thermal anomaly relate paleoridge',
#  'hypothesis explain high relief corsica associate normal crust',
#  'hand contradict surfacewave study predict thick lithosphere area',
#  'high heat flow corsica consequence evolution western mediterranean',
#  'model initial thermal state previous hercynian crust provenqal basin corsica characterize low heat flow correspond equilibrium stable hercynian domain',
#  'interesting study contribution crust mantle surface heat flow estimate initial boundary condition thermal modelling',
#  'day thermal state maure esterel reliable heat flow heat production datum estimate',
#  'derive crustal radioactivity distribution seismic crustal reflector',
#  'heat production exponentially depend pwave velocity',
#  'fact upper crustal rock wide range heat production pw pwave velocity range',
#  'hand rock low crust narrow range heat production pwave velocity range',
#  'recq crustal thicknfss coastline maure increase northwards calcareous provence',
#  'survey ligurian coastline gulf genova crust form thick seismic pwave velocity upper layer low layer',
#  'continental crust layer structure esp close maure thickness stretch crust pwave velocity thick upper crust thick low layer',
#  'structure observe hercynian domain france',
#  'strong evidence hercynian structure continue massif central maures esterel deep crust massif central xenolith carry volcanism maures estcrel',
#  'average heat production upper crust estimate surface rock',
#  'accord layer form complex consist metamorphic rock mix granite upper',
#  'enrich granite generally associate negative gravity anomaly high heat flow massif central corsica study',
#  'hand thick granite low heat production pw',
#  'granite contribute additional mw surface heat flow',
#  'purpose model granite heat production metamorphic basement uniform surface deep level attribute upper crust',
#  'contribute mw surface heat flow assume average heat production pw',
#  'low crust average heat production range pw',
#  'correspond contribution mw surface heat flow',
#  'mantle heat flow beneath stable hercynian crust range mw result agreement global heat flow study predict mantle heat flow beneath stable province mw',
#  'average heat production crust pw mm result compare geochemical model predict pw',
#  'temperature moho calculate basis distribution heat range assume constant conductivity crust',
#  'assume thermal conductivity decrease increase temperature accord model',
#  'conclusion thermal structure western mediterranean difficult understand represent interaction time dependent process',
#  'mediterranean sea evolve thermal modelling estimate temperature field mantle heat flow final goal thermal study egt programme',
#  'modelling work require establishment reference thermal state order estimate initial boundary condition',
#  'paper study hercynian area outcrop basin order propose reference thermal state western anean sea',
#  'corsica area presently thermal equilibrium',
#  'maure esterel reliable heat flow heat production datum study thermal state crust area expect correspond stationary condition',
#  'surface heat flow mw crustal heat contribution estimate seismic datum range mw mm',
#  'mantle heat flow mw agreement general consideration stable tectonic province',
#  'hand hercynian batholith corsica affect alpine orogeny subsequent erosion deepseated thermal anomaly evidence geological geophysical anomaly',
#  'heat flow map western mediterranean result compilation exist datum reveal deepseated anomaly extend tuscany balearic basin correspond paleoridge',
#  'iieat flow measurement owe des eaux departementale agriculture cogema',
#  'provide gamma count facility cfr gif',
#  'paper critically review anonymous reviewer']

# %% [markdown]
# ## NER Library

# %%
#Auto Read entities
dict_entities={}
path='C:/Users/Ryan Bobby A/Documents/RWTH AACHEN/KULIAH/THESIS_BISMILLAH/Thesis Progress/list_entities/'
for filename in glob.glob(os.path.join(path, '*.txt')):
    gist_file = open(filename, "r")
    try:
        content = gist_file.read().lower()
        dict_entities[re.search(r'(\w+).txt$',filename).group(1)] = list(filter(None, content.split("\n")))
    finally:
        gist_file.close()

# %%
#Ready for NLP NER
ready_ner = {'text':[],'tag':[],'entity':[]}
for i in prepro2:
    for j in dict_entities:
        pattern = r"(\.*\b(?:{}))\b".format("|".join(dict_entities[j]))
        if bool(re.search(pattern, i)) == True:
            for k in re.findall(pattern,i):
                if type(k) == tuple:
                    k = list(filter(None,[i for i in k]))
                    for m in k:
                        ready_ner['text'].append(i)
                        ready_ner['tag'].append(m)
                        ready_ner['entity'].append(re.search(r'list_(\w+)$',j).group(1))
                else:
                    ready_ner['text'].append(i)
                    ready_ner['tag'].append(k)
                    ready_ner['entity'].append(re.search(r'list_(\w+)$',j).group(1))
        else:
            pass

# %%
ready_ner['text']
# Out:
# ['introduction framework european geotraverse egt geothermal study undertake order evaluate surface heat flow temperature field lithosphere',
#  'introduction framework european geotraverse egt geothermal study undertake order evaluate surface heat flow temperature field lithosphere',
#  'context heat transfer time dependent evaluation temperature field require thermal modelling transient process uplift erosion rifting oceanic accretion sedimentation',
#  'context heat transfer time dependent evaluation temperature field require thermal modelling transient process uplift erosion rifting oceanic accretion sedimentation',
#  'context heat transfer time dependent evaluation temperature field require thermal modelling transient process uplift erosion rifting oceanic accretion sedimentation',
#  'exist area western mediterranean hercynian basement outcrop reference thermal state modelling work',
#  'paper focus thermal regime elsevier science publishers',
#  'hercynian outer provenqal basin northwest mediterranean maures esterel southern france corsica sardinia',
#  'hercynian outer provenqal basin northwest mediterranean maures esterel southern france corsica sardinia',
#  'hercynian outer provenqal basin northwest mediterranean maures esterel southern france corsica sardinia',
#  'hercynian outer provenqal basin northwest mediterranean maures esterel southern france corsica sardinia',
#  'basin form oligocene rifting continental lithosphere oceanic accretion shift corsicasardinia block france',
#  'basin form oligocene rifting continental lithosphere oceanic accretion shift corsicasardinia block france',
#  'basin form oligocene rifting continental lithosphere oceanic accretion shift corsicasardinia block france',
#  'basin continental crust progressively crustal thickness normal maures recq corsica sardinia',
#  'basin continental crust progressively crustal thickness normal maures recq corsica sardinia',
#  'basin continental crust progressively crustal thickness normal maures recq corsica sardinia',
#  'thermal regime hercynian crust discuss heat flow heat production datum mauresesterel corsica',
#  'thermal regime hercynian crust discuss heat flow heat production datum mauresesterel corsica',
#  'thermal regime hercynian crust discuss heat flow heat production datum mauresesterel corsica',
#  'thermal regime hercynian crust discuss heat flow heat production datum mauresesterel corsica',
#  'thermal regime hercynian crust discuss heat flow heat production datum mauresesterel corsica',
#  'fission track datum erosion process perturb temperature field',
#  'contour map heat flow western mediterranean result compilation exist datum final discussion paper',
#  'model stable hercynian crust base presentday thermal regime maures esterel',
#  'heat flow dpita corsica datum publish gather paper new measurement',
#  'heat flow dpita corsica datum publish gather paper new measurement',
#  'heat flow dpita corsica datum publish gather paper new measurement',
#  'temperature survey carry thermistor probe relative accuracy',
#  'temperature profile correct account topographic accord classical procedure',
#  'conductivity measurement watersaturated halfcore transient method determination',
#  'flow corsica datum shallow borehole drill water resource',
#  'flow corsica datum shallow borehole drill water resource',
#  'temperature profile display curvature explain case thermal conductivity contrast partinello water circulation casavecchie lama luri',
#  'temperature profile display curvature explain case thermal conductivity contrast partinello water circulation casavecchie lama luri',
#  'reliable datum variation thermal gradient borehole exceed',
#  'borehole hercynian basement standard deviation average gradient order magnitude',
#  'temoerature thermal gradient depth lama',
#  'temoerature thermal gradient depth lama',
#  'temperature profile versus depth borehole log corsica',
#  'temperature profile versus depth borehole log corsica',
#  'temperature profile versus depth borehole log corsica',
#  'temperature profile versus depth borehole log corsica',
#  'temperature represent arbitrary scale division represent degree',
#  'upper profile represent actual temperature depth thermal log',
#  'upper profile represent actual temperature depth thermal log',
#  'upper profile represent actual temperature depth thermal log',
#  'datum consistent shallow depth uncertainty individual thermal gradient',
#  'datum consistent shallow depth uncertainty individual thermal gradient',
#  'datum consistent shallow depth uncertainty individual thermal gradient',
#  'borehole cog conductivity estimate measurement surface sample',
#  'representative surface heat flow corsica local heat flow datum corsica locality long',
#  'representative surface heat flow corsica local heat flow datum corsica locality long',
#  'representative surface heat flow corsica local heat flow datum corsica locality long',
#  'representative surface heat flow corsica local heat flow datum corsica locality long',
#  'representative surface heat flow corsica local heat flow datum corsica locality long',
#  'representative surface heat flow corsica local heat flow datum corsica locality long',
#  'depth conducthermal heat flow tithology range tivity gradient',
#  'depth conducthermal heat flow tithology range tivity gradient',
#  'north alpine corsica average heat flow mw luri luri south alpine corsica average heat flow mw casavecchie ghisonaccia average heat flow mw novella lama lama osani area average heat flow mw partinelto osani osani osani ajuccio area average mw alata alata truva south ajaccio area average heat flow mw face urbalacone piattone sartene bronco mw mm schist schist loo schist sandstone flysch spilite granite rhyolite granite granite granite carbon schist gram granite gabbro granite granite granite granite granite average heat flow calculate borehofes deep',
#  'north alpine corsica average heat flow mw luri luri south alpine corsica average heat flow mw casavecchie ghisonaccia average heat flow mw novella lama lama osani area average heat flow mw partinelto osani osani osani ajuccio area average mw alata alata truva south ajaccio area average heat flow mw face urbalacone piattone sartene bronco mw mm schist schist loo schist sandstone flysch spilite granite rhyolite granite granite granite carbon schist gram granite gabbro granite granite granite granite granite average heat flow calculate borehofes deep',
#  'north alpine corsica average heat flow mw luri luri south alpine corsica average heat flow mw casavecchie ghisonaccia average heat flow mw novella lama lama osani area average heat flow mw partinelto osani osani osani ajuccio area average mw alata alata truva south ajaccio area average heat flow mw face urbalacone piattone sartene bronco mw mm schist schist loo schist sandstone flysch spilite granite rhyolite granite granite granite carbon schist gram granite gabbro granite granite granite granite granite average heat flow calculate borehofes deep',
#  'north alpine corsica average heat flow mw luri luri south alpine corsica average heat flow mw casavecchie ghisonaccia average heat flow mw novella lama lama osani area average heat flow mw partinelto osani osani osani ajuccio area average mw alata alata truva south ajaccio area average heat flow mw face urbalacone piattone sartene bronco mw mm schist schist loo schist sandstone flysch spilite granite rhyolite granite granite granite carbon schist gram granite gabbro granite granite granite granite granite average heat flow calculate borehofes deep',
#  'north alpine corsica average heat flow mw luri luri south alpine corsica average heat flow mw casavecchie ghisonaccia average heat flow mw novella lama lama osani area average heat flow mw partinelto osani osani osani ajuccio area average mw alata alata truva south ajaccio area average heat flow mw face urbalacone piattone sartene bronco mw mm schist schist loo schist sandstone flysch spilite granite rhyolite granite granite granite carbon schist gram granite gabbro granite granite granite granite granite average heat flow calculate borehofes deep',
#  'north alpine corsica average heat flow mw luri luri south alpine corsica average heat flow mw casavecchie ghisonaccia average heat flow mw novella lama lama osani area average heat flow mw partinelto osani osani osani ajuccio area average mw alata alata truva south ajaccio area average heat flow mw face urbalacone piattone sartene bronco mw mm schist schist loo schist sandstone flysch spilite granite rhyolite granite granite granite carbon schist gram granite gabbro granite granite granite granite granite average heat flow calculate borehofes deep',
#  'north alpine corsica average heat flow mw luri luri south alpine corsica average heat flow mw casavecchie ghisonaccia average heat flow mw novella lama lama osani area average heat flow mw partinelto osani osani osani ajuccio area average mw alata alata truva south ajaccio area average heat flow mw face urbalacone piattone sartene bronco mw mm schist schist loo schist sandstone flysch spilite granite rhyolite granite granite granite carbon schist gram granite gabbro granite granite granite granite granite average heat flow calculate borehofes deep',
#  'north alpine corsica average heat flow mw luri luri south alpine corsica average heat flow mw casavecchie ghisonaccia average heat flow mw novella lama lama osani area average heat flow mw partinelto osani osani osani ajuccio area average mw alata alata truva south ajaccio area average heat flow mw face urbalacone piattone sartene bronco mw mm schist schist loo schist sandstone flysch spilite granite rhyolite granite granite granite carbon schist gram granite gabbro granite granite granite granite granite average heat flow calculate borehofes deep',
#  'north alpine corsica average heat flow mw luri luri south alpine corsica average heat flow mw casavecchie ghisonaccia average heat flow mw novella lama lama osani area average heat flow mw partinelto osani osani osani ajuccio area average mw alata alata truva south ajaccio area average heat flow mw face urbalacone piattone sartene bronco mw mm schist schist loo schist sandstone flysch spilite granite rhyolite granite granite granite carbon schist gram granite gabbro granite granite granite granite granite average heat flow calculate borehofes deep',
#  'north alpine corsica average heat flow mw luri luri south alpine corsica average heat flow mw casavecchie ghisonaccia average heat flow mw novella lama lama osani area average heat flow mw partinelto osani osani osani ajuccio area average mw alata alata truva south ajaccio area average heat flow mw face urbalacone piattone sartene bronco mw mm schist schist loo schist sandstone flysch spilite granite rhyolite granite granite granite carbon schist gram granite gabbro granite granite granite granite granite average heat flow calculate borehofes deep',
#  'north alpine corsica average heat flow mw luri luri south alpine corsica average heat flow mw casavecchie ghisonaccia average heat flow mw novella lama lama osani area average heat flow mw partinelto osani osani osani ajuccio area average mw alata alata truva south ajaccio area average heat flow mw face urbalacone piattone sartene bronco mw mm schist schist loo schist sandstone flysch spilite granite rhyolite granite granite granite carbon schist gram granite gabbro granite granite granite granite granite average heat flow calculate borehofes deep',
#  'north alpine corsica average heat flow mw luri luri south alpine corsica average heat flow mw casavecchie ghisonaccia average heat flow mw novella lama lama osani area average heat flow mw partinelto osani osani osani ajuccio area average mw alata alata truva south ajaccio area average heat flow mw face urbalacone piattone sartene bronco mw mm schist schist loo schist sandstone flysch spilite granite rhyolite granite granite granite carbon schist gram granite gabbro granite granite granite granite granite average heat flow calculate borehofes deep',
#  'north alpine corsica average heat flow mw luri luri south alpine corsica average heat flow mw casavecchie ghisonaccia average heat flow mw novella lama lama osani area average heat flow mw partinelto osani osani osani ajuccio area average mw alata alata truva south ajaccio area average heat flow mw face urbalacone piattone sartene bronco mw mm schist schist loo schist sandstone flysch spilite granite rhyolite granite granite granite carbon schist gram granite gabbro granite granite granite granite granite average heat flow calculate borehofes deep',
#  'north alpine corsica average heat flow mw luri luri south alpine corsica average heat flow mw casavecchie ghisonaccia average heat flow mw novella lama lama osani area average heat flow mw partinelto osani osani osani ajuccio area average mw alata alata truva south ajaccio area average heat flow mw face urbalacone piattone sartene bronco mw mm schist schist loo schist sandstone flysch spilite granite rhyolite granite granite granite carbon schist gram granite gabbro granite granite granite granite granite average heat flow calculate borehofes deep',
#  'north alpine corsica average heat flow mw luri luri south alpine corsica average heat flow mw casavecchie ghisonaccia average heat flow mw novella lama lama osani area average heat flow mw partinelto osani osani osani ajuccio area average mw alata alata truva south ajaccio area average heat flow mw face urbalacone piattone sartene bronco mw mm schist schist loo schist sandstone flysch spilite granite rhyolite granite granite granite carbon schist gram granite gabbro granite granite granite granite granite average heat flow calculate borehofes deep',
#  'north alpine corsica average heat flow mw luri luri south alpine corsica average heat flow mw casavecchie ghisonaccia average heat flow mw novella lama lama osani area average heat flow mw partinelto osani osani osani ajuccio area average mw alata alata truva south ajaccio area average heat flow mw face urbalacone piattone sartene bronco mw mm schist schist loo schist sandstone flysch spilite granite rhyolite granite granite granite carbon schist gram granite gabbro granite granite granite granite granite average heat flow calculate borehofes deep',
#  'north alpine corsica average heat flow mw luri luri south alpine corsica average heat flow mw casavecchie ghisonaccia average heat flow mw novella lama lama osani area average heat flow mw partinelto osani osani osani ajuccio area average mw alata alata truva south ajaccio area average heat flow mw face urbalacone piattone sartene bronco mw mm schist schist loo schist sandstone flysch spilite granite rhyolite granite granite granite carbon schist gram granite gabbro granite granite granite granite granite average heat flow calculate borehofes deep',
#  'north alpine corsica average heat flow mw luri luri south alpine corsica average heat flow mw casavecchie ghisonaccia average heat flow mw novella lama lama osani area average heat flow mw partinelto osani osani osani ajuccio area average mw alata alata truva south ajaccio area average heat flow mw face urbalacone piattone sartene bronco mw mm schist schist loo schist sandstone flysch spilite granite rhyolite granite granite granite carbon schist gram granite gabbro granite granite granite granite granite average heat flow calculate borehofes deep',
#  'north alpine corsica average heat flow mw luri luri south alpine corsica average heat flow mw casavecchie ghisonaccia average heat flow mw novella lama lama osani area average heat flow mw partinelto osani osani osani ajuccio area average mw alata alata truva south ajaccio area average heat flow mw face urbalacone piattone sartene bronco mw mm schist schist loo schist sandstone flysch spilite granite rhyolite granite granite granite carbon schist gram granite gabbro granite granite granite granite granite average heat flow calculate borehofes deep',
#  'north alpine corsica average heat flow mw luri luri south alpine corsica average heat flow mw casavecchie ghisonaccia average heat flow mw novella lama lama osani area average heat flow mw partinelto osani osani osani ajuccio area average mw alata alata truva south ajaccio area average heat flow mw face urbalacone piattone sartene bronco mw mm schist schist loo schist sandstone flysch spilite granite rhyolite granite granite granite carbon schist gram granite gabbro granite granite granite granite granite average heat flow calculate borehofes deep',
#  'north alpine corsica average heat flow mw luri luri south alpine corsica average heat flow mw casavecchie ghisonaccia average heat flow mw novella lama lama osani area average heat flow mw partinelto osani osani osani ajuccio area average mw alata alata truva south ajaccio area average heat flow mw face urbalacone piattone sartene bronco mw mm schist schist loo schist sandstone flysch spilite granite rhyolite granite granite granite carbon schist gram granite gabbro granite granite granite granite granite average heat flow calculate borehofes deep',
#  'north alpine corsica average heat flow mw luri luri south alpine corsica average heat flow mw casavecchie ghisonaccia average heat flow mw novella lama lama osani area average heat flow mw partinelto osani osani osani ajuccio area average mw alata alata truva south ajaccio area average heat flow mw face urbalacone piattone sartene bronco mw mm schist schist loo schist sandstone flysch spilite granite rhyolite granite granite granite carbon schist gram granite gabbro granite granite granite granite granite average heat flow calculate borehofes deep',
#  'north alpine corsica average heat flow mw luri luri south alpine corsica average heat flow mw casavecchie ghisonaccia average heat flow mw novella lama lama osani area average heat flow mw partinelto osani osani osani ajuccio area average mw alata alata truva south ajaccio area average heat flow mw face urbalacone piattone sartene bronco mw mm schist schist loo schist sandstone flysch spilite granite rhyolite granite granite granite carbon schist gram granite gabbro granite granite granite granite granite average heat flow calculate borehofes deep',
#  'north alpine corsica average heat flow mw luri luri south alpine corsica average heat flow mw casavecchie ghisonaccia average heat flow mw novella lama lama osani area average heat flow mw partinelto osani osani osani ajuccio area average mw alata alata truva south ajaccio area average heat flow mw face urbalacone piattone sartene bronco mw mm schist schist loo schist sandstone flysch spilite granite rhyolite granite granite granite carbon schist gram granite gabbro granite granite granite granite granite average heat flow calculate borehofes deep',
#  'north alpine corsica average heat flow mw luri luri south alpine corsica average heat flow mw casavecchie ghisonaccia average heat flow mw novella lama lama osani area average heat flow mw partinelto osani osani osani ajuccio area average mw alata alata truva south ajaccio area average heat flow mw face urbalacone piattone sartene bronco mw mm schist schist loo schist sandstone flysch spilite granite rhyolite granite granite granite carbon schist gram granite gabbro granite granite granite granite granite average heat flow calculate borehofes deep',
#  'north alpine corsica average heat flow mw luri luri south alpine corsica average heat flow mw casavecchie ghisonaccia average heat flow mw novella lama lama osani area average heat flow mw partinelto osani osani osani ajuccio area average mw alata alata truva south ajaccio area average heat flow mw face urbalacone piattone sartene bronco mw mm schist schist loo schist sandstone flysch spilite granite rhyolite granite granite granite carbon schist gram granite gabbro granite granite granite granite granite average heat flow calculate borehofes deep',
#  'north alpine corsica average heat flow mw luri luri south alpine corsica average heat flow mw casavecchie ghisonaccia average heat flow mw novella lama lama osani area average heat flow mw partinelto osani osani osani ajuccio area average mw alata alata truva south ajaccio area average heat flow mw face urbalacone piattone sartene bronco mw mm schist schist loo schist sandstone flysch spilite granite rhyolite granite granite granite carbon schist gram granite gabbro granite granite granite granite granite average heat flow calculate borehofes deep',
#  'estimate heat flow prownce corsica',
#  'estimate heat flow prownce corsica',
#  'estimate heat flow prownce corsica',
#  'ixge dot represent heat flow measurement',
#  'hercynian granite tenda alpine corsica',
#  'hercynian granite tenda alpine corsica',
#  'hercynian granite tenda alpine corsica',
#  'alpine corsica mesozoic unit hercynian unit tenda',
#  'alpine corsica mesozoic unit hercynian unit tenda',
#  'alpine corsica mesozoic unit hercynian unit tenda',
#  'alpine corsica mesozoic unit hercynian unit tenda',
#  'ajaccio area characterize low heat flow',
#  'southern france new datum maures',
#  'southern france new datum maures',
#  'temperature profile regular corsica borehole deep',
#  'temperature profile regular corsica borehole deep',
#  'temperature profile regular corsica borehole deep',
#  'borehole esterel castelli gratadis drill mining permian rhyolite',
#  'borehole esterel castelli gratadis drill mining permian rhyolite',
#  'heat flow borehole mw mm correspond reliable datum accord egt criterion depth great conductivity measurement core borehole borehole free water circulation',
#  'heat flow borehole mw mm correspond reliable datum accord egt criterion depth great conductivity measurement core borehole borehole free water circulation',
#  'heat flow borehole mw mm correspond reliable datum accord egt criterion depth great conductivity measurement core borehole borehole free water circulation',
#  'borehole maure ramatuelle cogolin shallow conductivity estimate surface sample',
#  'heat flow mw temperature arbitrary scale gratadls kml depth casteill',
#  'heat flow mw temperature arbitrary scale gratadls kml depth casteill',
#  'heat flow mw temperature arbitrary scale gratadls kml depth casteill',
#  'temperature profile versus depth borehole log maures estcrel',
#  'temperature profile versus depth borehole log maures estcrel',
#  'temperature represent arbitrary scale division represent degree',
#  'upper profile represent actual temperature depth thermal log',
#  'upper profile represent actual temperature depth thermal log',
#  'upper profile represent actual temperature depth thermal log',
#  'cogolin gneish vtcinity maures clue heat flow datum mauresestcrel locality long',
#  'depth conducthermal heat flow lithology range tivity gradient mm fzw mw mm maure ramatuelle uchist rel castelli pelite rhyolite cratadis rhyolite dolomite gardanne limestone carte oil datum uc uncorrected correct topographic',
#  'depth conducthermal heat flow lithology range tivity gradient mm fzw mw mm maure ramatuelle uchist rel castelli pelite rhyolite cratadis rhyolite dolomite gardanne limestone carte oil datum uc uncorrected correct topographic',
#  'depth conducthermal heat flow lithology range tivity gradient mm fzw mw mm maure ramatuelle uchist rel castelli pelite rhyolite cratadis rhyolite dolomite gardanne limestone carte oil datum uc uncorrected correct topographic',
#  'depth conducthermal heat flow lithology range tivity gradient mm fzw mw mm maure ramatuelle uchist rel castelli pelite rhyolite cratadis rhyolite dolomite gardanne limestone carte oil datum uc uncorrected correct topographic',
#  'depth conducthermal heat flow lithology range tivity gradient mm fzw mw mm maure ramatuelle uchist rel castelli pelite rhyolite cratadis rhyolite dolomite gardanne limestone carte oil datum uc uncorrected correct topographic',
#  'depth conducthermal heat flow lithology range tivity gradient mm fzw mw mm maure ramatuelle uchist rel castelli pelite rhyolite cratadis rhyolite dolomite gardanne limestone carte oil datum uc uncorrected correct topographic',
#  'depth conducthermal heat flow lithology range tivity gradient mm fzw mw mm maure ramatuelle uchist rel castelli pelite rhyolite cratadis rhyolite dolomite gardanne limestone carte oil datum uc uncorrected correct topographic',
#  'estimate heat flow maure esttrel',
#  'diorite leucogranite cordieritegranite granitegneiss metamorphic schist gneiss anatectic gneiss',
#  'diorite leucogranite cordieritegranite granitegneiss metamorphic schist gneiss anatectic gneiss',
#  'diorite leucogranite cordieritegranite granitegneiss metamorphic schist gneiss anatectic gneiss',
#  'diorite leucogranite cordieritegranite granitegneiss metamorphic schist gneiss anatectic gneiss',
#  'diorite leucogranite cordieritegranite granitegneiss metamorphic schist gneiss anatectic gneiss',
#  'heat production datum surface ld consistent esterel',
#  'datum correspond oil exploration borehole bht measurement correct mud circulation',
#  'average area mw heat flow close average european mw stable hercynian province europe',
#  'continent thermal regime crust closely nature distribution heat source',
#  'continent thermal regime crust closely nature distribution heat source',
#  'stable area linear relationship exist surface heat flow surface heat production',
#  'stable area linear relationship exist surface heat flow surface heat production',
#  'study surface heat production order evaluate contribution heat source surface heat flow',
#  'study surface heat production order evaluate contribution heat source surface heat flow',
#  'study surface heat production order evaluate contribution heat source surface heat flow',
#  'heat production late uranium thorium potassium concentration accord work',
#  'heat production late uranium thorium potassium concentration accord work',
#  'work new measurement maure esterel compare previous result corsica',
#  'work new measurement maure esterel compare previous result corsica',
#  'hercynian basement outcropping maure esttrel form metamorphic rock basement outcropping corsica form hercynian granite',
#  'hercynian basement outcropping maure esttrel form metamorphic rock basement outcropping corsica form hercynian granite',
#  'hercynian basement outcropping maure esttrel form metamorphic rock basement outcropping corsica form hercynian granite',
#  'hercynian basement outcropping maure esttrel form metamorphic rock basement outcropping corsica form hercynian granite',
#  'mauresestcrel province characterize paleozoic metamorphic unit maures southwestern position tanneron northeastern position',
#  'mauresestcrel province characterize paleozoic metamorphic unit maures southwestern position tanneron northeastern position',
#  'mauresestcrel province characterize paleozoic metamorphic unit maures southwestern position tanneron northeastern position',
#  'massif separate permian volcanic sedimentary unit estcrel',
#  'massif separate permian volcanic sedimentary unit estcrel',
#  'massif separate permian volcanic sedimentary unit estcrel',
#  'petrographic feature metamorphic basement study',
#  'western maures form rnicaschist twomica gneis intrude cambrian granitegneiss',
#  'western maures form rnicaschist twomica gneis intrude cambrian granitegneiss',
#  'eastern maures tanneron massif form metamorphic rock anatectic gneiss',
#  'eastern maures tanneron massif form metamorphic rock anatectic gneiss',
#  'metamorphic domain separate fault hercynian granite plan tour situate',
#  'metamorphic domain separate fault hercynian granite plan tour situate',
#  'metamorphic domain separate fault hercynian granite plan tour situate',
#  'permian rhyolite correspond esttrel massif sensu stricto',
#  'permian rhyolite correspond esttrel massif sensu stricto',
#  'granitic equivalent rhyolite xenolith oligocene esttrellite rnicrodiorite',
#  'granitic equivalent rhyolite xenolith oligocene esttrellite rnicrodiorite',
#  'granitic equivalent rhyolite xenolith oligocene esttrellite rnicrodiorite',
#  'corsica classically divide alpine corsica western island correspond abduction mesozoic unit middle cretaceous hercynian corsica western southern form hercynian permian granitic basement',
#  'corsica classically divide alpine corsica western island correspond abduction mesozoic unit middle cretaceous hercynian corsica western southern form hercynian permian granitic basement',
#  'corsica classically divide alpine corsica western island correspond abduction mesozoic unit middle cretaceous hercynian corsica western southern form hercynian permian granitic basement',
#  'corsica classically divide alpine corsica western island correspond abduction mesozoic unit middle cretaceous hercynian corsica western southern form hercynian permian granitic basement',
#  'corsica classically divide alpine corsica western island correspond abduction mesozoic unit middle cretaceous hercynian corsica western southern form hercynian permian granitic basement',
#  'corsica classically divide alpine corsica western island correspond abduction mesozoic unit middle cretaceous hercynian corsica western southern form hercynian permian granitic basement',
#  'corsica classically divide alpine corsica western island correspond abduction mesozoic unit middle cretaceous hercynian corsica western southern form hercynian permian granitic basement',
#  'corsica classically divide alpine corsica western island correspond abduction mesozoic unit middle cretaceous hercynian corsica western southern form hercynian permian granitic basement',
#  'corsica classically divide alpine corsica western island correspond abduction mesozoic unit middle cretaceous hercynian corsica western southern form hercynian permian granitic basement',
#  'corsica classically divide alpine corsica western island correspond abduction mesozoic unit middle cretaceous hercynian corsica western southern form hercynian permian granitic basement',
#  'corsica classically divide alpine corsica western island correspond abduction mesozoic unit middle cretaceous hercynian corsica western southern form hercynian permian granitic basement',
#  'hercynian granite belong magmatic association talkalkaline subalkaline type',
#  'hercynian granite belong magmatic association talkalkaline subalkaline type',
#  'permian granite represent anorogenic type associate rhyolite northern island southern',
#  'permian granite represent anorogenic type associate rhyolite northern island southern',
#  'permian granite represent anorogenic type associate rhyolite northern island southern',
#  'level erosion increase esterel rhyolite outcrop granite exist deep level north corsica rhyolite granite outcrop finally',
#  'level erosion increase esterel rhyolite outcrop granite exist deep level north corsica rhyolite granite outcrop finally',
#  'level erosion increase esterel rhyolite outcrop granite exist deep level north corsica rhyolite granite outcrop finally',
#  'level erosion increase esterel rhyolite outcrop granite exist deep level north corsica rhyolite granite outcrop finally',
#  'level erosion increase esterel rhyolite outcrop granite exist deep level north corsica rhyolite granite outcrop finally',
#  'level erosion increase esterel rhyolite outcrop granite exist deep level north corsica rhyolite granite outcrop finally',
#  'level erosion increase esterel rhyolite outcrop granite exist deep level north corsica rhyolite granite outcrop finally',
#  'south corsica granite exist bonnin',
#  'south corsica granite exist bonnin',
#  'south corsica granite exist bonnin',
#  'sample representative geological formation result cenozoic mesozoic kiiz permian',
#  'sample representative geological formation result cenozoic mesozoic kiiz permian',
#  'sample representative geological formation result cenozoic mesozoic kiiz permian',
#  'sample representative geological formation result cenozoic mesozoic kiiz permian',
#  'sample representative geological formation result cenozoic mesozoic kiiz permian',
#  'sample representative geological formation result cenozoic mesozoic kiiz permian',
#  'stephanian hercyncan granite paleozoic basement fault mediterranean sea',
#  'stephanian hercyncan granite paleozoic basement fault mediterranean sea',
#  'stephanian hercyncan granite paleozoic basement fault mediterranean sea',
#  'stephanian hercyncan granite paleozoic basement fault mediterranean sea',
#  'geological map maures esterel location sample analyze heat production datum maures ppm wv method standard',
#  'enaa grs enaa enaa enaa enaa enaa enaa enaa grs enaa enaa enaa enaa enaa gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn enaa enaa gsn gsn granite gneiss average gc gc granite average average verage schist average average petrologic type',
#  'enaa grs enaa enaa enaa enaa enaa enaa enaa grs enaa enaa enaa enaa enaa gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn enaa enaa gsn gsn granite gneiss average gc gc granite average average verage schist average average petrologic type',
#  'enaa grs enaa enaa enaa enaa enaa enaa enaa grs enaa enaa enaa enaa enaa gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn enaa enaa gsn gsn granite gneiss average gc gc granite average average verage schist average average petrologic type',
#  'enaa grs enaa enaa enaa enaa enaa enaa enaa grs enaa enaa enaa enaa enaa gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn enaa enaa gsn gsn granite gneiss average gc gc granite average average verage schist average average petrologic type',
#  'metamorphic rock classify metasedimentary rock gneiss anatectic gneiss granitegneiss',
#  'metamorphic rock classify metasedimentary rock gneiss anatectic gneiss granitegneiss',
#  'metamorphic rock classify metasedimentary rock gneiss anatectic gneiss granitegneiss',
#  'radiogenic content ficantly change grade metamorphism metasedimentary rock average heat production pw',
#  'radiogenic content ficantly change grade metamorphism metasedimentary rock average heat production pw',
#  'graniteegneiss high average content thzk kfu diorite rhyolite continue ppm thko ppm kkak affj pw method standard average gc gc gc average gc gcx enaa enaa enaa enaa enaa enaa enaa enaa enaa enaa enaa gamma ray enaa epithermal neutron activation analysis',
#  'graniteegneiss high average content thzk kfu diorite rhyolite continue ppm thko ppm kkak affj pw method standard average gc gc gc average gc gcx enaa enaa enaa enaa enaa enaa enaa enaa enaa enaa enaa gamma ray enaa epithermal neutron activation analysis',
#  'graniteegneiss high average content thzk kfu diorite rhyolite continue ppm thko ppm kkak affj pw method standard average gc gc gc average gc gcx enaa enaa enaa enaa enaa enaa enaa enaa enaa enaa enaa gamma ray enaa epithermal neutron activation analysis',
#  'gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn ufo gnrlss annrectrc gnr enaa enaa enaa enaa enaa grs enaa enaa grs high heat production pw',
#  'gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn gsn ufo gnrlss annrectrc gnr enaa enaa enaa enaa enaa grs enaa enaa grs high heat production pw',
#  'work massif central france range',
#  'work massif central france range',
#  'surface anatectic gneiss massif central heat production pw material erupt depth volcanism heat production pw',
#  'surface anatectic gneiss massif central heat production pw material erupt depth volcanism heat production pw',
#  'surface anatectic gneiss massif central heat production pw material erupt depth volcanism heat production pw',
#  'surface anatectic gneiss massif central heat production pw material erupt depth volcanism heat production pw',
#  'surface anatectic gneiss massif central heat production pw material erupt depth volcanism heat production pw',
#  'granite maures esterel close leucogranite type massif central low characteristic granite crustal origin',
#  'granite maures esterel close leucogranite type massif central low characteristic granite crustal origin',
#  'granite maures esterel close leucogranite type massif central low characteristic granite crustal origin',
#  'sensu massif esttrel form permian rhyolite',
#  'sensu massif esttrel form permian rhyolite',
#  'finally diorite low heat production pw represent small outcropping volume',
#  'finally diorite low heat production pw represent small outcropping volume',
#  'finally diorite low heat production pw represent small outcropping volume',
#  'field grain number dose neutron track cmz track induce apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite',
#  'field grain number dose neutron track cmz track induce apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite',
#  'field grain number dose neutron track cmz track induce apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite',
#  'field grain number dose neutron track cmz track induce apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite',
#  'field grain number dose neutron track cmz track induce apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite',
#  'field grain number dose neutron track cmz track induce apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite',
#  'field grain number dose neutron track cmz track induce apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite',
#  'field grain number dose neutron track cmz track induce apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite',
#  'field grain number dose neutron track cmz track induce apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite',
#  'field grain number dose neutron track cmz track induce apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite',
#  'field grain number dose neutron track cmz track induce apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite',
#  'field grain number dose neutron track cmz track induce apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite',
#  'field grain number dose neutron track cmz track induce apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite',
#  'field grain number dose neutron track cmz track induce apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite',
#  'field grain number dose neutron track cmz track induce apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite',
#  'field grain number dose neutron track cmz track induce apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite',
#  'track track fossit mineral sample apatite fission track datum maures estcrel corsica apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite natural state laboratory annealing hour laboratory annealing',
#  'track track fossit mineral sample apatite fission track datum maures estcrel corsica apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite natural state laboratory annealing hour laboratory annealing',
#  'track track fossit mineral sample apatite fission track datum maures estcrel corsica apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite natural state laboratory annealing hour laboratory annealing',
#  'track track fossit mineral sample apatite fission track datum maures estcrel corsica apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite natural state laboratory annealing hour laboratory annealing',
#  'track track fossit mineral sample apatite fission track datum maures estcrel corsica apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite natural state laboratory annealing hour laboratory annealing',
#  'track track fossit mineral sample apatite fission track datum maures estcrel corsica apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite natural state laboratory annealing hour laboratory annealing',
#  'track track fossit mineral sample apatite fission track datum maures estcrel corsica apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite natural state laboratory annealing hour laboratory annealing',
#  'track track fossit mineral sample apatite fission track datum maures estcrel corsica apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite natural state laboratory annealing hour laboratory annealing',
#  'track track fossit mineral sample apatite fission track datum maures estcrel corsica apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite natural state laboratory annealing hour laboratory annealing',
#  'track track fossit mineral sample apatite fission track datum maures estcrel corsica apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite natural state laboratory annealing hour laboratory annealing',
#  'track track fossit mineral sample apatite fission track datum maures estcrel corsica apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite natural state laboratory annealing hour laboratory annealing',
#  'track track fossit mineral sample apatite fission track datum maures estcrel corsica apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite natural state laboratory annealing hour laboratory annealing',
#  'track track fossit mineral sample apatite fission track datum maures estcrel corsica apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite natural state laboratory annealing hour laboratory annealing',
#  'track track fossit mineral sample apatite fission track datum maures estcrel corsica apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite natural state laboratory annealing hour laboratory annealing',
#  'track track fossit mineral sample apatite fission track datum maures estcrel corsica apatite apatite apatite apatite apatite apatite apatite apatite apatite apatite natural state laboratory annealing hour laboratory annealing',
#  'hour laboratory annealing number track count',
#  'relative standard error inducedtrack count apatite',
#  'error calculate poisson relative standard error',
#  'previous heat production datum cock datum publish interesting recall principal result order discuss heat flow datum',
#  'previous heat production datum cock datum publish interesting recall principal result order discuss heat flow datum',
#  'talcalkaline granite represent threethird outcrop hercynian corsica',
#  'talcalkaline granite represent threethird outcrop hercynian corsica',
#  'talcalkaline granite represent threethird outcrop hercynian corsica',
#  'granite massif central high average uranium content ppm ratio consistent expect granite',
#  'granite massif central high average uranium content ppm ratio consistent expect granite',
#  'granite massif central high average uranium content ppm ratio consistent expect granite',
#  'granite massif central high average uranium content ppm ratio consistent expect granite',
#  'granite massif central high average uranium content ppm ratio consistent expect granite',
#  'granite corsica deplete weathering process',
#  'granite corsica deplete weathering process',
#  'granite corsica deplete weathering process',
#  'leucocratic granite represent evolve member talkalkaline series',
#  'enrich uranium ppm high heat production pw mm',
#  'enrich uranium ppm high heat production pw mm',
#  'subalkali granite enrich uranium ppm thorium ppm',
#  'subalkali granite enrich uranium ppm thorium ppm',
#  'close average granite massif central',
#  'close average granite massif central',
#  'finally heat production permian anorogenic granite vary pw mj',
#  'finally heat production permian anorogenic granite vary pw mj',
#  'finally heat production permian anorogenic granite vary pw mj',
#  'finally heat production permian anorogenic granite vary pw mj',
#  'apatite fission track datum fission track represent daughter product disintegration dating method',
#  'special feature method closure sensitive temperature',
#  'closure temperature characteristic mineral apatite',
#  'closure temperature characteristic mineral apatite',
#  'closure temperature characteristic mineral apatite',
#  'excellent indicator paleogeothermal condition apatite age represent cooling loo correspond depth',
#  'excellent indicator paleogeothermal condition apatite age represent cooling loo correspond depth',
#  'study set datum measurement corsica publish zircon new apatite age maure estcrel simultaneously determine international standard fish canyon tuff complete previous datum',
#  'study set datum measurement corsica publish zircon new apatite age maure estcrel simultaneously determine international standard fish canyon tuff complete previous datum',
#  'study set datum measurement corsica publish zircon new apatite age maure estcrel simultaneously determine international standard fish canyon tuff complete previous datum',
#  'study set datum measurement corsica publish zircon new apatite age maure estcrel simultaneously determine international standard fish canyon tuff complete previous datum',
#  'result corsica draw preoligocene position',
#  'result corsica draw preoligocene position',
#  'alpine corsica characterize eoceneoligocene apatite age northwest island maure estcrel cretaceous age',
#  'alpine corsica characterize eoceneoligocene apatite age northwest island maure estcrel cretaceous age',
#  'alpine corsica characterize eoceneoligocene apatite age northwest island maure estcrel cretaceous age',
#  'alpine corsica characterize eoceneoligocene apatite age northwest island maure estcrel cretaceous age',
#  'interpret fission track datum eastern corsica assume differential erosion subsequent wellknown eocene compressional stage erosion rate high mm yri',
#  'interpret fission track datum eastern corsica assume differential erosion subsequent wellknown eocene compressional stage erosion rate high mm yri',
#  'interpret fission track datum eastern corsica assume differential erosion subsequent wellknown eocene compressional stage erosion rate high mm yri',
#  'interpret fission track datum eastern corsica assume differential erosion subsequent wellknown eocene compressional stage erosion rate high mm yri',
#  'interpret fission track datum eastern corsica assume differential erosion subsequent wellknown eocene compressional stage erosion rate high mm yri',
#  'interpret fission track datum eastern corsica assume differential erosion subsequent wellknown eocene compressional stage erosion rate high mm yri',
#  'hand western corsica maure estcrel region affect cretaceous phase alpine orogeny apatite age',
#  'hand western corsica maure estcrel region affect cretaceous phase alpine orogeny apatite age',
#  'hand western corsica maure estcrel region affect cretaceous phase alpine orogeny apatite age',
#  'hand western corsica maure estcrel region affect cretaceous phase alpine orogeny apatite age',
#  'erosional process occur middle cretaceous oligocene rifting',
#  'erosional process occur middle cretaceous oligocene rifting',
#  'geological evidence distention arearole heat production',
#  'apatite fission track datum maure estcrel corsica',
#  'apatite fission track datum maure estcrel corsica',
#  'apatite fission track datum maure estcrel corsica',
#  'provenqal coastlme presentday position corsica heen reptace supposed preoligocene position',
#  'provenqal coastlme presentday position corsica heen reptace supposed preoligocene position',
#  'alpine corsica thermal regime ilercynian crust onset oligocene rifting equilibrium',
#  'alpine corsica thermal regime ilercynian crust onset oligocene rifting equilibrium',
#  'alpine corsica thermal regime ilercynian crust onset oligocene rifting equilibrium',
# ...
#  'heat production granite corsica wide range pw pw mj',
#  'heat production granite corsica wide range pw pw mj',
#  'heat production granite corsica wide range pw pw mj',
#  'low boundary increase pw granite massif central corsican talkalkaline granite deplete uranium',
#  'low boundary increase pw granite massif central corsican talkalkaline granite deplete uranium',
#  'low boundary increase pw granite massif central corsican talkalkaline granite deplete uranium',
#  'difference surface heat flow explain talkalkaline granite enrich granite corsica relative metamorphic basement mauresesterel',
#  'difference surface heat flow explain talkalkaline granite enrich granite corsica relative metamorphic basement mauresesterel',
#  'difference surface heat flow explain talkalkaline granite enrich granite corsica relative metamorphic basement mauresesterel',
#  'difference surface heat flow explain talkalkaline granite enrich granite corsica relative metamorphic basement mauresesterel',
#  'difference surface heat flow explain talkalkaline granite enrich granite corsica relative metamorphic basement mauresesterel',
#  'difference surface heat flow explain talkalkaline granite enrich granite corsica relative metamorphic basement mauresesterel',
#  'explanation problematic surface granite associate heat flow anomaly sardinia granite exist deep level maure esterel',
#  'explanation problematic surface granite associate heat flow anomaly sardinia granite exist deep level maure esterel',
#  'explanation problematic surface granite associate heat flow anomaly sardinia granite exist deep level maure esterel',
#  'radiogenic heat contribution crust area roughly heat flow anomaly corsica origin',
#  'radiogenic heat contribution crust area roughly heat flow anomaly corsica origin',
#  'radiogenic heat contribution crust area roughly heat flow anomaly corsica origin',
#  'radiogenic heat contribution crust area roughly heat flow anomaly corsica origin',
#  'radiogenic heat contribution crust area roughly heat flow anomaly corsica origin',
#  'role erosion corsica affect alpine orogeny major middle cretaceous phase correspond abduction process eocene phase correspond main tectonic compression',
#  'role erosion corsica affect alpine orogeny major middle cretaceous phase correspond abduction process eocene phase correspond main tectonic compression',
#  'role erosion corsica affect alpine orogeny major middle cretaceous phase correspond abduction process eocene phase correspond main tectonic compression',
#  'role erosion corsica affect alpine orogeny major middle cretaceous phase correspond abduction process eocene phase correspond main tectonic compression',
#  'attempt derive erosion rate combine fission track datum zircon apatite thermal modelling',
#  'attempt derive erosion rate combine fission track datum zircon apatite thermal modelling',
#  'attempt derive erosion rate combine fission track datum zircon apatite thermal modelling',
#  'maximum erosion rate eocene phase observe alpine corsica mm',
#  'maximum erosion rate eocene phase observe alpine corsica mm',
#  'maximum erosion rate eocene phase observe alpine corsica mm',
#  'maximum erosion rate eocene phase observe alpine corsica mm',
#  'yield maximum heat flow anomaly mw erosion rate prevail central western corsica increase surface heat flow expect',
#  'yield maximum heat flow anomaly mw erosion rate prevail central western corsica increase surface heat flow expect',
#  'yield maximum heat flow anomaly mw erosion rate prevail central western corsica increase surface heat flow expect',
#  'yield maximum heat flow anomaly mw erosion rate prevail central western corsica increase surface heat flow expect',
#  'yield maximum heat flow anomaly mw erosion rate prevail central western corsica increase surface heat flow expect',
#  'yield maximum heat flow anomaly mw erosion rate prevail central western corsica increase surface heat flow expect',
#  'yield maximum heat flow anomaly mw erosion rate prevail central western corsica increase surface heat flow expect',
#  'erosion explain heat flow difference alpine hercynian corsica case difference corsica maures sardinia',
#  'erosion explain heat flow difference alpine hercynian corsica case difference corsica maures sardinia',
#  'erosion explain heat flow difference alpine hercynian corsica case difference corsica maures sardinia',
#  'erosion explain heat flow difference alpine hercynian corsica case difference corsica maures sardinia',
#  'erosion explain heat flow difference alpine hercynian corsica case difference corsica maures sardinia',
#  'formation provensal basin oligocene affect thermal regime corsica increase surface heat flow',
#  'formation provensal basin oligocene affect thermal regime corsica increase surface heat flow',
#  'formation provensal basin oligocene affect thermal regime corsica increase surface heat flow',
#  'formation provensal basin oligocene affect thermal regime corsica increase surface heat flow',
#  'formation provensal basin oligocene affect thermal regime corsica increase surface heat flow',
#  'formation provensal basin oligocene affect thermal regime corsica increase surface heat flow',
#  'order investigate possibility gather heat flow datum wide domain hercynian outcrop',
#  'datum proveqal basin tyrrhenian sea sardinia italy france datum paper draw contour map heat flow western mediterranean automatic method',
#  'datum proveqal basin tyrrhenian sea sardinia italy france datum paper draw contour map heat flow western mediterranean automatic method',
#  'datum proveqal basin tyrrhenian sea sardinia italy france datum paper draw contour map heat flow western mediterranean automatic method',
#  'hercynian domain characterize low heat flow corsica',
#  'hercynian domain characterize low heat flow corsica',
#  'hercynian domain characterize low heat flow corsica',
#  'basin high heat flow anomaly extend tuscany balearic basin',
#  'basin high heat flow anomaly extend tuscany balearic basin',
#  'anomaly directly connect oceanic domain correspond margin corsica sardinia',
#  'anomaly directly connect oceanic domain correspond margin corsica sardinia',
#  'gulf lions characterize low heat flow mw explain blanket sediment absorb surface heat flow douaran',
#  'gulf lions characterize low heat flow mw explain blanket sediment absorb surface heat flow douaran',
#  'gulf lions characterize low heat flow mw explain blanket sediment absorb surface heat flow douaran',
#  'major feature map asymmetric distribution heat flow proveqal basin',
#  'heat flow map provencal basin',
#  'heat flow map provencal basin',
#  'combine result esp survey magnetic propose asymmetric model oceanic accretion great apreading rate provence',
#  'refraction seismic datum land gravity datum continental crust thick beneath corsica sardinia beneath northwestern corsica support observation asymmetric shape bathymetry bouguer anomaly high extension corsican margin',
#  'refraction seismic datum land gravity datum continental crust thick beneath corsica sardinia beneath northwestern corsica support observation asymmetric shape bathymetry bouguer anomaly high extension corsican margin',
#  'refraction seismic datum land gravity datum continental crust thick beneath corsica sardinia beneath northwestern corsica support observation asymmetric shape bathymetry bouguer anomaly high extension corsican margin',
#  'refraction seismic datum land gravity datum continental crust thick beneath corsica sardinia beneath northwestern corsica support observation asymmetric shape bathymetry bouguer anomaly high extension corsican margin',
#  'refraction seismic datum land gravity datum continental crust thick beneath corsica sardinia beneath northwestern corsica support observation asymmetric shape bathymetry bouguer anomaly high extension corsican margin',
#  'refraction seismic datum land gravity datum continental crust thick beneath corsica sardinia beneath northwestern corsica support observation asymmetric shape bathymetry bouguer anomaly high extension corsican margin',
#  'propose deepseated thermal anomaly locate beneath corsican accord heat flow map anomaly extend tuscany balearic basin residual thermal anomaly relate paleoridge',
#  'propose deepseated thermal anomaly locate beneath corsican accord heat flow map anomaly extend tuscany balearic basin residual thermal anomaly relate paleoridge',
#  'propose deepseated thermal anomaly locate beneath corsican accord heat flow map anomaly extend tuscany balearic basin residual thermal anomaly relate paleoridge',
#  'hypothesis explain high relief corsica associate normal crust',
#  'hypothesis explain high relief corsica associate normal crust',
#  'hypothesis explain high relief corsica associate normal crust',
#  'high heat flow corsica consequence evolution western mediterranean',
#  'high heat flow corsica consequence evolution western mediterranean',
#  'high heat flow corsica consequence evolution western mediterranean',
#  'high heat flow corsica consequence evolution western mediterranean',
#  'model initial thermal state previous hercynian crust provenqal basin corsica characterize low heat flow correspond equilibrium stable hercynian domain',
#  'model initial thermal state previous hercynian crust provenqal basin corsica characterize low heat flow correspond equilibrium stable hercynian domain',
#  'model initial thermal state previous hercynian crust provenqal basin corsica characterize low heat flow correspond equilibrium stable hercynian domain',
#  'model initial thermal state previous hercynian crust provenqal basin corsica characterize low heat flow correspond equilibrium stable hercynian domain',
#  'interesting study contribution crust mantle surface heat flow estimate initial boundary condition thermal modelling',
#  'interesting study contribution crust mantle surface heat flow estimate initial boundary condition thermal modelling',
#  'day thermal state maure esterel reliable heat flow heat production datum estimate',
#  'day thermal state maure esterel reliable heat flow heat production datum estimate',
#  'day thermal state maure esterel reliable heat flow heat production datum estimate',
#  'heat production exponentially depend pwave velocity',
#  'heat production exponentially depend pwave velocity',
#  'fact upper crustal rock wide range heat production pw pwave velocity range',
#  'fact upper crustal rock wide range heat production pw pwave velocity range',
#  'hand rock low crust narrow range heat production pwave velocity range',
#  'hand rock low crust narrow range heat production pwave velocity range',
#  'survey ligurian coastline gulf genova crust form thick seismic pwave velocity upper layer low layer',
#  'continental crust layer structure esp close maure thickness stretch crust pwave velocity thick upper crust thick low layer',
#  'continental crust layer structure esp close maure thickness stretch crust pwave velocity thick upper crust thick low layer',
#  'structure observe hercynian domain france',
#  'strong evidence hercynian structure continue massif central maures esterel deep crust massif central xenolith carry volcanism maures estcrel',
#  'strong evidence hercynian structure continue massif central maures esterel deep crust massif central xenolith carry volcanism maures estcrel',
#  'average heat production upper crust estimate surface rock',
#  'accord layer form complex consist metamorphic rock mix granite upper',
#  'accord layer form complex consist metamorphic rock mix granite upper',
#  'enrich granite generally associate negative gravity anomaly high heat flow massif central corsica study',
#  'enrich granite generally associate negative gravity anomaly high heat flow massif central corsica study',
#  'enrich granite generally associate negative gravity anomaly high heat flow massif central corsica study',
#  'enrich granite generally associate negative gravity anomaly high heat flow massif central corsica study',
#  'enrich granite generally associate negative gravity anomaly high heat flow massif central corsica study',
#  'enrich granite generally associate negative gravity anomaly high heat flow massif central corsica study',
#  'hand thick granite low heat production pw',
#  'hand thick granite low heat production pw',
#  'granite contribute additional mw surface heat flow',
#  'granite contribute additional mw surface heat flow',
#  'purpose model granite heat production metamorphic basement uniform surface deep level attribute upper crust',
#  'purpose model granite heat production metamorphic basement uniform surface deep level attribute upper crust',
#  'purpose model granite heat production metamorphic basement uniform surface deep level attribute upper crust',
#  'contribute mw surface heat flow assume average heat production pw',
#  'contribute mw surface heat flow assume average heat production pw',
#  'low crust average heat production range pw',
#  'correspond contribution mw surface heat flow',
#  'mantle heat flow beneath stable hercynian crust range mw result agreement global heat flow study predict mantle heat flow beneath stable province mw',
#  'mantle heat flow beneath stable hercynian crust range mw result agreement global heat flow study predict mantle heat flow beneath stable province mw',
#  'mantle heat flow beneath stable hercynian crust range mw result agreement global heat flow study predict mantle heat flow beneath stable province mw',
#  'average heat production crust pw mm result compare geochemical model predict pw',
#  'temperature moho calculate basis distribution heat range assume constant conductivity crust',
#  'temperature moho calculate basis distribution heat range assume constant conductivity crust',
#  'temperature moho calculate basis distribution heat range assume constant conductivity crust',
#  'assume thermal conductivity decrease increase temperature accord model',
#  'assume thermal conductivity decrease increase temperature accord model',
#  'conclusion thermal structure western mediterranean difficult understand represent interaction time dependent process',
#  'mediterranean sea evolve thermal modelling estimate temperature field mantle heat flow final goal thermal study egt programme',
#  'mediterranean sea evolve thermal modelling estimate temperature field mantle heat flow final goal thermal study egt programme',
#  'mediterranean sea evolve thermal modelling estimate temperature field mantle heat flow final goal thermal study egt programme',
#  'mediterranean sea evolve thermal modelling estimate temperature field mantle heat flow final goal thermal study egt programme',
#  'modelling work require establishment reference thermal state order estimate initial boundary condition',
#  'paper study hercynian area outcrop basin order propose reference thermal state western anean sea',
#  'corsica area presently thermal equilibrium',
#  'corsica area presently thermal equilibrium',
#  'corsica area presently thermal equilibrium',
#  'maure esterel reliable heat flow heat production datum study thermal state crust area expect correspond stationary condition',
#  'maure esterel reliable heat flow heat production datum study thermal state crust area expect correspond stationary condition',
#  'maure esterel reliable heat flow heat production datum study thermal state crust area expect correspond stationary condition',
#  'surface heat flow mw crustal heat contribution estimate seismic datum range mw mm',
#  'surface heat flow mw crustal heat contribution estimate seismic datum range mw mm',
#  'mantle heat flow mw agreement general consideration stable tectonic province',
#  'hand hercynian batholith corsica affect alpine orogeny subsequent erosion deepseated thermal anomaly evidence geological geophysical anomaly',
#  'hand hercynian batholith corsica affect alpine orogeny subsequent erosion deepseated thermal anomaly evidence geological geophysical anomaly',
#  'hand hercynian batholith corsica affect alpine orogeny subsequent erosion deepseated thermal anomaly evidence geological geophysical anomaly',
#  'heat flow map western mediterranean result compilation exist datum reveal deepseated anomaly extend tuscany balearic basin correspond paleoridge']

# %%
ready_ner['tag']
# Out:
# ['heat flow',
#  'temperature',
#  'heat',
#  'temperature',
#  'thermal',
#  'thermal',
#  'thermal',
#  'france',
#  'corsica',
#  'southern france',
#  'corsica',
#  'oligocene',
#  'france',
#  'block',
#  'continental crust',
#  'corsica',
#  'corsica',
#  'corsica',
#  'thermal',
#  'heat flow',
#  'heat',
#  'corsica',
#  'temperature',
#  'heat flow',
#  'thermal',
#  'corsica',
#  'heat flow',
#  'corsica',
#  'temperature',
#  'temperature',
#  'conductivity',
#  'corsica',
#  'corsica',
#  'temperature',
#  'thermal conductivity',
#  'thermal',
#  'standard deviation',
#  'thermal',
#  'depth',
#  'corsica',
#  'temperature',
#  'depth',
#  'corsica',
#  'temperature',
#  'temperature',
#  'depth',
#  'thermal',
#  'depth',
#  'uncertainty',
#  'thermal',
#  'conductivity',
#  'corsica',
#  'corsica',
#  'heat flow',
#  'heat flow',
#  'corsica',
#  'corsica',
#  'depth',
#  'heat flow',
#  'corsica',
#  'corsica',
#  'heat flow',
#  'heat flow',
#  'heat flow',
#  'heat flow',
#  'heat flow',
#  'heat flow',
#  'schist',
#  'schist',
#  'schist',
#  'sandstone',
#  'granite',
#  'rhyolite',
#  'granite',
#  'granite',
#  'granite',
#  'schist',
#  'granite',
#  'gabbro',
#  'granite',
#  'granite',
#  'granite',
#  'granite',
#  'granite',
#  'corsica',
#  'corsica',
#  'corsica',
#  'heat flow',
#  'corsica',
#  'heat flow',
#  'corsica',
#  'granite',
#  'corsica',
#  'mesozoic',
#  'mesozoic',
#  'corsica',
#  'corsica',
#  'heat flow',
#  'france',
#  'southern france',
#  'corsica',
#  'temperature',
#  'corsica',
#  'permian',
#  'rhyolite',
#  'heat flow',
#  'depth',
#  'conductivity',
#  'conductivity',
#  'heat flow',
#  'temperature',
#  'depth',
#  'temperature',
#  'depth',
#  'temperature',
#  'temperature',
#  'depth',
#  'thermal',
#  'heat flow',
#  'depth',
#  'heat flow',
#  'pelite',
#  'rhyolite',
#  'rhyolite',
#  'dolomite',
#  'limestone',
#  'heat flow',
#  'diorite',
#  'metamorphic',
#  'schist',
#  'gneiss',
#  'gneiss',
#  'heat',
#  'mud',
#  'heat flow',
#  'thermal',
#  'heat',
#  'heat flow',
#  'heat',
#  'heat',
#  'heat',
#  'heat flow',
#  'late',
#  'heat',
#  'corsica',
#  'corsica',
#  'corsica',
#  'metamorphic',
#  'granite',
#  'corsica',
#  'paleozoic',
#  'paleozoic',
#  'metamorphic',
#  'permian',
#  'volcanic',
#  'sedimentary',
#  'metamorphic',
#  'cambrian',
#  'gneis',
#  'metamorphic',
#  'gneiss',
#  'metamorphic',
#  'fault',
#  'granite',
#  'permian',
#  'rhyolite',
#  'oligocene',
#  'granitic',
#  'rhyolite',
#  'mesozoic',
#  'cretaceous',
#  'permian',
#  'mesozoic',
#  'corsica',
#  'corsica',
#  'corsica',
#  'granitic',
#  'corsica',
#  'corsica',
#  'corsica',
#  'granite',
#  'magmatic',
#  'permian',
#  'granite',
#  'rhyolite',
#  'corsica',
#  'finally',
#  'rhyolite',
#  'granite',
#  'rhyolite',
#  'granite',
#  'corsica',
#  'corsica',
#  'granite',
#  'corsica',
#  'cenozoic',
#  'mesozoic',
#  'permian',
#  'cenozoic',
#  'mesozoic',
#  'formation',
#  'paleozoic',
#  'paleozoic',
#  'granite',
#  'fault',
#  'heat',
#  'granite',
#  'gneiss',
#  'granite',
#  'schist',
#  'metamorphic',
#  'gneiss',
#  'gneiss',
#  'radiogenic',
#  'heat',
#  'high',
#  'diorite',
#  'rhyolite',
#  'heat',
#  'high',
#  'france',
#  'central',
#  'heat',
#  'depth',
#  'heat',
#  'gneiss',
#  'central',
#  'granite',
#  'granite',
#  'central',
#  'permian',
#  'rhyolite',
#  'finally',
#  'heat',
#  'diorite',
#  'grain',
#  'grain',
#  'apatite',
#  'apatite',
#  'apatite',
#  'apatite',
#  'apatite',
#  'apatite',
#  'apatite',
#  'apatite',
#  'apatite',
#  'apatite',
#  'apatite',
#  'apatite',
#  'apatite',
#  'apatite',
#  'corsica',
#  'hour',
#  'mineral',
#  'apatite',
#  'apatite',
#  'apatite',
#  'apatite',
#  'apatite',
#  'apatite',
#  'apatite',
#  'apatite',
#  'apatite',
#  'apatite',
#  'apatite',
#  'corsica',
#  'hour',
#  'apatite',
#  'poisson',
#  'heat',
#  'heat flow',
#  'corsica',
#  'granite',
#  'corsica',
#  'ratio',
#  'granite',
#  'high',
#  'granite',
#  'central',
#  'corsica',
#  'granite',
#  'corsica',
#  'granite',
#  'heat',
#  'high',
#  'subalkali',
#  'granite',
#  'granite',
#  'central',
#  'permian',
#  'finally',
#  'heat',
#  'granite',
#  'apatite',
#  'temperature',
#  'temperature',
#  'mineral',
#  'apatite',
#  'depth',
#  'apatite',
#  'corsica',
#  'apatite',
#  'tuff',
#  'corsica',
#  'corsica',
#  'corsica',
#  'cretaceous',
#  'corsica',
#  'apatite',
#  'corsica',
#  'eocene',
#  'corsica',
#  'differential',
#  'rate',
#  'high',
#  'corsica',
#  'cretaceous',
#  'corsica',
#  'apatite',
#  'corsica',
#  'cretaceous',
#  'oligocene',
#  'heat',
#  'corsica',
#  'apatite',
#  'corsica',
#  'corsica',
#  'corsica',
#  'oligocene',
#  'corsica',
#  'thermal',
#  'onset',
#  'corsica',
#  'corsica',
#  'heat flow',
#  'corsica',
#  'quaternary',
#  'heat flow',
#  'corsica',
#  'thermal',
#  'high',
#  'corsica',
#  'corsica',
#  'heat',
#  'granite',
#  'corsica',
#  'granite',
#  'granite',
#  'central',
#  'corsica',
#  'heat flow',
#  'granite',
#  'granite',
#  'metamorphic',
#  'corsica',
#  'heat flow',
#  'granite',
#  'granite',
#  'corsica',
#  'radiogenic',
#  'heat',
#  'heat flow',
#  'corsica',
#  'cretaceous',
#  'eocene',
#  'corsica',
#  'corsica',
#  'rate',
#  'thermal',
#  'apatite',
#  'eocene',
#  'corsica',
#  'rate',
#  'corsica',
#  'corsica',
#  'yield',
#  'heat flow',
#  'rate',
#  'heat flow',
#  'central',
#  'corsica',
#  'corsica',
#  'corsica',
#  'heat flow',
#  'corsica',
#  'corsica',
#  'oligocene',
#  'corsica',
#  'formation',
#  'thermal',
#  'heat flow',
#  'corsica',
#  'heat flow',
#  'italy',
#  'france',
#  'heat flow',
#  'corsica',
#  'heat flow',
#  'corsica',
#  'heat flow',
#  'high',
#  'corsica',
#  'corsica',
#  'heat flow',
#  'heat flow',
#  'sediment',
#  'heat flow',
#  'provencal basin',
#  'heat flow',
#  'rate',
#  'continental crust',
#  'corsica',
#  'corsica',
#  'high',
#  'corsica',
#  'corsica',
#  'thermal',
#  'heat flow',
#  'thermal',
#  'corsica',
#  'high',
#  'corsica',
#  'corsica',
#  'heat flow',
#  'high',
#  'corsica',
#  'corsica',
#  'thermal',
#  'heat flow',
#  'corsica',
#  'heat flow',
#  'thermal',
#  'thermal',
#  'heat flow',
#  'heat',
#  'heat',
#  'velocity',
#  'heat',
#  'velocity',
#  'heat',
#  'velocity',
#  'velocity',
#  'continental crust',
#  'velocity',
#  'france',
#  'central',
#  'central',
#  'heat',
#  'metamorphic',
#  'granite',
#  'corsica',
#  'heat flow',
#  'granite',
#  'high',
#  'central',
#  'corsica',
#  'heat',
#  'granite',
#  'heat flow',
#  'granite',
#  'heat',
#  'granite',
#  'metamorphic',
#  'heat flow',
#  'heat',
#  'heat',
#  'heat flow',
#  'heat flow',
#  'heat flow',
#  'heat flow',
#  'heat',
#  'temperature',
#  'heat',
#  'conductivity',
#  'thermal conductivity',
#  'temperature',
#  'thermal',
#  'thermal',
#  'temperature',
#  'heat flow',
#  'thermal',
#  'thermal',
#  'thermal',
#  'corsica',
#  'thermal',
#  'corsica',
#  'heat flow',
#  'heat',
#  'thermal',
#  'heat flow',
#  'heat',
#  'heat flow',
#  'corsica',
#  'thermal',
#  'corsica',
#  'heat flow']

# %%
ready_ner['entity']
# Out:
# ['methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'countries',
#  'geolocation',
#  'states',
#  'states',
#  'chrono',
#  'countries',
#  'petrography',
#  'geolocation',
#  'geolocation',
#  'states',
#  'geolocation',
#  'methods',
#  'methods',
#  'methods',
#  'states',
#  'methods',
#  'methods',
#  'methods',
#  'geolocation',
#  'methods',
#  'states',
#  'methods',
#  'methods',
#  'methods',
#  'geolocation',
#  'states',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'geolocation',
#  'methods',
#  'methods',
#  'states',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'geolocation',
#  'geolocation',
#  'methods',
#  'methods',
#  'states',
#  'states',
#  'methods',
#  'methods',
#  'geolocation',
#  'geolocation',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'states',
#  'states',
#  'geolocation',
#  'methods',
#  'states',
#  'methods',
#  'geolocation',
#  'petrography',
#  'states',
#  'chrono',
#  'era',
#  'geolocation',
#  'states',
#  'methods',
#  'countries',
#  'states',
#  'geolocation',
#  'methods',
#  'states',
#  'chrono',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'geolocation',
#  'methods',
#  'geolocation',
#  'states',
#  'geolocation',
#  'petrography',
#  'petrography',
#  'states',
#  'chrono',
#  'era',
#  'petrography',
#  'chrono',
#  'petrography',
#  'petrography',
#  'petrography',
#  'chrono',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'chrono',
#  'petrography',
#  'chrono',
#  'petrography',
#  'petrography',
#  'chrono',
#  'chrono',
#  'chrono',
#  'era',
#  'geolocation',
#  'geolocation',
#  'geolocation',
#  'petrography',
#  'states',
#  'states',
#  'states',
#  'petrography',
#  'petrography',
#  'chrono',
#  'petrography',
#  'petrography',
#  'geolocation',
#  'geolocation',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'states',
#  'geolocation',
#  'petrography',
#  'states',
#  'chrono',
#  'chrono',
#  'chrono',
#  'era',
#  'era',
#  'methods',
#  'chrono',
#  'era',
#  'petrography',
#  'petrography',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'methods',
#  'petrography',
#  'countries',
#  'states',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'states',
#  'petrography',
#  'petrography',
#  'states',
#  'chrono',
#  'petrography',
#  'geolocation',
#  'methods',
#  'petrography',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'geolocation',
#  'geolocation',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'states',
#  'geolocation',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'geolocation',
#  'petrography',
#  'states',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'states',
#  'geolocation',
#  'petrography',
#  'states',
#  'petrography',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'states',
#  'chrono',
#  'geolocation',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'petrography',
#  'geolocation',
#  'petrography',
#  'petrography',
#  'states',
#  'geolocation',
#  'states',
#  'chrono',
#  'geolocation',
#  'petrography',
#  'states',
#  'chrono',
#  'geolocation',
#  'methods',
#  'methods',
#  'petrography',
#  'states',
#  'chrono',
#  'geolocation',
#  'petrography',
#  'states',
#  'chrono',
#  'chrono',
#  'methods',
#  'geolocation',
#  'petrography',
#  'states',
#  'geolocation',
#  'states',
#  'chrono',
#  'geolocation',
#  'methods',
#  'methods',
#  'states',
#  'geolocation',
#  'methods',
#  'states',
#  'chrono',
#  'methods',
#  'geolocation',
#  'methods',
#  'petrography',
#  'states',
#  'geolocation',
#  'methods',
#  'petrography',
#  'states',
#  'petrography',
#  'petrography',
#  'states',
#  'geolocation',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'states',
#  'methods',
#  'petrography',
#  'petrography',
#  'geolocation',
#  'methods',
#  'methods',
#  'methods',
#  'states',
#  'chrono',
#  'chrono',
#  'geolocation',
#  'states',
#  'methods',
#  'methods',
#  'petrography',
#  'chrono',
#  'geolocation',
#  'methods',
#  'states',
#  'geolocation',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'states',
#  'states',
#  'geolocation',
#  'geolocation',
#  'methods',
#  'states',
#  'states',
#  'chrono',
#  'geolocation',
#  'methods',
#  'methods',
#  'methods',
#  'states',
#  'methods',
#  'countries',
#  'countries',
#  'methods',
#  'geolocation',
#  'methods',
#  'states',
#  'methods',
#  'petrography',
#  'geolocation',
#  'states',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'geolocation',
#  'methods',
#  'methods',
#  'geolocation',
#  'geolocation',
#  'geolocation',
#  'petrography',
#  'states',
#  'states',
#  'methods',
#  'methods',
#  'methods',
#  'geolocation',
#  'petrography',
#  'states',
#  'geolocation',
#  'methods',
#  'petrography',
#  'states',
#  'geolocation',
#  'methods',
#  'methods',
#  'states',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'geolocation',
#  'methods',
#  'countries',
#  'states',
#  'states',
#  'methods',
#  'petrography',
#  'petrography',
#  'geolocation',
#  'methods',
#  'petrography',
#  'petrography',
#  'states',
#  'states',
#  'methods',
#  'petrography',
#  'methods',
#  'petrography',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'geolocation',
#  'methods',
#  'states',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'geolocation',
#  'methods',
#  'states',
#  'methods']
