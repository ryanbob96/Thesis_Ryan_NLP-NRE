# %% [markdown]
# # Modules for Scraping

# %%
#PDF Miner (PDF Scraping)
fro`m pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.layout import LAParams
from pdfminer.converter import HTMLConverter, TextConverter, XMLConverter
from io import StringIO
from pdfminer.pdfpage import PDFPage


#PyPDF2 (PDF Scraping)
import PyPDF2 as pypdf


#OCR
from pdf2image import convert_from_path
import cv2
import pytesseract
pytesseract.pytesseract.tesseract_cmd=r'Tesseract-OCR\tesseract.exe'


#NLP Preprocessing
import nltk
import re
import regex
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer


#NLP Processing TensorFLow
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

#NLP Processing Spacy
import spacy
import spacy_transformers
spc = spacy.load('en_core_web_trf')
# spc = spacy.load(en_core_web_lg)
# spc.add_pipe('sentencizer')

#Model Training and Evaluation
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

#Basic
import numpy as np
import pandas as pd
import pickle
import glob
import os
import docker
import string

pc = '!"#$%&\'()*+,-./:;<=>?@[\]^_`{|}~'

# %% [markdown]
# # Data Input for Scanned PDF

# %%
pdf_path = r"PDF Data/1920s/ajs.s5-7.38.81.pdf"

# %% [markdown]
# # OCR Tesseract

# %%
# Scanned PDF Read
def get_pdf_file_content_Text_ocr(pdf_path)
    #Convert pdf to images
    images = convert_from_path(pdf_path, 500,poppler_path=r'C:\Program Files\poppler-0.68.0\bin')
    output_path = 'ocr_out/'
    for i, image in enumerate(images):
        fname = output_path + 'image_'+str(i)+'.png'
        image.save(fname, "PNG")

    extracted_text = []
    #images to text
    for i,filename in enumerate(glob.glob(os.path.join(output_path, '*.png'))):
        try:
            img1 = cv2.imread(filename)
            extracted_text.append(pytesseract.image_to_string(img1))
            print('successful'+str(i))
        except:
            print('unsuccessful'+str(i))

    text = ' '.join(extracted_text)
    
    return text
# Out:
# successful0
# successful1
# successful2
# successful3
# successful4
# successful5
# successful6
# successful7
# successful8
# successful9
# successful10
# successful11
# successful12
# successful13
# successful14
# successful15
# successful16
# successful17
# successful18
# successful19
# successful20
# successful21

# %%
text_pdfmine = ' '.join(get_pdf_file_content_Text_ocr(pdf_path))
text_pdfmine
# Out:
# 'THE\n\nAMERICAN JOURNAL OF SCIENCE\n[FIFTH SERIES.]\n\n———_#oe\n\nArt, VI.—The Thermal Conductivity and Compressi-\nbility of several Rocks under High Pressures; by\nP. W. Brineman.\n\nINTRODUCTION.\n\nThe effect of pressure on the thermal conductivity of\nrocks has apparently never been determined, although a\nknowledge of it is important in calculating the thermal\nequilibrium of the earth’s crust. The only measure-\nments we have that can give any idea of the possible\ninfluence of hydrostatic pressure are on the effect of one-\nsided compression on the thermal conductivity of granite\nand marble.t It1is of course well known that a one-sided\ncompression need not be at all like a hydrostatic pres-\nsure in its effects, and the only conclusion that we can\ndraw from the experiments of Lees as applied to condi-\ntions within the crust of the earth is that the effect of\npressure is probably not very large. .\n\nIn connection with my work on the effect of high pres-\nsures on general physical properties of various sub-\nstances, I have recently been engaged in measuring the\nthermal conductivity of-a number of liquids up to 12000\nke/em?. Since the apparatus could be adapted without\nmuch trouble to measure the effect of pressure on the\nthermal conductivity of those solids whose conductivity\nis not too high, such as the rocks, I thought it of interest\nto make a few measurements from which at least the\ngeneral trend of the effects to be expected could be\ninferred. I have been encouraged in this attempt by\nthe interest and advice of Professor R. A. Daly, who also\nwas so kind as to obtain several of the materials for me.\nI also have to thank my assistant, Mr. H. B. Curry, for\nmaking many of the readings.\n\n1For references see the end of this article.\n\nAm. Jour. Scr.— Firtx Sreriss, Vou. VII, No. 388.—Frpsrvuary, 1924.\n6\n 82 P., W. Bridgman—Thermal Conductivity and\n\nIn addition to the thermal conductivity I have deter-\nmined the compressibility of the materials used. It was\ncomparatively easy to do this as the apparatus had\nalready been developed for another purpose. When I\nbegan these measurements the important paper of Adams\nand Williamson? on the compressibility of rocks had not\nappeared, and such questions as that of the change with\npressure of the compressibility of a rock had not received\nan answer. Since the appearance of that paper, my\ncompressibility results lose some of their novel interest,\nbut there are still a number of points in connection with\nthem which I think may suggest new lines of thought.\nIn the first place, I have measured the compressibility\nof several of my materials at two temperatures, neither\nvery high it is true, 30° and 75°, but nevertheless suffi-\nciently far apart to give an idea of the variation of\ncompressibility with temperature. This of course is\nimportant when applying results obtained in the labora-\ntory at room temperatures to actual conditions. The\nnecessary information can not be obtained from the\nresults of Adams and Williamson because their compres-\nsibilities were measured at only one temperature. In\nthe second place, my method, which measures the linear\nas opposed to the cubical compressibility, brings out the\nimportance of non-isotropy, as the measurements of\nAdams and Williamson on cubical compressibility can-\nnot do. I have found surprisingly large differences of\ncompressibility in different directions, and also entirelv\nunexpected and abnormal hysteresis relations. Both\nthese factors are of importance in calculating the velocity\nof propagation of earthquake waves or other deforma-\ntional effects in the earth’s crust.\n\nThermal Conductivity.\n\nThe Method.—The method used for measuring thermal\nconductivity is essentially the same as that used for\nliquids, and is deseribed in detail elsewhere;? a brief\nsummary here will suffice. The material whose conduc-\ntivity is to be measured is worked to the form of a cylin-\ndrical shell, whic ...

# %% [markdown]
# ## Group PDF Scraping for OCR method

# %%
# #Group Read OCR
# all_extracted_text={}
# folder_patj = 'PDF Data/1920s/'
# for i,filename in enumerate(glob.glob(os.path.join(folder_path, '*.pdf'))):
#     try:
#         all_extracted_text[re.search(r'(\w+).pdf$',filename).group(1) +'_'+ str(i)] = get_pdf_file_content_Text_ocr(filename).lower()
#     except:
#         pass

# %% [markdown]
# # Data Input for Normal PDF

# %%
pdf_path = 'PDF Data/10s/Brehme2016_Article_PermeabilityDistributionInTheL.pdf'

# %% [markdown]
# # PDFMiner

# %%
def get_pdf_file_content_Text(path_to_pdf):
    
    '''
    path_to_pdf: is the parameter that will give access to the PDF File 
    we want to extract the content.
    '''
    
    '''
    PDFResourceManager is used to store shared resources such as fonts or images that 
    we might encounter in the files. 
    '''
    
    resource_manager = PDFResourceManager(caching=True)
    
    '''
    create a string object that will contain the final text the representation of the pdf. 
    '''
    out_text = StringIO()
    
    '''
    UTF-8 is one of the most commonly used encodings, and Python often defaults to using it.
    In our case, we are going to specify in order to avoid some encoding errors.
    '''
    codec = 'utf-8'
    
    """
    LAParams is the object containing the Layout parameters with a certain default value. 
    """
    laParams = LAParams(line_overlap=0.3, detect_vertical=True)
    
    '''
    Create a TextConverter Object, taking :
    - ressource_manager,
    - out_text 
    - layout parameters.
    '''
    text_converter = TextConverter(resource_manager, out_text, laparams=laParams)
    fp = open(path_to_pdf, 'rb')
    
    '''
    Create a PDF interpreter object taking: 
    - ressource_manager 
    - text_converter
    '''
    interpreter = PDFPageInterpreter(resource_manager, text_converter)

    '''
    We are going to process the content of each page of the original PDF File
    '''
    try:
        for page in PDFPage.get_pages(fp, pagenos=set(), maxpages=0, password="", caching=True, check_extractable=True):
            interpreter.process_page(page)
    except:
        for page in PDFPage.get_pages(fp, pagenos=set(), maxpages=0, password=b"", caching=True, check_extractable=True):
            interpreter.process_page(page)

#Considering Vertical Written
#         if page.mediabox[2] - page.mediabox[0] > page.mediabox[3] - page.mediabox[1]:
#             orientation = 'Landscape'
#         else:
#             orientation = 'Portrait'

    '''
    Retrieve the entire contents of the “file” at any time 
    before the StringIO object’s close() method is called.
    '''
    text = out_text.getvalue()

    '''
    Closing all the ressources we previously opened
    '''
    fp.close()
    text_converter.close()
    out_text.close()
    
    '''
    Return the final variable containing all the text of the PDF
    '''
    return text

# %%
text_pdfmine = get_pdf_file_content_Text(pdf_path)
text_pdfmine

# %% [markdown]
# ## Group PDF Scraping for normal method

# %%
# #Group Read PDF Miner
# all_extracted_text={}
# folder_path='PDF Data/10s/'
# for i,filename in enumerate(glob.glob(os.path.join(folder_path, '*.pdf'))):
#     try:
#         all_extracted_text[re.search(r'(\w+).pdf$',filename).group(1) +'_'+ str(i)] = get_pdf_file_content_Text(filename).lower()
#     except:
#         pass

# %% [markdown]
# ## Data Preprocessing (Conditioning, Stop Words, Stemmer)

# %% [markdown]
# ## Pre-Processing 1 : Regex Conditioning for Scientific Text

# %%
#Punctuation of '-' because make a newline 
text_punew = re.sub(r'(-\n?\s)','',text_pdfmine.lower())
text_punew
# Out:
# 'geothermics  65  (2017)  44–59\n\ncontents lists available at sciencedirect\n\ngeothermics\n\nj o u r n a l h o m e p a g e : w w w . e l s e v i e r . c o m / l o c a t e / g e o t h e r m i c s\n\nmechanical   behaviour   of   australian   strathbogie   granite   under   in-situ\nstress   and   temperature   conditions:   an   application   to   geothermal\nenergy   extraction\nw.g.p.   kumari a,   p.g.   ranjith a,∗,   m.s.a.   perera b,   s.   shao a,   b.k.   chen c,   a.   lashin d,\nn.al  ariﬁ e,   t.d.   rathnaweera a\na department  of  civil  engineering,  monash  university,  building  60,  melbourne,  victoria  3800,  australia\nb department  of  infrastructure  engineering,  building  block  d,  the  university  of  melbourne,  parkville,  melbourne,  3010,  australia\nc department  of  mechanical  &  aerospace  engineering,  monash  university,  building  36,  melbourne,  victoria  3800,  australia\nd king  saud  university,  college  of  engineering,  petroleum  and  natural  gas  engineering  department,  p.o.  box  800,  riyadh  11421,  saudi  arabia\ne king  saud  university,  college  of  science,  geology  and  geophysics  department,  p.o.  box  2455,  riyadh  11451,  saudi  arabia\n\na   r   t   i  c   l  e  \n\ni   n   f   o\n\na   b   s   t   r   a   c   t\n\narticle  history:\nreceived  18  may   2016\nreceived  in  revised  form  20  july  2016\naccepted  25  july  2016\n\nkeywords:\ngeothermal  energy\ngranite\nhigh  temperature\nstress-strain  response\ntriaxial\nacoustic\nxrd\n\ngeothermal   heat   has   now   been   identiﬁed   as   an   effective   renewable   energy   source   due   to  severe   environmental   impacts   created   by   conventional   fossil   usage   on  global   climatic   change.   however,   its  wide\napplication   has   been   limited   due   to   the   lack   of   knowledge,   particularly   of   the   geothermal   conditions   of\nreservoir   rocks   at   elevated   temperatures   and   pressures.   such   high   temperatures   and   pressures   possibly\nalter   the  mechanical   properties   of  reservoir   rocks   due   to   the   associated   micro-structural   and   mineralogical  alterations   of   the   rock   mass,   which   are   an   important   attribute   for   wellbore   stability   and   stimulation   of\ngeothermal   reservoirs   for   safe  and   effective   geothermal   energy   extraction.   this   study   therefore   investigates   the   stress-strain   behaviour   under   in-situ   stress   and   temperature   conditions   by   conducting   a  series\nof  high-pressure,   high-temperature   tri-axial   experiments   on  australian   strathbogie   granite   under   four\ndifferent  conﬁning   pressures   (10,   30,   60,   90   mpa)   and   four   different   temperatures   (rt,   100,   200,   300 ◦c).\nthe  effect   of  temperature   on   the   mechanical   behaviour   of   rock   specimens   was   studied   under   tri-axial   conditions   and   the   corresponding   fracture   propagation   behaviour   was   observed   using   an   advanced   acoustic\nemission   (ae)   system.   the   corresponding   micro-structure   alteration   in   granite   was   observed   using   sem\nanalysis.   according   to   the   ﬁndings,   increasing   temperature   leads   to  an   initial   increment   in   reservoir\nrock   strength   and   shear   parameters   followed   by   reduction,   and   the   trend   is   aligned   with   the   crack  formation   pattern   of   the  rock   mass.   this   was   further   conﬁrmed   by   the   sem   analysis,   according   to  which\nthe   rock   micro-structure   is   subject   to  only   minor   changes   at   relatively   low   temperatures   and  higher\ntemperatures   cause   micro-cracks   to   develop   along   the   rock   mass   grain   boundaries.   furthermore,   the\nconventional   mohr-coulomb   criteria   failed   to   model   the  stress-strain   response   of   rock   under   geothermal\nreservoir   condition ...

# %%
#Remove spacing n dot '\n' & '•'
if bool(regex.search(r'(?<=(\w\w))[\n•](?=(\w\w))',text_punew))==True:
    text_punew_spdo = re.sub(r'[\n•]', ' ', text_punew)
else:
    text_punew_spdo = re.sub(r'[\n•]', '', text_punew)

text_punew_spdo
# Out:
# 'geothermics  65  (2017)  44–59  contents lists available at sciencedirect  geothermics  j o u r n a l h o m e p a g e : w w w . e l s e v i e r . c o m / l o c a t e / g e o t h e r m i c s  mechanical   behaviour   of   australian   strathbogie   granite   under   in-situ stress   and   temperature   conditions:   an   application   to   geothermal energy   extraction w.g.p.   kumari a,   p.g.   ranjith a,∗,   m.s.a.   perera b,   s.   shao a,   b.k.   chen c,   a.   lashin d, n.al  ariﬁ e,   t.d.   rathnaweera a a department  of  civil  engineering,  monash  university,  building  60,  melbourne,  victoria  3800,  australia b department  of  infrastructure  engineering,  building  block  d,  the  university  of  melbourne,  parkville,  melbourne,  3010,  australia c department  of  mechanical  &  aerospace  engineering,  monash  university,  building  36,  melbourne,  victoria  3800,  australia d king  saud  university,  college  of  engineering,  petroleum  and  natural  gas  engineering  department,  p.o.  box  800,  riyadh  11421,  saudi  arabia e king  saud  university,  college  of  science,  geology  and  geophysics  department,  p.o.  box  2455,  riyadh  11451,  saudi  arabia  a   r   t   i  c   l  e    i   n   f   o  a   b   s   t   r   a   c   t  article  history: received  18  may   2016 received  in  revised  form  20  july  2016 accepted  25  july  2016  keywords: geothermal  energy granite high  temperature stress-strain  response triaxial acoustic xrd  geothermal   heat   has   now   been   identiﬁed   as   an   effective   renewable   energy   source   due   to  severe   environmental   impacts   created   by   conventional   fossil   usage   on  global   climatic   change.   however,   its  wide application   has   been   limited   due   to   the   lack   of   knowledge,   particularly   of   the   geothermal   conditions   of reservoir   rocks   at   elevated   temperatures   and   pressures.   such   high   temperatures   and   pressures   possibly alter   the  mechanical   properties   of  reservoir   rocks   due   to   the   associated   micro-structural   and   mineralogical  alterations   of   the   rock   mass,   which   are   an   important   attribute   for   wellbore   stability   and   stimulation   of geothermal   reservoirs   for   safe  and   effective   geothermal   energy   extraction.   this   study   therefore   investigates   the   stress-strain   behaviour   under   in-situ   stress   and   temperature   conditions   by   conducting   a  series of  high-pressure,   high-temperature   tri-axial   experiments   on  australian   strathbogie   granite   under   four different  conﬁning   pressures   (10,   30,   60,   90   mpa)   and   four   different   temperatures   (rt,   100,   200,   300 ◦c). the  effect   of  temperature   on   the   mechanical   behaviour   of   rock   specimens   was   studied   under   tri-axial   conditions   and   the   corresponding   fracture   propagation   behaviour   was   observed   using   an   advanced   acoustic emission   (ae)   system.   the   corresponding   micro-structure   alteration   in   granite   was   observed   using   sem analysis.   according   to   the   ﬁndings,   increasing   temperature   leads   to  an   initial   increment   in   reservoir rock   strength   and   shear   parameters   followed   by   reduction,   and   the   trend   is   aligned   with   the   crack  formation   pattern   of   the  rock   mass.   this   was   further   conﬁrmed   by   the   sem   analysis,   according   to  which the   rock   micro-structure   is   subject   to  only   minor   changes   at   relatively   low   temperatures   and  higher temperatures   cause   micro-cracks   to   develop   along   the   rock   mass   grain   boundaries.   furthermore,   the conventional   mohr-coulomb   criteria   failed   to   model   the  stress-strain   response   of   rock   under   geothermal reservoir   conditions,   and   was   therefore   modiﬁed   for   the   co ...

# %%
#Germany alphabetic umlaut
text_punew_spdo_ger = re.sub(r'(?<=[oua])(¨)','e',text_punew_spdo)
text_punew_spdo_ger = re.sub(r'ß','ss',text_punew_spdo_ger)
text_punew_spdo_ger
# Out:
# 'geothermics  65  (2017)  44–59  contents lists available at sciencedirect  geothermics  j o u r n a l h o m e p a g e : w w w . e l s e v i e r . c o m / l o c a t e / g e o t h e r m i c s  mechanical   behaviour   of   australian   strathbogie   granite   under   in-situ stress   and   temperature   conditions:   an   application   to   geothermal energy   extraction w.g.p.   kumari a,   p.g.   ranjith a,∗,   m.s.a.   perera b,   s.   shao a,   b.k.   chen c,   a.   lashin d, n.al  ariﬁ e,   t.d.   rathnaweera a a department  of  civil  engineering,  monash  university,  building  60,  melbourne,  victoria  3800,  australia b department  of  infrastructure  engineering,  building  block  d,  the  university  of  melbourne,  parkville,  melbourne,  3010,  australia c department  of  mechanical  &  aerospace  engineering,  monash  university,  building  36,  melbourne,  victoria  3800,  australia d king  saud  university,  college  of  engineering,  petroleum  and  natural  gas  engineering  department,  p.o.  box  800,  riyadh  11421,  saudi  arabia e king  saud  university,  college  of  science,  geology  and  geophysics  department,  p.o.  box  2455,  riyadh  11451,  saudi  arabia  a   r   t   i  c   l  e    i   n   f   o  a   b   s   t   r   a   c   t  article  history: received  18  may   2016 received  in  revised  form  20  july  2016 accepted  25  july  2016  keywords: geothermal  energy granite high  temperature stress-strain  response triaxial acoustic xrd  geothermal   heat   has   now   been   identiﬁed   as   an   effective   renewable   energy   source   due   to  severe   environmental   impacts   created   by   conventional   fossil   usage   on  global   climatic   change.   however,   its  wide application   has   been   limited   due   to   the   lack   of   knowledge,   particularly   of   the   geothermal   conditions   of reservoir   rocks   at   elevated   temperatures   and   pressures.   such   high   temperatures   and   pressures   possibly alter   the  mechanical   properties   of  reservoir   rocks   due   to   the   associated   micro-structural   and   mineralogical  alterations   of   the   rock   mass,   which   are   an   important   attribute   for   wellbore   stability   and   stimulation   of geothermal   reservoirs   for   safe  and   effective   geothermal   energy   extraction.   this   study   therefore   investigates   the   stress-strain   behaviour   under   in-situ   stress   and   temperature   conditions   by   conducting   a  series of  high-pressure,   high-temperature   tri-axial   experiments   on  australian   strathbogie   granite   under   four different  conﬁning   pressures   (10,   30,   60,   90   mpa)   and   four   different   temperatures   (rt,   100,   200,   300 ◦c). the  effect   of  temperature   on   the   mechanical   behaviour   of   rock   specimens   was   studied   under   tri-axial   conditions   and   the   corresponding   fracture   propagation   behaviour   was   observed   using   an   advanced   acoustic emission   (ae)   system.   the   corresponding   micro-structure   alteration   in   granite   was   observed   using   sem analysis.   according   to   the   ﬁndings,   increasing   temperature   leads   to  an   initial   increment   in   reservoir rock   strength   and   shear   parameters   followed   by   reduction,   and   the   trend   is   aligned   with   the   crack  formation   pattern   of   the  rock   mass.   this   was   further   conﬁrmed   by   the   sem   analysis,   according   to  which the   rock   micro-structure   is   subject   to  only   minor   changes   at   relatively   low   temperatures   and  higher temperatures   cause   micro-cracks   to   develop   along   the   rock   mass   grain   boundaries.   furthermore,   the conventional   mohr-coulomb   criteria   failed   to   model   the  stress-strain   response   of   rock   under   geothermal reservoir   conditions,   and   was   therefore   modiﬁed   for   the   co ...

# %%
#Over-Spacing
text_punew_spdo_ger_ovsp = re.sub(r'(\s)(?=\s+)','',text_punew_spdo_ger)
text_punew_spdo_ger_ovsp
# Out:
# 'geothermics 65 (2017) 44–59 contents lists available at sciencedirect geothermics j o u r n a l h o m e p a g e : w w w . e l s e v i e r . c o m / l o c a t e / g e o t h e r m i c s mechanical behaviour of australian strathbogie granite under in-situ stress and temperature conditions: an application to geothermal energy extraction w.g.p. kumari a, p.g. ranjith a,∗, m.s.a. perera b, s. shao a, b.k. chen c, a. lashin d, n.al ariﬁ e, t.d. rathnaweera a a department of civil engineering, monash university, building 60, melbourne, victoria 3800, australia b department of infrastructure engineering, building block d, the university of melbourne, parkville, melbourne, 3010, australia c department of mechanical & aerospace engineering, monash university, building 36, melbourne, victoria 3800, australia d king saud university, college of engineering, petroleum and natural gas engineering department, p.o. box 800, riyadh 11421, saudi arabia e king saud university, college of science, geology and geophysics department, p.o. box 2455, riyadh 11451, saudi arabia a r t i c l e i n f o a b s t r a c t article history: received 18 may 2016 received in revised form 20 july 2016 accepted 25 july 2016 keywords: geothermal energy granite high temperature stress-strain response triaxial acoustic xrd geothermal heat has now been identiﬁed as an effective renewable energy source due to severe environmental impacts created by conventional fossil usage on global climatic change. however, its wide application has been limited due to the lack of knowledge, particularly of the geothermal conditions of reservoir rocks at elevated temperatures and pressures. such high temperatures and pressures possibly alter the mechanical properties of reservoir rocks due to the associated micro-structural and mineralogical alterations of the rock mass, which are an important attribute for wellbore stability and stimulation of geothermal reservoirs for safe and effective geothermal energy extraction. this study therefore investigates the stress-strain behaviour under in-situ stress and temperature conditions by conducting a series of high-pressure, high-temperature tri-axial experiments on australian strathbogie granite under four different conﬁning pressures (10, 30, 60, 90 mpa) and four different temperatures (rt, 100, 200, 300 ◦c). the effect of temperature on the mechanical behaviour of rock specimens was studied under tri-axial conditions and the corresponding fracture propagation behaviour was observed using an advanced acoustic emission (ae) system. the corresponding micro-structure alteration in granite was observed using sem analysis. according to the ﬁndings, increasing temperature leads to an initial increment in reservoir rock strength and shear parameters followed by reduction, and the trend is aligned with the crack formation pattern of the rock mass. this was further conﬁrmed by the sem analysis, according to which the rock micro-structure is subject to only minor changes at relatively low temperatures and higher temperatures cause micro-cracks to develop along the rock mass grain boundaries. furthermore, the conventional mohr-coulomb criteria failed to model the stress-strain response of rock under geothermal reservoir conditions, and was therefore modiﬁed for the corresponding in-situ conditions. © 2016 elsevier ltd. all rights reserved. 1. introduction geothermal heat has been identiﬁed as a renewable and reliable energy source, given the severe environmental impacts created by conventional fossil fuels such as coal and oil (martín-gamboa et al., 2015; axelsson, 2010). exploratory geothermal wells have therefore been drilled to test the availability of geothermal reservoir ∗ corresponding author at: deep earth energy laboratory, department of civil engineering, monash university, building 60, melbourne, victoria 3800, australia. e-mail address: ranjith.pg@monash.edu (p.g. ranjith). http://dx.doi.org/10.1016/j.geothermics.2016.07.002 0375-6505/© 2016  ...

# %%
#Revise et al. + lower
text_punew_spdo_ger_ovsp_etal = regex.sub(r'(\w+\s+et al.)','',text_punew_spdo_ger_ovsp)
text_punew_spdo_ger_ovsp_etal
# Out:
# 'geothermics 65 (2017) 44–59 contents lists available at sciencedirect geothermics j o u r n a l h o m e p a g e : w w w . e l s e v i e r . c o m / l o c a t e / g e o t h e r m i c s mechanical behaviour of australian strathbogie granite under in-situ stress and temperature conditions: an application to geothermal energy extraction w.g.p. kumari a, p.g. ranjith a,∗, m.s.a. perera b, s. shao a, b.k. chen c, a. lashin d, n.al ariﬁ e, t.d. rathnaweera a a department of civil engineering, monash university, building 60, melbourne, victoria 3800, australia b department of infrastructure engineering, building block d, the university of melbourne, parkville, melbourne, 3010, australia c department of mechanical & aerospace engineering, monash university, building 36, melbourne, victoria 3800, australia d king saud university, college of engineering, petroleum and natural gas engineering department, p.o. box 800, riyadh 11421, saudi arabia e king saud university, college of science, geology and geophysics department, p.o. box 2455, riyadh 11451, saudi arabia a r t i c l e i n f o a b s t r a c t article history: received 18 may 2016 received in revised form 20 july 2016 accepted 25 july 2016 keywords: geothermal energy granite high temperature stress-strain response triaxial acoustic xrd geothermal heat has now been identiﬁed as an effective renewable energy source due to severe environmental impacts created by conventional fossil usage on global climatic change. however, its wide application has been limited due to the lack of knowledge, particularly of the geothermal conditions of reservoir rocks at elevated temperatures and pressures. such high temperatures and pressures possibly alter the mechanical properties of reservoir rocks due to the associated micro-structural and mineralogical alterations of the rock mass, which are an important attribute for wellbore stability and stimulation of geothermal reservoirs for safe and effective geothermal energy extraction. this study therefore investigates the stress-strain behaviour under in-situ stress and temperature conditions by conducting a series of high-pressure, high-temperature tri-axial experiments on australian strathbogie granite under four different conﬁning pressures (10, 30, 60, 90 mpa) and four different temperatures (rt, 100, 200, 300 ◦c). the effect of temperature on the mechanical behaviour of rock specimens was studied under tri-axial conditions and the corresponding fracture propagation behaviour was observed using an advanced acoustic emission (ae) system. the corresponding micro-structure alteration in granite was observed using sem analysis. according to the ﬁndings, increasing temperature leads to an initial increment in reservoir rock strength and shear parameters followed by reduction, and the trend is aligned with the crack formation pattern of the rock mass. this was further conﬁrmed by the sem analysis, according to which the rock micro-structure is subject to only minor changes at relatively low temperatures and higher temperatures cause micro-cracks to develop along the rock mass grain boundaries. furthermore, the conventional mohr-coulomb criteria failed to model the stress-strain response of rock under geothermal reservoir conditions, and was therefore modiﬁed for the corresponding in-situ conditions. © 2016 elsevier ltd. all rights reserved. 1. introduction geothermal heat has been identiﬁed as a renewable and reliable energy source, given the severe environmental impacts created by conventional fossil fuels such as coal and oil (martín-, 2015; axelsson, 2010). exploratory geothermal wells have therefore been drilled to test the availability of geothermal reservoir ∗ corresponding author at: deep earth energy laboratory, department of civil engineering, monash university, building 60, melbourne, victoria 3800, australia. e-mail address: ranjith.pg@monash.edu (p.g. ranjith). http://dx.doi.org/10.1016/j.geothermics.2016.07.002 0375-6505/© 2016 elsevier ltd. ...

# %%
#Eliminate fig and table
text_punew_spdo_ger_ovsp_etal = re.sub(r'ﬁ','fi',text_punew_spdo_ger_ovsp_etal)
text_punew_spdo_ger_ovsp_etal_fig = re.sub(r'(table|tables|figure|figures|fig.?|figs.)\s+(\d+|\d+.)', '', text_punew_spdo_ger_ovsp_etal)
text_punew_spdo_ger_ovsp_etal_fig
# Out:
# 'geothermics 65 (2017) 44–59 contents lists available at sciencedirect geothermics j o u r n a l h o m e p a g e : w w w . e l s e v i e r . c o m / l o c a t e / g e o t h e r m i c s mechanical behaviour of australian strathbogie granite under in-situ stress and temperature conditions: an application to geothermal energy extraction w.g.p. kumari a, p.g. ranjith a,∗, m.s.a. perera b, s. shao a, b.k. chen c, a. lashin d, n.al arifi e, t.d. rathnaweera a a department of civil engineering, monash university, building 60, melbourne, victoria 3800, australia b department of infrastructure engineering, building block d, the university of melbourne, parkville, melbourne, 3010, australia c department of mechanical & aerospace engineering, monash university, building 36, melbourne, victoria 3800, australia d king saud university, college of engineering, petroleum and natural gas engineering department, p.o. box 800, riyadh 11421, saudi arabia e king saud university, college of science, geology and geophysics department, p.o. box 2455, riyadh 11451, saudi arabia a r t i c l e i n f o a b s t r a c t article history: received 18 may 2016 received in revised form 20 july 2016 accepted 25 july 2016 keywords: geothermal energy granite high temperature stress-strain response triaxial acoustic xrd geothermal heat has now been identified as an effective renewable energy source due to severe environmental impacts created by conventional fossil usage on global climatic change. however, its wide application has been limited due to the lack of knowledge, particularly of the geothermal conditions of reservoir rocks at elevated temperatures and pressures. such high temperatures and pressures possibly alter the mechanical properties of reservoir rocks due to the associated micro-structural and mineralogical alterations of the rock mass, which are an important attribute for wellbore stability and stimulation of geothermal reservoirs for safe and effective geothermal energy extraction. this study therefore investigates the stress-strain behaviour under in-situ stress and temperature conditions by conducting a series of high-pressure, high-temperature tri-axial experiments on australian strathbogie granite under four different confining pressures (10, 30, 60, 90 mpa) and four different temperatures (rt, 100, 200, 300 ◦c). the effect of temperature on the mechanical behaviour of rock specimens was studied under tri-axial conditions and the corresponding fracture propagation behaviour was observed using an advanced acoustic emission (ae) system. the corresponding micro-structure alteration in granite was observed using sem analysis. according to the findings, increasing temperature leads to an initial increment in reservoir rock strength and shear parameters followed by reduction, and the trend is aligned with the crack formation pattern of the rock mass. this was further confirmed by the sem analysis, according to which the rock micro-structure is subject to only minor changes at relatively low temperatures and higher temperatures cause micro-cracks to develop along the rock mass grain boundaries. furthermore, the conventional mohr-coulomb criteria failed to model the stress-strain response of rock under geothermal reservoir conditions, and was therefore modified for the corresponding in-situ conditions. © 2016 elsevier ltd. all rights reserved. 1. introduction geothermal heat has been identified as a renewable and reliable energy source, given the severe environmental impacts created by conventional fossil fuels such as coal and oil (martín-, 2015; axelsson, 2010). exploratory geothermal wells have therefore been drilled to test the availability of geothermal reservoir ∗ corresponding author at: deep earth energy laboratory, department of civil engineering, monash university, building 60, melbourne, victoria 3800, australia. e-mail address: ranjith.pg@monash.edu (p.g. ranjith). http://dx.doi.org/10.1016/j.geothermics.2016.07.002 0375-6505/© 2016 elsevi ...

# %%
#Eliminate email
text_punew_spdo_ger_ovsp_etal_fig_emai = regex.sub(r'\b[\w-.]+?@\w+?.\w+[\w\.\-]+\b','',text_punew_spdo_ger_ovsp_etal_fig)
text_punew_spdo_ger_ovsp_etal_fig_emai
# Out:
# 'geothermics 65 (2017) 44–59 contents lists available at sciencedirect geothermics j o u r n a l h o m e p a g e : w w w . e l s e v i e r . c o m / l o c a t e / g e o t h e r m i c s mechanical behaviour of australian strathbogie granite under in-situ stress and temperature conditions: an application to geothermal energy extraction w.g.p. kumari a, p.g. ranjith a,∗, m.s.a. perera b, s. shao a, b.k. chen c, a. lashin d, n.al arifi e, t.d. rathnaweera a a department of civil engineering, monash university, building 60, melbourne, victoria 3800, australia b department of infrastructure engineering, building block d, the university of melbourne, parkville, melbourne, 3010, australia c department of mechanical & aerospace engineering, monash university, building 36, melbourne, victoria 3800, australia d king saud university, college of engineering, petroleum and natural gas engineering department, p.o. box 800, riyadh 11421, saudi arabia e king saud university, college of science, geology and geophysics department, p.o. box 2455, riyadh 11451, saudi arabia a r t i c l e i n f o a b s t r a c t article history: received 18 may 2016 received in revised form 20 july 2016 accepted 25 july 2016 keywords: geothermal energy granite high temperature stress-strain response triaxial acoustic xrd geothermal heat has now been identified as an effective renewable energy source due to severe environmental impacts created by conventional fossil usage on global climatic change. however, its wide application has been limited due to the lack of knowledge, particularly of the geothermal conditions of reservoir rocks at elevated temperatures and pressures. such high temperatures and pressures possibly alter the mechanical properties of reservoir rocks due to the associated micro-structural and mineralogical alterations of the rock mass, which are an important attribute for wellbore stability and stimulation of geothermal reservoirs for safe and effective geothermal energy extraction. this study therefore investigates the stress-strain behaviour under in-situ stress and temperature conditions by conducting a series of high-pressure, high-temperature tri-axial experiments on australian strathbogie granite under four different confining pressures (10, 30, 60, 90 mpa) and four different temperatures (rt, 100, 200, 300 ◦c). the effect of temperature on the mechanical behaviour of rock specimens was studied under tri-axial conditions and the corresponding fracture propagation behaviour was observed using an advanced acoustic emission (ae) system. the corresponding micro-structure alteration in granite was observed using sem analysis. according to the findings, increasing temperature leads to an initial increment in reservoir rock strength and shear parameters followed by reduction, and the trend is aligned with the crack formation pattern of the rock mass. this was further confirmed by the sem analysis, according to which the rock micro-structure is subject to only minor changes at relatively low temperatures and higher temperatures cause micro-cracks to develop along the rock mass grain boundaries. furthermore, the conventional mohr-coulomb criteria failed to model the stress-strain response of rock under geothermal reservoir conditions, and was therefore modified for the corresponding in-situ conditions. © 2016 elsevier ltd. all rights reserved. 1. introduction geothermal heat has been identified as a renewable and reliable energy source, given the severe environmental impacts created by conventional fossil fuels such as coal and oil (martín-, 2015; axelsson, 2010). exploratory geothermal wells have therefore been drilled to test the availability of geothermal reservoir ∗ corresponding author at: deep earth energy laboratory, department of civil engineering, monash university, building 60, melbourne, victoria 3800, australia. e-mail address:  (p.g. ranjith). http://dx.doi.org/10.1016/j.geothermics.2016.07.002 0375-6505/© 2016 elsevier ltd. all rights re ...

# %%
#Eliminate website
text_punew_spdo_ger_ovsp_etal_fig_emai_web = regex.sub(r'(http|https|ftp|ssh)://([\w_-]+(?:(?:\.[\w\s_-]+)+))([\w.,@?^=%&:/~+#-]*[\w@?^=%&/~+#-])?','',text_punew_spdo_ger_ovsp_etal_fig_emai)
text_punew_spdo_ger_ovsp_etal_fig_emai_web
# Out:
# 'geothermics 65 (2017) 44–59 contents lists available at sciencedirect geothermics j o u r n a l h o m e p a g e : w w w . e l s e v i e r . c o m / l o c a t e / g e o t h e r m i c s mechanical behaviour of australian strathbogie granite under in-situ stress and temperature conditions: an application to geothermal energy extraction w.g.p. kumari a, p.g. ranjith a,∗, m.s.a. perera b, s. shao a, b.k. chen c, a. lashin d, n.al arifi e, t.d. rathnaweera a a department of civil engineering, monash university, building 60, melbourne, victoria 3800, australia b department of infrastructure engineering, building block d, the university of melbourne, parkville, melbourne, 3010, australia c department of mechanical & aerospace engineering, monash university, building 36, melbourne, victoria 3800, australia d king saud university, college of engineering, petroleum and natural gas engineering department, p.o. box 800, riyadh 11421, saudi arabia e king saud university, college of science, geology and geophysics department, p.o. box 2455, riyadh 11451, saudi arabia a r t i c l e i n f o a b s t r a c t article history: received 18 may 2016 received in revised form 20 july 2016 accepted 25 july 2016 keywords: geothermal energy granite high temperature stress-strain response triaxial acoustic xrd geothermal heat has now been identified as an effective renewable energy source due to severe environmental impacts created by conventional fossil usage on global climatic change. however, its wide application has been limited due to the lack of knowledge, particularly of the geothermal conditions of reservoir rocks at elevated temperatures and pressures. such high temperatures and pressures possibly alter the mechanical properties of reservoir rocks due to the associated micro-structural and mineralogical alterations of the rock mass, which are an important attribute for wellbore stability and stimulation of geothermal reservoirs for safe and effective geothermal energy extraction. this study therefore investigates the stress-strain behaviour under in-situ stress and temperature conditions by conducting a series of high-pressure, high-temperature tri-axial experiments on australian strathbogie granite under four different confining pressures (10, 30, 60, 90 mpa) and four different temperatures (rt, 100, 200, 300 ◦c). the effect of temperature on the mechanical behaviour of rock specimens was studied under tri-axial conditions and the corresponding fracture propagation behaviour was observed using an advanced acoustic emission (ae) system. the corresponding micro-structure alteration in granite was observed using sem analysis. according to the findings, increasing temperature leads to an initial increment in reservoir rock strength and shear parameters followed by reduction, and the trend is aligned with the crack formation pattern of the rock mass. this was further confirmed by the sem analysis, according to which the rock micro-structure is subject to only minor changes at relatively low temperatures and higher temperatures cause micro-cracks to develop along the rock mass grain boundaries. furthermore, the conventional mohr-coulomb criteria failed to model the stress-strain response of rock under geothermal reservoir conditions, and was therefore modified for the corresponding in-situ conditions. © 2016 elsevier ltd. all rights reserved. 1. introduction geothermal heat has been identified as a renewable and reliable energy source, given the severe environmental impacts created by conventional fossil fuels such as coal and oil (martín-, 2015; axelsson, 2010). exploratory geothermal wells have therefore been drilled to test the availability of geothermal reservoir ∗ corresponding author at: deep earth energy laboratory, department of civil engineering, monash university, building 60, melbourne, victoria 3800, australia. e-mail address:  (p.g. ranjith).  0375-6505/© 2016 elsevier ltd. all rights reserved. rocks (rocks at elevated temperatures) and  ...

# %% [markdown]
# ## Pre-Processing 2 : Sentences with Conditioning, Stemmer / Lemmatizer,  & Stopwords

# %%
#Splitted into sentences by Spacy
spc_text = spc(text_punew_spdo_ger_ovsp_etal_fig_emai_web)

#Prep []
prepro1 = []
col_intro = []
stop_ack_stc = []
stop_ref_stc = []
name = []
pca = '!"#$%&\*+/:;<=>?@[\]^_`{|}~'
pattern_comb = regex.compile(r'([a-z]+[\d]+|\d+[a-z]+|\d+[{}]+|[a-z]+[{}]+|[{}]+[a-z]+|[{}]+[\d]+)'.format(pca,pca,pca,pca))

#list all name
for i in spc_text.ents:
    if i.label_.lower() == 'person':
        name.append(i.text)
    else:
        pass

#List of Sentences with lemmatization
for i,j in enumerate(spc_text.sents):
    
    #Eliminate word - number - punc-chars combination
    sent_lem = regex.sub(pattern_comb,'',j.lemma_)
    
    #delete name
    if len(name) != 0:
        try:
            sent_lem = regex.sub(r",*(\s*\b(?:{}))\b".format("|".join(name)),'',sent_lem)
        except:
            pass
    else:
        pass
    
    prepro1.append(sent_lem)
    
    #Serach for the start pf acknowledgements and references
    if bool(re.search('(acknowledgments|acknowledgment)',sent_lem)) == True:
        stop_ack_stc.append(i)
        
    if bool(re.search('(references|reference)',sent_lem)) == True:
        stop_ref_stc.append(i)
        
    elif bool(re.search('(introduction)',sent_lem)) == True:
        col_intro.append(i)

#Cut parts before Introduction and after the acknowledgments or references
try:
    if len(stop_ack_stc) == 0:
        try:
            prepro1 = prepro1[col_intro[0]:stop_ref_stc[-1]]
        except:
            prepro1 = prepro1[:stop_ref_stc[-1]]
    else:
        try:
            prepro1 = prepro1[col_intro[0]:stop_ack_stc[-1]]
        except:
            prepro1 = prepro1[:stop_ack_stc[-1]]
except:
    pass
    
#All results
brute_result = prepro1

# %%
prepro1
# Out:
# ['introduction geothermal heat have be identify as a renewable and reliable energy source, give the severe environmental impact create by conventional fossil fuel such as coal and oil (martín-, 2010).',
#  'exploratory geothermal well have therefore be drill to test the availability of geothermal reservoir ∗ correspond author  deep earth energy laboratory, department of civil engineering, monash university, building 60, melbourne, victoria 3800, australia.',
#  'e-mail   (p.g.).',
#  '',
#  '0375-',
#  '© 2016 elsevier ltd.',
#  'all right reserve.',
#  'rock (rock at elevated temperature) and deep granite reservoir have be find to have adequate temperature to serve as a geothermal reservoir (, 2013).',
#  'such exploration involve find vast block of   with fracture system.',
#  'such rock can be use to generate electricity.',
#  'in this process, water be first inject and circulate through the fracture in the geothermal reservoir and eventually pump back to the surface as steam.',
#  'however, the exploration of geothermal resource have become a challenge to engineer and geologist, due to the high temperature and stress environment in geothermal reservoir.',
#  'for this reason, laboratory experiment conduct under high pressure and temperature condition (geothermal condition) can assist in provide\x0cw.g.p.  / geothermics 65 (2017) 44–59 45 basic prediction.',
#  'a large number of laboratory experiment have therefore be conduct since 1970 to investigate the inﬂuence of high pressure and temperature on rock in relation to geothermal heat extraction (, 2016), deep geological disposal of nuclear waste ( and franc¸ ois, 1980), deep mining (wawersik and hannum, 1980) and geological  storage (, 2014).',
#  'the mechanical behaviour of reservoir rock be significantly inﬂuence by elevated temperature, because they cause the micro-structure of the rock mass to be alter through thermal expansion, the development of new micro-crack, extend or widen the exist micro crack and various mineralogical alteration.',
#  'rock strength-deformation criterion change with temperature, and some rock mechanical property, such as compressive strength, tensile strength, elastic modulus, cohesive strength and friction angle, decrease with increase temperature (,  , 2008).',
#  'however, such alteration be also affect by the confinement apply on the rock mass, and confine pressure cause the suppression of thermal crack and the widening of exist micro-crack.',
#  'this result in further alteration of the rock mass mechanical property, result in change failure mode (, 1966).',
#  'study have identify the transition of rock failure mode from brittle to ductile with increase confinement.',
#  'however, this transition be diverse due to the different mineralogical composition and grain boundary in different rock (, 1982).',
#  'although many study have be conduct to investigate the temperature-dependent mechanical behaviour of reservoir rock, most experiment have be conduct in unconfined environment (,  , 2014).',
#  'pre',
#  '-heat the specimen to the correspond temperature range and test at room temperature have be frequently do ( and,  , 2008), but the method be not reliable, as geothermal reservoir experience continuous thermal stress.',
#  'such limitation have occur mainly due to the limited number of appropriate test facility available to simulate the stress and temperature condition of actual geothermal reservoir.',
#  'although some study have analytically and numerically evaluate the mechanical property of rock under high temperature and pressure ( and,  ,  , 2016), to date none have capture the stress-strain behaviour and failure criterion of rock over a wide range of confine pressure and temperature, particularly for australian granite.',
#  'however, the thermo-elastic response and appropriate failure criterion be essential input for many engineering application under high pressure and temperature, include geothermal extraction application.',
#  'this study therefore intend to fill this gap, and it be hope it will make an important contribution to many deep underground application.',
#  '2. methodology 2.1.',
#  'test material granite be an abundant crystalline rock in the earth with medium to coarse grain which be form as a result of the slow cooling of magma.',
#  'granite therefore have abundant radioactive element (k, th, and u).',
#  'such element bring elevated geothermal gradient to deep granite reservoir, which therefore have ideal condition as geothermal reservoir.',
#  'the mineralogical composition of granite mainly consist of quartz, feldspar, plagioclase and biotite, and small amount of muscovite, amphibole, hornblende and opaque (, 2008).',
#  'for the present study, sample be collect from the strathbogie batholith, which be a composite granitoid intrusion body spread over more than 1500  in 150 km north-east from melbourne ().',
#  'strathbogie granite be a high-level, discordant .',
#  'sampling location of strathbogie batholith in central victoria.',
#  'physical, mechanical and petrographic property of strathbogie granite (obtain under room temperature and atmospheric pressure condition).',
#  'rock type granite colour average grain size petrographic description bulk density () compressive strength (mpa) elastic modulus (gpa) porosity (%) \u242em white with dark brown 70–600 mainly consist of feldspar, biotite, quartz and plagioclase equigranular, coarse grained, s-type granite 2703.4 118.17 9.09 1.16  result of xrd analysis.',
#  'mineral id alpha quartz sodic and intermediate plagioclase biotite—phlogopite k-feldspar clinochlore muscovite—sericite dolomite—ankerite other mineral  50 16 15 13 2 2 1 1 granite that mainly consist of quartz, k-feldspar, cordierite and biotite (, 1981).',
#  'the select granite type be coarsegrained and white and dark brown in colour with around 1. porosity.',
#  '',
#  'present a close-up view of a typical strathbogie granite sample, an optical microscopic image and an sem image of its thin section.',
#  'as can be see in (b), clear mineralogical assembling can be observe in the granite specimen, mainly with quartz, k-feldspar and plagioclase.',
#  'as show in , the grain size be measure from a thin section of this granite and find to be \u242em with only a small number mainly in the range of 0 mm–200 of large grain ( mm) (, 2014).  summarize the physical, mechanical and petrographic property of the test strathbogie granite.',
#  'in addition, an xrd analysis be conduct to determine the mineralogical composition of the select granite and the result be show in .',
#  'as the table show, quartz be the predominant mineral in the select granite (), follow by  of sodic and intermediate biotite and  of plagioclase.',
#  'the mineralogical composition of this particular granitic composition be representative of the composition of the majority of the earth’s granite (good, 1995).',
#  'all the physical property in  and 2\x0c46 w.g.p.  / geothermic 65 (2017) 44–59 .',
#  '(a) close-up view of a sample (b) microscopic image of a thin section of a sample (c) sem image of a thin section of a sample.',
#  'be obtain by conduct various test in the  xrd analysis (mineral composition), uniaxial compression testing (compressive strength, elastic modulus), thin section analysis (average grain size), mercury intrusion testing (porosity) and volume and weight measurement (bulk density).',
#  '2.2.',
#  'sample preparation sample preparation and testing be carry out at the deep earth energy research laboratory (deerl) in the civil engineering department of monash university, and the sample preparation be conduct in accordance with the astm standard for tri-axial compressive testing (astm -10 (2010)).',
#  'in order to maintain consistency, all the sample be core to 22.5 mm in diameter use the same block of granite at the same orientation.',
#  'during the sampling great care be take to obtain sample with the same crystalline orientation, and sample with different crystalline orientation, internal layer and visible crack be discard.',
#  'it should be note that coring-induce rock-microstructure alteration be an important aspect to consider in laboratory experiment, although few study have consider this effect.',
#  'to avoid such issue, a very small coring rate be adopt and water be use as a lubricant.',
#  'the core specimen be then cut into 45 mm high cylinder and both end of the specimen be grind to produce two parallel surface perpendicular to the axis of the cylindrical specimen.',
#  '2.3.',
#  'experimental procedure tri-axial experiment be conduct on sample under four different confining pressure (10, 30, 60 and 90 mpa) and four different temperature (rt, 100, 200, 300 ◦c).',
#  'these experimental condition be select, because the most preferable hot dry rock system be generally locate at depth of 2.5–3.5 km and have around 70 mpa–120 mpa confining pressure (assume the reservoir rock density be equal to 2500 ) and temperature of 200–350 ◦c (, 2013).',
#  'the different confining pressure and temperature be select to simulate the reservoir depth effect and to obtain a sufficient datum set to understand the failure criterion under different temperature.',
#  'the complete arrangement of the tri-axial cell be show in .',
#  'the prepare sample be first place inside the cell and the require confining pressure be then apply use a silicon oil system, and an anneal copper sleeve be use to isolate the sample from the confine liquid (refer to (b).',
#  'a mica-insulate metal band heater be use to heat the pressure cell and consequently the rock sample.',
#  'the temperature of the cell be adjust use a controller and a constant small heating rate of 2.5 ◦min be use to prevent micro-structural damage due to sudden thermal shock.',
#  'two separate thermocouple be use to achieve precise temperature control, and the reading of the thermocouple instal inside the cell ((b)) be record by the data acquisition system.',
#  'the other thermocouple that be attach to the barrel ((a)) be use to control the band heater.',
#  'furthermore, the barrel and the top of the pressure cell be cover use an insulate blanket to reduce heat loss during the experiment and to minimise the inﬂuence of air ﬂow towards the cell.',
#  'all the test be start once the system have achieve a steady state to ensure uniformity in temperature and pressure across the sample.',
#  'equilibrium be ensure by monitor the confinement pump volume and the thermocouple reading inside the cell (locate very close to the specimen).',
#  'under steady-state condition, constant pump volume and constant temperature be observe and testing be initiate.',
#  'a constant loading pump ﬂow rate of 1 min be adopt for all the test specimen and the convert displacement rate be 0.05 min.',
#  'it should be note that a small shaft resistance exist as a result of the sealing of the hydraulic cylinder, and this effect be consider in the calibration of the loading cell.',
#  'the sealing resistance be obtain by measure the pump pressure to initiate a movement in the loading shaft, and this be deduct from each pressure reading to eliminate the resistance of the sealing dur\x0cw.g.p.  / geothermics 65 (2017) 44–59 47 use the typical-coulomb brittle deformation.',
#  'the deviatoric stress-strain plot of the granite sample () exhibit concave upward curvilinear trend from initial loading to the peak value, beyond which strain softening occur, cause a rapid stress drop to a residual value.',
#  'increase peak stress with increase confine pressure can be observe, which be to be expect, accord to typical-coulomb type brittle failure ( and, 2005).',
#  'traditionally, rock failure in compression can occur in two main  (a) dilatancy and failure by strain softening under relatively low confine pressure and (b) failure by strain harden under elevate confining pressure, and a transitional regime may be observe at intermediate pressure.',
#  'these transitional failure mode have be refer to as -, and complex localize feature such as conjugate shear band can be observe under such condition (,  , 2004).',
#  'by visual inspection of the post-failure sample, important information about the alteration of the granite failure mechanism with confine pressure and temperature can be identify.',
#  'postfailure image () be therefore collect after each test.',
#  'accord to the post-failure image, specimen that fail at 10–60 mpa confining pressure mainly fail by shear localization along an inclined macroscopic shear band with a single shear zone across each sample.',
#  'however, sample test at high confinement of 90 mpa and 120 mpa (at 100 ◦c)',
#  'exhibit strain harden characteristic after achieve the peak stress, and several conjugate shear band could be observe on the cylindrical sample surface, instead of the single shear band observe early.',
#  'this characteristic be significant at 120 mpa confining pressure.',
#  'however, it should be note that only one test be conduct at 120 mpa confinement, because at such high confining pressure the correspond failure load of granite exceed the bottom pedestal’s load-bear capacity.',
#  'far, a progressive reduction be observe in the failure plane angle with respect to the minor principal stress direction with increase confine pressure, which imply a reduction in friction angle, possibly due to the great quasi-brittle behaviour that be show by granite sample at high confining pressure (, 2001).',
#  '3.2. effect of temperature and confine pressure on mechanical property of strathbogie granite  illustrate the inﬂuence of temperature on the deviatoric stress of the test granite under each confinement.',
#  'as the figure show, the inﬂuence of confinement be more significant than that of temperature in the temperature range consider here.',
#  ' and (1979) confirm that at low confining pressure considerable thermal cracking occur at relatively low temperature.',
#  'if thermal cracking be responsible for the reduction in failure strength, a sharp reduction in deviatoric stress with increase temperature (with suppression of thermal crack) should be exhibit under unconfined pressure condition.',
#  'however, base on the experimental result, under unconfined condition, up to 100 ◦c, 17. of increment in deviatoric stress be follow by 2. and 10. reduction at 200 ◦c and 300 ◦c, respectively.',
#  'however, when confinement be apply, strength reduction be initiate after high temperature of 200 ◦c, mainly due to the inhibition of a thermal crack by induce compressive force.',
#  'thermal cracking be therefore an important strength property alteration mechanism in reservoir rock under certain confine pressure condition.',
#  'a clear inﬂuence of temperature on deviatoric stress at any depth or confinement can be observe, and increase the temperature from room temperature to 200 ◦c cause an increment in deviatoric stress, and far increase of temperature to 300 ◦c',
#  'cause a slight reduction in it.',
#  'this be because the thermal expansion which occur with increase temperature cause the reduction of .',
#  '(a) high-pressure, high-temperature tri-axial machine (b) inside view of the cell.',
#  'e calibration.',
#  'however, it should be note that, compare to the large axial load, this resistance be negligible which be only 0. of maximum measurement.',
#  'during the load application, the axial strain be measure use linear variable differential transducer (lvdt) attach to the ram of the load cell ((a)).',
#  'an acoustic emission (ae) system be also employ in the testing of sample to record the datum relate to the fracturing process.',
#  'the ae system adopt be a peripheral component interconnection (pci) system with a nominal resolution frequency of 500 khz.',
#  'during the experiment, two sensor be attach to either side of the loading shaft and with the external amplifier, which generate low frequency acoustic wave with the fracturing of the sample.',
#  'in addition, possible micro-structural and mineralogical change that occur during thermal and confinement effect be check use sem analysis.',
#  '3. result and discussion 3.1.',
#  'the overall stress-strain response the inﬂuence of temperature on the stress-strain behaviour of the test granite be consider first and the test result (deviatoric load at failure, deviatoric stress at failure, triaxial compressive strength and elastic modulus) be give in .  illustrate the relationship between deviatoric stress and axial strain curve for the sample test at 10, 30, 60 and 90 mpa confining pressure at various temperature (20, 100, 200, 300 ◦c).',
#  'in relation to the stress-strain curve of the strathbogie granite under triaxial loading, the correspond failure mode be characterize\x0c48 w.g.p.  / geothermics 65 (2017) 44–59  mechanical property of strathbogie granite at different test temperature and pressure.',
#  'confining pressure (mpa) deviatoric load at failure (kn) \u24341–\u24343 (mpa) 118.2 186.9 311.9 422.5 503.3 \u24341 (mpa) 118.2 196.9 341.9 482.5 593.3 1390 235.5 363.7 500.9 600.3 688.9 135.5 268.2 404.4 5690 639.6 126.3 259.4 397.5 524.6 606.5 139.0 225.5 333.7 440.9 510.3 568.9 135.53 258.25 374.42 508.98 549.6 126.3 249.4 367.5 464.6 516.5 100 ◦c elastic modulus (gpa) 9.1 18.3 21.6 22.3 22.5 8.9 19.3 23.0 23.3 22.7 24.2 8.5 20.2 23.4 24.1 25.4 8.0 20.1 23.2 23.8 24.6 10 mpa 30 mpa 60 mpa 90 mpa 1 2 3 4 axial strain (%)',
#  '300',
#  '◦',
#  'c',
#  '10',
#  'mpa',
#  '30 mpa 60 mpa 90 mpa 4 5 3',
#  '(%) 0 0 1 2 axial strain .',
#  'correspond stress–strain response of granite at different temperature.',
#  'the distance between the interface of individual mineral, which increase their mutual attraction and bonding strength (, 1972).',
#  'however, further increase of temperature cause the crystalline particle of the rock mass to fracture through pre-exist grain boundary between mineral grain with different thermoelastic modulus and thermal conductivity, result in reduce rock strength (,  homand-etienne and, 1989).',
#  'accord to the tri-axial experimental study conduct by (1982) and and (1977), increase the temperature lead to reduction in the failure stress of westerly granite under any 600 500 400 300 200 100 0 0 σ1-σ3 (mpa) 600 500 400 300 200 100 σ1 -σ3(mpa) 47.0 90.9 175.4 281.6 371.3 55.2 104.6 183.5 271.0 368.6 450.3 53.9 116.7 195.9 316.6 383.2 50.2 93.6 195.7 272.1 306.0 20 ◦c 10 mpa 30 mpa 60 mpa 90 mpa 4 5 1 2 3 axial strain (%) 200 ◦c 10 mpa 30 mpa 60 mpa 90 mpa 1 2 3 4 axial strain (%) 0 10 30 60 90 0 10 30 60 90 120 0 10 30 60 90 0 10 30 60 90 600 500 400 300 200 100 0 0',
#  'σ1',
#  '-',
#  'σ3(mpa) 600 500 400 300 200 100 σ1-σ3(mpa) 0 0 temperature (◦c) rt 100 200 300',
#  'w.g.p.',
#  '/ geothermics 65 (2017) 44–59 49 .',
#  'post-failure image of test specimen.',
#  'confining pressure.',
#  'the reduction of strength characteristic be relatively small up to 500 ◦c and beyond that an accelerate downward trend be identify.',
#  'furthermore, wide localized zone be observe at high temperature in the post-failure image.',
#  'however, these study be conduct at wide temperature range (up to 700 ◦c and 900 ◦c, respectively) and the researcher therefore do not pay close attention to reservoir rock behaviour under relatively low geothermal temperature range ( ◦c).',
#  'this be the focus of the present study, accord to which there be an initial strengthening and stiffening in granite with increase temperature at low temperature (up to 200 ◦c), and increase the temperature beyond a certain value cause a gradual reduction in failure stress with increase temperature.',
#  'elastic modulus be an important mechanical property of any reservoir rock, and describe the brittle characteristic of the rock mass.',
#  'it be therefore often use to evaluate many in-situ stress application, include wellbore stability, fracturing possibility and tectonic stress distribution ( and page, 1982).',
#  'the temperature-dependent brittle property (elastic modulus) of the test granite be then evaluate.',
#  'the elastic region of each stress-strain curve be use to calculate the temperature and pressure-dependent young’s modulus (e) and the result be show in .',
#  'the axial strain be measure use lvdt attach to the loading ram with a linearity ±0. f. (full scale) (±0.0075 mm) and infinite resoluerror of tion (no hysteresis).',
#  'an increment of the modulus of strathbogie granite with increase temperature up to 200 ◦c can be observe, and further increase of temperature (to 300 ◦c) cause the elastic modulus to be slightly reduce for any confinement.',
#  "this trend be\x0ca 'brittle' or general increment in elastic modulus with increase confinement can be observe until 90 mpa, and a further increase of confinement (to 120 mpa) reduce the young’s modulus considerably.",
#  'with increase confine stress additional plastic deformation occur, exhibit strain-harden characteristic in granite under high confinement.',
#  "however, within the range of the experiment conduct (10 mpa–120 mpa) it cannot be definitively identify as a 'ductile' regime.",
#  "however, the strain-harden behaviour observe at 120 mpa indicate transitional characteristic and this can be identify as 'quasi-brittle' behaviour (, 2001).",
#  'the initial young’s modulus reduction with increase confinement be observe by and page (1982), who conduct test up to 55 mpa confining pressure.',
#  'however, the latter behaviour be not observe by these researcher.',
#  'interestingly, accord to the research literature, at low temperature ( ◦c) some granite type be more temperature-sensitive, while in contrast, some granite be more temperature-sensitive at high temperature.',
#  'the initial strength enhancement be more significant for coarse-grained granite and granodiorite than for fine-grained granite.',
#  'for example, accord to and page (1982), stripa granite be more sensitive to temperature at relatively low temperature ( ◦c), and westerly granite be more sensitive to temperature at high temperature ( ◦c).',
#  'such contradictory behaviour may occur in granite due to the different grain size distribution, grain orientation, mineralogical composition and heterogeneity of different granite type.',
#  'this indicate the importance of study the mineralogical composition and microstructural inﬂuence of granite on such on temperature-dependent strength variation.',
#  '3.3. effect of temperature on shear strength parameter of strathbogie granite  illustrate the variation of deviatoric stress of the test granite with confine pressure for each temperature.',
#  'the figure show that increase confinement cause the granite’s deviatoric stress to increase non-linearly and gradually come to a steady state.',
#  'this be consistent with similar previous study, which have clearly show the enhancement of rock strength with increase confinement, and the increase rate be reduce with increase confine pressure (,  , 2011).',
#  'this be because at low confining pressure there be a high dilation potential.',
#  'therefore, the ability to open rock micro-crack be high, result in high friction angle.',
#  'however, this dilation potential and the correspond tendency for micro-crack to open be suppress with increase confinement, result in low friction angle at high confining pressure.',
#  'therefore, the failure mechanism of the rock shift from brittle to ductile with increase confinement, change the shape of the-coulomb failure envelope, and accord to (1976), at critical confining pressure the-coulomb failure envelope reach a zero gradient.',
#  'this have also be show by (1983).',
#  'the present study have clearly identify this rock behaviour in the-coulomb failure envelope develop for each temperature condition (refer to ).',
#  'accord to , the traditional linear-coulomb criterion be applicable only in the brittle region of the failure envelope, and at high confinew.g.p.  / geothermics 65 (2017) 44–59 consistent with the temperature-dependent strength behaviour of the granite describe above.',
#  'the reason for the initial elastic module increment may be that the specimen become more brittle at the initial temperature range due to thermally-induce volumetric expansion and the associate pore volume reduction.',
#  'the later slight reduction of young’s modulus with increase temperature exhibit an enhancement in ductile behaviour (quasi-brittle characteristic) with further increase of temperature.',
#  'this be possibly due to the increase crack density cause by the induce thermal crack development and the relate weakening of the granite.',
#  '600 500 400 300 200 100 0 50 σ1-σ3(mpa)',
#  '0',
#  '100',
#  'temperature (ºc) 200 unconfined 60 mpa 10 mpa 90 mpa 300 30 mpa .',
#  'variation of deviatoric stress with different temperature under test confine pressure.',
#  '10 mpa 60 mpa 120 mp a 100 200 temperature (ºc) 30 mpa 90 mpa 300 30 25 20 15 10 05 e (gpa) 0 .',
#  'variation of elastic modulus versus confine pressure for different temperature.',
#  '20 rt 40 60 σ3 (mpa) 80 100 120 140   300 c 600 500 400 300 200 100 σ1 -σ3(mpa) 0 0 .',
#  'variation of deviatoric stress versus confine pressure for different temperature.',
#  'w.g.p.  / geothermics 65 (2017) 44–59 51 .',
#  'corresponding–coulomb failure envelope.',
#  'cohesio n 30 0 400 (◦c) 0 20 0 temperature (b) 0 10 30 25 20 15 10 05',
#  'cohesion',
#  '(',
#  'mpa) 30 0 400 friction ang le 0 10 0 temperature (◦c) 20 0 (a) 60 50 40 30 20 10 0 friction angle .',
#  'variation in (a) friction angle and (b) cohesion with different temperature (consider linear region of the coulomb failure envelope).',
#  'the latter positive effect of temperature on cohesion, accord to and (1979), increase the temperature to an extreme value may cause weakening of the grain boundary, dependent on the anisotropy of the rock matrix (due to potentially exist distinct mineral compound in granite those may contain different thermo-elastic modulus and this may causes to generate different internal stress with heating).',
#  'accord to and (1979), increase the temperature cause the induction of thermal crack in the rock mass due to the associate generation of internal stress (eq. (2)): (2) e(4)˛(4)t = \u2434 where, e, \x01␣, \x01t be the matrix young’s modulus, difference of thermal expansion coefficient of distinct mineral and temperature difference, respectively.',
#  'when the internal stress (give by eq. (2)) exceed the crack closure pressure with increase temperature, thermal crack form and far increase of temperature provide the surface energy require for the propagation of the initiate crack (, 2007).',
#  'this result in alteration of the grain-tograin contact in the rock matrix, which lead to reduce cohesion at high temperature.',
#  'in the case of the variation of friction angle with increase temperature, the granite friction angle appear to remain steady up to around 100 ◦c (52◦) and then slightly increase with increase temperature (54◦ at 200 and 300 ◦ c, respectively).',
#  'the friction between grain-to-grain contact may be alter by the thermally-induce micro-structural modification.',
#  'however, this effect on grain contact be expect to be small at relatively low temperature, result in relatively steady friction angle with increase temperature at low temperature.',
#  'however, a slight ment non-linearity must be take into account.',
#  'in addition to the confinement, accord to this study, increase temperature also alter the failure envelope of granite.',
#  'an initial increment in deviatoric stress with increase temperature can be observe up to 200 ◦c and further increase of temperature (to 300 ◦c) cause it to be slightly reduce.',
#  'the temperature-dependent shear parameter of granite be investigate next, and the shear parameter can be obtain from the-coulomb failure envelope.',
#  'as suggest by  (2011), the-coulomb parameter (cohesion and friction angle) be calculate use eq. (1), take into account the linear region of the obtain-coulomb failure envelope (consider only small confine stress, up to 30 mpa) for each temperature condition to obtain the temperature-dependent shear strength parameter ().',
#  '(1) sin(3) sin(3) (2)3 + − + 1 1 − (2)1 = (3) sin(3)i 1 \u24341, \u24343 be major principal stress and minor principal stress, where, and c and (3) be cohesion and friction angle, respectively.',
#  'accord to , cohesion increase from 20.7 to 25.7 mpa with increase temperature from room temperature to 100 ◦c and further increase of temperature up to 200 ◦c and 300 ◦c cause the granite cohesion to be reduce to 24.8 mpa and 23.2 mpa, respectively.',
#  'the observed cohesion gain at relatively low temperature confirm that thermally-induce rock matrix expansion induce a great mutual attraction among individual mineral.',
#  'this be also inﬂuence by the inhibition of micro-crack propagation at relatively low temperature (duclos and, 1991).',
#  'in relation to\x0c52 w.g.p.  / geothermics 65 (2017) 44–59 . cumulative ae event vs. axial stress at different pressure and temperature.\x0cw.g.p.  / geothermics 65 (2017) 44–59 53 .',
#  '(continue) enhancement in friction angle with increase temperature can be see, probably due to the increase resistance of mineral particle to external deformation as a result of the thermally-induce energy in the mineral particle.',
#  'however, compare with cohesion, the temperature dependency on friction angle be relatively insignificant within the temperature region consider here.',
#  'initial enhancement in shear parameter in sandstone with increase temperature have be observe by  (2015) at relatively low temperature region, and these researcher observe reduction in friction angle from 33.02◦ to 31.93◦ and an increment a in cohesion from 61.47 mpa to 66.44 mpa with increase temperature from 25 ◦c to 100 ◦c.',
#  'far and (1979) observe around  reduction in cohesion and  reduction in friction angle in westerly granite with increase temperature from room temperature to 300 ◦c, and  (1979) observe  reduction in cohesion and a  reduction in friction angle a with increase temperature from room temperature to 400 ◦c and 300 ◦c, respectively.',
#  'however, the variation of shear strength parameter with increase temperature at relatively low temperature ( ◦c) be not consider in the above study.',
#  'the observed initial shear strengthening may be due to the inhibition of micro-crack propagation by the plasticity mechanism which occur at crack tip (duclo and (1991)) at low temperature.',
#  'with further increment of temperature, the reduction of shear strength parameter can be expect, due to the thermal weakening of the rock micro-structure.',
#  'furthermore, accord to the sem study conduct by  (2007), large local plastic deformation and extremely rough cleavage fracture occur at relatively low temperature.',
#  'moreover, due to the volume expansion, the distance between the interface of the individual mineral decrease with the enhancement of their mutual attraction, and the strength of the bond increase (, 1972).',
#  'both of these phenomenon can be consider to explain the stress strengthening of granite under relatively low temperature when subject to confine pressure.',
#  '3.4. analysis of fracturing behaviour use ae technology acoustic emission (ae) detection technology be a powerful nondestructive tool to study crack propagation process in brittle material, include the stage of crack initiation, growth and crack damage (, 1993).',
#  'when a brittle material be under stress, strain energy be release during the development of new crack or the widening of exist crack.',
#  'this energy be release in the form of elastic stress wave from the crack tip, and can be capture and amplify by an ae system.',
#  'ae detection technology have therefore be widely use in a number of previous study to understand the crack development mechanism in brittle material ( and,  ,  , 2005).',
#  'by incorporate the crack propagation pattern into the stressstrain relationship of the crack material, the crack development process can be divide into several stage.',
#  ' and (1965) divide crack formation into five main  crack closure, crack initiation, secondary cracking, crack coalescence and crack damage.',
#  'later,  (2008) and  (2015) incorporate stress-strain curve into cumulative ae energy and strain plot.',
#  'in the crack propagation process, with the gradual increment of loading on brittle material, most pre-exist crack be first close, release an insignificant number of ae count.',
#  'this initial crack closure period be follow by the stable crack propagation period, which can be identify by the release of gradual ae energy increment.',
#  'further increment of loading cause an exponential increase in ae energy, indicate an unstable crack propagation period with failure approach.',
#  'the crack closure threshold ((2)cc) be define as the stress threshold at which the initial ae count be identify.',
#  'anan initial increment in cumulative ae\x0c54 w.g.p.  / geothermics 65 (2017) 44–59 count can be see at the crack initiation ((2)ci) threshold, and the cumulative ae count start exponential growth at the crack damage ((2)cd) threshold.',
#  'the region between the crack closure threshold and the crack initiation threshold be generally define as the stable crack closure region, where linear elastic deformation occur.',
#  'the region between the crack initiation threshold and the crack damage threshold be define as the stable crack propagation region, and the region between the crack damage threshold and sample failure be identify as the unstable crack propagation region.',
#  'the application of compressive loading fail rock through either shear localization (brittle regime) or cataclastic ﬂow, and the surround condition, such as temperature and pressure, may cause a homogenous plastic ﬂow.',
#  'accord to exist study, axial intra-granular cracking and shear rupturing of cement grain contact can be observe before failure in brittle regime, and grain crushing and pore collapse can be identify before failure in cataclastic ﬂow regime (, 1996).',
#  'accord to  (1997), the development of local stress concentration lead to the initiation of many intra-granular micro-crack in the rock mass, and the crack density increase with increase deviatoric stress and tend to merge on reach the peak stress, result in strain softening and shear localization.',
#  'these damage process be clearly identify by the intense ae activity in the field ( and, 2004).',
#  'ae technology be therefore use to investigate the progressive fracturing behaviour in strathbogie granite under tri-axial condition.',
#  '',
#  'illustrate the cumulative ae event with axial stress at various pressure and temperature for the test specimen.',
#  'the corresponding variation of deviatoric stress against strain be also include in the same plot to identify the stress threshold for crack closure, crack initiation and crack damage ().',
#  'the very high ae count in strathbogie granite at dilatancy in the pre-failure stage be due to the fact that ae wave generate when the local shear stress concentration at a grain contact be sufficiently high to rupture the grain boundary, and frictional slip and grain rotation may occur once the grain contact have lose their cohesion.',
#  'in the present study, crack threshold ratio be define to identify the temperature and pressure-dependent crack propagation in the test granite as follow, and  show the crack propagation stress threshold ratio of granite specimen test at various confining pressure and temperature.',
#  'crack closure stress threshold = deviatoric stress at crack closure stress deviatoric stress at failure ((2)cc) crack initiation stress threshold = deviatoric stress at crack initiation stress deviatoric stress at failure ((2)ci) crack damage stress threshold = deviatoric stress at crack damage stress ((2)cd) deviatoric stress at failure accord to the result, the beginning of crack damage occur at early stage of deviatoric loading for high confining pressure.',
#  'however, the crack damage stress increase with increase confinement due to the inﬂuence of confine pressure on thermal crack development and the suppression of the widening of exist micro-crack.',
#  'accord to , in the temperature range consider here, three tendency can be identify with increase confining  increase of the elastic deformation region, decrease of the stable crack propagation region, and increase of the unstable crack propagation region.',
#  'the crack initiation stress threshold also progressively increase with increase confine pressure, which can be attribute to the fact that the brittle behaviour of rock specimen at low confine pressure change to quasi-brittle behaviour with increase confine pressure.',
#  'this be because the suppression of micro-crack development be less at low confine pressure, and therefore sudden failure mostly occur, and the beginning of crack initiation occur at early stage of deviatoric loading at high confine pressure due to the high normal stress act on micro-crack, result in limited progression of cracking before failure.',
#  'in relation to the temperature effect, increase the temperature cause an initial increment in the crack propagation stress threshold, follow by a slight reduction for all the temperature condition consider.',
#  'for example, at 30 mpa confinement, the crack damage stress threshold ratio increase by around 6., 10. with increase temperature from room temperature to 100 and 200 ◦c, respectively, and reduce by around 4. when the temperature increase to 300 ◦c.',
#  'this imply that at low temperature a suppress micro-crack development mechanism be dominant, and increase the temperature cause crack damage to occur at early loading stage.',
#  'interestingly, at 60 mpa confinement the crack damage stress threshold ratio increase by around 4., 5., 2. with increase temperature from room to 100, 200 and 300 ◦c, respectively.',
#  'this exhibit the cumulative effect of temperature and pressure micro-crack development in the rock mass.',
#  'at relatively low temperature, micro-crack propagation may be inhibit by the thermally-induce plasticity mechanism which occur at crack tip and the increase bonding strength through thermally-induce rock matrix expansion (which increase crack stress threshold).',
#  'however, further increase of temperature create thermally-induce crack and cause the grain boundary crack to widen, result in early crack damage.',
#  'far, with the inﬂuence of confinement, micro-crack development be suppress, cause a relatively low increment of crack damage stress threshold ratio at high confinement.',
#  '3.5.',
#  'corresponding alteration in granite micro-structure a comprehensive micro-structural analysis be also perform to identify the interior correspondence of the above-describe temperature-dependent mechanical behaviour of granite.',
#  'sem and optical microscopic analysis be perform on thin section of granite specimen at various  room temperature (20 ◦c), pre-heat (72 hour) to 200 ◦c and 400 ◦c ().',
#  'these temperature be select to identify the microstructural behaviour at 200 ◦c, at which the high strength increment be observe, and 400 ◦c, at which clear thermally-induce rock mass weakening be observe.',
#  'a specimen at room temperature be use as a control.',
#  'base on optical microscope imaging, mineralogical assembling in the granite specimen could be identify by the colour and texture of each of the mineral assemblage.',
#  'far, a detailed sem study be perform use scanning electron imaging (sei) and bsei back-scatter electron imaging (bsei) technique.',
#  'bsei image take at low magnification clearly show different mineral assemblage and grain boundary (see ). use energy-dispersive x-ray (edx) technology with aztec oxford instrument, chemical component mapping be generate in each specimen, and each mineral be identify qualitatively.',
#  'the bright colour image observe in edx image indicate high concentration (high energy dispersion) while dark colour area indicate low concentration (low energy dispersion).',
#  'base on the spectrum of each point (point id), the correspond mineral be identify and a map spectrum provide overall element available for each specimen.',
#  'accord to  and 14, there be clear mineralogical assembling in the granite specimen, mainly with quartz, kfeldspar and plagioclase.',
#  'the heating of granite up to 200 ◦c temperature have not cause any significant thermally-induce micro-crack (in addition to the pre-existing fault and grain boundary) and almost all grain boundary remain intact.',
#  'however, further heating of granite to the high temperature of 400 ◦c cause the induction of some micro-crack, mainly along',
#  'w.g.p.  / geothermics 65 (2017) 44–59 55  stress threshold for different fracturing stage.',
#  'temperature (◦c) confine pressure (mpa) deviatoric stress at failure (mpa) crack closure threshold ((2)cc) (mpa) crack initiation threshold ((2)ci) (mpa) crack damage threshold ((2)cd) (mpa) 20 100 200 300 10 30 60 90 10 30 60 90 120 10 30 60 90 10 30 60 90 186.9 311.9 422.5 503.3 225.5 333.7 440.9 510.3 568.9 258.2 374.4 509.0 549.6 249.4 367.5 464.6 516.5 1.3 1.8 2.6 3.8 1.4 1.9 2.6 3.9 4.0 1.6 1.9 2.8 3.6 0.03 1.8 2.4 3.9 25.9 59.4 131.7 202.0 29.8 50.3 137.2 216.0 239.2 30.8 61.2 158.0 237.1 45.2 93.5 139.1 194.0 146.0 244.5 325.7 370.0 196.0 279.4 356.5 415.1 439.0 217.4 324.5 413.6 434.4 206.3 276.6 367.7 396.2 .',
#  'crack propagation stress threshold ratio of granite specimen test at various confining pressure and temperature.',
#  'the quartz and feldspar mineral (intra-granular crack) and the quartz-feldspar grain boundary (inter-granular crack).',
#  'some grain boundary crack run along grain boundary and around pore boundary could be identify.',
#  'a considerable number of crack be propagate after 400 ◦c at triple junction dominantly in quartz feldspar boundary.',
#  'however, only a few grain\x0c56 w.g.p.  / geothermic 65 (2017) 44–59 . optical microscopic and sem image of thin section of strathbogie granite (a) at room  (b) pre-heat to 100 ◦c (c) pre-heat to 400 ◦c.',
#  'boundary have be partially part and a significant number of grain boundary appear to remain intact up to this temperature.',
#  'furthermore, base on the edx mapping, it be confirm that intra-granular crack be mainly initiate along the feldspar and quartz mineral.',
#  'intragranular crack be mainly observe in large crystal (crystal great than 0.5 mm) and small crystal remain un-parted even at 400 ◦c.',
#  'for strathbogie granite, thermally-induce intra-granular micro-crack seem to play a significant role at relatively low temperature, probably due to the presence of relatively high k feldspar and biotite content.',
#  'similar observation have be report in and’s (1979) study conduct for charcoal granite, where intra-granular microcrack predominantly occur compare to grain boundary crack.',
#  'the sem analysis be also consistent with this finding, which exhibit inhibition of micro-crack development follow by micro-cracking at relatively high temperature.',
#  'the crack propagation process in any rock mass be largely inﬂuence by the mineralogical composition, because crack normally propagate through weak plane of the rock mass.',
#  'since granite be an igneous type of rock, two main type of thermallyinduced cracking mode can be  inter-granular and intragranular.',
#  'the amount of inter-granular or intra-granular cracking be dependent on the stress state, rock type and mineralogy of the rock mass.',
#  'inter-granular crack occur along grain boundary, pre-exist fault and micro-crack of the rock, while intragranular crack occur through weak mineralogical constituent (, 1983).',
#  'for example, k feldspar and biotite be weak mineralogical constituent due to their large crystal ( mm), as crystal great than 2–3 mm in size be generally define as weak mineralogical constituent compare to equi-dimensional small crystal like quartz (homand-etienne and, 1989).',
#  'base on experimental result, intra-granular cracking be highly temperature-dependent due to the temperature dependent dislocation in the rock.',
#  'this be because different mineralogical component have different thermo-elastic modulus and thermal conductivity (,  , 2008).',
#  'these observation suggest that micro-cracking in granite be highly temperature dependent, as evidence by the previously observe initial strength gain follow by slight strength reduction with increase temperature in the test granite.',
#  'however, this show that granite need to be heat to a sufficient temperature to cause thermal crack in it and therefore, heat to a low temperature may only cause a strength gain through the thermal expansion of the rock matrix.',
#  'this be consistent with the result of and (1979). the mechanical property of charcoal granite in their study remain relatively steady until 200 ◦c, and westerly granite exhibit a significant thermal dependency, even at relatively low temperature ( ◦c).',
#  'in homand-etienne and (1989) study, the variation of uni-axial compressive strength of both semones and remiremont granite be insignificant until 400 ◦c, follow by significant reduction at high temperature.',
#  'these result indicate the dependency of mineralogical composition and grain size distribution on the temperature dependent mechanical behaviour in various type of granite.',
#  'however,\x0cw.g.p.  / geothermics 65 (2017) 44–59 57 .',
#  'bse image of strathbogie granite with edx  (a) thin section at room  (c) thin section pre-heat to 400 ◦c.\x0c4.',
#  'conclusion',
#  'a series of tri-axial strength test be conduct on australian strathbogie granite under four different confining pressure (10, 30, 60, 90 mpa) and four different temperature (rt, 100, 200, 300 ◦c), simulate various geothermal reservoir condition.',
#  'the following conclusion can be  mechanical behaviour of the test granite be inﬂuence by both reservoir depth and temperature, and the depth effect be much great than the temperature effect.',
#  'granite locate at relatively small depth appear to fail through shear localization and increase depth may cause this to change to ductile failure through strain hardening.',
#  'a progressive enhancement in stress threshold with increase confine pressure be observe in strathbogie granite.',
#  'such behaviour exhibit great strength and low brittle characteristic in granite locate at great depth.',
#  'increase of temperature cause granite’s strength to be enhance up to a certain temperature (around 200 ◦c for strathbogie granite) through the possible thermal expansion of the rock matrix and far increase of temperature may cause it to weaken by induce thermal crack.',
#  'this be confirm by the micro-structural analysis, which do not reveal any noticeable amount of thermally-induce micro-cracking in strathbogie granite up to 200 ◦c, and heating of the granite to a great temperature as 400 ◦c cause many intra-granular crack in quartz and feldspar and some grain boundary crack between quartz and feldspar mineral.',
#  'furthermore, accord to ae analysis, increase the temperature first cause the crack propagation stress threshold to increase and far increase of the temperature cause it to be slightly reduce.',
#  'this indicate a suppression of micro-crack at low temperature by matrix expansion and the development of micro-crack through thermally-induce damage at high temperature.',
#  'finally an attempt be make to improve the conventional mohrcoulomb failure criterion for geothermal reservoir with extreme pressure and temperature, because the conventional criterion be not applicable to extreme condition.',
#  'acknowledgement this research project be fund by the australian research council (arc ) and the author would like to thank all the deep earth energy laboratory staff at monash university, clayton campus, australia and the monash centre for electron microscopy (mcem), who dedicate their time and energy to bring this experimental series to a successful conclusion.',
#  'the sixth author extend his appreciation to the deanship of scientific research at king saud university (saudi arabia) for fund the work through the international research group project no. -36.']

# %%
#Read the file Stopwords
gist_file = open("gist_stopwords.txt", "r")
try:
    content = gist_file.read()
    stopwords = content.split(",")
finally:
    gist_file.close()

prepro2=[]

#Pattern for Remove Citation
pattern1 = regex.compile(r'\(([\w\s\d{}]+)\)'.format(pc))

#Pattern for Apply the Stopwords
pattern2 = r",*(\s*\b(?:{}))\b".format("|".join(stopwords))

#Pattern for unused space first n last
pattern3 = regex.compile(r'((^\s+)(?=.)|(?<=.)(\s+$))')

#Pattern for Apply over-space
pattern4 = regex.compile(r'(\s)(?=\s+)')

#Pattern Additional compiler
pattern_add = regex.compile(r'(\x01|\x0c|\s[a-z]\s|°|^\b(\w\s)|I|)')

#Pattern for combined word and number
for i,j in enumerate(prepro1):
    if bool(regex.search(pattern1,j)) == True:
        if bool(regex.search(r'\d',regex.search(pattern1,j).group())) == True:
            try:
                layer = regex.findall(pattern1,j)
                if type(layer) == tuple:
                    layer = list(filter(None, [i for i in layer]))
                    prepro2.append(re.sub(layer[0],'',j))
                else:
                    prepro2.append(re.sub(regex.findall(pattern1,j)[0],'',j))
            except:
                prepro2.append(j)
        else:
            prepro2.append(j)
    else:
        prepro2.append(j)
    
    #Weird character of ﬂ
    layer = regex.sub(r'ﬂ','fl',prepro2[i])
    
    #With Removing number and punctuations    
    layer = regex.sub(r'(\d|[^A-Za-zöäüéíáúóðèñæýßôþ\s]|[^\P{P}]+)',' ',re.sub(pattern2,'', layer)) 
    
    #With Removing unused space first n las
    layer = regex.sub(pattern3,'',layer)
    
    #With Removing over-space
    layer = regex.sub(pattern4,'',layer)
    
    #With Removing Additional compiler
    prepro2[i] = regex.sub(pattern_add,'',layer)

#Final filtering for less than three words sentence
d = lambda y : None if len(y.split(' '))<=4 else y
prepro2 = list(filter(d, prepro2))

# %%
prepro2
# Out:
# ['introduction geothermal heat identify renewable reliable energy source severe environmental impact create conventional fossil fuel coal oil',
#  'exploratory geothermal drill test availability geothermal reservoir correspond author deep earth energy laboratory department civil engineering monash university building melbourne victoria australia',
#  'rock rock elevated temperature deep granite reservoir adequate temperature serve geothermal reservoir',
#  'exploration involve vast block fracture',
#  'process water inject circulate fracture geothermal reservoir eventually pump surface steam',
#  'exploration geothermal resource challenge engineer geologist high temperature stress environment geothermal reservoir',
#  'reason laboratory experiment conduct high pressure temperature condition geothermal condition assist provide geothermics basic prediction',
#  'large number laboratory experiment conduct investigate influence high pressure temperature rock relation geothermal heat extraction deep geological disposal nuclear waste franc ois deep mining wawersik hannum geological storage',
#  'mechanical behaviour reservoir rock influence elevated temperature micro structure rock mass alter thermal expansion development new micro crack extend widen exist micro crack mineralogical alteration',
#  'rock strength deformation criterion change temperature rock mechanical property compressive strength tensile strength elastic modulus cohesive strength friction angle decrease increase temperature',
#  'alteration affect confinement apply rock mass confine pressure suppression thermal crack widening exist micro crack',
#  'result alteration rock mass mechanical property result change failure mode',
#  'study identify transition rock failure mode brittle ductile increase confinement',
#  'transition diverse mineralogical composition grain boundary rock',
#  'study conduct investigate temperature dependent mechanical behaviour reservoir rock experiment conduct unconfined environment',
#  'heat specimen correspond temperature range test room temperature frequently method reliable geothermal reservoir experience continuous thermal stress',
#  'limitation occur limited number test facility simulate stress temperature condition actual geothermal reservoir',
#  'study analytically numerically evaluate mechanical property rock high temperature pressure capture stress strain behaviour failure criterion rock wide range confine pressure temperature australian granite',
#  'thermo elastic response failure criterion essential input engineering application high pressure temperature include geothermal extraction application',
#  'study intend gap hope contribution deep underground application',
#  'test material granite abundant crystalline rock earth medium coarse grain form result slow cooling magma',
#  'element bring elevated geothermal gradient deep granite reservoir ideal condition geothermal reservoir',
#  'mineralogical composition granite consist quartz feldspar plagioclase biotite small muscovite amphibole hornblende opaque',
#  'study sample collect strathbogie batholith composite granitoid intrusion body spread north east melbourne',
#  'strathbogie granite high level discordant',
#  'sampling location strathbogie batholith central victoria',
#  'physical mechanical petrographic property strathbogie granite room temperature atmospheric pressure condition',
#  'rock type granite colour average grain size petrographic description bulk density compressive strength mpa elastic modulus gpa porosity white dark brown consist feldspar biotite quartz plagioclase equigranular coarse grained type granite result xrd analysis',
#  'mineral alpha quartz sodic intermediate plagioclase biotite phlogopite feldspar clinochlore muscovite sericite dolomite ankerite mineral granite consist quartz feldspar cordierite biotite',
#  'select granite type coarsegrained white dark brown colour porosity',
#  'close view typical strathbogie granite sample optical microscopic image sem image',
#  'clear mineralogical assembling observe granite specimen quartz feldspar plagioclase',
#  'grain size measure granite small number range mm large grain mm summarize physical mechanical petrographic property test strathbogie granite',
#  'addition xrd analysis conduct determine mineralogical composition select granite result',
#  'table quartz predominant mineral select granite follow sodic intermediate biotite plagioclase',
#  'mineralogical composition granitic composition representative composition majority earth granite',
#  'close view sample microscopic image sample sem image sample',
#  'conduct test xrd analysis mineral composition uniaxial compression testing compressive strength elastic modulus analysis average grain size mercury intrusion testing porosity volume weight measurement bulk density',
#  'sample preparation sample preparation testing carry deep earth energy laboratory deerl civil engineering department monash university sample preparation conduct astm standard tri axial compressive testing astm',
#  'order maintain consistency sample core mm diameter block granite orientation',
#  'sampling great care sample crystalline orientation sample crystalline orientation internal layer visible crack discard',
#  'note coring induce rock microstructure alteration aspect laboratory experiment study',
#  'avoid issue small coring rate adopt water lubricant',
#  'core specimen cut mm high cylinder specimen grind produce parallel surface perpendicular axis cylindrical specimen',
#  'experimental procedure tri axial experiment conduct sample confining pressure temperature',
#  'experimental condition select preferable hot dry rock generally locate depth mpa mpa confining pressure temperature',
#  'confining pressure temperature select simulate reservoir depth sufficient datum set understand failure criterion temperature',
#  'complete arrangement tri axial cell',
#  'prepare sample place inside cell require confining pressure apply silicon oil anneal copper sleeve isolate sample confine liquid refer',
#  'mica insulate metal band heater heat pressure cell rock sample',
#  'temperature cell adjust controller constant small heating rate min prevent micro structural damage sudden thermal shock',
#  'separate thermocouple achieve precise temperature control reading thermocouple instal inside cell record data acquisition',
#  'thermocouple attach barrel control band heater',
#  'barrel pressure cell cover insulate blanket reduce heat loss experiment minimise influence air flow cell',
#  'test start achieve steady state ensure uniformity temperature pressure sample',
#  'equilibrium ensure monitor confinement pump volume thermocouple reading inside cell locate close specimen',
#  'steady state condition constant pump volume constant temperature observe testing initiate',
#  'constant loading pump flow rate min adopt test specimen convert displacement rate min',
#  'note small shaft resistance exist result sealing hydraulic cylinder calibration loading cell',
#  'sealing resistance measure pump pressure initiate movement loading shaft deduct pressure reading eliminate resistance sealing dur geothermics typical coulomb brittle deformation',
#  'deviatoric stress strain plot granite sample exhibit concave upward curvilinear trend initial loading peak strain softening occur rapid stress drop residual',
#  'increase peak stress increase confine pressure observe expect accord typical coulomb type brittle failure',
#  'traditionally rock failure compression occur main dilatancy failure strain softening low confine pressure failure strain harden elevate confining pressure transitional regime observe intermediate pressure',
#  'transitional failure mode refer complex localize feature conjugate shear band observe condition',
#  'visual inspection post failure sample alteration granite failure mechanism confine pressure temperature identify',
#  'accord post failure image specimen fail mpa confining pressure fail shear localization inclined macroscopic shear band single shear zone sample',
#  'sample test high confinement mpa mpa',
#  'exhibit strain harden characteristic achieve peak stress conjugate shear band observe cylindrical sample surface single shear band observe early',
#  'note test conduct mpa confinement high confining pressure correspond failure load granite exceed pedestal load bear capacity',
#  'progressive reduction observe failure plane angle respect minor principal stress direction increase confine pressure imply reduction friction angle great quasi brittle behaviour granite sample high confining pressure',
#  'temperature confine pressure mechanical property strathbogie granite illustrate influence temperature deviatoric stress test granite confinement',
#  'figure influence confinement temperature temperature range',
#  'confirm low confining pressure considerable thermal cracking occur low temperature',
#  'thermal cracking responsible reduction failure strength sharp reduction deviatoric stress increase temperature suppression thermal crack exhibit unconfined pressure condition',
#  'base experimental result unconfined condition increment deviatoric stress follow reduction',
#  'confinement apply strength reduction initiate high temperature inhibition thermal crack induce compressive force',
#  'thermal cracking strength property alteration mechanism reservoir rock confine pressure condition',
#  'clear influence temperature deviatoric stress depth confinement observe increase temperature room temperature increment deviatoric stress increase temperature',
#  'thermal expansion occur increase temperature reduction',
#  'high pressure high temperature tri axial machine inside view cell',
#  'note compare large axial load resistance negligible maximum measurement',
#  'load application axial strain measure linear variable differential transducer lvdt attach ram load cell',
#  'acoustic emission employ testing sample record datum relate fracturing process',
#  'adopt peripheral component interconnection pci nominal resolution frequency khz',
#  'experiment sensor attach loading shaft external amplifier generate low frequency acoustic wave fracturing sample',
#  'addition micro structural mineralogical change occur thermal confinement check sem analysis',
#  'stress strain response influence temperature stress strain behaviour test granite test result deviatoric load failure deviatoric stress failure triaxial compressive strength elastic modulus illustrate relationship deviatoric stress axial strain curve sample test mpa confining pressure temperature',
#  'relation stress strain curve strathbogie granite triaxial loading correspond failure mode characterize geothermics mechanical property strathbogie granite test temperature pressure',
#  'confining pressure mpa deviatoric load failure kn mpa mpa elastic modulus gpa mpa mpa mpa mpa axial strain',
#  'correspond stress strain response granite temperature',
#  'distance interface individual mineral increase mutual attraction bonding strength',
#  'increase temperature crystalline particle rock mass fracture pre exist grain boundary mineral grain thermoelastic modulus thermal conductivity result reduce rock strength',
#  'accord tri axial experimental study conduct increase temperature lead reduction failure stress westerly granite mpa mpa mpa mpa mpa mpa axial strain mpa mpa mpa mpa axial strain',
#  'post failure image test specimen',
#  'reduction strength characteristic small accelerate downward trend identify',
#  'wide localized zone observe high temperature post failure image',
#  'study conduct wide temperature range researcher pay close attention reservoir rock behaviour low geothermal temperature range',
#  'focus study accord initial strengthening stiffening granite increase temperature low temperature increase temperature gradual reduction failure stress increase temperature',
#  'elastic modulus mechanical property reservoir rock brittle characteristic rock mass',
#  'evaluate situ stress application include wellbore stability fracturing possibility tectonic stress distribution',
#  'temperature dependent brittle property elastic modulus test granite evaluate',
#  'elastic region stress strain curve calculate temperature pressure dependent young modulus result',
#  'axial strain measure lvdt attach loading ram linearity scale mm infinite resoluerror tion hysteresis',
#  'increment modulus strathbogie granite increase temperature observe increase temperature elastic modulus reduce confinement',
#  'trend brittle general increment elastic modulus increase confinement observe mpa increase confinement reduce young modulus considerably',
#  'increase confine stress additional plastic deformation occur exhibit strain harden characteristic granite high confinement',
#  'range experiment conduct mpa mpa definitively identify ductile regime',
#  'strain harden behaviour observe mpa transitional characteristic identify quasi brittle behaviour',
#  'initial young modulus reduction increase confinement observe conduct test mpa confining pressure',
#  'interestingly accord literature low temperature granite type temperature sensitive contrast granite temperature sensitive high temperature',
#  'initial strength enhancement coarse grained granite granodiorite fine grained granite',
#  'accord stripa granite sensitive temperature low temperature westerly granite sensitive temperature high temperature',
#  'contradictory behaviour occur granite grain size distribution grain orientation mineralogical composition heterogeneity granite type',
#  'study mineralogical composition microstructural influence granite temperature dependent strength variation',
#  'temperature shear strength parameter strathbogie granite illustrate variation deviatoric stress test granite confine pressure temperature',
#  'figure increase confinement granite deviatoric stress increase linearly gradually steady state',
#  'consistent previous study enhancement rock strength increase confinement increase rate reduce increase confine pressure',
#  'low confining pressure high dilation potential',
#  'ability open rock micro crack high result high friction angle',
#  'dilation potential correspond tendency micro crack open suppress increase confinement result low friction angle high confining pressure',
#  'failure mechanism rock shift brittle ductile increase confinement change shape coulomb failure envelope accord critical confining pressure coulomb failure envelope reach gradient',
#  'study identify rock behaviour coulomb failure envelope develop temperature condition refer',
#  'accord traditional linear coulomb criterion applicable brittle region failure envelope high confinew geothermics consistent temperature dependent strength behaviour granite',
#  'reason initial elastic module increment specimen brittle initial temperature range thermally induce volumetric expansion associate pore volume reduction',
#  'slight reduction young modulus increase temperature exhibit enhancement ductile behaviour quasi brittle characteristic increase temperature',
#  'increase crack density induce thermal crack development relate weakening granite',
#  'temperatureunconfined mpa mpa mpa mpa',
#  'variation deviatoric stress temperature test confine pressure',
#  'mpa mpa mp temperaturempa mpa gpa',
#  'variation elastic modulus versus confine pressure temperature',
#  'variation deviatoric stress versus confine pressure temperature',
#  'mpa friction ang temperature friction angle',
#  'variation friction angle cohesion temperature linear region coulomb failure envelope',
#  'positive temperature cohesion accord increase temperature extreme weakening grain boundary dependent anisotropy rock matrix exist distinct mineral compound granite thermo elastic modulus generate internal stress heating',
#  'accord increase temperature induction thermal crack rock mass associate generation internal stress matrix young modulus difference thermal expansion coefficient distinct mineral temperature difference',
#  'internal stress exceed crack closure pressure increase temperature thermal crack form increase temperature provide surface energy require propagation initiate crack',
#  'result alteration grain tograin contact rock matrix lead reduce cohesion high temperature',
#  'case variation friction angle increase temperature granite friction angle remain steady increase increase temperature',
#  'friction grain grain contact alter thermally induce micro structural modification',
#  'grain contact expect small low temperature result steady friction angle increase temperature low temperature',
#  'addition confinement accord study increase temperature alter failure envelope granite',
#  'initial increment deviatoric stress increase temperature observe increase temperature reduce',
#  'temperature dependent shear parameter granite investigate shear parameter coulomb failure envelope',
#  'coulomb parameter cohesion friction angle calculate account linear region coulomb failure envelope small confine stress mpa temperature condition temperature dependent shear strength parameter',
#  'sin sin sin major principal stress minor principal stress cohesion friction angle',
#  'accord cohesion increase mpa increase temperature room temperature increase temperature granite cohesion reduce mpa mpa',
#  'observed cohesion gain low temperature confirm thermally induce rock matrix expansion induce great mutual attraction individual mineral',
#  'influence inhibition micro crack propagation low temperature',
#  'relation geothermics cumulative event axial stress pressure temperature geothermics',
#  'continue enhancement friction angle increase temperature increase resistance mineral particle external deformation result thermally induce energy mineral particle',
#  'compare cohesion temperature dependency friction angle insignificant temperature region',
#  'initial enhancement shear parameter sandstone increase temperature observe low temperature region researcher observe reduction friction angle increment cohesion mpa mpa increase temperature',
#  'observe reduction cohesion reduction friction angle westerly granite increase temperature room temperature observe reduction cohesion reduction friction angle increase temperature room temperature',
#  'variation shear strength parameter increase temperature low temperature study',
#  'observed initial shear strengthening inhibition micro crack propagation plasticity mechanism occur crack duclo low temperature',
#  'increment temperature reduction shear strength parameter expect thermal weakening rock micro structure',
#  'accord sem study conduct large local plastic deformation extremely rough cleavage fracture occur low temperature',
#  'volume expansion distance interface individual mineral decrease enhancement mutual attraction strength bond increase',
#  'phenomenon explain stress strengthening granite low temperature subject confine pressure',
#  'analysis fracturing behaviour technology acoustic emission detection technology powerful nondestructive tool study crack propagation process brittle material include stage crack initiation growth crack damage',
#  'brittle material stress strain energy release development new crack widening exist crack',
#  'energy release form elastic stress wave crack capture amplify',
#  'detection technology number previous study understand crack development mechanism brittle material',
#  'incorporate crack propagation pattern stressstrain relationship crack material crack development process divide stage',
#  'divide crack formation main crack closure crack initiation secondary cracking crack coalescence crack damage',
#  'incorporate stress strain curve cumulative energy strain plot',
#  'crack propagation process gradual increment loading brittle material pre exist crack close release insignificant number count',
#  'initial crack closure period follow stable crack propagation period identify release gradual energy increment',
#  'increment loading exponential increase energy unstable crack propagation period failure approach',
#  'crack closure threshold define stress threshold initial count identify',
#  'anan initial increment cumulative geothermics count crack initiation threshold cumulative count start exponential growth crack damage threshold',
#  'region crack closure threshold crack initiation threshold generally define stable crack closure region linear elastic deformation occur',
#  'region crack initiation threshold crack damage threshold define stable crack propagation region region crack damage threshold sample failure identify unstable crack propagation region',
#  'application compressive loading fail rock shear localization brittle regime cataclastic flow surround condition temperature pressure homogenous plastic flow',
#  'accord exist study axial intra granular cracking shear rupturing cement grain contact observe failure brittle regime grain crushing pore collapse identify failure cataclastic flow regime',
#  'accord development local stress concentration lead initiation intra granular micro crack rock mass crack density increase increase deviatoric stress tend merge reach peak stress result strain softening shear localization',
#  'damage process identify intense activity field',
#  'technology investigate progressive fracturing behaviour strathbogie granite tri axial condition',
#  'illustrate cumulative event axial stress pressure temperature test specimen',
#  'variation deviatoric stress strain include plot identify stress threshold crack closure crack initiation crack damage',
#  'high count strathbogie granite dilatancy pre failure stage fact wave generate local shear stress concentration grain contact high rupture grain boundary frictional slip grain rotation occur grain contact lose cohesion',
#  'study crack threshold ratio define identify temperature pressure dependent crack propagation test granite follow crack propagation stress threshold ratio granite specimen test confining pressure temperature',
#  'crack closure stress threshold deviatoric stress crack closure stress deviatoric stress failure crack initiation stress threshold deviatoric stress crack initiation stress deviatoric stress failure crack damage stress threshold deviatoric stress crack damage stress deviatoric stress failure accord result crack damage occur early stage deviatoric loading high confining pressure',
#  'crack damage stress increase increase confinement influence confine pressure thermal crack development suppression widening exist micro crack',
#  'accord temperature range tendency identify increase confining increase elastic deformation region decrease stable crack propagation region increase unstable crack propagation region',
#  'crack initiation stress threshold progressively increase increase confine pressure attribute fact brittle behaviour rock specimen low confine pressure change quasi brittle behaviour increase confine pressure',
#  'suppression micro crack development low confine pressure sudden failure occur crack initiation occur early stage deviatoric loading high confine pressure high normal stress micro crack result limited progression cracking failure',
#  'relation temperature increase temperature initial increment crack propagation stress threshold follow slight reduction temperature condition',
#  'mpa confinement crack damage stress threshold ratio increase increase temperature room temperature reduce temperature increase',
#  'imply low temperature suppress micro crack development mechanism dominant increase temperature crack damage occur early loading stage',
#  'interestingly mpa confinement crack damage stress threshold ratio increase increase temperature room',
#  'exhibit cumulative temperature pressure micro crack development rock mass',
#  'low temperature micro crack propagation inhibit thermally induce plasticity mechanism occur crack increase bonding strength thermally induce rock matrix expansion increase crack stress threshold',
#  'increase temperature create thermally induce crack grain boundary crack widen result early crack damage',
#  'influence confinement micro crack development suppress low increment crack damage stress threshold ratio high confinement',
#  'alteration granite micro structure comprehensive micro structural analysis perform identify interior correspondence temperature dependent mechanical behaviour granite',
#  'sem optical microscopic analysis perform granite specimen room temperature pre heat',
#  'temperature select identify microstructural behaviour high strength increment observe clear thermally induce rock mass weakening observe',
#  'base optical microscope imaging mineralogical assembling granite specimen identify colour texture mineral assemblage',
#  'detailed sem study perform scanning electron imaging sei bsei scatter electron imaging bsei technique',
#  'bsei image low magnification mineral assemblage grain boundary energy dispersive ray edx technology aztec oxford instrument chemical component mapping generate specimen mineral identify qualitatively',
#  'bright colour image observe edx image high concentration high energy dispersion dark colour area low concentration low energy dispersion',
#  'base spectrum point point correspond mineral identify map spectrum provide element specimen',
#  'accord clear mineralogical assembling granite specimen quartz kfeldspar plagioclase',
#  'heating granite temperature thermally induce micro crack addition pre existing fault grain boundary grain boundary remain intact',
#  'heating granite high temperature induction micro crack',
#  'geothermics stress threshold fracturing stage',
#  'temperature confine pressure mpa deviatoric stress failure mpa crack closure threshold mpa crack initiation threshold mpa crack damage threshold mpa',
#  'crack propagation stress threshold ratio granite specimen test confining pressure temperature',
#  'quartz feldspar mineral intra granular crack quartz feldspar grain boundary inter granular crack',
#  'grain boundary crack grain boundary pore boundary identify',
#  'considerable number crack propagate triple junction dominantly quartz feldspar boundary',
#  'grain geothermic optical microscopic sem image strathbogie granite room pre heat pre heat',
#  'boundary partially number grain boundary remain intact temperature',
#  'base edx mapping confirm intra granular crack initiate feldspar quartz mineral',
#  'intragranular crack observe large crystal small crystal remain parted',
#  'strathbogie granite thermally induce intra granular micro crack play role low temperature presence high feldspar biotite content',
#  'observation report study conduct charcoal granite intra granular microcrack occur compare grain boundary crack',
#  'sem analysis consistent finding exhibit inhibition micro crack development follow micro cracking high temperature',
#  'crack propagation process rock mass influence mineralogical composition crack propagate weak plane rock mass',
#  'granite igneous type rock main type thermallyinduced cracking mode inter granular intragranular',
#  'inter granular intra granular cracking dependent stress state rock type mineralogy rock mass',
#  'inter granular crack occur grain boundary pre exist fault micro crack rock intragranular crack occur weak mineralogical constituent',
#  'feldspar biotite weak mineralogical constituent large crystal mm crystal great mm size generally define weak mineralogical constituent compare equi dimensional small crystal quartz homand etienne',
#  'base experimental result intra granular cracking highly temperature dependent temperature dependent dislocation rock',
#  'mineralogical component thermo elastic modulus thermal conductivity',
#  'observation micro cracking granite highly temperature dependent evidence observe initial strength gain follow slight strength reduction increase temperature test granite',
#  'granite heat sufficient temperature thermal crack heat low temperature strength gain thermal expansion rock matrix',
#  'consistent result mechanical property charcoal granite study remain steady westerly granite exhibit thermal dependency low temperature',
#  'homand etienne study variation uni axial compressive strength semones remiremont granite insignificant follow reduction high temperature',
#  'result dependency mineralogical composition grain size distribution temperature dependent mechanical behaviour type granite',
#  'bse image strathbogie granite edx room pre heat',
#  'series tri axial strength test conduct australian strathbogie granite confining pressure temperature simulate geothermal reservoir condition',
#  'conclusion mechanical behaviour test granite influence reservoir depth temperature depth great temperature',
#  'granite locate small depth fail shear localization increase depth change ductile failure strain hardening',
#  'progressive enhancement stress threshold increase confine pressure observe strathbogie granite',
#  'behaviour exhibit great strength low brittle characteristic granite locate great depth',
#  'increase temperature granite strength enhance temperature strathbogie granite thermal expansion rock matrix increase temperature weaken induce thermal crack',
#  'confirm micro structural analysis reveal noticeable thermally induce micro cracking strathbogie granite heating granite great temperature intra granular crack quartz feldspar grain boundary crack quartz feldspar mineral',
#  'accord analysis increase temperature crack propagation stress threshold increase increase temperature reduce',
#  'suppression micro crack low temperature matrix expansion development micro crack thermally induce damage high temperature',
#  'finally attempt improve conventional mohrcoulomb failure criterion geothermal reservoir extreme pressure temperature conventional criterion applicable extreme condition',
#  'acknowledgement project fund australian council arc author deep earth energy laboratory staff monash university clayton campus australia monash centre electron microscopy mcem dedicate time energy bring experimental series successful conclusion',
#  'sixth author extend appreciation deanship scientific king saud university saudi arabia fund work international group project']

# %% [markdown]
# ## NER Library

# %%
#Auto Read entities
dict_entities={}
path='C:/Users/Ryan Bobby A/Documents/RWTH AACHEN/KULIAH/THESIS_BISMILLAH/Thesis Progress/list_entities/'
for filename in glob.glob(os.path.join(path, '*.txt')):
    gist_file = open(filename, "r")
    try:
        content = gist_file.read().lower()
        dict_entities[re.search(r'(\w+).txt$',filename).group(1)] = list(filter(None, content.split("\n")))
    finally:
        gist_file.close()

# %%
#Ready for NLP NER
ready_ner = {'text':[],'tag':[],'entity':[]}
for i in prepro2:
    for j in dict_entities:
        pattern = r"(\.*\b(?:{}))\b".format("|".join(dict_entities[j]))
        if bool(re.search(pattern, i)) == True:
            for k in re.findall(pattern,i):
                if type(k) == tuple:
                    k = list(filter(None,[i for i in k]))
                    for m in k:
                        ready_ner['text'].append(i)
                        ready_ner['tag'].append(m)
                        ready_ner['entity'].append(re.search(r'list_(\w+)$',j).group(1))
                else:
                    ready_ner['text'].append(i)
                    ready_ner['tag'].append(k)
                    ready_ner['entity'].append(re.search(r'list_(\w+)$',j).group(1))
        else:
            pass

# %%
ready_ner['text']
# Out:
# ['introduction geothermal heat identify renewable reliable energy source severe environmental impact create conventional fossil fuel coal oil',
#  'introduction geothermal heat identify renewable reliable energy source severe environmental impact create conventional fossil fuel coal oil',
#  'exploratory geothermal drill test availability geothermal reservoir correspond author deep earth energy laboratory department civil engineering monash university building melbourne victoria australia',
#  'exploratory geothermal drill test availability geothermal reservoir correspond author deep earth energy laboratory department civil engineering monash university building melbourne victoria australia',
#  'exploratory geothermal drill test availability geothermal reservoir correspond author deep earth energy laboratory department civil engineering monash university building melbourne victoria australia',
#  'rock rock elevated temperature deep granite reservoir adequate temperature serve geothermal reservoir',
#  'rock rock elevated temperature deep granite reservoir adequate temperature serve geothermal reservoir',
#  'rock rock elevated temperature deep granite reservoir adequate temperature serve geothermal reservoir',
#  'exploration involve vast block fracture',
#  'exploration geothermal resource challenge engineer geologist high temperature stress environment geothermal reservoir',
#  'exploration geothermal resource challenge engineer geologist high temperature stress environment geothermal reservoir',
#  'exploration geothermal resource challenge engineer geologist high temperature stress environment geothermal reservoir',
#  'reason laboratory experiment conduct high pressure temperature condition geothermal condition assist provide geothermics basic prediction',
#  'reason laboratory experiment conduct high pressure temperature condition geothermal condition assist provide geothermics basic prediction',
#  'reason laboratory experiment conduct high pressure temperature condition geothermal condition assist provide geothermics basic prediction',
#  'reason laboratory experiment conduct high pressure temperature condition geothermal condition assist provide geothermics basic prediction',
#  'large number laboratory experiment conduct investigate influence high pressure temperature rock relation geothermal heat extraction deep geological disposal nuclear waste franc ois deep mining wawersik hannum geological storage',
#  'large number laboratory experiment conduct investigate influence high pressure temperature rock relation geothermal heat extraction deep geological disposal nuclear waste franc ois deep mining wawersik hannum geological storage',
#  'large number laboratory experiment conduct investigate influence high pressure temperature rock relation geothermal heat extraction deep geological disposal nuclear waste franc ois deep mining wawersik hannum geological storage',
#  'large number laboratory experiment conduct investigate influence high pressure temperature rock relation geothermal heat extraction deep geological disposal nuclear waste franc ois deep mining wawersik hannum geological storage',
#  'mechanical behaviour reservoir rock influence elevated temperature micro structure rock mass alter thermal expansion development new micro crack extend widen exist micro crack mineralogical alteration',
#  'mechanical behaviour reservoir rock influence elevated temperature micro structure rock mass alter thermal expansion development new micro crack extend widen exist micro crack mineralogical alteration',
#  'rock strength deformation criterion change temperature rock mechanical property compressive strength tensile strength elastic modulus cohesive strength friction angle decrease increase temperature',
#  'rock strength deformation criterion change temperature rock mechanical property compressive strength tensile strength elastic modulus cohesive strength friction angle decrease increase temperature',
#  'rock strength deformation criterion change temperature rock mechanical property compressive strength tensile strength elastic modulus cohesive strength friction angle decrease increase temperature',
#  'rock strength deformation criterion change temperature rock mechanical property compressive strength tensile strength elastic modulus cohesive strength friction angle decrease increase temperature',
#  'rock strength deformation criterion change temperature rock mechanical property compressive strength tensile strength elastic modulus cohesive strength friction angle decrease increase temperature',
#  'rock strength deformation criterion change temperature rock mechanical property compressive strength tensile strength elastic modulus cohesive strength friction angle decrease increase temperature',
#  'rock strength deformation criterion change temperature rock mechanical property compressive strength tensile strength elastic modulus cohesive strength friction angle decrease increase temperature',
#  'rock strength deformation criterion change temperature rock mechanical property compressive strength tensile strength elastic modulus cohesive strength friction angle decrease increase temperature',
#  'alteration affect confinement apply rock mass confine pressure suppression thermal crack widening exist micro crack',
#  'alteration affect confinement apply rock mass confine pressure suppression thermal crack widening exist micro crack',
#  'study identify transition rock failure mode brittle ductile increase confinement',
#  'transition diverse mineralogical composition grain boundary rock',
#  'transition diverse mineralogical composition grain boundary rock',
#  'transition diverse mineralogical composition grain boundary rock',
#  'transition diverse mineralogical composition grain boundary rock',
#  'study conduct investigate temperature dependent mechanical behaviour reservoir rock experiment conduct unconfined environment',
#  'heat specimen correspond temperature range test room temperature frequently method reliable geothermal reservoir experience continuous thermal stress',
#  'heat specimen correspond temperature range test room temperature frequently method reliable geothermal reservoir experience continuous thermal stress',
#  'heat specimen correspond temperature range test room temperature frequently method reliable geothermal reservoir experience continuous thermal stress',
#  'heat specimen correspond temperature range test room temperature frequently method reliable geothermal reservoir experience continuous thermal stress',
#  'heat specimen correspond temperature range test room temperature frequently method reliable geothermal reservoir experience continuous thermal stress',
#  'limitation occur limited number test facility simulate stress temperature condition actual geothermal reservoir',
#  'limitation occur limited number test facility simulate stress temperature condition actual geothermal reservoir',
#  'study analytically numerically evaluate mechanical property rock high temperature pressure capture stress strain behaviour failure criterion rock wide range confine pressure temperature australian granite',
#  'study analytically numerically evaluate mechanical property rock high temperature pressure capture stress strain behaviour failure criterion rock wide range confine pressure temperature australian granite',
#  'study analytically numerically evaluate mechanical property rock high temperature pressure capture stress strain behaviour failure criterion rock wide range confine pressure temperature australian granite',
#  'study analytically numerically evaluate mechanical property rock high temperature pressure capture stress strain behaviour failure criterion rock wide range confine pressure temperature australian granite',
#  'study analytically numerically evaluate mechanical property rock high temperature pressure capture stress strain behaviour failure criterion rock wide range confine pressure temperature australian granite',
#  'study analytically numerically evaluate mechanical property rock high temperature pressure capture stress strain behaviour failure criterion rock wide range confine pressure temperature australian granite',
#  'study analytically numerically evaluate mechanical property rock high temperature pressure capture stress strain behaviour failure criterion rock wide range confine pressure temperature australian granite',
#  'study analytically numerically evaluate mechanical property rock high temperature pressure capture stress strain behaviour failure criterion rock wide range confine pressure temperature australian granite',
#  'thermo elastic response failure criterion essential input engineering application high pressure temperature include geothermal extraction application',
#  'thermo elastic response failure criterion essential input engineering application high pressure temperature include geothermal extraction application',
#  'thermo elastic response failure criterion essential input engineering application high pressure temperature include geothermal extraction application',
#  'test material granite abundant crystalline rock earth medium coarse grain form result slow cooling magma',
#  'test material granite abundant crystalline rock earth medium coarse grain form result slow cooling magma',
#  'test material granite abundant crystalline rock earth medium coarse grain form result slow cooling magma',
#  'test material granite abundant crystalline rock earth medium coarse grain form result slow cooling magma',
#  'element bring elevated geothermal gradient deep granite reservoir ideal condition geothermal reservoir',
#  'mineralogical composition granite consist quartz feldspar plagioclase biotite small muscovite amphibole hornblende opaque',
#  'mineralogical composition granite consist quartz feldspar plagioclase biotite small muscovite amphibole hornblende opaque',
#  'mineralogical composition granite consist quartz feldspar plagioclase biotite small muscovite amphibole hornblende opaque',
#  'mineralogical composition granite consist quartz feldspar plagioclase biotite small muscovite amphibole hornblende opaque',
#  'mineralogical composition granite consist quartz feldspar plagioclase biotite small muscovite amphibole hornblende opaque',
#  'mineralogical composition granite consist quartz feldspar plagioclase biotite small muscovite amphibole hornblende opaque',
#  'mineralogical composition granite consist quartz feldspar plagioclase biotite small muscovite amphibole hornblende opaque',
#  'mineralogical composition granite consist quartz feldspar plagioclase biotite small muscovite amphibole hornblende opaque',
#  'mineralogical composition granite consist quartz feldspar plagioclase biotite small muscovite amphibole hornblende opaque',
#  'strathbogie granite high level discordant',
#  'strathbogie granite high level discordant',
#  'sampling location strathbogie batholith central victoria',
#  'sampling location strathbogie batholith central victoria',
#  'sampling location strathbogie batholith central victoria',
#  'physical mechanical petrographic property strathbogie granite room temperature atmospheric pressure condition',
#  'physical mechanical petrographic property strathbogie granite room temperature atmospheric pressure condition',
#  'physical mechanical petrographic property strathbogie granite room temperature atmospheric pressure condition',
#  'rock type granite colour average grain size petrographic description bulk density compressive strength mpa elastic modulus gpa porosity white dark brown consist feldspar biotite quartz plagioclase equigranular coarse grained type granite result xrd analysis',
#  'rock type granite colour average grain size petrographic description bulk density compressive strength mpa elastic modulus gpa porosity white dark brown consist feldspar biotite quartz plagioclase equigranular coarse grained type granite result xrd analysis',
#  'rock type granite colour average grain size petrographic description bulk density compressive strength mpa elastic modulus gpa porosity white dark brown consist feldspar biotite quartz plagioclase equigranular coarse grained type granite result xrd analysis',
#  'rock type granite colour average grain size petrographic description bulk density compressive strength mpa elastic modulus gpa porosity white dark brown consist feldspar biotite quartz plagioclase equigranular coarse grained type granite result xrd analysis',
#  'rock type granite colour average grain size petrographic description bulk density compressive strength mpa elastic modulus gpa porosity white dark brown consist feldspar biotite quartz plagioclase equigranular coarse grained type granite result xrd analysis',
#  'rock type granite colour average grain size petrographic description bulk density compressive strength mpa elastic modulus gpa porosity white dark brown consist feldspar biotite quartz plagioclase equigranular coarse grained type granite result xrd analysis',
#  'rock type granite colour average grain size petrographic description bulk density compressive strength mpa elastic modulus gpa porosity white dark brown consist feldspar biotite quartz plagioclase equigranular coarse grained type granite result xrd analysis',
#  'rock type granite colour average grain size petrographic description bulk density compressive strength mpa elastic modulus gpa porosity white dark brown consist feldspar biotite quartz plagioclase equigranular coarse grained type granite result xrd analysis',
#  'rock type granite colour average grain size petrographic description bulk density compressive strength mpa elastic modulus gpa porosity white dark brown consist feldspar biotite quartz plagioclase equigranular coarse grained type granite result xrd analysis',
#  'rock type granite colour average grain size petrographic description bulk density compressive strength mpa elastic modulus gpa porosity white dark brown consist feldspar biotite quartz plagioclase equigranular coarse grained type granite result xrd analysis',
#  'rock type granite colour average grain size petrographic description bulk density compressive strength mpa elastic modulus gpa porosity white dark brown consist feldspar biotite quartz plagioclase equigranular coarse grained type granite result xrd analysis',
#  'rock type granite colour average grain size petrographic description bulk density compressive strength mpa elastic modulus gpa porosity white dark brown consist feldspar biotite quartz plagioclase equigranular coarse grained type granite result xrd analysis',
#  'rock type granite colour average grain size petrographic description bulk density compressive strength mpa elastic modulus gpa porosity white dark brown consist feldspar biotite quartz plagioclase equigranular coarse grained type granite result xrd analysis',
#  'rock type granite colour average grain size petrographic description bulk density compressive strength mpa elastic modulus gpa porosity white dark brown consist feldspar biotite quartz plagioclase equigranular coarse grained type granite result xrd analysis',
#  'rock type granite colour average grain size petrographic description bulk density compressive strength mpa elastic modulus gpa porosity white dark brown consist feldspar biotite quartz plagioclase equigranular coarse grained type granite result xrd analysis',
#  'rock type granite colour average grain size petrographic description bulk density compressive strength mpa elastic modulus gpa porosity white dark brown consist feldspar biotite quartz plagioclase equigranular coarse grained type granite result xrd analysis',
#  'rock type granite colour average grain size petrographic description bulk density compressive strength mpa elastic modulus gpa porosity white dark brown consist feldspar biotite quartz plagioclase equigranular coarse grained type granite result xrd analysis',
#  'mineral alpha quartz sodic intermediate plagioclase biotite phlogopite feldspar clinochlore muscovite sericite dolomite ankerite mineral granite consist quartz feldspar cordierite biotite',
#  'mineral alpha quartz sodic intermediate plagioclase biotite phlogopite feldspar clinochlore muscovite sericite dolomite ankerite mineral granite consist quartz feldspar cordierite biotite',
#  'mineral alpha quartz sodic intermediate plagioclase biotite phlogopite feldspar clinochlore muscovite sericite dolomite ankerite mineral granite consist quartz feldspar cordierite biotite',
#  'mineral alpha quartz sodic intermediate plagioclase biotite phlogopite feldspar clinochlore muscovite sericite dolomite ankerite mineral granite consist quartz feldspar cordierite biotite',
#  'mineral alpha quartz sodic intermediate plagioclase biotite phlogopite feldspar clinochlore muscovite sericite dolomite ankerite mineral granite consist quartz feldspar cordierite biotite',
#  'mineral alpha quartz sodic intermediate plagioclase biotite phlogopite feldspar clinochlore muscovite sericite dolomite ankerite mineral granite consist quartz feldspar cordierite biotite',
#  'mineral alpha quartz sodic intermediate plagioclase biotite phlogopite feldspar clinochlore muscovite sericite dolomite ankerite mineral granite consist quartz feldspar cordierite biotite',
#  'mineral alpha quartz sodic intermediate plagioclase biotite phlogopite feldspar clinochlore muscovite sericite dolomite ankerite mineral granite consist quartz feldspar cordierite biotite',
#  'mineral alpha quartz sodic intermediate plagioclase biotite phlogopite feldspar clinochlore muscovite sericite dolomite ankerite mineral granite consist quartz feldspar cordierite biotite',
#  'mineral alpha quartz sodic intermediate plagioclase biotite phlogopite feldspar clinochlore muscovite sericite dolomite ankerite mineral granite consist quartz feldspar cordierite biotite',
#  'mineral alpha quartz sodic intermediate plagioclase biotite phlogopite feldspar clinochlore muscovite sericite dolomite ankerite mineral granite consist quartz feldspar cordierite biotite',
#  'mineral alpha quartz sodic intermediate plagioclase biotite phlogopite feldspar clinochlore muscovite sericite dolomite ankerite mineral granite consist quartz feldspar cordierite biotite',
#  'mineral alpha quartz sodic intermediate plagioclase biotite phlogopite feldspar clinochlore muscovite sericite dolomite ankerite mineral granite consist quartz feldspar cordierite biotite',
#  'mineral alpha quartz sodic intermediate plagioclase biotite phlogopite feldspar clinochlore muscovite sericite dolomite ankerite mineral granite consist quartz feldspar cordierite biotite',
#  'mineral alpha quartz sodic intermediate plagioclase biotite phlogopite feldspar clinochlore muscovite sericite dolomite ankerite mineral granite consist quartz feldspar cordierite biotite',
#  'select granite type coarsegrained white dark brown colour porosity',
#  'select granite type coarsegrained white dark brown colour porosity',
#  'select granite type coarsegrained white dark brown colour porosity',
#  'close view typical strathbogie granite sample optical microscopic image sem image',
#  'clear mineralogical assembling observe granite specimen quartz feldspar plagioclase',
#  'clear mineralogical assembling observe granite specimen quartz feldspar plagioclase',
#  'clear mineralogical assembling observe granite specimen quartz feldspar plagioclase',
#  'clear mineralogical assembling observe granite specimen quartz feldspar plagioclase',
#  'grain size measure granite small number range mm large grain mm summarize physical mechanical petrographic property test strathbogie granite',
#  'grain size measure granite small number range mm large grain mm summarize physical mechanical petrographic property test strathbogie granite',
#  'grain size measure granite small number range mm large grain mm summarize physical mechanical petrographic property test strathbogie granite',
#  'grain size measure granite small number range mm large grain mm summarize physical mechanical petrographic property test strathbogie granite',
#  'grain size measure granite small number range mm large grain mm summarize physical mechanical petrographic property test strathbogie granite',
#  'grain size measure granite small number range mm large grain mm summarize physical mechanical petrographic property test strathbogie granite',
#  'addition xrd analysis conduct determine mineralogical composition select granite result',
#  'addition xrd analysis conduct determine mineralogical composition select granite result',
#  'table quartz predominant mineral select granite follow sodic intermediate biotite plagioclase',
#  'table quartz predominant mineral select granite follow sodic intermediate biotite plagioclase',
#  'table quartz predominant mineral select granite follow sodic intermediate biotite plagioclase',
#  'table quartz predominant mineral select granite follow sodic intermediate biotite plagioclase',
#  'table quartz predominant mineral select granite follow sodic intermediate biotite plagioclase',
#  'table quartz predominant mineral select granite follow sodic intermediate biotite plagioclase',
#  'mineralogical composition granitic composition representative composition majority earth granite',
#  'mineralogical composition granitic composition representative composition majority earth granite',
#  'mineralogical composition granitic composition representative composition majority earth granite',
#  'mineralogical composition granitic composition representative composition majority earth granite',
#  'mineralogical composition granitic composition representative composition majority earth granite',
#  'conduct test xrd analysis mineral composition uniaxial compression testing compressive strength elastic modulus analysis average grain size mercury intrusion testing porosity volume weight measurement bulk density',
#  'conduct test xrd analysis mineral composition uniaxial compression testing compressive strength elastic modulus analysis average grain size mercury intrusion testing porosity volume weight measurement bulk density',
#  'conduct test xrd analysis mineral composition uniaxial compression testing compressive strength elastic modulus analysis average grain size mercury intrusion testing porosity volume weight measurement bulk density',
#  'conduct test xrd analysis mineral composition uniaxial compression testing compressive strength elastic modulus analysis average grain size mercury intrusion testing porosity volume weight measurement bulk density',
#  'conduct test xrd analysis mineral composition uniaxial compression testing compressive strength elastic modulus analysis average grain size mercury intrusion testing porosity volume weight measurement bulk density',
#  'conduct test xrd analysis mineral composition uniaxial compression testing compressive strength elastic modulus analysis average grain size mercury intrusion testing porosity volume weight measurement bulk density',
#  'conduct test xrd analysis mineral composition uniaxial compression testing compressive strength elastic modulus analysis average grain size mercury intrusion testing porosity volume weight measurement bulk density',
#  'conduct test xrd analysis mineral composition uniaxial compression testing compressive strength elastic modulus analysis average grain size mercury intrusion testing porosity volume weight measurement bulk density',
#  'order maintain consistency sample core mm diameter block granite orientation',
#  'order maintain consistency sample core mm diameter block granite orientation',
#  'order maintain consistency sample core mm diameter block granite orientation',
#  'avoid issue small coring rate adopt water lubricant',
#  'core specimen cut mm high cylinder specimen grind produce parallel surface perpendicular axis cylindrical specimen',
#  'experimental procedure tri axial experiment conduct sample confining pressure temperature',
#  'experimental procedure tri axial experiment conduct sample confining pressure temperature',
#  'experimental procedure tri axial experiment conduct sample confining pressure temperature',
#  'experimental condition select preferable hot dry rock generally locate depth mpa mpa confining pressure temperature',
#  'experimental condition select preferable hot dry rock generally locate depth mpa mpa confining pressure temperature',
#  'experimental condition select preferable hot dry rock generally locate depth mpa mpa confining pressure temperature',
#  'experimental condition select preferable hot dry rock generally locate depth mpa mpa confining pressure temperature',
#  'experimental condition select preferable hot dry rock generally locate depth mpa mpa confining pressure temperature',
#  'experimental condition select preferable hot dry rock generally locate depth mpa mpa confining pressure temperature',
#  'confining pressure temperature select simulate reservoir depth sufficient datum set understand failure criterion temperature',
#  'confining pressure temperature select simulate reservoir depth sufficient datum set understand failure criterion temperature',
#  'confining pressure temperature select simulate reservoir depth sufficient datum set understand failure criterion temperature',
#  'confining pressure temperature select simulate reservoir depth sufficient datum set understand failure criterion temperature',
#  'confining pressure temperature select simulate reservoir depth sufficient datum set understand failure criterion temperature',
#  'prepare sample place inside cell require confining pressure apply silicon oil anneal copper sleeve isolate sample confine liquid refer',
#  'prepare sample place inside cell require confining pressure apply silicon oil anneal copper sleeve isolate sample confine liquid refer',
#  'prepare sample place inside cell require confining pressure apply silicon oil anneal copper sleeve isolate sample confine liquid refer',
#  'mica insulate metal band heater heat pressure cell rock sample',
#  'mica insulate metal band heater heat pressure cell rock sample',
#  'mica insulate metal band heater heat pressure cell rock sample',
#  'mica insulate metal band heater heat pressure cell rock sample',
#  'temperature cell adjust controller constant small heating rate min prevent micro structural damage sudden thermal shock',
#  'temperature cell adjust controller constant small heating rate min prevent micro structural damage sudden thermal shock',
#  'temperature cell adjust controller constant small heating rate min prevent micro structural damage sudden thermal shock',
#  'temperature cell adjust controller constant small heating rate min prevent micro structural damage sudden thermal shock',
#  'separate thermocouple achieve precise temperature control reading thermocouple instal inside cell record data acquisition',
#  'barrel pressure cell cover insulate blanket reduce heat loss experiment minimise influence air flow cell',
#  'barrel pressure cell cover insulate blanket reduce heat loss experiment minimise influence air flow cell',
#  'test start achieve steady state ensure uniformity temperature pressure sample',
#  'test start achieve steady state ensure uniformity temperature pressure sample',
#  'steady state condition constant pump volume constant temperature observe testing initiate',
#  'constant loading pump flow rate min adopt test specimen convert displacement rate min',
#  'constant loading pump flow rate min adopt test specimen convert displacement rate min',
#  'constant loading pump flow rate min adopt test specimen convert displacement rate min',
#  'constant loading pump flow rate min adopt test specimen convert displacement rate min',
#  'sealing resistance measure pump pressure initiate movement loading shaft deduct pressure reading eliminate resistance sealing dur geothermics typical coulomb brittle deformation',
#  'sealing resistance measure pump pressure initiate movement loading shaft deduct pressure reading eliminate resistance sealing dur geothermics typical coulomb brittle deformation',
#  'deviatoric stress strain plot granite sample exhibit concave upward curvilinear trend initial loading peak strain softening occur rapid stress drop residual',
#  'deviatoric stress strain plot granite sample exhibit concave upward curvilinear trend initial loading peak strain softening occur rapid stress drop residual',
#  'deviatoric stress strain plot granite sample exhibit concave upward curvilinear trend initial loading peak strain softening occur rapid stress drop residual',
#  'deviatoric stress strain plot granite sample exhibit concave upward curvilinear trend initial loading peak strain softening occur rapid stress drop residual',
#  'deviatoric stress strain plot granite sample exhibit concave upward curvilinear trend initial loading peak strain softening occur rapid stress drop residual',
#  'increase peak stress increase confine pressure observe expect accord typical coulomb type brittle failure',
#  'increase peak stress increase confine pressure observe expect accord typical coulomb type brittle failure',
#  'traditionally rock failure compression occur main dilatancy failure strain softening low confine pressure failure strain harden elevate confining pressure transitional regime observe intermediate pressure',
#  'traditionally rock failure compression occur main dilatancy failure strain softening low confine pressure failure strain harden elevate confining pressure transitional regime observe intermediate pressure',
#  'traditionally rock failure compression occur main dilatancy failure strain softening low confine pressure failure strain harden elevate confining pressure transitional regime observe intermediate pressure',
#  'traditionally rock failure compression occur main dilatancy failure strain softening low confine pressure failure strain harden elevate confining pressure transitional regime observe intermediate pressure',
#  'traditionally rock failure compression occur main dilatancy failure strain softening low confine pressure failure strain harden elevate confining pressure transitional regime observe intermediate pressure',
#  'traditionally rock failure compression occur main dilatancy failure strain softening low confine pressure failure strain harden elevate confining pressure transitional regime observe intermediate pressure',
#  'traditionally rock failure compression occur main dilatancy failure strain softening low confine pressure failure strain harden elevate confining pressure transitional regime observe intermediate pressure',
#  'transitional failure mode refer complex localize feature conjugate shear band observe condition',
#  'visual inspection post failure sample alteration granite failure mechanism confine pressure temperature identify',
#  'visual inspection post failure sample alteration granite failure mechanism confine pressure temperature identify',
#  'visual inspection post failure sample alteration granite failure mechanism confine pressure temperature identify',
#  'accord post failure image specimen fail mpa confining pressure fail shear localization inclined macroscopic shear band single shear zone sample',
#  'accord post failure image specimen fail mpa confining pressure fail shear localization inclined macroscopic shear band single shear zone sample',
#  'accord post failure image specimen fail mpa confining pressure fail shear localization inclined macroscopic shear band single shear zone sample',
#  'accord post failure image specimen fail mpa confining pressure fail shear localization inclined macroscopic shear band single shear zone sample',
#  'accord post failure image specimen fail mpa confining pressure fail shear localization inclined macroscopic shear band single shear zone sample',
#  'accord post failure image specimen fail mpa confining pressure fail shear localization inclined macroscopic shear band single shear zone sample',
#  'sample test high confinement mpa mpa',
#  'sample test high confinement mpa mpa',
#  'sample test high confinement mpa mpa',
#  'exhibit strain harden characteristic achieve peak stress conjugate shear band observe cylindrical sample surface single shear band observe early',
#  'exhibit strain harden characteristic achieve peak stress conjugate shear band observe cylindrical sample surface single shear band observe early',
#  'exhibit strain harden characteristic achieve peak stress conjugate shear band observe cylindrical sample surface single shear band observe early',
#  'exhibit strain harden characteristic achieve peak stress conjugate shear band observe cylindrical sample surface single shear band observe early',
#  'note test conduct mpa confinement high confining pressure correspond failure load granite exceed pedestal load bear capacity',
#  'note test conduct mpa confinement high confining pressure correspond failure load granite exceed pedestal load bear capacity',
#  'note test conduct mpa confinement high confining pressure correspond failure load granite exceed pedestal load bear capacity',
#  'note test conduct mpa confinement high confining pressure correspond failure load granite exceed pedestal load bear capacity',
#  'note test conduct mpa confinement high confining pressure correspond failure load granite exceed pedestal load bear capacity',
#  'note test conduct mpa confinement high confining pressure correspond failure load granite exceed pedestal load bear capacity',
#  'progressive reduction observe failure plane angle respect minor principal stress direction increase confine pressure imply reduction friction angle great quasi brittle behaviour granite sample high confining pressure',
#  'progressive reduction observe failure plane angle respect minor principal stress direction increase confine pressure imply reduction friction angle great quasi brittle behaviour granite sample high confining pressure',
#  'progressive reduction observe failure plane angle respect minor principal stress direction increase confine pressure imply reduction friction angle great quasi brittle behaviour granite sample high confining pressure',
#  'progressive reduction observe failure plane angle respect minor principal stress direction increase confine pressure imply reduction friction angle great quasi brittle behaviour granite sample high confining pressure',
#  'progressive reduction observe failure plane angle respect minor principal stress direction increase confine pressure imply reduction friction angle great quasi brittle behaviour granite sample high confining pressure',
#  'progressive reduction observe failure plane angle respect minor principal stress direction increase confine pressure imply reduction friction angle great quasi brittle behaviour granite sample high confining pressure',
#  'progressive reduction observe failure plane angle respect minor principal stress direction increase confine pressure imply reduction friction angle great quasi brittle behaviour granite sample high confining pressure',
#  'temperature confine pressure mechanical property strathbogie granite illustrate influence temperature deviatoric stress test granite confinement',
#  'temperature confine pressure mechanical property strathbogie granite illustrate influence temperature deviatoric stress test granite confinement',
#  'temperature confine pressure mechanical property strathbogie granite illustrate influence temperature deviatoric stress test granite confinement',
#  'temperature confine pressure mechanical property strathbogie granite illustrate influence temperature deviatoric stress test granite confinement',
#  'temperature confine pressure mechanical property strathbogie granite illustrate influence temperature deviatoric stress test granite confinement',
#  'temperature confine pressure mechanical property strathbogie granite illustrate influence temperature deviatoric stress test granite confinement',
#  'figure influence confinement temperature temperature range',
#  'figure influence confinement temperature temperature range',
#  'confirm low confining pressure considerable thermal cracking occur low temperature',
#  'confirm low confining pressure considerable thermal cracking occur low temperature',
#  'confirm low confining pressure considerable thermal cracking occur low temperature',
#  'confirm low confining pressure considerable thermal cracking occur low temperature',
#  'thermal cracking responsible reduction failure strength sharp reduction deviatoric stress increase temperature suppression thermal crack exhibit unconfined pressure condition',
#  'thermal cracking responsible reduction failure strength sharp reduction deviatoric stress increase temperature suppression thermal crack exhibit unconfined pressure condition',
#  'thermal cracking responsible reduction failure strength sharp reduction deviatoric stress increase temperature suppression thermal crack exhibit unconfined pressure condition',
#  'thermal cracking responsible reduction failure strength sharp reduction deviatoric stress increase temperature suppression thermal crack exhibit unconfined pressure condition',
#  'thermal cracking responsible reduction failure strength sharp reduction deviatoric stress increase temperature suppression thermal crack exhibit unconfined pressure condition',
#  'thermal cracking responsible reduction failure strength sharp reduction deviatoric stress increase temperature suppression thermal crack exhibit unconfined pressure condition',
#  'base experimental result unconfined condition increment deviatoric stress follow reduction',
#  'confinement apply strength reduction initiate high temperature inhibition thermal crack induce compressive force',
#  'confinement apply strength reduction initiate high temperature inhibition thermal crack induce compressive force',
#  'confinement apply strength reduction initiate high temperature inhibition thermal crack induce compressive force',
#  'confinement apply strength reduction initiate high temperature inhibition thermal crack induce compressive force',
#  'thermal cracking strength property alteration mechanism reservoir rock confine pressure condition',
#  'thermal cracking strength property alteration mechanism reservoir rock confine pressure condition',
#  'thermal cracking strength property alteration mechanism reservoir rock confine pressure condition',
#  'clear influence temperature deviatoric stress depth confinement observe increase temperature room temperature increment deviatoric stress increase temperature',
#  'clear influence temperature deviatoric stress depth confinement observe increase temperature room temperature increment deviatoric stress increase temperature',
#  'clear influence temperature deviatoric stress depth confinement observe increase temperature room temperature increment deviatoric stress increase temperature',
#  'clear influence temperature deviatoric stress depth confinement observe increase temperature room temperature increment deviatoric stress increase temperature',
#  'clear influence temperature deviatoric stress depth confinement observe increase temperature room temperature increment deviatoric stress increase temperature',
#  'clear influence temperature deviatoric stress depth confinement observe increase temperature room temperature increment deviatoric stress increase temperature',
#  'clear influence temperature deviatoric stress depth confinement observe increase temperature room temperature increment deviatoric stress increase temperature',
#  'thermal expansion occur increase temperature reduction',
#  'thermal expansion occur increase temperature reduction',
#  'high pressure high temperature tri axial machine inside view cell',
#  'high pressure high temperature tri axial machine inside view cell',
#  'high pressure high temperature tri axial machine inside view cell',
#  'high pressure high temperature tri axial machine inside view cell',
#  'load application axial strain measure linear variable differential transducer lvdt attach ram load cell',
#  'load application axial strain measure linear variable differential transducer lvdt attach ram load cell',
#  'adopt peripheral component interconnection pci nominal resolution frequency khz',
#  'adopt peripheral component interconnection pci nominal resolution frequency khz',
#  'experiment sensor attach loading shaft external amplifier generate low frequency acoustic wave fracturing sample',
#  'addition micro structural mineralogical change occur thermal confinement check sem analysis',
#  'stress strain response influence temperature stress strain behaviour test granite test result deviatoric load failure deviatoric stress failure triaxial compressive strength elastic modulus illustrate relationship deviatoric stress axial strain curve sample test mpa confining pressure temperature',
#  'stress strain response influence temperature stress strain behaviour test granite test result deviatoric load failure deviatoric stress failure triaxial compressive strength elastic modulus illustrate relationship deviatoric stress axial strain curve sample test mpa confining pressure temperature',
#  'stress strain response influence temperature stress strain behaviour test granite test result deviatoric load failure deviatoric stress failure triaxial compressive strength elastic modulus illustrate relationship deviatoric stress axial strain curve sample test mpa confining pressure temperature',
#  'stress strain response influence temperature stress strain behaviour test granite test result deviatoric load failure deviatoric stress failure triaxial compressive strength elastic modulus illustrate relationship deviatoric stress axial strain curve sample test mpa confining pressure temperature',
#  'stress strain response influence temperature stress strain behaviour test granite test result deviatoric load failure deviatoric stress failure triaxial compressive strength elastic modulus illustrate relationship deviatoric stress axial strain curve sample test mpa confining pressure temperature',
#  'stress strain response influence temperature stress strain behaviour test granite test result deviatoric load failure deviatoric stress failure triaxial compressive strength elastic modulus illustrate relationship deviatoric stress axial strain curve sample test mpa confining pressure temperature',
#  'stress strain response influence temperature stress strain behaviour test granite test result deviatoric load failure deviatoric stress failure triaxial compressive strength elastic modulus illustrate relationship deviatoric stress axial strain curve sample test mpa confining pressure temperature',
#  'stress strain response influence temperature stress strain behaviour test granite test result deviatoric load failure deviatoric stress failure triaxial compressive strength elastic modulus illustrate relationship deviatoric stress axial strain curve sample test mpa confining pressure temperature',
#  'stress strain response influence temperature stress strain behaviour test granite test result deviatoric load failure deviatoric stress failure triaxial compressive strength elastic modulus illustrate relationship deviatoric stress axial strain curve sample test mpa confining pressure temperature',
#  'stress strain response influence temperature stress strain behaviour test granite test result deviatoric load failure deviatoric stress failure triaxial compressive strength elastic modulus illustrate relationship deviatoric stress axial strain curve sample test mpa confining pressure temperature',
#  'stress strain response influence temperature stress strain behaviour test granite test result deviatoric load failure deviatoric stress failure triaxial compressive strength elastic modulus illustrate relationship deviatoric stress axial strain curve sample test mpa confining pressure temperature',
#  'stress strain response influence temperature stress strain behaviour test granite test result deviatoric load failure deviatoric stress failure triaxial compressive strength elastic modulus illustrate relationship deviatoric stress axial strain curve sample test mpa confining pressure temperature',
#  'stress strain response influence temperature stress strain behaviour test granite test result deviatoric load failure deviatoric stress failure triaxial compressive strength elastic modulus illustrate relationship deviatoric stress axial strain curve sample test mpa confining pressure temperature',
#  'stress strain response influence temperature stress strain behaviour test granite test result deviatoric load failure deviatoric stress failure triaxial compressive strength elastic modulus illustrate relationship deviatoric stress axial strain curve sample test mpa confining pressure temperature',
#  'stress strain response influence temperature stress strain behaviour test granite test result deviatoric load failure deviatoric stress failure triaxial compressive strength elastic modulus illustrate relationship deviatoric stress axial strain curve sample test mpa confining pressure temperature',
#  'relation stress strain curve strathbogie granite triaxial loading correspond failure mode characterize geothermics mechanical property strathbogie granite test temperature pressure',
#  'relation stress strain curve strathbogie granite triaxial loading correspond failure mode characterize geothermics mechanical property strathbogie granite test temperature pressure',
#  'relation stress strain curve strathbogie granite triaxial loading correspond failure mode characterize geothermics mechanical property strathbogie granite test temperature pressure',
#  'relation stress strain curve strathbogie granite triaxial loading correspond failure mode characterize geothermics mechanical property strathbogie granite test temperature pressure',
#  'relation stress strain curve strathbogie granite triaxial loading correspond failure mode characterize geothermics mechanical property strathbogie granite test temperature pressure',
#  'relation stress strain curve strathbogie granite triaxial loading correspond failure mode characterize geothermics mechanical property strathbogie granite test temperature pressure',
#  'confining pressure mpa deviatoric load failure kn mpa mpa elastic modulus gpa mpa mpa mpa mpa axial strain',
#  'confining pressure mpa deviatoric load failure kn mpa mpa elastic modulus gpa mpa mpa mpa mpa axial strain',
#  'confining pressure mpa deviatoric load failure kn mpa mpa elastic modulus gpa mpa mpa mpa mpa axial strain',
#  'confining pressure mpa deviatoric load failure kn mpa mpa elastic modulus gpa mpa mpa mpa mpa axial strain',
#  'confining pressure mpa deviatoric load failure kn mpa mpa elastic modulus gpa mpa mpa mpa mpa axial strain',
#  'confining pressure mpa deviatoric load failure kn mpa mpa elastic modulus gpa mpa mpa mpa mpa axial strain',
#  'confining pressure mpa deviatoric load failure kn mpa mpa elastic modulus gpa mpa mpa mpa mpa axial strain',
#  'confining pressure mpa deviatoric load failure kn mpa mpa elastic modulus gpa mpa mpa mpa mpa axial strain',
#  'confining pressure mpa deviatoric load failure kn mpa mpa elastic modulus gpa mpa mpa mpa mpa axial strain',
#  'confining pressure mpa deviatoric load failure kn mpa mpa elastic modulus gpa mpa mpa mpa mpa axial strain',
#  'confining pressure mpa deviatoric load failure kn mpa mpa elastic modulus gpa mpa mpa mpa mpa axial strain',
#  'confining pressure mpa deviatoric load failure kn mpa mpa elastic modulus gpa mpa mpa mpa mpa axial strain',
#  'correspond stress strain response granite temperature',
#  'correspond stress strain response granite temperature',
#  'correspond stress strain response granite temperature',
#  'correspond stress strain response granite temperature',
#  'distance interface individual mineral increase mutual attraction bonding strength',
#  'distance interface individual mineral increase mutual attraction bonding strength',
#  'increase temperature crystalline particle rock mass fracture pre exist grain boundary mineral grain thermoelastic modulus thermal conductivity result reduce rock strength',
#  'increase temperature crystalline particle rock mass fracture pre exist grain boundary mineral grain thermoelastic modulus thermal conductivity result reduce rock strength',
#  'increase temperature crystalline particle rock mass fracture pre exist grain boundary mineral grain thermoelastic modulus thermal conductivity result reduce rock strength',
# ...
#  'grain geothermic optical microscopic sem image strathbogie granite room pre heat pre heat',
#  'grain geothermic optical microscopic sem image strathbogie granite room pre heat pre heat',
#  'boundary partially number grain boundary remain intact temperature',
#  'boundary partially number grain boundary remain intact temperature',
#  'boundary partially number grain boundary remain intact temperature',
#  'base edx mapping confirm intra granular crack initiate feldspar quartz mineral',
#  'base edx mapping confirm intra granular crack initiate feldspar quartz mineral',
#  'base edx mapping confirm intra granular crack initiate feldspar quartz mineral',
#  'intragranular crack observe large crystal small crystal remain parted',
#  'intragranular crack observe large crystal small crystal remain parted',
#  'strathbogie granite thermally induce intra granular micro crack play role low temperature presence high feldspar biotite content',
#  'strathbogie granite thermally induce intra granular micro crack play role low temperature presence high feldspar biotite content',
#  'strathbogie granite thermally induce intra granular micro crack play role low temperature presence high feldspar biotite content',
#  'strathbogie granite thermally induce intra granular micro crack play role low temperature presence high feldspar biotite content',
#  'strathbogie granite thermally induce intra granular micro crack play role low temperature presence high feldspar biotite content',
#  'observation report study conduct charcoal granite intra granular microcrack occur compare grain boundary crack',
#  'observation report study conduct charcoal granite intra granular microcrack occur compare grain boundary crack',
#  'observation report study conduct charcoal granite intra granular microcrack occur compare grain boundary crack',
#  'sem analysis consistent finding exhibit inhibition micro crack development follow micro cracking high temperature',
#  'sem analysis consistent finding exhibit inhibition micro crack development follow micro cracking high temperature',
#  'crack propagation process rock mass influence mineralogical composition crack propagate weak plane rock mass',
#  'granite igneous type rock main type thermallyinduced cracking mode inter granular intragranular',
#  'granite igneous type rock main type thermallyinduced cracking mode inter granular intragranular',
#  'inter granular intra granular cracking dependent stress state rock type mineralogy rock mass',
#  'inter granular crack occur grain boundary pre exist fault micro crack rock intragranular crack occur weak mineralogical constituent',
#  'inter granular crack occur grain boundary pre exist fault micro crack rock intragranular crack occur weak mineralogical constituent',
#  'inter granular crack occur grain boundary pre exist fault micro crack rock intragranular crack occur weak mineralogical constituent',
#  'feldspar biotite weak mineralogical constituent large crystal mm crystal great mm size generally define weak mineralogical constituent compare equi dimensional small crystal quartz homand etienne',
#  'feldspar biotite weak mineralogical constituent large crystal mm crystal great mm size generally define weak mineralogical constituent compare equi dimensional small crystal quartz homand etienne',
#  'feldspar biotite weak mineralogical constituent large crystal mm crystal great mm size generally define weak mineralogical constituent compare equi dimensional small crystal quartz homand etienne',
#  'feldspar biotite weak mineralogical constituent large crystal mm crystal great mm size generally define weak mineralogical constituent compare equi dimensional small crystal quartz homand etienne',
#  'feldspar biotite weak mineralogical constituent large crystal mm crystal great mm size generally define weak mineralogical constituent compare equi dimensional small crystal quartz homand etienne',
#  'feldspar biotite weak mineralogical constituent large crystal mm crystal great mm size generally define weak mineralogical constituent compare equi dimensional small crystal quartz homand etienne',
#  'base experimental result intra granular cracking highly temperature dependent temperature dependent dislocation rock',
#  'base experimental result intra granular cracking highly temperature dependent temperature dependent dislocation rock',
#  'mineralogical component thermo elastic modulus thermal conductivity',
#  'mineralogical component thermo elastic modulus thermal conductivity',
#  'observation micro cracking granite highly temperature dependent evidence observe initial strength gain follow slight strength reduction increase temperature test granite',
#  'observation micro cracking granite highly temperature dependent evidence observe initial strength gain follow slight strength reduction increase temperature test granite',
#  'observation micro cracking granite highly temperature dependent evidence observe initial strength gain follow slight strength reduction increase temperature test granite',
#  'observation micro cracking granite highly temperature dependent evidence observe initial strength gain follow slight strength reduction increase temperature test granite',
#  'observation micro cracking granite highly temperature dependent evidence observe initial strength gain follow slight strength reduction increase temperature test granite',
#  'observation micro cracking granite highly temperature dependent evidence observe initial strength gain follow slight strength reduction increase temperature test granite',
#  'granite heat sufficient temperature thermal crack heat low temperature strength gain thermal expansion rock matrix',
#  'granite heat sufficient temperature thermal crack heat low temperature strength gain thermal expansion rock matrix',
#  'granite heat sufficient temperature thermal crack heat low temperature strength gain thermal expansion rock matrix',
#  'granite heat sufficient temperature thermal crack heat low temperature strength gain thermal expansion rock matrix',
#  'granite heat sufficient temperature thermal crack heat low temperature strength gain thermal expansion rock matrix',
#  'granite heat sufficient temperature thermal crack heat low temperature strength gain thermal expansion rock matrix',
#  'granite heat sufficient temperature thermal crack heat low temperature strength gain thermal expansion rock matrix',
#  'granite heat sufficient temperature thermal crack heat low temperature strength gain thermal expansion rock matrix',
#  'consistent result mechanical property charcoal granite study remain steady westerly granite exhibit thermal dependency low temperature',
#  'consistent result mechanical property charcoal granite study remain steady westerly granite exhibit thermal dependency low temperature',
#  'consistent result mechanical property charcoal granite study remain steady westerly granite exhibit thermal dependency low temperature',
#  'consistent result mechanical property charcoal granite study remain steady westerly granite exhibit thermal dependency low temperature',
#  'consistent result mechanical property charcoal granite study remain steady westerly granite exhibit thermal dependency low temperature',
#  'homand etienne study variation uni axial compressive strength semones remiremont granite insignificant follow reduction high temperature',
#  'homand etienne study variation uni axial compressive strength semones remiremont granite insignificant follow reduction high temperature',
#  'homand etienne study variation uni axial compressive strength semones remiremont granite insignificant follow reduction high temperature',
#  'homand etienne study variation uni axial compressive strength semones remiremont granite insignificant follow reduction high temperature',
#  'result dependency mineralogical composition grain size distribution temperature dependent mechanical behaviour type granite',
#  'result dependency mineralogical composition grain size distribution temperature dependent mechanical behaviour type granite',
#  'result dependency mineralogical composition grain size distribution temperature dependent mechanical behaviour type granite',
#  'result dependency mineralogical composition grain size distribution temperature dependent mechanical behaviour type granite',
#  'result dependency mineralogical composition grain size distribution temperature dependent mechanical behaviour type granite',
#  'bse image strathbogie granite edx room pre heat',
#  'bse image strathbogie granite edx room pre heat',
#  'series tri axial strength test conduct australian strathbogie granite confining pressure temperature simulate geothermal reservoir condition',
#  'series tri axial strength test conduct australian strathbogie granite confining pressure temperature simulate geothermal reservoir condition',
#  'series tri axial strength test conduct australian strathbogie granite confining pressure temperature simulate geothermal reservoir condition',
#  'series tri axial strength test conduct australian strathbogie granite confining pressure temperature simulate geothermal reservoir condition',
#  'series tri axial strength test conduct australian strathbogie granite confining pressure temperature simulate geothermal reservoir condition',
#  'conclusion mechanical behaviour test granite influence reservoir depth temperature depth great temperature',
#  'conclusion mechanical behaviour test granite influence reservoir depth temperature depth great temperature',
#  'conclusion mechanical behaviour test granite influence reservoir depth temperature depth great temperature',
#  'conclusion mechanical behaviour test granite influence reservoir depth temperature depth great temperature',
#  'conclusion mechanical behaviour test granite influence reservoir depth temperature depth great temperature',
#  'granite locate small depth fail shear localization increase depth change ductile failure strain hardening',
#  'granite locate small depth fail shear localization increase depth change ductile failure strain hardening',
#  'granite locate small depth fail shear localization increase depth change ductile failure strain hardening',
#  'granite locate small depth fail shear localization increase depth change ductile failure strain hardening',
#  'granite locate small depth fail shear localization increase depth change ductile failure strain hardening',
#  'progressive enhancement stress threshold increase confine pressure observe strathbogie granite',
#  'progressive enhancement stress threshold increase confine pressure observe strathbogie granite',
#  'progressive enhancement stress threshold increase confine pressure observe strathbogie granite',
#  'behaviour exhibit great strength low brittle characteristic granite locate great depth',
#  'behaviour exhibit great strength low brittle characteristic granite locate great depth',
#  'behaviour exhibit great strength low brittle characteristic granite locate great depth',
#  'increase temperature granite strength enhance temperature strathbogie granite thermal expansion rock matrix increase temperature weaken induce thermal crack',
#  'increase temperature granite strength enhance temperature strathbogie granite thermal expansion rock matrix increase temperature weaken induce thermal crack',
#  'increase temperature granite strength enhance temperature strathbogie granite thermal expansion rock matrix increase temperature weaken induce thermal crack',
#  'increase temperature granite strength enhance temperature strathbogie granite thermal expansion rock matrix increase temperature weaken induce thermal crack',
#  'increase temperature granite strength enhance temperature strathbogie granite thermal expansion rock matrix increase temperature weaken induce thermal crack',
#  'increase temperature granite strength enhance temperature strathbogie granite thermal expansion rock matrix increase temperature weaken induce thermal crack',
#  'increase temperature granite strength enhance temperature strathbogie granite thermal expansion rock matrix increase temperature weaken induce thermal crack',
#  'increase temperature granite strength enhance temperature strathbogie granite thermal expansion rock matrix increase temperature weaken induce thermal crack',
#  'confirm micro structural analysis reveal noticeable thermally induce micro cracking strathbogie granite heating granite great temperature intra granular crack quartz feldspar grain boundary crack quartz feldspar mineral',
#  'confirm micro structural analysis reveal noticeable thermally induce micro cracking strathbogie granite heating granite great temperature intra granular crack quartz feldspar grain boundary crack quartz feldspar mineral',
#  'confirm micro structural analysis reveal noticeable thermally induce micro cracking strathbogie granite heating granite great temperature intra granular crack quartz feldspar grain boundary crack quartz feldspar mineral',
#  'confirm micro structural analysis reveal noticeable thermally induce micro cracking strathbogie granite heating granite great temperature intra granular crack quartz feldspar grain boundary crack quartz feldspar mineral',
#  'confirm micro structural analysis reveal noticeable thermally induce micro cracking strathbogie granite heating granite great temperature intra granular crack quartz feldspar grain boundary crack quartz feldspar mineral',
#  'confirm micro structural analysis reveal noticeable thermally induce micro cracking strathbogie granite heating granite great temperature intra granular crack quartz feldspar grain boundary crack quartz feldspar mineral',
#  'confirm micro structural analysis reveal noticeable thermally induce micro cracking strathbogie granite heating granite great temperature intra granular crack quartz feldspar grain boundary crack quartz feldspar mineral',
#  'confirm micro structural analysis reveal noticeable thermally induce micro cracking strathbogie granite heating granite great temperature intra granular crack quartz feldspar grain boundary crack quartz feldspar mineral',
#  'confirm micro structural analysis reveal noticeable thermally induce micro cracking strathbogie granite heating granite great temperature intra granular crack quartz feldspar grain boundary crack quartz feldspar mineral',
#  'confirm micro structural analysis reveal noticeable thermally induce micro cracking strathbogie granite heating granite great temperature intra granular crack quartz feldspar grain boundary crack quartz feldspar mineral',
#  'accord analysis increase temperature crack propagation stress threshold increase increase temperature reduce',
#  'accord analysis increase temperature crack propagation stress threshold increase increase temperature reduce',
#  'accord analysis increase temperature crack propagation stress threshold increase increase temperature reduce',
#  'suppression micro crack low temperature matrix expansion development micro crack thermally induce damage high temperature',
#  'suppression micro crack low temperature matrix expansion development micro crack thermally induce damage high temperature',
#  'suppression micro crack low temperature matrix expansion development micro crack thermally induce damage high temperature',
#  'finally attempt improve conventional mohrcoulomb failure criterion geothermal reservoir extreme pressure temperature conventional criterion applicable extreme condition',
#  'finally attempt improve conventional mohrcoulomb failure criterion geothermal reservoir extreme pressure temperature conventional criterion applicable extreme condition',
#  'finally attempt improve conventional mohrcoulomb failure criterion geothermal reservoir extreme pressure temperature conventional criterion applicable extreme condition',
#  'acknowledgement project fund australian council arc author deep earth energy laboratory staff monash university clayton campus australia monash centre electron microscopy mcem dedicate time energy bring experimental series successful conclusion',
#  'sixth author extend appreciation deanship scientific king saud university saudi arabia fund work international group project']

# %%
ready_ner['tag']
# Out:
# ['heat',
#  'coal',
#  'australia',
#  'victoria',
#  'victoria',
#  'temperature',
#  'temperature',
#  'granite',
#  'block',
#  'temperature',
#  'stress',
#  'high',
#  'pressure',
#  'temperature',
#  'high',
#  'basic',
#  'pressure',
#  'temperature',
#  'heat',
#  'high',
#  'temperature',
#  'thermal',
#  'strength',
#  'temperature',
#  'strength',
#  'tensile strength',
#  'modulus',
#  'strength',
#  'friction',
#  'temperature',
#  'pressure',
#  'thermal',
#  'transition',
#  'grain',
#  'transition',
#  'composition',
#  'grain',
#  'temperature',
#  'heat',
#  'temperature',
#  'temperature',
#  'thermal',
#  'stress',
#  'stress',
#  'temperature',
#  'temperature',
#  'pressure',
#  'stress',
#  'strain',
#  'pressure',
#  'temperature',
#  'high',
#  'granite',
#  'pressure',
#  'temperature',
#  'high',
#  'grain',
#  'granite',
#  'coarse',
#  'grain',
#  'granite',
#  'composition',
#  'granite',
#  'quartz',
#  'feldspar',
#  'plagioclase',
#  'biotite',
#  'muscovite',
#  'amphibole',
#  'hornblende',
#  'granite',
#  'high',
#  'victoria',
#  'central',
#  'victoria',
#  'temperature',
#  'pressure',
#  'granite',
#  'grain',
#  'bulk density',
#  'strength',
#  'mpa',
#  'modulus',
#  'gpa',
#  'porosity',
#  'granite',
#  'grain',
#  'brown',
#  'feldspar',
#  'biotite',
#  'quartz',
#  'plagioclase',
#  'coarse',
#  'grained',
#  'granite',
#  'mineral',
#  'quartz',
#  'intermediate',
#  'plagioclase',
#  'biotite',
#  'feldspar',
#  'muscovite',
#  'sericite',
#  'dolomite',
#  'mineral',
#  'granite',
#  'quartz',
#  'feldspar',
#  'cordierite',
#  'biotite',
#  'porosity',
#  'granite',
#  'brown',
#  'granite',
#  'granite',
#  'quartz',
#  'feldspar',
#  'plagioclase',
#  'grain',
#  'grain',
#  'grain',
#  'granite',
#  'grain',
#  'granite',
#  'composition',
#  'granite',
#  'quartz',
#  'mineral',
#  'granite',
#  'intermediate',
#  'biotite',
#  'plagioclase',
#  'composition',
#  'granitic',
#  'composition',
#  'composition',
#  'granite',
#  'strength',
#  'modulus',
#  'grain',
#  'porosity',
#  'bulk density',
#  'mineral',
#  'composition',
#  'grain',
#  'diameter',
#  'block',
#  'granite',
#  'rate',
#  'high',
#  'confining',
#  'pressure',
#  'temperature',
#  'depth',
#  'mpa',
#  'mpa',
#  'confining',
#  'pressure',
#  'temperature',
#  'confining',
#  'pressure',
#  'temperature',
#  'depth',
#  'temperature',
#  'confining',
#  'pressure',
#  'copper',
#  'heat',
#  'pressure',
#  'mica',
#  'metal',
#  'temperature',
#  'rate',
#  'min',
#  'thermal',
#  'temperature',
#  'pressure',
#  'heat',
#  'temperature',
#  'pressure',
#  'temperature',
#  'rate',
#  'min',
#  'rate',
#  'min',
#  'pressure',
#  'pressure',
#  'stress',
#  'strain',
#  'strain',
#  'stress',
#  'granite',
#  'stress',
#  'pressure',
#  'strain',
#  'pressure',
#  'strain',
#  'confining',
#  'pressure',
#  'pressure',
#  'intermediate',
#  'shear',
#  'pressure',
#  'temperature',
#  'granite',
#  'mpa',
#  'confining',
#  'pressure',
#  'shear',
#  'shear',
#  'shear',
#  'mpa',
#  'mpa',
#  'high',
#  'strain',
#  'stress',
#  'shear',
#  'shear',
#  'mpa',
#  'confining',
#  'pressure',
#  'capacity',
#  'high',
#  'granite',
#  'stress',
#  'pressure',
#  'friction',
#  'confining',
#  'pressure',
#  'granite',
#  'high',
#  'temperature',
#  'pressure',
#  'temperature',
#  'stress',
#  'granite',
#  'granite',
#  'temperature',
#  'temperature',
#  'confining',
#  'pressure',
#  'thermal',
#  'temperature',
#  'thermal',
#  'strength',
#  'stress',
#  'temperature',
#  'thermal',
#  'pressure',
#  'stress',
#  'strength',
#  'temperature',
#  'thermal',
#  'high',
#  'thermal',
#  'strength',
#  'pressure',
#  'temperature',
#  'stress',
#  'depth',
#  'temperature',
#  'temperature',
#  'stress',
#  'temperature',
#  'thermal',
#  'temperature',
#  'pressure',
#  'temperature',
#  'high',
#  'high',
#  'strain',
#  'differential',
#  'frequency',
#  'khz',
#  'frequency',
#  'thermal',
#  'stress',
#  'strain',
#  'temperature',
#  'stress',
#  'strain',
#  'stress',
#  'strength',
#  'modulus',
#  'stress',
#  'strain',
#  'mpa',
#  'confining',
#  'pressure',
#  'temperature',
#  'granite',
#  'stress',
#  'strain',
#  'temperature',
#  'pressure',
#  'granite',
#  'granite',
#  'confining',
#  'pressure',
#  'mpa',
#  'mpa',
#  'mpa',
#  'modulus',
#  'gpa',
#  'mpa',
#  'mpa',
#  'mpa',
#  'mpa',
#  'strain',
#  'stress',
#  'strain',
#  'temperature',
#  'granite',
#  'strength',
#  'mineral',
#  'temperature',
#  'grain',
#  'grain',
#  'modulus',
#  'thermal conductivity',
#  'strength',
#  'grain',
#  'mineral',
#  'grain',
#  'lead',
#  'westerly',
#  'temperature',
#  'stress',
#  'mpa',
#  'mpa',
#  'mpa',
#  'mpa',
#  'mpa',
#  'mpa',
#  'strain',
#  'mpa',
#  'mpa',
#  'mpa',
#  'mpa',
#  'strain',
#  'lead',
#  'granite',
#  'strength',
#  'temperature',
#  'high',
#  'temperature',
#  'temperature',
#  'temperature',
#  'temperature',
#  'temperature',
#  'stress',
#  'temperature',
#  'granite',
#  'modulus',
#  'stress',
#  'stress',
#  'temperature',
#  'modulus',
#  'granite',
#  'stress',
#  'strain',
#  'temperature',
#  'pressure',
#  'modulus',
#  'strain',
#  'modulus',
#  'temperature',
#  'temperature',
#  'modulus',
#  'granite',
#  'modulus',
#  'mpa',
#  'modulus',
#  'stress',
#  'strain',
#  'granite',
#  'high',
#  'mpa',
#  'mpa',
#  'strain',
#  'mpa',
#  'modulus',
#  'mpa',
#  'confining',
#  'pressure',
#  'temperature',
#  'temperature',
#  'temperature',
#  'temperature',
#  'granite',
#  'granite',
#  'high',
#  'strength',
#  'coarse',
#  'grained',
#  'granite',
#  'granodiorite',
#  'grained',
#  'granite',
#  'westerly',
#  'temperature',
#  'temperature',
#  'temperature',
#  'temperature',
#  'granite',
#  'granite',
#  'high',
#  'grain',
#  'grain',
#  'granite',
#  'grain',
#  'grain',
#  'composition',
#  'granite',
#  'temperature',
#  'strength',
#  'composition',
#  'granite',
#  'temperature',
#  'shear',
#  'strength',
#  'stress',
#  'pressure',
#  'temperature',
#  'granite',
#  'granite',
#  'stress',
#  'granite',
#  'strength',
#  'rate',
#  'pressure',
#  'confining',
#  'pressure',
#  'high',
#  'friction',
#  'high',
#  'high',
#  'friction',
#  'confining',
#  'pressure',
#  'high',
#  'critical',
#  'confining',
#  'pressure',
#  'temperature',
#  'temperature',
#  'strength',
#  'high',
#  'granite',
#  'temperature',
#  'volumetric',
#  'pore',
#  'modulus',
#  'temperature',
#  'temperature',
#  'density',
#  'thermal',
#  'granite',
#  'mpa',
#  'mpa',
#  'mpa',
#  'mpa',
#  'stress',
#  'temperature',
#  'pressure',
#  'mpa',
#  'mpa',
#  'mpa',
#  'gpa',
#  'modulus',
#  'pressure',
#  'temperature',
#  'stress',
#  'pressure',
#  'temperature',
#  'mpa',
#  'friction',
#  'temperature',
#  'friction',
#  'friction',
#  'cohesion',
#  'temperature',
#  'temperature',
#  'cohesion',
#  'temperature',
#  'grain',
#  'modulus',
#  'stress',
#  'grain',
#  'mineral',
#  'granite',
#  'temperature',
#  'thermal',
#  'stress',
#  'modulus',
#  'thermal',
#  'coefficient',
#  'temperature',
#  'mineral',
#  'stress',
#  'pressure',
#  'temperature',
#  'thermal',
#  'temperature',
#  'lead',
#  'grain',
#  'cohesion',
#  'temperature',
#  'grain',
#  'lead',
#  'high',
#  'friction',
#  'temperature',
#  'friction',
#  'temperature',
#  'granite',
#  'friction',
#  'grain',
#  'grain',
#  'grain',
#  'grain',
#  'grain',
#  'temperature',
#  'friction',
#  'temperature',
#  'temperature',
#  'grain',
#  'temperature',
#  'granite',
#  'stress',
#  'temperature',
#  'temperature',
#  'temperature',
#  'shear',
#  'shear',
#  'granite',
#  'cohesion',
#  'friction',
#  'stress',
#  'mpa',
#  'temperature',
#  'temperature',
#  'shear',
#  'strength',
#  'stress',
#  'stress',
#  'cohesion',
#  'friction',
#  'cohesion',
#  'mpa',
#  'temperature',
#  'temperature',
#  'temperature',
#  'cohesion',
#  'mpa',
#  'mpa',
#  'granite',
#  'cohesion',
#  'temperature',
#  'mineral',
#  'temperature',
#  'stress',
#  'pressure',
#  'temperature',
#  'friction',
#  'temperature',
#  'mineral',
#  'mineral',
#  'cohesion',
#  'temperature',
#  'friction',
#  'temperature',
#  'shear',
#  'temperature',
#  'temperature',
#  'friction',
#  'cohesion',
#  'mpa',
#  'mpa',
#  'temperature',
#  'sandstone',
#  'westerly',
#  'cohesion',
#  'friction',
#  'temperature',
#  'temperature',
#  'cohesion',
#  'friction',
#  'temperature',
#  'temperature',
#  'granite',
#  'shear',
#  'strength',
#  'temperature',
#  'temperature',
#  'shear',
#  'temperature',
#  'temperature',
#  'shear',
#  'strength',
#  'thermal',
#  'temperature',
#  'strength',
#  'mineral',
#  'stress',
#  'temperature',
#  'pressure',
#  'granite',
#  'stress',
#  'strain',
#  'stress',
#  'formation',
#  'stress',
#  'strain',
#  'strain',
#  'stress',
#  'shear',
#  'temperature',
#  'pressure',
#  'shear',
#  'grain',
#  'grain',
#  'pore',
#  'grain',
#  'grain',
#  'lead',
#  'stress',
#  'density',
#  'stress',
#  'stress',
#  'strain',
#  'shear',
#  'lead',
#  'granite',
#  'stress',
#  'pressure',
#  'temperature',
#  'stress',
#  'strain',
#  'stress',
#  'shear',
#  'stress',
#  'grain',
#  'grain',
#  'grain',
#  'grain',
#  'cohesion',
#  'high',
#  'granite',
#  'grain',
#  'high',
#  'grain',
#  'grain',
#  'grain',
#  'ratio',
#  'temperature',
#  'pressure',
#  'stress',
#  'ratio',
#  'confining',
#  'pressure',
#  'temperature',
#  'granite',
#  'granite',
#  'stress',
#  'stress',
#  'stress',
#  'stress',
#  'stress',
#  'stress',
#  'stress',
#  'stress',
#  'stress',
#  'stress',
#  'stress',
#  'stress',
#  'confining',
#  'pressure',
#  'high',
#  'stress',
#  'pressure',
#  'thermal',
#  'temperature',
#  'confining',
#  'stress',
#  'pressure',
#  'pressure',
#  'pressure',
#  'pressure',
#  'pressure',
#  'stress',
#  'high',
#  'high',
#  'temperature',
#  'temperature',
#  'stress',
#  'temperature',
#  'mpa',
#  'stress',
#  'ratio',
#  'temperature',
#  'temperature',
#  'temperature',
#  'temperature',
#  'temperature',
#  'mpa',
#  'stress',
#  'ratio',
#  'temperature',
#  'temperature',
#  'pressure',
#  'temperature',
#  'strength',
#  'stress',
#  'temperature',
#  'grain',
#  'grain',
#  'stress',
#  'ratio',
#  'high',
#  'temperature',
#  'granite',
#  'granite',
#  'temperature',
#  'heat',
#  'granite',
#  'temperature',
#  'strength',
#  'high',
#  'granite',
#  'mineral',
#  'grain',
#  'mineral',
#  'grain',
#  'mineral',
#  'high',
#  'high',
#  'mineral',
#  'granite',
#  'quartz',
#  'plagioclase',
#  'temperature',
#  'grain',
#  'grain',
#  'granite',
#  'fault',
#  'grain',
#  'grain',
#  'temperature',
#  'granite',
#  'high',
#  'stress',
#  'temperature',
#  'pressure',
#  'mpa',
#  'stress',
#  'mpa',
#  'mpa',
#  'mpa',
#  'mpa',
#  'stress',
#  'ratio',
#  'confining',
#  'pressure',
#  'temperature',
#  'granite',
#  'grain',
#  'quartz',
#  'feldspar',
#  'mineral',
#  'quartz',
#  'feldspar',
#  'grain',
#  'grain',
#  'grain',
#  'pore',
#  'grain',
#  'grain',
#  'quartz',
#  'feldspar',
#  'grain',
#  'heat',
#  'heat',
#  'grain',
#  'granite',
#  'grain',
#  'temperature',
#  'grain',
#  'feldspar',
#  'quartz',
#  'mineral',
#  'crystal',
#  'crystal',
#  'temperature',
#  'granite',
#  'high',
#  'feldspar',
#  'biotite',
#  'grain',
#  'granite',
#  'grain',
#  'temperature',
#  'high',
#  'composition',
#  'granite',
#  'igneous',
#  'stress',
#  'grain',
#  'grain',
#  'fault',
#  'feldspar',
#  'biotite',
#  'crystal',
#  'crystal',
#  'crystal',
#  'quartz',
#  'temperature',
#  'temperature',
#  'modulus',
#  'thermal conductivity',
#  'temperature',
#  'strength',
#  'strength',
#  'temperature',
#  'granite',
#  'granite',
#  'heat',
#  'temperature',
#  'thermal',
#  'heat',
#  'temperature',
#  'strength',
#  'thermal',
#  'granite',
#  'westerly',
#  'thermal',
#  'temperature',
#  'granite',
#  'granite',
#  'strength',
#  'temperature',
#  'granite',
#  'high',
#  'grain',
#  'temperature',
#  'composition',
#  'grain',
#  'granite',
#  'heat',
#  'granite',
#  'strength',
#  'confining',
#  'pressure',
#  'temperature',
#  'granite',
#  'depth',
#  'temperature',
#  'depth',
#  'temperature',
#  'granite',
#  'depth',
#  'shear',
#  'depth',
#  'strain',
#  'granite',
#  'stress',
#  'pressure',
#  'granite',
#  'strength',
#  'depth',
#  'granite',
#  'temperature',
#  'strength',
#  'temperature',
#  'thermal',
#  'temperature',
#  'thermal',
#  'granite',
#  'granite',
#  'temperature',
#  'grain',
#  'granite',
#  'granite',
#  'quartz',
#  'feldspar',
#  'grain',
#  'quartz',
#  'feldspar',
#  'mineral',
#  'temperature',
#  'stress',
#  'temperature',
#  'temperature',
#  'temperature',
#  'high',
#  'finally',
#  'pressure',
#  'temperature',
#  'australia',
#  'saudi arabia']

# %%
ready_ner['entity']
# Out:
# ['methods',
#  'petrography',
#  'countries',
#  'geolocation',
#  'states',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'geolocation',
#  'states',
#  'states',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'geolocation',
#  'geolocation',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'geolocation',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'geolocation',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'geolocation',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'geolocation',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'geolocation',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'geolocation',
#  'methods',
#  'methods',
#  'countries',
#  'countries']
