# %%
from pybtex.database.input import bibtex
import bibtexparser
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
with open("References_P3.bib",encoding='utf-8') as bibtex_file:
    bib_database = bibtexparser.load(bibtex_file)
# Out:
# Entry type other not standard. Not considered.

# %%
catalog_publisher = []
list_publisher = []
list_doi = []
list_title = []
none = 0
for i in bib_database.entries:
    try:
        list_publisher.append(i['publisher'])
        if i['publisher'] not in catalog_publisher:
            catalog_publisher.append(i['publisher'])
        else:
            pass
    except:
        none +=1
        
for i in bib_database.entries:
    try:
        list_title.append(i['title'])
        list_doi.append(i['doi'])
    except:
        pass

# %%
list_publisher
# Out:
# ['Springer Nature',
#  'Elsevier {BV}',
#  'American Association of Petroleum Geologists',
#  'Elsevier {BV}',
#  'Elsevier {BV}',
#  'Balkema Rotterdam',
#  'Elsevier',
#  'University of Chicago Press',
#  'Elsevier {BV}',
#  'American Geophysical Union ({AGU})',
#  'Oxford University Press ({OUP})',
#  'American Geophysical Union',
#  'American Geophysical Union ({AGU})',
#  'Canadian Science Publishing',
#  'Elsevier {BV}',
#  'Elsevier {BV}',
#  'Blackwell Science',
#  'Springer Nature',
#  'American Journal of Science ({AJS})',
#  'Geological Society of America',
#  'Wiley',
#  'Elsevier {BV}',
#  'Springer Nature',
#  'American Journal of Science ({AJS})',
#  'Society of Exploration Geophysicists',
#  'American Geophysical Union ({AGU})',
#  'The Royal Society',
#  'Springer Berlin Heidelberg',
#  'Elsevier {BV}',
#  'The University of Chicago Press',
#  'Elsevier {BV}',
#  'Springer Nature',
#  'Elsevier {BV}',
#  'Elsevier {BV}',
#  'University of Chicago Press',
#  'Elsevier {BV}',
#  'Elsevier {BV}',
#  'Geological Society of America',
#  'Oxford University Press ({OUP})',
#  'American Geophysical Union ({AGU})',
#  'Elsevier {BV}',
#  'Elsevier {BV}',
#  'Oxford University Press ({OUP})',
#  'Canadian Science Publishing',
#  'American Geophysical Union ({AGU})',
#  'Geological Society of America',
#  'Oxford University Press ({OUP})',
#  'AUSTRALIAN GOVERNMENT PUBLISHING SERVICE',
#  'Mineralogical Society',
#  'Oxford University Press ({OUP})',
#  'Springer Nature',
#  'Elsevier {BV}',
#  '{IOP} Publishing',
#  'Elsevier {BV}',
#  'Elsevier {BV}',
#  'Oxford University Press ({OUP})',
#  'Elsevier-Pergamon',
#  'Geological Society of America',
#  'Copernicus {GmbH}',
#  'American Geophysical Union ({AGU})',
#  'Canadian Science Publishing',
#  'Springer Nature',
#  'Canadian Science Publishing',
#  'CRC Press',
#  'Oxford University Press ({OUP})',
#  'Elsevier {BV}',
#  'Elsevier {BV}',
#  'American Geophysical Union ({AGU})',
#  'Elsevier {BV}',
#  'Elsevier {BV}',
#  'Geological Society of America',
#  'Lule{\\aa} tekniska universitet,',
#  'New York: American Society of Heating, Refrigerating and Air-Conditioning Engineers, c1968-',
#  'Landesamt für Geologie, Rohstoffe und Bergbau',
#  'Elsevier {BV}',
#  'Springer Berlin Heidelberg',
#  'American Geophysical Union ({AGU})',
#  'Springer Nature',
#  'American Geophysical Union ({AGU})',
#  'Springer Nature',
#  'Technische Informationsbibliothek u. Universitätsbibliothek',
#  'Elsevier {BV}',
#  'Elsevier {BV}',
#  'Elsevier {BV}',
#  'Elsevier {BV}',
#  'Elsevier',
#  'Elsevier {BV}',
#  'American Geophysical Union ({AGU})',
#  'Elsevier {BV}',
#  'Copernicus {GmbH}',
#  'Elsevier {BV}',
#  'Springer Nature',
#  'Oxford University Press ({OUP})',
#  'Geological Society of America',
#  'American Geophysical Union ({AGU})',
#  'Elsevier {BV}',
#  'Elsevier {BV}',
#  'Elsevier {BV}',
#  'Society of Exploration Geophysicists',
#  'American Geophysical Union ({AGU})',
#  'Elsevier {BV}',
#  'Oxford University Press ({OUP})',
#  'Elsevier {BV}',
#  'Society of Exploration Geophysicists',
#  'Canadian Science Publishing',
#  "Schweizerbart'sche Verlagsbuchhandlung",
#  'Oxford University Press ({OUP})',
#  'Elsevier {BV}',
#  'Springer Nature',
#  'Springer Nature',
#  'Elsevier {BV}',
#  'Elsevier {BV}',
#  'Elsevier {BV}',
#  'Springer Nature',
#  'Elsevier {BV}',
#  'Geological Society of America',
#  'American Geophysical Union ({AGU})',
#  'American Geophysical Union ({AGU})',
#  'Elsevier {BV}',
#  'Elsevier {BV}',
#  'Gebrüder Borntraeger',
#  'Elsevier {BV}',
#  'Elsevier {BV}',
#  'Geological Society of America',
#  'Geological Society of America',
#  'American Association of Petroleum Geologists',
#  'Elsevier',
#  'Elsevier {BV}',
#  'Springer Nature',
#  'Elsevier {BV}',
#  'Mineralogical Society of America',
#  'Elsevier',
#  'American Geophysical Union ({AGU})',
#  'Elsevier',
#  'Springer Nature',
#  'American Geophysical Union',
#  'Wiley',
#  'Oxford University Press ({OUP})',
#  'Copernicus {GmbH}',
#  'Elsevier {BV}',
#  'Elsevier {BV}',
#  'Elsevier {BV}',
#  'Elsevier {BV}',
#  'Elsevier {BV}',
#  'Elsevier {BV}',
#  'American Geophysical Union ({AGU})',
#  'Oxford University Press ({OUP})',
#  'Elsevier {BV}',
#  'American Geophysical Union',
#  'American Geophysical Union ({AGU})',
#  'Elsevier {BV}',
#  'Springer Nature',
#  'Elsevier {BV}',
#  'American Association of Petroleum Geologists',
#  'Geological Society of America',
#  'Elsevier {BV}',
#  'Elsevier {BV}',
#  'Elsevier {BV}',
#  'Oxford University Press ({OUP})',
#  'American Geophysical Union ({AGU})',
#  'Springer {US}',
#  'Oxford University Press ({OUP})',
#  'Elsevier {BV}',
#  'McGraw-Hill',
#  'Oxford University Press ({OUP})',
#  'Oxford University Press ({OUP})',
#  'Elsevier {BV}',
#  'American Geophysical Union ({AGU})',
#  'American Geophysical Union ({AGU})',
#  'Sektion Geowissenschaften, Bergakademie',
#  'Springer Nature',
#  'Nauka Press, Moscow',
#  'Elsevier {BV}',
#  'American Geophysical Union',
#  'Springer Nature',
#  'Elsevier {BV}',
#  'American Geophysical Union ({AGU})',
#  'Elsevier {BV}',
#  'Elsevier {BV}',
#  'Elsevier {BV}',
#  'Elsevier {BV}',
#  'Elsevier {BV}',
#  'Elsevier {BV}',
#  'Elsevier {BV}',
#  'Elsevier {BV}',
#  'Copernicus {GmbH}',
#  'Elsevier {BV}',
#  'Oxford University Press ({OUP})',
#  'American Geophysical Union ({AGU})',
#  'Elsevier Amsterdam',
#  'American Geophysical Union ({AGU})',
#  'Elsevier {BV}',
#  'Gordon and Breach',
#  'Elsevier {BV}',
#  'Schlussbericht',
#  'Izd. Nauka',
#  'Wiley',
#  'American Geophysical Union ({AGU})',
#  'American Geophysical Union ({AGU})',
#  'Elsevier {BV}',
#  'Schweizerische Geophysikalische Kommission',
#  'F. Enke',
#  'Pergamon Pr',
#  'Elsevier {BV}',
#  'Springer Nature',
#  'Elsevier {BV}',
#  'Springer Nature',
#  'American Geophysical Union ({AGU})',
#  'Elsevier {BV}',
#  'Springer Nature',
#  'Springer Nature',
#  'Geological Society of London',
#  'Birkh�user Basel',
#  'American Geophysical Union ({AGU})',
#  'Elsevier {BV}',
#  'Elsevier {BV}',
#  'Elsevier {BV}',
#  'Oxford University Press ({OUP})',
#  'Oxford University Press ({OUP})',
#  'Technische Universität Berlin',
#  'Elsevier {BV}',
#  'Oxford University Press ({OUP})',
#  'Elsevier {BV}',
#  'Springer Nature',
#  'American Geophysical Union ({AGU})',
#  'Elsevier {BV}',
#  'American Geophysical Union',
#  'Geothermal Resources Council',
#  'Elsevier {BV}',
#  'Geological Society of London',
#  'Elsevier {BV}',
#  'Oxford University Press ({OUP})',
#  'Springer-Verlag Berlin Heidelberg',
#  'Elsevier {BV}',
#  'Gebrüder Bornträger']

# %%
catalog_publisher
# Out:
# ['Springer Nature',
#  'Elsevier {BV}',
#  'American Association of Petroleum Geologists',
#  'Balkema Rotterdam',
#  'Elsevier',
#  'University of Chicago Press',
#  'American Geophysical Union ({AGU})',
#  'Oxford University Press ({OUP})',
#  'American Geophysical Union',
#  'Canadian Science Publishing',
#  'Blackwell Science',
#  'American Journal of Science ({AJS})',
#  'Geological Society of America',
#  'Wiley',
#  'Society of Exploration Geophysicists',
#  'The Royal Society',
#  'Springer Berlin Heidelberg',
#  'The University of Chicago Press',
#  'AUSTRALIAN GOVERNMENT PUBLISHING SERVICE',
#  'Mineralogical Society',
#  '{IOP} Publishing',
#  'Elsevier-Pergamon',
#  'Copernicus {GmbH}',
#  'CRC Press',
#  'Lule{\\aa} tekniska universitet,',
#  'New York: American Society of Heating, Refrigerating and Air-Conditioning Engineers, c1968-',
#  'Landesamt für Geologie, Rohstoffe und Bergbau',
#  'Technische Informationsbibliothek u. Universitätsbibliothek',
#  "Schweizerbart'sche Verlagsbuchhandlung",
#  'Gebrüder Borntraeger',
#  'Mineralogical Society of America',
#  'Springer {US}',
#  'McGraw-Hill',
#  'Sektion Geowissenschaften, Bergakademie',
#  'Nauka Press, Moscow',
#  'Elsevier Amsterdam',
#  'Gordon and Breach',
#  'Schlussbericht',
#  'Izd. Nauka',
#  'Schweizerische Geophysikalische Kommission',
#  'F. Enke',
#  'Pergamon Pr',
#  'Geological Society of London',
#  'Birkh�user Basel',
#  'Technische Universität Berlin',
#  'Geothermal Resources Council',
#  'Springer-Verlag Berlin Heidelberg',
#  'Gebrüder Bornträger']

# %%
dict_publisher = {}
for i in catalog_publisher:
    dict_publisher[i] = list_publisher.count(i)

# %%
dict_publisher
# Out:
# {'Springer Nature': 22,
#  'Elsevier {BV}': 86,
#  'American Association of Petroleum Geologists': 3,
#  'Balkema Rotterdam': 1,
#  'Elsevier': 5,
#  'University of Chicago Press': 2,
#  'American Geophysical Union ({AGU})': 28,
#  'Oxford University Press ({OUP})': 21,
#  'American Geophysical Union': 5,
#  'Canadian Science Publishing': 5,
#  'Blackwell Science': 1,
#  'American Journal of Science ({AJS})': 2,
#  'Geological Society of America': 10,
#  'Wiley': 3,
#  'Society of Exploration Geophysicists': 3,
#  'The Royal Society': 1,
#  'Springer Berlin Heidelberg': 2,
#  'The University of Chicago Press': 1,
#  'AUSTRALIAN GOVERNMENT PUBLISHING SERVICE': 1,
#  'Mineralogical Society': 1,
#  '{IOP} Publishing': 1,
#  'Elsevier-Pergamon': 1,
#  'Copernicus {GmbH}': 4,
#  'CRC Press': 1,
#  'Lule{\\aa} tekniska universitet,': 1,
#  'New York: American Society of Heating, Refrigerating and Air-Conditioning Engineers, c1968-': 1,
#  'Landesamt für Geologie, Rohstoffe und Bergbau': 1,
#  'Technische Informationsbibliothek u. Universitätsbibliothek': 1,
#  "Schweizerbart'sche Verlagsbuchhandlung": 1,
#  'Gebrüder Borntraeger': 1,
#  'Mineralogical Society of America': 1,
#  'Springer {US}': 1,
#  'McGraw-Hill': 1,
#  'Sektion Geowissenschaften, Bergakademie': 1,
#  'Nauka Press, Moscow': 1,
#  'Elsevier Amsterdam': 1,
#  'Gordon and Breach': 1,
#  'Schlussbericht': 1,
#  'Izd. Nauka': 1,
#  'Schweizerische Geophysikalische Kommission': 1,
#  'F. Enke': 1,
#  'Pergamon Pr': 1,
#  'Geological Society of London': 2,
#  'Birkh�user Basel': 1,
#  'Technische Universität Berlin': 1,
#  'Geothermal Resources Council': 1,
#  'Springer-Verlag Berlin Heidelberg': 1,
#  'Gebrüder Bornträger': 1}

# %%
len(list_title)
# Out:
# 355

# %%
list_title
# Out:
# ['Fault controlled geochemical properties in {Lahendong} geothermal reservoir {Indonesia}',
#  'Deformation modes in an {Icelandic} basalt: From brittle failure to localized deformation bands',
#  'Permeability prediction in chalks',
#  'High-potassium, calc-alkaline I-type plutonism in the {European Variscides}: northern {Vosges (France)} and northern {Schwarzwald (Germany)}',
#  '{Aufschlussanalogstudie zur geothermischen Reservoircharakterisierung des Permokarbons im nördlichen Oberrheingraben}',
#  'Heat production in an {Archean} crustal profile and implications for heat flow and mobilization of heat-producing elements',
#  'Principles of Nuclear Geology',
#  'Padioactive Elemental Distribution in the Granjlite Terrains and Dearwar Schist Belis of Peninsular India',
#  'Contrasting Metamorphic Record of Heat Production Anomalies in the Penokean Orogen of Northern Michigan',
#  'Geochemistry of arc volcanic rocks of the Zagros Crush Zone, Neyriz, Iran',
#  'A summary of the geology and petrology of the Sierra La Primavera, Jalisco, Mexico',
#  'Untersuchung der tiefengeothermischen Potenziale von Hessen',
#  '{3D-Modellierung des tiefengeothermischen Potenzials des nördlichen Oberrheingrabens und Untersuchung der geothermischen Eigenschaften des Rotliegend}',
#  "Petrogenesis of Quaternary Intraplate Volcanism, Sana'a, Yemen: Implications for Plume-Lithosphere Interaction and Polybaric Melt Hybridization",
#  'Integrated Studies of the Elastic Properties of Some Indian Rocks',
#  'Terrestrial heat flow in {Botswana} and {Namibia}',
#  'The Mid-Atlantic Ridge near 45{\\textdegree} N. {XI}. Seismic velocity, density, and layering of the crust',
#  'Geochemistry of Precambrian and Paleozoic siliciclastic rocks from the Iberian Range ({NE} Spain): implications for source-area weathering, sorting, provenance, and tectonic setting.',
#  'Behavior of accessory phases and redistribution of Zr, {REE}, Y, Th, and U during metamorphism and partial melting of metapelites in the lower crust: an example from the Kinzigite Formation of Ivrea-Verbano, {NW} Italy',
#  'Untersuchung der geothermischen Gesteinskennwerte von Kulmgrauwacke (Oberharz) und Tanner Grauwacke (Nordhessen)',
#  'Igneous Petrology',
#  '3D-Laserscanning, DFN-Modellierung und Aufschlussaufnahme im Rotliegend des oestlichen Saar-Nahe-Beckens',
#  'Trace element characteristics of graywackes and tectonic setting discrimination of sedimentary basins',
#  'Vergleich von Eigenschaften petrothermaler Reservoirgesteine des Gonghe- Beckens und Tromm-Granits / Weschnitz-Plutons',
#  'Bestimmung der Temperaturabhaengigkeit der Wärmekapazität und Wärmeleitfähigkeit von Karbonatgesteinen der Schwäbischen und Fränkischen Alb',
#  'The thermal conductivity of rocks and its dependence upon temperature and composition',
#  'Handbook of physical constants',
#  'Geothermal Map of North America: American Association of Petroleum Geologists',
#  'Long-term thermal consequences of the redistribution of heat-producing elements associated with large-scale granitic complexes',
#  'The distribution of radiogenic heat production as a function of depth in the Sierra Nevada Batholith, California',
#  'Zum Stand der Nutzung der oberflächennahen Geothermie in Norddeutschland',
#  'Permeability distribution in the Lahendong geothermal field: A blind fault captured by thermal{\\textendash}hydraulic simulation',
#  'Thermophysical and hydraulic rock properties of greywackes and andesites of the Taupo Volcanic Zone in New Zealand',
#  'The thermal conductivity and compressibility of several rocks under high pressures',
#  'Thermal state in the north Viking Graben (North Sea) determined from oil exploration well data',
#  'Caledonian plutonism in Britain: A summary',
#  'Heat Flow in South Africa',
#  'Andesites of Bagana volcano, Papua New Guinea: chemical stratigraphy, and a reference andesite composition',
#  'Geothermie',
#  'The determination of the acoustic parameters of volcanic rocks from compressional wave velocity measurements',
#  'Contrasting Metamorphic Record of Heat Production Anomalies in the Penokean Orogen of Northern Michigan',
#  'Geochemistry of the Quaternary alkali basalts of Garrotxa ({NE} Volcanic Province, Spain): a case of double enrichment of the mantle lithosphere',
#  '{New Chemical Weathering Indices for Estimating the Mechanical Properties of Rocks: A Case Study from the Kürtün Granodiorite, NE Turkey}',
#  'Influence of weathering on the engineering properties of Harsit granitic rocks (NE Turkey)',
#  'Heat flow and heat production in Zambia: Evidence for lithospheric thinning in central Africa',
#  'Aluminium saturation in I- and S-type granites and the characterization of fractionated haplogranites',
#  'Trace Element and Isotope Characteristics of Cenozoic Basalts around the Tanlu Fault with Implications for the Eastern Plate Boundary between North and South China',
#  'Miocene basalts in northwestern Taiwan: Evidence for {EM}-type mantle sources in the continental lithosphere',
#  'High-Mg potassic rocks from Taiwan: implications for the genesis of orogenic potassic lavas',
#  'Handbook of physical constants',
#  'Heat Flow in the Austrian Alps',
#  'Heat flow at Grass Valley, California',
#  'Strukturelle, Advektive und Paläoklimatische Einflüsse auf den Wärmetransport in der Kristallinen Oberkruste am Beispiel der Kola-Halbinsel',
#  'Interaction manteau-croûte: son rôle dans la genèse d’associations plutoniques calo-alcalines, contraintes géochimiques (éléments en traces et isotopes du strontium et de l’oxygène)',
#  'Crust and mantle contributions to granite genesis - An example from the Variscan batholith of Corsica, France, studied by trace-element and Nd-isotope systematics',
#  'Chemical composition and evolution of the upper continental crust: Contrasting results from surface samples and shales',
#  'The Electrical Conductivity of Rocks at High Temperatures',
#  'Thermal conductivity of base-course materials',
#  'Late Cenozoic volcanism at Twin Peaks, Utah: Geology and petrology',
#  'Bestimmung thermischer Stoffwerte von Salzgesteinen und Nebengesteinen',
#  "Variabilité géochimique des métapélites dans l'auréole métamorphique d'Oulmès (Maroc central)",
#  'Pre-Mesozoic evolution of the central Andes$\\mathsemicolon$ The basement revisited',
#  'Evolution of Mg/Fe Ratios in Late Variscan Plutonic Rocks from the External Crystalline Massifs of the Alps (France, Italy, Switzerland)',
#  'Interpretation of aerial gamma-ray surveys-adding the geochemical factors',
#  'Thermal conductivity of serpentinite from Mayaguez, Puerto Rico,\nand other localities',
#  'Trace element geochemistry of parts of the Closepet granite, Mysore State, India',
#  'Lower Crustal Xenoliths, Chinese Peak Lava Flow, Central Sierra Nevada',
#  'Outcrop Analogue Study of Geothermal Properties of the Southesk-Cairn Carbonate Complex in the Alberta Basin, Canada',
#  'The age and origin of a thick mafic - ultramafic keel from beneath the Sierra Nevada batholith',
#  'Pb isotopes of Gorgona Island (Colombia): isotopic variations correlated with magma type',
#  'Erdwärmesondenfeld Aarau, Heizen und Kühlen eines grossen Bürogebäudes mit teilweise wärmeisolierten Erdwärmesonden.',
#  'Influence of Temporal Variation of Water Saturation on Shallow Geothermal Systems Using Numerical Modeling',
#  'The determination of thermal conductivity and its temperature-variation for medium conductors',
#  'Study cases of thermal conductivity prediction from P-wave velocity and porosity',
#  'An outline of the geology and geochemistry, and the possible petrogenetic evolution of the volcanic rocks of the Tonga-Kerma-New Zealand island arc',
#  'Mineralogy and Geochemistry of the Younger Volcanic Islands of Tonga, S.W. Pacific',
#  'Untersuchung und Bewertung der geothermischen Eigenschaften der Gesteine der Nördlichen Pyllitzone, Vordertaunus',
#  'Continental Basaltic Rocks',
#  'Did lithospheric delamination trigger late Cenozoic potassic volcanism in the southern Sierra Nevada, California?',
#  'Inelastic compaction and permeability evolution in volcanic rock',
#  'Strain-induced permeability increase in volcanic rock',
#  'Heat production and thermal conductivity of rocks from the Pikwitonei{\\textendash}Sachigo continental cross section, central Manitoba: implications for the thermal structure of Archean crust',
#  'Trace element behaviour in granite genesis. The calc-alkaline plutonic association from the Querigut Complex (Pyrenees, {France})',
#  'A database of physical properties of rocks from the Trans-Hudson Orogen, Canada',
#  'Icelandic Hyaloclastite Tuffs - Petrophysical properties, alteration and geochemical mobility',
#  'Porosity, density and chemical composition relationships in altered Icelandic hyaloclastites',
#  'Reservoir Parameters TCP-Project A Thin-section Study of the Öskjuhlid Samples',
#  'Electrical conductivity measurement of granulite under mid- to lower crustal pressure-temperature conditions',
#  'Variations in electrical conductivity of rocks above metamorphic conditions',
#  'Electrical conductivity measurement of gneiss under mid- to lower crustal P{\\textendash}T conditions',
#  'Crustal composition and mantle heat flow: Implications from surface heat flow and radiogenic heat production in the Variscan Erzgebirge (Germany)',
#  'Comparison of geothermal properties of the carbonatic aquifer systems in the Western Canada Sedimentary Basin and the South German Molasse Basin',
#  'Sr-Nd isotopic record of multi-stage interactions between mantle-derived magmas and crustal components in a collision context - The ultramafic-granitoid association from Vivero (Hercynian belt, \\{NW\\} {Spain})',
#  'Trace elements in the kimberlites of Andhra Pradesh, India',
#  'Chemical composition of the continental crust as revealed by studies in East China',
#  'Measurement of Thermal Conductivity and Diffusivity of Drill Core Samples from the Los Humeros Geothermal Field, Mexico, by a Line-Source Technique',
#  'Pathways for degassing during the lava dome eruption of Mount St. Helens 2004{\\textendash}2008',
#  'Thermal response test method development and evaluation',
#  'Comparison of Four Models for Thermal Response Test Evaluation',
#  'Geothermische und gesteinsmechanische Untersuchung an ausgewaehlten Standorten der Fraenkischen Alb',
#  'Geopotenziale des tieferen Untergrundes im Oberrheingraben, Fachlich-Technischer Abschlussbericht des INTERREG-Projekts GeORG, Teil 1',
#  'Geochemistry of subalkaline and alkaline extrusives from the Kermanshah ophiolite, Zagros Suture Zone, Western Iran: implications for Tethyan plate tectonics',
#  'Orogenic Andesites and Plate Tectonics',
#  'Early rifting of an oceanic island arc (Fiji) produced shoshonitic to tholeiitic basalts',
#  'Electrical conductivity of rock samples subjected to high temperatures and pressures',
#  'Beyond {KTB} - electrical conductivity of the deep continental crust',
#  'Electrical conductivity of the continental crust',
#  'Electrical conductivity of carbonbearing granulite at raised temperatures and pressures',
#  'HDR project Soultz - thermophysical study of GPK2 and GPK3 granite samples',
#  'Der Elbsandstein: Vorkommen, Verwendung, Eigenschaften; Elbe Sandstone: deposits, use, properties',
#  'Calculations of the optimized design for an existing multifunctional building with borehole heat exchangers',
#  'For Oafrce Oistu Olar Sofnun syna Afangask Yrsla urn sarnvinnuverk Hitaveitu Reykjavfkur. Hitaveitu Su Ournesja og Orkustofnunar',
#  'Petrographie und Petrophysik des Rotliegend der Forschungsbohrung Messel GA2',
#  'Geochemical constraints on the bimodal origin of High Himalayan leucogranites',
#  'Heat flow variations in the Grenville Province, Canada',
#  'Heat flow and heat generation in the Archaean Dharwar cratons and implications for the Southern Indian Shield geotherm and lithospheric thickness',
#  'On the content and vertical distribution of K, Th and U in the continental crust',
#  'Determining major fluid-flow zones in a geothermal sandstone reservoir from thermal conductivity and temperature logs',
#  'Determination of fluid-flow zones in a geothermal sandstone reservoir using thermal conductivity and temperature logs',
#  'Thermal conductivity from core and well log data',
#  'Age and geochemistry of basaltic complexes in western Costa Rica: Contributions to the geotectonic evolution of Central America',
#  'Brittle creep in basalt and its application to time-dependent volcano deformation',
#  'The permeability and elastic moduli of tuff from Campi Flegrei, Italy: implications for ground deformation modelling',
#  'Timescales for permeability reduction and strength recovery in densifying magma',
#  'Fracture and compaction of andesite in a volcanic edifice',
#  'Elastic moduli evolution and accompanying stress changes with increasing crack damage: implications for stress changes around fault zones and volcanoes during deformation',
#  'How tough is tuff in the event of fire?',
#  "Microstructural controls on the physical and mechanical properties of edifice-forming andesites at Volc{\\'{a}}n de Colima, Mexico",
#  'Mechanical behaviour of dacite from Mount St. Helens ({USA}): A link between porosity and lava dome extrusion mechanism (dome or spine)?',
#  'The evolution of elastic moduli with increasing crack damage during cyclic stressing of a basalt from Mt. Etna volcano',
#  'Mechanical behaviour and failure modes in the Whakaari (White Island volcano) hydrothermal system, New Zealand',
#  'Heat flow in west Texas and eastern New Mexico',
#  'Untersuchung des geothermischen Potenzials der effusiven Vulkanite der permischen Donnersberg-Formation',
#  'Hybrid granodiorites intruding the accretionary prism, Kodiak, Shumagin, and Sanak Islands, southwest Alaska',
#  'Petrophysikalische Eigenschaften der Mitteldeutschen Kristallinschwelle im Bereich des Oberrheingrabens',
#  'Bestimmung von geothermischen Kennwerten an Gesteinen des Kellerwaldes',
#  'Chemical differentiation of the Earth: the relationship between mantle, continental crust, and oceanic crust',
#  'Aufschlussanalogstudie zur Charakterisierung oberjurassischer geothermischer Karbonatreservoire im Molassebecken',
#  'Isotopic and Geochemical Constraints on the Origin and Evolution of the Columbia River Basalt',
#  'Gekoppelte Kälte-und Wärmeerzeugung mit Erdwärmesonden-Handbuch zum Planungsvorgehen',
#  '{Wärmeleitfähigkeitsmessungen} unter einaxialem {Druck}',
#  'Thermal and electrical conductivities of sandstone rocks and ocean sediments',
#  'The Mid-Atlantic Ridge Near 45{\\textdegree} N. {XV}. Thermal Conductivity of Dredge and Drill Core Samples',
#  'Geothermische Untersuchungen im Saarkarbon',
#  'Geochemical Constraints on Leucogranite Magmatism in the Langtang Valley, Nepal Himalaya',
#  'Sr-Nd isotope and trace-element geochemistry of late Variscan volcanism in the Pyrenees: Magmatism in post-orogenic extension?',
#  'Petrophysical evaluation of subsurface reservoir sandstones of Bengal Basin, Bangladesh',
#  'Radioactive element distribution in the Archean granulite terrane of Jequié - Bahia, Brazil',
#  'A detailed study of the distribution of heat flow and radioactivity in New Hampshire (U.S.A.)',
#  'Temperature dependence of seismic properties in geothermal rocks at reservoir conditions',
#  'Geothermische Untersuchung des Hauptrogenstein im südlichen Oberrheingraben',
#  'Influence of surrounding environments and strain rates on the strength of rocks subjected to uniaxial compression',
#  'K, U and Th in mid-ocean ridge basalt glasses and heat production, K/U and K/Rb in the mantle',
#  'Porositäten und Permeabilitäten im Oberrheingraben und Südwestdeutschen Molassebecken',
#  'The link between migmatites and S-type granites in the Turku area, southern Finland',
#  'Chapter 5: Petrology and geochemistry of the metaluminous to peraluminous Chemehuevi Mountains Plutonic Suite, southeastern California',
#  'Heat flow in the Witwatersrand Basin and environs and its significance for the South African Shield Geotherm and lithosphere thickness',
#  'Heat flow and heat production in the Namaqua Mobile Belt, South Africa',
#  'The correlations between the saturated and dry P-wave velocity of rocks',
#  'Geochemistry and petrogenesis of S-type granites in the East Greenland Caledonides',
#  'Geothermics with special reference to application',
#  'Porosity estimation from compressional wave velocity: A study based on Egyptian sandstone formations',
#  'Study on P-wave and S-wave velocity in dry and wet sandstones of Tushka region, Egypt',
#  'Studies of the Thermal State of the Earth. The 17th Paper: Variation of Thermal Conductivity of Rocks. Part 2.',
#  'Studies of the Thermal State of the Earth. The 15th Paper: Variation of Thermal Conductivity of Rocks. Part 1.',
#  'Calc-alkaline plutonism in the intra-oceanic Aleutian arc, Alaska',
#  'Aleutian magmas in space and time',
#  'Measured Radiogenic Heat Production in Sediments from Continental Margin of Eastern North America: Implications for Petroleum Generation: GEOLOGIC NOTE',
#  'Granitic perspectives on the generation and secular evolution of the continental crust. Treatise on Geochemistry',
#  'Tracking the permeable porous network during strain-dependent magmatic flow',
#  'The influence of thermal and cyclic stressing on the strength of rocks from Mount St. Helens, Washington',
#  'Cataclastic production of volcanic ash at Mount Saint Helens',
#  'Origins of Mount St. Helens cataclasites: Experimental insights',
#  'Oceanic Plateaus',
#  'Solubility of water in basaltic and granitic melts',
#  'Tectonic and magmatic development of the Salinian Coast Ridge Belt, California',
#  'Bestimmung des geothermischen Potenzials des Kristallinen Odenwaldes',
#  'Geochemistry of the Igneous Oceanic Crust',
#  'Permeability development in vesiculating magmas: implications for fragmentation',
#  'Petrophysical properties of geothermal reservoir rocks in the Upper Rhine Graben from surface outcrops',
#  'Photogrammetrische und felsmechanische Untersuchungen am Piesberger Karbon-Quarzit',
#  'Geophysical Monograph 12:The Crust and Upper Mantle of the Pacific Area',
#  'Über die thermoelektrischen Effekte (Thermokräfte, Thomsonwärme) und die Wärmeleitung in einigen Elementen und Verbindungen und über die experimentelle Prüfung der Elektronentheorien',
#  'Basement Geochemistry and Geochronology of Central Malaita, Solomon Islands, with Implications for the Origin and Evolution of the Ontong Java Plateau',
#  'Strength and permeability recovery of tuffisite-bearing andesite',
#  'Untersuchung des Einflusses der Wassersättigung auf die thermophysikalischen Eigenschaften von Buntsandstein',
#  'Crustal heat production and style of metamorphism: a comparison between two Archean high grade provinces in the Limpopo Belt, southern Africa',
#  '3D Modellierung des tiefengeothermischen Potentials und der Petrologie des west-lichen Taunus/Rheinisches Schiefergebirge',
#  'Electrical conductivity and P-wave velocity in rock samples from high-temperature Icelandic geothermal fields',
#  'Low geothermal heat flow of the Urals fold belt {\\textemdash} implication of low heat production, fluid circulation or palaeoclimate?',
#  'Radioelements and heat production of an exposed Archaean crustal cross-section, Dharwar craton, south India',
#  'Mechanical behaviour of Australian Strathbogie granite under in-situ stress and temperature conditions: An application to geothermal energy extraction',
#  'Bestimmung der petrophysikalischen und felsmechanischen Kennwerte des Tromm? und Weschnitz-Plutons, Odenwald, Deutschland',
#  'Anisotropy of electrical conductivity of dry and saturated {KTB} samples',
#  'Fracturation et paléocirculations hydrothermales. Application au granite de Soultz-sous-Forêts',
#  'Heat capacities of rocks at high temperatures',
#  'Measurement of heat capacities of quartz, kyanite and granite at high temperatures',
#  'Premières détermination du flux de chaleur et de la production de chaleur en Corse',
#  'Geothermische Eigenschaften Schweizer Molassebecken (Tiefenbereich 0-500m)',
#  'Lithofaziesanalyse der Forschungsbohrung Messel GA 1',
#  'Mechanical behavior and localized failure modes in a porous basalt from the Azores',
#  'The Generation of Continental Crust: An Integrated Study of Crust-Forming Processes in the Archaean of Zimbabwe',
#  'Heat flow, heat production and fission track data from the Hercynian basement around the Proven{\\c{c}}al Basin (Western Mediterranean)',
#  'Geothermische Untersuchungen in Calw',
#  'Investigation of thermo-physical and mechanical parameters of crystalline geothermal reservoir rocks of the Upper Rhine Graben (Germany)',
#  'Elastic Wave Velocities in Hawaiian Rocks at Pressures to Ten Kilobars',
#  'Low mantle heat flow at the edge of the North American Continent, Voisey Bay, Labrador',
#  'Looking into a volcanic area: An overview on the 350~m scientific drilling at Colli Albani (Rome, Italy)',
#  'Régimen tér mico en la Península Ibérica. Estructura litosférica a través del Macizo Ibérico y el Margen Surportugués.',
#  'Geochemical constraints on crustal anatexis: a case study from the Pan-African Damara granitoids of Namibia',
#  'Constraints on the composition of the continental lithospheric mantle',
#  'Radiogenic heat production in sedimentary rocks of the Gulf of Mexico Basin, south Texas',
#  'High radiogenic heat{\\textendash}producing granites and metamorphism{\\textemdash}An example from the western Mount Isa inlier, Australia',
#  'Geochemical and Nd-Sr isotopic composition of deep-sea turbidites: Crustal evolution and plate tectonic associations',
#  'Leucosome-forming small-scale geochemical processes in the metapelitic migmatites of the Turku area, Finland',
#  'Properties of the Reservoir Rocks in the Geothermal Field of Wairakai/New Zealand',
#  'Thermo-physical rock properties and the impact of advancing hydrothermal alteration - A case study from the Tauhara geothermal field, New Zealand',
#  'Untersuchung thermophysikalischer Eigenschaften an hessischen Zechstein- und Buntsandsteinproben',
#  'Formation of Diatexite Migmatite and Granite Magma during Anatexis of Semi-pelitic Metasedimentary Rocks: an Example from St. Malo, France',
#  'Terrestrial heat flow in Ontario and Quebec',
#  'Kimberlites, Orangeites, and Related Rocks',
#  'Wärmeleitfähigkeit der Gesteine bei hohen Temperaturen',
#  'Ergebnisse geothermischer Untersuchungen in Sibirien',
#  'Thermal conductivity of some rocks of the East Sayan and Eastern Kazhakstan',
#  'Thermal conductivity of granite at high temperatures',
#  'Heat capacities of eclogite and dolerite at high temperatures',
#  'Gabbro-derived Granulites from the Northern Apennines (Italy): Evidence for Lower-crustal Emplacement of Tholeiitic Liquids in Post-Variscan Times',
#  'The thermal constants of some rocks from the Orange Free State',
#  'New heat flow data from the immediate vicinity of the Kola super-deep borehole: Vertical variation in heat flow confirmed and attributed to advection',
#  'Investigation on the spatial variability of petrophysical parameters of sandstone (Buntsandstein) in the Spessart, Germany',
#  'Synthese géothermique du Fossé rhénan Supérieur,',
#  'Physical properties of rocks and minerals (McGraw-Hill/CINDAS data series on material properties : Group II, Properties of special materials)',
#  'Electric pore fabric of the Nubia sandstones in south Egypt: characterization and modelling',
#  'Petrophysical and magnetic pore network anisotropy of some cretaceous sandstone from Tushka Basin, Egypt',
#  'Uranium and thorium contents of coexisting gneisses, granites and pegmatites',
#  'Geothermische Untersuchungen des Zechsteins im Raum Sontra',
#  'The Vredefort radioelement profile extended to supracrustal strata at Carletonville, with implications for continental heat flow',
#  'Studies on the Electrical Conductivity of a few Samples of Granite and Andesite',
#  'Terrestrial heat flow in east and southern Africa',
#  'Grundlagen der Geothermik',
#  'Geothermisches Potenzial im Erlaubnisfeld Südtaunus',
#  'Auswirkung hydrogeologischer Kenngrößen auf die Kältefahnen von Erdwärmesondenanlagen in Lockersedimenten',
#  'Ausbreitung von Kältefahnen oberflächennaher Erdwärmesonden in Lockergestein, 48 S',
#  'Electrical conductivity of rocks at high pressures and temperatures',
#  'Enrichment of the continental lithosphere by {OIB} melts: Isotopic evidence from the volcanic province of northern Tanzania',
#  "The Paran{\\'{a}}-Etendeka Province",
#  'Geochemistry of eocene calc-alkaline volcanic rocks from the Kastamonu area, Northern Turkey',
#  'Analysis of initiation and propagation of hydraulically induced fracture',
#  'U, Th and K content, heat production and thermal conductivity of S{\\~{a}}o Paulo, Brazil, continental shelf sediments: A reconnaissance work',
#  'Thermobarometric constraints on the depth of exposure and conditions of plutonism and metamorphism at deep levels of the Sierra Nevada Batholith, Tehachapi Mountains, California',
#  'The chemical composition of subducting sediment and its consequences for the crust and mantle',
#  'General characterization of the mechanical behaviour of different volcanic rocks with respect to alteration',
#  'Influence of alteration on physical properties of volcanic rocks',
#  'Characterization of rock thermal conductivity by high-resolution optical scanning',
#  'Thermal Data Collection and Heat Flow Recalculations for ODP Legs 101--180: Hanover, Germany (Inst. Joint Geosci. Res., Inst. Geowiss. Gemeinschaftsauf.[GGA])',
#  'Strontium isotopic and trace element heterogeneity in the plains basalts of the Newer Volcanic Province, Victoria, Australia',
#  'Properties of geothermal reservoir rocks. Comparison between Ohaaki Field (NZ) and Saar-Nahe Basin (Germany).',
#  'Heat flow in Indian Gondwana basins and heat production of their basement rocks',
#  'Radiogeologic studies at NGRI - a review',
#  'Tracking the thermal properties of the lower continental crust: Measured versus calculated thermal conductivity of high-grade metamorphic rocks (Southern Granulite Province, India)',
#  'Emplacement at granulite facies conditions of the Sesia{\\textendash}Lanzo metagabbros: an early record of Permian rifting?',
#  'Empirical relations of rock properties of outcrop and core samples from the Northwest German Basin for geothermal drilling',
#  'Oceanic plateau and island arcs of southwestern Ecuador: their place in the geodynamic evolution of northwestern South America',
#  'Electrical resistivity measurements of andesite and hydrothermal breccia from the Awibengkok geothermal field, Indonesia',
#  'The Generation of Potassic Lavas from the Eastern Virunga Province, Rwanda',
#  'Surface heat flow, crustal temperatures and mantle heat flow in the Proterozoic Trans-Hudson Orogen, Canadian Shield',
#  'Etude pétrophysique et modélisation des effets des transferts thermiques entre roche et fluide dans le contexte géothermique de Soultz-sous-Forêts.',
#  'Nature and composition of the continental crust: A lower crustal perspective',
#  'Thermal structure, thickness and composition of continental lithosphere',
#  'The Validation of the LMC device - Analysis of Icelandic basaltic rocks',
#  'Physical properties of the core K21, borehole GPK1, Soultz-sous-Forêts, depth interval 3522.58-3525.88 m',
#  'Physical properties of the rock in the granitic section of borehole GPK1, Soultz-sous-Forêts',
#  'Physical properties of the rock in the granitic section of borehole GPK1, Soultz-sous-Forêts',
#  'Heat production and heat flow in the mantle lithosphere, Slave craton, Canada',
#  'Projekt Drahtloser Minidatenlogger für Temperaturmessungen in Erdwärmesonden',
#  'Verkhnaya Mantiya',
#  'Trace element and isotopic characteristics of Kerguelen-Heard Plateau basalts',
#  'Untersuchungen zum Verhalten von Erdwärmesonden',
#  'Long-term thermal consequences of the redistribution of heat-producing elements associated with large-scale granitic complexes',
#  'Untersuchung des Einflusses der Wassersättigung auf die thermophysikalischen Eigenschaften von Kernproben der Bohrungen Aura und Rosenthal',
#  'Drilling methods for shallow geothermal installations',
#  'Erfahrungen mit dem thermal response test in Deutschland',
#  'Terrestrial heat flow in east and southern Africa',
#  'Thermal conductivity of rocks from measurements on fragments and its application to heat-flow determinations',
#  'Fractionation of uranium, thorium and rare earth elements in a vertically zoned granodiorite: Implications for heat production distributions in the Sierra Nevada batholith, California, U.S.A.',
#  'Hydrogeologische und geothermische Untersuchungen der Heilquellen und Heilbrunnen Bad Soden-Salmünsters',
#  'Archivierung und Kompilation geothermischer Daten der Schweiz und angrenzender Gebiete',
#  'The Geothermal Potential of Luxembourg',
#  'Handbook of geophysical exploration',
#  'Determination of Rockmechanical Properties of the Palatinate Forest’s Buntsandstein',
#  'Geothermische Untersuchungen des Buntsandsteins des Odenwaldes',
#  'GIS basierte Erdwärmepotenzialkarte Spielberg und Wart',
#  'Bestimmung geothermischer Kennwerte an Cuttings und Auswertung der bohrtechnischen Daten der Tiefbohrung Geretsried',
#  'Thermofazielle und petrophysikalische Untersuchung der Bohrung Solnhofen-Maxberg und weiterer Aufschlussproben der Fränkischen und Schwäbischen Alb',
#  'Petrophysik: Physikalische Eigenschaften von Gesteinen und Mineralen',
#  'Physical properties of rocks: fundamentals and principles of petrophysics',
#  'Surface heat flow and lithospheric thermal structure of the northwestern Arabian Plate',
#  'Electrical conductivity of fluid-bearing quartzite under lower crustal conditions',
#  'Geochemistry and petrology of the jequie granulitic complex (Brazil): an archean basement complex',
#  'Strukturgeologische und geothermische Analogstudie verkarsteter Karbonatgesteine im Bereich der Tunnelbaustelle Widderstall',
#  'Geology, geochemistry, and age of Archean and early Proterozoic rocks in the Marenisco-Watersmeet area, northern Michigan; and Geologic interpretation of gravity data, Marenisco-Watersmeet area, northern Michigan',
#  'Thermal Stimulation of Icelandic High-Temperature Geothermal Systems',
#  'Mechanical behaviour of the Rotokawa Andesites (New Zealand): Insight into permeability evolution and stress-induced behaviour in an actively utilised geothermal reservoir',
#  'Physical property relationships of the Rotokawa Andesite, a significant geothermal reservoir rock in the Taupo Volcanic Zone, New Zealand',
#  "Modification des structures de porosité de grès lors de transformations petrographiques dans la diagenese et l'hydrothermalisme",
#  'Contrasting rhyolite suites in the Late Cenozoic of Papua New Guinea',
#  'Evolution of the mechanics of the 2004{\\textendash}2008 Mt. St. Helens lava dome with time and temperature',
#  'Hydraulic properties of the crystalline basement',
#  'Eigenschaften geothermischer Nutzhorizonte im Baden-Württembergischen und französischen Teil des Oberrheingrabens',
#  'Chemical and isotopic systematics of oceanic basalts: implications for mantle composition and processes',
#  'Thermal properties of soils and rocks',
#  "Détermination de la porosité des zones endommagées autour des failles et rôle de l'état du matériau sur les propriétés d'echange fluides-roches: minéralogie, structures de porosité, caractéristiques mécaniques",
#  'Porosity and Thermal Conductivity of the Soultz-sous-For{\\^{e}}ts Granite',
#  'Vertical distribution of heat generation in the Idaho batholith',
#  'Geochemistry of loess, continental crustal composition and crustal model ages',
#  'Comparative geochemistry of West African kimberlites: Evidence for a micaceous kimberlite endmember of sublithospheric origin',
#  'Neoarch{\\ae}an crustal evolution in the Congo Craton: evidence from K rich granitoids of the Ntem Complex, southern Cameroon',
#  'Age and Geochemistry of Basement and Alkalic Rocks of Malaita and Santa Isabel, Solomon Islands, Southern Margin of Ontong Java Plateau',
#  "Early Cretaceous Basalt and Picrite Dykes of the Southern Etendeka Region, {NW} Namibia: Windows into the Role of the Tristan Mantle Plume in Paran{\\'{a}}{\\textendash}Etendeka Magmatism",
#  'Poroelastische Verformung und petrophysikalische Eigenschaften von Rotliegend Sandsteinen',
#  'Temperature dependence of the electrical resistivity of aqueous salt solutions and solution-saturated porous rocks',
#  'The geothermal potentials of the Middle and Lower Benue Trough, Nigeria',
#  'SMU Geothermal Lab Heat Flow and Western Geothermal Data Bases References',
#  'Radiogenic heat production in the Variscan crust: new determinations and distribution models in Corsica (northwestern Mediterranean)',
#  'Geological and petrophysical parameters of a deep fractured sandstone formation as applied to geothermal exploitation',
#  'Rapport BRGM SGN/IRG ARG 93 T37',
#  'Nature and Composition of the Lower Continental Crust in Central Spain and the Granulite-Granite Linkage: Inferences from Granulitic Xenoliths',
#  'Radiogenic heat production variability of some common lithological groups and its significance to lithospheric thermal modeling',
#  'A New Cell for Electrical Conductivity Measurement on Saturated Samples at Upper Crust Conditions',
#  'An experimental study of the brittle-ductile transition of basalt at oceanic crust pressure and temperature conditions',
#  'Petrophysical properties of the root zone of sheeted dikes in the ocean crust: A case study from Hole {ODP}/{IODP} 1256D, Eastern Equatorial Pacific',
#  'Petrophysikalische und felsmechanische Untersuchung kristalliner Gesteine des Weschnitz-Plutons',
#  'Geophysical Aspects of the Problems of Elastic and Electrical Properties of Rocks at Pressures Up to Tens of Kilobars',
#  'Heat flow in The Geysers-Clear Lake geothermal area of northern California, USA',
#  'Seismic velocities, density, porosity, and permeability measured at a deep hole penetrating the Chelungpu fault in central Taiwan',
#  'Geochemistry of ocean island basalts from the South Atlantic: Ascension, Bouvet, St. Helena, Gough and Tristan da Cunha',
#  'Vorplanung einer geothermischen Nutzung der Tiefbohrung Rotenburg HKZ 1001',
#  'Geothermische Aufschlussanalyse des Steinbruches Mainzer Berg, oestlich von Darmstadt',
#  'Geomechanical Characterization of Volcanic Rocks of the Taupo and Coromandel Volcanic Zone, New Zealand',
#  'Forschungsbohrung Heubach: Untersuchungen zu den geothermischen Reservoireigenschaften des Odenwald Kristallins',
#  'Geothermische Untersuchungen an ausgewaehlten Standorten der Schwaebischen Alb',
#  'Simulation und Evaluierung von Kopplungs- und Speicherkonzepten regenerativer Energieformen zur Heizwärmeversorgung',
#  'Physical constants of Alpine rocks (density, porosity, specific heat, thermal diffusivity and conductivity)',
#  'Analogue Study of Geothermal Properties of the Rimbey-Meadowbrook Reef Trend in the Alberta Basin, Canada',
#  'Strontium isotopic studies of the volcanic rocks of the Saunda arc, Indonesia, and their petrogenetic implications',
#  'Faziesabhaengigkeit geothermischer Kennwerte am Beispiel des Oberen Muschelkalk (Crailsheim, Baden-Wuerttemberg)',
#  'Crustal Anatexis and Granite Petrogenesis During Low-pressure Regional Metamorphism: The Trois Seigneurs Massif, Pyrenees, France',
#  'Modellierung einer mitteltiefen Erdwaermesonde zur Heiz-Grundlastabkung des Taunusgymnasiums Koenigstein',
#  'Landolt-Börnstein, Zahlenwerte und Funktionen Bd. III Astronomie und Geophysik',
#  'Charakterisierung der Aquifereigenschaften von Dolomiten der Wustkogel-Formation im Raum Tux, Tirol',
#  'Experimental investigations on the thermal conductivity characteristics of Beishan granitic rocks for China{\\textquotesingle}s {HLW} disposal',
#  'Micromechanics of brittle faulting and cataclastic flow in Mount Etna basalt',
#  'Micromechanics of brittle faulting and cataclastic flow in Alban Hills tuff',
#  'Geothermische Gesteinskennwerte der palaeozoischen Gesteine des Werra-Grauwacken-Aufbruchs',
#  'Nordwestdeutschland im Tertiär']

# %%
len(list_doi)
# Out:
# 213

# %%
list_doi
# Out:
# ['10.1007/s00767-015-0313-9',
#  '10.1016/j.jvolgeores.2013.01.011',
#  '10.1306/03011110172',
#  '10.1016/S0024-4937(99)00052-3',
#  '10.1016/0012-821X(87)90139-7',
#  '10.1016/S0166-2635(08)70099-9',
#  '10.1086/314406',
#  '10.1016/S1367-9120(00)00012-2',
#  '10.1029/JB086iB11p10137',
#  '10.1093/petroj/38.10.1359',
#  '10.1029/GM012p0489',
#  '10.1029/JB092iB07p06291',
#  '10.1139/e70-105',
#  '10.1016/S0009-2541(00)00192-3',
#  '10.1016/S0016-7037(98)00292-0',
#  '10.1017/S0016756802216507',
#  '10.1007/BF00375292',
#  '10.2475/ajs.238.8.529',
#  '10.1130/SPE36',
#  '10.1046/j.0263-4929.2001.00359.x',
#  '10.1016/j.lithos.2005.06.003',
#  '10.1007/s12665-016-5878-9',
#  '10.2475/ajs.s5-7.38.81',
#  '10.1190/1.1443190',
#  '10.1029/JB086iB11p10502',
#  '10.1098/rspa.1939.0159',
#  '10.1007/978-3-662-00910-9',
#  '10.1016/0148-9062(69)90022-9',
#  '10.1086/314406',
#  '10.1016/S0377-0273(00)00189-X',
#  '10.1007/s10064-007-0115-0',
#  '10.1016/0040-1951(77)90181-0',
#  '10.1016/S0024-4937(98)00086-3',
#  '10.1086/314348',
#  '10.1016/0016-7037(94)00360-X',
#  '10.1016/S0024-4937(01)00067-6',
#  '10.1130/MEM97',
#  '10.1111/j.1365-246X.1961.tb02961.x',
#  '10.1029/tr038i002p00239',
#  '10.1016/0009-2541(94)90186-4',
#  '10.1016/0009-2541(93)90140-E',
#  '10.1111/j.1365-246X.1948.tb02935.x',
#  '10.1139/t04-081',
#  '10.1029/JB086iB11p10303',
#  '10.1130/SPE241-p101',
#  '10.1093/petroj/40.7.1151',
#  '10.1180/minmag.1972.038.298.04',
#  '10.1093/petrology/27.6.1277',
#  '10.1007/s004100050445',
#  '10.1016/0012-821X(84)90113-4',
#  '10.1088/0959-5309/43/5/314',
#  '10.1016/j.geothermics.2014.06.003',
#  '10.1016/0377-0273(77)90001-4',
#  '10.1093/petrology/14.3.429',
#  '10.1016/B0-08-043751-6/03019-x',
#  '10.1130/0016-7606(2002)114<0754:DLDTLC>2.0.CO;2',
#  '10.5194/se-2016-166',
#  '10.1002/2016GL071540',
#  '10.1139/e87-154',
#  '10.1007/BF00371958',
#  '10.1139/e05-006',
#  '10.1111/j.1365-246X.2004.02165.x',
#  '10.1016/j.tecto.2011.03.008',
#  '10.1016/j.tecto.2007.02.004',
#  '10.1029/2000JB900279',
#  '10.1016/0009-2541(96)00027-7',
#  '10.1016/S0016-7037(98)00121-5',
#  '10.1130/G35940.1',
#  '10.1016/S0743-9547(98)00070-1',
#  '10.1007/978-3-642-68012-0',
#  '10.1029/JB094iB04p04561',
#  '10.1007/BF00682710',
#  '10.1029/94GL01015',
#  '10.1038/360723a0',
#  '10.1016/0024-4937(94)00052-4',
#  '10.1016/0012-821X(95)00187-H',
#  '10.1016/0040-1951(91)90275-W',
#  '10.1016/0012-821X(83)90006-7',
#  '10.1016/j.geothermics.2012.11.001',
#  '10.1016/j.ijrmms.2005.05.015',
#  '10.1029/1999GC000020',
#  '10.1016/j.epsl.2011.04.035',
#  '10.5194/se-5-25-2014',
#  '10.1016/j.epsl.2015.07.053',
#  '10.1007/s00445-015-0938-7',
#  '10.1111/j.1365-246X.2010.04726.x',
#  '10.1130/G32940.1',
#  '10.1002/2013JB010521',
#  '10.1016/j.jvolgeores.2016.10.015',
#  '10.1016/j.tecto.2008.10.004',
#  '10.1016/j.jvolgeores.2015.02.012',
#  '10.1190/1.1438306',
#  '10.1029/JB086iB11p10569',
#  '10.1016/0012-821X(88)90132-X',
#  '10.1093/petrology/34.6.1203',
#  '10.1016/0040-1951(70)90098-3',
#  '10.1190/1.1439946',
#  '10.1139/e71-040',
#  '10.1093/petrology/34.2.345',
#  '10.1016/0040-1951(94)90054-X',
#  '10.1007/s12594-010-0122-9',
#  '10.1007/BF00380226',
#  '10.1016/0012-821X(82)90131-5',
#  '10.1016/j.geothermics.2009.12.002',
#  '10.1016/j.ijrmms.2006.07.009',
#  '10.1038/306431a0',
#  '10.1016/S0024-4937(03)00032-X',
#  '10.1130/MEM174-p71',
#  '10.1029/JB093iB04p03243',
#  '10.1029/JB092iB07p06273',
#  '10.1016/j.ultras.2007.05.003',
#  '10.1016/S0024-4937(01)00038-X',
#  '10.1016/j.petrol.2011.06.011',
#  '10.1016/j.ejpe.2015.02.001',
#  '10.1130/SPE241-p233',
#  '10.1130/dnag-gna-g1.687',
#  '10.1016/B0-08-043751-6/03027-9',
#  '10.1016/j.jvolgeores.2013.05.012',
#  '10.1007/s00445-013-0728-z',
#  '10.1016/j.pce.2011.07.052',
#  '10.2138/am.2009.3129',
#  '10.1016/B0-08-043751-6/03033-4',
#  '10.1029/2002TC001409',
#  '10.1016/B0-08-043751-6/03030-9',
#  '10.1007/s004450050128',
#  '10.1029/gm012',
#  '10.1002/andp.19113400602',
#  '10.1093/petrology/43.3.449',
#  '10.5194/se-3-191-2012',
#  '10.1016/S0301-9268(01)00173-5',
#  '10.1016/j.geothermics.2009.12.001',
#  '10.1016/S0040-1951(97)00048-6',
#  '10.1016/j.epsl.2004.05.032',
#  '10.1016/j.geothermics.2016.07.002',
#  '10.1016/0031-9201(93)90138-Y',
#  '10.1029/2012GL053218',
#  '10.1093/petrology/35.1.43',
#  '10.1016/0040-1951(86)90300-8',
#  '10.1029/GM012p0501',
#  '10.1029/1999GL011069',
#  '10.1016/j.jvolgeores.2008.04.007',
#  '10.1007/s004100050165',
#  '10.1016/0012-821X(90)90119-I',
#  '10.1130/0091-7613(1999)027<0679:hrhpga>2.3.co;2',
#  '10.1016/0016-7037(90)90269-Q',
#  '10.1016/S0024-4937(00)00059-1',
#  '10.1016/j.jvolgeores.2015.04.007',
#  '10.1093/petrology/42.3.487',
#  '10.1029/tr032i005p00729',
#  '10.1007/978-1-4615-1993-5',
#  '10.1093/petrology/42.12.2259',
#  '10.1016/j.tecto.2005.03.005',
#  '10.1111/j.1365-246X.2010.04789.x',
#  '10.1111/j.1365-246X.2008.04061.x',
#  '10.1016/0016-7037(69)90111-2',
#  '10.1029/JB086iB11p10653',
#  '10.1029/JB095iB11p17371',
#  '10.1007/s00767-006-0114-2',
#  '10.1016/0012-821X(95)00002-T',
#  '10.1029/gm100p0217',
#  '10.1007/BF00384745',
#  '10.1016/0168-9622(86)90011-4',
#  '10.1029/92JB01889',
#  '10.1016/S0009-2541(97)00150-2',
#  '10.1016/j.enggeo.2013.11.011',
#  '10.1016/j.tecto.2012.07.017',
#  '10.1016/S0375-6505(99)00007-3',
#  '10.1016/s0016-7037(96)00318-3',
#  '10.1016/0040-1951(83)90060-4',
#  '10.1016/j.geothermics.2015.01.007',
#  '10.1016/s0024-4937(01)00046-9',
#  '10.5194/gtes-2-21-2014',
#  '10.1016/s0040-1951(99)00099-2',
#  '10.1093/petroj/39.6.1223',
#  '10.1029/2001jb000698',
#  '10.1029/95rg01302',
#  '10.1016/s0009-2541(97)00151-4',
#  '10.1016/S0031-9201(00)00201-6',
#  '10.1046/j.0263-4929.2001.00359.x',
#  '10.1029/JB095iB11p17371',
#  '10.1029/jb076i014p03391',
#  '10.1016/0016-7037(88)90267-0',
#  '10.1016/j.pepi.2012.03.007',
#  '10.1007/bf00398921',
#  '10.1016/j.geothermics.2016.05.005',
#  '10.1186/s40517-014-0010-4',
#  '10.1029/JB086iB11p10257',
#  '10.1016/j.epsl.2011.04.044',
#  '10.1007/s10040-006-0094-4',
#  '10.1007/s00767-009-0103-3',
#  '10.1144/GSL.SP.1989.042.01.19',
#  '10.1007/978-3-0348-8083-1_20',
#  '10.1029/JB077i014p02508',
#  '10.1016/0016-7037(83)90206-5',
#  '10.1016/0016-7037(94)90264-X',
#  '10.1016/S0899-5362(00)00012-9',
#  '10.1093/petrology/37.2.361',
#  '10.1093/petrology/42.11.2049',
#  '10.14279/depositonce-1240',
#  '10.1016/s0040-1951(98)00031-6',
#  '10.1093/petroj/40.10.1465',
#  '10.1016/j.tecto.2010.05.003',
#  '10.1007/s11242-011-9846-2',
#  '10.1029/2011jb008884',
#  '10.1016/j.tecto.2010.07.013',
#  '10.1029/gm012p0517',
#  '10.1016/j.jseaes.2009.01.010',
#  '10.1144/GSL.SP.1987.030.01.11',
#  '10.1016/0016-7037(75)90136-2',
#  '10.1093/petrology/28.1.127',
#  '10.1016/j.tecto.2016.06.021',
#  '10.1002/2016JB012826',
#  '10.1029/2010JB008046']

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
cloud = WordCloud()
cloud.generate_from_frequencies(dict_publisher)
plt.figure(figsize=(10,10))
plt.imshow(cloud)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)
