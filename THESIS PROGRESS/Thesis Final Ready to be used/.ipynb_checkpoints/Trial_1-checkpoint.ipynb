# %%
#PDF Miner (PDF Scraping)
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.layout import LAParams
from pdfminer.converter import HTMLConverter, TextConverter, XMLConverter
from io import StringIO
from pdfminer.pdfpage import PDFPage

#NLP Preprocessing
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer


#NLP Processing TensorFLow
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

#NLP Processing Spacy
import spacy
spc = spacy.load("en_core_web_lg")
spc.add_pipe('sentencizer')

#Model Training and Evaluation
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

#Basic
import numpy as np
import pandas as pd

# %% [markdown]
# ## P3 Data (Stratigraphy)

# %%
df = pd.read_excel('C:/Users/Ryan Bobby A/Documents/RWTH AACHEN/KULIAH/THESIS_BISMILLAH/Thesis Progress/Target Data/Stratigraphy_P3.xlsx')

# %%
df.head()
# Out:
#    Stratigraphic ID  Stratigraphic parent ID  Eonothem / Eon ID  \
# 0               1.0                      NaN                1.0
# 1               2.0                      1.0                1.0
# 2               3.0                      1.0                1.0
# 3               4.0                      3.0                1.0
# 4               5.0                      3.0                1.0
#
#    Erathem / Era ID  Period ID  System ID  Series / Epoch ID  Stage / Age ID  \
# 0               NaN        NaN        NaN                NaN             NaN
# 1               2.0        NaN        NaN                NaN             NaN
# 2               3.0        NaN        NaN                NaN             NaN
# 3               3.0        4.0        NaN                NaN             NaN
# 4               3.0        5.0        NaN                NaN             NaN
#
#   Eonothem / Eon Erathem / Era  ... Series / Epoch Stage / Age  \
# 0    Precambrium           NaN  ...            NaN         NaN
# 1    Precambrium        Hadean  ...            NaN         NaN
# 2    Precambrium       Archean  ...            NaN         NaN
# 3    Precambrium       Archean  ...            NaN         NaN
# 4    Precambrium       Archean  ...            NaN         NaN
#
#   Numerical_Age Lower Boundary [Ma] Num_Age Plus_Minus [Ma]  \
# 0                            4600.0                     NaN
# 1                            4600.0                     NaN
# 2                            4000.0                     NaN
# 3                            4000.0                     NaN
# 4                            3600.0                     NaN
#
#    Chronostratigraphical Unit  Stratigraphic ID.1 Rank      R      G      B
# 0                 Precambrium                 1.0  1.0  239.0  103.0  130.0
# 1                      Hadean                 2.0  2.0  178.0   20.0  141.0
# 2                     Archean                 3.0  2.0  234.0    1.0  140.0
# 3                   Eoarchean                 4.0  3.0  224.0   58.0  149.0
# 4                Paleoarchean                 5.0  3.0  240.0  132.0  182.0
#
# [5 rows x 22 columns]

# %%
df_chrono = df[['Eonothem / Eon', 'Erathem / Era','Chronostratigraphical Unit']]
df_chrono.head()
# Out:
#   Eonothem / Eon Erathem / Era Chronostratigraphical Unit
# 0    Precambrium           NaN                Precambrium
# 1    Precambrium        Hadean                     Hadean
# 2    Precambrium       Archean                    Archean
# 3    Precambrium       Archean                  Eoarchean
# 4    Precambrium       Archean               Paleoarchean

# %%
list_chrono = df['Chronostratigraphical Unit'].values.tolist()
temp_eon = df['Eonothem / Eon'].values.tolist()
temp_era = df['Erathem / Era'].values.tolist()

# %%
list_chrono
# Out:
# ['Precambrium',
#  'Hadean',
#  'Archean',
#  'Eoarchean',
#  'Paleoarchean',
#  'Mesoarchean',
#  'Neoarchean',
#  'Proterozoic',
#  'Paleoproterozoic',
#  'Siderian',
#  'Rhyacian',
#  'Orosirian',
#  'Satherian',
#  'Mesoproterozoic',
#  'Calymmian',
#  'Ectasian',
#  'Stenian',
#  'Neoproterozoic',
#  'Tonian',
#  'Cryogenian',
#  'Ediacaran',
#  'Phanerozoic',
#  'Paleozoic',
#  'Cambrian',
#  'Terreneuvian',
#  'Fortunian',
#  'Cambrian Stage 2',
#  'Cambrian Series 2',
#  'Cambrian Stage 3',
#  'Cambrian Stage 4',
#  'Cambrian Series 3',
#  'Cambrian Stage 5',
#  'Drumian',
#  'Guzhangian',
#  'Furongian',
#  'Paibian',
#  'Jingshanian',
#  'Stage 10',
#  'Ordovician',
#  'Lower Ordovician',
#  'Tremadocian',
#  'Floian',
#  'Middle Ordovician',
#  'Dapingian',
#  'Darriwilian',
#  'Upper Ordovician',
#  'Sandbian',
#  'Katian',
#  'Hirnantian',
#  'Silurian',
#  'Llandovery',
#  'Rhuddanian',
#  'Aeronian',
#  'Telychian',
#  'Wenlock',
#  'Sheinwoodian',
#  'Homerian',
#  'Ludlow',
#  'Gorstian',
#  'Ludfordian',
#  'Pridoli',
#  'Devonian',
#  'Lower Devonian',
#  'Lochkovian',
#  'Pragian',
#  'Emsian',
#  'Middle Devonian',
#  'Eifelian',
#  'Givetian',
#  'Upper Devonian',
#  'Frasnian',
#  'Famennian',
#  'Carboniferous',
#  'Mississippian',
#  'Lower Mississippian',
#  'Tournaisian',
#  'Middle Mississippian',
#  'Visean',
#  'Upper Mississippian',
#  'Serpukhovian',
#  'Pennsylvanian',
#  'Lower Pennsylvanian',
#  'Bashkirian',
#  'Middle Pennsylvanian',
#  'Moscovian',
#  'Upper Pennsylvanian',
#  'Kasimovian',
#  'Gzhelian',
#  'Permian',
#  'Cisuralian',
#  'Asselian',
#  'Sakmarian',
#  'Artinskian',
#  'Kungurian',
#  'Guadalupian',
#  'Roadian',
#  'Wordian',
#  'Capitanian',
#  'Lopingian',
#  'Wuchiapingian',
#  'Changhsingian',
#  'Mesozoic',
#  'Triassic',
#  'Lower Triassic',
#  'Induan',
#  'Olenekian',
#  'Middle Triassic',
#  'Anisian',
#  'Ladinian',
#  'Upper Triassic',
#  'Carnian',
#  'Norian',
#  'Rhaetian',
#  'Jurassic',
#  'Lower Jurassic',
#  'Hettangian',
#  'Sinemurian',
#  'Pliensbachian',
#  'Toarcian',
#  'Middle Jurassic',
#  'Alenian',
#  'Bajocian',
#  'Bathonian',
#  'Callovian',
#  'Upper Jurassic',
#  'Oxfordian',
#  'Kimmeridgian',
#  'Tithonian',
#  'Cretaceous',
#  'Lower Cretaceous',
#  'Berriasian',
#  'Valanginian',
#  'Hauterivian',
#  'Barremian',
#  'Aptian',
#  'Albian',
#  'Upper Cretaceous',
#  'Cenomanian',
#  'Turonian',
#  'Coniacian',
#  'Santonian',
#  'Campanian',
#  'Maastrichtian',
#  'Cenozoic',
#  'Paleogene',
#  'Paleocene',
#  'Danian',
#  'Selandian',
#  'Thanetian',
#  'Eocene',
#  'Ypresian',
#  'Lutetian',
#  'Bartonian',
#  'Priabonian',
#  'Oligocene',
#  'Rupelian',
#  'Chattian',
#  'Neogene',
#  'Miocene',
#  'Aquitanian',
#  'Burdigalian',
#  'Langhian',
#  'Serravallian',
#  'Tortonian',
#  'Messinian',
#  'Pliocene',
#  'Zanclean',
#  'Piacenzian',
#  'Quaternary',
#  'Pleistocene',
#  'Gelasian ',
#  'Calabrian ',
#  'Middle Pleistocene',
#  'Upper Pleistocene',
#  'Holocene',
#  nan]

# %%
with open ('list_chrono.txt', 'w') as f:
    for item in list_chrono:
        f.write(str(item) + '\n')

# %%
list_eon = []
for i in temp_eon:
    if i in list_eon:
        pass
    else:
        list_eon.append(i)
add = ['Archaean','Proterozoic']
for i in add:
    list_eon.append(i)
list_eon.remove(np.nan)
list_eon
# Out:
# ['Precambrium', 'Phanerozoic', 'Archaean', 'Proterozoic']

# %%
with open ('list_eon.txt', 'w') as f:
    for item in list_eon:
        f.write(str(item) + '\n')

# %%
list_era = []
for i in temp_era:
    if i in list_era:
        pass
    else:
        list_era.append(i)
list_era.remove(np.nan)
list_era
# Out:
# ['Hadean', 'Archean', 'Proterozoic', 'Paleozoic', 'Mesozoic', 'Cenozoic']

# %%
with open ('list_era.txt', 'w') as f:
    for item in list_era:
        f.write(str(item) + '\n')

# %% [markdown]
# ## P3 Data (Petrography)

# %%
df = pd.read_excel('C:/Users/Ryan Bobby A/Documents/RWTH AACHEN/KULIAH/THESIS_BISMILLAH/Thesis Progress/Target Data/Petrography_P3.xlsx')

# %%
df.head()
# Out:
#    Petrographic ID  Petrographic parental ID        1        2        3    4  \
# 0              NaN                       NaN      1.0      2.0      3.0  4.0
# 1          10101.0                       NaN  10101.0      NaN      NaN  NaN
# 2          10102.0                       NaN  10102.0      NaN      NaN  NaN
# 3          10104.0                   10102.0  10102.0  10104.0      NaN  NaN
# 4          10105.0                   10104.0  10102.0  10104.0  10105.0  NaN
#
#      5    6    7    8  ...                           Unnamed: 25  Unnamed: 26  \
# 0  5.0  6.0  7.0  8.0  ...                                   NaN          NaN
# 1  NaN  NaN  NaN  NaN  ...                                   NaN          NaN
# 2  NaN  NaN  NaN  NaN  ...                                   NaN          NaN
# 3  NaN  NaN  NaN  NaN  ...  American Geological Institute (1987)          NaN
# 4  NaN  NaN  NaN  NaN  ...                           IUGS (1989)          NaN
#
#    Unnamed: 27 Unnamed: 28 Petrographic term.1 Unnamed: 30 Unnamed: 31  \
# 0          NaN         NaN                 NaN         NaN         NaN
# 1          NaN         NaN                 NaN         NaN         NaN
# 2          NaN         NaN   Consolidated rock         NaN         NaN
# 3          NaN         NaN       Magmatic rock         NaN         NaN
# 4          NaN         NaN       Plutonic rock         NaN         NaN
#
#   Unnamed: 32 Unnamed: 33 Unnamed: 34
# 0         NaN         NaN     m magma
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN
#
# [5 rows x 35 columns]

# %%
list_petro = df['Petrographic term.1'].values.tolist()
list_petro = [i for i in list_petro if type(i) == str ]

# %%
for i,j in enumerate(list_petro):
    if bool(re.search(r' rock',j)) == True:
        list_petro[i] = re.sub(r' rock','',j)
list_petro
# Out:
# ['Consolidated',
#  'Magmatic',
#  'Plutonic',
#  'Plutonic, modal, field description',
#  'Very- Quartz rich plutonic',
#  'Quartz- rich granitic plutonic',
#  'Quartz- rich plutonic',
#  'Granitic plutonic',
#  'Quartz- bearing to Foid- bearing plutonic',
#  'Syenitic plutonic',
#  'Dioritic plutonic',
#  'Gabbrotic plutonic',
#  'Foid- rich plutonic',
#  'Foid- syenitic plutonic',
#  'Foid- dioritic plutonic',
#  'Foid- gabbrodic plutonic',
#  'Very- Foid- rich plutonic/ Foidolite',
#  'Foidolitic plutonic',
#  'Ultra- mafic plutonic (field classification)',
#  'Plutonic, modal (QAPF)',
#  'Quartzolite (QAPF)',
#  'Granite (QAPF)',
#  'Alkali- Feldspar- Granite',
#  'Syenogranite',
#  'Monzogranite',
#  'Granodiorite (QAPF)',
#  'Tonalite (QAPF)',
#  'Quartz-Alkali-Feldspar-Syenite (QAPF)',
#  'Quartz-Syenite (QAPF)',
#  'Quartz-Monzonite (QAPF)',
#  'Quartz-Monzodiorite (QAPF)',
#  'Quartz-Monzogabbro (QAPF)',
#  'Quartz-Diorite (QAPF)',
#  'Quartz-Gabbro (QAPF)',
#  'Quartz-Anorthosite (QAPF)',
#  'Alkali-Feldspar-Syenite (QAPF)',
#  'Syenite (QAPF)',
#  'Monzonite (QAPF)',
#  'Monzodiorite (QAPF)',
#  'Monzogabbro (QAPF)',
#  'Diorite (QAPF)',
#  'Gabbro (QAPF)',
#  'Gabbronorite',
#  'Norite',
#  'Troctolite',
#  'Olivine- Gabbro',
#  'Olivine- Gabbronorite',
#  'Olivine- Norite',
#  'Orthopyroxene- Gabbro',
#  'Clinopyroxene- Norite',
#  'Hornblende- Gabbro',
#  'Pyroxene- Hornblende- Gabbro',
#  'Pyroxene- Hornblende- Gabbronorite',
#  'Pyroxene- Hornblende- Norite',
#  'Anorthosite (QAPF)',
#  'Foid-bearing-Alkali-Feldspar-Syenite (QAPF)',
#  'Foid-bearing Syenite (QAPF)',
#  'Foid-bearing Monzonite (QAPF)',
#  'Foid-bearing Monzodiorite (QAPF)',
#  'Foid-bearing Monzogabbro (QAPF)',
#  'Foid-bearing Diorite (QAPF)',
#  'Foid-bearing Gabbro (QAPF)',
#  'Foid-bearing Anorthosite (QAPF)',
#  'Foid-Syenite (eg. Nepheline-Syenite) (QAPF)',
#  'Malignite',
#  'Shoncinite',
#  'Foid-Monzosyenite (QAPF)',
#  'Foid-Monzodiorite (QAPF)',
#  'Foid-Monzogabbro (QAPF)',
#  'Foid-Diorite (QAPF)',
#  'Foid-Gabbro (QAPF)',
#  'Nephelinolite (QAPF)',
#  'Urtite',
#  'Ijolite',
#  'Melteigite',
#  'Leucitolite (QAPF)',
#  'Italite',
#  'Fergustite',
#  'Missourite',
#  'Ultramafic plutonics',
#  'Peridotite',
#  'Dunite',
#  'Harzburgite',
#  'Lherzolite',
#  'Wehrlite',
#  'Pyroxene-Peridotite',
#  'Pyroxene-Hornblende-Peridotite',
#  'Hornblende-Peridotite',
#  'Pyroxenite',
#  'Orthopyroxenite',
#  'Olivine- Orthopyroxenite',
#  'Websterite',
#  'Olivine- Websterite',
#  'Klinopyroxenite',
#  'Olivine- Klinopyroxenite',
#  'Olivine- Pyroxenite',
#  'Olivine- Hornblende- Pyroxenite',
#  'Plagioclase- bearing Pyroxenite',
#  'Plagioclase- bearing Hornblende- Pyroxenite',
#  'Hornblendite',
#  'Pyroxene- Hornblendite',
#  'Olivine- Hornblendite',
#  'Olivine- Pyroxene- Hornblendite',
#  'Plagioclase- bearing Hornblendite',
#  'Plagioclase- bearing Pyroxene- Hornblendite',
#  'Ultramafic melilitic plutonic',
#  'Melilolite',
#  'Olivine- Melilitolite',
#  'Pyroxene- Melilitolite',
#  'Olivine- Pyroxene- Melilitolite',
#  'Pyroxene- Olivine- Melililolite',
#  'Carbonatite (plutonic)',
#  'Calcite- Carbonatite (plutonic affinity)',
#  'Dolomite- Carbonatite (plutonic affinity)',
#  'Ferro- Carbonatite (plutonic affinity)',
#  'Charnockite (plutonic)',
#  'Volcanic',
#  'Volcanic (modal)',
#  'Quartz- rich volcanic',
#  'Rhyolitic volcanic',
#  'Dacitic volcanic',
#  'Quartz- to Foid- bearing volcanic',
#  'Trachytic volcanic',
#  'Latitic volcanic',
#  'Basaltic volcanic',
#  'Tholeiitic volcanic',
#  'Olivine- basaltic volcanic',
#  'Alkali- basaltic volcanic',
#  'Andesitic volcanic',
#  'Foid- rich volcanic',
#  'Phonolitic volcanic',
#  'Tephritic volcanic',
#  'Basanitic volcanic',
#  'Very- Foid- rich volcanic',
#  'Foiditic volcanic',
#  'Ultramafic volcanic (field classification)',
#  'Volcanic (modal/normativ)',
#  'Alkali-Feldspar-Rhyolite (QAPF)',
#  'Rhyolite (QAPF)',
#  'Rhyodacite (QAPF)',
#  'Dacite (QAPF)',
#  'Obsidian',
#  'Quartz-alkali-Feldspar-Trachyte (QAPF)',
#  'Quartz-Trachyte (QAPF)',
#  'Alkali-Feldspar-Trachyte (QAPF)',
#  'Trachyte (QAPF)',
#  'Foid-bearing-alkali-Feldspar-Trachyte (QAPF)',
#  'Foid-bearing-Trachyte (QAPF)',
#  'Quartz-Latite (QAPF)',
#  'Latite (QAPF)',
#  'Foid-bearing Latite (QAPF)',
#  'Basalt (QAPF)',
#  'Tholeitic basalt',
#  'Olivine- basalt',
#  'Alkali- basalt',
#  'Alkali- basalt, Amphibole- bearing',
#  'Leucobasalt (QAPF)',
#  'Leuco- Alkali- Basalt',
#  'Andesite (QAPF)',
#  'Mela-Andesite (QAPF)',
#  'Phonolite (QAPF)',
#  'Tephritic-Phonolite (QAPF)',
#  'Tephrite (QAPF)',
#  'Phonolitic-Tephrite (QAPF)',
#  'Basanite (QAPF)',
#  'Limburgite',
#  'Basanite, Analcim- rich',
#  'basanite, Amphibole- bearing',
#  'Phonolitic-Basanite (QAPF)',
#  'Phonolitic-Foidite (QAPF)',
#  'Tephritic-Foidite (QAPF)',
#  'Basanitic-Foidite (QAPF)',
#  'Foidite (QAPF)',
#  'Nephelinite (QAPF)',
#  'Melilite-Nephelinite (QAPF)',
#  'Analcimite (QAPF)',
#  'Leucitite (QAPF)',
#  'Ultramafic volcanic ',
#  'Melilithite',
#  'Olivine- Melilithite',
#  'Melilithite- bearing ultramafic',
#  'Carbonatite',
#  'Calcite- Carbonatite',
#  'Dolomite- Carbonatite',
#  'Ferro- Carbonatite',
#  'Natro- Carbonatite',
#  'Volcanic (chemically)',
#  'Acidic volcanic',
#  'Intermediate volcanic',
#  'Basic volcanics',
#  'Ultra- basic',
#  'SiO2-oversaturated volcanic (TAS)',
#  'Rhyolite (TAS)',
#  'Rhyolite (TAS)',
#  'Comenditic Rhyolite/ Comendite',
#  'Pantelleritic Rhyolite/ Pantellerite',
#  'Trachydacite (TAS)',
#  'Dacite (TAS)',
#  'High- K- Dacite (TAS)',
#  'Medium- K- Dacite (TAS)',
#  'Low- K- Dacite (TAS)',
#  'Andesite (TAS)',
#  'High- K- Andesite (TAS)',
#  'Medium- K- Andesite (TAS)',
#  'Low- K- Andesite (TAS)',
#  'Basaltic Andesite (TAS)',
#  'High- K- Basaltic- Andesite (TAS)',
#  'Medium- K- Basaltic- Andesite (TAS)',
#  'Low- K- Basaltic Andesite (TAS)',
#  'SiO2-saturated volcanic (TAS)',
#  'Trachyte (TAS)',
#  'Trachite (TAS)',
#  'Peralkalic Trachyte (TAS)',
#  'Comenditic Trachyte (TAS)',
#  'Pantellitic Trachyte (TAS)',
#  'Trachyandesite (TAS)',
#  'Benmoreite (TAS)',
#  'Latite (TAS)',
#  'Basaltic Trachyandesite (TAS)',
#  'Mugearite (TAS)',
#  'Shoshonite (TAS)',
#  'Trachybasalt (TAS)',
#  'Hawaiite (TAS)',
#  'K- Trachybasalt (TAS)',
#  'SiO2-saturated or slightly undersaturated volcanic (TAS)',
#  'Basalt (TAS)',
#  'Subalkali- Basalt (TAS)',
#  'Tholeitic Basalt (TAS)',
#  'High- Alumina- Basalt (TAS)',
#  'Alkali- Basalt (TAS)',
#  'Alkali- Olivine- Basalt (TAS)',
#  'SiO2-undersaturated volcanic (TAS)',
#  'Phonolite (TAS)',
#  'Tephri-Phonolite (TAS)',
#  'Phono-Tephrite (TAS)',
#  'Tephrite (TAS)',
#  'Basanite (TAS)',
#  'Picrobasalt (TAS)',
#  'Foidite (TAS)',
#  'Nephelinite (TAS)',
#  'High-Mg-volcanics (TAS)',
#  'Boninite (TAS)',
#  'Picritic volcanic (TAS)',
#  'Picrite (TAS)',
#  'Comatiite (TAS)',
#  'Meimechite (TAS)',
#  'Volcaniclastic',
#  'Volcaniclastics (field classification)',
#  'Rhyolitic volcaniclast',
#  'Dacitic volcaniclast',
#  'Trachytic volcaniclast',
#  'Andesitic volcaniclast',
#  'Basaltic volcaniclast',
#  'Alkali- Basaltic volcaniclast',
#  'Tholeitic volcaniclast',
#  'Phonolitic volcaniclast',
#  'Tephritic volcaniclast',
#  'Basanitic volcaniclast',
#  'Foiditic volcaniclast',
#  'Pyroclastics',
#  'Pyroclastic, undefined',
#  '(Ash-) Tuff ',
#  'Fine- grained ash- tuff',
#  'Coarse- grained ash- tuff',
#  'Crystal ash- tuff',
#  'Lapilli ash- tuff',
#  'Bomb ash- tuff',
#  'Block ash- tuff',
#  'Lapillistone',
#  'Ash- Lapillistone',
#  'Bomb- Lapillistone',
#  'Block- Lapillistone',
#  'Agglomerate',
#  'Bomb- Tuff',
#  'Lapilli- Bomb- Tuff',
#  'Ash- Bomb- Tuff',
#  'Agglutinate',
#  'Pyroclastic Breccia',
#  'Block- tuff',
#  'Lapilli- block- tuff',
#  'Ash- block- tuff',
#  'Tuff-Breccia',
#  'Lapilli- tuff- breccia',
#  'Ash- tuff- breccia',
#  'Air-fall deposit, consolidated',
#  'Ash-flow deposit, consolidated',
#  'Ignimbrite, consolidated',
#  'Ignimbrite, welded',
#  'Ignimbrite, unwelded, consolidated',
#  'Surge- deposit, consolidated',
#  'Peperite',
#  'Pyroclastic, rhyolitic',
#  'Rhyolitic ash- tuff',
#  'Fine- grained ash- tuff, rhyolitic',
#  'Coarse- grained ash- tuff, rhyolitic',
#  'Rhyolitic crystal- ash- tuff',
#  'Rhyolitic lapilli- ash- tuff',
#  'Rhyolitic bomb- ash- tuff',
#  'Rhyolitic block- ash- tuff',
#  'Rhyolitic Lapilli- tuff',
#  'Rhyolitic ash- lapilli- tuff',
#  'Rhyolitic bomb- lapilli- tuff',
#  'Rhyolitic block- lapilli- tuff',
#  'Rhyolitic agglomerate',
#  'Rhyolitic bomb- tuff',
#  'Rhyolitic lapilli- bomb- tuff',
#  'Rhyolitic ash- bomb- tuff',
#  'Rhyolitic agglutinate',
#  'Pyroclastoc Breccia, rhyolitic',
#  'Rhyolitic block- tuff',
#  'Rhyolitic lapilli- block- tuff',
#  'Rhyolitic ash- block- tuff',
#  'Rhyolitic tuff- breccia',
#  'Rhyolitic lapilli- tuff- breccia',
#  'Rhyolitic ash- tuff- breccia',
#  'Rhyolitic air- fall- deposit, consolidated',
#  'Rhyolitic ash- flow- deposit, consolidated',
#  'Rhyolitic Ignimbrite, consolidated',
#  'Rhyolitic Ignimbrite, welded',
#  'Rhyolitic Ignimbrite, unwelded, consolidated',
#  'Rhyolitic surge- deposit',
#  'Rhyolitic Peperite',
#  'Pyroclastic, dacitic',
#  'Dacitic ash- tuff',
#  'Fine grained ash- tuff, dacitic',
#  'Coarse grained ash- tuff, dacitic',
#  'Dacitic crystal- ash- tuff',
#  'Dacitic lapilli- ash- tuff',
#  'Dacitic bomb- ash- tuff',
#  'Dacitic block- ash- tuff',
#  'Dacitic lapilli- tuff',
#  'Dacitic ash- lapilli- tuff',
#  'Dacitic bomb- lapilli- tuff',
#  'Dacitic block- lapilli- tuff',
#  'Dacitic Agglomerate',
#  'Dacitic bomb- tuff',
#  'Dacitic lapilli- bomb- tuff',
#  'Dacitic ash- bomb- tuff',
#  'Dacitic Agglutinate',
#  'Pyroclastic Breccia, dacitic',
#  'Dacitic block- tuff',
#  'Dacitic lapilli- block- tuff',
#  'Dacitic ash- block- tuff',
#  'Dacitic tuff- breccia',
#  'Dacitic lapilli- tuff- breccia',
#  'Dacitic ash- tuff- breccia',
#  'Dacitic air- fall- deposit, consolidated',
#  'Dacitic ash- flow- deposit, consolidated',
#  'Dacitic Ignimbrite, consolidated',
#  'Dacitic Ignimbrite, welded',
#  'Dacitic Ignimbrite, unwelded, consolidated',
#  'Dacitic surge- deposit, consolidated',
#  'Dacitic Peperite',
#  'Pyroclastic, trachytic',
#  'Trachytic ash- tuff',
#  'Fine- grained trachytic ash- tuff',
#  'Coarse- grained trachytic ash- tuff',
#  'Trachytic crystal- ash- tuff',
#  'Trachytic lapilli- ash- tuff',
#  'Trachytic bomb- ash- tuff',
#  'Trachytic block- ash- tuff',
#  'Trachytic lapilli- tuff',
#  'Trachytic ash- lapilli- tuff',
#  'Trachytic bomb- lapilli- tuff',
#  'Trachytic block- lapilli- tuff',
#  'Trachytic agglomerate',
#  'Trachytic bomb- tuff',
#  'Trachytic lapilli- bomb- tuff',
#  'Trachytic ash- bomb- tuff',
#  'Trachytic agglutinate',
#  'Pyroclastic breccia, trachytic',
#  'Trachytic block- tuff',
#  'Trachytic lapilli- block- tuff',
#  'Trachytic ash- block- tuff',
#  'Trachytic tuff- breccia',
#  'Trachytic lapilli- tuff- breccia',
#  'Trachytic ash- tuff- breccia',
#  'Trachytic air- fall- deposit, consolidated',
#  'Trachytic ash- flow- deposit, consolidated',
#  'Trachytic Ignimbrite, consolidated',
#  'Trachytic Ignimbrite, welded',
#  'Trachytic Ignimbrite, unwelded, consolidated',
#  'Trachytic surge- deposit, consolidated',
#  'Trachytic Peperite',
#  'Pyroclastic, latitic ',
#  'Latitic ash- tuff',
#  'Fine- grained latitic ash- tuff',
#  'Coarse - grained latitic ash- tuff',
#  'Latitic crystal- ash- tuff',
#  'Latitic lapilli- ash- tuff',
#  'Latitic bomb- ash- tuff',
#  'Latitic block- ash- tuff',
#  'Latitic lapilli- tuff',
#  'Latitic ash- lapilli- tuff',
#  'Latitic bomb- lapilli- tuff',
#  'Latitic block- lapilli- tuff',
#  'Latitic agglomerate',
#  'Latitic bomb- tuff',
#  'Latitic lapilli- bomb- tuff',
#  'Latitic ash- bomb- tuff',
#  'Latitic aggglutinate',
#  'Pyroclastic breccia, latitic',
#  'Latitic block- tuff',
#  'Latitic lapilli- block- tuff',
#  'Latitic ash- block- tuff',
#  'Latitic tuff- breccia',
#  'Latitic lapilli- tuff- breccia',
#  'Latitic ash- tuff- breccia',
#  'Latitic air- flow- deposit, consolidated',
#  'Latitic ash- flow- deposit, consolidated',
#  'Latitic Ignimbrite, consolidated',
#  'Latitic Ignimbrite, welded',
#  'Latitic Ignimbrite, unwelded, consolidated',
#  'Latitic surge- deposit, consolidated',
#  'Latitic Peperite',
#  'Pyroclastic, andesitic',
#  'Andesitic ash- tuff',
#  'Fine- grained andesitic ash- tuff',
#  'Coarse- grained andesitic ash- tuff',
#  'Andesitic crystal- ash- tuff',
#  'Andesitic lapilli- ash- tuff',
#  'Andesitic bomb- ash- tuff',
#  'Andesitic block- ash- tuff',
#  'Andesitic lapilli- tuff',
#  'Andesitic ash- lapilli- tuff',
#  'Andesitic bomb- lapilli- tuff',
#  'Andesitic block- lapilli- tuff',
#  'Andesitic agglomerate',
#  'Andesitic bomb- tuff',
#  'Andesitic lapilli- bomb- tuff',
#  'Andesitic ash- bomb- tuff',
#  'Andesitic agglutinate',
#  'Pyroclastic breccia, andesitic',
#  'Andesitic block- tuff',
#  'Andesitic lapilli- block- tuff',
#  'Andesitic ash- block- tuff',
#  'Andesitic tuff- breccia',
#  'Andesitic lapilli- tuff- breccia',
#  'Andesitic ash- tuff- breccia',
#  'Andesitic air- flow- deposit, consolidated',
#  'Andesitic ash- flow- deposit, consolidated',
#  'Andesitic Ignimbrite, consolidated',
#  'Andesitic Ignimbrite, welded',
#  'Andesitic Ignimbrite, unwelded, consolidated',
#  'Andesitic surge- deposit, consolidated',
#  'Andesitic Peperite',
#  'Pyroclastic, basaltic',
#  'Basaltic ash- tuff',
#  'Fine- grained ash- tuff, basaltic',
#  'Coarse- grained ah- tuff, basaltic',
#  'Basaltic crystal ash- tuff',
#  'Basaltic lapilli- ash- tuff',
#  'Basaltic bomb- ash- tuff',
#  'Basaltic block- ash- tuff',
#  'Basaltic lapilli- tuff',
#  'Basaltic crystal lapilli- tuff',
#  'Basaltic ash- lapilli tuff',
#  'Basaltic bomb- lapilli- tuff',
#  'Basaltic block- lapilli- tuff',
#  'Basaltic agglomerate',
#  'Basaltic bomb- tuff',
#  'Basaltic lapilli- bomb- tuff',
#  'Basaltic ash- bomb- tuff',
#  'Basaltic agglutinate',
#  'Pyroclastic breccia, consolidated',
#  'Basaltic block- tuff',
#  'Basaltic lapilli- block- tuff',
#  'Basaltic ash- block- tuff',
#  'Basaltic tuff- breccia',
#  'Basaltic lapilli- tuff- breccia',
#  'Basaltic ash- tuff- breccia',
#  'Basaltic air- fall- deposit, consolidated',
#  'Basaltic ash- flow- deposit, consolidated',
#  'Basaltic Ignimbrite, consolidated',
#  'Basaltic surge- deposit, consolidated',
#  'Basaltic Peperite',
#  'Pyroclastic, phonolitic',
#  'Phonolitic ash- tuff',
#  'Fine- grained ash- tuff, phonolitic',
#  'Coarse- grained ash- tuff, phonolitic',
#  'Phonolitic crystal ash- tuff',
#  'Phonolitic lapilli- ash- tuff',
#  'Phonolitic bomb- ash- tuff',
#  'Phonolitic block- ash- tuff',
#  'Phonolitic lapilli- tuff',
#  'Phonlitic ash- lapilli- tuff',
#  'Phonolitic bomb- lapilli- tuff',
#  'Phonolitic block- lapilli- tuff',
#  'Phonolitic agglomerate',
#  'Phonolitic bomb- tuff',
#  'Phonolitic lapilli- block- tuff',
#  'Phonolitic ash- block- tuff',
#  'Phonolitic agglutinate',
#  'Pyroclastic breccia, phonolitic',
#  'Phonolitic block- tuff',
#  'Phonolitic lapilli- block- tuff',
#  'Phonolitic ash- block- tuff',
#  'Phonolitic tuff- breccia',
#  'Phonolitic lapilli- tuff- breccia',
#  'Phonolitic ash- tuff- breccia',
#  'Phonolitic air- fall- deposit, consolidated',
#  'Phonolitic ash- flow- deposit, consolidated',
#  'Phonolitic Ignimbrite, consolidated',
#  'Phonolitic Ignimbrite, welded',
#  'Phonolitic Ignimbrite, unwelded, consolidated',
#  'Phonolitic surge- deposit, consolidated',
#  'Phonolitic Peperite',
#  'Pyroclastic, basanitic',
#  'Basanitic ash- tuff',
#  'Fine - grained ash- tuff, basanitic',
#  'Coarse- grained ash- tuff, basanitic',
#  'Basanitic crystall ash- tuff',
#  'Basanitic lapilli- ash- tuff',
#  'Basanitic bomb- ash- tuff',
#  'Basanitic block- ash tuff',
#  'Basanitic lapilli- tuff',
#  'Basanitic ash- lapilli- tuff',
#  'Basanitic bomb- lapilli- tuff',
#  'Basanitic block- lapilli- tuff',
#  'Basanitic agglomerate',
#  'Basanitic bomb- tuff',
#  'Basanitic lapilli- bomb- tuff',
#  'Basanitic ash- bomb- tuff',
#  'Basanitic agglutinate',
#  'Pyroclastic breccia, basanitic',
#  'Basanitic block- tuff',
#  'Basanitic lapilli- block- tuff',
#  'Basanitic ash- block- tuff',
#  'Basanitic tuff- breccia',
#  'Basanitic lapilli- tuff- breccia',
#  'Basanitic ash- tuff- breccia',
#  'Basanitic air- fall- deposit, consolidated',
#  'Basanitic ash- flow- deposit, consolidated',
#  'Basanitic Ignimbrite, consolidated',
#  'Basanitic Ignimbrite, unwelded, consolidated',
#  'Basanitic surhe- deposit- consolidated',
#  'Basanitic peperite',
#  'Autoclastic Volcaniclast',
#  'Top- breccia',
#  'Bottom- breccia',
#  'Tuffite',
#  'Tuffaceous-claystone',
#  'Tuffaceous-siltstone',
#  'Tuffaceous-sandstone',
#  'Tuffaceous-conglomerate',
#  'Tuffaceous-breccia',
#  'Volcaniclastic sedimentary (epiclastic)',
#  'Volcaniclastic claystone',
#  'Volcaniclastic siltstone',
#  'Volcaniclastic sandstone',
#  'Volcaniclastic conglomerate',
#  'Volcaniclastic breccia',
#  'Lahar, consolidated',
#  'Volcanic and volcaniclastic, structureless',
#  'Dyke ',
#  'Dyke, modal (field classification)',
#  'Quartz-rich dyke',
#  'Quartz-bearing to foid-bearing dyke',
#  'Foid-rich dyke',
#  'Dolerite (field classification)',
#  'Lamprophyr (field classification)',
#  'Dyke, modal ',
#  'Pegmatite, granitoidic composition',
#  'Quartz-rich Aplite',
#  'Granite- Aplite',
#  'Granodiorite- Aplite',
#  'Tonalite- Aplite',
#  'Dykes´ Granite',
#  'Dykes´ Granodiorite',
#  'Dykes´ Tonalite',
#  'Microgranite',
#  'Microgranodiorite',
#  'Microtonalite',
#  'Granophyr',
#  'Porphyritic Granite',
#  'Porphyritic Granodiorite',
#  'Porphyritic Tonalite',
#  'Pegmatite of nephelinitic composition',
#  'Quartz- bearing to Quartz- free Aplite',
#  'Syenite- Aplite',
#  'Monzonite- Aplite',
#  'Monzodiorite- Aplite',
#  'Diorite- Aplite',
#  'Gabbro- Aplite',
#  'Dykes´ Syenite',
#  'Dykes´ Monzonite',
#  'Dykes´ Monzodiorite',
#  'Dykes´ Diorite',
#  'Dykes´ Gabbro',
#  'Microsyenite',
#  'Micromonzonite',
#  'Micromonzodiorite',
#  'Microdiorite',
#  'Microgabbro',
#  'Porphyric Syenite',
#  'Porphyric Monzonite',
#  'Porphyric Monzodiorite',
#  'Porphyric Diorite',
#  'Porphyric Gabbro',
#  'Dolerite (diabase)',
#  'Alkalibasaltic Dolerite',
#  'Leucite- Nepheline- Dolerite',
#  'Theoleitic Dolerite',
#  'Foid-rich dyke',
#  'Fioditic dyke',
#  'Lamprophyre',
#  'Lamprophyre',
#  'Minette',
#  'Kersanite',
#  'Vogesite',
#  'Spessartite',
#  'Alkali- Lamprophyre',
#  'Camptonite',
#  'Sannaite',
#  'Monchiquite',
#  'Fourchite',
#  'Ultrabasic Alkali- Lamprophyr',
#  'Quachitite',
#  'Melilitic Lamprophyr',
#  'Alnoite',
#  'Polzenite',
#  'Lamprophyric- carbonatic dyke',
#  'Kimberlite',
#  'Carbonatic Kimberlite',
#  'Hydrothermal gangue mineralization',
#  'Quartz- rich gangue mineralization',
#  'Milky Quartz mineral aggregate',
#  'Capped Quartz mineral aggregate',
#  'Pseudomorphosic Quartz mineral aggregate',
#  'Carbonate- rich gangue mineralization',
#  'Calcite mineral aggregate',
#  'Feldspar- rich gangue mineralization',
#  'Feldspar mineral aggregate',
#  'Baryte- rich gangue mineralization',
#  'Baryte mineral aggregate',
#  'Sulfide- rich gangue mineralization',
#  'Metamorphic',
#  'Metamorphic (after educt)',
#  'Meta- sedimentary',
#  'Meta- Pelite',
#  'Hornfels',
#  'Buchite',
#  'Silicic',
#  'Silicic schist',
#  'Meta- Psammite',
#  'Meta- Arkose',
#  'Meta- Graywacke',
#  'Meta- Psephite',
#  'Meta- Conglomerate',
#  'Meta- igneous',
#  'Meta- Plutonite',
#  'Meta- Granite',
#  'Meta- Granodiorite',
#  'Meta- Diorite',
#  'Meta- Gabbro',
#  'Metamorphic dyke',
#  'Meta- Aplite',
#  'Garnet- Meta- Aplite',
#  'Garnet- Turmaline- Meta- Aplite',
#  'Meta- Pegmatite',
#  'Meta- Dolerite',
#  'Alkalibasaltic Meta- Dolerite',
#  'Tholeitic Meta- Dolerite',
#  'Meta volcanic',
#  'Meta- Rhyolite',
#  'Peralkaline Meta- Rhyolite',
#  'Meta- Rhyodacite',
#  'Meta- Dacite',
#  'Meta- Trachyte',
#  'Meta- Basalt',
#  'Meta- Basalt sorted',
#  'Meta- Alkali- Basalt',
#  'Tholeitic Meta- Basalt',
#  'Meta- Andesite',
#  'Meta- Phonolite',
#  'Meta- Basanite',
#  'Meta- Pikrite',
#  'Meta volcaniclastic',
#  'Rhyolitic meta volcaniclastic',
#  'Rhyodacitic meta volcaniclastic',
#  'Dacitic meta volcaniclastic',
#  'Trachytic meta volcaniclastic',
#  'Andesitic meta volcaniclastic',
#  'Basaltic meta volcaniclastic',
#  'Alkali- basaltic meta volcaniclastic',
#  'Tholeitic meta volcaniclastic',
#  'Phonolitic meta volcaniclastic',
#  'Basanitic meta volcaniclastic',
#  'Meta pyroclastic',
#  'Rhyolitic meta pyroclastic',
#  'Rhyodacitic meta pyroclastic',
#  'Dacitic meta pyroclastic',
#  'Trachytic meta pyroclastic',
#  'Andesitic meta pyroclastic',
#  'Basaltic meta pyroclastic',
#  'Alkali- basaltic meta pyroclastic',
#  'Basanitic meta pyroclastic',
#  'Meta- Tuffite',
#  'Tuffitic meta- pelite',
#  'Tuffitic meta- psammite',
#  'Tuffitic meta- conglomerate',
#  'Autoclastic meta- volcaniclastic',
#  'Autoclastic/ hydroclastic meta volcaniclastic',
#  'Pillow- breccia',
#  'Pillow- fragment breccia',
#  'Hydroclastic',
#  'Volcaniclastic meta sedimentary (epiclastic)',
#  'Metamorphic (after chemistry, fabric, mineral content)',
#  'Metacarbonate',
#  'Marble',
#  'Marble sorted',
#  'Calcite- Marble',
#  'Dolomite- Marble',
#  'Carbonate- silicate Marble (Silica- Marble)',
#  'Metamorphic Carbonate- silicate',
#  'Carbonate- Phyllite',
#  'Carbonate- silicate (coarse)',
#  'Quartz- rich metamorphic',
#  'Quartzite',
#  'Apatite- Quartzite',
#  'Epidote- Quartzite',
#  'Garnet- Quartzite',
#  'Graphite- Quartzite',
#  'Magnetite- Quartzite',
#  'Muscovite- Quartzite',
#  'Serictite- Quartzite',
#  'Metafelsics',
#  'Phyllite',
#  'Albite- Phyllite',
#  'Chloritoide- Phyllite',
#  'Garnet- Albite- Phyllite',
#  'Garnet- Phyllite',
#  'Quartz- Phyllite',
#  'Sericite- Phyllite',
#  'Mica schist',
#  'Albite- mica schist',
#  'Andalusite- mica schist',
#  'Apatite- mica schist',
#  'Biotite- Plagioclase- mica schist',
#  'Chlorite- mica schist',
#  'Garnet- mica schist',
#  'Graphite- mica schist',
#  'Muscovite- Chlorite- mica schist',
#  'Muscovite- Biotite- mica schist (two- mica schist)',
#  'Sericite- mica schist',
#  'Staurolite- Biotite- Muscovite- mica schist',
#  'Gneiss',
#  'Epidote- Hornblende- Plagioclase- Gneiss',
#  'Albite- Gneiss',
#  'Andalusite- Gneiss',
#  'Biotite- Gneiss',
#  'Biotite- Cordierit- Gneiss',
#  'Biotite- Garnet- Gneiss',
#  'Biotite- Plagioclase- Gneiss',
#  'Biotite- Muscovite- Gneiss',
#  'Biotite- Sillimanite- Gneiss',
#  'Cordierit- Gneiss',
#  'Disthene- Gneiss',
#  'Disthene- Staurolite- Gneiss',
#  'Disthene- Sillimanite- Gneiss',
#  'Mica- Gneiss',
#  'Garnet- Gneiss',
#  'Garnet- Biotite- Gneiss',
#  'Garnet- Cordierit- Sillimanite- Gneiss',
#  'Garnet- Disthene- Gneiss',
#  'Garnet- Disthene- Sillimanite- Gneiss',
#  'Garnet- Disthene- Staurolite- Gneiss',
#  'Garnet- Plagioclase- Gneis',
#  'Graphite- Gneiss',
#  'Hornblende- Biotite- Gneiss',
#  'Muscovite- Gneiss',
#  'Muscovite- Biotite- Gneiss',
#  'Muscovite- Biotite- Garnet- Gneiss',
#  'Muscovite- Garnet- Gneiss',
#  'Pyroxene- Gneiss',
#  'Quartz- Biotite- Plagioclase- Gneiss',
#  'Staurolite- Garnet- Plagioclase- Gneiss',
#  'Metafelsic Granulite',
#  'Granulite',
#  'Granulite- Gneiss',
#  'Charnockite (metamorphic affinity)',
#  'Acidic to intermediate Hornfels',
#  'Andalusite- Hornfels',
#  'Biotite- Hornblende- Plagioclase- Hornfels',
#  'Cordierite- Hornels',
#  'Coround- Hercynite- Hornfels',
#  'Metamafics',
#  'Greenschist',
#  'Actinolite- schist',
#  'Prasinite',
#  'Amphibolite',
#  'Biotite- Amphibolite',
#  'Biotite- Pyroxene- Amphibolite',
#  'Diopside- Amphibolite',
#  'Epidote- Amphibolite',
#  'Garnet- Amphibolite',
#  'Carbonate- Silicate- Amphibolite',
#  'Zoisite- Amphibolite',
#  'Eklogite- Amphibolite',
#  'Metamafic Granulite',
#  'Eclogite',
#  'Metamafic Hornfels',
#  'Meta- Ultramafic',
#  'Chlorite- Actinolite- schist',
#  'Talcum schist',
#  'Serpentinite',
#  'Ultra- mafic Hornfels',
#  'Olivine- Fels',
#  'Tectonite',
#  'Cataclast',
#  'Fault breccia',
#  'Melange',
#  'Schist',
#  'Slate/ slaty metamudstone',
#  'Black shale',
#  'Alum shale',
#  'Ribbon slate',
#  'Silty schist',
#  'Mylonite',
#  'Migmatite',
#  'Anatexite',
#  'Metatexite',
#  'Diatexite',
#  'Syntexite',
#  'Sedimentary',
#  'Siliciclastic sedimentary',
#  'Sandstone- Pelite- Alternation',
#  'Sandstone- dominated Sandstone- Pelite- Alternation',
#  'Pelite- dominated Sandstone- Pelite- Alternation',
#  'Pelite- Gypsum- Alternation',
#  'Pelite dominated Pelite- Gypsum- Alternation',
#  'Gypsum dominated Pelite- Gypsum- Alternation',
#  'Pelite',
#  'Silicate- Claystone',
#  'Silicate- Siltstone',
#  'Sapropelite',
#  'Psammite/Arenite',
#  '(Arenite-) Sandstone',
#  'Fine Sandstone',
#  'Medium Sandstone',
#  'Coarse Sandstone',
#  'Quartz- Arenite',
#  'Fine Quartz- Arenite',
#  'Medium Quartz- Arenite',
#  'Coarse Quartz- Arenite',
#  'Subfeldspatic- Arenite / Feldspatic Sandstone',
#  'Fine Subfeldspatic- Arenite',
#  'Medium Subfeldspatic- Arenite',
#  'Coarse Subfeldspatic- Arenite',
#  'Feldspatic- Arenite',
#  'Fine Feldspatic- Arenite',
#  'Medium Feldspatic- Arenite',
#  'Coarse Feldspatic- Arenite',
#  'Arkose',
#  'Fine Arkose',
#  'Medium Arkose',
#  'Coarse Arkose',
#  'Sublitharenite',
#  'Fine Sublitharenite',
#  'Medium Sublitharenite',
#  'Coarse Sublitharenite',
#  'Litharenite',
#  'Fine Litharenite',
#  'Medium Litharenite',
#  'Coarse Litharenite',
#  'Lithic- Arenite',
#  'Fine Lithic- Arenite',
#  'Medium Lithic- Arenite',
#  'Coarse Lithic- Arenite',
#  'Graywacke/ Wacke',
#  'Fine Graywacke',
#  'Medium Graywacke',
#  'Coarse Graywacke',
#  'Quartz- Wacke',
#  'Fine Quartz- Wacke',
#  'Medium Quartz- Wacke',
#  'Coarse Quartz- Wacke',
#  'Feldspathic- Wacke',
#  'Fine Feldspethic- Wacke',
#  'Medium Feldspethic- Wacke',
#  'Coarse Feldspethic- Wacke',
#  'Lithic Wacke',
#  'Fine Lithic- Wacke',
#  'Medium Lithic- Wacke',
#  'Coarse Lithic- Wacke',
#  'Psephite',
#  'Conglomerate',
#  'Pebbly conglomerate',
#  'Fine Pebble, Granule',
#  'Medium to coarse pebble',
#  'Very Coarse Pebble',
#  'Cobbles',
#  'Boulders',
#  'Breccia',
#  'Grus- Breccia',
#  'Fine Grus- Breccia',
#  'Medium Grus- Breccia',
#  'Coarse Grud- Breccia',
#  'Debris- Breccia',
#  'Block- Debris Breccia',
#  'Carbonatic sedimentary',
#  'Carbonatic siliciclastic sedimentary',
#  'Limestone- Marl- Alteration',
#  'Limestone dominated Limestone- Marl- Alteration',
#  'Marl dominated Limestone- Marl- Alteration',
#  'Pelite- Marl- Alteration',
#  'Pelite dominated Pelite- Marl- Alteration',
#  'Marol dominated Pelite- Marl- Alteration',
#  'Carbonate-bearing siliciclastic',
#  'Carbonate- bearing claystone',
#  'Carbonate- bearing mudstone',
#  'Carbonate- bearing sandstone',
#  'Carbonate- bearing fine sandstone',
#  'Carbonate- bearing medium sandstone',
#  'Carbonate- bearing coarse sandstone',
#  'Carbonate- bearing conglomerate',
#  'Carbonate- bearing breccia',
#  'Dolomite- bearing siliciclastic',
#  'Dolomite- bearing claystone',
#  'Dolomite- bearing mudstone',
#  'Dolomite- bearing sandstone',
#  'Dolomite- bearing fine sandstone',
#  'Dolomite- bearing medium sandstone',
#  'Dolomite- bearing coarse sandstone',
#  'Dolomite- bearing conglomerate',
#  'Dolomite- bearing breccia',
#  'Carbonatic siliciclastic',
#  'Carbonatic claystone',
#  'Carbonatic mudstone',
#  'Carbonatic sandstone',
#  'Carbonatic fine sandstone',
#  'Carbonatic medium sandstone',
#  'Carbonatic coarse sandstone',
#  'Carbonatic conglomerate',
#  'Carbonatic breccia',
#  'Dolomitic siliciclastic',
#  'Dolomitic claystone',
#  'Dolomitic mudstone',
#  'Dolomitic sandstone',
#  'Dolomitic fine sandstone',
#  'Dolomitic medium sandstone',
#  'Dolomitic coarse sandstone',
#  'Dolomitic conglomerate',
#  'Dolomitic breccia',
#  'Siliciclastic limestone',
#  'Clayey limestone',
#  'Muddy limestone',
#  'Sandy limestone',
#  'Fine- sandy limestone',
#  'Medium- sandy limestone',
#  'Coarse- sandy limestone',
#  'Conglomeratic limestone',
#  'Brecciatic limestone',
#  'Siliciclastic dolimite',
#  'Clayey dolomite',
#  'Muddy dolomite',
#  'Sandy dolomite',
#  'Fine- sandy dolomite',
#  'Medium- sandy dolomite',
#  'Coarse- sandy dolomite',
#  'Conglomeratic dolomite',
#  'Brecciatic dolomite',
#  'Clay- lime- composite',
#  'Marly Claystone',
#  'Marl- Claystone',
#  'Clay- Marl',
#  'Marl',
#  'Lime-Marl',
#  'Dolomite- Marl',
#  'Marl- Limestone',
#  'Marl- Dolomite',
#  'Marly Limestone',
#  'Marly Dolomite',
#  'Carbonate',
#  'Clastic sedimentary Carbonate',
#  'Carbonate',
#  'Lutite',
#  'Siltite',
#  'Arenite',
#  'Fine- grained Arenite',
#  'Medium- grained Arenite',
#  'Coarse- grained Arenite',
#  'Ooidlothic',
#  'Oncolithic',
#  'Rudite',
#  'Dolomite',
#  'Dolomitic Lutite',
#  'Dolomitic Siltite',
#  'Dolomitic Arenite',
#  'Fine- grained dolomitic Arenite',
#  'Medium- grained dolomitic Arenite',
#  'Coarse- grained dolomitic Arenite',
#  'Dolomitic Rudite',
#  'Limestone',
#  'Calcitic Lutite',
#  'Calcitic Siltite',
#  'Calcitic Arenite',
#  'Fine- grained calcitic Arenite',
#  'Medium- grained calcitic Arenite',
#  'Coarse- grained calcitic Arenite',
#  ...]

# %%
for i in list_petro:
    print(i)
# Out:
# Consolidated
# Magmatic
# Plutonic
# Plutonic, modal, field description
# Very- Quartz rich plutonic
# Quartz- rich granitic plutonic
# Quartz- rich plutonic
# Granitic plutonic
# Quartz- bearing to Foid- bearing plutonic
# Syenitic plutonic
# Dioritic plutonic
# Gabbrotic plutonic
# Foid- rich plutonic
# Foid- syenitic plutonic
# Foid- dioritic plutonic
# Foid- gabbrodic plutonic
# Very- Foid- rich plutonic/ Foidolite
# Foidolitic plutonic
# Ultra- mafic plutonic (field classification)
# Plutonic, modal (QAPF)
# Quartzolite (QAPF)
# Granite (QAPF)
# Alkali- Feldspar- Granite
# Syenogranite
# Monzogranite
# Granodiorite (QAPF)
# Tonalite (QAPF)
# Quartz-Alkali-Feldspar-Syenite (QAPF)
# Quartz-Syenite (QAPF)
# Quartz-Monzonite (QAPF)
# Quartz-Monzodiorite (QAPF)
# Quartz-Monzogabbro (QAPF)
# Quartz-Diorite (QAPF)
# Quartz-Gabbro (QAPF)
# Quartz-Anorthosite (QAPF)
# Alkali-Feldspar-Syenite (QAPF)
# Syenite (QAPF)
# Monzonite (QAPF)
# Monzodiorite (QAPF)
# Monzogabbro (QAPF)
# Diorite (QAPF)
# Gabbro (QAPF)
# Gabbronorite
# Norite
# Troctolite
# Olivine- Gabbro
# Olivine- Gabbronorite
# Olivine- Norite
# Orthopyroxene- Gabbro
# Clinopyroxene- Norite
# Hornblende- Gabbro
# Pyroxene- Hornblende- Gabbro
# Pyroxene- Hornblende- Gabbronorite
# Pyroxene- Hornblende- Norite
# Anorthosite (QAPF)
# Foid-bearing-Alkali-Feldspar-Syenite (QAPF)
# Foid-bearing Syenite (QAPF)
# Foid-bearing Monzonite (QAPF)
# Foid-bearing Monzodiorite (QAPF)
# Foid-bearing Monzogabbro (QAPF)
# Foid-bearing Diorite (QAPF)
# Foid-bearing Gabbro (QAPF)
# Foid-bearing Anorthosite (QAPF)
# Foid-Syenite (eg. Nepheline-Syenite) (QAPF)
# Malignite
# Shoncinite
# Foid-Monzosyenite (QAPF)
# Foid-Monzodiorite (QAPF)
# Foid-Monzogabbro (QAPF)
# Foid-Diorite (QAPF)
# Foid-Gabbro (QAPF)
# Nephelinolite (QAPF)
# Urtite
# Ijolite
# Melteigite
# Leucitolite (QAPF)
# Italite
# Fergustite
# Missourite
# Ultramafic plutonics
# Peridotite
# Dunite
# Harzburgite
# Lherzolite
# Wehrlite
# Pyroxene-Peridotite
# Pyroxene-Hornblende-Peridotite
# Hornblende-Peridotite
# Pyroxenite
# Orthopyroxenite
# Olivine- Orthopyroxenite
# Websterite
# Olivine- Websterite
# Klinopyroxenite
# Olivine- Klinopyroxenite
# Olivine- Pyroxenite
# Olivine- Hornblende- Pyroxenite
# Plagioclase- bearing Pyroxenite
# Plagioclase- bearing Hornblende- Pyroxenite
# Hornblendite
# Pyroxene- Hornblendite
# Olivine- Hornblendite
# Olivine- Pyroxene- Hornblendite
# Plagioclase- bearing Hornblendite
# Plagioclase- bearing Pyroxene- Hornblendite
# Ultramafic melilitic plutonic
# Melilolite
# Olivine- Melilitolite
# Pyroxene- Melilitolite
# Olivine- Pyroxene- Melilitolite
# Pyroxene- Olivine- Melililolite
# Carbonatite (plutonic)
# Calcite- Carbonatite (plutonic affinity)
# Dolomite- Carbonatite (plutonic affinity)
# Ferro- Carbonatite (plutonic affinity)
# Charnockite (plutonic)
# Volcanic
# Volcanic (modal)
# Quartz- rich volcanic
# Rhyolitic volcanic
# Dacitic volcanic
# Quartz- to Foid- bearing volcanic
# Trachytic volcanic
# Latitic volcanic
# Basaltic volcanic
# Tholeiitic volcanic
# Olivine- basaltic volcanic
# Alkali- basaltic volcanic
# Andesitic volcanic
# Foid- rich volcanic
# Phonolitic volcanic
# Tephritic volcanic
# Basanitic volcanic
# Very- Foid- rich volcanic
# Foiditic volcanic
# Ultramafic volcanic (field classification)
# Volcanic (modal/normativ)
# Alkali-Feldspar-Rhyolite (QAPF)
# Rhyolite (QAPF)
# Rhyodacite (QAPF)
# Dacite (QAPF)
# Obsidian
# Quartz-alkali-Feldspar-Trachyte (QAPF)
# Quartz-Trachyte (QAPF)
# Alkali-Feldspar-Trachyte (QAPF)
# Trachyte (QAPF)
# Foid-bearing-alkali-Feldspar-Trachyte (QAPF)
# Foid-bearing-Trachyte (QAPF)
# Quartz-Latite (QAPF)
# Latite (QAPF)
# Foid-bearing Latite (QAPF)
# Basalt (QAPF)
# Tholeitic basalt
# Olivine- basalt
# Alkali- basalt
# Alkali- basalt, Amphibole- bearing
# Leucobasalt (QAPF)
# Leuco- Alkali- Basalt
# Andesite (QAPF)
# Mela-Andesite (QAPF)
# Phonolite (QAPF)
# Tephritic-Phonolite (QAPF)
# Tephrite (QAPF)
# Phonolitic-Tephrite (QAPF)
# Basanite (QAPF)
# Limburgite
# Basanite, Analcim- rich
# basanite, Amphibole- bearing
# Phonolitic-Basanite (QAPF)
# Phonolitic-Foidite (QAPF)
# Tephritic-Foidite (QAPF)
# Basanitic-Foidite (QAPF)
# Foidite (QAPF)
# Nephelinite (QAPF)
# Melilite-Nephelinite (QAPF)
# Analcimite (QAPF)
# Leucitite (QAPF)
# Ultramafic volcanic
# Melilithite
# Olivine- Melilithite
# Melilithite- bearing ultramafic
# Carbonatite
# Calcite- Carbonatite
# Dolomite- Carbonatite
# Ferro- Carbonatite
# Natro- Carbonatite
# Volcanic (chemically)
# Acidic volcanic
# Intermediate volcanic
# Basic volcanics
# Ultra- basic
# SiO2-oversaturated volcanic (TAS)
# Rhyolite (TAS)
# Rhyolite (TAS)
# Comenditic Rhyolite/ Comendite
# Pantelleritic Rhyolite/ Pantellerite
# Trachydacite (TAS)
# Dacite (TAS)
# High- K- Dacite (TAS)
# Medium- K- Dacite (TAS)
# Low- K- Dacite (TAS)
# Andesite (TAS)
# High- K- Andesite (TAS)
# Medium- K- Andesite (TAS)
# Low- K- Andesite (TAS)
# Basaltic Andesite (TAS)
# High- K- Basaltic- Andesite (TAS)
# Medium- K- Basaltic- Andesite (TAS)
# Low- K- Basaltic Andesite (TAS)
# SiO2-saturated volcanic (TAS)
# Trachyte (TAS)
# Trachite (TAS)
# Peralkalic Trachyte (TAS)
# Comenditic Trachyte (TAS)
# Pantellitic Trachyte (TAS)
# Trachyandesite (TAS)
# Benmoreite (TAS)
# Latite (TAS)
# Basaltic Trachyandesite (TAS)
# Mugearite (TAS)
# Shoshonite (TAS)
# Trachybasalt (TAS)
# Hawaiite (TAS)
# K- Trachybasalt (TAS)
# SiO2-saturated or slightly undersaturated volcanic (TAS)
# Basalt (TAS)
# Subalkali- Basalt (TAS)
# Tholeitic Basalt (TAS)
# High- Alumina- Basalt (TAS)
# Alkali- Basalt (TAS)
# Alkali- Olivine- Basalt (TAS)
# SiO2-undersaturated volcanic (TAS)
# Phonolite (TAS)
# Tephri-Phonolite (TAS)
# Phono-Tephrite (TAS)
# Tephrite (TAS)
# Basanite (TAS)
# Picrobasalt (TAS)
# Foidite (TAS)
# Nephelinite (TAS)
# High-Mg-volcanics (TAS)
# Boninite (TAS)
# Picritic volcanic (TAS)
# Picrite (TAS)
# Comatiite (TAS)
# Meimechite (TAS)
# Volcaniclastic
# Volcaniclastics (field classification)
# Rhyolitic volcaniclast
# Dacitic volcaniclast
# Trachytic volcaniclast
# Andesitic volcaniclast
# Basaltic volcaniclast
# Alkali- Basaltic volcaniclast
# Tholeitic volcaniclast
# Phonolitic volcaniclast
# Tephritic volcaniclast
# Basanitic volcaniclast
# Foiditic volcaniclast
# Pyroclastics
# Pyroclastic, undefined
# (Ash-) Tuff
# Fine- grained ash- tuff
# Coarse- grained ash- tuff
# Crystal ash- tuff
# Lapilli ash- tuff
# Bomb ash- tuff
# Block ash- tuff
# Lapillistone
# Ash- Lapillistone
# Bomb- Lapillistone
# Block- Lapillistone
# Agglomerate
# Bomb- Tuff
# Lapilli- Bomb- Tuff
# Ash- Bomb- Tuff
# Agglutinate
# Pyroclastic Breccia
# Block- tuff
# Lapilli- block- tuff
# Ash- block- tuff
# Tuff-Breccia
# Lapilli- tuff- breccia
# Ash- tuff- breccia
# Air-fall deposit, consolidated
# Ash-flow deposit, consolidated
# Ignimbrite, consolidated
# Ignimbrite, welded
# Ignimbrite, unwelded, consolidated
# Surge- deposit, consolidated
# Peperite
# Pyroclastic, rhyolitic
# Rhyolitic ash- tuff
# Fine- grained ash- tuff, rhyolitic
# Coarse- grained ash- tuff, rhyolitic
# Rhyolitic crystal- ash- tuff
# Rhyolitic lapilli- ash- tuff
# Rhyolitic bomb- ash- tuff
# Rhyolitic block- ash- tuff
# Rhyolitic Lapilli- tuff
# Rhyolitic ash- lapilli- tuff
# Rhyolitic bomb- lapilli- tuff
# Rhyolitic block- lapilli- tuff
# Rhyolitic agglomerate
# Rhyolitic bomb- tuff
# Rhyolitic lapilli- bomb- tuff
# Rhyolitic ash- bomb- tuff
# Rhyolitic agglutinate
# Pyroclastoc Breccia, rhyolitic
# Rhyolitic block- tuff
# Rhyolitic lapilli- block- tuff
# Rhyolitic ash- block- tuff
# Rhyolitic tuff- breccia
# Rhyolitic lapilli- tuff- breccia
# Rhyolitic ash- tuff- breccia
# Rhyolitic air- fall- deposit, consolidated
# Rhyolitic ash- flow- deposit, consolidated
# Rhyolitic Ignimbrite, consolidated
# Rhyolitic Ignimbrite, welded
# Rhyolitic Ignimbrite, unwelded, consolidated
# Rhyolitic surge- deposit
# Rhyolitic Peperite
# Pyroclastic, dacitic
# Dacitic ash- tuff
# Fine grained ash- tuff, dacitic
# Coarse grained ash- tuff, dacitic
# Dacitic crystal- ash- tuff
# Dacitic lapilli- ash- tuff
# Dacitic bomb- ash- tuff
# Dacitic block- ash- tuff
# Dacitic lapilli- tuff
# Dacitic ash- lapilli- tuff
# Dacitic bomb- lapilli- tuff
# Dacitic block- lapilli- tuff
# Dacitic Agglomerate
# Dacitic bomb- tuff
# Dacitic lapilli- bomb- tuff
# Dacitic ash- bomb- tuff
# Dacitic Agglutinate
# Pyroclastic Breccia, dacitic
# Dacitic block- tuff
# Dacitic lapilli- block- tuff
# Dacitic ash- block- tuff
# Dacitic tuff- breccia
# Dacitic lapilli- tuff- breccia
# Dacitic ash- tuff- breccia
# Dacitic air- fall- deposit, consolidated
# Dacitic ash- flow- deposit, consolidated
# Dacitic Ignimbrite, consolidated
# Dacitic Ignimbrite, welded
# Dacitic Ignimbrite, unwelded, consolidated
# Dacitic surge- deposit, consolidated
# Dacitic Peperite
# Pyroclastic, trachytic
# Trachytic ash- tuff
# Fine- grained trachytic ash- tuff
# Coarse- grained trachytic ash- tuff
# Trachytic crystal- ash- tuff
# Trachytic lapilli- ash- tuff
# Trachytic bomb- ash- tuff
# Trachytic block- ash- tuff
# Trachytic lapilli- tuff
# Trachytic ash- lapilli- tuff
# Trachytic bomb- lapilli- tuff
# Trachytic block- lapilli- tuff
# Trachytic agglomerate
# Trachytic bomb- tuff
# Trachytic lapilli- bomb- tuff
# Trachytic ash- bomb- tuff
# Trachytic agglutinate
# Pyroclastic breccia, trachytic
# Trachytic block- tuff
# Trachytic lapilli- block- tuff
# Trachytic ash- block- tuff
# Trachytic tuff- breccia
# Trachytic lapilli- tuff- breccia
# Trachytic ash- tuff- breccia
# Trachytic air- fall- deposit, consolidated
# Trachytic ash- flow- deposit, consolidated
# Trachytic Ignimbrite, consolidated
# Trachytic Ignimbrite, welded
# Trachytic Ignimbrite, unwelded, consolidated
# Trachytic surge- deposit, consolidated
# Trachytic Peperite
# Pyroclastic, latitic
# Latitic ash- tuff
# Fine- grained latitic ash- tuff
# Coarse - grained latitic ash- tuff
# Latitic crystal- ash- tuff
# Latitic lapilli- ash- tuff
# Latitic bomb- ash- tuff
# Latitic block- ash- tuff
# Latitic lapilli- tuff
# Latitic ash- lapilli- tuff
# Latitic bomb- lapilli- tuff
# Latitic block- lapilli- tuff
# Latitic agglomerate
# Latitic bomb- tuff
# Latitic lapilli- bomb- tuff
# Latitic ash- bomb- tuff
# Latitic aggglutinate
# Pyroclastic breccia, latitic
# Latitic block- tuff
# Latitic lapilli- block- tuff
# Latitic ash- block- tuff
# Latitic tuff- breccia
# Latitic lapilli- tuff- breccia
# Latitic ash- tuff- breccia
# Latitic air- flow- deposit, consolidated
# Latitic ash- flow- deposit, consolidated
# Latitic Ignimbrite, consolidated
# Latitic Ignimbrite, welded
# Latitic Ignimbrite, unwelded, consolidated
# Latitic surge- deposit, consolidated
# Latitic Peperite
# Pyroclastic, andesitic
# Andesitic ash- tuff
# Fine- grained andesitic ash- tuff
# Coarse- grained andesitic ash- tuff
# Andesitic crystal- ash- tuff
# Andesitic lapilli- ash- tuff
# Andesitic bomb- ash- tuff
# Andesitic block- ash- tuff
# Andesitic lapilli- tuff
# Andesitic ash- lapilli- tuff
# Andesitic bomb- lapilli- tuff
# Andesitic block- lapilli- tuff
# Andesitic agglomerate
# Andesitic bomb- tuff
# Andesitic lapilli- bomb- tuff
# Andesitic ash- bomb- tuff
# Andesitic agglutinate
# Pyroclastic breccia, andesitic
# Andesitic block- tuff
# Andesitic lapilli- block- tuff
# Andesitic ash- block- tuff
# Andesitic tuff- breccia
# Andesitic lapilli- tuff- breccia
# Andesitic ash- tuff- breccia
# Andesitic air- flow- deposit, consolidated
# Andesitic ash- flow- deposit, consolidated
# Andesitic Ignimbrite, consolidated
# Andesitic Ignimbrite, welded
# Andesitic Ignimbrite, unwelded, consolidated
# Andesitic surge- deposit, consolidated
# Andesitic Peperite
# Pyroclastic, basaltic
# Basaltic ash- tuff
# Fine- grained ash- tuff, basaltic
# Coarse- grained ah- tuff, basaltic
# Basaltic crystal ash- tuff
# Basaltic lapilli- ash- tuff
# Basaltic bomb- ash- tuff
# Basaltic block- ash- tuff
# Basaltic lapilli- tuff
# Basaltic crystal lapilli- tuff
# Basaltic ash- lapilli tuff
# Basaltic bomb- lapilli- tuff
# Basaltic block- lapilli- tuff
# Basaltic agglomerate
# Basaltic bomb- tuff
# Basaltic lapilli- bomb- tuff
# Basaltic ash- bomb- tuff
# Basaltic agglutinate
# Pyroclastic breccia, consolidated
# Basaltic block- tuff
# Basaltic lapilli- block- tuff
# Basaltic ash- block- tuff
# Basaltic tuff- breccia
# Basaltic lapilli- tuff- breccia
# Basaltic ash- tuff- breccia
# Basaltic air- fall- deposit, consolidated
# Basaltic ash- flow- deposit, consolidated
# Basaltic Ignimbrite, consolidated
# Basaltic surge- deposit, consolidated
# Basaltic Peperite
# Pyroclastic, phonolitic
# Phonolitic ash- tuff
# Fine- grained ash- tuff, phonolitic
# Coarse- grained ash- tuff, phonolitic
# Phonolitic crystal ash- tuff
# Phonolitic lapilli- ash- tuff
# Phonolitic bomb- ash- tuff
# Phonolitic block- ash- tuff
# Phonolitic lapilli- tuff
# Phonlitic ash- lapilli- tuff
# Phonolitic bomb- lapilli- tuff
# Phonolitic block- lapilli- tuff
# Phonolitic agglomerate
# Phonolitic bomb- tuff
# Phonolitic lapilli- block- tuff
# Phonolitic ash- block- tuff
# Phonolitic agglutinate
# Pyroclastic breccia, phonolitic
# Phonolitic block- tuff
# Phonolitic lapilli- block- tuff
# Phonolitic ash- block- tuff
# Phonolitic tuff- breccia
# Phonolitic lapilli- tuff- breccia
# Phonolitic ash- tuff- breccia
# Phonolitic air- fall- deposit, consolidated
# Phonolitic ash- flow- deposit, consolidated
# Phonolitic Ignimbrite, consolidated
# Phonolitic Ignimbrite, welded
# Phonolitic Ignimbrite, unwelded, consolidated
# Phonolitic surge- deposit, consolidated
# Phonolitic Peperite
# Pyroclastic, basanitic
# Basanitic ash- tuff
# Fine - grained ash- tuff, basanitic
# Coarse- grained ash- tuff, basanitic
# Basanitic crystall ash- tuff
# Basanitic lapilli- ash- tuff
# Basanitic bomb- ash- tuff
# Basanitic block- ash tuff
# Basanitic lapilli- tuff
# Basanitic ash- lapilli- tuff
# Basanitic bomb- lapilli- tuff
# Basanitic block- lapilli- tuff
# Basanitic agglomerate
# Basanitic bomb- tuff
# Basanitic lapilli- bomb- tuff
# Basanitic ash- bomb- tuff
# Basanitic agglutinate
# Pyroclastic breccia, basanitic
# Basanitic block- tuff
# Basanitic lapilli- block- tuff
# Basanitic ash- block- tuff
# Basanitic tuff- breccia
# Basanitic lapilli- tuff- breccia
# Basanitic ash- tuff- breccia
# Basanitic air- fall- deposit, consolidated
# Basanitic ash- flow- deposit, consolidated
# Basanitic Ignimbrite, consolidated
# Basanitic Ignimbrite, unwelded, consolidated
# Basanitic surhe- deposit- consolidated
# Basanitic peperite
# Autoclastic Volcaniclast
# Top- breccia
# Bottom- breccia
# Tuffite
# Tuffaceous-claystone
# Tuffaceous-siltstone
# Tuffaceous-sandstone
# Tuffaceous-conglomerate
# Tuffaceous-breccia
# Volcaniclastic sedimentary (epiclastic)
# Volcaniclastic claystone
# Volcaniclastic siltstone
# Volcaniclastic sandstone
# Volcaniclastic conglomerate
# Volcaniclastic breccia
# Lahar, consolidated
# Volcanic and volcaniclastic, structureless
# Dyke
# Dyke, modal (field classification)
# Quartz-rich dyke
# Quartz-bearing to foid-bearing dyke
# Foid-rich dyke
# Dolerite (field classification)
# Lamprophyr (field classification)
# Dyke, modal
# Pegmatite, granitoidic composition
# Quartz-rich Aplite
# Granite- Aplite
# Granodiorite- Aplite
# Tonalite- Aplite
# Dykes´ Granite
# Dykes´ Granodiorite
# Dykes´ Tonalite
# Microgranite
# Microgranodiorite
# Microtonalite
# Granophyr
# Porphyritic Granite
# Porphyritic Granodiorite
# Porphyritic Tonalite
# Pegmatite of nephelinitic composition
# Quartz- bearing to Quartz- free Aplite
# Syenite- Aplite
# Monzonite- Aplite
# Monzodiorite- Aplite
# Diorite- Aplite
# Gabbro- Aplite
# Dykes´ Syenite
# Dykes´ Monzonite
# Dykes´ Monzodiorite
# Dykes´ Diorite
# Dykes´ Gabbro
# Microsyenite
# Micromonzonite
# Micromonzodiorite
# Microdiorite
# Microgabbro
# Porphyric Syenite
# Porphyric Monzonite
# Porphyric Monzodiorite
# Porphyric Diorite
# Porphyric Gabbro
# Dolerite (diabase)
# Alkalibasaltic Dolerite
# Leucite- Nepheline- Dolerite
# Theoleitic Dolerite
# Foid-rich dyke
# Fioditic dyke
# Lamprophyre
# Lamprophyre
# Minette
# Kersanite
# Vogesite
# Spessartite
# Alkali- Lamprophyre
# Camptonite
# Sannaite
# Monchiquite
# Fourchite
# Ultrabasic Alkali- Lamprophyr
# Quachitite
# Melilitic Lamprophyr
# Alnoite
# Polzenite
# Lamprophyric- carbonatic dyke
# Kimberlite
# Carbonatic Kimberlite
# Hydrothermal gangue mineralization
# Quartz- rich gangue mineralization
# Milky Quartz mineral aggregate
# Capped Quartz mineral aggregate
# Pseudomorphosic Quartz mineral aggregate
# Carbonate- rich gangue mineralization
# Calcite mineral aggregate
# Feldspar- rich gangue mineralization
# Feldspar mineral aggregate
# Baryte- rich gangue mineralization
# Baryte mineral aggregate
# Sulfide- rich gangue mineralization
# Metamorphic
# Metamorphic (after educt)
# Meta- sedimentary
# Meta- Pelite
# Hornfels
# Buchite
# Silicic
# Silicic schist
# Meta- Psammite
# Meta- Arkose
# Meta- Graywacke
# Meta- Psephite
# Meta- Conglomerate
# Meta- igneous
# Meta- Plutonite
# Meta- Granite
# Meta- Granodiorite
# Meta- Diorite
# Meta- Gabbro
# Metamorphic dyke
# Meta- Aplite
# Garnet- Meta- Aplite
# Garnet- Turmaline- Meta- Aplite
# Meta- Pegmatite
# Meta- Dolerite
# Alkalibasaltic Meta- Dolerite
# Tholeitic Meta- Dolerite
# Meta volcanic
# Meta- Rhyolite
# Peralkaline Meta- Rhyolite
# Meta- Rhyodacite
# Meta- Dacite
# Meta- Trachyte
# Meta- Basalt
# Meta- Basalt sorted
# Meta- Alkali- Basalt
# Tholeitic Meta- Basalt
# Meta- Andesite
# Meta- Phonolite
# Meta- Basanite
# Meta- Pikrite
# Meta volcaniclastic
# Rhyolitic meta volcaniclastic
# Rhyodacitic meta volcaniclastic
# Dacitic meta volcaniclastic
# Trachytic meta volcaniclastic
# Andesitic meta volcaniclastic
# Basaltic meta volcaniclastic
# Alkali- basaltic meta volcaniclastic
# Tholeitic meta volcaniclastic
# Phonolitic meta volcaniclastic
# Basanitic meta volcaniclastic
# Meta pyroclastic
# Rhyolitic meta pyroclastic
# Rhyodacitic meta pyroclastic
# Dacitic meta pyroclastic
# Trachytic meta pyroclastic
# Andesitic meta pyroclastic
# Basaltic meta pyroclastic
# Alkali- basaltic meta pyroclastic
# Basanitic meta pyroclastic
# Meta- Tuffite
# Tuffitic meta- pelite
# Tuffitic meta- psammite
# Tuffitic meta- conglomerate
# Autoclastic meta- volcaniclastic
# Autoclastic/ hydroclastic meta volcaniclastic
# Pillow- breccia
# Pillow- fragment breccia
# Hydroclastic
# Volcaniclastic meta sedimentary (epiclastic)
# Metamorphic (after chemistry, fabric, mineral content)
# Metacarbonate
# Marble
# Marble sorted
# Calcite- Marble
# Dolomite- Marble
# Carbonate- silicate Marble (Silica- Marble)
# Metamorphic Carbonate- silicate
# Carbonate- Phyllite
# Carbonate- silicate (coarse)
# Quartz- rich metamorphic
# Quartzite
# Apatite- Quartzite
# Epidote- Quartzite
# Garnet- Quartzite
# Graphite- Quartzite
# Magnetite- Quartzite
# Muscovite- Quartzite
# Serictite- Quartzite
# Metafelsics
# Phyllite
# Albite- Phyllite
# Chloritoide- Phyllite
# Garnet- Albite- Phyllite
# Garnet- Phyllite
# Quartz- Phyllite
# Sericite- Phyllite
# Mica schist
# Albite- mica schist
# Andalusite- mica schist
# Apatite- mica schist
# Biotite- Plagioclase- mica schist
# Chlorite- mica schist
# Garnet- mica schist
# Graphite- mica schist
# Muscovite- Chlorite- mica schist
# Muscovite- Biotite- mica schist (two- mica schist)
# Sericite- mica schist
# Staurolite- Biotite- Muscovite- mica schist
# Gneiss
# Epidote- Hornblende- Plagioclase- Gneiss
# Albite- Gneiss
# Andalusite- Gneiss
# Biotite- Gneiss
# Biotite- Cordierit- Gneiss
# Biotite- Garnet- Gneiss
# Biotite- Plagioclase- Gneiss
# Biotite- Muscovite- Gneiss
# Biotite- Sillimanite- Gneiss
# Cordierit- Gneiss
# Disthene- Gneiss
# Disthene- Staurolite- Gneiss
# Disthene- Sillimanite- Gneiss
# Mica- Gneiss
# Garnet- Gneiss
# Garnet- Biotite- Gneiss
# Garnet- Cordierit- Sillimanite- Gneiss
# Garnet- Disthene- Gneiss
# Garnet- Disthene- Sillimanite- Gneiss
# Garnet- Disthene- Staurolite- Gneiss
# Garnet- Plagioclase- Gneis
# Graphite- Gneiss
# Hornblende- Biotite- Gneiss
# Muscovite- Gneiss
# Muscovite- Biotite- Gneiss
# Muscovite- Biotite- Garnet- Gneiss
# Muscovite- Garnet- Gneiss
# Pyroxene- Gneiss
# Quartz- Biotite- Plagioclase- Gneiss
# Staurolite- Garnet- Plagioclase- Gneiss
# Metafelsic Granulite
# Granulite
# Granulite- Gneiss
# Charnockite (metamorphic affinity)
# Acidic to intermediate Hornfels
# Andalusite- Hornfels
# Biotite- Hornblende- Plagioclase- Hornfels
# Cordierite- Hornels
# Coround- Hercynite- Hornfels
# Metamafics
# Greenschist
# Actinolite- schist
# Prasinite
# Amphibolite
# Biotite- Amphibolite
# Biotite- Pyroxene- Amphibolite
# Diopside- Amphibolite
# Epidote- Amphibolite
# Garnet- Amphibolite
# Carbonate- Silicate- Amphibolite
# Zoisite- Amphibolite
# Eklogite- Amphibolite
# Metamafic Granulite
# Eclogite
# Metamafic Hornfels
# Meta- Ultramafic
# Chlorite- Actinolite- schist
# Talcum schist
# Serpentinite
# Ultra- mafic Hornfels
# Olivine- Fels
# Tectonite
# Cataclast
# Fault breccia
# Melange
# Schist
# Slate/ slaty metamudstone
# Black shale
# Alum shale
# Ribbon slate
# Silty schist
# Mylonite
# Migmatite
# Anatexite
# Metatexite
# Diatexite
# Syntexite
# Sedimentary
# Siliciclastic sedimentary
# Sandstone- Pelite- Alternation
# Sandstone- dominated Sandstone- Pelite- Alternation
# Pelite- dominated Sandstone- Pelite- Alternation
# Pelite- Gypsum- Alternation
# Pelite dominated Pelite- Gypsum- Alternation
# Gypsum dominated Pelite- Gypsum- Alternation
# Pelite
# Silicate- Claystone
# Silicate- Siltstone
# Sapropelite
# Psammite/Arenite
# (Arenite-) Sandstone
# Fine Sandstone
# Medium Sandstone
# Coarse Sandstone
# Quartz- Arenite
# Fine Quartz- Arenite
# Medium Quartz- Arenite
# Coarse Quartz- Arenite
# Subfeldspatic- Arenite / Feldspatic Sandstone
# Fine Subfeldspatic- Arenite
# Medium Subfeldspatic- Arenite
# Coarse Subfeldspatic- Arenite
# Feldspatic- Arenite
# Fine Feldspatic- Arenite
# Medium Feldspatic- Arenite
# Coarse Feldspatic- Arenite
# Arkose
# Fine Arkose
# Medium Arkose
# Coarse Arkose
# Sublitharenite
# Fine Sublitharenite
# Medium Sublitharenite
# Coarse Sublitharenite
# Litharenite
# Fine Litharenite
# Medium Litharenite
# Coarse Litharenite
# Lithic- Arenite
# Fine Lithic- Arenite
# Medium Lithic- Arenite
# Coarse Lithic- Arenite
# Graywacke/ Wacke
# Fine Graywacke
# Medium Graywacke
# Coarse Graywacke
# Quartz- Wacke
# Fine Quartz- Wacke
# Medium Quartz- Wacke
# Coarse Quartz- Wacke
# Feldspathic- Wacke
# Fine Feldspethic- Wacke
# Medium Feldspethic- Wacke
# Coarse Feldspethic- Wacke
# Lithic Wacke
# Fine Lithic- Wacke
# Medium Lithic- Wacke
# Coarse Lithic- Wacke
# Psephite
# Conglomerate
# Pebbly conglomerate
# Fine Pebble, Granule
# Medium to coarse pebble
# Very Coarse Pebble
# Cobbles
# Boulders
# Breccia
# Grus- Breccia
# Fine Grus- Breccia
# Medium Grus- Breccia
# Coarse Grud- Breccia
# Debris- Breccia
# Block- Debris Breccia
# Carbonatic sedimentary
# Carbonatic siliciclastic sedimentary
# Limestone- Marl- Alteration
# Limestone dominated Limestone- Marl- Alteration
# Marl dominated Limestone- Marl- Alteration
# Pelite- Marl- Alteration
# Pelite dominated Pelite- Marl- Alteration
# Marol dominated Pelite- Marl- Alteration
# Carbonate-bearing siliciclastic
# Carbonate- bearing claystone
# Carbonate- bearing mudstone
# Carbonate- bearing sandstone
# Carbonate- bearing fine sandstone
# Carbonate- bearing medium sandstone
# Carbonate- bearing coarse sandstone
# Carbonate- bearing conglomerate
# Carbonate- bearing breccia
# Dolomite- bearing siliciclastic
# Dolomite- bearing claystone
# Dolomite- bearing mudstone
# Dolomite- bearing sandstone
# Dolomite- bearing fine sandstone
# Dolomite- bearing medium sandstone
# Dolomite- bearing coarse sandstone
# Dolomite- bearing conglomerate
# Dolomite- bearing breccia
# Carbonatic siliciclastic
# Carbonatic claystone
# Carbonatic mudstone
# Carbonatic sandstone
# Carbonatic fine sandstone
# Carbonatic medium sandstone
# Carbonatic coarse sandstone
# Carbonatic conglomerate
# Carbonatic breccia
# Dolomitic siliciclastic
# Dolomitic claystone
# Dolomitic mudstone
# Dolomitic sandstone
# Dolomitic fine sandstone
# Dolomitic medium sandstone
# Dolomitic coarse sandstone
# Dolomitic conglomerate
# Dolomitic breccia
# Siliciclastic limestone
# Clayey limestone
# Muddy limestone
# Sandy limestone
# Fine- sandy limestone
# Medium- sandy limestone
# Coarse- sandy limestone
# Conglomeratic limestone
# Brecciatic limestone
# Siliciclastic dolimite
# Clayey dolomite
# Muddy dolomite
# Sandy dolomite
# Fine- sandy dolomite
# Medium- sandy dolomite
# Coarse- sandy dolomite
# Conglomeratic dolomite
# Brecciatic dolomite
# Clay- lime- composite
# Marly Claystone
# Marl- Claystone
# Clay- Marl
# Marl
# Lime-Marl
# Dolomite- Marl
# Marl- Limestone
# Marl- Dolomite
# Marly Limestone
# Marly Dolomite
# Carbonate
# Clastic sedimentary Carbonate
# Carbonate
# Lutite
# Siltite
# Arenite
# Fine- grained Arenite
# Medium- grained Arenite
# Coarse- grained Arenite
# Ooidlothic
# Oncolithic
# Rudite
# Dolomite
# Dolomitic Lutite
# Dolomitic Siltite
# Dolomitic Arenite
# Fine- grained dolomitic Arenite
# Medium- grained dolomitic Arenite
# Coarse- grained dolomitic Arenite
# Dolomitic Rudite
# Limestone
# Calcitic Lutite
# Calcitic Siltite
# Calcitic Arenite
# Fine- grained calcitic Arenite
# Medium- grained calcitic Arenite
# Coarse- grained calcitic Arenite
# Calcitic Rudite
# Carbonate of Dunham (1962) and Embry & Klovan (1972)
# Allothonous limestone
# Mud- supported limestone
# Mudstone
# Wackstone
# Floatstone
# Grain- supported limestones
# Packstone
# Grainstone
# Rudstone
# Autochthonous limestone
# Boundstone
# Bafflestone
# Bindstone
# Framestone
# Carbonate Rock of Folk (1959, 1962)
# Mikritic Limestone
# Micrite- Limestone
# Intramicrite- Limestone
# Intraclastic Micrite- Limestone
# Oomicrite- Limestone
# Ooid- bearing Micrite Limestone
# Biomicrite- Limestone
# Fossile- bearing Micrite- Limestone
# Biopelmicrite- Limestone
# Pelmicrite- Limestone
# Peloid- bearing Micrite- Limestone
# Dismicrite- Limestone
# Sparitic Limestone
# Sparite- Limestone
# Intrasparite- Limestone
# Intraclastic Sparite- Limestone
# Oosparite- Limestone
# Ooid- bearing Sparite- Limestone
# Biosparite- Limestone
# Fossile- bearing Sparite Limestone
# Biopelsparite- Limestone
# Pelsparite- Limestone
# Peloid- bearing Sparite- Limestone
# Biolithites
# Algual biolithite
# Brachiopod biolithite
# Cephalopod biolithite
# Crinoidal biolithite
# Coral biolithite
# Shell biolithite
# Reef biolithite
# Poriferan biolithite
# Stromatolithic biolithite
# Bioclastic
# Fresh- water carbonate
# Chemical/biogene non-carbonate sedimentary
# Non-Carbonate salts
# Sulphate salt
# Gypsum
# Anhydrite
# Chloride salt
# Halite
# Potassium salt
# Sylvenite
# Nitrate salt
# Salpeter
# Borate salt
# Bora
# Mixed- salt
# Sylvine
# Silica sedimentarys
# Silica introducted Quartzite
# Chert
# Radiolarite (Silica- schist)
# Lydite (Alaun- Silica- schist)
# Carbonatic Radiolarite (Silica- Carbonate)
# Phosphate- sedimentarys
# Phosphorite
# Phosphorite- nodule
# Coal
# Xyloid coal
# Fusite
# Stubben- horizon
# Gagatite
# Humic coal
# Lignite
# Ortho- lignite (brown lignite)
# Earthy ortho- lignite
# Slaty ortho- lignite
# Meta- lignite (black lignite)
# Dull meta- lignite
# Bright meta- lignite (pitch coal)
# Bituminous-coal
# Flaming coal
# Gas flaming coal
# Gas coal
# Cooking coal
# Steam coal
# Lean coal
# Anthracite
# Semi- Anthracite
# Anthracite
# Meta- Anthracite
# Sapropelic coal
# Sapropelic lignite
# Boghead- lignite
# Cannel- lignite
# Sapropolic bituminous coal
# Boghead- coal
# Cannel- coal
# Liptobiolote
# Oil Shale
# Ore
# Iron ore
# Red- iron ore
# Brown- iron ore
# Spar- iron ore
# Pyrite- ore deposit
# Manganese- ore
# Phosphate- ore
# Aluminia- ore
# Nickel- ore
# Non- ferrous metal ore
# Copper- ore
# Lead- zinc- ore
# Unconsolidateds
# Volcaniclastic sediments
# Tephra
# Ash- layering
# Fine- grained ash- layering
# Coarse- grained ash- layering
# Crystal ash- layering
# Lapillie ash- layering
# Block ash- layering
# Bomb ash- layering
# Lapilli- layering
# Ash- lapilli- layering
# Block- lapilli- layering
# Bomb- lapilli- layering
# Bomb- layering
# Lapilli- bomb- layering
# Ash- bomb- layering
# Block- layering
# Lapilli- block- layering
# Ash- block- layering
# Air- fall- deposit
# Ash- flow- deposit
# Ignimbrite, unconsolidated
# Surge- deposit
# Tuffaceous deposit
# Tuffaceous clay
# Tuffaceous silt
# Tuffaceous sand
# Tuffaceous gravel
# Tuffaceous pebble
# Volcaniclastic Sediment (epiclastic)
# Volcaniclastic clay
# Volcaniclastic silt
# Volcaniclastic sand
# Volcaniclastic gravel
# Volcaniclastic pebble
# Lahar, unconsolidated
# Clastic sediments
# Siliciclastic sediments
# Clay- Sediment
# Clay (dry)
# Silty clay
# Muddy clay
# Clay (moistured)
# Gravel clay
# Pebbel- bearing clay
# Pebbly clay
# Grus- bearing clay
# Grus clay
# Debris- bearing clay
# Detrital clay
# Strongly humus clay
# Muddy sediments
# Mud ("dry")
# Mud ("moistured")
# Clayey mud
# Normal mud
# Sandy mud
# Gravel- bearing mud
# Gravelly mud
# Pebble- bearing mud
# Pebbly mud
# Grus- bearing mud
# Grus- mud
# Debris- bearing mud
# Detrital mud
# Strong humus mud
# Silty sediments
# Silt ("dry")
# Silt ("moistured")
# Clayey silt
# Muddy silt
# Sandy silt
# Gravel- bearing silt
# Gravelly silt
# Pebble- bearing silt
# Pebbly silt
# Grus- bearing silt
# Grus- silt
# Debris- bearing silt
# Detrital silt
# Strong humus silt
# Sandy sediments
# Sand
# Silty sand
# Muddy sand
# Pure sand
# Gravel- bearing sand
# Gravelly sand
# Pebble- bearing sand
# Pebbly sand
# Grus- bearing sand
# Grus sand
# Debris- bearing sand
# Detrital sand
# Strong humus sand
# Gravel sediments
# Gravel
# Grus- gravel
# Detrital gravel
# Pebbly gravel
# Sandy gravel
# Silty gravel
# Clayey gravel
# Muddy gravel
# Pebbly sediments
# Pebble
# Grus- pebble
# Detrital pebble
# Gravely pebble
# Clayey pebble
# Silty pebble
# Muddy pebble
# Sandy pebble
# Grus- sediments
# Grus
# Gravely grus
# Pebbly grus
# Detrital grus
# Sandy grus
# Silty grus
# Clayey grus
# Muddy grus
# Detrital sediments
# Debris
# Gravely debris
# Pebbly debris
# Grus debris
# Sandy debris
# Silty debris
# Clayey debris
# Muddy debris
# Block sediments
# Blocks
# Block- debris
# Block- pebble
# Blocky debris- pebble
# Clastic carbonatic sediment
# Carbonate- bearing sediment
# Carbonate- bearing clay sediment
# Carbonate- bearing clay
# Carbonate- bearing silty clay
# Carbonate- bearing muddy clay
# Carbonate-, gravel- bearing clay
# Carbonate- bearing gravely clay
# Carbonate-, pebble- bearing clay
# Carbonate- bearing pebbly clay
# Carbonate-, grus- bearing clay
# Carbonate- bearing grus- clay
# Carbonate-, debris- bearing clay
# Carbonate- bearing detrital clay
# Carbonate- bearing, strongly humus clay
# Carbonate- bearing mud sediment
# Carbonate- bearing mud
# Carbonate- bearing clayey mud
# Carbonate- bearing mud
# Carbonate- bearing sandy mud
# Carbonate-, gravel- bearing mud
# Carbonate- bearing gravelly mud
# Carbonate-, pebble- bearing mud
# Carbonate- bearing pebbly mud
# Carbonate-, grus- bearing mud
# Carbonate- bearing grus- mud
# Carbonate-, debris- bearing mud
# Carbonate- bearing detrital mud
# Carbonate- bearing, stronly humus mud
# Carbonate- bearing silt sediment
# Carbonate- bearing silt
# Carbonate- bearing clayey silt
# Carbonate- bearing muddy silt
# Carbonate- bearing sandy silt
# Carbonate-, gravel- bearing silt
# Carbonate- bearing gravelly silt
# Carbonate-, pebble- bearing silt
# Carbonate- bearing pebbly silt
# Carbonate-, grus- bearing silt
# Carbonate- bearing grus- silt
# Carbonate-, debris- bearing silt
# Carbonate- bearing detrital silt
# Carbonate- bearing, stronly humus silt
# Carbonate- bearing sand sediment
# Carbonate- bearing sand
# Carbonate- bearing silty sand
# Carbonate- bearing muddy sand
# Carbonate- bearing sand
# Carbonate-, gravel- bearing sand
# Carbonate- bearing gravelly sand
# Carbonate-, pebble- bearing sand
# Carbonate- bearing pebbly sand
# Carbonate-, grus- bearing sand
# Carbonate- bearing grus- sand
# Carbonate-, debris- bearing sand
# Carbonate- bearing detrital sand
# Carbonate- bearing, stronly humus sand
# Carbonate- bearing gravel sediment
# Carbonate- bearing gravel
# Carbonate- bearing grus- gravel
# Carbonate- bearing detrital gravel
# Carbonate- bearing pebbly gravel
# Carbonate- bearing sandy gravel
# Carbonate- bearing silty gravel
# Carbonate- bearing clayey gravel
# Carbonate- bearing muddy gravel
# Carbonate- bearing pebble sediment
# Carbonate- bearing pebble
# Carbonate- bearing grus- pebble
# Carbonate bearing detrital pebble
# Carbonate- bearing gravelly pebble
# Carbonate- bearing clayey pebble
# Carbonate- bearing silty pebble
# Carbonate- bearing muddy pebble
# Carbonate- bearing sandy pebble
# Carbonate- bearing grus sediment
# Carbonate- bearing grus
# Carbonate- bearing gravelly grus
# Carbonate- bearing pebbly grus
# Carbonate- bearing detrital grus
# Carbonate- bearing sandy grus
# Carbonate- bearing silty grus
# Carbonate- bearing clayey grus
# Carbonate- bearing muddy grus
# Carbonate- bearing debris sediment
# Carbonate- bearing debris
# Carbonate- bearing gravelly debris
# Carbonate- bearing pebbly debris
# Carbonate- bearing grus- debris
# Carbonate- bearing sandy debris
# Carbonate- bearing silty debris
# Carbonate- bearing clayey debris
# Carbonate- bearing muddy debris
# Carbonate- bearing block sediment
# Carbonate- bearing blocks
# Carbonate- bearing detrital blocks
# Carbonate- bearing pebbly blocks
# Carbonate- bearing detrital pebble- blocks
# Carbonate- rich sediment
# Argillaceous marl sediment
# Argillaceous marl
# Silty argillaceous marl
# Muddy argillaceous marl
# Gravel- bearing argillaecous marl
# Gravelly argillaceous marl
# Pebble- bearing argillaceous marl
# Pebbly argillaceous marl
# Grus- bearing argillaceous marl
# Grus- argillaceous marl
# Debris- bearing argillaceous marl
# Detrital argillaceous marl
# Strongly humus argillaceous marl
# Muddy marl sediment
# Muddy marl
# Clayey muddy marl
# Muddy marl
# Sandy muddy marl
# Gravel- bearing muddy marl
# Gravelly muddy marl
# Pebble- bearing muddy marl
# Pebbly muddy marl
# Grus- bearing muddy marl
# Grus- muddy marl
# Debris- bearing muddy marl
# Detrital muddy marl
# Stronly humus muddy marl
# Silty marl sediment
# Silty marl
# Clayey silty marl
# Muddy silty marl
# Sandy silty marl
# Gravel- bearing silty marl
# Gravelly silty marl
# Pebble- bearing silty marl
# Pebbly silty marl
# Grus- bearing silty marl
# Grus- silty marl
# Debris- bearing silty marl
# Detrital silty marl
# Strongly humus silty marl
# Carbonatic sand sediment
# Carbonatic sand
# Carbonatic silty sand
# Carbonatic muddy sand
# Carbonatic sand
# Gravel- bearing carbonatic sand
# Gravelly carbonatic sand
# Pebble- bearing carbonatic sand
# Pebbly carbonatic sand
# Grus- bearing carbonatic sand
# Carbonatic grus- sand
# Debris- bearing carbonatic sand
# Carbonatic debris- sand
# Strongly humus carbonatic sand
# Carbonatic gravel sediment
# Carbonatic gravel
# Carbonatic grus- gravel
# Detrital carbonatic gravel
# Pebbly carbonatic gravel
# Sandy carbonatic gravel
# Sitly carbonatic gravel
# Clayey carbonatic gravel
# Muddy carbonatic gravel
# Carbonatic pebble sediment
# Carbonatic pebble
# Carbonatic grus- pebble
# Detrital carbonatic pebble
# Gravely carbonatic pebble
# Clayey carbonatic pebble
# Silty carbonatic pebble
# Muddy carbonatic pebble
# Sandy carbonatic pebble
# Carbonatic grus sediment
# Carbonatic grus
# Gravely carbonatic grus
# Pebbly carbonatic grus
# Detrital carbonatic grus
# Sandy carbonatic grus
# Silty carbonatic grus
# Clayey carbonatic grus
# Muddy carbonatic grus
# Carbonatic debris sediment
# Carbonatic debris- sand
# Gravely carbonatic debris
# Pebbly carbonatic debris
# Carbonatic grus- debris
# Sandy carbonatic debris
# Silty carbonatic debris
# Clayey carbonatic debris
# Muddy carbonatic debris
# Carbonatic block sediment
# Carbonatic blocks
# Carbonatic detrital blocks
# Carbonatic pebbly blocks
# Carbonatic detrital pebble- blocks
# Carbonate- sediment
# Carbonate
# Dolomite
# Organic sediment
# Carbonate- free organic sediment
# Litter
# Decomposed litter
# Humus
# Turf/ Peat
# Turf/ Peat ("dry")
# Lowland fen- turf
# Transition bog turf
# Upland fen- turf
# Organic mud
# Coaly sediments
# Earthy/ slaty lignite
# Bitumen
# Asphalt
# Petroleum
# Siliceous sediments
# Diatomite
# Carbonate- bearing organic sediment
# Carbonate- bearing humus
# Carbonate- rich humus
# Carbonate- bearing turf/ peat
# Carbonate- bearing lowland- fen turf
# Carbonate- rich turf/ peat
# Carbonate- rich lowland- fen turf
# Carbonate- bearing organic mud
# Carbonate- rich organic mud
# Artificial sediments
# consolidated
# magmatic
# plutonic
# plutonic,
# modal,
# field
# description
# very
# quartz
# rich
# quartz
# granitic
# quartz
# quartz
# bearing
# to
# foid
# syenitic
# dioritic
# gabbrotic
# foid
# foid
# foid
# foid
# gabbrodic
# very
# foid
# plutonic/
# foidolite
# foidolitic
# ultra
# mafic
# (field
# classification)
# modal
# (qapf)
# quartzolite
# granite
# alkali
# feldspar
# syenogranite
# monzogranite
# granodiorite
# tonalite
# quartzalkalifeldsparsyenite
# quartzsyenite
# quartzmonzonite
# quartzmonzodiorite
# quartzmonzogabbro
# quartzdiorite
# quartzgabbro
# quartzanorthosite
# alkalifeldsparsyenite
# syenite
# monzonite
# monzodiorite
# monzogabbro
# diorite
# gabbro
# gabbronorite
# norite
# troctolite
# olivine
# olivine
# olivine
# orthopyroxene
# clinopyroxene
# hornblende
# pyroxene
# hornblende
# pyroxene
# hornblende
# pyroxene
# hornblende
# anorthosite
# foidbearingalkalifeldsparsyenite
# foidbearing
# foidbearing
# foidbearing
# foidbearing
# foidbearing
# foidbearing
# foidbearing
# foidsyenite
# (eg.
# nephelinesyenite)
# malignite
# shoncinite
# foidmonzosyenite
# foidmonzodiorite
# foidmonzogabbro
# foiddiorite
# foidgabbro
# nephelinolite
# urtite
# ijolite
# melteigite
# leucitolite
# italite
# fergustite
# missourite
# ultramafic
# plutonics
# peridotite
# dunite
# harzburgite
# lherzolite
# wehrlite
# pyroxeneperidotite
# pyroxenehornblendeperidotite
# hornblendeperidotite
# pyroxenite
# orthopyroxenite
# olivine
# websterite
# olivine
# klinopyroxenite
# olivine
# olivine
# olivine
# hornblende
# plagioclase
# plagioclase
# hornblende
# hornblendite
# pyroxene
# olivine
# olivine
# pyroxene
# plagioclase
# plagioclase
# pyroxene
# melilitic
# melilolite
# olivine
# melilitolite
# pyroxene
# olivine
# pyroxene
# pyroxene
# olivine
# melililolite
# carbonatite
# (plutonic)
# calcite
# (plutonic
# affinity)
# dolomite
# ferro
# charnockite
# volcanic
# (modal)
# quartz
# rhyolitic
# dacitic
# quartz
# foid
# trachytic
# latitic
# basaltic
# tholeiitic
# olivine
# alkali
# andesitic
# foid
# phonolitic
# tephritic
# basanitic
# very
# foid
# foiditic
# (modal/normativ)
# alkalifeldsparrhyolite
# rhyolite
# rhyodacite
# dacite
# obsidian
# quartzalkalifeldspartrachyte
# quartztrachyte
# alkalifeldspartrachyte
# trachyte
# foidbearingalkalifeldspartrachyte
# foidbearingtrachyte
# quartzlatite
# latite
# foidbearing
# basalt
# tholeitic
# olivine
# alkali
# alkali
# basalt,
# amphibole
# leucobasalt
# leuco
# alkali
# andesite
# melaandesite
# phonolite
# tephriticphonolite
# tephrite
# phonolitictephrite
# basanite
# limburgite
# basanite,
# analcim
# amphibole
# phonoliticbasanite
# phonoliticfoidite
# tephriticfoidite
# basaniticfoidite
# foidite
# nephelinite
# melilitenephelinite
# analcimite
# leucitite
# melilithite
# olivine
# melilithite
# calcite
# dolomite
# ferro
# natro
# (chemically)
# acidic
# intermediate
# basic
# volcanics
# ultra
# sio2oversaturated
# (tas)
# comenditic
# rhyolite/
# comendite
# pantelleritic
# pantellerite
# trachydacite
# high
# k
# medium
# k
# low
# k
# high
# k
# medium
# k
# low
# k
# high
# k
# basaltic
# medium
# k
# basaltic
# low
# k
# sio2saturated
# trachite
# peralkalic
# pantellitic
# trachyandesite
# benmoreite
# mugearite
# shoshonite
# trachybasalt
# hawaiite
# k
# sio2saturated
# or
# slightly
# undersaturated
# subalkali
# high
# alumina
# alkali
# alkali
# olivine
# sio2undersaturated
# tephriphonolite
# phonotephrite
# picrobasalt
# highmgvolcanics
# boninite
# picritic
# picrite
# comatiite
# meimechite
# volcaniclastic
# volcaniclastics
# volcaniclast
# alkali
# pyroclastics
# pyroclastic,
# undefined
# (ash)
# tuff
# fine
# grained
# ash
# coarse
# ash
# crystal
# ash
# lapilli
# ash
# bomb
# ash
# block
# ash
# lapillistone
# ash
# bomb
# block
# agglomerate
# bomb
# lapilli
# bomb
# ash
# bomb
# agglutinate
# pyroclastic
# breccia
# block
# lapilli
# block
# ash
# block
# tuffbreccia
# lapilli
# tuff
# ash
# tuff
# airfall
# deposit,
# ashflow
# ignimbrite,
# welded
# unwelded,
# surge
# peperite
# ash
# fine
# ash
# tuff,
# coarse
# ash
# crystal
# ash
# lapilli
# ash
# bomb
# ash
# block
# ash
# lapilli
# ash
# lapilli
# bomb
# lapilli
# block
# lapilli
# bomb
# lapilli
# bomb
# ash
# bomb
# pyroclastoc
# breccia,
# block
# lapilli
# block
# ash
# block
# tuff
# lapilli
# tuff
# ash
# tuff
# air
# fall
# ash
# flow
# surge
# deposit
# ash
# ash
# ash
# crystal
# ash
# lapilli
# ash
# bomb
# ash
# block
# ash
# lapilli
# ash
# lapilli
# bomb
# lapilli
# block
# lapilli
# bomb
# lapilli
# bomb
# ash
# bomb
# block
# lapilli
# block
# ash
# block
# tuff
# lapilli
# tuff
# ash
# tuff
# air
# fall
# ash
# flow
# surge
# ash
# fine
# ash
# coarse
# ash
# crystal
# ash
# lapilli
# ash
# bomb
# ash
# block
# ash
# lapilli
# ash
# lapilli
# bomb
# lapilli
# block
# lapilli
# bomb
# lapilli
# bomb
# ash
# bomb
# block
# lapilli
# block
# ash
# block
# tuff
# lapilli
# tuff
# ash
# tuff
# air
# fall
# ash
# flow
# surge
# ash
# fine
# ash
#
# ash
# crystal
# ash
# lapilli
# ash
# bomb
# ash
# block
# ash
# lapilli
# ash
# lapilli
# bomb
# lapilli
# block
# lapilli
# bomb
# lapilli
# bomb
# ash
# bomb
# aggglutinate
# block
# lapilli
# block
# ash
# block
# tuff
# lapilli
# tuff
# ash
# tuff
# air
# flow
# ash
# flow
# surge
# ash
# fine
# ash
# coarse
# ash
# crystal
# ash
# lapilli
# ash
# bomb
# ash
# block
# ash
# lapilli
# ash
# lapilli
# bomb
# lapilli
# block
# lapilli
# bomb
# lapilli
# bomb
# ash
# bomb
# block
# lapilli
# block
# ash
# block
# tuff
# lapilli
# tuff
# ash
# tuff
# air
# flow
# ash
# flow
# surge
# ash
# fine
# ash
# coarse
# ah
# ash
# lapilli
# ash
# bomb
# ash
# block
# ash
# lapilli
# lapilli
# ash
# bomb
# lapilli
# block
# lapilli
# bomb
# lapilli
# bomb
# ash
# bomb
# block
# lapilli
# block
# ash
# block
# tuff
# lapilli
# tuff
# ash
# tuff
# air
# fall
# ash
# flow
# surge
# ash
# fine
# ash
# coarse
# ash
# ash
# lapilli
# ash
# bomb
# ash
# block
# ash
# lapilli
# phonlitic
# ash
# lapilli
# bomb
# lapilli
# block
# lapilli
# bomb
# lapilli
# block
# ash
# block
# block
# lapilli
# block
# ash
# block
# tuff
# lapilli
# tuff
# ash
# tuff
# air
# fall
# ash
# flow
# surge
# ash
#
# ash
# coarse
# ash
# crystall
# ash
# lapilli
# ash
# bomb
# ash
# block
# lapilli
# ash
# lapilli
# bomb
# lapilli
# block
# lapilli
# bomb
# lapilli
# bomb
# ash
# bomb
# block
# lapilli
# block
# ash
# block
# tuff
# lapilli
# tuff
# ash
# tuff
# air
# fall
# ash
# flow
# surhe
# deposit
# autoclastic
# top
# bottom
# tuffite
# tuffaceousclaystone
# tuffaceoussiltstone
# tuffaceoussandstone
# tuffaceousconglomerate
# tuffaceousbreccia
# sedimentary
# (epiclastic)
# claystone
# siltstone
# sandstone
# conglomerate
# lahar,
# and
# volcaniclastic,
# structureless
# dyke
# dyke,
# quartzrich
# quartzbearing
# foidbearing
# foidrich
# dolerite
# lamprophyr
# pegmatite,
# granitoidic
# composition
# quartzrich
# aplite
# granite
# granodiorite
# tonalite
# dykes´
# microgranite
# microgranodiorite
# microtonalite
# granophyr
# porphyritic
# pegmatite
# of
# nephelinitic
# quartz
# quartz
# free
# syenite
# monzonite
# monzodiorite
# diorite
# gabbro
# microsyenite
# micromonzonite
# micromonzodiorite
# microdiorite
# microgabbro
# porphyric
# (diabase)
# alkalibasaltic
# leucite
# nepheline
# theoleitic
# foidrich
# fioditic
# lamprophyre
# minette
# kersanite
# vogesite
# spessartite
# alkali
# camptonite
# sannaite
# monchiquite
# fourchite
# ultrabasic
# alkali
# quachitite
# alnoite
# polzenite
# lamprophyric
# carbonatic
# kimberlite
# hydrothermal
# gangue
# mineralization
# quartz
# milky
# mineral
# aggregate
# capped
# pseudomorphosic
# carbonate
# feldspar
# baryte
# sulfide
# metamorphic
# (after
# educt)
# meta
# meta
# pelite
# hornfels
# buchite
# silicic
# schist
# meta
# psammite
# meta
# arkose
# meta
# graywacke
# meta
# psephite
# meta
# meta
# igneous
# meta
# plutonite
# meta
# meta
# meta
# meta
# meta
# garnet
# meta
# garnet
# turmaline
# meta
# meta
# meta
# meta
# meta
# meta
# peralkaline
# meta
# meta
# meta
# meta
# meta
# meta
# sorted
# meta
# alkali
# meta
# meta
# meta
# meta
# meta
# pikrite
# rhyodacitic
# alkali
# alkali
# meta
# tuffitic
# meta
# meta
# meta
# meta
# autoclastic/
# hydroclastic
# pillow
# pillow
# fragment
# chemistry,
# fabric,
# content)
# metacarbonate
# marble
# calcite
# dolomite
# carbonate
# silicate
# (silica
# marble)
# carbonate
# carbonate
# phyllite
# carbonate
# (coarse)
# quartz
# quartzite
# apatite
# epidote
# garnet
# graphite
# magnetite
# muscovite
# serictite
# metafelsics
# albite
# chloritoide
# garnet
# albite
# garnet
# quartz
# sericite
# mica
# albite
# andalusite
# apatite
# biotite
# plagioclase
# chlorite
# garnet
# graphite
# muscovite
# chlorite
# muscovite
# biotite
# (two
# schist)
# sericite
# staurolite
# biotite
# muscovite
# gneiss
# epidote
# hornblende
# plagioclase
# albite
# andalusite
# biotite
# biotite
# cordierit
# biotite
# garnet
# biotite
# plagioclase
# biotite
# muscovite
# biotite
# sillimanite
# cordierit
# disthene
# disthene
# staurolite
# disthene
# sillimanite
# mica
# garnet
# garnet
# biotite
# garnet
# cordierit
# sillimanite
# garnet
# disthene
# garnet
# disthene
# sillimanite
# garnet
# disthene
# staurolite
# garnet
# plagioclase
# gneis
# graphite
# hornblende
# biotite
# muscovite
# muscovite
# biotite
# muscovite
# biotite
# garnet
# muscovite
# garnet
# pyroxene
# quartz
# biotite
# plagioclase
# staurolite
# garnet
# plagioclase
# metafelsic
# granulite
# granulite
# (metamorphic
# andalusite
# biotite
# hornblende
# plagioclase
# cordierite
# hornels
# coround
# hercynite
# metamafics
# greenschist
# actinolite
# prasinite
# amphibolite
# biotite
# biotite
# pyroxene
# diopside
# epidote
# garnet
# carbonate
# silicate
# zoisite
# eklogite
# metamafic
# eclogite
# meta
# chlorite
# actinolite
# talcum
# serpentinite
# ultra
# olivine
# fels
# tectonite
# cataclast
# fault
# melange
# slate/
# slaty
# metamudstone
# black
# shale
# alum
# ribbon
# slate
# silty
# mylonite
# migmatite
# anatexite
# metatexite
# diatexite
# syntexite
# siliciclastic
# sandstone
# pelite
# alternation
# sandstone
# dominated
# sandstone
# pelite
# pelite
# sandstone
# pelite
# pelite
# gypsum
# pelite
# gypsum
# pelite
# gypsum
# silicate
# silicate
# sapropelite
# psammite/arenite
# (arenite)
# quartz
# arenite
# quartz
# quartz
# quartz
# subfeldspatic
# /
# feldspatic
# subfeldspatic
# subfeldspatic
# subfeldspatic
# feldspatic
# feldspatic
# feldspatic
# feldspatic
# sublitharenite
# litharenite
# lithic
# lithic
# lithic
# lithic
# graywacke/
# wacke
# quartz
# quartz
# quartz
# quartz
# feldspathic
# feldspethic
# feldspethic
# feldspethic
# lithic
# lithic
# lithic
# pebbly
# pebble,
# granule
# pebble
# cobbles
# boulders
# grus
# grus
# grus
# grud
# debris
# block
# limestone
# marl
# alteration
# limestone
# marl
# limestone
# marl
# pelite
# marl
# pelite
# marl
# marol
# pelite
# marl
# carbonatebearing
# carbonate
# carbonate
# mudstone
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# dolomite
# dolomite
# dolomite
# dolomite
# dolomite
# dolomite
# dolomite
# dolomite
# dolomite
# dolomitic
# clayey
# muddy
# sandy
# fine
# medium
# coarse
# conglomeratic
# brecciatic
# dolimite
# fine
# medium
# coarse
# clay
# lime
# composite
# marly
# marl
# clay
# limemarl
# dolomite
# marl
# marl
# clastic
# lutite
# siltite
# fine
# medium
# coarse
# ooidlothic
# oncolithic
# rudite
# fine
# medium
# coarse
# calcitic
# fine
# medium
# coarse
# dunham
# (1962)
# embry
# &
# klovan
# (1972)
# allothonous
# mud
# supported
# wackstone
# floatstone
# grain
# limestones
# packstone
# grainstone
# rudstone
# autochthonous
# boundstone
# bafflestone
# bindstone
# framestone
# rock
# folk
# (1959,
# 1962)
# mikritic
# micrite
# intramicrite
# intraclastic
# micrite
# oomicrite
# ooid
# biomicrite
# fossile
# micrite
# biopelmicrite
# pelmicrite
# peloid
# micrite
# dismicrite
# sparitic
# sparite
# intrasparite
# sparite
# oosparite
# ooid
# sparite
# biosparite
# fossile
# biopelsparite
# pelsparite
# peloid
# sparite
# biolithites
# algual
# biolithite
# brachiopod
# cephalopod
# crinoidal
# coral
# shell
# reef
# poriferan
# stromatolithic
# bioclastic
# fresh
# water
# chemical/biogene
# noncarbonate
# noncarbonate
# salts
# sulphate
# salt
# anhydrite
# chloride
# halite
# potassium
# sylvenite
# nitrate
# salpeter
# borate
# bora
# mixed
# sylvine
# silica
# sedimentarys
# introducted
# chert
# radiolarite
# (silica
# lydite
# (alaun
# silica
# (silica
# carbonate)
# phosphate
# phosphorite
# phosphorite
# nodule
# coal
# xyloid
# fusite
# stubben
# horizon
# gagatite
# humic
# lignite
# ortho
# (brown
# lignite)
# earthy
# ortho
# ortho
# meta
# (black
# dull
# meta
# bright
# meta
# (pitch
# coal)
# bituminouscoal
# flaming
# gas
# cooking
# steam
# lean
# anthracite
# semi
# meta
# sapropelic
# boghead
# cannel
# sapropolic
# bituminous
# boghead
# cannel
# liptobiolote
# oil
# ore
# iron
# red
# brown
# spar
# pyrite
# manganese
# phosphate
# aluminia
# nickel
# non
# ferrous
# metal
# copper
# lead
# zinc
# unconsolidateds
# sediments
# tephra
# ash
# layering
# fine
# ash
# coarse
# ash
# ash
# lapillie
# ash
# ash
# ash
# lapilli
# ash
# lapilli
# block
# lapilli
# bomb
# lapilli
# bomb
# lapilli
# bomb
# ash
# bomb
# block
# lapilli
# block
# ash
# block
# air
# fall
# ash
# flow
# unconsolidated
# surge
# tuffaceous
# silt
# sand
# gravel
# sediment
# clay
# (dry)
# (moistured)
# pebbel
# grus
# debris
# detrital
# strongly
# humus
# ("dry")
# ("moistured")
# normal
# gravel
# gravelly
# pebble
# grus
# grus
# debris
# strong
# gravel
# pebble
# grus
# grus
# debris
# pure
# gravel
# pebble
# grus
# debris
# grus
# grus
# gravely
# grus
# blocks
# block
# block
# blocky
# debris
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate,
# gravel
# carbonate
# carbonate,
# pebble
# carbonate
# carbonate,
# grus
# carbonate
# grus
# carbonate,
# debris
# carbonate
# carbonate
# bearing,
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate,
# gravel
# carbonate
# carbonate,
# pebble
# carbonate
# carbonate,
# grus
# carbonate
# grus
# carbonate,
# debris
# carbonate
# carbonate
# stronly
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate,
# gravel
# carbonate
# carbonate,
# pebble
# carbonate
# carbonate,
# grus
# carbonate
# grus
# carbonate,
# debris
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate,
# gravel
# carbonate
# carbonate,
# pebble
# carbonate
# carbonate,
# grus
# carbonate
# grus
# carbonate,
# debris
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# grus
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# grus
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# grus
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# pebble
# carbonate
# argillaceous
# gravel
# argillaecous
# pebble
# grus
# grus
# debris
# gravel
# pebble
# grus
# grus
# debris
# gravel
# pebble
# grus
# grus
# debris
# gravel
# pebble
# grus
# grus
# debris
# debris
# grus
# sitly
# grus
# debris
# grus
# pebble
# carbonate
# organic
# carbonate
# litter
# decomposed
# turf/
# peat
# lowland
# fen
# turf
# transition
# bog
# upland
# fen
# coaly
# earthy/
# bitumen
# asphalt
# petroleum
# siliceous
# diatomite
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# lowland
# carbonate
# carbonate
# lowland
# carbonate
# carbonate
# artificial
# very
# quartz
# quartz
# quartz
# foid
# foid
# foid
# foid
# foid
# very
# foid
# ultra
# alkali
# feldspar
# quartzalkalifeldsparsyenite
# quartzsyenite
# quartzmonzonite
# quartzmonzodiorite
# quartzmonzogabbro
# quartzdiorite
# quartzgabbro
# quartzanorthosite
# alkalifeldsparsyenite
# olivine
# olivine
# olivine
# orthopyroxene
# clinopyroxene
# hornblende
# pyroxene
# hornblende
# pyroxene
# hornblende
# pyroxene
# hornblende
# foidbearingalkalifeldsparsyenite
# foidbearing
# foidbearing
# foidbearing
# foidbearing
# foidbearing
# foidbearing
# foidbearing
# foidsyenite
# nephelinesyenite)
# foidmonzosyenite
# foidmonzodiorite
# foidmonzogabbro
# foiddiorite
# foidgabbro
# pyroxeneperidotite
# pyroxenehornblendeperidotite
# hornblendeperidotite
# olivine
# olivine
# olivine
# olivine
# olivine
# hornblende
# plagioclase
# plagioclase
# hornblende
# pyroxene
# olivine
# olivine
# pyroxene
# plagioclase
# plagioclase
# pyroxene
# olivine
# pyroxene
# olivine
# pyroxene
# pyroxene
# olivine
# calcite
# dolomite
# ferro
# quartz
# quartz
# foid
# olivine
# alkali
# foid
# very
# foid
# alkalifeldsparrhyolite
# quartzalkalifeldspartrachyte
# quartztrachyte
# alkalifeldspartrachyte
# foidbearingalkalifeldspartrachyte
# foidbearingtrachyte
# quartzlatite
# foidbearing
# olivine
# alkali
# alkali
# amphibole
# leuco
# alkali
# melaandesite
# tephriticphonolite
# phonolitictephrite
# analcim
# amphibole
# phonoliticbasanite
# phonoliticfoidite
# tephriticfoidite
# basaniticfoidite
# melilitenephelinite
# olivine
# melilithite
# calcite
# dolomite
# ferro
# natro
# ultra
# sio2oversaturated
# high
# k
# medium
# k
# low
# k
# high
# k
# medium
# k
# low
# k
# high
# k
# basaltic
# medium
# k
# basaltic
# low
# k
# sio2saturated
# k
# sio2saturated
# subalkali
# high
# alumina
# alkali
# alkali
# olivine
# sio2undersaturated
# tephriphonolite
# phonotephrite
# highmgvolcanics
# alkali
# (ash)
# fine
# ash
# coarse
# ash
# ash
# ash
# ash
# ash
# ash
# bomb
# block
# bomb
# lapilli
# bomb
# ash
# bomb
# block
# lapilli
# block
# ash
# block
# tuffbreccia
# lapilli
# tuff
# ash
# tuff
# airfall
# ashflow
# surge
# ash
# fine
# ash
# coarse
# ash
# crystal
# ash
# lapilli
# ash
# bomb
# ash
# block
# ash
# lapilli
# ash
# lapilli
# bomb
# lapilli
# block
# lapilli
# bomb
# lapilli
# bomb
# ash
# bomb
# block
# lapilli
# block
# ash
# block
# tuff
# lapilli
# tuff
# ash
# tuff
# air
# fall
# ash
# flow
# surge
# ash
# ash
# ash
# crystal
# ash
# lapilli
# ash
# bomb
# ash
# block
# ash
# lapilli
# ash
# lapilli
# bomb
# lapilli
# block
# lapilli
# bomb
# lapilli
# bomb
# ash
# bomb
# block
# lapilli
# block
# ash
# block
# tuff
# lapilli
# tuff
# ash
# tuff
# air
# fall
# ash
# flow
# surge
# ash
# fine
# ash
# coarse
# ash
# crystal
# ash
# lapilli
# ash
# bomb
# ash
# block
# ash
# lapilli
# ash
# lapilli
# bomb
# lapilli
# block
# lapilli
# bomb
# lapilli
# bomb
# ash
# bomb
# block
# lapilli
# block
# ash
# block
# tuff
# lapilli
# tuff
# ash
# tuff
# air
# fall
# ash
# flow
# surge
# ash
# fine
# ash
#
# ash
# crystal
# ash
# lapilli
# ash
# bomb
# ash
# block
# ash
# lapilli
# ash
# lapilli
# bomb
# lapilli
# block
# lapilli
# bomb
# lapilli
# bomb
# ash
# bomb
# block
# lapilli
# block
# ash
# block
# tuff
# lapilli
# tuff
# ash
# tuff
# air
# flow
# ash
# flow
# surge
# ash
# fine
# ash
# coarse
# ash
# crystal
# ash
# lapilli
# ash
# bomb
# ash
# block
# ash
# lapilli
# ash
# lapilli
# bomb
# lapilli
# block
# lapilli
# bomb
# lapilli
# bomb
# ash
# bomb
# block
# lapilli
# block
# ash
# block
# tuff
# lapilli
# tuff
# ash
# tuff
# air
# flow
# ash
# flow
# surge
# ash
# fine
# ash
# coarse
# ah
# ash
# lapilli
# ash
# bomb
# ash
# block
# ash
# lapilli
# lapilli
# ash
# bomb
# lapilli
# block
# lapilli
# bomb
# lapilli
# bomb
# ash
# bomb
# block
# lapilli
# block
# ash
# block
# tuff
# lapilli
# tuff
# ash
# tuff
# air
# fall
# ash
# flow
# surge
# ash
# fine
# ash
# coarse
# ash
# ash
# lapilli
# ash
# bomb
# ash
# block
# ash
# lapilli
# ash
# lapilli
# bomb
# lapilli
# block
# lapilli
# bomb
# lapilli
# block
# ash
# block
# block
# lapilli
# block
# ash
# block
# tuff
# lapilli
# tuff
# ash
# tuff
# air
# fall
# ash
# flow
# surge
# ash
#
# ash
# coarse
# ash
# ash
# lapilli
# ash
# bomb
# ash
# block
# lapilli
# ash
# lapilli
# bomb
# lapilli
# block
# lapilli
# bomb
# lapilli
# bomb
# ash
# bomb
# block
# lapilli
# block
# ash
# block
# tuff
# lapilli
# tuff
# ash
# tuff
# air
# fall
# ash
# flow
# surhe
# deposit
# top
# bottom
# tuffaceousclaystone
# tuffaceoussiltstone
# tuffaceoussandstone
# tuffaceousconglomerate
# tuffaceousbreccia
# quartzrich
# quartzbearing
# foidbearing
# foidrich
# quartzrich
# granite
# granodiorite
# tonalite
# quartz
# quartz
# syenite
# monzonite
# monzodiorite
# diorite
# gabbro
# leucite
# nepheline
# foidrich
# alkali
# alkali
# lamprophyric
# quartz
# carbonate
# feldspar
# baryte
# sulfide
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# garnet
# meta
# garnet
# turmaline
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# alkali
# meta
# meta
# meta
# meta
# meta
# alkali
# alkali
# meta
# meta
# meta
# meta
# meta
# pillow
# pillow
# calcite
# dolomite
# carbonate
# (silica
# carbonate
# carbonate
# carbonate
# quartz
# apatite
# epidote
# garnet
# graphite
# magnetite
# muscovite
# serictite
# albite
# chloritoide
# garnet
# albite
# garnet
# quartz
# sericite
# albite
# andalusite
# apatite
# biotite
# plagioclase
# chlorite
# garnet
# graphite
# muscovite
# chlorite
# muscovite
# biotite
# (two
# sericite
# staurolite
# biotite
# muscovite
# epidote
# hornblende
# plagioclase
# albite
# andalusite
# biotite
# biotite
# cordierit
# biotite
# garnet
# biotite
# plagioclase
# biotite
# muscovite
# biotite
# sillimanite
# cordierit
# disthene
# disthene
# staurolite
# disthene
# sillimanite
# mica
# garnet
# garnet
# biotite
# garnet
# cordierit
# sillimanite
# garnet
# disthene
# garnet
# disthene
# sillimanite
# garnet
# disthene
# staurolite
# garnet
# plagioclase
# graphite
# hornblende
# biotite
# muscovite
# muscovite
# biotite
# muscovite
# biotite
# garnet
# muscovite
# garnet
# pyroxene
# quartz
# biotite
# plagioclase
# staurolite
# garnet
# plagioclase
# granulite
# andalusite
# biotite
# hornblende
# plagioclase
# cordierite
# coround
# hercynite
# actinolite
# biotite
# biotite
# pyroxene
# diopside
# epidote
# garnet
# carbonate
# silicate
# zoisite
# eklogite
# meta
# chlorite
# actinolite
# ultra
# olivine
# sandstone
# pelite
# sandstone
# sandstone
# pelite
# pelite
# sandstone
# pelite
# pelite
# gypsum
# pelite
# gypsum
# pelite
# gypsum
# silicate
# silicate
# (arenite)
# quartz
# quartz
# quartz
# quartz
# subfeldspatic
# subfeldspatic
# subfeldspatic
# subfeldspatic
# feldspatic
# feldspatic
# feldspatic
# feldspatic
# lithic
# lithic
# lithic
# lithic
# quartz
# quartz
# quartz
# quartz
# feldspathic
# feldspethic
# feldspethic
# feldspethic
# lithic
# lithic
# lithic
# grus
# grus
# grus
# grud
# debris
# block
# limestone
# marl
# limestone
# marl
# limestone
# marl
# pelite
# marl
# pelite
# marl
# pelite
# marl
# carbonatebearing
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# dolomite
# dolomite
# dolomite
# dolomite
# dolomite
# dolomite
# dolomite
# dolomite
# dolomite
# fine
# medium
# coarse
# fine
# medium
# coarse
# clay
# lime
# marl
# clay
# limemarl
# dolomite
# marl
# marl
# fine
# medium
# coarse
# fine
# medium
# coarse
# fine
# medium
# coarse
# mud
# grain
# micrite
# intramicrite
# micrite
# oomicrite
# ooid
# biomicrite
# fossile
# micrite
# biopelmicrite
# pelmicrite
# peloid
# micrite
# dismicrite
# sparite
# intrasparite
# sparite
# oosparite
# ooid
# sparite
# biosparite
# fossile
# biopelsparite
# pelsparite
# peloid
# sparite
# fresh
# noncarbonate
# noncarbonate
# mixed
# (silica
# (alaun
# silica
# (silica
# phosphate
# phosphorite
# stubben
# ortho
# ortho
# ortho
# meta
# meta
# meta
# bituminouscoal
# semi
# meta
# boghead
# cannel
# boghead
# cannel
# red
# brown
# spar
# pyrite
# manganese
# phosphate
# aluminia
# nickel
# non
# copper
# lead
# zinc
# ash
# fine
# ash
# coarse
# ash
# ash
# ash
# ash
# ash
# lapilli
# ash
# lapilli
# block
# lapilli
# bomb
# lapilli
# bomb
# lapilli
# bomb
# ash
# bomb
# block
# lapilli
# block
# ash
# block
# air
# fall
# ash
# flow
# surge
# clay
# pebbel
# grus
# debris
# gravel
# pebble
# grus
# grus
# debris
# gravel
# pebble
# grus
# grus
# debris
# gravel
# pebble
# grus
# debris
# grus
# grus
# grus
# block
# block
# debris
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate,
# gravel
# carbonate
# carbonate,
# pebble
# carbonate
# carbonate,
# grus
# carbonate
# grus
# carbonate,
# debris
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate,
# gravel
# carbonate
# carbonate,
# pebble
# carbonate
# carbonate,
# grus
# carbonate
# grus
# carbonate,
# debris
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate,
# gravel
# carbonate
# carbonate,
# pebble
# carbonate
# carbonate,
# grus
# carbonate
# grus
# carbonate,
# debris
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate,
# gravel
# carbonate
# carbonate,
# pebble
# carbonate
# carbonate,
# grus
# carbonate
# grus
# carbonate,
# debris
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# grus
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# grus
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# grus
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# pebble
# carbonate
# gravel
# pebble
# grus
# grus
# debris
# gravel
# pebble
# grus
# grus
# debris
# gravel
# pebble
# grus
# grus
# debris
# gravel
# pebble
# grus
# grus
# debris
# debris
# grus
# grus
# debris
# grus
# pebble
# carbonate
# carbonate
# fen
# fen
# carbonate
# carbonate
# carbonate
# carbonate
# carbonate
# lowland
# carbonate
# carbonate
# lowland
# carbonate
# carbonate

# %%
for i in list_petro:
    for j in i.split():
        if j.lower() not in list_petro:
            list_petro.append(re.sub(r'-','',j.lower()))
        else:
            pass

list_petro_det=[]

for i in list_petro:
    if re.sub(r'[/,"0-9)(]','',i.lower()) not in list_petro_det:
        list_petro_det.append(re.sub(r'[/,"0-9)(]','',i.lower()))
    else:
        pass
    
remove = ["bora",'ah', 'capped','after','educt','chemistry','fabric','content','pillow','black','ribbon','alteration','composite', 'dunham',
          'modal', 'field', 'description', 'very' ,'rich', 'bearing', 'to' ,'foid', 'eg.' ,'chemically' ,'tas', 'k' ,'medium', 'low' ,
          'or', 'slightly', 'fine', 'air', 'fall' ,'flow', ' ' ,'top' ,'bottom' ,'and' ,'of' ,'free', 'milky', 'sorted' ,'two' ,'&' ,
          'embry', 'klovan', 'supported' ,'fresh', 'water', 'mixed', 'humic', 'horizon', 'ortho', 'pitch', 'flaming' ,'gas' ,
          'cooking', 'steam' ,'lean' ,'semi', 'artificial', 'fen' ,'stronly', 'blocky', 'strong' ,'pure' ,'normal', 'detrital' ,
          'moistured', 'dry', 'layering', 'strongly','allothonous', 'folk','fossile','dull','bright','oil','non','decomposed','lowland','upland']
for i in remove:
    try:
        list_petro_det.remove(i)
    except:
        pass
    
for i,j in enumerate(list_petros):
    list_petro_det[i] = re.sub(r'(- |-|qapf|plutonic affinity|field classification|tas|modal|modal/normativ|chemically|epiclastic)',' ', j)

# %%
list_petro_det = list(filter(lambda a: a != ' ', list_petro_det))

# %%
list_petro_det
# Out:
# ['consolidated',
#  'magmatic',
#  'plutonic',
#  'plutonic   field description',
#  'very quartz rich plutonic',
#  'quartz rich granitic plutonic',
#  'quartz rich plutonic',
#  'granitic plutonic',
#  'quartz bearing to foid bearing plutonic',
#  'syenitic plutonic',
#  'dioritic plutonic',
#  'gabbrotic plutonic',
#  'foid rich plutonic',
#  'foid syenitic plutonic',
#  'foid dioritic plutonic',
#  'foid gabbrodic plutonic',
#  'very foid rich plutonic foidolite',
#  'foidolitic plutonic',
#  'ultra mafic plutonic  ',
#  'plutonic    ',
#  'quartzolite  ',
#  'granite  ',
#  'alkali feldspar granite',
#  'syenogranite',
#  'monzogranite',
#  'granodiorite  ',
#  'tonalite  ',
#  'quartz alkali feldspar syenite  ',
#  'quartz syenite  ',
#  'quartz monzonite  ',
#  'quartz monzodiorite  ',
#  'quartz monzogabbro  ',
#  'quartz diorite  ',
#  'quartz gabbro  ',
#  'quartz anorthosite  ',
#  'alkali feldspar syenite  ',
#  'syenite  ',
#  'monzonite  ',
#  'monzodiorite  ',
#  'monzogabbro  ',
#  'diorite  ',
#  'gabbro  ',
#  'gabbronorite',
#  'norite',
#  'troctolite',
#  'olivine gabbro',
#  'olivine gabbronorite',
#  'olivine norite',
#  'orthopyroxene gabbro',
#  'clinopyroxene norite',
#  'hornblende gabbro',
#  'pyroxene hornblende gabbro',
#  'pyroxene hornblende gabbronorite',
#  'pyroxene hornblende norite',
#  'anorthosite  ',
#  'foid bearing alkali feldspar syenite  ',
#  'foid bearing syenite  ',
#  'foid bearing monzonite  ',
#  'foid bearing monzodiorite  ',
#  'foid bearing monzogabbro  ',
#  'foid bearing diorite  ',
#  'foid bearing gabbro  ',
#  'foid bearing anorthosite  ',
#  'foid syenite eg. nepheline syenite  ',
#  'malignite',
#  'shoncinite',
#  'foid monzosyenite  ',
#  'foid monzodiorite  ',
#  'foid monzogabbro  ',
#  'foid diorite  ',
#  'foid gabbro  ',
#  'nephelinolite  ',
#  'urtite',
#  'ijolite',
#  'melteigite',
#  'leucitolite  ',
#  'italite',
#  'fergustite',
#  'missourite',
#  'ultramafic plutonics',
#  'peridotite',
#  'dunite',
#  'harzburgite',
#  'lherzolite',
#  'wehrlite',
#  'pyroxene peridotite',
#  'pyroxene hornblende peridotite',
#  'hornblende peridotite',
#  'pyroxenite',
#  'orthopyroxenite',
#  'olivine orthopyroxenite',
#  'websterite',
#  'olivine websterite',
#  'klinopyroxenite',
#  'olivine klinopyroxenite',
#  'olivine pyroxenite',
#  'olivine hornblende pyroxenite',
#  'plagioclase bearing pyroxenite',
#  'plagioclase bearing hornblende pyroxenite',
#  'hornblendite',
#  'pyroxene hornblendite',
#  'olivine hornblendite',
#  'olivine pyroxene hornblendite',
#  'plagioclase bearing hornblendite',
#  'plagioclase bearing pyroxene hornblendite',
#  'ultramafic melilitic plutonic',
#  'melilolite',
#  'olivine melilitolite',
#  'pyroxene melilitolite',
#  'olivine pyroxene melilitolite',
#  'pyroxene olivine melililolite',
#  'carbonatite plutonic',
#  'calcite carbonatite  ',
#  'dolomite carbonatite  ',
#  'ferro carbonatite  ',
#  'charnockite plutonic',
#  'volcanic',
#  'volcanic  ',
#  'quartz rich volcanic',
#  'rhyolitic volcanic',
#  'dacitic volcanic',
#  'quartz to foid bearing volcanic',
#  'trachytic volcanic',
#  'latitic volcanic',
#  'basaltic volcanic',
#  'tholeiitic volcanic',
#  'olivine basaltic volcanic',
#  'alkali basaltic volcanic',
#  'andesitic volcanic',
#  'foid rich volcanic',
#  'phonolitic volcanic',
#  'tephritic volcanic',
#  'basanitic volcanic',
#  'very foid rich volcanic',
#  'foiditic volcanic',
#  'ultramafic volcanic  ',
#  'volcanic  normativ',
#  'alkali feldspar rhyolite  ',
#  'rhyolite  ',
#  'rhyodacite  ',
#  'dacite  ',
#  'obsidian',
#  'quartz alkali feldspar trachyte  ',
#  'quartz trachyte  ',
#  'alkali feldspar trachyte  ',
#  'trachyte  ',
#  'foid bearing alkali feldspar trachyte  ',
#  'foid bearing trachyte  ',
#  'quartz latite  ',
#  'latite  ',
#  'foid bearing latite  ',
#  'basalt  ',
#  'tholeitic basalt',
#  'olivine basalt',
#  'alkali basalt',
#  'alkali basalt amphibole bearing',
#  'leucobasalt  ',
#  'leuco alkali basalt',
#  'andesite  ',
#  'mela andesite  ',
#  'phonolite  ',
#  'tephritic phonolite  ',
#  'tephrite  ',
#  'phonolitic tephrite  ',
#  'basanite  ',
#  'limburgite',
#  'basanite analcim rich',
#  'basanite amphibole bearing',
#  'phonolitic basanite  ',
#  'phonolitic foidite  ',
#  'tephritic foidite  ',
#  'basanitic foidite  ',
#  'foidite  ',
#  'nephelinite  ',
#  'melilite nephelinite  ',
#  'analcimite  ',
#  'leucitite  ',
#  'ultramafic volcanic ',
#  'melilithite',
#  'olivine melilithite',
#  'melilithite bearing ultramafic',
#  'carbonatite',
#  'calcite carbonatite',
#  'dolomite carbonatite',
#  'ferro carbonatite',
#  'natro carbonatite',
#  'volcanic  ',
#  'acidic volcanic',
#  'intermediate volcanic',
#  'basic volcanics',
#  'ultra basic',
#  'sio oversaturated volcanic  ',
#  'rhyolite  ',
#  'comenditic rhyolite comendite',
#  'pantelleritic rhyolite pantellerite',
#  'trachydacite  ',
#  'dacite  ',
#  'high k dacite  ',
#  'medium k dacite  ',
#  'low k dacite  ',
#  'andesite  ',
#  'high k andesite  ',
#  'medium k andesite  ',
#  'low k andesite  ',
#  'basaltic andesite  ',
#  'high k basaltic andesite  ',
#  'medium k basaltic andesite  ',
#  'low k basaltic andesite  ',
#  'sio saturated volcanic  ',
#  'trachyte  ',
#  'trachite  ',
#  'peralkalic trachyte  ',
#  'comenditic trachyte  ',
#  'pantellitic trachyte  ',
#  'trachyandesite  ',
#  'benmoreite  ',
#  'latite  ',
#  'basaltic trachyandesite  ',
#  'mugearite  ',
#  'shoshonite  ',
#  'trachybasalt  ',
#  'hawaiite  ',
#  'k trachybasalt  ',
#  'sio saturated or slightly undersaturated volcanic  ',
#  'basalt  ',
#  'subalkali basalt  ',
#  'tholeitic basalt  ',
#  'high alumina basalt  ',
#  'alkali basalt  ',
#  'alkali olivine basalt  ',
#  'sio undersaturated volcanic  ',
#  'phonolite  ',
#  'tephri phonolite  ',
#  'phono tephrite  ',
#  'tephrite  ',
#  'basanite  ',
#  'picrobasalt  ',
#  'foidite  ',
#  'nephelinite  ',
#  'high mg volcanics  ',
#  'boninite  ',
#  'picritic volcanic  ',
#  'picrite  ',
#  'comatiite  ',
#  'meimechite  ',
#  'volcaniclastic',
#  'volcaniclastics  ',
#  'rhyolitic volcaniclast',
#  'dacitic volcaniclast',
#  'trachytic volcaniclast',
#  'andesitic volcaniclast',
#  'basaltic volcaniclast',
#  'alkali basaltic volcaniclast',
#  'tholeitic volcaniclast',
#  'phonolitic volcaniclast',
#  'tephritic volcaniclast',
#  'basanitic volcaniclast',
#  'foiditic volcaniclast',
#  'pyroclastics',
#  'pyroclastic undefined',
#  'ash tuff ',
#  'fine grained ash tuff',
#  'coarse grained ash tuff',
#  'crystal ash tuff',
#  'lapilli ash tuff',
#  'bomb ash tuff',
#  'block ash tuff',
#  'lapillistone',
#  'ash lapillistone',
#  'bomb lapillistone',
#  'block lapillistone',
#  'agglomerate',
#  'bomb tuff',
#  'lapilli bomb tuff',
#  'ash bomb tuff',
#  'agglutinate',
#  'pyroclastic breccia',
#  'block tuff',
#  'lapilli block tuff',
#  'ash block tuff',
#  'tuff breccia',
#  'lapilli tuff breccia',
#  'ash tuff breccia',
#  'air fall deposit consolidated',
#  'ash flow deposit consolidated',
#  'ignimbrite consolidated',
#  'ignimbrite welded',
#  'ignimbrite unwelded consolidated',
#  'surge deposit consolidated',
#  'peperite',
#  'pyroclastic rhyolitic',
#  'rhyolitic ash tuff',
#  'fine grained ash tuff rhyolitic',
#  'coarse grained ash tuff rhyolitic',
#  'rhyolitic crystal ash tuff',
#  'rhyolitic lapilli ash tuff',
#  'rhyolitic bomb ash tuff',
#  'rhyolitic block ash tuff',
#  'rhyolitic lapilli tuff',
#  'rhyolitic ash lapilli tuff',
#  'rhyolitic bomb lapilli tuff',
#  'rhyolitic block lapilli tuff',
#  'rhyolitic agglomerate',
#  'rhyolitic bomb tuff',
#  'rhyolitic lapilli bomb tuff',
#  'rhyolitic ash bomb tuff',
#  'rhyolitic agglutinate',
#  'pyroclastoc breccia rhyolitic',
#  'rhyolitic block tuff',
#  'rhyolitic lapilli block tuff',
#  'rhyolitic ash block tuff',
#  'rhyolitic tuff breccia',
#  'rhyolitic lapilli tuff breccia',
#  'rhyolitic ash tuff breccia',
#  'rhyolitic air fall deposit consolidated',
#  'rhyolitic ash flow deposit consolidated',
#  'rhyolitic ignimbrite consolidated',
#  'rhyolitic ignimbrite welded',
#  'rhyolitic ignimbrite unwelded consolidated',
#  'rhyolitic surge deposit',
#  'rhyolitic peperite',
#  'pyroclastic dacitic',
#  'dacitic ash tuff',
#  'fine grained ash tuff dacitic',
#  'coarse grained ash tuff dacitic',
#  'dacitic crystal ash tuff',
#  'dacitic lapilli ash tuff',
#  'dacitic bomb ash tuff',
#  'dacitic block ash tuff',
#  'dacitic lapilli tuff',
#  'dacitic ash lapilli tuff',
#  'dacitic bomb lapilli tuff',
#  'dacitic block lapilli tuff',
#  'dacitic agglomerate',
#  'dacitic bomb tuff',
#  'dacitic lapilli bomb tuff',
#  'dacitic ash bomb tuff',
#  'dacitic agglutinate',
#  'pyroclastic breccia dacitic',
#  'dacitic block tuff',
#  'dacitic lapilli block tuff',
#  'dacitic ash block tuff',
#  'dacitic tuff breccia',
#  'dacitic lapilli tuff breccia',
#  'dacitic ash tuff breccia',
#  'dacitic air fall deposit consolidated',
#  'dacitic ash flow deposit consolidated',
#  'dacitic ignimbrite consolidated',
#  'dacitic ignimbrite welded',
#  'dacitic ignimbrite unwelded consolidated',
#  'dacitic surge deposit consolidated',
#  'dacitic peperite',
#  'pyroclastic trachytic',
#  'trachytic ash tuff',
#  'fine grained trachytic ash tuff',
#  'coarse grained trachytic ash tuff',
#  'trachytic crystal ash tuff',
#  'trachytic lapilli ash tuff',
#  'trachytic bomb ash tuff',
#  'trachytic block ash tuff',
#  'trachytic lapilli tuff',
#  'trachytic ash lapilli tuff',
#  'trachytic bomb lapilli tuff',
#  'trachytic block lapilli tuff',
#  'trachytic agglomerate',
#  'trachytic bomb tuff',
#  'trachytic lapilli bomb tuff',
#  'trachytic ash bomb tuff',
#  'trachytic agglutinate',
#  'pyroclastic breccia trachytic',
#  'trachytic block tuff',
#  'trachytic lapilli block tuff',
#  'trachytic ash block tuff',
#  'trachytic tuff breccia',
#  'trachytic lapilli tuff breccia',
#  'trachytic ash tuff breccia',
#  'trachytic air fall deposit consolidated',
#  'trachytic ash flow deposit consolidated',
#  'trachytic ignimbrite consolidated',
#  'trachytic ignimbrite welded',
#  'trachytic ignimbrite unwelded consolidated',
#  'trachytic surge deposit consolidated',
#  'trachytic peperite',
#  'pyroclastic latitic ',
#  'latitic ash tuff',
#  'fine grained latitic ash tuff',
#  'coarse  grained latitic ash tuff',
#  'latitic crystal ash tuff',
#  'latitic lapilli ash tuff',
#  'latitic bomb ash tuff',
#  'latitic block ash tuff',
#  'latitic lapilli tuff',
#  'latitic ash lapilli tuff',
#  'latitic bomb lapilli tuff',
#  'latitic block lapilli tuff',
#  'latitic agglomerate',
#  'latitic bomb tuff',
#  'latitic lapilli bomb tuff',
#  'latitic ash bomb tuff',
#  'latitic aggglutinate',
#  'pyroclastic breccia latitic',
#  'latitic block tuff',
#  'latitic lapilli block tuff',
#  'latitic ash block tuff',
#  'latitic tuff breccia',
#  'latitic lapilli tuff breccia',
#  'latitic ash tuff breccia',
#  'latitic air flow deposit consolidated',
#  'latitic ash flow deposit consolidated',
#  'latitic ignimbrite consolidated',
#  'latitic ignimbrite welded',
#  'latitic ignimbrite unwelded consolidated',
#  'latitic surge deposit consolidated',
#  'latitic peperite',
#  'pyroclastic andesitic',
#  'andesitic ash tuff',
#  'fine grained andesitic ash tuff',
#  'coarse grained andesitic ash tuff',
#  'andesitic crystal ash tuff',
#  'andesitic lapilli ash tuff',
#  'andesitic bomb ash tuff',
#  'andesitic block ash tuff',
#  'andesitic lapilli tuff',
#  'andesitic ash lapilli tuff',
#  'andesitic bomb lapilli tuff',
#  'andesitic block lapilli tuff',
#  'andesitic agglomerate',
#  'andesitic bomb tuff',
#  'andesitic lapilli bomb tuff',
#  'andesitic ash bomb tuff',
#  'andesitic agglutinate',
#  'pyroclastic breccia andesitic',
#  'andesitic block tuff',
#  'andesitic lapilli block tuff',
#  'andesitic ash block tuff',
#  'andesitic tuff breccia',
#  'andesitic lapilli tuff breccia',
#  'andesitic ash tuff breccia',
#  'andesitic air flow deposit consolidated',
#  'andesitic ash flow deposit consolidated',
#  'andesitic ignimbrite consolidated',
#  'andesitic ignimbrite welded',
#  'andesitic ignimbrite unwelded consolidated',
#  'andesitic surge deposit consolidated',
#  'andesitic peperite',
#  'pyroclastic basaltic',
#  'basaltic ash tuff',
#  'fine grained ash tuff basaltic',
#  'coarse grained ah tuff basaltic',
#  'basaltic crystal ash tuff',
#  'basaltic lapilli ash tuff',
#  'basaltic bomb ash tuff',
#  'basaltic block ash tuff',
#  'basaltic lapilli tuff',
#  'basaltic crystal lapilli tuff',
#  'basaltic ash lapilli tuff',
#  'basaltic bomb lapilli tuff',
#  'basaltic block lapilli tuff',
#  'basaltic agglomerate',
#  'basaltic bomb tuff',
#  'basaltic lapilli bomb tuff',
#  'basaltic ash bomb tuff',
#  'basaltic agglutinate',
#  'pyroclastic breccia consolidated',
#  'basaltic block tuff',
#  'basaltic lapilli block tuff',
#  'basaltic ash block tuff',
#  'basaltic tuff breccia',
#  'basaltic lapilli tuff breccia',
#  'basaltic ash tuff breccia',
#  'basaltic air fall deposit consolidated',
#  'basaltic ash flow deposit consolidated',
#  'basaltic ignimbrite consolidated',
#  'basaltic surge deposit consolidated',
#  'basaltic peperite',
#  'pyroclastic phonolitic',
#  'phonolitic ash tuff',
#  'fine grained ash tuff phonolitic',
#  'coarse grained ash tuff phonolitic',
#  'phonolitic crystal ash tuff',
#  'phonolitic lapilli ash tuff',
#  'phonolitic bomb ash tuff',
#  'phonolitic block ash tuff',
#  'phonolitic lapilli tuff',
#  'phonlitic ash lapilli tuff',
#  'phonolitic bomb lapilli tuff',
#  'phonolitic block lapilli tuff',
#  'phonolitic agglomerate',
#  'phonolitic bomb tuff',
#  'phonolitic lapilli block tuff',
#  'phonolitic ash block tuff',
#  'phonolitic agglutinate',
#  'pyroclastic breccia phonolitic',
#  'phonolitic block tuff',
#  'phonolitic tuff breccia',
#  'phonolitic lapilli tuff breccia',
#  'phonolitic ash tuff breccia',
#  'phonolitic air fall deposit consolidated',
#  'phonolitic ash flow deposit consolidated',
#  'phonolitic ignimbrite consolidated',
#  'phonolitic ignimbrite welded',
#  'phonolitic ignimbrite unwelded consolidated',
#  'phonolitic surge deposit consolidated',
#  'phonolitic peperite',
#  'pyroclastic basanitic',
#  'basanitic ash tuff',
#  'fine  grained ash tuff basanitic',
#  'coarse grained ash tuff basanitic',
#  'basanitic crystall ash tuff',
#  'basanitic lapilli ash tuff',
#  'basanitic bomb ash tuff',
#  'basanitic block ash tuff',
#  'basanitic lapilli tuff',
#  'basanitic ash lapilli tuff',
#  'basanitic bomb lapilli tuff',
#  'basanitic block lapilli tuff',
#  'basanitic agglomerate',
#  'basanitic bomb tuff',
#  'basanitic lapilli bomb tuff',
#  'basanitic ash bomb tuff',
#  'basanitic agglutinate',
#  'pyroclastic breccia basanitic',
#  'basanitic block tuff',
#  'basanitic lapilli block tuff',
#  'basanitic ash block tuff',
#  'basanitic tuff breccia',
#  'basanitic lapilli tuff breccia',
#  'basanitic ash tuff breccia',
#  'basanitic air fall deposit consolidated',
#  'basanitic ash flow deposit consolidated',
#  'basanitic ignimbrite consolidated',
#  'basanitic ignimbrite unwelded consolidated',
#  'basanitic surhe deposit consolidated',
#  'basanitic peperite',
#  'autoclastic volcaniclast',
#  'top breccia',
#  'bottom breccia',
#  'tuffite',
#  'tuffaceous claystone',
#  'tuffaceous siltstone',
#  'tuffaceous sandstone',
#  'tuffaceous conglomerate',
#  'tuffaceous breccia',
#  'volcaniclastic sedimentary  ',
#  'volcaniclastic claystone',
#  'volcaniclastic siltstone',
#  'volcaniclastic sandstone',
#  'volcaniclastic conglomerate',
#  'volcaniclastic breccia',
#  'lahar consolidated',
#  'volcanic and volcaniclastic structureless',
#  'dyke ',
#  'dyke    ',
#  'quartz rich dyke',
#  'quartz bearing to foid bearing dyke',
#  'foid rich dyke',
#  'dolerite  ',
#  'lamprophyr  ',
#  'dyke   ',
#  'pegmatite granitoidic composition',
#  'quartz rich aplite',
#  'granite aplite',
#  'granodiorite aplite',
#  'tonalite aplite',
#  'dykes´ granite',
#  'dykes´ granodiorite',
#  'dykes´ tonalite',
#  'microgranite',
#  'microgranodiorite',
#  'microtonalite',
#  'granophyr',
#  'porphyritic granite',
#  'porphyritic granodiorite',
#  'porphyritic tonalite',
#  'pegmatite of nephelinitic composition',
#  'quartz bearing to quartz free aplite',
#  'syenite aplite',
#  'monzonite aplite',
#  'monzodiorite aplite',
#  'diorite aplite',
#  'gabbro aplite',
#  'dykes´ syenite',
#  'dykes´ monzonite',
#  'dykes´ monzodiorite',
#  'dykes´ diorite',
#  'dykes´ gabbro',
#  'microsyenite',
#  'micromonzonite',
#  'micromonzodiorite',
#  'microdiorite',
#  'microgabbro',
#  'porphyric syenite',
#  'porphyric monzonite',
#  'porphyric monzodiorite',
#  'porphyric diorite',
#  'porphyric gabbro',
#  'dolerite diabase',
#  'alkalibasaltic dolerite',
#  'leucite nepheline dolerite',
#  'theoleitic dolerite',
#  'fioditic dyke',
#  'lamprophyre',
#  'minette',
#  'kersanite',
#  'vogesite',
#  'spessartite',
#  'alkali lamprophyre',
#  'camptonite',
#  'sannaite',
#  'monchiquite',
#  'fourchite',
#  'ultrabasic alkali lamprophyr',
#  'quachitite',
#  'melilitic lamprophyr',
#  'alnoite',
#  'polzenite',
#  'lamprophyric carbonatic dyke',
#  'kimberlite',
#  'carbonatic kimberlite',
#  'hydrothermal gangue mineralization',
#  'quartz rich gangue mineralization',
#  'milky quartz mineral aggregate',
#  'capped quartz mineral aggregate',
#  'pseudomorphosic quartz mineral aggregate',
#  'carbonate rich gangue mineralization',
#  'calcite mineral aggregate',
#  'feldspar rich gangue mineralization',
#  'feldspar mineral aggregate',
#  'baryte rich gangue mineralization',
#  'baryte mineral aggregate',
#  'sulfide rich gangue mineralization',
#  'metamorphic',
#  'metamorphic after educt',
#  'meta sedimentary',
#  'meta pelite',
#  'hornfels',
#  'buchite',
#  'silicic',
#  'silicic schist',
#  'meta psammite',
#  'meta arkose',
#  'meta graywacke',
#  'meta psephite',
#  'meta conglomerate',
#  'meta igneous',
#  'meta plutonite',
#  'meta granite',
#  'meta granodiorite',
#  'meta diorite',
#  'meta gabbro',
#  'metamorphic dyke',
#  'meta aplite',
#  'garnet meta aplite',
#  'garnet turmaline meta aplite',
#  'meta pegmatite',
#  'meta dolerite',
#  'alkalibasaltic meta dolerite',
#  'tholeitic meta dolerite',
#  'meta volcanic',
#  'meta rhyolite',
#  'peralkaline meta rhyolite',
#  'meta rhyodacite',
#  'meta dacite',
#  'meta trachyte',
#  'meta basalt',
#  'meta basalt sorted',
#  'meta alkali basalt',
#  'tholeitic meta basalt',
#  'meta andesite',
#  'meta phonolite',
#  'meta basanite',
#  'meta pikrite',
#  'meta volcaniclastic',
#  'rhyolitic meta volcaniclastic',
#  'rhyodacitic meta volcaniclastic',
#  'dacitic meta volcaniclastic',
#  'trachytic meta volcaniclastic',
#  'andesitic meta volcaniclastic',
#  'basaltic meta volcaniclastic',
#  'alkali basaltic meta volcaniclastic',
#  'tholeitic meta volcaniclastic',
#  'phonolitic meta volcaniclastic',
#  'basanitic meta volcaniclastic',
#  'meta pyroclastic',
#  'rhyolitic meta pyroclastic',
#  'rhyodacitic meta pyroclastic',
#  'dacitic meta pyroclastic',
#  'trachytic meta pyroclastic',
#  'andesitic meta pyroclastic',
#  'basaltic meta pyroclastic',
#  'alkali basaltic meta pyroclastic',
#  'basanitic meta pyroclastic',
#  'meta tuffite',
#  'tuffitic meta pelite',
#  'tuffitic meta psammite',
#  'tuffitic meta conglomerate',
#  'autoclastic meta volcaniclastic',
#  'autoclastic hydroclastic meta volcaniclastic',
#  'pillow breccia',
#  'pillow fragment breccia',
#  'hydroclastic',
#  'volcaniclastic meta sedimentary  ',
#  'metamorphic after chemistry fabric mineral content',
#  'metacarbonate',
#  'marble',
#  'marble sorted',
#  'calcite marble',
#  'dolomite marble',
#  'carbonate silicate marble silica marble',
#  'metamorphic carbonate silicate',
#  'carbonate phyllite',
#  'carbonate silicate coarse',
#  'quartz rich metamorphic',
#  'quartzite',
#  'apatite quartzite',
#  'epidote quartzite',
#  'garnet quartzite',
#  'graphite quartzite',
#  'magnetite quartzite',
#  'muscovite quartzite',
#  'serictite quartzite',
#  'metafelsics',
#  'phyllite',
#  'albite phyllite',
#  'chloritoide phyllite',
#  'garnet albite phyllite',
#  'garnet phyllite',
#  'quartz phyllite',
#  'sericite phyllite',
#  'mica schist',
#  'albite mica schist',
#  'andalusite mica schist',
#  'apatite mica schist',
#  'biotite plagioclase mica schist',
#  'chlorite mica schist',
#  'garnet mica schist',
#  'graphite mica schist',
#  'muscovite chlorite mica schist',
#  'muscovite biotite mica schist two mica schist',
#  'sericite mica schist',
#  'staurolite biotite muscovite mica schist',
#  'gneiss',
#  'epidote hornblende plagioclase gneiss',
#  'albite gneiss',
#  'andalusite gneiss',
#  'biotite gneiss',
#  'biotite cordierit gneiss',
#  'biotite garnet gneiss',
#  'biotite plagioclase gneiss',
#  'biotite muscovite gneiss',
#  'biotite sillimanite gneiss',
#  'cordierit gneiss',
#  'disthene gneiss',
#  'disthene staurolite gneiss',
#  'disthene sillimanite gneiss',
#  'mica gneiss',
#  'garnet gneiss',
#  'garnet biotite gneiss',
#  'garnet cordierit sillimanite gneiss',
#  'garnet disthene gneiss',
#  'garnet disthene sillimanite gneiss',
#  'garnet disthene staurolite gneiss',
#  'garnet plagioclase gneis',
#  'graphite gneiss',
#  'hornblende biotite gneiss',
#  'muscovite gneiss',
#  'muscovite biotite gneiss',
#  'muscovite biotite garnet gneiss',
#  'muscovite garnet gneiss',
#  'pyroxene gneiss',
#  'quartz biotite plagioclase gneiss',
#  'staurolite garnet plagioclase gneiss',
#  'metafelsic granulite',
#  'granulite',
#  'granulite gneiss',
#  'charnockite metamorphic affinity',
#  'acidic to intermediate hornfels',
#  'andalusite hornfels',
#  'biotite hornblende plagioclase hornfels',
#  'cordierite hornels',
#  'coround hercynite hornfels',
#  'metamafics',
#  'greenschist',
#  'actinolite schist',
#  'prasinite',
#  'amphibolite',
#  'biotite amphibolite',
#  'biotite pyroxene amphibolite',
#  'diopside amphibolite',
#  'epidote amphibolite',
#  'garnet amphibolite',
#  'carbonate silicate amphibolite',
#  'zoisite amphibolite',
#  'eklogite amphibolite',
#  'metamafic granulite',
#  'eclogite',
#  'metamafic hornfels',
#  'meta ultramafic',
#  'chlorite actinolite schist',
#  'talcum schist',
#  'serpentinite',
#  'ultra mafic hornfels',
#  'olivine fels',
#  'tectonite',
#  'cataclast',
#  'fault breccia',
#  'melange',
#  'schist',
#  'slate slaty metamudstone',
#  'black shale',
#  'alum shale',
#  'ribbon slate',
#  'silty schist',
#  'mylonite',
#  'migmatite',
#  'anatexite',
#  'metatexite',
#  'diatexite',
#  'syntexite',
#  'sedimentary',
#  'siliciclastic sedimentary',
#  'sandstone pelite alternation',
#  'sandstone dominated sandstone pelite alternation',
#  'pelite dominated sandstone pelite alternation',
#  'pelite gypsum alternation',
#  'pelite dominated pelite gypsum alternation',
#  'gypsum dominated pelite gypsum alternation',
#  'pelite',
#  'silicate claystone',
#  'silicate siltstone',
#  'sapropelite',
#  'psammitearenite',
#  'arenite sandstone',
#  'fine sandstone',
#  'medium sandstone',
#  'coarse sandstone',
#  'quartz arenite',
#  'fine quartz arenite',
#  'medium quartz arenite',
#  'coarse quartz arenite',
#  'subfeldspatic arenite  feldspatic sandstone',
#  'fine subfeldspatic arenite',
#  'medium subfeldspatic arenite',
#  'coarse subfeldspatic arenite',
#  'feldspatic arenite',
#  'fine feldspatic arenite',
#  'medium feldspatic arenite',
#  'coarse feldspatic arenite',
#  'arkose',
#  'fine arkose',
#  'medium arkose',
#  'coarse arkose',
#  'sublitharenite',
#  'fine sublitharenite',
#  'medium sublitharenite',
#  'coarse sublitharenite',
#  'litharenite',
#  'fine litharenite',
#  'medium litharenite',
#  'coarse litharenite',
#  'lithic arenite',
#  'fine lithic arenite',
#  'medium lithic arenite',
#  'coarse lithic arenite',
#  'graywacke wacke',
#  'fine graywacke',
#  'medium graywacke',
#  'coarse graywacke',
#  'quartz wacke',
#  'fine quartz wacke',
#  'medium quartz wacke',
#  'coarse quartz wacke',
#  'feldspathic wacke',
#  'fine feldspethic wacke',
#  'medium feldspethic wacke',
#  'coarse feldspethic wacke',
#  'lithic wacke',
#  'fine lithic wacke',
#  'medium lithic wacke',
#  'coarse lithic wacke',
#  'psephite',
#  'conglomerate',
#  'pebbly conglomerate',
#  'fine pebble granule',
#  'medium to coarse pebble',
#  'very coarse pebble',
#  'cobbles',
#  'boulders',
#  'breccia',
#  'grus breccia',
#  'fine grus breccia',
#  'medium grus breccia',
#  'coarse grud breccia',
#  'debris breccia',
#  'block debris breccia',
#  'carbonatic sedimentary',
#  'carbonatic siliciclastic sedimentary',
#  'limestone marl alteration',
#  'limestone dominated limestone marl alteration',
#  'marl dominated limestone marl alteration',
#  'pelite marl alteration',
#  'pelite dominated pelite marl alteration',
#  'marol dominated pelite marl alteration',
#  'carbonate bearing siliciclastic',
#  'carbonate bearing claystone',
#  'carbonate bearing mudstone',
#  'carbonate bearing sandstone',
#  'carbonate bearing fine sandstone',
#  'carbonate bearing medium sandstone',
#  'carbonate bearing coarse sandstone',
#  'carbonate bearing conglomerate',
#  'carbonate bearing breccia',
#  'dolomite bearing siliciclastic',
#  'dolomite bearing claystone',
#  'dolomite bearing mudstone',
#  'dolomite bearing sandstone',
#  'dolomite bearing fine sandstone',
#  'dolomite bearing medium sandstone',
#  'dolomite bearing coarse sandstone',
#  'dolomite bearing conglomerate',
#  'dolomite bearing breccia',
#  'carbonatic siliciclastic',
#  'carbonatic claystone',
#  'carbonatic mudstone',
#  'carbonatic sandstone',
#  'carbonatic fine sandstone',
#  'carbonatic medium sandstone',
#  'carbonatic coarse sandstone',
#  'carbonatic conglomerate',
#  'carbonatic breccia',
#  'dolomitic siliciclastic',
#  'dolomitic claystone',
#  'dolomitic mudstone',
#  'dolomitic sandstone',
#  'dolomitic fine sandstone',
#  'dolomitic medium sandstone',
#  'dolomitic coarse sandstone',
#  'dolomitic conglomerate',
#  'dolomitic breccia',
#  'siliciclastic limestone',
#  'clayey limestone',
#  'muddy limestone',
#  'sandy limestone',
#  'fine sandy limestone',
#  'medium sandy limestone',
#  'coarse sandy limestone',
#  'conglomeratic limestone',
#  'brecciatic limestone',
#  'siliciclastic dolimite',
#  'clayey dolomite',
#  'muddy dolomite',
#  'sandy dolomite',
#  'fine sandy dolomite',
#  'medium sandy dolomite',
#  'coarse sandy dolomite',
#  'conglomeratic dolomite',
#  'brecciatic dolomite',
#  'clay lime composite',
#  'marly claystone',
#  'marl claystone',
#  'clay marl',
#  'marl',
#  'lime marl',
#  'dolomite marl',
#  'marl limestone',
#  'marl dolomite',
#  'marly limestone',
#  'marly dolomite',
#  'carbonate',
#  'clastic sedimentary carbonate',
#  'lutite',
#  'siltite',
#  'arenite',
#  'fine grained arenite',
#  'medium grained arenite',
#  'coarse grained arenite',
#  'ooidlothic',
#  'oncolithic',
#  'rudite',
#  'dolomite',
#  'dolomitic lutite',
#  'dolomitic siltite',
#  'dolomitic arenite',
#  'fine grained dolomitic arenite',
#  'medium grained dolomitic arenite',
#  'coarse grained dolomitic arenite',
#  'dolomitic rudite',
#  'limestone',
#  'calcitic lutite',
#  'calcitic siltite',
#  'calcitic arenite',
#  'fine grained calcitic arenite',
#  'medium grained calcitic arenite',
#  'coarse grained calcitic arenite',
#  'calcitic rudite',
#  'carbonate of dunham  and embry & klovan ',
#  'allothonous limestone',
#  'mud supported limestone',
#  'mudstone',
#  'wackstone',
#  ...]

# %%
with open ('list_petrography.txt', 'w') as f:
    for item in list_petro_det:
        f.write(str(item) + '\n')

# %% [markdown]
# ## P3 Data (Method)

# %%
df = pd.read_excel('C:/Users/Ryan Bobby A/Documents/RWTH AACHEN/KULIAH/THESIS_BISMILLAH/Thesis Progress/Target Data/Method_P3.xlsx')

# %%
df.head()
# Out:
#   Unnamed: 0                      Reference           Unnamed: 2  \
# 0  Sample ID  Primary Reference (Bibtexkey)  Secondary Reference
#
#       Unnamed: 3 Sampling Point              Unnamed: 5     Unnamed: 6  \
# 0  Date of Input  Location Type  Original Location Type  Location name
#
#   Unnamed: 7    Unnamed: 8      Unnamed: 9  ...                Unnamed: 277  \
# 0    Country  State/Region  Name Shapefile  ...  help indice for saturation
#
#                         Unnamed: 278                   Unnamed: 279  \
# 0  indice for measurement conditions  Indice Measurement conditions
#
#   Quality indice Measurement Parameter        Unnamed: 281  \
# 0         Indice Measurement parameter  help indice values
#
#                  Unnamed: 282               Unnamed: 283  \
# 0  N = Single (0) or Mean (1)  help indice values 1 (SD)
#
#                     Unnamed: 284   Value Quality index Class Quality index
# 0  help indice values 2 (MinMax)  Quality index values       Quality index
#
# [1 rows x 287 columns]

# %%
list_method = df.loc[0,:].values.tolist()
list_method
# Out:
# ['Sample ID',
#  'Primary Reference (Bibtexkey)',
#  'Secondary Reference',
#  'Date of Input',
#  'Location Type',
#  'Original Location Type',
#  'Location name',
#  'Country',
#  'State/Region',
#  'Name Shapefile',
#  'Location longitude (decimaldegree.minutes)',
#  'Location latitude (decimaldegree.minutes)',
#  'Location elevation Z (m a.s.l.)',
#  'Radius of Uncertainty (km)',
#  'Sample type',
#  'Original sample ID',
#  'International Geo Sample Number (IGSN)',
#  'Sample length (m)',
#  'Sample height (m)',
#  'Sample width (m)',
#  'Sample diameter (for cores)\n(m)',
#  ' Sample longitude (decimaldegrees.minutes)',
#  ' Sample latitude (decimaldegrees.minutes)',
#  ' Sample depth Z (MD) (m below location elevation)',
#  'Sample depth Z (TVD) (m below location elevation)',
#  'Rock Classification ID',
#  'Rock Classification Parent ID',
#  'Rock Classification ID 2nd Level',
#  'Rock Classification ID Rank',
#  'Petrographic term',
#  'Petrography (in detail, original)',
#  'Petrographic methods',
#  'Sample texture',
#  'Homogeneous / Inhomogenous',
#  'Layering',
#  'Direction of measurement',
#  'Consolidated / Unconsolidated',
#  'Degree of Alteration / Weathering',
#  'Remarks on sample',
#  'Stratigraphic ID',
#  'Stratigraphic Parent ID',
#  'Chronostratigraphical Unit',
#  'Local/Regional stratigraphic unit (original stratigraphy)',
#  'Temperature (K)',
#  'Pressure (Pa)',
#  'Saturating Fluid',
#  'Saturation (%)',
#  'Sigma1 (MPa)',
#  'Sigma2 (MPa)',
#  'Sigma3 (MPa)',
#  'Pore Pressure (MPa)',
#  'strain rate (kN/s)',
#  'strain rate (MPa/s)',
#  'strain rate (mm/s)',
#  'strain rate (1/s)',
#  'Remarks on measurement conditions',
#  'Value grain density\n(kg/m³)',
#  'Standard Deviation grain density\n(kg/m³)',
#  'Min grain density\n(kg/m³)',
#  'Max grain density\n(kg/m³)',
#  'Number of measurements grain density',
#  'Measuring Type grain density',
#  'Remarks on grain density',
#  'Value bulk density\n(kg/m³)',
#  'Standard Deviation bulk density\n(kg/m³)',
#  'Min bulk density\n(kg/m³)',
#  'Max bulk density\n(kg/m³)',
#  'Number of measurements bulk density',
#  'Measuring Type bulk density',
#  'Remarks',
#  'Value total porosity\n(%)',
#  'Standard Deviation total porosity\n(%)',
#  'Min total porosity\n(%)',
#  'Max total porosity\n(%)',
#  'Number of measurements total porosity',
#  'Measuring Type total porosity',
#  'Remarks on total porosity',
#  'Value effective porosity\n(%)',
#  'Standard Deviation effective porosity\n(%)',
#  'Min effective porosity\n(%)',
#  'Max effective porosity\n(%) ',
#  'Number of measurements effective porosity',
#  'Measuring Type effective porosity',
#  'Remarks effective porosity',
#  'Value apparent permeability\n(m²)',
#  'Standard Deviation apparent permeability\n(m²)',
#  'Min apparent permeability\n(m²)',
#  'Max apparent permeability\n(m²)',
#  'Number of measurements apparent permeability',
#  'Measuring Type apparent permeability',
#  'Remarks on apparent permeability',
#  'Value intrinsic permeability\n(m²)',
#  'Standard Deviation intrinsic permeability\n(m²)',
#  'Min intrinsic permeability\n(m²)',
#  'Max intrinsic permeability\n(m²)',
#  'Number of measurements intrinsic permeability',
#  'Measuring Type intrinsic permeability',
#  'Remarks on intrinsic permeability',
#  'Value bulk thermal conductivity\n(W/(m·K))',
#  'Standard Deviation bulk thermal conductivity\n(W/(m·K))',
#  'Min bulk thermal conductivity\n(W/(m·K))',
#  'Max bulk thermal conductivity\n(W/(m·K))',
#  'Inhomogenity bulk thermal conductivity',
#  'Number of measurements bulk thermal conductivity',
#  'Measuring Type bulk thermal conductivity',
#  'Remarks on bulk thermal conductivity',
#  'Value matrix thermal conductivity\n(W/(m·K))',
#  'Standard Deviation matrix thermal conductivity\n(W/(m·K))',
#  'Min matrix thermal conductivity\n(W/(m·K))',
#  'Max matrix thermal conductivity\n(W/(m·K))',
#  'Inhomogenity matrix thermal conductivity',
#  'Number of measurements matrix thermal conductivity',
#  'Mixing Law matrix thermal conductivity',
#  'Remarks on matrix thermal conductivity',
#  'Value specific heat capacity\n(J/(kg·K))',
#  'Standard Deviation specific heat capacity\n(J/(kg·K))',
#  'Min specific heat capacity\n(J/(kg·K))',
#  'Max specific heat capacity\n(J/(kg·K))',
#  'Number of measurements specific heat capacity',
#  'Measuring Type specific heat capacity',
#  'Remarks on specific heat capacity',
#  'Value volumetric heat capacity\n(J/(m³·K))',
#  'Standard Deviation volumetric heat capacity\n(J/(m³·K))',
#  'Min volumetric heat capacity\n(J/(m³·K))',
#  'Max volumetric heat capacity\n(J/(m³·K))',
#  'Number of measurements volumetric heat capacity',
#  'Measuring Type volumetric heat capacity',
#  'Remarks on volumetric heat capacity',
#  'Value thermal diffusivity\n(m²/s)',
#  'Standard Deviation thermal diffusivity\n(m²/s)',
#  'Min thermal diffusivity\n(m²/s)',
#  'Max thermal diffusivity\n(m²/s)',
#  'Number of measurements thermal diffusivity',
#  'Measuring Type thermal diffusivity',
#  'Remarks on thermal diffusivity',
#  'Value radiogenic heat production\n(W/m³)',
#  'Standard Deviation radiogenic heat production\n(W/m³)',
#  'Min radiogenic heat production\n(W/m³)',
#  'Max radiogenic heat production\n(W/m³)',
#  'Number of measurements radiogenic heat production',
#  'Measuring Type radiogenic heat production',
#  'Calculation Type radiogenic heat production',
#  'Remarks on radiogenic heat production',
#  'Value p-wave velocity \n(m/s)',
#  'Standard Deviation p-wave velocity \n(m/s)',
#  'Min p-wave velocity \n(m/s)',
#  'Max p-wave velocity \n(m/s)',
#  'Number of measurements p-wave velocity ',
#  'Measuring Type p-wave velocity ',
#  'Measurement Frequency [kHz] p-wave velocity ',
#  'Remarks on p-wave velocity ',
#  'Value s-wave velocity\n(m/s)',
#  'Standard Deviation s-wave velocity\n(m/s)',
#  'Min s-wave velocity\n(m/s)',
#  'Max s-wave velocity\n(m/s)',
#  'Number of measurements s-wave velocity',
#  'Measuring Type s-wave velocity',
#  'Measurement Frequency [kHz] s-wave velocity',
#  'Remarks on s-wave velocity',
#  'Value dyn Youngs modulus (GPa)',
#  'Standard Deviation dyn Youngs modulus (GPa)',
#  'Min dyn Youngs modulus (GPa)',
#  'Max dyn Youngs modulus (GPa)',
#  'Number of measurements dyn Youngs modulus',
#  'Measuring Type dyn Youngs modulus',
#  'Remarks on dyn Youngs modulus',
#  'Value stat Youngs modulus (GPa)',
#  'Standard Deviation stat Youngs modulus (GPa)',
#  'Min stat Youngs modulus (GPa)',
#  'Max stat Youngs modulus (GPa)',
#  'Number of measurements stat Youngs modulus',
#  'Measuring Type stat Youngs modulus',
#  'Remarks on stat Youngs modulus (GPa)',
#  'Value shear modulus (GPa)',
#  'Standard Deviation shear modulus (GPa)',
#  'Min shear modulus (GPa)',
#  'Max shear modulus (GPa)',
#  'Number of measurements shear modulus',
#  'Measuring Type shear modulus (GPa)',
#  'Remarks on shear modulus',
#  'Value bulk modulus (GPa)',
#  'Standard Deviation bulk modulus (GPa)',
#  'Min bulk modulus (GPa)',
#  'Max bulk modulus (GPa)',
#  'Number of measurements bulk modulus',
#  'Measuring Type bulk modulus',
#  'Remarks on bulk modulus',
#  'Value lame modulus',
#  'Standard Deviation lame modulus',
#  'Min lame modulus',
#  'Max lame modulus',
#  'Number of measurements lame modulus',
#  'Measuring Type lame modulus',
#  'Remarks on lame modulus',
#  'Value cohesion',
#  'Standard Deviation cohesion',
#  'Min cohesion',
#  'Max cohesion',
#  'Number of measurements cohesion',
#  'Measuring Type cohesion',
#  'Remarks on cohesion',
#  'Value friction coefficient',
#  'Standard Deviation friction coefficient',
#  'Min friction coefficient',
#  'Max friction coefficient',
#  'Number of measurements friction coefficient',
#  'Measuring Type friction coefficient',
#  'Remarks on friction coefficient',
#  'Effective pressure (MPa)',
#  'Confining pressure (MPa)',
#  'Porefluid pressure (MPa)',
#  '(Peak) Differential stress (MPa)',
#  'Effective mean stress (MPa)',
#  'Differential stress (MPa) [Compactive Yield Stress C]',
#  'Effective mean Stress (MPa) [Compactive Yield Stress C*]',
#  'Differential stress (MPa) [Critical Yield Stress]',
#  'Effective mean stress (MPa) [Critical Yield stress]',
#  'The onset of inelastic hydrostatic compaction (MPa)',
#  'The onset of shear-enhanced inelastic compaction (MPa)',
#  'Onset of shear enhanced compaction (MPa)',
#  'Measuring Type',
#  'Remarks on',
#  'Value poisson ratio (dynamic)',
#  'Standard Deviation poisson ratio (dymic)',
#  'Min poisson ratio (dymic)',
#  'Max poisson ratio (dymic)',
#  'Number of measurements poisson ratio (dymic)',
#  'Measuring Type poisson ratio (dynamic)',
#  'Remarks on poisson ratio (dynamic)',
#  ' Value poisson ratio (static)',
#  'Standard Deviation poisson ratio (static)',
#  'Min poisson ratio (static)',
#  'Max poisson ratio (static)',
#  'Number of measurements poisson ratio (static)',
#  'Measuring Type poisson ratio (static)',
#  'Remarks on poisson ratio (static)',
#  'Value UCS\n(MPa)',
#  'Standard Deviation UCS\n(MPa)',
#  'Min UCS\n(MPa)',
#  'Max UCS\n(MPa)',
#  'Number of measurements UCS',
#  'Effective Mean Stress (MPa) (P=(σ1+2σ3)/3-Pp))',
#  'Measuring Type UCS',
#  'Remarks on UCS',
#  'Value tensile strength\n(MPa)',
#  'Standard Deviation tensile strength\n(MPa)',
#  'Min tensile strength\n(MPa)',
#  'Max tensile strength\n(MPa)',
#  'Number of measurements tensile strength',
#  'Measuring Type tensile strength',
#  'Remarks tensile strength',
#  'Rock Conductivity (S/m)',
#  'Fluid Conductivity (S/m)',
#  'Formation Resistivity Factor',
#  'Standard Deviation electrical conductivity',
#  'Min electrical conductivity',
#  'Max electrical conductivity',
#  'Number of measurements electrical conductivity',
#  'Measuring Type electrical conductivity',
#  'Measurement frequency',
#  'Remarks',
#  'Value or Mean Value',
#  'Standard Deviation',
#  'Min',
#  'Max',
#  'Number of measurements',
#  'Measuring Type',
#  'Remarks',
#  'Q Indice Geographic Uncertainty',
#  'Q Indice Petrography',
#  'Chronostratigraphy Rank',
#  'Indice Stratigraphy',
#  '1st help indices for measurement device',
#  '2nd help indices for measurement device',
#  'indice for measurement device',
#  'help indice for temperature',
#  'help indice for pressure',
#  'help indice for saturation',
#  'indice for measurement conditions',
#  'Indice Measurement conditions',
#  'Indice Measurement parameter',
#  'help indice values',
#  'N = Single (0) or Mean (1)',
#  'help indice values 1 (SD)',
#  'help indice values 2 (MinMax)',
#  'Quality index values',
#  'Quality index']

# %%
list_methods = []
for i in list_method:
    new_text = re.sub(r'[]\n[]', ' ', i)
    for j in new_text.split():
        if re.sub(r'[)(]', '', j).lower() not in list_methods:
            list_methods.append(re.sub(r'[)(]', '', j).lower())
        else:
            pass
list_methods = [i for i in list_methods if len(i) !=1]

# %%
for i in df.columns.values.tolist():
    if bool(re.search(r'Unnamed: \d+',i)) != True:
        list_methods.append(i)

# %%
list_methods_det = ['longitude',
 'decimaldegree.minutes',
 'latitude',
 'elevation',
 'a.s.l.',
 'radius',
 'uncertainty',
 'km',
 'igsn',
 'length',
 'height',
 'width',
 'diameter',
 'decimaldegrees.minutes',
 'depth',
 'md',
 'tvd',
 'petrography',
 'stratigraphy',
 'temperature',
 'pressure',
 'pa',
 'saturating',
 'saturation',
 'sigma1',
 'mpa',
 'sigma2',
 'sigma3',
 'pore',
 'strain',
 'rate',
 'kn/s',
 'mpa/s',
 'mm/s',
 '1/s',
 'value',
 'grain',
 'density',
 'kg/m³',
 'standard deviation',
 'min',
 'max',
 'porosity',
 'permeability',
 'm²',
 'thermal',
 'conductivity',
 'w/m·k',
 'inhomogenity',
 'specific heat capacity',
 'heat',
 'capacity',
 'j/kg·k',
 'volumetric',
 'j/m³·k',
 'diffusivity',
 'm²/s',
 'radiogenic',
 'w/m³',
 'p-wave',
 'velocity',
 'm/s',
 'frequency',
 'khz',
 's-wave',
 'dyn',
 'youngs modulus',
 'modulus',
 'gpa',
 'stat',
 'shear',
 'lame',
 'cohesion',
 'friction',
 'coefficient',
 'confining',
 'porefluid',
 'differential',
 'stress',
 'mean',
 'compactive',
 'yield',
 'critical',
 'onset',
 'inelastic',
 'hydrostatic',
 'compaction',
 'shear-enhanced',
 'enhanced',
 'poisson',
 'ratio',
 'dynamic',
 'static',
 'ucs',
 'tensile',
 'strength',
 's/m',
 'formation',
 'resistivity',
 'chronostratigraphy',
 'sampling point',
 'petrography',
 'stratigraphy',
 'grain density',
 'bulk density',
 'total porosity',
 'effective porosity',
 'apparent permeability',
 'intrinsic permeability',
 'bulk thermal conductivity',
 'matrix thermal conductivity',
 'specific heat capacity',
 'volumetric heat capacity',
 'thermal diffusivity',
 'radiogenic heat production',
 'p-wave velocity',
 's-wave velocity',
 'youngs modulus',
 'shear modulus',
 'bulk modulus',
 'lamé modulus',
 'cohesion',
 'friction coefficient',
 'triaxial experiments',
 'poisson ratio',
 'uniaxial compressive strength',
 'tensile strength',
 'electrical conductivity',
 'magnetic susceptibility',
 'quality indice geographic uncertatiny',
 'qualitiy indice petrography',
 'quality indice stratigraphy',
 'qualitiy indice measurement conditions',
 'quality indice measurement parameter',
 'value quality index',
 'class quality index'
]

# %%
with open ('list_methods.txt', 'w') as f:
    for item in list_methods_det:
        f.write(str(item) + '\n')

# %% [markdown]
# ## P3 Data (Geolocation)

# %% [markdown]
# ### Geolocation

# %%
df = pd.read_excel('C:/Users/Ryan Bobby A/Documents/RWTH AACHEN/KULIAH/THESIS_BISMILLAH/Thesis Progress/Target Data/Geolocation_P3.xlsx')

# %%
df.head()
# Out:
#   Location name
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
temp_loc= df['Location name'].values.tolist()
temp_loc= [i.lower() for i in list_loc if type(i) == str ]

list_geoloc = []
for i in list_loc:
    if i in list_geoloc:
        pass
    else:
        list_geoloc.append(i)

list_geolocation = []
list_geolocation_det = []

#Conditioning
for i in list_geoloc:
    for j in i.split(sep='/'):
        if j.strip() not in list_geolocation:
            list_geolocation.append(j.strip())

#Conditioning
for i in list_geolocation:
    for j in re.split(', |,|/', i):
        if re.sub(r' \d+','',j.strip()) not in list_geolocation_det and len(re.search(r'\w+', j).group()) !=1:
            list_geolocation_det.append(re.sub('( \d+\w?| (ca. km))','',j.strip()))

#Conditioning over-spaced
for j,i in enumerate(list_geolocation_det):
    try:
        if len(re.search(' +',i).group()) > 1:
            list_geolocation_det[j] = ' '.join(i.split())
    except:
        pass
    
#Conditioning Core Well Data
for j, i in enumerate(list_geolocation_det):
    list_geolocation_det[j] = re.sub('\d+ m \w+´ ','',i)

# %%
list_geolocation_det
# Out:
# ['kraka massif',
#  'southern urals',
#  'kuznetsk alatau',
#  'berikul region',
#  'klyuchovsky volcano',
#  'kamchatka',
#  'rockport',
#  'belokurikhinsky massif',
#  'altai',
#  'val verde',
#  'porterville',
#  'frederick',
#  'maryland',
#  'westerly',
#  'westfield',
#  'peninsula station',
#  'ont.',
#  'vinal haven',
#  'maine',
#  'barre',
#  'farm doornspruit',
#  'sylmar',
#  'french creek',
#  'stillwater igneous complex',
#  'new glasgow',
#  'mellen',
#  'pilansberg',
#  'balsam gap',
#  'allentown',
#  'bethlehem',
#  'nazareth',
#  'pennsylvania',
#  'pelham',
#  'proctor',
#  'solnhofen',
#  'offshore louisiana',
#  'texas',
#  'kyushu',
#  'mie',
#  'aichi',
#  'kyoto',
#  'oklahoma',
#  'fukushima',
#  'colorado',
#  'iwate',
#  'utah',
#  'wyoming',
#  'hokkaido',
#  'oregon',
#  'twin sisters mountain',
#  'madneuli',
#  'shaori reservoir',
#  'akhalkalaki highlands',
#  'karatsu',
#  'ichinomegata',
#  'horoman',
#  'chiatura',
#  'central asia',
#  'dzirula massif',
#  'jraber',
#  'upper rhine graben',
#  'southern part of upper rhine graben',
#  'upper rhine graben between black forest and vosges',
#  'upper rhine graben and surroundings',
#  'koytas',
#  'kandygatay mts.',
#  'kalbinsky massif',
#  'shindinsky massif',
#  'southwest german molasse basin',
#  'south arne',
#  'north sea',
#  'near freiburg',
#  'black forest',
#  'near offenburg',
#  'tyger-tysh ridge',
#  'ulen-tuimsky massif',
#  'uybatsky massif',
#  'karymsky volcano',
#  'kamtchatka',
#  'mid-atlantic ocean ridge',
#  'hawaii',
#  'cerro prieto',
#  'mexicali',
#  'ohio',
#  'kentucky',
#  'west virginia',
#  'idaho',
#  'higo metamorphic belt',
#  'hadaki metamorphic belt',
#  'beni bouchera massif (beni bouzere)',
#  'ivrea zone',
#  'lofoten-vesteralen region',
#  'austvagoya',
#  'langoya',
#  'salem',
#  'mysore',
#  'pallavaram',
#  'madras (chennai)',
#  'tamil nadu',
#  'podili',
#  'kurnool',
#  'andhra pradesh',
#  'vinukonda',
#  'guntur',
#  'vijayawada',
#  'kondapalli',
#  'hyderabad',
#  'yellandalpad (yellandu)',
#  'manditog',
#  'waltair (visakhapatnam)',
#  'maharashtra',
#  'talchir',
#  'chaibasa',
#  'bundelkhand (south uttar and north madhya pradesh)',
#  'bihar',
#  'kishengarh',
#  'rajasthan',
#  'rajputana',
#  'shahabad',
#  'sujarghar',
#  'halemaumau',
#  'hawaii island',
#  'hualai flow',
#  'india',
#  'maui island',
#  'salt lake crater',
#  'oahu island (honolulu)',
#  'kauai',
#  'molokai or niihau island',
#  'scotland',
#  'sendai',
#  'miyagi prefecture',
#  'hagino',
#  'yamagata prefecture',
#  'nishimonai',
#  'akita prefecture',
#  'tanohata',
#  'iwate prefecture',
#  'transvaal (historical)',
#  'usa',
#  'south africa',
#  'hengill geothermal field',
#  'nesja-vellir geothermal field',
#  'krafla geothermal field',
#  'kazakhstan',
#  'caucasus',
#  'pavlovsk',
#  'reunion island',
#  'oskoletsk',
#  'voronezh anteclise',
#  'saltykov (voronezh massif)',
#  'north karelia',
#  'sakhalin island',
#  'mamonov complex',
#  'voronezh massif',
#  'gorky oblast (today: oblast of nishni novgorod)',
#  'south ural mountains',
#  'ussr far east',
#  'ural',
#  'monchegorsk',
#  'kola peninsula',
#  'pechenga',
#  'seychelles',
#  'gegam plateau',
#  'bezumskiy ridge',
#  'sikhote-alin-ridge',
#  'gorky complex',
#  'udzha river',
#  'indian ocean ridge',
#  'indian ocean island',
#  'referred to as gondwana island',
#  'armenia',
#  'borisov volcano',
#  'baikal region',
#  'avachinsk volcano',
#  'lake baikal',
#  'obnazhennaya formation',
#  'southeast corner of þingvallavatn',
#  'surtsey',
#  'heimaey',
#  'reykjanes high temperature field',
#  'southwall of excavated drillpad for rn-18',
#  'sandfell in þrengsli',
#  'west side. slightly north and above the quarry.',
#  'south part of vigdísarvellir road',
#  'possibly ne part of tófubruna hyaloclastite',
#  'south part of vigdísarvellir road about m from road',
#  'north end of vigdísarvellir track',
#  'vigdísarvellir track',
#  'probably ne of einbúi on south side of reykjanes west of krísuvík road',
#  'silfurberg',
#  'north of kögunarhóll',
#  'ingólfsfjall quarry',
#  'votuklettar-threngsli',
#  'slightly west of votuklettar',
#  'river eroded exposure in to a hyaloclastite ridge',
#  'north side of road',
#  'north of tindafjalla',
#  'west of kirkjufellsós',
#  'southwest end of raudhnukar at bláfjalla- and hafnarfjardar road intersection.',
#  'southwest end of raudhnukar at bláfjalla- and hafnarfjardarroad intersection.',
#  'west of hveradalaskálinn',
#  'dómadalur',
#  'south end of þjórsárholt by river',
#  'south end of vörðufell',
#  'hellisskarð in hengill',
#  'sediment west of fossá',
#  'road cut about-100 m east of fossá',
#  'krókagiljabrún se of lambafitjahraun',
#  'valahnúkar',
#  'valahnúkar on dómadalsroute',
#  'gaukshöfdi',
#  'in roadcut',
#  'ca. km east of gaukshöfði and about m from main road',
#  'roadcut near idntaeknistofnun',
#  'west side of reykholt',
#  'smooth surfaced  hyaloclastite',
#  'west side of reykholt same hyaloclastite as',
#  'at north end of reykholt',
#  'ca. west of swimmingpool.',
#  'roadcut in mosfellsbaer',
#  'reykholt biskupstungur',
#  'reykholt',
#  'ne-end of thjorsárdalur on way to "summer house" there',
#  'miðfell',
#  'below dolerite north side of kollafjordur',
#  'south of laugardalshellir',
#  'stora dímon',
#  'arnarfell',
#  'west side of stóra dímon',
#  'skefilsfjoll eldri- south exposure',
#  'skefilsfjoll eldri- north exposure',
#  'skefilsfjoll yngri (last glaciation)',
#  'south side of meðalfell in baejargil.',
#  'southeast side of blákollur',
#  'iceland',
#  'helgafell',
#  'easternmost arnarthufa',
#  'west of vifilfell',
#  'awibengkok geothermal field',
#  'ktb borehole',
#  'groß schönebeck',
#  'geitafell volcano',
#  'krafla volcano',
#  'evrona',
#  'gerofit',
#  'ora',
#  'samar',
#  'zihor',
#  'well sinaf-1',
#  'tamardol',
#  'well ramon-1',
#  'well avdat-1',
#  'en yorq',
#  'hevyon',
#  'ghareb',
#  'avnon',
#  'mishash',
#  'nezer',
#  'shivta',
#  'well maka-36',
#  'menuha',
#  'tamar',
#  'well hmch-1',
#  'well hm-1',
#  'taqiye',
#  'well daya-1',
#  'well hltza-2',
#  'well hzrm-1',
#  'well bshev-1',
#  'well gurim-3',
#  'well zhrd-8',
#  'well zohar-1',
#  'well dshet-1',
#  'well hlz-2',
#  'well hlz-37',
#  'well negba-1',
#  'karnei-hitin volcano',
#  'weiss-kaul',
#  'west of rümelingen',
#  'belvaux',
#  'giele botter',
#  'profile kinett',
#  'east of moutfort',
#  'rebierg',
#  'züschschiefer',
#  'kirchberg',
#  'grouft',
#  'wasserbillig vormann',
#  'mersch',
#  'ell',
#  'rosswinkel',
#  'everlange',
#  'wartenstein',
#  'martelange',
#  'ingeldorf',
#  'radelange',
#  'reisdorf',
#  'stolzemburg',
#  'schüttburg',
#  'mirwart',
#  'southeastern ardennes',
#  'clerf',
#  'berlé',
#  'wiltz',
#  'sainthubert',
#  'villé',
#  'oignies',
#  'la gleize',
#  'bihain',
#  'fépin',
#  'meuville',
#  'colanhan',
#  'lierneux',
#  'les plattes',
#  'hour',
#  'deep drilling of grand halleux',
#  'wanne',
#  'la venne',
#  'spa',
#  'solwaster',
#  'belleaux',
#  'east pacific rise',
#  'schwerin',
#  'neubrandenburg',
#  'stralsund',
#  'pan-african damara mobile belt',
#  'external crystalline massif of the alps',
#  'lachlan fold belt',
#  'namaqua mobile belt',
#  'jequié',
#  'penokean orogen',
#  'jequie complex',
#  'new hampshire',
#  'galicia-tras-os-montes zone (gt)',
#  'williams + naraku batholith (mount isa)',
#  'mount isa',
#  'superior province',
#  'canadian shield',
#  'variscan batholith of corsica',
#  'northern taiwan volcanic zone',
#  'zimbabwe craton',
#  'central spain',
#  'tethyan neyriz opholite complex',
#  'coso volcanic field',
#  'westasturian-leonese zone (al)',
#  'norris creek',
#  'tarenga shale',
#  'biritish caledonian intrusions',
#  'burnside (pine creek)',
#  'mount webb (arunta inlier)',
#  'idaho batholith',
#  'variscan crust',
#  'corsica',
#  'njiri',
#  'dharwar craton',
#  'central african plateau',
#  'oulmès metamorphic aureole',
#  'sonhat basin (son valley)',
#  'warrego (tennant creek)',
#  'dawson strait area',
#  'continental crust',
#  'sybella batholith (mount isa)',
#  'vosges',
#  'schwarzwald',
#  'bear lake',
#  'twin peaks volcanic field',
#  'karnataka',
#  'sierra la primavera',
#  'rift-related; include sybella batholith (mount isa)',
#  'kong oscar fjord',
#  'tinemaha granodiorite',
#  'st. malo',
#  'provencal basin',
#  'langtang valley',
#  'natawahunan lake',
#  'damara belt',
#  'central-iberian zone (ci)',
#  'merced peak',
#  'cauchon lake',
#  'singhbhum trust belt',
#  'hidden bay pluton',
#  'sierra nevada batholith',
#  'turku area',
#  'chemehuevi mountains',
#  'shellenbarger lake',
#  'kaapvaal craton',
#  'kalkadoon (mount isa)',
#  'timber knob',
#  'betics (b)',
#  'alpujárrides',
#  'red peak',
#  'southwark (arunta inlier)',
#  'tennant creekt',
#  'kimberlite pipes',
#  'chintalapudi basin (godavari valley)',
#  'trois segneurs massif',
#  'post peak',
#  'paperbark (kimberley)',
#  'vredefort structure',
#  'bodrum volcanic complex',
#  'deep drilling of grandhalleux',
#  'kolar schist belt',
#  'west african kimberlites',
#  'ossa morena zone (omz)',
#  'westasturian-leonese zone (wl)',
#  'querigut complex',
#  'maláguides',
#  'belén',
#  'cordón tucúaro',
#  'iberian range',
#  'moresby strait area',
#  'oxford lake',
#  'shaler pluton',
#  'sally downs (kimberley)',
#  'central eastern china',
#  'closepet granite',
#  'southwestern alaska',
#  'comte',
#  'strona valley',
#  'samrée',
#  'quebrada tajamar',
#  'gulf of mexico basin',
#  'nevado-filábrides',
#  'eastern virunga province',
#  'eastern australia',
#  'quebrada choja',
#  'urals',
#  'vivero massif',
#  'captains bay pluton',
#  'manaslu granite',
#  'arita',
#  'pam lin island',
#  'st. andrew strait',
#  'basotu',
#  'grenville province',
#  'jackass lakes',
#  'minarets complex',
#  'etendeka region',
#  'santa rosa de tastil',
#  'north arcot-pallavaram granulite belt',
#  'pyrenees',
#  'limpopo belt (nmz)',
#  'trans-hudson orogen',
#  'tehachapi mts',
#  'salar de navidad',
#  'ochaquí',
#  'lamrômenil',
#  'longido',
#  'ghanzi-chobe fold belt',
#  'cantabrian zone',
#  'ebolowa area',
#  'ntem complex',
#  'pingo pingo',
#  'salar de diablillos',
#  'utik lake',
#  'continental shelf off sao paulo or cananéia-iguape lagoon',
#  'tuluman island',
#  'finger bay pluton',
#  'kirn',
#  'namaqua-natal belt',
#  'nanking',
#  'dodoma',
#  'kerguelen plateau',
#  'voisey bay',
#  'iowa',
#  'bp-1',
#  'bp-2',
#  'verril canyon',
#  'mic mac',
#  'bp-3',
#  'ne volcanic province',
#  'spain',
#  'kansas c',
#  'choschas',
#  'south atlantic',
#  'solya',
#  'bp-4',
#  'bp-5',
#  'sierra de macón',
#  'sinuyu',
#  'souther extension of east african rift',
#  'merapi volcano',
#  'kansas a',
#  'pikwitonei - sachigo',
#  'charmuria limestone',
#  'sierra nevada',
#  'plagidac',
#  'mississauga',
#  'champua thrust belt',
#  'logan canyon',
#  'kansas b',
#  'cordón chinquilchoro',
#  'dawson canyon',
#  'kaiserstuhl',
#  'pacific ocean',
#  'kagalaska pluton',
#  'kanyemba',
#  'peninsula de mejillones',
#  'northern apennines',
#  'kastamonu',
#  'sesia–lanzo zone',
#  'redwig',
#  'tanlu fault',
#  'pikwitonei lake',
#  'garua harbour',
#  'mohican',
#  'renco',
#  'santa lucia mts',
#  'aleutian islands',
#  'paraná-etendeka province',
#  'jericho kimberlite pipe',
#  'zagros suture zone',
#  'sierra limón verde',
#  'banquereau',
#  'morbs & oibs',
#  'andean',
#  'goulet lake',
#  'saitoco',
#  'mount garbuna',
#  'new britain',
#  'columbia river basalt',
#  'mount welcker',
#  'luzon',
#  'holili',
#  'lau ridge',
#  'sugarloaf pluton',
#  'chinese peak',
#  "sana'a-amran volcanic field",
#  'newer volcanic basalt province',
#  'garove island',
#  'lesser antilles',
#  'cordón de lila',
#  'nelson river',
#  'peninsula de majillones',
#  'abenaki',
#  'aleutian',
#  'bagana volcano',
#  'lolobau island',
#  'cape reilnitz',
#  'aleutian arc',
#  'sulu range',
#  'pikwitonei river',
#  'limpopo belt (smz)',
#  'atlantic ocean',
#  'kansa pathar',
#  'cascades',
#  'central america',
#  'kermadec',
#  'niuatoputapu',
#  'scotia',
#  'boninites',
#  'big creek',
#  'caribbean-columbian oceanic plateau',
#  'marianas',
#  'piñón oceanic plateau',
#  'late',
#  'burntwood river',
#  'cape hoskins volcanoes',
#  'ontong java plateau',
#  'deep sea drilling',
#  'site',
#  'mid ocean ridge',
#  'indian ocean',
#  'jijicao',
#  'xinchang',
#  '* the area is bounded by the\ncuitzeo lake to the north and the quinceo-tetillas volcanic complex\n(qtvc) to the south.                     * the most representative outcrops are located near the guadalajara-mexico\ncity highway on the southern shore of the cuitzeo lake',
#  'los humeros geothermal field',
#  'ischia',
#  'solfatara',
#  'bolsena',
#  'vulsini volcanic zone',
#  'akranes',
#  'ferstikla',
#  'borgarfjarðarsveit',
#  'búlandshöfði',
#  'grundarfjarðarbær',
#  'gullbringusýsla',
#  'mfa-1',
#  'mfa-2',
#  'mfa-3',
#  'hafnarfjall',
#  'hoffell',
#  'dakeng',
#  'hrafnabjörg',
#  'hveragerði',
#  'innrihólmur',
#  'klafastaðir',
#  'kúludalsá',
#  'leirá',
#  'kolgrafir í eyrarsveit',
#  'leirár- og melahreppur',
#  'leirárdalur',
#  'demre',
#  'finike',
#  'mut',
#  'fethiye',
#  'korkuteli',
#  'meke',
#  'karaman',
#  'milas',
#  'yatagan',
#  'bucak',
#  'kolsuz',
#  'gödene',
#  'kilavuzkoy',
#  'ückapili',
#  'kavlaktepe',
#  'gümüsler',
#  'altinhisar',
#  'yesilburc',
#  'hazro',
#  'kemalpasa',
#  'ortaköy',
#  'bunyan',
#  'iscehisar',
#  'altintas',
#  'kozak',
#  'kaman',
#  'yildizeli',
#  'sögütalan',
#  'marmara island',
#  'porrino',
#  'mosfellsbær',
#  'lýsuhóll',
#  'reykjavík',
#  'seleyrargil',
#  'ytrihólmur',
#  'skilmannahreppur',
#  'þyrill',
#  'skorradalshreppur',
#  'stóra-drageyri',
#  'snæfellsbær',
#  'sandabotnaskarð',
#  'ek-105',
#  'kan-3',
#  'nc-99',
#  '98-46',
#  'ku5',
#  'mp-98',
#  'mp-101',
#  '98-78',
#  '98-89a',
#  '98-39',
#  '306i',
#  '316i',
#  '98-43b',
#  'ko2',
#  'caldera in klausturtunguhóll',
#  'caldera in western snókur',
#  'hafnarfjall caldera',
#  'western leirárdalur',
#  'caldera in \nwestern leirárdalur',
#  'leirárdalur gully',
#  'east of klausturtunguhóll',
#  'nevada',
#  'southern and western margins of the western region of the north german basin',
#  'eulenflucht (wellbore)                                                southern and western margins of the western region of the north german basin',
#  'groß buchholz (wellbore)                                 southern and western margins of the western region of the north german basin',
#  'east of snókur',
#  'western canada sedimentary basin',
#  'alberta basin',
#  'well',
#  '08-06-055-22w5',
#  '00',
#  'hof trages',
#  'sw freigericht-somborn',
#  '10-33-036-10w5',
#  'lesesteine w stolzenberg',
#  'bad soden-salmünster',
#  'feldweg böschung a n kinzig-stausee',
#  'ost',
#  'west',
#  'rothenberg',
#  'alzenau-kälberau',
#  '06-11-051-26w4',
#  'alter steinbruch',
#  'gap lake',
#  'alberta',
#  'canada',
#  'hohlweg rauher berg',
#  '15-23-036-10w5',
#  'grassi lakes',
#  'canmore up the rr742 to whitemans pond',
#  'maisenheimer hof',
#  'nigel peak',
#  'alberta canada',
#  'steinbruch niedermittlauer heiligenkopf',
#  'gelnhausen-meerholz',
#  'klosterruine',
#  'parkplatz landstraße',
#  'alter steinbruch büdinger berg',
#  'gründau-breitenborn',
#  'steinbruch schnepfenkopf',
#  'gelnhausen',
#  'kalkwerk firma hufgard',
#  'hösbach-rottenberg',
#  'kleiner aufschluss',
#  'freibad gelnhausen-roth',
#  'steinbruch meerholzer heiligenkopf',
#  'steinbruch sw heinrichshöhe',
#  'lochmühle',
#  'biebergemünd-bieber',
#  'anschnitt b276',
#  'wächtersbach',
#  'altegrube',
#  'gelnhausen-höchst',
#  'steinbruch altenhaßlau',
#  'linsengericht-altenhaßlau',
#  'steinbruch nassbüchelbach',
#  'steinbruch altenmittlau',
#  'anschnitt kreuzung b276 - l3216',
#  'burgfelsen am bahnhof alzenau-burg',
#  'alzenau',
#  'steinbruch an der pizzeria "zum paradies"',
#  'gelnhausen-roth',
#  'steinbruch am neuenberg',
#  'penken',
#  'tauernfenster nordrand',
#  'österreich',
#  'hohlweg',
#  'steinbrüche e bad orb',
#  'pfannköpfl',
#  'straßenanschnitt b276',
#  'biebergemünd-kassel',
#  'tettensjoch',
#  'steinbruch kerkelberg',
#  'biebergemünd-roßbach',
#  'alter steinbruch am hirschberg',
#  'steinbruch wintersberg',
#  'se bad orb',
#  'finkenberg',
#  'abtshecken e langenselbold (unweit der a66)',
#  'alter steinbruch herzberg',
#  'bahnhofstraße',
#  'alte tongrube',
#  'elsbach',
#  'alter kalksteinbruch nw sonnenberg',
#  'gelnhausen-hailer',
#  'tongrube hailer',
#  'dornau am tuxbach',
#  'wasserfall am elsbach',
#  'altes kalkwerk firma ickes',
#  'elsalm',
#  'schraubenfall',
#  'acker auf dem mühlberg',
#  'ne langenselbold',
#  'steinbruch franzosenkopf',
#  'huckelheim',
#  'neuer steinbruch',
#  'sw hösbach-rottenberg',
#  'tuxer joch',
#  'weitental',
#  'lachtalscharte',
#  'schwarze pfanne',
#  'bahnhof mittelgründau',
#  'parkplatz hanauer straße',
#  'tongrube firma zeller',
#  'neuburg-ravolzhausen',
#  'tongrube bettenburger loch',
#  'schöneck-oberdorfelden',
#  '10-31-37-9w5',
#  'rosenthal',
#  'arbonne la foret',
#  'aura',
#  'sterbfritz',
#  'hessen',
#  'deutschland',
#  'piarere (ca. km)',
#  'te awamutu (ca. km)',
#  'waikato region',
#  'waotu (ca. km)',
#  'cedar creek',
#  'mount tamborine',
#  'te puke (ca. km )',
#  'whakaari (white island volcano) within\nthe taupo volcanic zone (tvz)                      * active andesite–dacite stratovolcano',
#  'gonghe basin',
#  'zotzenbach',
#  'nieder-liebersbach',
#  'scharbach',
#  'campi flegrei caldera                                                   *  neapolitan area                                                               * few kilometers west of the city of naples',
#  'the north-west of the town of caserta',
#  'campi flegrei caldera at monte san serverio',
#  'colli albani (alban hills)',
#  'mt. etna volcano',
#  'southern flank of the volcano',
#  'stromboli volcano',
#  'rhode island',
#  'bentheim',
#  'darley dale',
#  'seljadur',
#  'mt etna volcano',
#  'kirschhausen',
#  'wald-erlenbach',
#  'krumbach',
#  'bonsweiher',
#  'ca.',
#  '88 km ne von taupo',
#  'waihi',
#  'ca. westlich des südwestlichen endes des tauposees',
#  'ca.m sw von papamoa',
#  '62 km e von taupo',
#  'ca. km sw von turangi',
#  'straßenaufschluss an der autobahn a3',
#  'aufgegebene steinbrüche im unteren buntsandstein im südlichen spessart in stadtprozelten',
#  'pfalz',
#  'östliche grabenschulter des oberrheingrabens',
#  'odenwald',
#  'westliche grabenschulter des oberrheingrabens',
#  'aufgegebene steinbrüche im unteren buntsandstein im südlichen spessart an der bundesstrasse am mainufer',
#  'südhang des triefnebachtales',
#  'etwa km nordwestlich von kirchheimbolanden',
#  'tunnelbaustelle widderstall',
#  'lhd4-653',
#  'lhd4-852',
#  'lhd4-1002',
#  'lhd4-2305',
#  'lhd5-603',
#  'lhd5-753',
#  'lhd5-1103',
#  'lhd5-1406',
#  'lhd5-1576',
#  'lhd1-2101',
#  'lhd1-501',
#  'lhd1-802',
#  'lhd1-1001',
#  'lhd1',
#  'lhd7-902',
#  'lhd7.8-1568',
#  'lhd7-1758',
#  'lhd2-302',
#  'lhd3-2203',
#  'mount st. helen',
#  'dacites from the-2008 spine-forming eruption. the samples were taken at the lava spine (~120  m in diameter',
#  'extruded between january and april).',
#  'dacites from the-2008 spine-forming eruption (spine)',
#  'dacites from the-2008 spine-forming eruption',
#  'dacite lava collected from the dome.',
#  'dacites from the-2008 spine-forming eruption (kid dome gulley)',
#  'mount meager volcano                                               (part of the garibaldi volcanic belt',
#  'the\nnorthernmost segment of the cascade volcanic arc of north america)',
#  'st. augustine volcano',
#  'dacite cinderblock lava from the eruption',
#  'reykjanes',
#  'dacites from the-2008 spine-forming eruption (pine creek period)                     kid dome',
#  'dacites from the-2008 spine-forming eruption (castle creek period)                        dyke',
#  'ne crater wall',
#  'dacites from the-2008 spine-forming eruption (pine creek period)                     northeast dome',
#  'dacites from the-2008 spine-forming eruption (pine creek period)                     kid dome gulley',
#  'el zarco riverbed on the south-eastern flank of volcán de colima',
#  'volcán de colima                                                           andesite from the pyroclastic flows (2005)',
#  'volcán de colima                                                           tuffisite-bearing andesite from the pyroclastic flows (2005)',
#  'kumamoto prefecture',
#  'mount etna volcano',
#  'rotokawa geothermal field',
#  'volcán de colima                                                 lahar deposit on the west flank of the volcano (in the el zarco river bed near la becerrera)',
#  'volcán de colima                                                old lava flow',
#  'volcán de colima                                                blow-and-ash flow in the san antonio ravine (1998-1999)',
#  'volcán de colima                                                lava flow in the cordoban ravine (1998-1999)',
#  'volcán de colima                                          la lumbre debris-flow track (barranca) on the south-western flank of the volcan.',
#  'volcán de colima                                                lava flow(975-1976) from  the southeast slope of the volcano',
#  'volcán de colima                                              andesite from the dome-building eruptions and explosions that occurred during',
#  'harsit granitoid along the\nriver harsit around dogankent',
#  'area between kürtün dogankent',
#  'quarry in piesberg on the northern edge of the city osnabrück',
#  'quarry bruchsal',
#  'quarry knittlingen',
#  'quarry near the village seebach',
#  'quarry near the village  raumünzach',
#  'small quarry in grünwettersbach.         a village near city of karlsruhe',
#  'quarry on the outskirts of wilferdingen . a village near pforzheim',
#  'huge quarry near the village of albersweiler',
#  'outcrop near the village of waldhambach',
#  'buntsandstein quarry göbel in the palatinate forest',
#  'th18',
#  'tauhara geothermal field',
#  'thm12',
#  'thm19',
#  'thm14',
#  'thm18',
#  'thm17',
#  'thm13',
#  'kailash tila-2',
#  'bengal basin',
#  'titas-11',
#  'bakhrabad-10',
#  'shahbazpur-1',
#  'kwv-1',
#  'ecca pass',
#  'eastern cape',
#  'koksharovskoe plateau',
#  'ussr maritime region (primorskiy krai)',
#  'russian platform',
#  'lovozero formation',
#  'kurginsk formation',
#  'anabar bed',
#  'kimpersay massif',
#  'aldan',
#  'tanba belt',
#  'synnyr complex',
#  'khibiny mountains',
#  'caucasus or oboyansk or gorky region (oblast of nishni novgorod)',
#  'oboyansk',
#  'today: oblast of nishni novgorod',
#  'escandorgue lava flow',
#  'lunas',
#  'dévés lava flow',
#  'senouire vallée',
#  'josat',
#  'norseman',
#  'broken hill',
#  'coolgardie',
#  'kalgoorlie',
#  'west-australien',
#  'south and west australia',
#  'heimersdorf',
#  'illfurth',
#  'michelbach',
#  'schweighouse',
#  'chalampe',
#  'staffelfelden',
#  'staffelfelden d',
#  'sainte croix en plaine',
#  'colmar-sud-1',
#  'muntzenheim',
#  'artzenheim',
#  'mackenheim',
#  'muttersholtz',
#  'saint-pierre r1',
#  'grunsbuhl (schaeffersheim)',
#  'erstein',
#  'schaeffersheim',
#  'schaeffersheim (erstein)',
#  'binnenweg',
#  'meistratzheim',
#  'eschau',
#  'lipsheim',
#  'holtzheim',
#  'cronenbourg',
#  'kilstett',
#  'schirrhein',
#  'schweighouse sur moder',
#  'roeschwoog',
#  'rountzenheim',
#  'donau',
#  'donau (soufflenheim)',
#  'donau bis',
#  'donau bis (soufflenheim)',
#  'beinheim',
#  'rohrlach',
#  'hitzeln',
#  'rittershoffen',
#  'rittershoffen (oberbetschdorf)',
#  'schaffhousse (kesseldorf)',
#  'abwaender',
#  'reimerswiller',
#  'schelmenberg',
#  'soultzegs',
#  'knoeringue (steinsoultz)',
#  'preuschdorf',
#  'soultz sous forêts',
#  'oberlauterbach',
#  'guckenberg',
#  'muenzfeld',
#  'neewiller nord',
#  'neewiller nord (scheibenhard)',
#  'marienbronn',
#  'niederlauterbach',
#  'salmbach',
#  'scheibenhard',
#  'niederlauterbach',
#  'niederlauterbach',
#  'pico da orizaba',
#  'miami',
#  'naples',
#  'west palm beach',
#  'tampa',
#  'plant city',
#  'beeville',
#  'orlando',
#  'daytona beach',
#  'san antonio',
#  'presidio',
#  'gainesville',
#  'apalachicola',
#  'transvaal',
#  'gerhardminnebron bore',
#  'dubbeldevei bore',
#  'dubbeldevlei bore',
#  'bushveld',
#  'kestell bore',
#  'orange free staate',
#  'orange free state',
#  'transvaal (bytonite)',
#  'kestell borehole',
#  'loraine borehole',
#  'austin',
#  'marfa',
#  'pensacola',
#  'tallahassee',
#  ...]

# %%
list_geoloc_det = []
with open ('ryan_.txt', 'r') as f:
    for item in f:
        list_geoloc_det.append(f.read())

# %%
for i in list_geoloc_det:
    print(i)
# Out:
# southern urals
# kuznetsk alatau
# berikul region
# klyuchovsky volcano
# kamchatka
# rockport
# belokurikhinsky massif
# altai
# val verde
# porterville
# frederick
# maryland
# westerly
# westfield
# peninsula station
# ont.
# vinal haven
# maine
# barre
# farm doornspruit
# sylmar
# french creek
# stillwater igneous complex
# new glasgow
# mellen
# pilansberg
# balsam gap
# allentown
# bethlehem
# nazareth
# pennsylvania
# pelham
# proctor
# solnhofen
# offshore louisiana
# texas
# kyushu
# mie
# aichi
# kyoto
# oklahoma
# fukushima
# colorado
# iwate
# utah
# wyoming
# hokkaido
# oregon
# twin sisters mountain
# madneuli
# shaori reservoir
# akhalkalaki highlands
# karatsu
# ichinomegata
# horoman
# chiatura
# central asia
# dzirula massif
# jraber
# upper rhine graben
# black forest
# vosges
# upper rhine graben
# koytas
# kandygatay mts.
# kalbinsky massif
# shindinsky massif
# southwest german molasse basin
# south arne
# north sea
# near freiburg
# black forest
# near offenburg
# tyger-tysh ridge
# ulen-tuimsky massif
# uybatsky massif
# karymsky volcano
# kamtchatka
# mid-atlantic ocean ridge
# hawaii
# cerro prieto
# mexicali
# ohio
# kentucky
# west virginia
# idaho
# higo metamorphic belt
# hadaki metamorphic belt
# beni bouchera massif (beni bouzere)
# ivrea zone
# lofoten-vesteralen region
# austvagoya
# langoya
# salem
# mysore
# pallavaram
# madras
# chennai
# tamil nadu
# podili
# kurnool
# andhra pradesh
# vinukonda
# guntur
# vijayawada
# kondapalli
# hyderabad
# yellandalpad
# yellandu
# manditog
# waltair
# visakhapatnam
# maharashtra
# talchir
# chaibasa
# bundelkhand
# south uttar
# north madhya pradesh
# bihar
# kishengarh
# rajasthan
# rajputana
# shahabad
# sujarghar
# halemaumau
# hawaii island
# hualai flow
# india
# maui island
# salt lake crater
# oahu island
# honolulu
# kauai
# molokai or niihau island
# scotland
# sendai
# miyagi prefecture
# hagino
# yamagata prefecture
# nishimonai
# akita prefecture
# tanohata
# iwate prefecture
# transvaal
# usa
# south africa
# hengill
# nesja-vellir
# krafla
# kazakhstan
# caucasus
# pavlovsk
# reunion island
# oskoletsk
# voronezh anteclise
# saltykov
# voronezh massif
# north karelia
# sakhalin island
# mamonov complex
# voronezh massif
# gorky oblast
# oblast of nishni novgorod
# south ural mountains
# ussr far east
# ural
# monchegorsk
# kola peninsula
# pechenga
# seychelles
# gegam plateau
# bezumskiy ridge
# sikhote-alin-ridge
# gorky complex
# udzha river
# indian ocean ridge
# indian ocean island
# referred to as gondwana island
# armenia
# borisov volcano
# baikal region
# avachinsk volcano
# lake baikal
# obnazhennaya formation
# southeast corner of þingvallavatn
# surtsey
# heimaey
# reykjanes
# sandfell
# þrengsli
# vigdísarvelli
# tófubruna hyaloclastited
# vigdísarvellir
# reykjanes
# krísuvík road
# silfurberg
# north of kögunarhóll
# ingólfsfjall quarry
# votuklettar-threngsli
# slightly west of votuklettar
# hyaloclastite
# north of tindafjalla
# west of kirkjufellsós
# raudhnukar
# bláfjalla
# hafnarfjardar
# west
# hveradalaskálinn
# dómadalur
# þjórsárholt
# vörðufell
# hellisskarð
# hengill
# fossá
# krókagiljabrún
# lambafitjahraun
# valahnúkar
# valahnúkar on dómadalsroute
# gaukshöfdi
# idntaeknistofnun
# hyaloclastite
# reykholt
# mosfellsbaer
# reykholt biskupstungur
# thjorsárdalur
# miðfell
# dolerite
# kollafjordur
# laugardalshellir
# stora dímon
# arnarfell
# skefilsfjoll eldri
# skefilsfjoll yngri
# meðalfell
# baejargil
# blákollur
# iceland
# helgafell
# arnarthufa
# vifilfell
# awibengkok
# groß schönebeck
# geitafell volcano
# krafla
# volcano
# evrona
# gerofit
# ora
# samar
# zihor
# well sinaf-1
# tamardol
# well ramon-1
# well avdat-1
# en yorq
# hevyon
# ghareb
# avnon
# mishash
# nezer
# shivta
# well maka-36
# menuha
# tamar
# well hmch-1
# well hm-1
# taqiye
# well daya-1
# well hltza-2
# well hzrm-1
# well bshev-1
# well gurim-3
# well zhrd-8
# well zohar-1
# well dshet-1
# well hlz-2
# well hlz-37
# well negba-1
# karnei-hitin volcano
# weiss-kaul
# west of rümelingen
# belvaux
# giele botter
# profile kinett
# east of moutfort
# rebierg
# züschschiefer
# kirchberg
# grouft
# wasserbillig vormann
# mersch
# ell
# rosswinkel
# everlange
# wartenstein
# martelange
# ingeldorf
# radelange
# reisdorf
# stolzemburg
# schüttburg
# mirwart
# ardennes
# clerf
# berlé
# wiltz
# sainthubert
# villé
# oignies
# la gleize
# bihain
# fépin
# meuville
# colanhan
# lierneux
# les plattes
# hour
# grand halleux
# wanne
# la venne
# spa
# solwaster
# belleaux
# east pacific rise
# schwerin
# neubrandenburg
# stralsund
# pan-african damara
# alps
# lachlan fold belt
# namaqua mobile belt
# jequié
# penokean orogen
# jequie complex
# new hampshire
# galicia-tras-os-montes zone
# naraku batholith
# mount isa
# superior province
# canadian shield
# variscan batholith of corsica
# taiwan volcanic zone
# zimbabwe
# tethyan neyriz opholite complex
# coso volcanic field
# westasturian-leonese
# norris creek
# tarenga shale
# biritish caledonian
# burnside
# pine creek
# mount webb
# arunta inlier
# idaho batholith
# variscan crust
# corsica
# njiri
# dharwar craton
# central african plateau
# oulmès metamorphic aureole
# sonhat basin
# son valley
# warrego
# tennant creek
# dawson
# continental crust
# sybella batholith
# vosges
# schwarzwald
# bear lake
# karnataka
# sierra la primavera
# sybella batholith
# kong oscar fjord
# tinemaha granodiorite
# st. malo
# provencal basin
# langtang valley
# natawahunan lake
# damara belt
# central-iberian zone
# merced peak
# cauchon lake
# singhbhum trust belt
# hidden bay pluton
# sierra nevada batholith
# turku area
# chemehuevi mountains
# shellenbarger lake
# kaapvaal craton
# kalkadoon
# timber knob
# betics
# alpujárrides
# red peak
# southwark
# arunta inlier
# tennant creekt
# kimberlite pipes
# chintalapudi basin
# godavari valley
# trois segneurs massif
# post peak
# paperbark
# kimberley
# vredefort structure
# bodrum volcanic complex
# grandhalleux
# kolar schist belt
# west african kimberlites
# ossa morena zone
# westasturian-leonese zone
# querigut complex
# maláguides
# belén
# cordón tucúaro
# iberian range
# moresby strait area
# oxford lake
# shaler pluton
# sally downs
# kimberley
# central eastern china
# closepet granite
# southwestern alaska
# comte
# strona valley
# samrée
# quebrada tajamar
# gulf of mexico basin
# nevado-filábrides
# eastern virunga province
# eastern australia
# quebrada choja
# urals
# vivero massif
# captains bay pluton
# manaslu granite
# arita
# pam lin island
# st. andrew strait
# basotu
# grenville province
# jackass lakes
# minarets complex
# etendeka region
# santa rosa de tastil
# arcot-pallavaram
# pyrenees
# limpopo belt
# trans-hudson orogen
# tehachapi mts
# salar de navidad
# ochaquí
# lamrômenil
# longido
# ghanzi-chobe fold belt
# cantabrian zone
# ebolowa area
# ntem complex
# pingo pingo
# salar de diablillos
# utik lake
# sao paulo
# cananéia-iguape lagoon
# tuluman island
# finger bay pluton
# kirn
# namaqua-natal belt
# nanking
# dodoma
# kerguelen plateau
# voisey bay
# iowa
# bp-1
# bp-2
# verril canyon
# mic mac
# bp-3
# ne volcanic province
# spain
# kansas c
# choschas
# south atlantic
# solya
# bp-4
# bp-5
# sierra de macón
# sinuyu
# east african rift
# merapi volcano
# kansas
# pikwitonei
# sachigo
# charmuria limestone
# sierra nevada
# plagidac
# mississauga
# champua thrust belt
# logan canyon
# kansas
# cordón chinquilchoro
# dawson canyon
# kaiserstuhl
# pacific ocean
# kagalaska pluton
# kanyemba
# peninsula de mejillones
# northern apennines
# kastamonu
# sesia–lanzo zone
# redwig
# tanlu fault
# pikwitonei lake
# garua harbour
# mohican
# renco
# santa lucia mts
# aleutian islands
# paraná-etendeka province
# jericho kimberlite pipe
# zagros suture zone
# sierra limón verde
# banquereau
# morbs & oibs
# andean
# goulet lake
# saitoco
# mount garbuna
# new britain
# columbia river basalt
# mount welcker
# luzon
# holili
# lau ridge
# sugarloaf pluton
# chinese peak
# sana'a-amran volcanic field
# garove island
# lesser antilles
# cordón de lila
# nelson river
# peninsula de majillones
# abenaki
# aleutian
# bagana volcano
# lolobau island
# cape reilnitz
# aleutian arc
# sulu range
# pikwitonei river
# limpopo belt
# atlantic ocean
# kansa pathar
# cascades
# central america
# kermadec
# niuatoputapu
# scotia
# boninites
# big creek
# caribbean-columbian oceanic plateau
# marianas
# piñón oceanic plateau
# late
# burntwood river
# cape hoskins volcanoes
# ontong java plateau
# deep sea drilling
# site
# mid ocean ridge
# indian ocean
# jijicao
# xinchang
# cuitzeo lake
# quinceo-tetillas
# guadalajara
# cuitzeo lake
# los humeros geothermal field
# ischia
# solfatara
# bolsena
# vulsini volcanic zone
# akranes
# ferstikla
# borgarfjarðarsveit
# búlandshöfði
# grundarfjarðarbær
# gullbringusýsla
# mfa-1
# mfa-2
# mfa-3
# hafnarfjall
# hoffell
# dakeng
# hrafnabjörg
# hveragerði
# innrihólmur
# klafastaðir
# kúludalsá
# leirá
# kolgrafir í eyrarsveit
# leirár- og melahreppur
# leirárdalur
# demre
# finike
# mut
# fethiye
# korkuteli
# meke
# karaman
# milas
# yatagan
# bucak
# kolsuz
# gödene
# kilavuzkoy
# ückapili
# kavlaktepe
# gümüsler
# altinhisar
# yesilburc
# hazro
# kemalpasa
# ortaköy
# bunyan
# iscehisar
# altintas
# kozak
# kaman
# yildizeli
# sögütalan
# marmara island
# porrino
# mosfellsbær
# lýsuhóll
# reykjavík
# seleyrargil
# ytrihólmur
# skilmannahreppur
# þyrill
# skorradalshreppur
# stóra-drageyri
# snæfellsbær
# sandabotnaskarð
# ek-105
# kan-3
# nc-99
# 98-46
# ku5
# mp-98
# mp-101
# 98-78
# 98-89a
# 98-39
# 306i
# 316i
# 98-43b
# ko2
# klausturtunguhóll
# western snókur
# hafnarfjall caldera
# leirárdalur
# leirárdalur gully
# east of klausturtunguhóll
# nevada
# north german basin
# eulenflucht
# groß buchholz
# east of snókur
# western canada sedimentary basin
# alberta basin
# well
# hof trages
# freigericht-somborn
# lesesteine w stolzenberg
# bad soden-salmünster
# feldweg böschung
# kinzig-stausee
# ost
# west
# rothenberg
# alzenau-kälberau
# 06-11-051-26w4
# alter steinbruch
# gap lake
# alberta
# canada
# hohlweg rauher berg
# 15-23-036-10w5
# grassi lakes
# canmore
# whitemans pond
# maisenheimer hof
# nigel peak
# alberta canada
# steinbruch
# niedermittlauer
# heiligenkopf
# gelnhausen-meerholz
# klosterruine
# berg
# gründau-breitenborn
# steinbruch
# schnepfenkopf
# gelnhausen
# kalkwerk firma hufgard
# hösbach-rottenberg
# kleiner aufschluss
# freibad gelnhausen-roth
# steinbruch
# heiligenkopf
# steinbruch
# heinrichshöhe
# lochmühle
# biebergemünd-bieber
# anschnitt b276
# wächtersbach
# altegrube
# gelnhausen-höchst
# steinbruch
# altenhaßlau
# linsengericht-altenhaßlau
# steinbruch
# nassbüchelbach
# altenmittlau
# anschnitt
# kreuzung
# burgfelsen
# alzenau-burg
# alzenau
# steinbruch
# gelnhausen-roth
# steinbruch
# neuenberg
# penken
# tauernfenster
# nordrand
# österreich
# hohlweg
# steinbrüche e bad orb
# pfannköpfl
# biebergemünd-kassel
# tettensjoch
# steinbruch kerkelberg
# biebergemünd-roßbach
# alter steinbruch am hirschberg
# steinbruch wintersberg
# bad orb
# finkenberg
# langenselbold
# alter steinbruch herzberg
# bahnhofstraße
# alte tongrube
# elsbach
# alter kalksteinbruch
# sonnenberg
# gelnhausen-hailer
# tongrube hailer
# dornau am tuxbach
# wasserfall am elsbach
# altes kalkwerk firma ickes
# elsalm
# schraubenfall
# acker auf dem mühlberg
# langenselbold
# steinbruch franzosenkopf
# huckelheim
# neuer steinbruch
# sw hösbach-rottenberg
# tuxer joch
# weitental
# lachtalscharte
# schwarze pfanne
# bahnhof mittelgründau
# parkplatz hanauer straße
# tongrube firma zeller
# neuburg-ravolzhausen
# tongrube bettenburger loch
# schöneck-oberdorfelden
# 10-31-37-9w5
# rosenthal
# arbonne la foret
# aura
# sterbfritz
# hessen
# deutschland
# piarere
# te awamutu
# waikat
# waotu
# cedar creek
# mount tamborine
# te puke
# whakaari
# the taupo volcanic zone
# gonghe basin
# zotzenbach
# nieder-liebersbach
# scharbach
# campi flegrei
# naples
# caserta
# monte san serverio
# colli albani
# mt. etna volcano
# stromboli volcano
# rhode island
# bentheim
# darley dale
# seljadur
# kirschhausen
# wald-erlenbach
# krumbach
# bonsweiher
# taupo
# waihi
# tauposees
# papamoa
# turangi
# straßenaufschluss
# pfalz
# grabenschulter
# oberrheingrabens
# odenwald
# grabenschulter
# spessart
# mainufer
# triefnebachtales
# kirchheimbolanden
# tunnelbaustelle
# widderstall
# lhd4-653
# lhd4-852
# lhd4-1002
# lhd4-2305
# lhd5-603
# lhd5-753
# lhd5-1103
# lhd5-1406
# lhd5-1576
# lhd1-2101
# lhd1-501
# lhd1-802
# lhd1-1001
# lhd1
# lhd7-902
# lhd7.8-1568
# lhd7-1758
# lhd2-302
# lhd3-2203
# mount st. helen
# spine-forming eruption
# mount meager volcano
# cascade volcanic
# st. augustine volcano
# cinderblock lava
# reykjanes
# castle creek period
# kid dome gulley
# el zarco riverbed
# kumamoto prefecture
# mount etna volcano
# rotokawa
# volcán de colima
# river harsit
# kürtün dogankent
# piesberg
# osnabrück
# bruchsal
# knittlingen
# seebach
# raumünzach
# karlsruhe
# wilferdingen
# pforzheim
# albersweiler
# waldhambach
# buntsandstein
# göbel
# palatinate forest
# th18
# tauhara geothermal field
# thm12
# thm19
# thm14
# thm18
# thm17
# thm13
# kailash tila-2
# bengal basin
# titas-11
# bakhrabad-10
# shahbazpur-1
# kwv-1
# ecca pass
# eastern cape
# koksharovskoe plateau
# ussr maritime region (primorskiy krai)
# russian platform
# lovozero formation
# kurginsk formation
# anabar bed
# kimpersay massif
# aldan
# tanba belt
# synnyr complex
# khibiny mountains
# caucasus
# oboyansk
# gorky region
# nishni novgorod
# oboyansk
# nishni novgorod
# escandorgue lava flow
# lunas
# dévés lava flow
# senouire vallée
# josat
# norseman
# broken hill
# coolgardie
# kalgoorlie
# west-australien
# south and west australia
# heimersdorf
# illfurth
# michelbach
# schweighouse
# chalampe
# staffelfelden
# sainte croix en plaine
# colmar-sud-1
# muntzenheim
# artzenheim
# mackenheim
# muttersholtz
# saint-pierre r1
# grunsbuhl
# schaeffersheim
# erstein
# binnenweg
# meistratzheim
# eschau
# lipsheim
# holtzheim
# cronenbourg
# kilstett
# schirrhein
# schweighouse
# moder
# roeschwoog
# rountzenheim
# donau
# soufflenheim
# donau
# soufflenheim
# beinheim
# rohrlach
# hitzeln
# rittershoffen
# oberbetschdorf
# schaffhousse
# kesseldorf
# abwaender
# reimerswiller
# schelmenberg
# soultzegs
# knoeringue
# steinsoultz
# preuschdorf
# soultz sous forêts
# oberlauterbach
# guckenberg
# muenzfeld
# neewiller nord
# scheibenhard
# marienbronn
# niederlauterbach
# salmbach
# scheibenhard
# niederlauterbach
# niederlauterbach
# pico da orizaba
# miami
# naples
# west palm beach
# tampa
# plant city
# beeville
# orlando
# daytona beach
# san antonio
# presidio
# gainesville
# apalachicola
# transvaal
# gerhardminnebron bore
# dubbeldevei bore
# dubbeldevlei bore
# bushveld
# kestell bore
# orange free state
# transvaal
# bytonite
# kestell borehole
# loraine borehole
# austin
# marfa
# pensacola
# tallahassee
# baton rouge
# mobile
# valdosta
# jackson
# van horn
# hueco tanks
# brunswick
# dothan
# best
# alexandria
# hattiesburg
# nogales
# douglas
# pecos
# san angelo
# waco
# natchez
# el paso
# clifton
# canutillo
# masjed soleyman
# masjid-i-sulaiman ir
# tucson
# las cruces
# meridian
# montgomery
# ajo
# carlsbad
# phenix city
# shreveport
# hobbs
# san diego
# silver city
# dallas
# el centro
# binghamton
# macon
# greenville
# el dorado
# georgetown
# mesa
# texarkana
# phoenix
# north augusta
# aiken
# west point
# sherman
# santa ana
# atlanta
# long beach
# marble canyon
# safford basin
# athens
# gadsden
# los angeles
# socorro
# san bernardino
# twentynine palms
# ardmore
# florence
# wilmington
# rome
# tupelo
# st. johns
# helena
# prescott
# beaufort
# little rock
# strauss
# zuni
# needles
# holbrook
# spartanburg
# chattanooga
# albuquerque
# west memphis
# kingman
# flagstaff
# charlotte
# williams
# russellville
# san luis obispo
# roesburg
# randsburg
# bakersfield
# fort smith
# oklahoma city
# clinton
# gallup
# tehran
# trona
# raleigh
# manteo
# blytheville
# rocky mount
# knoxville
# dyersburg
# greensboro
# winston-salem
# tulsa
# salton sea
# death valley
# gass valley
# las vegas
# harrison
# johnson city
# perryton
# woodward
# fresno
# poplar bluff
# norfolk
# raton
# santa cruz
# joplin
# jenkins
# roanoke
# durango
# san jose
# cortez
# eastville
# mariposa
# richmond
# ironton
# caliente
# pratt
# cedar city
# goldfield
# dodge city
# escalante desert
# san francisco
# rolla
# lemmon
# st. la
# tyler
# victoria
# waington
# huntington ams
# mcalester
# medford
# palestine ams
# valentine ne
# waington ams dst col
# elmira
# enid
# fresna
# hot springs
# cap rock gulf coast
# cap rock
# gulf coast
# berkeley
# new mx and texas
# eastern and western usa
# eastern usa
# mount givens
# ralston valley
# western usa
# michigan
# drum-keg mtns
# madison county
# buffalo valley
# cabezon prospect
# cactus prospect
# churchill valley
# early morning
# finally
# fish lake
# alum
# glass buttes
# grandview
# huntoon valley
# little mountain
# marysville - butte ams
# mccoy
# old pete
# panther canyon
# rawhide-black eagle
# ruby valley
# stillwater
# surprise valley
# white pine
# dayton-sutro
# ely
# charlottesville
# hutchinson
# tonopah
# pueblo
# salisbury
# great bend
# vya
# walker lake
# steamboat springs
# leach hot springs
# terraced hills
# tuscarora sulphur springs
# baltazor-mcgee
# black rock desert
# dixie valley
# fallon - salt wells
# garfield flat
# santa rosa
# canon city
# montrose
# scott city
# moab
# sacramento
# richfield
# greenwood
# lund
# salina
# lawrence
# geq..br-10
# usgs cloverdale
# ggc-120918-1
# geo-ng-31
# geo-tv-8
# geo-hs-8
# geo-lr-9
# ggc-kx-8
# ggc-kx-9
# ggc-blm-1
# ggc-hs-2
# geo-hs-9
# geo-hs-19
# cl-18
# geo-hs-25
# geo-hs-26
# geo-hs-39
# geo-hs-7
# geo-seg-6
# geo-gp-1
# geo-gp-1a
# geo-gp-3
# geo-tv-2
# ch-rm-5
# ch-rm-14
# grand junction
# adams tunnel
# san luis valley
# eleven mile canyon
# kansas city
# ukiah
# leadville
# clarksburg
# baltimore
# goodland
# delta
# beloit
# pirouette mountain
# reno
# chico
# denver
# monroe-red hill
# spor mountain
# twin peaks
# fifthwater
# lovelock
# mccook
# harrisburg
# roosevelt
# kyle hot springs
# susanville
# greeley
# vernal
# tooele
# redding
# nebraska city
# newark
# salt lake city
# lincoln
# winnemucca
# wells
# dubois
# north platte
# cheyenne
# scranton
# weed
# fremont
# alturas
# brigham city
# rock springs
# rawlins
# providence
# warren
# scottsbluff
# preston
# alliance
# adel
# klamath falls
# rockford
# boston
# sioux city
# twin falls
# albany
# lander
# adula
# casper
# pocatello
# new boston
# jordan valley
# jorden valley
# queenston
# martin
# arminto
# roseburg
# chester
# glens falls
# lake champlain
# crescent
# idaho falls
# hailey
# sioux falls
# burns
# boise
# thermopolis
# fairmont
# portland
# toronto
# mitchell
# newberry volcano
# driggs
# newcastle
# beulah
# vinalhaven
# bend
# ashton
# rapid city
# lewiston
# raft river
# adligenswil lu
# gillette
# lead
# pierre
# canyon city
# challis
# madoc
# cody
# anzola
# santiam pass
# longford mills
# ogdensburg
# baker city
# bangor
# philipsburg
# dillon
# milbank
# mte. leone
# antigorio
# candoglia
# crevola
# la grande
# ivrea
# rice lake
# novate milanese
# the dalles
# vancouver
# malenco
# devero
# disgrazia
# pendleton
# bozeman
# calumet island
# billings
# savoie
# grangeville
# forage gare
# butte
# mattarello
# walla walla
# montescheno
# baltschiedertal
# dervio
# beura
# iron river
# thetford mines
# humilly
# domodossola
# faucigny
# weissmies
# gex cd04
# gondo
# simplon
# thônex
# varzo
# hamilton
# gex cd01
# gex cd07
# verzasca
# baceno
# forsyth
# leventina
# maggia
# malcantone
# riviera
# robiei
# bavona
# cavagnoli
# centovalli
# sissone
# brig
# poschiavo
# peccia
# basodino
# sambuco
# avers
# greater sudbury
# white sulphur springs
# splügen
# grimsel
# yakima
# romanenes-1
# chapelle-1
# st. marc des carrieres
# essertines-1
# orbe
# julier
# rofla
# schin
# bergell
# bernina
# calanca
# pullman
# grandson
# linden-1
# courtion
# fargo
# hoquiam
# gotthard tunnel
# switzerland
# loetschberg tunnel
# simplon tunnel
# meeresmolasse
# schweizerischen
# süsswassermolasse
# unteralptal
# gotthard
# tschugg-1
# two harbors
# kriens lu
# malters lu
# sonnenberg lu
# littau lu
# burgdorf m1400
# hermrigen-1
# ruppoldsried
# dierikon lu
# udligenswil lu
# root lu
# längenbold lu
# copalis beach
# meierskappel lu
# hancock
# ritzville
# zug
# hünenberg-1
# menzingen zg
# pfäffikon sz
# altishofen
# pfaffnau-süd
# bäch sz
# pfaffnau-süd-2
# jona
# uznach sg
# pfaffnau-1
# calumet
# goldingen sg
# uetikon a.s.
# zürichsee
# boswil-1
# boppelsen
# thalwil
# wattwil sg
# egg zh
# mönchaltorf zh
# küsnacht-1
# arlberg tunnel
# tauern tunnel
# travern tunnel
# ausria
# tiefenbrunnen
# aqui-1
# aqui-2
# zürich
# schafisheim
# zürich-dolder
# jura
# fehraltorf
# sandpoint
# aarau
# madetswil zh
# gubrist
# wenatchee
# oetwil a.l.
# au sg
# st. margrethen
# lindau-1
# arnegg
# walzenhausen sg
# gtb bassersdorf
# buechen sg
# buchs zh
# otelfingen
# buechsberg sg
# augwil
# bemidji
# wallace
# goldach
# bachenbulach
# bülach-iw
# bülach-w
# bulach
# thief river falls
# weiach
# buchberg
# seattle
# herdern-1
# kreuzlingen-1
# kreuzlingen-2
# spokane
# berlingen-1
# choteau
# kinding
# grand forks
# ellighofen
# steinbruch bollschweil
# 79283 bollschweil
# liptingen
# larder lake
# malartic
# kirkland lake
# williston
# strassberg
# am plettenberg
# minot
# vohenbrunnen
# okanogan
# östlich gerhausen
# herrlingen
# timmins
# moosburg
# moosburg sc4
# concrete
# landkreis calw
# baden-württemberg
# neidlingen
# östlich mergelstetten
# haardtbruch
# langenaltheimer haardt
# oberdolling
# südöstlich hülen
# wasseralfingen
# braunen
# berg
# eichstätt
# wasserzell
# solnhofen
# maxberg
# soultz-sous-forets
# arzberg bei köttingwörth
# crailsheim
# deutschlan
# waldhambach
# vilshofen
# albersweiler
# saarbrucken
# neckarsteinach
# ruine hinterburg
# wölsendorf
# neckarhausen
# schlossbuckel
# hirschhorn
# höhe
# gräfenberg
# ersheim
# se´ ersheim
# westrand hirschhorn
# igelsbach
# böser berg
# hebstahl
# sensberg
# zitterberg
# gammelsbach
# flockenbusch
# rauschenbuckel
# welchel
# unter-abtsteinach
# unter-sensbach
# unter-sensbach
# unter-schönmattenwag
# oberdorf
# ober-schönmattenwag
# kailbach
# seckenrain
# falken-gesäß
# beerfelden
# ober-sensbach
# knosebuckel
# voeckelsbach
# winnweiler
# wingertsweilerhof
# winnweiler wald
# kiesebuckel
# winneiler rotes kreuz
# aschbach
# vöckelsbach
# hetzbach
# olfen
# affolterbach
# drügendorf
# marbach
# kocherbach
# hubenstrich
# zotzenbach
# ireneturm
# scharbach
# rimbach
# münschbach
# jungholzhöhe
# hüttenthal
# wahlen
# rimbach
# fahrenbacher kopf
# schönnen
# litzelbach
# lenzenbuckel
# ittlinger mühle
# simmelsdorf
# rimbach
# fahrenbacher kopf
# erbach
# hammelbach
# erbach
# steinkopf
# sonderbach
# grasellenbach
# albersbach
# steinbach
# hammelbach
# erlenbach
# erlenbach
# steinbruch
# heppenheim
# unterhalb
# starkenburg
# erbach
# kirschhausen
# weschnitz
# dorf-erbach
# unter-mossau
# kirschhausen
# lindenstein
# kirschhausen
# silbergrubenkopf
# ernsbach
# brombach
# abzweig
# brombach
# ellenbach
# erlenbach
# krumbach
# siegfriedstraße
# ober-hambach
# lindenstein
# rohrbach
# gronau (eichel-berg)
# michelstadt zentrum
# sportplatz michelstadt
# kirche steinbach
# e´ gipfel stickelberg
# gesäß
# miltenberg
# bayern
# hembach
# steinbruch am wannberg
# vogelherd
# etzen-gesäß
# ostrand etzen-gesäß
# klein-bieberau
# tannenkopf
# niedernhausen
# mümling-grumbach
# hardt-berg
# hassenroth
# frankenstein
# sportplatz seckmauern
# langer berg
# höchst im odenwald
# schorsch-berg
# queck
# vogelsbergkreis
# veste otzberg
# wiebelsbach
# heidel-berg
# da-eberstadt
# kohlberge
# frau nauses
# burzel-berg
# auen
# willigis kapelle
# erbendorf
# zufahrt firma frenger
# ortseingang heubach
# wiebelsbach-heubach
# flur
# flurstück
# dieburg
# grube messel
# steinbruch mainzer berg
# buchenbusch
# spitzelberg
# golfplatz hof trages
# eppstein-fischbach
# natursteinwerke
# fischbach
# königsteiner
# burgberg
# taunus
# falkensteiner
# hain
# kronberg
# waldschwimmbadm
# altkönig
# berges
# hünfelden
# gelnhaar
# ortenberg-gelnhaar
# hessen
# kransberg
# beselich
# runkel
# weilmünster
# neuhof
# braunfels
# langgöns
# hilders
# wetzlar
# breitscheid
# herborn
# dillenburg
# bad endbach
# weimar
# lehrbach
# grebenau
# eschenburg
# angelburg
# marburg
# steffenberg
# neukirchen
# kirchhain
# gilserberg
# sontra
# mittelrhein
# hansa
# cottaer
# postaer
# germany
# grube jägerfreude richtstrecke
# frankenau
# steinbruch
# schuchardt
# cornberg
# armsfeld
# bad wildungen
# fürstenberg
# blaue kuppe
# eschwege
# fritzlar
# küchen
# vöhl
# waldeck
# albungen
# bahndamm
# berkatal
# steinbruch
# berkatal
# oppermann
# albungen
# albungen
# hitzerode
# motzerode
# albungen
# bad sooden
# allendorf
# schauenburg
# arolsen
# braunsen
# felsberg
# warburg
# diemelstadt
# bad karlshafen
# trendelburg
# poland
# ronnenberg
# hänigsen
# st. albert
# halford
# mont-st-hilaire
# rimouski
# st-anaclet
# st-eustache
# st-joseph-de-beauce
# st-marc-des-carrières
# westerley
# athabasca
# trans-hudson orogen
# percy island
# duke island
# kaldbaksfjordur
# faroe islands
# skulaskeid
# geldingafell
# kolgrafir
# herdubreid
# hottur
# seydisfjordur
# saeberg
# glera river
# akureyri
# tjaldfell
# sao miguel
# azores

# %%
with open ('list_geolocation.txt', 'w') as f:
    for item in list_geoloc_det:
        f.write(str(item) + '\n')

# %% [markdown]
# ### Countries

# %%
list_countries_det = ['Afghanistan', 'Aland Islands', 'Albania', 'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Anguilla', 'Antarctica', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia, Plurinational State of', 'Bonaire, Sint Eustatius and Saba', 'Bosnia and Herzegovina', 'Botswana', 'Bouvet Island', 'Brazil', 'British Indian Ocean Territory', 'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde', 'Cayman Islands', 'Central African Republic', 'Chad', 'Chile', 'China', 'Christmas Island', 'Cocos (Keeling) Islands', 'Colombia', 'Comoros', 'Congo', 'Congo, The Democratic Republic of the', 'Cook Islands', 'Costa Rica', "Côte d'Ivoire", 'Croatia', 'Cuba', 'Curaçao', 'Cyprus', 'Czech Republic', 'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia', 'Ethiopia', 'Falkland Islands (Malvinas)', 'Faroe Islands', 'Fiji', 'Finland', 'France', 'French Guiana', 'French Polynesia', 'French Southern Territories', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada', 'Guadeloupe', 'Guam', 'Guatemala', 'Guernsey', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti', 'Heard Island and McDonald Islands', 'Holy See (Vatican City State)', 'Honduras', 'Hong Kong', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran, Islamic Republic of', 'Iraq', 'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jersey', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', "Korea, Democratic People's Republic of", 'Korea, Republic of', 'Kuwait', 'Kyrgyzstan', "Lao People's Democratic Republic", 'Latvia', 'Lebanon', 'Lesotho', 'Liberia', 'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Macao', 'Macedonia, Republic of', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'Marshall Islands', 'Martinique', 'Mauritania', 'Mauritius', 'Mayotte', 'Mexico', 'Micronesia, Federated States of', 'Moldova, Republic of', 'Monaco', 'Mongolia', 'Montenegro', 'Montserrat', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Caledonia', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Niue', 'Norfolk Island', 'Northern Mariana Islands', 'Norway', 'Oman', 'Pakistan', 'Palau', 'Palestinian Territory, Occupied', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Pitcairn', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar', 'Réunion', 'Romania', 'Russian Federation', 'Rwanda', 'Saint Barthélemy', 'Saint Helena, Ascension and Tristan da Cunha', 'Saint Kitts and Nevis', 'Saint Lucia', 'Saint Martin (French part)', 'Saint Pierre and Miquelon', 'Saint Vincent and the Grenadines', 'Samoa', 'San Marino', 'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore', 'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia', 'Solomon Islands', 'Somalia', 'South Africa', 'South Georgia and the South Sandwich Islands', 'Spain', 'Sri Lanka', 'Sudan', 'Suriname', 'South Sudan', 'Svalbard and Jan Mayen', 'Swaziland', 'Sweden', 'Switzerland', 'Syrian Arab Republic', 'Taiwan, Province of China', 'Tajikistan', 'Tanzania, United Republic of', 'Thailand', 'Timor-Leste', 'Togo', 'Tokelau', 'Tonga', 'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu', 'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom', 'United States', 'United States Minor Outlying Islands', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela, Bolivarian Republic of', 'Viet Nam', 'Virgin Islands, British', 'Virgin Islands, U.S.', 'Wallis and Futuna', 'Yemen', 'Zambia', 'Zimbabwe']

# %%
with open ('list_countries.txt', 'w') as f:
    for item in list_countries_det:
        f.write(str(item) + '\n')

# %% [markdown]
# ### State

# %%
df = pd.read_excel('C:/Users/Ryan Bobby A/Documents/RWTH AACHEN/KULIAH/THESIS_BISMILLAH/Thesis Progress/Target Data/State_P3.xlsx')

# %%
list_state = []
for i in df.values.tolist():
    if i[0] not in list_state:
        list_state.append(i[0])
    else:
        pass

list_state = list_state[0:list_state.index('BR')]
list_state = [str(i).lower() for i in list_state]

# %%
list_state_det = ['massachusetts',
 'california',
 'rhode island',
 'vermont',
 'transvaal',
 'pennsylvania',
 'montana',
 'quebec',
 'wisconsin',
 'north carolina',
 'bavaria',
 'louisiana',
 'texas',
 'oklahoma',
 'colorado',
 'utah',
 'wyoming',
 'oregon',
 'washington',
 'kyushu',
 'akita',
 'hokkaido',
 'atlantic ocean',
 'hawaii',
 'java',
 'brandenburg',
 'schleswig-holstein',
 'western namibia',
 'southeastern australia',
 'western south africa',
 'bahia',
 'michigan',
 'new hampshire',
 'iberian peninsula',
 'queensland',
 'ontario',
 'corsica',
 'north taiwan',
 'central',
 'ávila',
 'fars',
 'inyo county',
 'chhattisgarh',
 'scotland',
 'northern territory',
 'central zimbabwe',
 'idaho',
 'singida',
 'southern india',
 'otjozondjupa',
 'central zambia',
 'khémisset',
 'dawson strait',
 'baden-württemberg',
 'manitoba',
 'karnataka',
 'jalisco',
 'east greenland',
 'sierra nevada',
 'bretagne',
 'southern france',
 'central northern nepal',
 'karas',
 'jharkand',
 'alaska',
 'southern finland',
 'eastern south africa',
 'scottland',
 'andhra pradesh',
 'pyrenees',
 'western australia',
 'central south africa',
 'bodrum',
 'parinacota',
 'antofagasta',
 'northeastern spain',
 'moresby strait',
 'central eastern china',
 'ivrea-verbano',
 'salta',
 'virunga',
 'eastern australia',
 'tarapacá',
 'khomas',
 'vianden',
 'western russia',
 'galicia',
 'central nepal',
 'australia',
 'bismarck archipelago',
 'manyara',
 'québec',
 'erongo',
 'tamil nadu',
 'eastern canada',
 'arusha',
 'sud',
 'iguape',
 'rhineland-palatinate',
 'north west',
 'jiangsu',
 'dodoma',
 'heard island',
 'mcdonald islands',
 'labrador',
 'iowa',
 'banks peninsula, christchurch',
 'nova scotia',
 'garratoxa',
 'kansas',
 'tristan da cunha',
 'gough',
 'northern tanzania',
 'chile & argentina',
 'vogelsaug',
 'mashonaland',
 'apennines',
 'kastamonu',
 'piemonte',
 'mutasa',
 'oberbergau',
 'ascension',
 'masvingo',
 'southern brazil',
 'northwest territories',
 'western iran',
 'st. helena',
 'kilimanjaro region',
 'kunene',
 'bouvet',
 'viti levu, tavua',
 'kamchatka',
 "sana'a and amran",
 'victoria',
 'bougainville',
 'norther pacific',
 'new hebrides',
 'kgalagadi',
 'niuatoputapu',
 'north-east',
 'western cordillera',
 'montechristi',
 'new britain',
 'santa isabel',
 'malaita',
 'gorgona island',
 'gansu province',
 'michoacán ',
 'puebla',
 'tushka',
 'campanian',
 'pozzuoli/ campanian',
 'roman',
 'red sea area',
 'sinai',
 'western desert',
 'akranes',
 'hvalfjarðarsveit',
 'borgarbyggð',
 'grundarfjörður',
 'grundarfjarðarbær',
 'gullbringusýsla',
 'west tushka',
 'hornafjörður',
 'chelungpu fault',
 'hvalfjarðarstrandarhreppur',
 'hveragerði',
 'antalya',
 'icel',
 'mugla',
 'konya',
 'burgur',
 'nigde',
 'diayarbakir',
 'bursa',
 'aksaray',
 'kayseri',
 'ayfonkarahisar',
 'afyonkarahisar',
 'kutahya',
 'izmir',
 'izmir or balikesir',
 'kirsehir',
 'sivas',
 'marmara island',
 'provinz pontevedra',
 'mosfellsbær',
 'snæfellsbær',
 'reykjavík',
 'skorradalshreppur',
 'skútustaðahreppur',
 'kerala',
 'vesturland',
 'nevada',
 'north german basin',
 'alberta',
 'hessen',
 'tirol',
 'ile de france',
 'campanian area',
 'rome',
 'sicily',
 'messina',
 'rhode island',
 'niedersachsen',
 'east midlands',
 'south iceland',
 'lahendong',
 'washington state',
 'british columbia',
 'suðurnes',
 'kyūshū',
 'waikato',
 'colima',
 'jalisco ',
 'giresun',
 'gümüshane',
 'lower saxony'
 'niedersachsen',
 'baden würtemberg',
 'rheinland pfalz',
 'bengal basin']

# %%
with open ('list_states.txt', 'w') as f:
    for item in list_state_det:
        try:
            f.write(str(item) + '\n')
        except:
            pass

# %% [markdown]
# ## PDF Data Reader

# %%
def get_pdf_file_content_Text(path_to_pdf):
    
    '''
    path_to_pdf: is the parameter that will give access to the PDF File 
    we want to extract the content.
    '''
    
    '''
    PDFResourceManager is used to store shared resources such as fonts or images that 
    we might encounter in the files. 
    '''
    
    resource_manager = PDFResourceManager(caching=True)
    
    '''
    create a string object that will contain the final text the representation of the pdf. 
    '''
    out_text = StringIO()
    
    '''
    UTF-8 is one of the most commonly used encodings, and Python often defaults to using it.
    In our case, we are going to specify in order to avoid some encoding errors.
    '''
    codec = 'utf-8'
    
    """
    LAParams is the object containing the Layout parameters with a certain default value. 
    """
    laParams = LAParams()
    
    '''
    Create a TextConverter Object, taking :
    - ressource_manager,
    - out_text 
    - layout parameters.
    '''
    text_converter = TextConverter(resource_manager, out_text, laparams=laParams)
    fp = open(path_to_pdf, 'rb')
    
    '''
    Create a PDF interpreter object taking: 
    - ressource_manager 
    - text_converter
    '''
    interpreter = PDFPageInterpreter(resource_manager, text_converter)

    '''
    We are going to process the content of each page of the original PDF File
    '''
    for page in PDFPage.get_pages(fp, pagenos=set(), maxpages=0, password="", caching=True, check_extractable=True):
        interpreter.process_page(page)

    '''
    Retrieve the entire contents of the “file” at any time 
    before the StringIO object’s close() method is called.
    '''
    text = out_text.getvalue()

    '''
    Closing all the ressources we previously opened
    '''
    fp.close()
    text_converter.close()
    out_text.close()
    
    '''
    Return the final variable containing all the text of the PDF
    '''
    return text

# %%
pdf_path = 'C:/Users/Ryan Bobby A/Documents/RWTH AACHEN/KULIAH/THESIS_BISMILLAH/Thesis Progress/PDF Data/Brehme2016_Article_PermeabilityDistributionInTheL.pdf'

# %%
text = get_pdf_file_content_Text(pdf_path)
print(text)
# Out:
# Environ Earth Sci (2016) 75:1088
# DOI 10.1007/s12665-016-5878-9
#
# O R I G I N A L A R T I C L E
#
# Permeability distribution in the Lahendong geothermal ﬁeld:
# A blind fault captured by thermal–hydraulic simulation
#
# Maren Brehme1
# Martin Sauter3
#
# • Guido Blo¨cher1
# • Gu¨ nter Zimmermann1
#
# • Mauro Cacace1
#
# • Yustin Kamah2
#
# •
#
# Received: 24 November 2015 / Accepted: 4 July 2016 / Published online: 19 July 2016
# Ó Springer-Verlag Berlin Heidelberg 2016
#
# Abstract Subsurface ﬂuid ﬂow of reservoirs in active
# tectonic regions is mainly controlled by permeability of
# fault zones. Therefore, the characterization of fault zones is
# an important step toward performance assessment of a
# reservoir. The ﬂuid ﬂow is controlled also by pressure and
# temperature conditions.
# In this context, we simulated
# pressure and temperature ﬁelds to elaborate on the inﬂu-
# ence of permeability on subsurface ﬂuid ﬂow in the
# Lahendong geothermal reservoir. Thermal–hydraulic sim-
# ulation is performed using a ﬁnite element approach.
# Adjusting the permeability through 370 different cases,
# modeling results converged to the observed data within a
# misﬁt range of 0–7 %. The best ﬁtting models identiﬁed a
# deep-seated fault that has previously not been traced at the
# surface. Simulated temperature distribution suggests a
# prominent convective heat ﬂow, driven by an upward
# migrating and SW–NE oriented ﬂuid ﬂow. This hydraulic
# gradient causes a pressure drop along the reservoir. High-
# pressure patterns are used to constrain recharge areas, in
# addition to inﬁltration measurements. Discharge ﬂow
# occurs from SW to NE migrating also upward toward the
# hot springs. In that frame, thermal–hydraulic simulations
# identiﬁed previously unresolved subsurface faults, which
#
# & Maren Brehme
#
# brehme@gfz-potsdam.de
#
# 1 Helmholtz Centre Potsdam – GFZ German Research Centre
# for Geosciences, Telegrafenberg, 14473 Potsdam, Germany
#
# 2 Upstream Technology Center Pertamina, Jl. Medan Merdeka
#
# Timur no. 6, Jakarta, Indonesia
#
# 3 Applied Geology, University of Go¨ttingen,
#
# Goldschmidtstraße. 3, 37077 Go¨ttingen, Germany
#
# now allow a better understanding of the subsurface per-
# meability and its inﬂuence on ﬂuid ﬂow.
# Keywords Permeable faults  Hydrogeology  Fluid ﬂow
# Geothermal ﬁeld management  Reservoir engineering
# Pressure drop
#
# Introduction
#
# It
#
# Geothermal energy is an essential component to supply
# future energy demands.
# requires developing new
# geothermal sites and improving the performance of exist-
# ing systems to satisfy continuously growing demand. The
# productivity of a geothermal ﬁeld mainly depends on
# subsurface ﬂuid ﬂow, which in active tectonic regions is
# controlled by permeability of fault zones (Moeck 2014). In
# that frame, the primary focus is on locating and charac-
# terizing faulted areas in geothermal ﬁelds. This study
# employs numerical modeling to allocate and quantify
# permeability anisotropies and discontinuities, e.g., faults, in
# order to understand their inﬂuence on subsurface ﬂuid ﬂow
# in geothermal reservoirs.
#
# Numerical models have been increasingly used to
# understand the setup and productivity of geothermal sys-
# tems. A general overview of geothermal models has been
# given by O’Sullivan et al. (2001). Additionally, there are
# several sites exemplifying similar characteristics as in
# Lahendong. The underground movement of hot and cold
# ﬂuids has been modeled for geothermal ﬁelds in New
# Zealand (Kaya et al. 2014). The Kakkonda geothermal site,
# e.g., consists of two reservoirs at various depths with dif-
# ferent ﬂuid properties. There,
# results from ﬂuid ﬂow
# analysis show the importance of fractures for ﬂuid transport
# enhancing the recharge or discharge in the reservoir
#
# 123
#
# 1088 Page 2 of 11
#
# Environ Earth Sci (2016) 75:1088
#
# (McGuinness et al. 1995). Generally, faults acting as
# preferential ﬂuid path ways signiﬁcantly change the pres-
# sure and temperature ﬁeld in the reservoir (Cherubini et al.
# 2013). Models for the Seferihisar–Balc¸ova ﬁeld focus on
# the ﬂuid ﬂow inside of faults. Results show an enhanced
# upward heat transport through ﬂuids from bottom of the
# geothermal system (Magri et al. 2011).
#
# Our test ground is the Lahendong geothermal ﬁeld
# located in Sulawesi, Indonesia. The ﬁeld is owned and
# operated by P.T. Pertamina Geothermal Energy and hosts a
# power plant with a production capacity of 80 MWe. There,
# geothermal exploration started in the early 1970s including
# geophysical and geohydrochemical approaches. It
# is a
# water-dominated magmatic structurally controlled system.
# Faults generally act as across-fault ﬂuid barriers and along-
# fault ﬂuid conductors (Brehme et al. 2014). As a result, hot
# springs mainly appear on the top of vertically permeable
# faults at the surface. Available numerous drilling and sur-
# face measurements allowed a detailed characterization of
# the geological and hydrogeological setting of the area
# (Fig. 1; Brehme et al. 2011, 2013, 2014, 2016; Wiegand
# et al. 2013). The model presented here is developed for
# investigating subsurface ﬂuid ﬂow and the permeability
# distribution including the fault zones in the Lahendong
# geothermal ﬁeld. Below, the geological structure of the
#
# ﬁeld is presented followed by an introduction to the mod-
# eling approach.
#
# Detailed investigation of subsurface permeability dis-
# tribution is a crucial step for site selection and smart dril-
# ling strategies. The numerical simulations presented will
# provide insight into understanding the subsurface ﬂuid ﬂow
# considering the hydraulic conductivity of faults. It ensures
# productive as well as sustainable operation of geothermal
# ﬁelds avoiding risks, such as drilling into non-fractured or
# cold zones, and targeting highly corroding waters.
# Although the target area is Lahendong, the general work-
# ﬂow is applicable for other geothermal sites consisting of
# similar constraints.
#
# Reservoir characterization
#
# Hydrogeology
#
# The overall driving force for the ﬂuid ﬂow is the SW–NE
# oriented natural hydraulic gradient
# in the Lahendong
# geothermal system. The direction of ﬂuid ﬂow varies
# through the geothermal site due to horizontal partitioning
# of the reservoir by relatively less permeable fault zones
# (Brehme et al. 2014). The basic sections are located in the
#
# Fig. 1 Topographic map of the study area with geological features, water and rock sample locations, and model cross section
#
# 123
#
# Environ Earth Sci (2016) 75:1088
#
# Page 3 of 11
#
# 1088
#
# south, in the east, and beneath Lake Linau. Beneath Lake
# Linau, the direction of ﬂuid ﬂow is slightly rotated to
# WSW–ENE (Fig. 1). Also, types of ﬂuid change from one
# section to another, e.g., an acidic highly saline-type
# beneath Lake Linau and a neutral low saline-type south and
# east of Lake Linau (Fig. 1). The impermeable structure
# across faults prevent the ﬂuids from diluting each other
# (Brehme et al. 2016). However, faults are rather permeable
# along the vertical axis, which allows recharge of the system
# through the faults. Rainwater inﬁltrates at a fault in the SW,
# at Mt. Lengkoan, and creek water inﬁltrates into the normal
# faults at Lake Linau (Fig. 2). The hydrothermal system
# discharges into Lake Linau and toward the NE, as driven
# by the hydraulic gradient (Brehme et al. 2014).
#
# The fracture network along the area is characterized by
# strike slip faults and normal faults. The sinistral faults
# strike N 40° and steeply dip toward the SE. Left step over
# on the strike slip faults forms an extension basin in the
# central study area. Normal faults at the extension basin
# strike NW and dip 70°–80° beneath Lake Linau (Brehme
# et al. 2014).
#
# Lithology
#
# Lahendong area is mainly characterized by Pre-, Post- and
# Tondano formation of Plio- to Pleistocene age (Koestono
# et al. 2010). The rocks are typically andesite, volcanic
# breccia, and tuff. Those types have been sampled from
# borehole cores and used to determine porosity, permeabil-
# ity, and thermal conductivity. Effective porosity and matrix
# permeability have been analyzed using a cylindrical-shaped
#
# specimen with a dimension of 5 cm x 5 cm 9 2.5 cm ori-
# ented parallel to the coring (Brehme et al. 2016). Thermal
# conductivity has been measured on plain sections of dried
# cores. The experimental setup consists of a gas perme-
# ameter for determining matrix permeability (Milsch et al.
# 2011), of an helium pycnometry for effective porosity
# measurements (Johnson-Maynard et al. 1994) and of an
# optical scanner for thermal conductivity measurements
# (Popov et al. 1999). These parameters have been measured
# and averaged for the three rock types (Brehme et al. 2016;
# Table 1). Andesite has an effective porosity of 3.7 %, a
# permeability of 2.1 9 10-14 m2, and a thermal conductiv-
# ity of 1.8 W m-1 K-1 (dry) or 2.2 W m-1 K-1 (saturated).
# Tuff has a porosity of 7.7 % but the lowest permeability of
# 2.0 9 10-15 m2
# of
# 1.6 W m-1 K-1
# (saturated).
# Volcanic breccia is a permeable layer with an effective
# porosity of 10.5 %, a permeability of 2.3 9 10-14 m2, and
# a thermal conductivity of 1.6 W m-1 K-1
# (dry) or
# 2.5 W m-1 K-1 (saturated). Reservoir rocks reﬂect gener-
# ally low matrix permeability suggesting fracture-controlled
# ﬂuid ﬂow throughout the aquifer (Brehme et al. 2016).
#
# and
# (dry) or 2.1 W m-1 K-1
#
# a
#
# thermal
#
# conductivity
#
# Model setup
#
# Model geometry
#
# Numerical models developed for the study area represent
# the initial conditions of the reservoir before production or
# the commercial ﬁnite
# injection start. For simulation,
#
# Fig. 2 Cross section of the modeled area with geological structure, boundary conditions, and location of observation points
#
# 123
#
# 1088 Page 4 of 11
#
# Environ Earth Sci (2016) 75:1088
#
# Table 1 Thermal and hydraulic parameters of the Lahendong reservoir rocks measured in laboratory (Brehme et al. 2016)
#
# Sample (name, depth)
#
# Rock type
#
# Effective
# porosity (%)
#
# Thermal conductivity
# dry (W m-1 K-1)
#
# Thermal conductivity
# saturated (W m-1 K-1)
#
# Matrix permeability
# (m2)
#
# LHD1 500–501
#
# LHD1 801–802
#
# LHD1 1000–1001
#
# LHD1 2100–2101
#
# LHD2 300–302
#
# LHD3 2201–2203
#
# LHD4 652–653
#
# LHD4 850–852
#
# LHD4 1001–1002
#
# LHD4 2304–2305
#
# LHD5 602–603
#
# LHD5 752–753
#
# LHD5 1102–1103
#
# LHD5 1404–1406
#
# LHD5 1575–1576
#
# LHD7 901–902,3
#
# LHD7 1567.8–1568
#
# LHD7 1756–1758
#
# Average values
#
# A
#
# B
#
# T
#
# T
#
# A
#
# B
#
# B
#
# A
#
# B
#
# A
#
# B
#
# A
#
# A
#
# A
#
# A
#
# A
#
# T
#
# B
#
# Andesite (A)
#
# Breccia (B)
#
# Tuff (T)
#
# 1.1
#
# 14.5
#
# 5.0
#
# 7.2
#
# 12.5
#
# 5.7
#
# 6.3
#
# 1.6
#
# 16.4
#
# 1.6
#
# 16.3
#
# 2.7
#
# 5.2
#
# 3.6
#
# 0.6
#
# 4.6
#
# 11.0
#
# 3.9
#
# 3.7
#
# 10.5
#
# 7.7
#
# (LHD1 550) 2.0
#
# (LHD1 550) 2.2
#
# 1.6
#
# 1.8
#
# 1.4
#
# 2.1
#
# 1.8
#
# 1.4
#
# 1.8
#
# 1.4
#
# 1.9
#
# 1.5
#
# 1.6
#
# 2.1
#
# 1.8
#
# 1.6
#
# 1.6
#
# 2.4
#
# 2.2
#
# 2.0
#
# 2.4
#
# 2.0
#
# 2.7
#
# 2.7
#
# 2.3
#
# 2.3
#
# 1.7
#
# 2.2
#
# 2.7
#
# 2.2
#
# 2.5
#
# 2.1
#
# 1.5 9 10-14
# 8.9 9 10-16
# 3.3 9 10-15
# 6.1 9 10-14
# 1.5 9 10-14
# 1.3 9 10-14
# 2.3 9 10-14
# 6.8 9 10-14
# 3.4 9 10-16
# 1.1 9 10-14
# 1.1 9 10-16
# 7.9 9 10-14
# 3.0 9 10-15
# 7.9 9 10-18
# 7.2 9 10-16
# 1.7 9 10-15
# 1.7 9 10-14
# 2.1 9 10-14
# 2.3 9 10-14
# 2.0 9 10-15
#
# element software FEFLOW is used to model pressure-
# driven and thermally induced ﬂuid ﬂow including viscosity
# changes. Governing equations for ﬂuid ﬂow and heat
# transport in saturated porous media are derived from con-
# servation principles of linear momentum, mass, and energy
# (DHI-Wasy 2009). Details on the software and the
# parameterization can be found in Diersch (2014).
#
# The model geometry is a 2D vertical SW–NE trending
# cross section extending 6 km in horizontal and 3 km in
# vertical direction. The direction of the proﬁle has been
# selected to cover all relevant processes in the Lahendong
# geothermal ﬁeld: It cuts major faults and the production
# and injection wells, which are used for temperature and
# pressure calibration. Furthermore,
# to the
# groundwater ﬂow direction, showing major ﬂuid ﬂow
# activities. The homogeneous and isotropic geological lay-
# ers in the model are stratiﬁed nearly horizontally. Faults in
# the middle of the model, striking perpendicular to the cross
# section, dip with 84° toward a cooling pluton beneath Lake
# Linau. Details on structural and geological components of
# the modeled region have been presented in Brehme et al.
# (2014).
#
# is parallel
#
# it
#
# the numerical
#
# The mesh used for
#
# simulation in
# FEFLOW consists of 45,264 nodes and 89,320 elements
# that are denser surrounding the faults because of expected
# gradients due to parameter contrasts. Material properties of
#
# 123
#
# elements are permeability, porosity, and thermal conduc-
# tivity and set according to laboratory measurements
# (Table 1). However, properties of the faults and Lake
# Linau are slightly adapted to speciﬁc conditions. The def-
# initions for the modeled grids along the faults are as fol-
# lows: porosity is 30 % and thermal conductivity is
# 1.8 W m-1 K-1. Corresponding grids for Lake Linau are
# deﬁned by a porosity of 100 % and a thermal conductivity
# of 0.6 W m-1 K-1. The model simulates ﬂuid ﬂow and
# thermal transport in saturated media in steady state.
#
# Initial values and boundary conditions
#
# Fluid ﬂow boundary conditions in the model describe
# groundwater heads and recharge amounts (Table 2; Fig. 2).
# The hydraulic head at the SW model boundary is 837 m
# and 500 m at the NE boundary. The SW hydraulic head
# represents inﬁltration of surface water into a fault, striking
# perpendicular to the model. Hydraulic head at the NE
# border is adapted to borehole measurements in that area
# (Brehme et al. 2014). Inﬁltration into the fault zones at
# Lake Linau is described by ﬂuid ﬂux boundary conditions.
# The quantity is 3.0 9 10-4 m s-1
# the SW and
# 1.3 9 10-6 m s-1 at the NE fault distributed over 40 m
# fault width. Groundwater recharge is set to 412 mm a-1 at
# the NE top surface (Table 2; Fig. 2). Fluid movement in
#
# for
#
# Environ Earth Sci (2016) 75:1088
#
# Page 5 of 11
#
# 1088
#
# c
# 0
# 0
# 1
#
# l
# e
# d
# o
# m
#
# f
# o
#
# m
# o
# t
# t
# o
# B
#
# l
# e
# d
# o
# m
# E
# N
#
# y
# r
# a
# d
# n
# u
# o
# b
#
# a
#
# t
# n
# e
# m
# e
# r
# u
# s
# a
# e
# m
#
# g
# o
# l
#
# e
# r
# o
# b
#
# 0
# 0
# 5
#
# b
# n
# o
# i
# t
# a
# l
# u
# c
# l
# a
# c
#
# 8
# -
# 0
# 1
#
# x
#
# 3
# .
# 1
#
# a
#
# t
# n
# e
# m
# e
# r
# u
# s
# a
# e
# m
#
# d
# l
# e
# ﬁ
#
# 4
# -
# 0
# 1
#
# x
#
# 3
# 1
#
# .
#
# a
#
# t
# n
# e
# m
# e
# r
# u
# s
# a
# e
# m
# d
# l
# e
# ﬁ
#
# 8
# 2
#
# a
# n
# o
# i
# t
# a
# m
#
# i
# t
# s
# e
#
# 0
# 7
#
# a
#
# t
# n
# e
# m
# e
# r
# u
# s
# a
# e
# m
#
# g
# o
# l
#
# e
# r
# o
# b
#
# 0
# 5
# 3
#
# a
# n
# o
# i
# t
# a
# v
# e
# l
# e
#
# e
# c
# a
# f
# r
# u
# s
#
# 7
# 6
# 7
#
# a
#
# t
# n
# e
# m
# e
# r
# u
# s
# a
# e
# m
#
# d
# l
# e
# ﬁ
#
# 4
# -
# 0
# 1
#
# x
#
# 0
#
# .
#
# 3
#
# a
# n
# o
# i
# t
# a
# m
#
# i
# t
# s
# e
#
# 0
# 7
#
# a
#
# t
# n
# e
# m
# e
# r
# u
# s
# a
# e
# m
#
# g
# o
# l
#
# e
# r
# o
# b
#
# 7
# 3
# 8
#
# )
#
# m
#
# (
#
# d
# a
# e
# h
#
# c
# i
# l
# u
# a
# r
# d
# y
# H
#
# )
#
# 1
# -
# s
#
# m
#
# (
#
# x
# u
# ﬂ
#
# d
# i
# u
# l
# F
#
# a
#
# t
# n
# e
# m
# e
# r
# u
# s
# a
# e
# m
# g
# o
# l
#
# e
# r
# o
# b
#
# 1
# -
# m
# k
# C
# °
#
# 6
# 1
# 1
#
# )
#
# 2
# -
# m
# W
# m
#
# (
#
# x
# u
# ﬂ
#
# t
# a
# e
# H
#
# )
# C
# °
# (
#
# e
# r
# u
# t
# a
# r
# e
# p
# m
# e
# T
#
# t
# r
# o
# p
# s
# n
# a
# r
# t
#
# t
# a
# e
# H
#
# 1
#
# e
# l
# b
# a
# T
#
# e
# e
# S
#
# s
# e
# i
# t
# r
# e
# p
# o
# r
# p
#
# l
# a
# i
# r
# e
# t
# a
# M
#
# n
# o
# i
# t
# i
# d
# n
# o
# c
#
# w
# o
# ﬂ
#
# d
# i
# u
# l
# F
#
# e
# c
# a
# f
# r
# u
# s
#
# l
# e
# d
# o
# m
# E
# N
#
# t
# l
# u
# a
# f
#
# E
# N
#
# n
# o
# t
# u
# l
# p
#
# g
# n
# i
# l
# o
# o
# C
#
# e
# k
# a
# L
#
# t
# l
# u
# a
# f
#
# W
# S
#
# y
# r
# a
# d
# n
# u
# o
# b
#
# l
# e
# d
# o
# m
# W
# S
#
# y
# r
# a
# d
# n
# u
# o
# B
#
# f
# o
#
# e
# p
# y
# T
#
# e
# s
# a
# b
# a
# t
# a
# d
#
# f
# o
#
# s
# e
# c
# n
# e
# r
# e
# f
# e
# r
#
# e
# v
# i
# t
# c
# e
# p
# s
# e
# r
#
# d
# n
# a
#
# s
# n
# o
# i
# t
# a
# c
# ﬁ
# i
# c
# e
# p
# s
#
# n
# o
# i
# t
# i
# d
# n
# o
# c
#
# y
# r
# a
# d
# n
# u
# o
# B
#
# 2
#
# e
# l
# b
# a
# T
#
# the model domain is constrained by no-ﬂow boundary at
# the bottom, recharge through the surrounding fault zones,
# and the low hydraulic heads in the NE model area. Dis-
# charge of the system in the central study area is mainly
# toward Lake Linau and across the NE model boundary.
# Initial hydraulic head for the whole model domain is
# 500 m.
#
# The heat
#
# is 116 °C km-1 at
#
# transport boundary conditions are time-in-
# variant, ﬁxed temperatures, and heat ﬂux (Table 2; Fig. 2).
# Thermal gradient
# the SW model
# boundary, and the temperature is constant 350 °C at the
# pluton. Temperature of water inﬁltrating into faults and
# here mixing with shallow warm groundwater is 70 °C,
# while surface groundwater recharge is at 28 °C. Temper-
# ature values are obtained from ﬁeld and bore log mea-
# surements (Brehme et al. 2014). Heat ﬂux is set
# to
# 100 mW m-2 at
# the bottom model boundary (Table 2;
# Fig. 2). This value is ﬁxed based on the studies from
# Delisle et al. (1998), Nagao and Uyeda (1995), and Neben
# et al. (1998). Initial temperature for the model domain is
# set as 116 °C km-1, according to the local
# thermal
# gradient.
#
# Permeability determination
#
# Initial values for permeability are deﬁned based on labo-
# ratory measurements (Table 1). After each simulation run,
# modeled and measured temperature and pressure values
# have been compared at indicated observation points. In
# case of poor matching (errors [10 %), permeability has
# been adjusted until satisfactory results have been achieved.
# Beneath lake Linau, simulation results showed locally
# strong discrepancies between modeled and measured
# pressure and temperature (errors [45 %). Adjustment of
# permeability in geological
# inﬁltration rates into
# faults, or hydraulic heads did not lead to acceptable results.
# Only the implementation of strong permeability anisotropy
# throughout whole depth, i.e., an additional fault, resulted in
# minimization of errors (0–7 %). Implementation has been
# accomplished by mesh adaptation to ensure appropriate
# behavior around the fault. By this procedure, permeability
# anisotropies have been located and characterized in detail
# throughout the model.
#
# layers,
#
# In general, deﬁning a direction-dependent permeability
# improves the data ﬁt rather than using similar permeabili-
# ties in all directions. This is probably due to the fractures
# increasing the permeability mostly in vertical direction.
#
# Porosity and thermal conductivity remained constant
# throughout simulation. Variation in porosity is negligible
# because it would directly be reﬂected in permeability,
# while thermal conductivity differences would only affect
# conductive heat transport, which is not dominant in the
# Lahendong area (Ondrak et al. 1998; Brehme et al. 2014).
#
# 123
#
# )
# 3
# 1
# 0
# 2
# (
#
# .
# l
# a
#
# t
# e
#
# i
# n
# a
# v
# a
# r
# h
# g
# a
# S
#
# ,
# )
# 5
# 0
# 0
# 2
# (
#
# y
# e
# w
# e
# d
# l
# o
# C
#
# d
# n
# a
#
# g
# n
# i
# t
# l
# o¨
# H
#
# ,
# )
# 7
# 0
# 0
# 2
# (
#
# D
# W
# D
#
# )
# 8
# 9
# 9
# 1
# (
#
# .
# l
# a
#
# t
# e
#
# n
# e
# b
# e
# N
#
# ,
# )
# 5
# 9
# 9
# 1
# (
#
# a
# d
# e
# y
# U
# d
# n
# a
#
# o
# a
# g
# a
# N
#
# ,
# )
# 8
# 9
# 9
# 1
# (
#
# .
# l
# a
#
# t
# e
#
# e
# l
# s
# i
# l
# e
# D
#
# )
# 4
# 1
# 0
# 2
# (
#
# .
# l
# a
#
# t
# e
#
# e
# m
# h
# e
# r
# B
#
# a
#
# b
#
# c
#
# 1088 Page 6 of 11
#
# Results
#
# Numerical simulation is performed to obtain the best ﬁt to
# the measured data changing the absolute and relative
# permeability in geological elements. Relative permeability
# refers to different permeabilities in horizontal and vertical
# direction. As a main result, a blind fault has been rec-
# ognized beneath Lake Linau, which has not been known
# from former studies. Simulated pressure and temperature
# are measured at ﬁve selected observation points, which
# represent boreholes with available bore logs for pressure
# and temperature. Details on data are given in Fig. 6. The
# model with best data ﬁt, out of 370 different models, is
# considered to generate the ﬁnal model developed for
# Lahendong.
#
# Permeability distribution and identiﬁcation
# of a blind fault
#
# Distribution of permeability patterns in the reservoir has
# been conceived comparing temperature and pressure data
# in several wells. Especially beneath Lake Linau, closely
# located wells show high variations in temperature and
# pressure. A drop of 100 °C and 18 bar along 300 m dis-
# tance has been observed between well LHD 24 and
# LHD 28. Models ﬁrst showed high discrepancies between
# modeled and measured values in this area. However, after
# implementing another high anisotropic permeable structure
# between the observation points, models resulted in satis-
# factory results. The structure has ten times higher vertical
#
# Environ Earth Sci (2016) 75:1088
#
# permeability than horizontal permeability. This structure is
# assumed to be another fault zone located between two
# known faults with vertical dip and NW strike. This fault
# shows no trace at surface, because it is covered by Lake
# Linau.
#
# Generally, modeled permeability distribution in the
# Lahendong reservoir is direction-dependent and overprints
# the lithology. Modeled permeability is generally higher
# than measured ones in the order of up to four magnitudes.
# This is due to fracture patterns, which are not detectable at
# core-sample scale. Permeability patterns directly affect
# subsurface ﬂuid ﬂow and temperature and pressure
# distribution.
#
# Permeability in the faulted zones and surroundings is
# lowest in the study area. Especially the middle and NE
# fault, the shallow area beneath SW Lake Linau and the
# deep NE section of the NE fault show low permeabilities
# between 10-13 and 10-14 m2 (Fig. 3). The area between
# the middle and NE fault, the deep section NE of the SW
# fault, the SW fault itself and the whole model area toward
# the SW and NE boundary show higher permeabilities of
# 10-10 and 10-12 m2 (Fig. 3).
#
# Permeability varies not only within the modeled area,
# but also in vertical and horizontal direction. In faults and
# the deep reservoir section in the NE, permeability is by a
# factor of 10 higher in the vertical direction than in the
# horizontal direction (Fig. 3). In the areas between faults,
# permeability is in some parts by a factor of 10–100 lower in
# the vertical direction. In the rest of the model, vertical and
# horizontal permeability do not differ (Fig. 3).
#
# Fig. 3 Final adapted permeability and anisotropy distribution throughout the model domain. Anisotropy shows the relation between vertical and
# horizontal permeability, if anisotropy [1 vertical permeability is higher than horizontal permeability
#
# 123
#
# Environ Earth Sci (2016) 75:1088
#
# Page 7 of 11
#
# 1088
#
# Fig. 4 Modeled temperature and pressure distribution in the study area shows high-pressure ﬁelds in the SW and convective heat transport with
# rising hot ﬂuids and inﬁltration of cooler water through faults
#
# Pressure distribution
#
# The pressure distribution in the study area is controlled by
# groundwater ﬂow in low permeable rocks and vertically
# high permeable fault zones. Isobars drop following the
# natural hydraulic gradient from SW to NE. The SW section
# of the system shows higher pressures, which is caused by
# inﬁltration from higher elevations in the SW. Some wells
# existing in this region are of artesian-type. Overpressure
# releases through high permeable zones beneath Lake Linau
# and discharges toward surface. The pressure drop is up to
# 20 bars across the faults (Fig. 4).
#
# Temperature distribution
#
# Temperature distribution along the Lahendong geothermal
# reservoir suggests that convective heat transport
# is the
# dominating process in the reservoir rocks. Isotherms gen-
# erally follow the SW–NE oriented ﬂow pattern, the rise and
# the inﬁltration of ﬂuids. Upwelling of isotherms between
# the faults veriﬁes water rise toward Lake Linau. Inﬁltration
# of cold water causes down welling of isotherms particu-
# larly on the northeast section of the model. Temperature is
# locally increased at the bottom of the model surrounding
# the pluton (Fig. 4).
#
# Subsurface ﬂuid ﬂow
#
# The absolute and horizontal/vertical permeability distri-
# bution controls local ﬂuid ﬂow in the Lahendong reservoir.
#
# The general ﬂuid ﬂow, driven by the natural pressure
# gradient, is oriented from SW to NE. Vertical inﬁltration
# occurs at faults at Lake Linau and at the SW boundary.
# Discharge is across the NE model boundary (Fig. 5). The
# more detailed ﬂow patterns can be observed with stream-
# lines, which show a ﬂuid ﬂow along highly permeable
# areas. Calculated streamlines describe particle ﬂow within
# the model domain. A forward calculation shows how
# inﬁltrating water at the SW model boundary distributes
# through the reservoir. The backward calculation shows the
# source of ﬂuid particles arriving at the NE model boundary
# (Fig. 5). Patterns show that hot groundwater ﬂows toward
# the faults beneath Lake Linau, where the ﬂuid ﬂow is
# disturbed by a rise in temperature and vertically high per-
# meable layers. This causes a rise of groundwater in this
# model area (red forward streamlines in Fig. 5). At the same
# time, cold water inﬁltrates into high permeable areas and
# distributes over the NE model domain (blue backward
# streamlines in Fig. 5). It is clearly seen that the composi-
# tion of the NE reservoir domain is dominated by coldwater
# inﬁltration into faults, while the production areas are
# characterized by hot water ﬂow (Fig. 5).
#
# Discussion
#
# Investigation of
# subsurface ﬂuid ﬂow in geothermal
# reservoirs is crucial for sustainable exploitation avoiding
# drilling into less productive areas. Subsurface ﬂuid ﬂow
# might be locally inﬂuenced by fault zones or physical
#
# 123
#
# 1088 Page 8 of 11
#
# Environ Earth Sci (2016) 75:1088
#
# Fig. 5 Model domain with calculated streamlines, in red: forward streamlines follow hydraulic gradient from SW model boundary towards NE,
# in blue: backward streamlines representing inﬁltrating cold water ﬂowing towards NE model boundary
#
# properties of water (i.e. viscosity). The inﬂuence of these
# parameters on the ﬂuid ﬂow has been investigated in
# Lahendong geothermal reservoir using hydraulic–thermal
# simulations. Simulation results show the detailed perme-
# ability distribution in the reservoir including location of an
# additional fault zone.
#
# Matching of measured and simulated temperature and
# pressure has been used as a tool for resolving the perme-
# ability distribution. Temperature and pressure have been
# iteratively determined at
# several observation points
# (Fig. 2). Generally, modeled values are in good agreement
# with observed ones (Fig. 6). Nevertheless, some observa-
# tion points give slightly different values for both pressure
# and temperature (LHD 4 and LHD 7) or only temperature
# (LHD 24). This is probably due to the complicated ﬂow
# processes or strong small-scale structural variation in
# fractured and faulted areas. Furthermore, density varia-
# tions, which could have not been included into simulation
# due to high temperatures, could cause variation of ﬂuid
# pressure. However,
# the average deviation of simulated
# pressure and temperature is 1 %.
#
# Implemented model parameters are porosity, perme-
# ability, and heat conductivity. From those parameters, only
# permeability has been tested in a speciﬁc range during
# simulation. The inﬂuence of porosity and heat conductivity
# on ﬂuid ﬂow is negligible due to dominating convective
# heat ﬂow (Ondrak et al. 1998). Values implemented in the
# model are based on measured permeabilities, which rep-
# resent matrix permeability of rocks.
#
# The measured matrix permeability, representing per-
# meability in horizontal direction, is 1.5 9 10-14 m2 on
#
# 123
#
# average, which remains within typical permeability range
# for fractured igneous rocks (Scho¨n 2004). Permeability for
# volcanic breccias ranges typically between 3 9 10-15 and
# 5 9 10-12 m2 and tuff permeabilities
# range between
# 7 9 10-17 and 7 9 10-12 m2 (Klavetter and Peters 1987).
# In the Wairakei geothermal ﬁeld, simulating the imper-
# meable layers resulted in permeabilities of 10-18 and
# 10-14 m2,
# in horizontal and vertical axis, respectively
# (Mercer and Faust 1979).
#
# However, permeability in reservoir rocks might be
# locally increased due to fracture formation. It might also be
# decreased due to alteration and sealing in faults.
# In
# Lahendong, modeled permeability can be up to four mag-
# nitudes higher than measured ones in faulted areas. This is
# caused by fractures, which are not detectable in core scale.
# Moreover, in fault cores, it is by a factor of 10 higher in
# vertical direction than in horizontal direction. However, in
# areas between faults (fault gauge), permeability is in some
# parts by a factor of 10–100 lower in the vertical direction.
# Adaptation of permeability ensures a ﬁt to measured tem-
# perature and pressure data.
#
# Permeability in fractured areas is the main factor inﬂu-
# encing subsurface ﬂuid ﬂow and temperature distribution in
# the Lahendong reservoir area. Subsurface ﬂuid ﬂow is
# driven by local hydraulic heads, which show high varia-
# tions at different sections of the study area. Consequently,
# convective heat distribution leads to high temperature
# variation along the reservoir. These phenomena are
# observed in Lahendong as well as comparable ﬁelds. In
# New Mexico, water level drops of 30–100 m are observed
# across
# (Haneberg 1995). High
#
# several
#
# fault
#
# zones
#
# Environ Earth Sci (2016) 75:1088
#
# Page 9 of 11
#
# 1088
#
# 400
#
# 350
#
# 300
#
# 250
#
# 200
#
# 150
#
#
# ]
#
# C
# °
# [
#
#
#
# e
# r
# u
# t
# a
# r
# p
# e
# m
# e
# t
#
# d
# e
# r
# u
# s
# a
# e
# m
#
# 100
#
# 100
#
# LHD
#
# 5
#
# LHD
#
# 28
#
# LHD
#
# 7
#
# LHD
#
# 4
#
# LHD
#
# 24
#
# date of
# well name date drilling
# bore log
# completed
# Oct 1985
# Jan 86
# May 1986 Jul 2000
# Jul 96
# Oct 1987
# Jul 09
# Jul 09
# Aug 09 Aug 09
#
#   LHD 4
#   LHD 5
#   LHD 7
#   LHD 24
#   LHD 28
#
# 150
#
# 200
#
# 250
#
# 300
#
# 350
#
# 400
#
# modelled temperature  [°C]
#
# 150
#
# 140
#
# 130
#
# 120
#
# 110
#
#
# ]
# r
# a
# b
# [
#
#
#
# e
# r
# u
# s
# s
# e
# r
# p
# d
# e
#
#
#
# l
# l
#
# e
# d
# o
# m
#
# 100
#
# 100
#
# 7
#
# 24
#
# 4
#
# 28
#
# 5
#
# well name
#
#   LHD 4
#   LHD 5
#   LHD 7
#   LHD 24
#   LHD 28
#
# reservoir depth
#
# [m] below
# surface
# 1400
# 1750
# 2100
# 1820
# 1800
#
# 110
#
# 120
#
# 130
#
# 140
#
# 400
#
# modelled pressure  [bar]
#
# Fig. 6 Modeled versus measured temperature and pressure at selected observation points. Well speciﬁcations and measured data from Brehme
# et al. (2014)
#
# temperature drops and upwelling of isotherms indicate that
# fault zones control the ﬂuid ﬂow in the Lake Long and
# Valentine ﬁelds, USA (Hooper 1991). The analysis of ﬂuid
# pressure differences at
# the Alpine fault, New Zealand,
# allowed to characterize the change in permeability between
# hanging and footwall blocks (Sutherland et al. 2012).
#
# In summary, high pressure or temperature gradients are
# indicators for ﬂuid barriers between observation points. In
# other words, reservoir sections of different properties are
# separated by horizontally less permeable faults. In Lahen-
# dong, most signiﬁcant ﬂuid barriers are faults to the SW
# and to the NE of Lake Linau. Across these barriers, the
# pressure drops up to 20 bars. A similar pattern has been
# measured in bore logs beneath Lake Linau, where no sur-
# face trace of a fault had been observed in former studies.
# However, only by implementing another fault, modeled
# and measured values could have been adapted. The
# recently identiﬁed fault zone beneath Lake Linau remains
# under lake water and therefore is only traceable by this
# kind of reservoir modeling.
#
# Additionally to fault identiﬁcation, the internal structure
# of known fault zones has been understood in detail. The NE
# fault,
# i.e., shows a displacement at 2 km depth. The
# detailed trend has been understood by permeability adap-
# tation in this area.
#
# Due to low permeability in horizontal direction in the
# faults, ﬂuids propagate mostly vertically toward the hot
# springs at surface. It also allows surface water to inﬁltrate
# into the reservoir in case the pressure within the fault zone
# is low enough (Fig. 5). This vertical ﬂuid movement
#
# eventually controls the temperature distribution in the
# reservoir. Upward migration of deep hot water increases
# the temperature, while inﬁltration of cold surface water
# causes local drop of temperature.
#
# In summary, the most important factors inﬂuencing the
# reliability of numerical reservoir models are absolute and
# different horizontal and vertical permeability. However, a
# permeability adaptation has been done for each geological
# layer; the vertical permeability anomalies are overprinting
# those layers and are constraining the regional groundwater
# ﬂow. Those permeabilities of fractures directly inﬂuence
# the productivity of the reservoir (Cherubini et al. 2013).
# Therefore,
# their permeability characteristics should be
# investigated in detail.
#
# In a previous study, a numerical model for the Lahen-
# dong site has been set up in TOUGH2 and aimed at fore-
# casting the reservoir behavior during exploitation until the
# year 2036. With a production of 60 MWe, it predicts a
# pressure drop of 10 bars. However, the forecast results are
# uncertain due to lack of measured pressure draw down data
# (Yani 2006). Accordingly, the next steps of the presented
# study should include a realistic production and injection
# scenario in order
# reservoir
# exploitation. Furthermore, chemical characteristics could
# be considered to achieve reliable production setups,
# because hydrochemical processes play an important role in
# the Lahendong reservoir (Brehme et al. 2016). Presented
# models from this study provide important information on
# ﬂuid ﬂow in the water-dominated Lahendong reservoir.
# However, additional
# the
#
# two-phase ﬂow models of
#
# to support
#
# sustainable
#
# 123
#
# 1088 Page 10 of 11
#
# Environ Earth Sci (2016) 75:1088
#
# Lahendong area are in progress to understand the inﬂuence
# of steam driven ﬂuid ﬂow in this high-temperature system.
#
# Conclusion
#
# The primary focus of this study is to understand the
# inﬂuence of fault zones and permeability patterns on sub-
# surface ﬂuid ﬂow in geothermal reservoirs. The ﬂuid ﬂow
# mainly depends on rock and fault zone permeability. These
# processes have been considered in numerical models,
# which simulate local temperature and pressure conditions.
# the initial reservoir
# conditions, which refers to the case before production
# starts. Models are developed based on the conceptual
# models of the study area, which explain reservoir geome-
# try, geological structures, temperature, and hydraulic con-
# ditions. Temperature and pressure well-logs have been
# used for model calibration.
#
# The numerical models represent
#
# Vertical and horizontal ﬂuid ﬂow is mainly controlled
# by fault permeability. This characteristic is used to simu-
# late different reservoir sections, and vertical ﬂuid rise
# toward the surface. By stepwise adaptation of permeability
# ﬁelds, based on observed temperature and pressure gradi-
# ents, an additional blind fault zone can be identiﬁed
# beneath Lake Linau. Temperature and pressure signiﬁ-
# cantly drop across that ﬂuid barrier. This behavior has been
# observed in comparable ﬁelds in the USA as well. The
# overall shape of ﬂuid ﬂow direction trends in a SW–NE
# direction. Main recharge occurs by inﬁltration of surface
# water into the faults, especially in the southwest and near to
# Lake Linau. Discharge is enhanced in highly fractured
# areas toward Lake Linau. Vertical permeability of faults
# allows ﬂuids rising toward the hot springs at surface.
#
# Results show that permeability has to be considered for
# simulation of a geothermal system. The geothermal system
# is mainly controlled by ﬂuid ﬂow in fractures/faults
# depending on temperature and pressure conditions. The
# locally modiﬁed ﬂuid ﬂow can considerably inﬂuence the
# productivity of a geothermal ﬁeld. Results also guide
# reservoir management
# in case of a potential for ﬁeld
# extension, as performed in Lahendong.
#
# Acknowledgments The authors acknowledge the continuous support
# within the team of the International Center for Geothermal Research
# under the direction of E. Huenges. Thanks to H. Milsch, B. Peters,
# and D. Otten for helping at the Gas-Permeameter. We thank A.
# Fo¨rster for giving access and introduction to the optical scanner for
# thermal conductivity measurements and S. Fuchs for assisting while
# interpretation of data. A special gratitude to F. Bulut, who carefully
# reviewed the manuscript, took care of linguistic issues, and supported
# the analysis with helpful discussions. Prof. M. Hochstein is greatly
# acknowledged for continuous fruitful discussions during the study.
# The support of the team of Pertamina Geothermal Energy in Jakarta
# as well as in Lahendong including the access to data, and the ﬁeld is
#
# 123
#
# highly appreciated. The authors thank PGE for the permission to
# publish this paper. The German Federal Ministry for Education and
# Research (BMBF) is funding this German project ‘‘Sustainability
# concepts for exploitation of geothermal reservoirs in Indonesia—ca-
# pacity building and methodologies for site deployment’’ under Grant
# 03G0753A.
#
# References
#
# Brehme M, Regenspurg S, Zimmermann G (2011) Hydraulic-
# hydrochemical modelling of a geothermal reservoir in Indonesia.
# Mineral Mag 75:577
#
# Brehme M, Haase C, Regenspurg S, Moeck I, Deon F, Wiegand BA,
# Kamah Y, Zimmermann G, Sauter M (2013) Hydrochemical
# patterns in a structurally controlled geothermal system. Miner
# Mag 77:767. doi:10.1180/minmag.2013.077.5.2
#
# Brehme M, Moeck I, Kamah Y, Zimmermann G, Sauter M (2014) A
# hydrotectonic model of a geothermal reservoir—a study in
# Lahendong, Indonesia. Geothermics 51:228–239. doi:10.1016/j.
# geothermics.2014.01.010
#
# Brehme M, Deon F, Haase C, Wiegand B, Kamah Y, Sauter M,
# Regenspurg S (2016) Geochemical properties controlled by fault
# permeability in a geothermal reservoir (Lahendong, Indonesia).
# Grundwasser 21:29–41. doi:10.1007/s00767–015–0313–9
#
# Cherubini Y, Cacace M, Blo¨cher G, Scheck-Wenderoth M (2013)
# Impact of single inclined faults on the ﬂuid ﬂow and heat
# transport: results from 3-D ﬁnite element simulations. Environ
# Earth Sci 70:3603–3618. doi:10.1007/s12665-012-2212-z
#
# Delisle G, Beiersdorf H, Neben S, Steinmann D (1998) The
# geothermal ﬁeld of the North Sulawesi accretionary wedge and
# a model on BSR migration in unstable depositional environ-
# ments. Geol Soc Lond Spec Publ 137:267–274. doi:10.1144/
# GSL.SP.1998.137.01.21
#
# DHI-Wasy (2009) FEFLOW white papers, vol 1, 368 pp
# Diersch H-JG (2014) Finite Element modeling of ﬂow, mass and heat
# transport in porous and fractured media. Springer, Berlin, p 996
# DWD, Deutscher Wetterdienst (2007) Offenbach/Main. http://www.
#
# dwd.de/. Accessed June 2012
#
# Haneberg WC (1995) Steady state groundwater ﬂow across idealized
#
# faults. Water Resour Res 31:1815–1820
#
# Hooper ECD (1991) Fluid migration along growth faults
#
# in
# compacting sediments. J Pet Geol 14:161–180. doi:10.1111/j.
# 1747-5457.1991.tb00360.x
#
# Ho¨lting B, Coldewey W (2005) Hydrogeologie: Einfu¨hrung in die
#
# allgemeine und angewandte Hydrogeologie. Springer, Berlin
#
# Johnson-Maynard J, Anderson M, Green S, Graham R (1994)
# Physical and hydraulic properties of weathered granitic rock in
# southern California. Soil Sci 158:375–380
#
# Kaya E, O’Sullivan MJ, Hochstein MP (2014) A three dimensional
# numerical model of
# the Waiotapu, Waikite and Reporoa
# geothermal areas, New Zealand. J Volcanol Geotherm Res
# 283:127–142. doi:10.1016/j.jvolgeores.2014.07.008
#
# Klavetter E, Peters R (1987) An evaluation of the use of mercury
# porosimetry in calculating hydrologic properties of tuffs from
# Yucca Mountain, Nevada, Nevada Nuclear Waste Storage
# Investigations Project Report. Project-Report, Nevada Nuclear
# Waste Storage Investigations Project
#
# Koestono H, Siahaan EE, Silaban M, Franzson H (2010) Geothermal
# model of
# In:
# Proceedings World Geothermal Congress 2010, Bali, Indonesia,
# 25–29 April 2010
#
# the Lahendong geothermal ﬁeld,
#
# Indonesia.
#
# Magri F, Akar T, Gemici U, Pekdeger A (2011) Numerical
# fault-induced seawater circulation in the
#
# investigations of
#
# Environ Earth Sci (2016) 75:1088
#
# Page 11 of 11
#
# 1088
#
# Seferihisar–Balc¸ova geothermal system, western Turkey. Hydro-
# geol J 20:103–118. doi:10.1007/s10040-011-0797-z
#
# McGuinness M, White S, Young R, Ishizaki H, Ikeuchi K, Yoshida Y
# (1995) A model of the Kakkonda geothermal reservoir. Geother-
# mics 24:1–48. doi:10.1016/0375-6505(94)00020-D
#
# Mercer JW, Faust CR (1979) Geothermal reservoir simulation: 3.
# Application of liquid-and vapor-dominated hydrothermal mod-
# eling techniques to Wairakei, New Zealand. Water Resour Res
# 15:653–671. doi:10.1029/WR015i003p00653
#
# Milsch H, Priegnitz M, Blo¨cher G (2011) Permeability of gypsum
# samples dehydrated in air. Geophys Res Lett 38:6. doi:10.1029/
# 2011GL048797
#
# Moeck IS (2014) Catalog of geothermal play types based on geologic
# controls. Renew Sustain Energy Rev 37:867–882. doi:10.1016/j.
# rser.2014.05.032
#
# Nagao T, Uyeda S (1995) Heat-ﬂow distribution in Southeast Asia
# Tectonophysics
#
# consideration
#
# volcanic
#
# with
# 251:153–159
#
# of
#
# heat.
#
# Neben S, Hinz K, Beiersdorf H (1998) Reﬂection characteristics,
# depth and geographical distribution of bottom simulating
# reﬂectors within the accretionary wedge of Sulawesi. Geol Soc
# Lond Spec Publ 137:255–265. doi:10.1144/GSL.SP.1998.137.
# 01.20
#
# O’Sullivan MJ, Pruess K, Lippmann MJ (2001) State of the art of
# simulation. Geothermics 30:395–429.
#
# reservoir
#
# geothermal
# doi:10.1016/S0375-6505(01)00005-0
#
# Ondrak R, Wenderoth F, Scheck M, Bayer U (1998) Integrated
# geothermal modeling on different scales in the Northeast
# German basin. Geol Rundschau 87:32–42.
# doi:10.1007/
# s005310050187
#
# Popov Y, Pribnow D, Sass J (1999) Characterization of rock thermal
# conductivity by high-resolution optical scanning. Geothermics
# 28:253–276
#
# Scho¨n JH (2004) Physical properties of
#
# rocks. Elsevier Ltd,
#
# Amsterdam
#
# Saghravani S, Yusoff I, Mustapha S, Saghravani S (2013) Estimating
# groundwater recharge using empirical method: a case study in
# the tropical zone. Sains Malays 42:553–560
#
# Sutherland R, Toy VG, Townend J, Cox SC, Eccles JD, Faulkner DR,
# Prior DJ, Norris RJ, Mariani E, Boulton C, Carpenter BM,
# Menzies CD, Little TA, Hasting M, De Pascale GP, Langridge
# RM, Scott HR, Reid Lindroos Z, Fleming B, Kopf J (2012)
# Drilling reveals ﬂuid control on architecture and rupture of the
# Alpine fault, New Zealand. Geology 40:1143–1146. doi:10.
# 1130/G33614.1
#
# Wiegand BA, Brehme M, Teuku F, Amran IA, Prasetio R, Kamah Y,
# Sauter M (2013) Geochemical and isotopic investigation of
# ﬂuids from Lahendong geothermal ﬁeld. Miner Mag 77:2491.
# doi:10.1180/minmag.2013.077.5.23
#
# Yani A (2006) Numerical modelling of the Lahendong geothermal
#
# system, Indonesia, Report from United Nations University
#
# 123

# %%
text
# Out:
# 'Environ Earth Sci (2016) 75:1088\nDOI 10.1007/s12665-016-5878-9\n\nO R I G I N A L A R T I C L E\n\nPermeability distribution in the Lahendong geothermal ﬁeld:\nA blind fault captured by thermal–hydraulic simulation\n\nMaren Brehme1\nMartin Sauter3\n\n• Guido Blo¨cher1\n• Gu¨ nter Zimmermann1\n\n• Mauro Cacace1\n\n• Yustin Kamah2\n\n•\n\nReceived: 24 November 2015 / Accepted: 4 July 2016 / Published online: 19 July 2016\nÓ Springer-Verlag Berlin Heidelberg 2016\n\nAbstract Subsurface ﬂuid ﬂow of reservoirs in active\ntectonic regions is mainly controlled by permeability of\nfault zones. Therefore, the characterization of fault zones is\nan important step toward performance assessment of a\nreservoir. The ﬂuid ﬂow is controlled also by pressure and\ntemperature conditions.\nIn this context, we simulated\npressure and temperature ﬁelds to elaborate on the inﬂu-\nence of permeability on subsurface ﬂuid ﬂow in the\nLahendong geothermal reservoir. Thermal–hydraulic sim-\nulation is performed using a ﬁnite element approach.\nAdjusting the permeability through 370 different cases,\nmodeling results converged to the observed data within a\nmisﬁt range of 0–7 %. The best ﬁtting models identiﬁed a\ndeep-seated fault that has previously not been traced at the\nsurface. Simulated temperature distribution suggests a\nprominent convective heat ﬂow, driven by an upward\nmigrating and SW–NE oriented ﬂuid ﬂow. This hydraulic\ngradient causes a pressure drop along the reservoir. High-\npressure patterns are used to constrain recharge areas, in\naddition to inﬁltration measurements. Discharge ﬂow\noccurs from SW to NE migrating also upward toward the\nhot springs. In that frame, thermal–hydraulic simulations\nidentiﬁed previously unresolved subsurface faults, which\n\n& Maren Brehme\n\nbrehme@gfz-potsdam.de\n\n1 Helmholtz Centre Potsdam – GFZ German Research Centre\nfor Geosciences, Telegrafenberg, 14473 Potsdam, Germany\n\n2 Upstream Technology Center Pertamina, Jl. Medan Merdeka\n\nTimur no. 6, Jakarta, Indonesia\n\n3 Applied Geology, University of Go¨ttingen,\n\nGoldschmidtstraße. 3, 37077 Go¨ttingen, Germany\n\nnow allow a better understanding of the subsurface per-\nmeability and its inﬂuence on ﬂuid ﬂow.\nKeywords Permeable faults \x01 Hydrogeology \x01 Fluid ﬂow \x01\nGeothermal ﬁeld management \x01 Reservoir engineering \x01\nPressure drop\n\nIntroduction\n\nIt\n\nGeothermal energy is an essential component to supply\nfuture energy demands.\nrequires developing new\ngeothermal sites and improving the performance of exist-\ning systems to satisfy continuously growing demand. The\nproductivity of a geothermal ﬁeld mainly depends on\nsubsurface ﬂuid ﬂow, which in active tectonic regions is\ncontrolled by permeability of fault zones (Moeck 2014). In\nthat frame, the primary focus is on locating and charac-\nterizing faulted areas in geothermal ﬁelds. This study\nemploys numerical modeling to allocate and quantify\npermeability anisotropies and discontinuities, e.g., faults, in\norder to understand their inﬂuence on subsurface ﬂuid ﬂow\nin geothermal reservoirs.\n\nNumerical models have been increasingly used to\nunderstand the setup and productivity of geothermal sys-\ntems. A general overview of geothermal models has been\ngiven by O’Sullivan et al. (2001). Additionally, there are\nseveral sites exemplifying similar characteristics as in\nLahendong. The underground movement of hot and cold\nﬂuids has been modeled for geothermal ﬁelds in New\nZealand (Kaya et al. 2014). The Kakkonda geothermal site,\ne.g., consists of two reservoirs at various depths with dif-\nferent ﬂuid properties. There,\nresults from ﬂuid ﬂow\nanalysis show the importance of fractures for ﬂuid transport\nenhancing the recharge or discharge in the reservoir\n\n123\n\n\x0c1088 Page 2 of 11\n\nEnviron Earth Sci (2016) 75:1088\n\n(McGuinness et al. 1995). Generally, faults acting as\npreferential ﬂuid path ways signiﬁcantly change the pres-\nsure and temperature ﬁeld in th ...

# %% [markdown]
# ## Data Preprocessing (Conditioning, Stop Words, Stemmer)

# %% [markdown]
# ### Regex Conditioning & NLTK StopWords

# %%
#Remove '\n' & '•'
new_text = re.sub(r'[\n•]', ' ', text)
new_text
# Out:
# 'Environ Earth Sci (2016) 75:1088 DOI 10.1007/s12665-016-5878-9  O R I G I N A L A R T I C L E  Permeability distribution in the Lahendong geothermal ﬁeld: A blind fault captured by thermal–hydraulic simulation  Maren Brehme1 Martin Sauter3    Guido Blo¨cher1   Gu¨ nter Zimmermann1    Mauro Cacace1    Yustin Kamah2     Received: 24 November 2015 / Accepted: 4 July 2016 / Published online: 19 July 2016 Ó Springer-Verlag Berlin Heidelberg 2016  Abstract Subsurface ﬂuid ﬂow of reservoirs in active tectonic regions is mainly controlled by permeability of fault zones. Therefore, the characterization of fault zones is an important step toward performance assessment of a reservoir. The ﬂuid ﬂow is controlled also by pressure and temperature conditions. In this context, we simulated pressure and temperature ﬁelds to elaborate on the inﬂu- ence of permeability on subsurface ﬂuid ﬂow in the Lahendong geothermal reservoir. Thermal–hydraulic sim- ulation is performed using a ﬁnite element approach. Adjusting the permeability through 370 different cases, modeling results converged to the observed data within a misﬁt range of 0–7 %. The best ﬁtting models identiﬁed a deep-seated fault that has previously not been traced at the surface. Simulated temperature distribution suggests a prominent convective heat ﬂow, driven by an upward migrating and SW–NE oriented ﬂuid ﬂow. This hydraulic gradient causes a pressure drop along the reservoir. High- pressure patterns are used to constrain recharge areas, in addition to inﬁltration measurements. Discharge ﬂow occurs from SW to NE migrating also upward toward the hot springs. In that frame, thermal–hydraulic simulations identiﬁed previously unresolved subsurface faults, which  & Maren Brehme  brehme@gfz-potsdam.de  1 Helmholtz Centre Potsdam – GFZ German Research Centre for Geosciences, Telegrafenberg, 14473 Potsdam, Germany  2 Upstream Technology Center Pertamina, Jl. Medan Merdeka  Timur no. 6, Jakarta, Indonesia  3 Applied Geology, University of Go¨ttingen,  Goldschmidtstraße. 3, 37077 Go¨ttingen, Germany  now allow a better understanding of the subsurface per- meability and its inﬂuence on ﬂuid ﬂow. Keywords Permeable faults \x01 Hydrogeology \x01 Fluid ﬂow \x01 Geothermal ﬁeld management \x01 Reservoir engineering \x01 Pressure drop  Introduction  It  Geothermal energy is an essential component to supply future energy demands. requires developing new geothermal sites and improving the performance of exist- ing systems to satisfy continuously growing demand. The productivity of a geothermal ﬁeld mainly depends on subsurface ﬂuid ﬂow, which in active tectonic regions is controlled by permeability of fault zones (Moeck 2014). In that frame, the primary focus is on locating and charac- terizing faulted areas in geothermal ﬁelds. This study employs numerical modeling to allocate and quantify permeability anisotropies and discontinuities, e.g., faults, in order to understand their inﬂuence on subsurface ﬂuid ﬂow in geothermal reservoirs.  Numerical models have been increasingly used to understand the setup and productivity of geothermal sys- tems. A general overview of geothermal models has been given by O’Sullivan et al. (2001). Additionally, there are several sites exemplifying similar characteristics as in Lahendong. The underground movement of hot and cold ﬂuids has been modeled for geothermal ﬁelds in New Zealand (Kaya et al. 2014). The Kakkonda geothermal site, e.g., consists of two reservoirs at various depths with dif- ferent ﬂuid properties. There, results from ﬂuid ﬂow analysis show the importance of fractures for ﬂuid transport enhancing the recharge or discharge in the reservoir  123  \x0c1088 Page 2 of 11  Environ Earth Sci (2016) 75:1088  (McGuinness et al. 1995). Generally, faults acting as preferential ﬂuid path ways signiﬁcantly change the pres- sure and temperature ﬁeld in the reservoir (Cherubini et al. 2013). Models for the Seferihisar–Balc¸ova ﬁeld focus on the ﬂuid ﬂow inside of  ...

# %%
#Remove '- ' and '  '
new_text = re.sub(r'- ', '', new_text)
new_text = re.sub(r'  ', ' ', new_text)
new_text
# Out:
# 'Environ Earth Sci (2016) 75:1088 DOI 10.1007/s12665-016-5878-9 O R I G I N A L A R T I C L E Permeability distribution in the Lahendong geothermal ﬁeld: A blind fault captured by thermal–hydraulic simulation Maren Brehme1 Martin Sauter3  Guido Blo¨cher1  Gu¨ nter Zimmermann1  Mauro Cacace1  Yustin Kamah2   Received: 24 November 2015 / Accepted: 4 July 2016 / Published online: 19 July 2016 Ó Springer-Verlag Berlin Heidelberg 2016 Abstract Subsurface ﬂuid ﬂow of reservoirs in active tectonic regions is mainly controlled by permeability of fault zones. Therefore, the characterization of fault zones is an important step toward performance assessment of a reservoir. The ﬂuid ﬂow is controlled also by pressure and temperature conditions. In this context, we simulated pressure and temperature ﬁelds to elaborate on the inﬂuence of permeability on subsurface ﬂuid ﬂow in the Lahendong geothermal reservoir. Thermal–hydraulic simulation is performed using a ﬁnite element approach. Adjusting the permeability through 370 different cases, modeling results converged to the observed data within a misﬁt range of 0–7 %. The best ﬁtting models identiﬁed a deep-seated fault that has previously not been traced at the surface. Simulated temperature distribution suggests a prominent convective heat ﬂow, driven by an upward migrating and SW–NE oriented ﬂuid ﬂow. This hydraulic gradient causes a pressure drop along the reservoir. Highpressure patterns are used to constrain recharge areas, in addition to inﬁltration measurements. Discharge ﬂow occurs from SW to NE migrating also upward toward the hot springs. In that frame, thermal–hydraulic simulations identiﬁed previously unresolved subsurface faults, which & Maren Brehme brehme@gfz-potsdam.de 1 Helmholtz Centre Potsdam – GFZ German Research Centre for Geosciences, Telegrafenberg, 14473 Potsdam, Germany 2 Upstream Technology Center Pertamina, Jl. Medan Merdeka Timur no. 6, Jakarta, Indonesia 3 Applied Geology, University of Go¨ttingen, Goldschmidtstraße. 3, 37077 Go¨ttingen, Germany now allow a better understanding of the subsurface permeability and its inﬂuence on ﬂuid ﬂow. Keywords Permeable faults \x01 Hydrogeology \x01 Fluid ﬂow \x01 Geothermal ﬁeld management \x01 Reservoir engineering \x01 Pressure drop Introduction It Geothermal energy is an essential component to supply future energy demands. requires developing new geothermal sites and improving the performance of existing systems to satisfy continuously growing demand. The productivity of a geothermal ﬁeld mainly depends on subsurface ﬂuid ﬂow, which in active tectonic regions is controlled by permeability of fault zones (Moeck 2014). In that frame, the primary focus is on locating and characterizing faulted areas in geothermal ﬁelds. This study employs numerical modeling to allocate and quantify permeability anisotropies and discontinuities, e.g., faults, in order to understand their inﬂuence on subsurface ﬂuid ﬂow in geothermal reservoirs. Numerical models have been increasingly used to understand the setup and productivity of geothermal systems. A general overview of geothermal models has been given by O’Sullivan et al. (2001). Additionally, there are several sites exemplifying similar characteristics as in Lahendong. The underground movement of hot and cold ﬂuids has been modeled for geothermal ﬁelds in New Zealand (Kaya et al. 2014). The Kakkonda geothermal site, e.g., consists of two reservoirs at various depths with different ﬂuid properties. There, results from ﬂuid ﬂow analysis show the importance of fractures for ﬂuid transport enhancing the recharge or discharge in the reservoir 123 \x0c1088 Page 2 of 11 Environ Earth Sci (2016) 75:1088 (McGuinness et al. 1995). Generally, faults acting as preferential ﬂuid path ways signiﬁcantly change the pressure and temperature ﬁeld in the reservoir (Cherubini et al. 2013). Models for the Seferihisar–Balc¸ova ﬁeld focus on the ﬂuid ﬂow inside of faults. Results show an enhanced upward heat tr ...

# %%
#Apply the Stopwords from NLTK
nltk.download('stopwords')
pattern = r",*(\s*\b(?:{}))\b".format("|".join(stopwords.words('english')))
text_stw = re.sub(pattern,'', new_text)
text_stw
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Ryan Bobby
# [nltk_data]     A\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 'Environ Earth Sci (2016) 75:1088 DOI 10.1007/s12665-016-5878-9 O R I G I N A L A R T I C L E Permeability distribution Lahendong geothermal ﬁeld: A blind fault captured thermal–hydraulic simulation Maren Brehme1 Martin Sauter3  Guido Blo¨cher1  Gu¨ nter Zimmermann1  Mauro Cacace1  Yustin Kamah2   Received: 24 November 2015 / Accepted: 4 July 2016 / Published online: 19 July 2016 Ó Springer-Verlag Berlin Heidelberg 2016 Abstract Subsurface ﬂuid ﬂow reservoirs active tectonic regions mainly controlled permeability fault zones. Therefore characterization fault zones important step toward performance assessment reservoir. The ﬂuid ﬂow controlled also pressure temperature conditions. In context simulated pressure temperature ﬁelds elaborate inﬂuence permeability subsurface ﬂuid ﬂow Lahendong geothermal reservoir. Thermal–hydraulic simulation performed using ﬁnite element approach. Adjusting permeability 370 different cases, modeling results converged observed data within misﬁt range 0–7 %. The best ﬁtting models identiﬁed deep-seated fault previously traced surface. Simulated temperature distribution suggests prominent convective heat ﬂow, driven upward migrating SW–NE oriented ﬂuid ﬂow. This hydraulic gradient causes pressure drop along reservoir. Highpressure patterns used constrain recharge areas addition inﬁltration measurements. Discharge ﬂow occurs SW NE migrating also upward toward hot springs. In frame, thermal–hydraulic simulations identiﬁed previously unresolved subsurface faults & Maren Brehme brehme@gfz-potsdam.de 1 Helmholtz Centre Potsdam – GFZ German Research Centre Geosciences, Telegrafenberg, 14473 Potsdam, Germany 2 Upstream Technology Center Pertamina, Jl. Medan Merdeka Timur. 6, Jakarta, Indonesia 3 Applied Geology, University Go¨ttingen, Goldschmidtstraße. 3, 37077 Go¨ttingen, Germany allow better understanding subsurface permeability inﬂuence ﬂuid ﬂow. Keywords Permeable faults \x01 Hydrogeology \x01 Fluid ﬂow \x01 Geothermal ﬁeld management \x01 Reservoir engineering \x01 Pressure drop Introduction It Geothermal energy essential component supply future energy demands. requires developing new geothermal sites improving performance existing systems satisfy continuously growing demand. The productivity geothermal ﬁeld mainly depends subsurface ﬂuid ﬂow active tectonic regions controlled permeability fault zones (Moeck 2014). In frame primary focus locating characterizing faulted areas geothermal ﬁelds. This study employs numerical modeling allocate quantify permeability anisotropies discontinuities, e.g., faults order understand inﬂuence subsurface ﬂuid ﬂow geothermal reservoirs. Numerical models increasingly used understand setup productivity geothermal systems. A general overview geothermal models given O’Sullivan et al. (2001). Additionally several sites exemplifying similar characteristics Lahendong. The underground movement hot cold ﬂuids modeled geothermal ﬁelds New Zealand (Kaya et al. 2014). The Kakkonda geothermal site, e.g., consists two reservoirs various depths different ﬂuid properties. There, results ﬂuid ﬂow analysis show importance fractures ﬂuid transport enhancing recharge discharge reservoir 123 \x0c1088 Page 2 11 Environ Earth Sci (2016) 75:1088 (McGuinness et al. 1995). Generally, faults acting preferential ﬂuid path ways signiﬁcantly change pressure temperature ﬁeld reservoir (Cherubini et al. 2013). Models Seferihisar–Balc¸ova ﬁeld focus ﬂuid ﬂow inside faults. Results show enhanced upward heat transport ﬂuids bottom geothermal system (Magri et al. 2011). Our test ground Lahendong geothermal ﬁeld located Sulawesi, Indonesia. The ﬁeld owned operated P.T. Pertamina Geothermal Energy hosts power plant production capacity 80 MWe. There, geothermal exploration started early 1970s including geophysical geohydrochemical approaches. It water-dominated magmatic structurally controlled system. Faults generally act across-fault ﬂuid barriers alongfault ﬂuid conductors (Brehme et al. 2014). As result ...

# %%
#Check Chrono
pattern = r",*(\s*\b(?:{}))\b".format("|".join(map(str,list_chrono)))
grab = re.findall(pattern, new_text)
for i in range(len(grab)):
    grab[i] = re.sub(' ','',grab[i])
grab
# Out:
# ['Pleistocene']

# %% [markdown]
# ### SPACY Conditioning (Parsing)

# %%
#Splitted into sentences by Spacy
spc_text = spc(text_stw)

#Apply Lemmatizer
lemmatizer = WordNetLemmatizer()
lemmatizer.lemmatize('goes')

ready = []
for j in spc_text.sents:
    #Conditioning for Splitting & Apply Lemmatizer
    text_1 = ' '.join([lemmatizer.lemmatize(i.text) for i in spc(j.text.lower()) if len(i)!=1 or i.is_punct or i.is_digit])
    if len(text_1) <=1 or bool(re.search('[A-Za-z]', text_1)) == False:
        pass
    else:
        ready.append(text_1)
    
    #No Acknowledgements
    if bool(re.search('(acknowledgments)', text_1)) == True:
        break
    else:
        continue
    
    #No References
    if bool(re.search('(references|reference)', text_1)) == True:
        break
    else:
        continue
        
#Ready for NLP NER
ready_nlp = {'Text':[],'Tag':[],'Entity':[]}
for i in ready:
    for j in grab:
        if bool(re.search(j.lower(), i)) == True:
            ready_nlp['Text'].append(i)
            ready_nlp['Tag'].append(j.lower())
            ready_nlp['Entity'].append('Chrono')

# %%
ready
# Out:
# ['environ earth sci ( 2016 ) 75:1088 doi 10.1007 / s12665 - 016-',
#  'permeability distribution lahendong geothermal ﬁeld : blind fault captured thermal – hydraulic simulation maren brehme1 martin sauter3 guido blo¨cher1 gu¨ nter zimmermann1 mauro cacace1 yustin kamah2    received : 24 november 2015 / accepted : 4 july 2016 / published online : 19 july 2016 springer - verlag berlin heidelberg 2016',
#  'abstract subsurface ﬂuid ﬂow reservoirs active tectonic regions mainly controlled permeability fault zones .',
#  'therefore characterization fault zones important step toward performance assessment reservoir .',
#  'the ﬂuid ﬂow controlled also pressure temperature conditions .',
#  'in context simulated pressure temperature ﬁelds elaborate inﬂuence permeability subsurface ﬂuid ﬂow lahendong geothermal reservoir .',
#  'thermal – hydraulic simulation performed using ﬁnite element approach .',
#  'adjusting permeability 370 different cases , modeling results converged observed data within misﬁt range 0–7 % .',
#  'the best ﬁtting models identiﬁed deep - seated fault previously traced surface .',
#  'simulated temperature distribution suggests prominent convective heat ﬂow , driven upward migrating sw – ne oriented ﬂuid ﬂow .',
#  'this hydraulic gradient causes pressure drop along reservoir .',
#  'highpressure patterns used constrain recharge areas addition inﬁltration measurements .',
#  'discharge ﬂow occurs sw ne migrating also upward toward hot springs .',
#  'in frame , thermal – hydraulic simulations identiﬁed previously unresolved subsurface faults & maren brehme brehme@gfz-potsdam.de 1 helmholtz centre potsdam – gfz german research centre geosciences , telegrafenberg , 14473 potsdam , germany 2 upstream technology center pertamina , jl .',
#  'medan merdeka timur . 6 , jakarta , indonesia 3 applied geology , university go¨ttingen , goldschmidtstraße . 3 , 37077 go¨ttingen , germany allow better understanding subsurface permeability inﬂuence ﬂuid ﬂow .',
#  'keywords permeable faults hydrogeology fluid ﬂow geothermal ﬁeld management reservoir engineering pressure drop',
#  'introduction it geothermal energy essential component supply future energy demands .',
#  'requires developing new geothermal sites improving performance existing systems satisfy continuously growing demand .',
#  'the productivity geothermal ﬁeld mainly depends subsurface ﬂuid ﬂow active tectonic regions controlled permeability fault zones ( moeck 2014 ) .',
#  'in frame primary focus locating characterizing faulted areas geothermal ﬁelds .',
#  'this study employs numerical modeling allocate quantify permeability anisotropies discontinuities , e.g. , faults order understand inﬂuence subsurface ﬂuid ﬂow geothermal reservoirs .',
#  'numerical models increasingly used understand setup productivity geothermal systems .',
#  'general overview geothermal models given o’sullivan et al . ( 2001 ) .',
#  'additionally several sites exemplifying similar characteristics lahendong .',
#  'the underground movement hot cold ﬂuids modeled geothermal ﬁelds new zealand ( kaya et al . 2014 ) .',
#  'the kakkonda geothermal site , e.g. , consists two reservoirs various depths different ﬂuid properties .',
#  'there , results ﬂuid ﬂow analysis show importance fractures ﬂuid transport enhancing recharge discharge reservoir 123 1088 page 2 11 environ earth sci ( 2016 ) 75:1088',
#  '( mcguinness et al . 1995 ) .',
#  'generally , faults acting preferential ﬂuid path ways signiﬁcantly change pressure temperature ﬁeld reservoir ( cherubini et al . 2013 ) .',
#  'models seferihisar – balc¸ova ﬁeld focus ﬂuid ﬂow inside faults .',
#  'results show enhanced upward heat transport ﬂuids bottom geothermal system ( magri et al . 2011 ) .',
#  'our test ground lahendong geothermal ﬁeld located sulawesi , indonesia .',
#  'the ﬁeld owned operated p.t . pertamina geothermal energy hosts power plant production capacity 80 mwe .',
#  'there , geothermal exploration started early 1970s including geophysical geohydrochemical approaches .',
#  'it water - dominated magmatic structurally controlled system .',
#  'faults generally act across - fault ﬂuid barriers alongfault ﬂuid conductors ( brehme et al . 2014 ) .',
#  'as result , hot springs mainly appear top vertically permeable faults surface .',
#  'available numerous drilling surface measurements allowed detailed characterization geological hydrogeological setting area ( fig . 1 ; brehme et al . 2011 , 2013 , 2014 , 2016 ; wiegand et al . 2013 ) .',
#  'the model presented developed investigating subsurface ﬂuid ﬂow permeability distribution including fault zones lahendong geothermal ﬁeld .',
#  'below geological structure ﬁeld presented followed introduction modeling approach .',
#  'detailed investigation subsurface permeability distribution crucial step site selection smart drilling strategies .',
#  'the numerical simulations presented provide insight understanding subsurface ﬂuid ﬂow considering hydraulic conductivity faults .',
#  'it ensures productive well sustainable operation geothermal ﬁelds avoiding risks drilling non - fractured cold zones targeting highly corroding waters .',
#  'although target area lahendong general workﬂow applicable geothermal sites consisting similar constraints .',
#  'reservoir characterization hydrogeology the overall driving force ﬂuid ﬂow sw – ne oriented natural hydraulic gradient lahendong geothermal system .',
#  'the direction ﬂuid ﬂow varies geothermal site due horizontal partitioning reservoir relatively less permeable fault zones ( brehme et al . 2014 ) .',
#  'the basic sections located fig . 1 topographic map study area geological features , water rock sample locations model cross section 123 environ earth sci ( 2016 ) 75:1088',
#  'page 3 11 1088 south east beneath lake linau .',
#  'beneath lake linau direction ﬂuid ﬂow slightly rotated wsw – ene ( fig . 1 ) .',
#  'also , types ﬂuid change one section another , e.g. acidic highly saline - type beneath lake linau neutral low saline - type south east',
#  'lake linau ( fig . 1 ) .',
#  'the impermeable structure across faults prevent ﬂuids diluting ( brehme et al . 2016 ) .',
#  'however , faults rather permeable along vertical axis allows recharge system faults .',
#  'rainwater inﬁltrates fault sw mt . lengkoan creek water inﬁltrates normal faults lake linau ( fig . 2 ) .',
#  'the hydrothermal system discharges lake linau toward ne driven hydraulic gradient ( brehme et al . 2014 ) .',
#  'the fracture network along area characterized strike slip faults normal faults .',
#  'the sinistral faults strike 40 steeply dip toward se .',
#  'left step strike slip faults forms extension basin central study area .',
#  'normal faults extension basin strike nw dip 70 –80 beneath lake linau ( brehme et al . 2014 ) .',
#  'lithology lahendong area mainly characterized pre- , postand tondano formation plioto pleistocene age ( koestono et al . 2010 ) .',
#  'the rocks typically andesite , volcanic breccia tuff .',
#  'those types sampled borehole cores used determine porosity , permeability thermal conductivity .',
#  'effective porosity matrix permeability analyzed using cylindrical - shaped specimen dimension 5 cm 5 cm 9 2.5 cm oriented parallel coring ( brehme et al . 2016 ) .',
#  'thermal conductivity measured plain sections dried cores .',
#  'the experimental setup consists gas permeameter determining matrix permeability ( milsch et al . 2011 ) helium pycnometry effective porosity measurements ( johnson - maynard et al . 1994 ) optical scanner thermal conductivity measurements ( popov et al . 1999 ) .',
#  'these parameters measured averaged three rock types ( brehme et al . 2016 ; table 1 ) .',
#  'andesite effective porosity 3.7 % permeability 2.1 9 10 - 14 m2 thermal conductivity 1.8 w-1 k-1 ( dry ) 2.2 w-1 k-1 ( saturated ) .',
#  'tuff porosity 7.7 % lowest permeability 2.0 9 10 - 15 m2 1.6 w-1 k-1 ( saturated ) .',
#  'volcanic breccia permeable layer effective porosity 10.5 % permeability 2.3 9 10 - 14 m2 thermal conductivity 1.6 w-1 k-1 ( dry ) 2.5 w-1 k-1 ( saturated ) .',
#  'reservoir rocks reﬂect generally low matrix permeability suggesting fracture - controlled ﬂuid ﬂow throughout aquifer ( brehme et al . 2016 ) .',
#  '( dry ) 2.1 w-1 k-1 thermal conductivity model setup model geometry numerical models developed study area represent initial conditions reservoir production commercial ﬁnite injection start .',
#  'for simulation , fig . 2',
#  'cross section modeled area geological structure , boundary conditions location observation points 123 1088 page 4 11 environ earth sci ( 2016 ) 75:1088 table 1 thermal hydraulic parameters lahendong reservoir rocks measured laboratory ( brehme et al . 2016 )',
#  'sample ( name , depth ) rock type effective porosity ( % )',
#  'thermal conductivity dry ( w-1 k-1 ) thermal conductivity saturated ( w-1 k-1 ) matrix permeability ( m2 ) lhd1 500–501 lhd1 801–802 lhd1 1000–1001 lhd1 2100–2101 lhd2 300–302 lhd3 2201–2203 lhd4 652–653 lhd4 850–852 lhd4 1001–1002 lhd4 2304–2305 lhd5 602–603 lhd5 752–753 lhd5 1102–1103 lhd5 1404–1406 lhd5 1575–1576 lhd7 901–902,3 lhd7 1567.8–1568 lhd7 1756–1758 average values andesite ( ) breccia ( ) tuff ( ) 1.1 14.5 5.0 7.2 12.5 5.7 6.3 1.6 16.4 1.6 16.3 2.7 5.2 3.6 0.6 4.6 11.0 3.9 3.7 10.5 7.7 ( lhd1 550 ) 2.0 ( lhd1 550 ) 2.2 1.6 1.8 1.4 2.1 1.8 1.4 1.8 1.4 1.9 1.5 1.6 2.1 1.8 1.6 1.6 2.4 2.2 2.0 2.4 2.0 2.7 2.7 2.3 2.3 1.7 2.2 2.7 2.2 2.5 2.1 1.5 9 10 - 14 8.9 9 10 - 16 3.3 9 10 - 15 6.1 9 10 - 14 1.5 9 10 - 14 1.3 9 10 - 14 2.3 9 10 - 14 6.8 9 10 - 14 3.4 9 10 - 16 1.1 9 10 - 14 1.1 9 10 - 16 7.9 9 10 - 14 3.0 9 10 - 15 7.9 9 10 - 18 7.2 9 10 - 16 1.7 9 10 - 15 1.7 9 10 - 14 2.1 9 10 - 14 2.3 9 10 - 14 2.0 9 10 - 15 element software feflow used model pressuredriven thermally induced ﬂuid ﬂow including viscosity changes .',
#  'governing equations ﬂuid ﬂow heat transport saturated porous media derived conservation principles linear momentum , mass energy ( dhi - wasy 2009 ) .',
#  'details software parameterization found diersch ( 2014 ) .',
#  'the model geometry 2d vertical sw – ne trending cross section extending 6 km horizontal 3 km vertical direction .',
#  'the direction proﬁle selected cover relevant processes lahendong geothermal ﬁeld : it cuts major faults production injection wells used temperature pressure calibration .',
#  'furthermore groundwater ﬂow direction , showing major ﬂuid ﬂow activities .',
#  'the homogeneous isotropic geological layers model stratiﬁed nearly horizontally .',
#  'faults middle model , striking perpendicular cross section , dip 84 toward cooling pluton beneath lake linau .',
#  'details structural geological components modeled region presented brehme et al . ( 2014 ) .',
#  'parallel numerical the mesh used simulation feflow consists 45,264 nodes 89,320 elements denser surrounding faults expected gradients due parameter contrasts .',
#  'material properties 123 elements permeability , porosity thermal conductivity set according laboratory measurements ( table 1 ) .',
#  'however , properties faults lake linau slightly adapted speciﬁc conditions .',
#  'the definitions modeled grids along faults follows : porosity 30 % thermal conductivity 1.8 w-1 k-1 .',
#  'corresponding grids lake linau deﬁned porosity 100 % thermal conductivity 0.6 w-1 k-1 .',
#  'the model simulates ﬂuid ﬂow thermal transport saturated media steady state .',
#  'initial values boundary conditions fluid ﬂow boundary conditions model describe groundwater heads recharge amounts ( table 2 ; fig . 2 ) .',
#  'the hydraulic head sw model boundary 837 500 ne boundary .',
#  'the sw hydraulic head represents inﬁltration surface water fault , striking perpendicular model .',
#  'hydraulic head ne border adapted borehole measurements area ( brehme et al . 2014 ) .',
#  'inﬁltration fault zones lake linau described ﬂuid ﬂux boundary conditions .',
#  'the quantity 3.0 9 10 - 4 - 1 sw 1.3 9 10 - 6 - 1 ne fault distributed 40 fault width .',
#  'groundwater recharge set 412 mm-1 ne top surface ( table 2 ; fig . 2 ) .',
#  'fluid movement environ earth sci ( 2016 ) 75:1088',
#  'page 5 11 1088 0 0 1',
#  '2 model domain constrained-ﬂow boundary bottom , recharge surrounding fault zones low hydraulic heads ne model area .',
#  'discharge system central study area mainly toward lake linau across ne model boundary .',
#  'initial hydraulic head whole model domain 500 .',
#  'the heat 116 km-1 transport boundary conditions time - invariant , ﬁxed temperatures heat ﬂux ( table 2 ; fig . 2 ) .',
#  'thermal gradient sw model boundary temperature constant 350 pluton .',
#  'temperature water inﬁltrating faults mixing shallow warm groundwater 70 surface groundwater recharge 28 .',
#  'temperature values obtained ﬁeld bore log measurements ( brehme et al . 2014 ) .',
#  'heat ﬂux set 100 mw-2 bottom model boundary ( table 2 ; fig . 2 ) .',
#  'this value ﬁxed based studies delisle et al . ( 1998 ) , nagao uyeda ( 1995 ) neben et al .',
#  'initial temperature model domain set 116 km-1 , according local thermal gradient .',
#  'permeability determination initial values permeability deﬁned based laboratory measurements ( table 1 ) .',
#  'after simulation run , modeled measured temperature pressure values compared indicated observation points .',
#  'in case poor matching ( errors [ 10 % ) , permeability adjusted satisfactory results achieved .',
#  'beneath lake linau , simulation results showed locally strong discrepancies modeled measured pressure temperature ( errors [ 45 % ) .',
#  'adjustment permeability geological inﬁltration rates faults hydraulic heads lead acceptable results .',
#  'only implementation strong permeability anisotropy throughout whole depth.e .',
#  'additional fault , resulted minimization errors ( 0–7 % ) .',
#  'implementation accomplished mesh adaptation ensure appropriate behavior around fault .',
#  'by procedure , permeability anisotropies located characterized detail throughout model .',
#  'layers ,',
#  'in general , deﬁning direction - dependent permeability improves data ﬁt rather using similar permeabilities directions .',
#  'this probably due fractures increasing permeability mostly vertical direction .',
#  'porosity thermal conductivity remained constant throughout simulation .',
#  'variation porosity negligible would directly reﬂected permeability thermal conductivity differences would affect conductive heat transport dominant lahendong area ( ondrak et al . 1998 ; brehme et al . 2014 ) .',
#  ', ) 5 0 0 2 ( l¨ , ) 7 0 0 2 ( ) 8 9 9 1 ( .',
#  '1088 page 6 11 results numerical simulation performed obtain best ﬁt measured data changing absolute relative permeability geological elements .',
#  'relative permeability refers different permeabilities horizontal vertical direction .',
#  'as main result blind fault recognized beneath lake linau known former studies .',
#  'simulated pressure temperature measured ﬁve selected observation points represent boreholes available bore logs pressure temperature .',
#  'details data given fig . 6 .',
#  'the model best data ﬁt 370 different models considered generate ﬁnal model developed lahendong .',
#  'permeability distribution identiﬁcation blind fault distribution permeability patterns reservoir conceived comparing temperature pressure data several wells .',
#  'especially beneath lake linau , closely located wells show high variations temperature pressure .',
#  'drop 100 18 bar along 300 distance observed well lhd 24 lhd 28 .',
#  'models ﬁrst showed high discrepancies modeled measured values area .',
#  'however implementing another high anisotropic permeable structure observation points , models resulted satisfactory results .',
#  'the structure ten times higher vertical environ earth sci ( 2016 )',
#  '75:1088 permeability horizontal permeability .',
#  'this structure assumed another fault zone located two known faults vertical dip nw strike .',
#  'this fault shows trace surface covered lake linau .',
#  'generally , modeled permeability distribution lahendong reservoir direction - dependent overprints lithology .',
#  'modeled permeability generally higher measured ones order four magnitudes .',
#  'this due fracture patterns detectable core - sample scale .',
#  'permeability patterns directly affect subsurface ﬂuid ﬂow temperature pressure distribution .',
#  'permeability faulted zones surroundings lowest study area .',
#  'especially middle ne fault shallow area beneath sw lake linau deep ne section ne fault show low permeabilities 10 - 13 10 - 14 m2 ( fig . 3 ) .',
#  'the area middle ne fault deep section ne sw fault sw fault whole model area toward sw ne boundary show higher permeabilities 10 - 10 10 - 12 m2 ( fig . 3 ) .',
#  'permeability varies within modeled area also vertical horizontal direction .',
#  'in faults deep reservoir section ne , permeability factor 10 higher vertical direction horizontal direction ( fig . 3 ) .',
#  'in areas faults , permeability parts factor 10–100 lower vertical direction .',
#  'in rest model , vertical horizontal permeability differ ( fig . 3 ) .',
#  'fig . 3 final adapted permeability anisotropy distribution throughout model domain .',
#  'anisotropy shows relation vertical horizontal permeability anisotropy [ 1 vertical permeability higher horizontal permeability 123 environ earth sci ( 2016 ) 75:1088',
#  'page 7 11 1088 fig . 4 modeled temperature pressure distribution study area shows high - pressure ﬁelds sw convective heat transport rising hot ﬂuids inﬁltration cooler water faults pressure distribution',
#  'the pressure distribution study area controlled groundwater ﬂow low permeable rocks vertically high permeable fault zones .',
#  'isobars drop following natural hydraulic gradient sw ne .',
#  'the sw section system shows higher pressures caused inﬁltration higher elevations sw .',
#  'some wells existing region artesian - type .',
#  'overpressure releases high permeable zones beneath lake linau discharges toward surface .',
#  'the pressure drop 20 bars across faults ( fig . 4 ) .',
#  'temperature distribution temperature distribution along lahendong geothermal reservoir suggests convective heat transport dominating process reservoir rocks .',
#  'isotherms generally follow sw – ne oriented ﬂow pattern rise inﬁltration ﬂuids .',
#  'upwelling isotherms faults veriﬁes water rise toward lake linau .',
#  'inﬁltration cold water causes welling isotherms particularly northeast section model .',
#  'temperature locally increased bottom model surrounding pluton ( fig . 4 ) .',
#  'subsurface ﬂuid ﬂow the absolute horizontal / vertical permeability distribution controls local ﬂuid ﬂow lahendong reservoir .',
#  'the general ﬂuid ﬂow , driven natural pressure gradient oriented sw ne .',
#  'vertical inﬁltration occurs faults lake linau sw boundary .',
#  'discharge across ne model boundary ( fig . 5 ) .',
#  'the detailed ﬂow patterns observed streamlines show ﬂuid ﬂow along highly permeable areas .',
#  'calculated streamlines describe particle ﬂow within model domain .',
#  'forward calculation shows inﬁltrating water sw model boundary distributes reservoir .',
#  'the backward calculation shows source ﬂuid particles arriving ne model boundary ( fig . 5 ) .',
#  'patterns show hot groundwater ﬂows toward faults beneath lake linau ﬂuid ﬂow disturbed rise temperature vertically high permeable layers .',
#  'this causes rise groundwater model area ( red forward streamlines fig . 5 ) .',
#  'at time , cold water inﬁltrates high permeable areas distributes ne model domain ( blue backward streamlines fig . 5 ) .',
#  'it clearly seen composition ne reservoir domain dominated coldwater inﬁltration faults production areas characterized hot water ﬂow ( fig . 5 ) .',
#  'discussion investigation subsurface ﬂuid ﬂow geothermal reservoirs crucial sustainable exploitation avoiding drilling less productive areas .',
#  'subsurface ﬂuid ﬂow might locally inﬂuenced fault zones physical 123 1088 page 8 11 environ earth sci ( 2016 ) 75:1088',
#  'fig . 5 model domain calculated streamlines red : forward streamlines follow hydraulic gradient sw model boundary towards ne blue : backward streamlines representing inﬁltrating cold water ﬂowing towards ne model boundary properties water ( .e .',
#  'viscosity ) .',
#  'the inﬂuence parameters ﬂuid ﬂow investigated lahendong geothermal reservoir using hydraulic – thermal simulations .',
#  'simulation results show detailed permeability distribution reservoir including location additional fault zone .',
#  'matching measured simulated temperature pressure used tool resolving permeability distribution .',
#  'temperature pressure iteratively determined several observation points ( fig . 2 ) .',
#  'generally , modeled values good agreement observed ones ( fig . 6 ) .',
#  'nevertheless observation points give slightly different values pressure temperature ( lhd 4 lhd 7 ) temperature ( lhd 24 ) .',
#  'this probably due complicated ﬂow processes strong small - scale structural variation fractured faulted areas .',
#  'furthermore , density variations could included simulation due high temperatures , could cause variation ﬂuid pressure .',
#  'however average deviation simulated pressure temperature 1 % .',
#  'implemented model parameters porosity , permeability heat conductivity .',
#  'from parameters permeability tested speciﬁc range simulation .',
#  'the inﬂuence porosity heat conductivity ﬂuid ﬂow negligible due dominating convective heat ﬂow ( ondrak et al . 1998 ) .',
#  'values implemented model based measured permeabilities represent matrix permeability rocks .',
#  'the measured matrix permeability , representing permeability horizontal direction 1.5 9 10 - 14 m2 123 average remains within typical permeability range fractured igneous rocks ( scho¨n 2004 ) .',
#  'permeability volcanic breccias ranges typically 3 9 10 - 15 5 9 10 - 12 m2 tuff permeabilities range 7 9 10 - 17 7 9 10 - 12 m2 ( klavetter peters 1987 ) .',
#  'in wairakei geothermal ﬁeld , simulating impermeable layers resulted permeabilities 10 - 18 10 - 14 m2 horizontal vertical axis , respectively ( mercer faust 1979 ) .',
#  'however , permeability reservoir rocks might locally increased due fracture formation .',
#  'it might also decreased due alteration sealing faults .',
#  'in lahendong , modeled permeability four magnitudes higher measured ones faulted areas .',
#  'this caused fractures detectable core scale .',
#  'moreover fault cores factor 10 higher vertical direction horizontal direction .',
#  'however areas faults ( fault gauge ) , permeability parts factor 10–100 lower vertical direction .',
#  'adaptation permeability ensures ﬁt measured temperature pressure data .',
#  'permeability fractured areas main factor inﬂuencing subsurface ﬂuid ﬂow temperature distribution lahendong reservoir area .',
#  'subsurface ﬂuid ﬂow driven local hydraulic heads show high variations different sections study area .',
#  'consequently , convective heat distribution leads high temperature variation along reservoir .',
#  'these phenomena observed lahendong well comparable ﬁelds .',
#  'in new mexico , water level drops 30–100 observed across ( haneberg 1995 ) .',
#  'high several fault zones environ earth sci ( 2016 )',
#  'page 9 11 1088 400 350 300 250 200 150    ] [   ',
#  '100 100 lhd 5 lhd 28 lhd 7 lhd 4 lhd 24 date well name date drilling bore log completed oct 1985 jan 86',
#  'may 1986 jul 2000 jul 96 oct 1987 jul 09 jul 09 aug 09 aug 09 lhd 4 lhd 5 lhd 7 lhd 24 lhd 28 150 200 250 300 350 400 modelled temperature [ ] 150 140 130 120 110    ] [   ',
#  '   100 100 7 24 4 28 5 well name lhd 4 lhd 5 lhd 7 lhd 24 lhd 28 reservoir depth       [ ] surface 1400 1750 2100 1820 1800 110 120 130 140 400 modelled pressure [ bar ] fig . 6 modeled versus measured temperature pressure selected observation points .',
#  'well speciﬁcations measured data brehme et al .',
#  '( 2014 ) temperature drops upwelling isotherms indicate fault zones control ﬂuid ﬂow lake long valentine ﬁelds , usa ( hooper 1991 ) .',
#  'the analysis ﬂuid pressure differences alpine fault , new zealand , allowed characterize change permeability hanging footwall blocks ( sutherland et al . 2012 ) .',
#  'in summary , high pressure temperature gradients indicators ﬂuid barriers observation points .',
#  'in words , reservoir sections different properties separated horizontally less permeable faults .',
#  'in lahendong signiﬁcant ﬂuid barriers faults sw ne lake linau .',
#  'across barriers pressure drops 20 bars .',
#  'similar pattern measured bore logs beneath lake linau surface trace fault observed former studies .',
#  'however implementing another fault , modeled measured values could adapted .',
#  'the recently identiﬁed fault zone beneath lake linau remains lake water therefore traceable kind reservoir modeling .',
#  'additionally fault identiﬁcation internal structure known fault zones understood detail .',
#  'the ne fault.e . , shows displacement 2 km depth .',
#  'the detailed trend understood permeability adaptation area .',
#  'due low permeability horizontal direction faults , ﬂuids propagate mostly vertically toward hot springs surface .',
#  'it also allows surface water inﬁltrate reservoir case pressure within fault zone low enough ( fig . 5 ) .',
#  'this vertical ﬂuid movement eventually controls temperature distribution reservoir .',
#  'upward migration deep hot water increases temperature inﬁltration cold surface water causes local drop temperature .',
#  'in summary important factors inﬂuencing reliability numerical reservoir models absolute different horizontal vertical permeability .',
#  'however permeability adaptation done geological layer ; vertical permeability anomalies overprinting layers constraining regional groundwater ﬂow .',
#  'those permeabilities fractures directly inﬂuence productivity reservoir',
#  '( cherubini et al . 2013 ) .',
#  'therefore permeability characteristics investigated detail .',
#  'in previous study numerical model lahendong site set tough2 aimed forecasting reservoir behavior exploitation year 2036 .',
#  'with production 60 mwe predicts pressure drop 10 bars .',
#  'however forecast results uncertain due lack measured pressure draw data ( yani 2006 ) .',
#  'accordingly next steps presented study include realistic production injection scenario order reservoir exploitation .',
#  'furthermore , chemical characteristics could considered achieve reliable production setups hydrochemical processes play important role lahendong reservoir ( brehme et al . 2016 ) .',
#  'presented models study provide important information ﬂuid ﬂow water - dominated lahendong reservoir .',
#  'however , additional two - phase ﬂow models support sustainable 123 1088 page 10 11 environ earth sci ( 2016 ) 75:1088',
#  'lahendong area progress understand inﬂuence steam driven ﬂuid ﬂow high - temperature system .',
#  'conclusion the primary focus study understand inﬂuence fault zones permeability patterns subsurface ﬂuid ﬂow geothermal reservoirs .',
#  'the ﬂuid ﬂow mainly depends rock fault zone permeability .',
#  'these processes considered numerical models simulate local temperature pressure conditions .',
#  'initial reservoir conditions refers case production starts .',
#  'models developed based conceptual models study area explain reservoir geometry , geological structures , temperature hydraulic conditions .',
#  'temperature pressure well - logs used model calibration .',
#  'the numerical models represent vertical horizontal ﬂuid ﬂow mainly controlled fault permeability .',
#  'this characteristic used simulate different reservoir sections vertical ﬂuid rise toward surface .',
#  'by stepwise adaptation permeability ﬁelds , based observed temperature pressure gradients additional blind fault zone identiﬁed beneath lake linau .',
#  'temperature pressure signiﬁcantly drop across ﬂuid barrier .',
#  'this behavior observed comparable ﬁelds usa well .',
#  'the overall shape ﬂuid ﬂow direction trends sw – ne direction .',
#  'main recharge occurs inﬁltration surface water faults , especially southwest near lake linau .',
#  'discharge enhanced highly fractured areas toward lake linau .',
#  'vertical permeability faults allows ﬂuids rising toward hot springs surface .',
#  'results show permeability considered simulation geothermal system .',
#  'the geothermal system mainly controlled ﬂuid ﬂow fractures / faults depending temperature pressure conditions .',
#  'the locally modiﬁed ﬂuid ﬂow considerably inﬂuence productivity geothermal ﬁeld .',
#  'results also guide reservoir management case potential ﬁeld extension performed lahendong .',
#  'acknowledgments']

# %%
ready_nlp
# Out:
# {'Text': ['lithology lahendong area mainly characterized pre- , postand tondano formation plioto pleistocene age ( koestono et al . 2010 ) .'],
#  'Tag': ['pleistocene'],
#  'Entity': ['Chrono']}

# %% [markdown]
# ## One Hot Encoding

# %%
voc_size = 10000
onehot_repr = [one_hot(words, voc_size) for words in text_stw_sent]
onehot_repr

# %% [markdown]
# ## Add Pading

# %%
sent_length = 20
embedded_docs = pad_sequences(onehot_repr, padding = 'pre', maxlen=sent_length)
print(embedded_docs)

# %% [markdown]
# ## OHE to Vector + Model

# %%
embedding_vector_features=40
model = Sequential()
model.add(Embedding(voc_size, embedding_vector_features, input_length = sent_length))
model.add(LSTM(100)) #LSTM with 100 neurons
model.add(Dense(32, activation = 'relu')) #Our Output is is Classesy. SO it's better relu
model.compile(optimizer='adam', metrics=['accuracy'])
print(model.summary())
