# %%
import re
import regex
import glob
import os

# %% [markdown]
# # Non English Alphabetic Conditioning

# %%
def search_bool(j):
    aa = [
        bool(re.search(r'ö',j)),
        bool(re.search(r'ä',j)),
        bool(re.search(r'ü',j)),
        bool(re.search(r'é',j)),
        bool(re.search(r'í',j)),
        bool(re.search(r'á',j)),
        bool(re.search(r'ú',j)),
        bool(re.search(r'ó',j)),
        bool(re.search(r'ð',j)),
        bool(re.search(r'è',j)),
        bool(re.search(r'ñ',j)),
        bool(re.search(r'æ',j)),
        bool(re.search(r'ý',j)),
        bool(re.search(r'ß',j)),
        bool(re.search(r'\bst.\b',j)),
        bool(re.search(r'ô',j)),
        bool(re.search(r'\bst-\b',j)),
        bool(re.search(r'þ',j))]
    return aa

def append_tool(j):
    a =[
        re.sub(r'ö','oe',j),
        re.sub(r'ä','ae',j),
        re.sub(r'ü','ue',j),
        re.sub(r'é','e',j),
        re.sub(r'í','i',j),
        re.sub(r'á','a',j),
        re.sub(r'ú','u',j),
        re.sub(r'ó','o',j),
        re.sub(r'ð','d',j),
        re.sub(r'è','e',j),
        re.sub(r'ñ','n',j),
        re.sub(r'æ','ae',j),
        re.sub(r'ý','y',j),
        re.sub(r'ß','ss',j),
        re.sub(r'\bst.\b','saint ',j),
        re.sub(r'ô','o',j),
        re.sub(r'\bst-\b','saint ',j),
        re.sub(r'þ','p',j)
]
    return a

# %%
path='C:/Users/Ryan Bobby A/Documents/RWTH AACHEN/KULIAH/THESIS_BISMILLAH/Thesis Progress/list_entities/'
for filename in glob.glob(os.path.join(path, '*.txt')):
    gist_file = open(filename, "r")
    lis = list(filter(None, gist_file.read().lower().split("\n")))
    extra = []
    for i,j in enumerate(lis):
        layer = [i for i, x in enumerate(search_bool(lis[i])) if x == True]
        if len(layer) > 0:
            layer1 = lis[i]
            for l in layer:
                layer1 = append_tool(layer1)[l]           
            if layer1 not in lis:
                extra.append(layer1)
            else:
                pass
        else:
            pass
    
    with open(filename, 'w') as f:
        for i in lis + extra:
            f.write(str(i) + '\n')

# %%
path = 'list_entities\list_states.txt'

# %%
lis = []
with open(path,'r') as l:
    for i in l.readlines():
        lis.append(re.sub(r'\n','',i))
lis
# Out:
# ['massachusetts',
#  'california',
#  'rhode island',
#  'vermont',
#  'transvaal',
#  'pennsylvania',
#  'montana',
#  'quebec',
#  'wisconsin',
#  'north carolina',
#  'bavaria',
#  'louisiana',
#  'texas',
#  'oklahoma',
#  'colorado',
#  'utah',
#  'wyoming',
#  'oregon',
#  'washington',
#  'kyushu',
#  'akita',
#  'hokkaido',
#  'atlantic ocean',
#  'hawaii',
#  'java',
#  'brandenburg',
#  'schleswig-holstein',
#  'western namibia',
#  'southeastern australia',
#  'western south africa',
#  'bahia',
#  'michigan',
#  'new hampshire',
#  'iberian peninsula',
#  'queensland',
#  'ontario',
#  'corsica',
#  'north taiwan',
#  'central',
#  'ávila',
#  'fars',
#  'inyo county',
#  'chhattisgarh',
#  'scotland',
#  'northern territory',
#  'central zimbabwe',
#  'idaho',
#  'singida',
#  'southern india',
#  'otjozondjupa',
#  'central zambia',
#  'khémisset',
#  'dawson strait',
#  'baden-württemberg',
#  'manitoba',
#  'karnataka',
#  'jalisco',
#  'east greenland',
#  'sierra nevada',
#  'bretagne',
#  'southern france',
#  'central northern nepal',
#  'karas',
#  'jharkand',
#  'alaska',
#  'southern finland',
#  'eastern south africa',
#  'scottland',
#  'andhra pradesh',
#  'pyrenees',
#  'western australia',
#  'central south africa',
#  'bodrum',
#  'parinacota',
#  'antofagasta',
#  'northeastern spain',
#  'moresby strait',
#  'central eastern china',
#  'ivrea-verbano',
#  'salta',
#  'virunga',
#  'eastern australia',
#  'tarapacá',
#  'khomas',
#  'vianden',
#  'western russia',
#  'galicia',
#  'central nepal',
#  'australia',
#  'bismarck archipelago',
#  'manyara',
#  'québec',
#  'erongo',
#  'tamil nadu',
#  'eastern canada',
#  'arusha',
#  'sud',
#  'iguape',
#  'rhineland-palatinate',
#  'north west',
#  'jiangsu',
#  'dodoma',
#  'heard island',
#  'mcdonald islands',
#  'labrador',
#  'iowa',
#  'banks peninsula, christchurch',
#  'nova scotia',
#  'garratoxa',
#  'kansas',
#  'tristan da cunha',
#  'gough',
#  'northern tanzania',
#  'chile & argentina',
#  'vogelsaug',
#  'mashonaland',
#  'apennines',
#  'kastamonu',
#  'piemonte',
#  'mutasa',
#  'oberbergau',
#  'ascension',
#  'masvingo',
#  'southern brazil',
#  'northwest territories',
#  'western iran',
#  'st. helena',
#  'kilimanjaro region',
#  'kunene',
#  'bouvet',
#  'viti levu, tavua',
#  'kamchatka',
#  "sana'a and amran",
#  'victoria',
#  'bougainville',
#  'norther pacific',
#  'new hebrides',
#  'kgalagadi',
#  'niuatoputapu',
#  'north-east',
#  'western cordillera',
#  'montechristi',
#  'new britain',
#  'santa isabel',
#  'malaita',
#  'gorgona island',
#  'gansu province',
#  'michoacán ',
#  'puebla',
#  'tushka',
#  'campanian',
#  'pozzuoli/ campanian',
#  'roman',
#  'red sea area',
#  'sinai',
#  'western desert',
#  'akranes',
#  'hvalfjarðarsveit',
#  'borgarbyggð',
#  'grundarfjörður',
#  'grundarfjarðarbær',
#  'gullbringusýsla',
#  'west tushka',
#  'hornafjörður',
#  'chelungpu fault',
#  'hvalfjarðarstrandarhreppur',
#  'hveragerði',
#  'antalya',
#  'icel',
#  'mugla',
#  'konya',
#  'burgur',
#  'nigde',
#  'diayarbakir',
#  'bursa',
#  'aksaray',
#  'kayseri',
#  'ayfonkarahisar',
#  'afyonkarahisar',
#  'kutahya',
#  'izmir',
#  'izmir or balikesir',
#  'kirsehir',
#  'sivas',
#  'marmara island',
#  'provinz pontevedra',
#  'mosfellsbær',
#  'snæfellsbær',
#  'reykjavík',
#  'skorradalshreppur',
#  'skútustaðahreppur',
#  'kerala',
#  'vesturland',
#  'nevada',
#  'north german basin',
#  'alberta',
#  'hessen',
#  'tirol',
#  'ile de france',
#  'campanian area',
#  'rome',
#  'sicily',
#  'messina',
#  'rhode island',
#  'niedersachsen',
#  'east midlands',
#  'south iceland',
#  'lahendong',
#  'washington state',
#  'british columbia',
#  'suðurnes',
#  'waikato',
#  'colima',
#  'jalisco ',
#  'giresun',
#  'gümüshane',
#  'lower saxonyniedersachsen',
#  'baden würtemberg',
#  'rheinland pfalz',
#  'bengal basin']

# %%
extra = []
for i,j in enumerate(lis):
    layer = [i for i, x in enumerate(search_bool(lis[i])) if x == True]
    if len(layer) > 0:
        layer1 = lis[i]
        for l in layer:
            layer1 = append_tool(layer1)[l]           
        if layer1 not in lis:
            extra.append(layer1)
        else:
            pass
    else:
        pass
lis = lis + extra
lis
# Out:
# ['massachusetts',
#  'california',
#  'rhode island',
#  'vermont',
#  'transvaal',
#  'pennsylvania',
#  'montana',
#  'quebec',
#  'wisconsin',
#  'north carolina',
#  'bavaria',
#  'louisiana',
#  'texas',
#  'oklahoma',
#  'colorado',
#  'utah',
#  'wyoming',
#  'oregon',
#  'washington',
#  'kyushu',
#  'akita',
#  'hokkaido',
#  'atlantic ocean',
#  'hawaii',
#  'java',
#  'brandenburg',
#  'schleswig-holstein',
#  'western namibia',
#  'southeastern australia',
#  'western south africa',
#  'bahia',
#  'michigan',
#  'new hampshire',
#  'iberian peninsula',
#  'queensland',
#  'ontario',
#  'corsica',
#  'north taiwan',
#  'central',
#  'ávila',
#  'fars',
#  'inyo county',
#  'chhattisgarh',
#  'scotland',
#  'northern territory',
#  'central zimbabwe',
#  'idaho',
#  'singida',
#  'southern india',
#  'otjozondjupa',
#  'central zambia',
#  'khémisset',
#  'dawson strait',
#  'baden-württemberg',
#  'manitoba',
#  'karnataka',
#  'jalisco',
#  'east greenland',
#  'sierra nevada',
#  'bretagne',
#  'southern france',
#  'central northern nepal',
#  'karas',
#  'jharkand',
#  'alaska',
#  'southern finland',
#  'eastern south africa',
#  'scottland',
#  'andhra pradesh',
#  'pyrenees',
#  'western australia',
#  'central south africa',
#  'bodrum',
#  'parinacota',
#  'antofagasta',
#  'northeastern spain',
#  'moresby strait',
#  'central eastern china',
#  'ivrea-verbano',
#  'salta',
#  'virunga',
#  'eastern australia',
#  'tarapacá',
#  'khomas',
#  'vianden',
#  'western russia',
#  'galicia',
#  'central nepal',
#  'australia',
#  'bismarck archipelago',
#  'manyara',
#  'québec',
#  'erongo',
#  'tamil nadu',
#  'eastern canada',
#  'arusha',
#  'sud',
#  'iguape',
#  'rhineland-palatinate',
#  'north west',
#  'jiangsu',
#  'dodoma',
#  'heard island',
#  'mcdonald islands',
#  'labrador',
#  'iowa',
#  'banks peninsula, christchurch',
#  'nova scotia',
#  'garratoxa',
#  'kansas',
#  'tristan da cunha',
#  'gough',
#  'northern tanzania',
#  'chile & argentina',
#  'vogelsaug',
#  'mashonaland',
#  'apennines',
#  'kastamonu',
#  'piemonte',
#  'mutasa',
#  'oberbergau',
#  'ascension',
#  'masvingo',
#  'southern brazil',
#  'northwest territories',
#  'western iran',
#  'st. helena',
#  'kilimanjaro region',
#  'kunene',
#  'bouvet',
#  'viti levu, tavua',
#  'kamchatka',
#  "sana'a and amran",
#  'victoria',
#  'bougainville',
#  'norther pacific',
#  'new hebrides',
#  'kgalagadi',
#  'niuatoputapu',
#  'north-east',
#  'western cordillera',
#  'montechristi',
#  'new britain',
#  'santa isabel',
#  'malaita',
#  'gorgona island',
#  'gansu province',
#  'michoacán ',
#  'puebla',
#  'tushka',
#  'campanian',
#  'pozzuoli/ campanian',
#  'roman',
#  'red sea area',
#  'sinai',
#  'western desert',
#  'akranes',
#  'hvalfjarðarsveit',
#  'borgarbyggð',
#  'grundarfjörður',
#  'grundarfjarðarbær',
#  'gullbringusýsla',
#  'west tushka',
#  'hornafjörður',
#  'chelungpu fault',
#  'hvalfjarðarstrandarhreppur',
#  'hveragerði',
#  'antalya',
#  'icel',
#  'mugla',
#  'konya',
#  'burgur',
#  'nigde',
#  'diayarbakir',
#  'bursa',
#  'aksaray',
#  'kayseri',
#  'ayfonkarahisar',
#  'afyonkarahisar',
#  'kutahya',
#  'izmir',
#  'izmir or balikesir',
#  'kirsehir',
#  'sivas',
#  'marmara island',
#  'provinz pontevedra',
#  'mosfellsbær',
#  'snæfellsbær',
#  'reykjavík',
#  'skorradalshreppur',
#  'skútustaðahreppur',
#  'kerala',
#  'vesturland',
#  'nevada',
#  'north german basin',
#  'alberta',
#  'hessen',
#  'tirol',
#  'ile de france',
#  'campanian area',
#  'rome',
#  'sicily',
#  'messina',
#  'rhode island',
#  'niedersachsen',
#  'east midlands',
#  'south iceland',
#  'lahendong',
#  'washington state',
#  'british columbia',
#  'suðurnes',
#  'waikato',
#  'colima',
#  'jalisco ',
#  'giresun',
#  'gümüshane',
#  'lower saxonyniedersachsen',
#  'baden würtemberg',
#  'rheinland pfalz',
#  'bengal basin',
#  'avila',
#  'khemisset',
#  'baden-wuerttemberg',
#  'tarapaca',
#  'michoacan ',
#  'hvalfjardarsveit',
#  'borgarbyggd',
#  'grundarfjoerdur',
#  'grundarfjardarbaer',
#  'gullbringusysla',
#  'hornafjoerdur',
#  'hvalfjardarstrandarhreppur',
#  'hveragerdi',
#  'mosfellsbaer',
#  'snaefellsbaer',
#  'reykjavik',
#  'skutustadahreppur',
#  'sudurnes',
#  'guemueshane',
#  'baden wuertemberg']

# %%
with open (path,'w') as f:
    for item in lis:
        f.write(str(item) + '\n')
    f.close()

# %% [markdown]
# # Final Conditioning

# %%
lis_countr = []
with open('list_entities\list_countries.txt','r') as l:
    for i in l.readlines():
        lis_countr.append(re.sub(r'\n','',i).lower())
        
lis_states = []
with open('list_entities\list_states.txt','r') as l:
    for i in l.readlines():
        lis_states.append(re.sub(r'\n','',i))
        
lis_geol = []
with open('list_entities\list_geolocation.txt','r') as l:
    for i in l.readlines():
        lis_geol.append(re.sub(r'\n','',i))

# %%
pattern = r"((^\s*\b(?:{}))\b)".format("|".join(lis_countr))

for i,k in enumerate(lis_states):
    if bool(re.search(pattern, k)) == True:
        lis_states[i] = ''
    else:
        pass
lis_states = list(filter(None, lis_states))

with open ('list_entities\list_states.txt','w') as f:
    for item in lis_states:
        f.write(str(item) + '\n')
    f.close()    


for i,k in enumerate(lis_geol):
    if bool(re.search(pattern, k)) == True:
        lis_geol[i] = ''
    else:
        pass
lis_geol = list(filter(None, lis_geol))
    
with open ('list_entities\list_geolocation.txt','w') as f:
    for item in lis_geol:
        f.write(str(item) + '\n')
    f.close()

# %%
lis_countr
# Out:
# ['afghanistan',
#  'aland islands',
#  'albania',
#  'algeria',
#  'american samoa',
#  'andorra',
#  'angola',
#  'anguilla',
#  'antarctica',
#  'antigua barbuda',
#  'antigua',
#  'barbuda',
#  'argentina',
#  'armenia',
#  'aruba',
#  'australia',
#  'austria',
#  'azerbaijan',
#  'bahamas',
#  'bahrain',
#  'bangladesh',
#  'barbados',
#  'belarus',
#  'belgium',
#  'belize',
#  'benin',
#  'bermuda',
#  'bhutan',
#  'plurinational state bolivia',
#  'bolivia',
#  'sint eustatius saba bonaire',
#  'bonaire',
#  'bosnia herzegovina',
#  'bosnia',
#  'herzegovina',
#  'botswana',
#  'bouvet island',
#  'brazil',
#  'british indian ocean territory',
#  'brunei darussalam',
#  'bulgaria',
#  'burkina faso',
#  'burundi',
#  'cambodia',
#  'cameroon',
#  'canada',
#  'cape verde',
#  'cayman islands',
#  'central african',
#  'chad',
#  'chile',
#  'china',
#  'christmas island',
#  'cocos islands',
#  'keeling',
#  'colombia',
#  'comoros',
#  'congo',
#  'the democratic republic of the congo',
#  'cook islands',
#  'costa rica',
#  'cote divoire',
#  'croatia',
#  'cuba',
#  'curaçao',
#  'cyprus',
#  'czech republic',
#  'czech',
#  'denmark',
#  'djibouti',
#  'dominica',
#  'dominican republic',
#  'ecuador',
#  'egypt',
#  'el salvador',
#  'equatorial guinea',
#  'eritrea',
#  'estonia',
#  'ethiopia',
#  'falkland islands ',
#  'malvinas',
#  'faroe islands',
#  'fiji',
#  'finland',
#  'france',
#  'french guiana',
#  'french polynesia',
#  'french southern territories',
#  'gabon',
#  'gambia',
#  'georgia',
#  'germany',
#  'ghana',
#  'gibraltar',
#  'greece',
#  'greenland',
#  'grenada',
#  'guadeloupe',
#  'guam',
#  'guatemala',
#  'guernsey',
#  'guinea',
#  'guinea-bissau',
#  'guyana',
#  'haiti',
#  'heard island',
#  'mcdonald islands',
#  'holy see',
#  'vatican',
#  'honduras',
#  'hong kong',
#  'hungary',
#  'iceland',
#  'india',
#  'indonesia',
#  'iran',
#  'iraq',
#  'ireland',
#  'isle of man',
#  'israel',
#  'italy',
#  'jamaica',
#  'japan',
#  'jersey',
#  'jordan',
#  'kazakhstan',
#  'kenya',
#  'kiribati',
#  'south korea',
#  'north korea',
#  'kuwait',
#  'kyrgyzstan',
#  'lao',
#  'latvia',
#  'lebanon',
#  'lesotho',
#  'liberia',
#  'libya',
#  'liechtenstein',
#  'lithuania',
#  'luxembourg',
#  'macao',
#  'macedonia',
#  'madagascar',
#  'malawi',
#  'malaysia',
#  'maldives',
#  'mali',
#  'malta',
#  'marshall islands',
#  'martinique',
#  'mauritania',
#  'mauritius',
#  'mayotte',
#  'mexico',
#  'micronesia',
#  'moldova',
#  'monaco',
#  'mongolia',
#  'montenegro',
#  'montserrat',
#  'morocco',
#  'mozambique',
#  'myanmar',
#  'namibia',
#  'nauru',
#  'nepal',
#  'netherlands',
#  'new caledonia',
#  'new zealand',
#  'nicaragua',
#  'niger',
#  'nigeria',
#  'niue',
#  'norfolk island',
#  'northern mariana islands',
#  'norway',
#  'oman',
#  'pakistan',
#  'palau',
#  'palestine',
#  'panama',
#  'papua new guinea',
#  'paraguay',
#  'peru',
#  'philippines',
#  'pitcairn',
#  'poland',
#  'portugal',
#  'puerto rico',
#  'qatar',
#  'réunion',
#  'romania',
#  'russian federation',
#  'rwanda',
#  'saint barthelemy',
#  'saint helena ascension',
#  'tristan da cunha',
#  'saint kitts nevis',
#  'saint kitts',
#  'nevis',
#  'saint lucia',
#  'saint martin',
#  'saint pierre miquelon',
#  'saint vincent grenadines',
#  'samoa',
#  'san marino',
#  'sao tome principe',
#  'sao tome',
#  'principe',
#  'saudi arabia',
#  'senegal',
#  'serbia',
#  'seychelles',
#  'sierra leone',
#  'singapore',
#  'sint maarten',
#  'slovakia',
#  'slovenia',
#  'solomon islands',
#  'somalia',
#  'south africa',
#  'south georgia',
#  'south sandwich islands',
#  'spain',
#  'sri lanka',
#  'sudan',
#  'suriname',
#  'south sudan',
#  'svalbard jan mayen',
#  'svalbard',
#  'jan mayen',
#  'swaziland',
#  'sweden',
#  'switzerland',
#  'syria',
#  'taiwan',
#  'tajikistan',
#  'tanzania',
#  'thailand',
#  'timor leste',
#  'togo',
#  'tokelau',
#  'tonga',
#  'trinidad tobago',
#  'trinidad',
#  'tobago',
#  'tunisia',
#  'turkey',
#  'turkmenistan',
#  'turks',
#  'turks caicos islands',
#  'caicos islands',
#  'tuvalu',
#  'uganda',
#  'ukraine',
#  'united emirates arab',
#  'united kingdom',
#  'united states',
#  'united states minor outlying islands',
#  'uruguay',
#  'uzbekistan',
#  'vanuatu',
#  'venezuela',
#  'vietnam',
#  'virgin islands',
#  'wallis futuna',
#  'yemen',
#  'zambia',
#  'zimbabwe',
#  'reunion']

# %% [markdown]
# # No Spacing at the last entities

# %%
lis_petro = []

# %%
with open ('list_entities\list_petrography.txt','r') as f:
    for i in f.readlines():
        lis_petro.append(re.sub(r'\n','',i))

# %%
'|'.join(lis_petro)
# Out:
# 'consolidated|magmatic|plutonic|plutonic field description|very quartz rich plutonic|quartz rich granitic plutonic|quartz rich plutonic|granitic plutonic|quartz bearing to foid bearing plutonic|syenitic plutonic|dioritic plutonic|gabbrotic plutonic|foid rich plutonic|foid syenitic plutonic|foid dioritic plutonic|foid gabbrodic plutonic|very foid rich plutonic foidolite|foidolitic plutonic|ultra mafic plutonic|plutonic|quartzolite|granite|alkali feldspar granite|syenogranite|monzogranite|granodiorite|tonalite|quartz alkali feldspar syenite|quartz syenite|quartz monzonite|quartz monzodiorite|quartz monzogabbro|quartz diorite|quartz gabbro|quartz anorthosite|alkali feldspar syenite|syenite|monzonite|monzodiorite|monzogabbro|diorite|gabbro|gabbronorite|norite|troctolite|olivine gabbro|olivine gabbronorite|olivine norite|orthopyroxene gabbro|clinopyroxene norite|hornblende gabbro|pyroxene hornblende gabbro|pyroxene hornblende gabbronorite|pyroxene hornblende norite|anorthosite|foid bearing alkali feldspar syenite|foid bearing syenite|foid bearing monzonite|foid bearing monzodiorite|foid bearing monzogabbro|foid bearing diorite|foid bearing gabbro|foid bearing anorthosite|foid syenite eg. nepheline syenite|malignite|shoncinite|foid monzosyenite|foid monzodiorite|foid monzogabbro|foid diorite|foid gabbro|nephelinolite|urtite|ijolite|melteigite|leucitolite|italite|fergustite|missourite|ultramafic plutonics|peridotite|dunite|harzburgite|lherzolite|wehrlite|pyroxene peridotite|pyroxene hornblende peridotite|hornblende peridotite|pyroxenite|orthopyroxenite|olivine orthopyroxenite|websterite|olivine websterite|klinopyroxenite|olivine klinopyroxenite|olivine pyroxenite|olivine hornblende pyroxenite|plagioclase bearing pyroxenite|plagioclase bearing hornblende pyroxenite|hornblendite|pyroxene hornblendite|olivine hornblendite|olivine pyroxene hornblendite|plagioclase bearing hornblendite|plagioclase bearing pyroxene hornblendite|ultramafic melilitic plutonic|melilolite|olivine melilitolite|pyroxene melilitolite|olivine pyroxene melilitolite|pyroxene olivine melililolite|carbonatite plutonic|calcite carbonatite|dolomite carbonatite|ferro carbonatite|charnockite plutonic|volcanic|volcanic|quartz rich volcanic|rhyolitic volcanic|dacitic volcanic|quartz to foid bearing volcanic|trachytic volcanic|latitic volcanic|basaltic volcanic|tholeiitic volcanic|olivine basaltic volcanic|alkali basaltic volcanic|andesitic volcanic|foid rich volcanic|phonolitic volcanic|tephritic volcanic|basanitic volcanic|very foid rich volcanic|foiditic volcanic|ultramafic volcanic|volcanic  normativ|alkali feldspar rhyolite|rhyolite|rhyodacite|dacite|obsidian|quartz alkali feldspar trachyte|quartz trachyte|alkali feldspar trachyte|trachyte|foid bearing alkali feldspar trachyte|foid bearing trachyte|quartz latite|latite|foid bearing latite|basalt|tholeitic basalt|olivine basalt|alkali basalt|alkali basalt amphibole bearing|leucobasalt|leuco alkali basalt|andesite|mela andesite|phonolite|tephritic phonolite|tephrite|phonolitic tephrite|basanite|limburgite|basanite analcim rich|basanite amphibole bearing|phonolitic basanite|phonolitic foidite|tephritic foidite|basanitic foidite|foidite|nephelinite|melilite nephelinite|analcimite|leucitite|ultramafic volcanic|melilithite|olivine melilithite|melilithite bearing ultramafic|carbonatite|calcite carbonatite|dolomite carbonatite|ferro carbonatite|natro carbonatite|volcanic|acidic volcanic|intermediate volcanic|basic volcanics|ultra basic|sio oversaturated volcanic|rhyolite|comenditic rhyolite comendite|pantelleritic rhyolite pantellerite|trachydacite|dacite|high k dacite|medium k dacite|low k dacite|andesite|high k andesite|medium k andesite|low k andesite|basaltic andesite|high k basaltic andesite|medium k basaltic andesite|low k basaltic andesite|sio saturated volcanic|trachyte|trachite|peralkalic trachyte|comenditic trachyte|pantellitic trachyte|trachyandesite|benmoreite|latite|basaltic trachyandesite|mugearite|shoshonite|trac ...

# %%
for i,j in enumerate(lis_petro):
    lis_petro[i] = re.sub('\s+$','',j)
lis_petro
# Out:
# ['consolidated',
#  'magmatic',
#  'plutonic',
#  'plutonic field description',
#  'very quartz rich plutonic',
#  'quartz rich granitic plutonic',
#  'quartz rich plutonic',
#  'granitic plutonic',
#  'quartz bearing to foid bearing plutonic',
#  'syenitic plutonic',
#  'dioritic plutonic',
#  'gabbrotic plutonic',
#  'foid rich plutonic',
#  'foid syenitic plutonic',
#  'foid dioritic plutonic',
#  'foid gabbrodic plutonic',
#  'very foid rich plutonic foidolite',
#  'foidolitic plutonic',
#  'ultra mafic plutonic',
#  'plutonic',
#  'quartzolite',
#  'granite',
#  'alkali feldspar granite',
#  'syenogranite',
#  'monzogranite',
#  'granodiorite',
#  'tonalite',
#  'quartz alkali feldspar syenite',
#  'quartz syenite',
#  'quartz monzonite',
#  'quartz monzodiorite',
#  'quartz monzogabbro',
#  'quartz diorite',
#  'quartz gabbro',
#  'quartz anorthosite',
#  'alkali feldspar syenite',
#  'syenite',
#  'monzonite',
#  'monzodiorite',
#  'monzogabbro',
#  'diorite',
#  'gabbro',
#  'gabbronorite',
#  'norite',
#  'troctolite',
#  'olivine gabbro',
#  'olivine gabbronorite',
#  'olivine norite',
#  'orthopyroxene gabbro',
#  'clinopyroxene norite',
#  'hornblende gabbro',
#  'pyroxene hornblende gabbro',
#  'pyroxene hornblende gabbronorite',
#  'pyroxene hornblende norite',
#  'anorthosite',
#  'foid bearing alkali feldspar syenite',
#  'foid bearing syenite',
#  'foid bearing monzonite',
#  'foid bearing monzodiorite',
#  'foid bearing monzogabbro',
#  'foid bearing diorite',
#  'foid bearing gabbro',
#  'foid bearing anorthosite',
#  'foid syenite eg. nepheline syenite',
#  'malignite',
#  'shoncinite',
#  'foid monzosyenite',
#  'foid monzodiorite',
#  'foid monzogabbro',
#  'foid diorite',
#  'foid gabbro',
#  'nephelinolite',
#  'urtite',
#  'ijolite',
#  'melteigite',
#  'leucitolite',
#  'italite',
#  'fergustite',
#  'missourite',
#  'ultramafic plutonics',
#  'peridotite',
#  'dunite',
#  'harzburgite',
#  'lherzolite',
#  'wehrlite',
#  'pyroxene peridotite',
#  'pyroxene hornblende peridotite',
#  'hornblende peridotite',
#  'pyroxenite',
#  'orthopyroxenite',
#  'olivine orthopyroxenite',
#  'websterite',
#  'olivine websterite',
#  'klinopyroxenite',
#  'olivine klinopyroxenite',
#  'olivine pyroxenite',
#  'olivine hornblende pyroxenite',
#  'plagioclase bearing pyroxenite',
#  'plagioclase bearing hornblende pyroxenite',
#  'hornblendite',
#  'pyroxene hornblendite',
#  'olivine hornblendite',
#  'olivine pyroxene hornblendite',
#  'plagioclase bearing hornblendite',
#  'plagioclase bearing pyroxene hornblendite',
#  'ultramafic melilitic plutonic',
#  'melilolite',
#  'olivine melilitolite',
#  'pyroxene melilitolite',
#  'olivine pyroxene melilitolite',
#  'pyroxene olivine melililolite',
#  'carbonatite plutonic',
#  'calcite carbonatite',
#  'dolomite carbonatite',
#  'ferro carbonatite',
#  'charnockite plutonic',
#  'volcanic',
#  'volcanic',
#  'quartz rich volcanic',
#  'rhyolitic volcanic',
#  'dacitic volcanic',
#  'quartz to foid bearing volcanic',
#  'trachytic volcanic',
#  'latitic volcanic',
#  'basaltic volcanic',
#  'tholeiitic volcanic',
#  'olivine basaltic volcanic',
#  'alkali basaltic volcanic',
#  'andesitic volcanic',
#  'foid rich volcanic',
#  'phonolitic volcanic',
#  'tephritic volcanic',
#  'basanitic volcanic',
#  'very foid rich volcanic',
#  'foiditic volcanic',
#  'ultramafic volcanic',
#  'volcanic  normativ',
#  'alkali feldspar rhyolite',
#  'rhyolite',
#  'rhyodacite',
#  'dacite',
#  'obsidian',
#  'quartz alkali feldspar trachyte',
#  'quartz trachyte',
#  'alkali feldspar trachyte',
#  'trachyte',
#  'foid bearing alkali feldspar trachyte',
#  'foid bearing trachyte',
#  'quartz latite',
#  'latite',
#  'foid bearing latite',
#  'basalt',
#  'tholeitic basalt',
#  'olivine basalt',
#  'alkali basalt',
#  'alkali basalt amphibole bearing',
#  'leucobasalt',
#  'leuco alkali basalt',
#  'andesite',
#  'mela andesite',
#  'phonolite',
#  'tephritic phonolite',
#  'tephrite',
#  'phonolitic tephrite',
#  'basanite',
#  'limburgite',
#  'basanite analcim rich',
#  'basanite amphibole bearing',
#  'phonolitic basanite',
#  'phonolitic foidite',
#  'tephritic foidite',
#  'basanitic foidite',
#  'foidite',
#  'nephelinite',
#  'melilite nephelinite',
#  'analcimite',
#  'leucitite',
#  'ultramafic volcanic',
#  'melilithite',
#  'olivine melilithite',
#  'melilithite bearing ultramafic',
#  'carbonatite',
#  'calcite carbonatite',
#  'dolomite carbonatite',
#  'ferro carbonatite',
#  'natro carbonatite',
#  'volcanic',
#  'acidic volcanic',
#  'intermediate volcanic',
#  'basic volcanics',
#  'ultra basic',
#  'sio oversaturated volcanic',
#  'rhyolite',
#  'comenditic rhyolite comendite',
#  'pantelleritic rhyolite pantellerite',
#  'trachydacite',
#  'dacite',
#  'high k dacite',
#  'medium k dacite',
#  'low k dacite',
#  'andesite',
#  'high k andesite',
#  'medium k andesite',
#  'low k andesite',
#  'basaltic andesite',
#  'high k basaltic andesite',
#  'medium k basaltic andesite',
#  'low k basaltic andesite',
#  'sio saturated volcanic',
#  'trachyte',
#  'trachite',
#  'peralkalic trachyte',
#  'comenditic trachyte',
#  'pantellitic trachyte',
#  'trachyandesite',
#  'benmoreite',
#  'latite',
#  'basaltic trachyandesite',
#  'mugearite',
#  'shoshonite',
#  'trachybasalt',
#  'hawaiite',
#  'k trachybasalt',
#  'sio saturated or slightly undersaturated volcanic',
#  'basalt',
#  'subalkali basalt',
#  'tholeitic basalt',
#  'high alumina basalt',
#  'alkali basalt',
#  'alkali olivine basalt',
#  'sio undersaturated volcanic',
#  'phonolite',
#  'tephri phonolite',
#  'phono tephrite',
#  'tephrite',
#  'basanite',
#  'picrobasalt',
#  'foidite',
#  'nephelinite',
#  'high mg volcanics',
#  'boninite',
#  'picritic volcanic',
#  'picrite',
#  'comatiite',
#  'meimechite',
#  'volcaniclastic',
#  'volcaniclastics',
#  'rhyolitic volcaniclast',
#  'dacitic volcaniclast',
#  'trachytic volcaniclast',
#  'andesitic volcaniclast',
#  'basaltic volcaniclast',
#  'alkali basaltic volcaniclast',
#  'tholeitic volcaniclast',
#  'phonolitic volcaniclast',
#  'tephritic volcaniclast',
#  'basanitic volcaniclast',
#  'foiditic volcaniclast',
#  'pyroclastics',
#  'pyroclastic undefined',
#  'ash tuff',
#  'fine grained ash tuff',
#  'coarse grained ash tuff',
#  'crystal ash tuff',
#  'lapilli ash tuff',
#  'bomb ash tuff',
#  'block ash tuff',
#  'lapillistone',
#  'ash lapillistone',
#  'bomb lapillistone',
#  'block lapillistone',
#  'agglomerate',
#  'bomb tuff',
#  'lapilli bomb tuff',
#  'ash bomb tuff',
#  'agglutinate',
#  'pyroclastic breccia',
#  'block tuff',
#  'lapilli block tuff',
#  'ash block tuff',
#  'tuff breccia',
#  'lapilli tuff breccia',
#  'ash tuff breccia',
#  'air fall deposit consolidated',
#  'ash flow deposit consolidated',
#  'ignimbrite consolidated',
#  'ignimbrite welded',
#  'ignimbrite unwelded consolidated',
#  'surge deposit consolidated',
#  'peperite',
#  'pyroclastic rhyolitic',
#  'rhyolitic ash tuff',
#  'fine grained ash tuff rhyolitic',
#  'coarse grained ash tuff rhyolitic',
#  'rhyolitic crystal ash tuff',
#  'rhyolitic lapilli ash tuff',
#  'rhyolitic bomb ash tuff',
#  'rhyolitic block ash tuff',
#  'rhyolitic lapilli tuff',
#  'rhyolitic ash lapilli tuff',
#  'rhyolitic bomb lapilli tuff',
#  'rhyolitic block lapilli tuff',
#  'rhyolitic agglomerate',
#  'rhyolitic bomb tuff',
#  'rhyolitic lapilli bomb tuff',
#  'rhyolitic ash bomb tuff',
#  'rhyolitic agglutinate',
#  'pyroclastoc breccia rhyolitic',
#  'rhyolitic block tuff',
#  'rhyolitic lapilli block tuff',
#  'rhyolitic ash block tuff',
#  'rhyolitic tuff breccia',
#  'rhyolitic lapilli tuff breccia',
#  'rhyolitic ash tuff breccia',
#  'rhyolitic air fall deposit consolidated',
#  'rhyolitic ash flow deposit consolidated',
#  'rhyolitic ignimbrite consolidated',
#  'rhyolitic ignimbrite welded',
#  'rhyolitic ignimbrite unwelded consolidated',
#  'rhyolitic surge deposit',
#  'rhyolitic peperite',
#  'pyroclastic dacitic',
#  'dacitic ash tuff',
#  'fine grained ash tuff dacitic',
#  'coarse grained ash tuff dacitic',
#  'dacitic crystal ash tuff',
#  'dacitic lapilli ash tuff',
#  'dacitic bomb ash tuff',
#  'dacitic block ash tuff',
#  'dacitic lapilli tuff',
#  'dacitic ash lapilli tuff',
#  'dacitic bomb lapilli tuff',
#  'dacitic block lapilli tuff',
#  'dacitic agglomerate',
#  'dacitic bomb tuff',
#  'dacitic lapilli bomb tuff',
#  'dacitic ash bomb tuff',
#  'dacitic agglutinate',
#  'pyroclastic breccia dacitic',
#  'dacitic block tuff',
#  'dacitic lapilli block tuff',
#  'dacitic ash block tuff',
#  'dacitic tuff breccia',
#  'dacitic lapilli tuff breccia',
#  'dacitic ash tuff breccia',
#  'dacitic air fall deposit consolidated',
#  'dacitic ash flow deposit consolidated',
#  'dacitic ignimbrite consolidated',
#  'dacitic ignimbrite welded',
#  'dacitic ignimbrite unwelded consolidated',
#  'dacitic surge deposit consolidated',
#  'dacitic peperite',
#  'pyroclastic trachytic',
#  'trachytic ash tuff',
#  'fine grained trachytic ash tuff',
#  'coarse grained trachytic ash tuff',
#  'trachytic crystal ash tuff',
#  'trachytic lapilli ash tuff',
#  'trachytic bomb ash tuff',
#  'trachytic block ash tuff',
#  'trachytic lapilli tuff',
#  'trachytic ash lapilli tuff',
#  'trachytic bomb lapilli tuff',
#  'trachytic block lapilli tuff',
#  'trachytic agglomerate',
#  'trachytic bomb tuff',
#  'trachytic lapilli bomb tuff',
#  'trachytic ash bomb tuff',
#  'trachytic agglutinate',
#  'pyroclastic breccia trachytic',
#  'trachytic block tuff',
#  'trachytic lapilli block tuff',
#  'trachytic ash block tuff',
#  'trachytic tuff breccia',
#  'trachytic lapilli tuff breccia',
#  'trachytic ash tuff breccia',
#  'trachytic air fall deposit consolidated',
#  'trachytic ash flow deposit consolidated',
#  'trachytic ignimbrite consolidated',
#  'trachytic ignimbrite welded',
#  'trachytic ignimbrite unwelded consolidated',
#  'trachytic surge deposit consolidated',
#  'trachytic peperite',
#  'pyroclastic latitic',
#  'latitic ash tuff',
#  'fine grained latitic ash tuff',
#  'coarse  grained latitic ash tuff',
#  'latitic crystal ash tuff',
#  'latitic lapilli ash tuff',
#  'latitic bomb ash tuff',
#  'latitic block ash tuff',
#  'latitic lapilli tuff',
#  'latitic ash lapilli tuff',
#  'latitic bomb lapilli tuff',
#  'latitic block lapilli tuff',
#  'latitic agglomerate',
#  'latitic bomb tuff',
#  'latitic lapilli bomb tuff',
#  'latitic ash bomb tuff',
#  'latitic aggglutinate',
#  'pyroclastic breccia latitic',
#  'latitic block tuff',
#  'latitic lapilli block tuff',
#  'latitic ash block tuff',
#  'latitic tuff breccia',
#  'latitic lapilli tuff breccia',
#  'latitic ash tuff breccia',
#  'latitic air flow deposit consolidated',
#  'latitic ash flow deposit consolidated',
#  'latitic ignimbrite consolidated',
#  'latitic ignimbrite welded',
#  'latitic ignimbrite unwelded consolidated',
#  'latitic surge deposit consolidated',
#  'latitic peperite',
#  'pyroclastic andesitic',
#  'andesitic ash tuff',
#  'fine grained andesitic ash tuff',
#  'coarse grained andesitic ash tuff',
#  'andesitic crystal ash tuff',
#  'andesitic lapilli ash tuff',
#  'andesitic bomb ash tuff',
#  'andesitic block ash tuff',
#  'andesitic lapilli tuff',
#  'andesitic ash lapilli tuff',
#  'andesitic bomb lapilli tuff',
#  'andesitic block lapilli tuff',
#  'andesitic agglomerate',
#  'andesitic bomb tuff',
#  'andesitic lapilli bomb tuff',
#  'andesitic ash bomb tuff',
#  'andesitic agglutinate',
#  'pyroclastic breccia andesitic',
#  'andesitic block tuff',
#  'andesitic lapilli block tuff',
#  'andesitic ash block tuff',
#  'andesitic tuff breccia',
#  'andesitic lapilli tuff breccia',
#  'andesitic ash tuff breccia',
#  'andesitic air flow deposit consolidated',
#  'andesitic ash flow deposit consolidated',
#  'andesitic ignimbrite consolidated',
#  'andesitic ignimbrite welded',
#  'andesitic ignimbrite unwelded consolidated',
#  'andesitic surge deposit consolidated',
#  'andesitic peperite',
#  'pyroclastic basaltic',
#  'basaltic ash tuff',
#  'fine grained ash tuff basaltic',
#  'coarse grained ah tuff basaltic',
#  'basaltic crystal ash tuff',
#  'basaltic lapilli ash tuff',
#  'basaltic bomb ash tuff',
#  'basaltic block ash tuff',
#  'basaltic lapilli tuff',
#  'basaltic crystal lapilli tuff',
#  'basaltic ash lapilli tuff',
#  'basaltic bomb lapilli tuff',
#  'basaltic block lapilli tuff',
#  'basaltic agglomerate',
#  'basaltic bomb tuff',
#  'basaltic lapilli bomb tuff',
#  'basaltic ash bomb tuff',
#  'basaltic agglutinate',
#  'pyroclastic breccia consolidated',
#  'basaltic block tuff',
#  'basaltic lapilli block tuff',
#  'basaltic ash block tuff',
#  'basaltic tuff breccia',
#  'basaltic lapilli tuff breccia',
#  'basaltic ash tuff breccia',
#  'basaltic air fall deposit consolidated',
#  'basaltic ash flow deposit consolidated',
#  'basaltic ignimbrite consolidated',
#  'basaltic surge deposit consolidated',
#  'basaltic peperite',
#  'pyroclastic phonolitic',
#  'phonolitic ash tuff',
#  'fine grained ash tuff phonolitic',
#  'coarse grained ash tuff phonolitic',
#  'phonolitic crystal ash tuff',
#  'phonolitic lapilli ash tuff',
#  'phonolitic bomb ash tuff',
#  'phonolitic block ash tuff',
#  'phonolitic lapilli tuff',
#  'phonlitic ash lapilli tuff',
#  'phonolitic bomb lapilli tuff',
#  'phonolitic block lapilli tuff',
#  'phonolitic agglomerate',
#  'phonolitic bomb tuff',
#  'phonolitic lapilli block tuff',
#  'phonolitic ash block tuff',
#  'phonolitic agglutinate',
#  'pyroclastic breccia phonolitic',
#  'phonolitic block tuff',
#  'phonolitic tuff breccia',
#  'phonolitic lapilli tuff breccia',
#  'phonolitic ash tuff breccia',
#  'phonolitic air fall deposit consolidated',
#  'phonolitic ash flow deposit consolidated',
#  'phonolitic ignimbrite consolidated',
#  'phonolitic ignimbrite welded',
#  'phonolitic ignimbrite unwelded consolidated',
#  'phonolitic surge deposit consolidated',
#  'phonolitic peperite',
#  'pyroclastic basanitic',
#  'basanitic ash tuff',
#  'fine  grained ash tuff basanitic',
#  'coarse grained ash tuff basanitic',
#  'basanitic crystall ash tuff',
#  'basanitic lapilli ash tuff',
#  'basanitic bomb ash tuff',
#  'basanitic block ash tuff',
#  'basanitic lapilli tuff',
#  'basanitic ash lapilli tuff',
#  'basanitic bomb lapilli tuff',
#  'basanitic block lapilli tuff',
#  'basanitic agglomerate',
#  'basanitic bomb tuff',
#  'basanitic lapilli bomb tuff',
#  'basanitic ash bomb tuff',
#  'basanitic agglutinate',
#  'pyroclastic breccia basanitic',
#  'basanitic block tuff',
#  'basanitic lapilli block tuff',
#  'basanitic ash block tuff',
#  'basanitic tuff breccia',
#  'basanitic lapilli tuff breccia',
#  'basanitic ash tuff breccia',
#  'basanitic air fall deposit consolidated',
#  'basanitic ash flow deposit consolidated',
#  'basanitic ignimbrite consolidated',
#  'basanitic ignimbrite unwelded consolidated',
#  'basanitic surhe deposit consolidated',
#  'basanitic peperite',
#  'autoclastic volcaniclast',
#  'top breccia',
#  'bottom breccia',
#  'tuffite',
#  'tuffaceous claystone',
#  'tuffaceous siltstone',
#  'tuffaceous sandstone',
#  'tuffaceous conglomerate',
#  'tuffaceous breccia',
#  'volcaniclastic sedimentary',
#  'volcaniclastic claystone',
#  'volcaniclastic siltstone',
#  'volcaniclastic sandstone',
#  'volcaniclastic conglomerate',
#  'volcaniclastic breccia',
#  'lahar consolidated',
#  'volcanic and volcaniclastic structureless',
#  'dyke',
#  'dyke',
#  'quartz rich dyke',
#  'quartz bearing to foid bearing dyke',
#  'foid rich dyke',
#  'dolerite',
#  'lamprophyr',
#  'dyke',
#  'pegmatite granitoidic composition',
#  'quartz rich aplite',
#  'granite aplite',
#  'granodiorite aplite',
#  'tonalite aplite',
#  'dykes´ granite',
#  'dykes´ granodiorite',
#  'dykes´ tonalite',
#  'microgranite',
#  'microgranodiorite',
#  'microtonalite',
#  'granophyr',
#  'porphyritic granite',
#  'porphyritic granodiorite',
#  'porphyritic tonalite',
#  'pegmatite of nephelinitic composition',
#  'quartz bearing to quartz free aplite',
#  'syenite aplite',
#  'monzonite aplite',
#  'monzodiorite aplite',
#  'diorite aplite',
#  'gabbro aplite',
#  'dykes´ syenite',
#  'dykes´ monzonite',
#  'dykes´ monzodiorite',
#  'dykes´ diorite',
#  'dykes´ gabbro',
#  'microsyenite',
#  'micromonzonite',
#  'micromonzodiorite',
#  'microdiorite',
#  'microgabbro',
#  'porphyric syenite',
#  'porphyric monzonite',
#  'porphyric monzodiorite',
#  'porphyric diorite',
#  'porphyric gabbro',
#  'dolerite diabase',
#  'alkalibasaltic dolerite',
#  'leucite nepheline dolerite',
#  'theoleitic dolerite',
#  'fioditic dyke',
#  'lamprophyre',
#  'minette',
#  'kersanite',
#  'vogesite',
#  'spessartite',
#  'alkali lamprophyre',
#  'camptonite',
#  'sannaite',
#  'monchiquite',
#  'fourchite',
#  'ultrabasic alkali lamprophyr',
#  'quachitite',
#  'melilitic lamprophyr',
#  'alnoite',
#  'polzenite',
#  'lamprophyric carbonatic dyke',
#  'kimberlite',
#  'carbonatic kimberlite',
#  'hydrothermal gangue mineralization',
#  'quartz rich gangue mineralization',
#  'milky quartz mineral aggregate',
#  'capped quartz mineral aggregate',
#  'pseudomorphosic quartz mineral aggregate',
#  'carbonate rich gangue mineralization',
#  'calcite mineral aggregate',
#  'feldspar rich gangue mineralization',
#  'feldspar mineral aggregate',
#  'baryte rich gangue mineralization',
#  'baryte mineral aggregate',
#  'sulfide rich gangue mineralization',
#  'metamorphic',
#  'metamorphic after educt',
#  'meta sedimentary',
#  'meta pelite',
#  'hornfels',
#  'buchite',
#  'silicic',
#  'silicic schist',
#  'meta psammite',
#  'meta arkose',
#  'meta graywacke',
#  'meta psephite',
#  'meta conglomerate',
#  'meta igneous',
#  'meta plutonite',
#  'meta granite',
#  'meta granodiorite',
#  'meta diorite',
#  'meta gabbro',
#  'metamorphic dyke',
#  'meta aplite',
#  'garnet meta aplite',
#  'garnet turmaline meta aplite',
#  'meta pegmatite',
#  'meta dolerite',
#  'alkalibasaltic meta dolerite',
#  'tholeitic meta dolerite',
#  'meta volcanic',
#  'meta rhyolite',
#  'peralkaline meta rhyolite',
#  'meta rhyodacite',
#  'meta dacite',
#  'meta trachyte',
#  'meta basalt',
#  'meta basalt sorted',
#  'meta alkali basalt',
#  'tholeitic meta basalt',
#  'meta andesite',
#  'meta phonolite',
#  'meta basanite',
#  'meta pikrite',
#  'meta volcaniclastic',
#  'rhyolitic meta volcaniclastic',
#  'rhyodacitic meta volcaniclastic',
#  'dacitic meta volcaniclastic',
#  'trachytic meta volcaniclastic',
#  'andesitic meta volcaniclastic',
#  'basaltic meta volcaniclastic',
#  'alkali basaltic meta volcaniclastic',
#  'tholeitic meta volcaniclastic',
#  'phonolitic meta volcaniclastic',
#  'basanitic meta volcaniclastic',
#  'meta pyroclastic',
#  'rhyolitic meta pyroclastic',
#  'rhyodacitic meta pyroclastic',
#  'dacitic meta pyroclastic',
#  'trachytic meta pyroclastic',
#  'andesitic meta pyroclastic',
#  'basaltic meta pyroclastic',
#  'alkali basaltic meta pyroclastic',
#  'basanitic meta pyroclastic',
#  'meta tuffite',
#  'tuffitic meta pelite',
#  'tuffitic meta psammite',
#  'tuffitic meta conglomerate',
#  'autoclastic meta volcaniclastic',
#  'autoclastic hydroclastic meta volcaniclastic',
#  'pillow breccia',
#  'pillow fragment breccia',
#  'hydroclastic',
#  'volcaniclastic meta sedimentary',
#  'metamorphic after chemistry fabric mineral content',
#  'metacarbonate',
#  'marble',
#  'marble sorted',
#  'calcite marble',
#  'dolomite marble',
#  'carbonate silicate marble silica marble',
#  'metamorphic carbonate silicate',
#  'carbonate phyllite',
#  'carbonate silicate coarse',
#  'quartz rich metamorphic',
#  'quartzite',
#  'apatite quartzite',
#  'epidote quartzite',
#  'garnet quartzite',
#  'graphite quartzite',
#  'magnetite quartzite',
#  'muscovite quartzite',
#  'serictite quartzite',
#  'metafelsics',
#  'phyllite',
#  'albite phyllite',
#  'chloritoide phyllite',
#  'garnet albite phyllite',
#  'garnet phyllite',
#  'quartz phyllite',
#  'sericite phyllite',
#  'mica schist',
#  'albite mica schist',
#  'andalusite mica schist',
#  'apatite mica schist',
#  'biotite plagioclase mica schist',
#  'chlorite mica schist',
#  'garnet mica schist',
#  'graphite mica schist',
#  'muscovite chlorite mica schist',
#  'muscovite biotite mica schist two mica schist',
#  'sericite mica schist',
#  'staurolite biotite muscovite mica schist',
#  'gneiss',
#  'epidote hornblende plagioclase gneiss',
#  'albite gneiss',
#  'andalusite gneiss',
#  'biotite gneiss',
#  'biotite cordierit gneiss',
#  'biotite garnet gneiss',
#  'biotite plagioclase gneiss',
#  'biotite muscovite gneiss',
#  'biotite sillimanite gneiss',
#  'cordierit gneiss',
#  'disthene gneiss',
#  'disthene staurolite gneiss',
#  'disthene sillimanite gneiss',
#  'mica gneiss',
#  'garnet gneiss',
#  'garnet biotite gneiss',
#  'garnet cordierit sillimanite gneiss',
#  'garnet disthene gneiss',
#  'garnet disthene sillimanite gneiss',
#  'garnet disthene staurolite gneiss',
#  'garnet plagioclase gneis',
#  'graphite gneiss',
#  'hornblende biotite gneiss',
#  'muscovite gneiss',
#  'muscovite biotite gneiss',
#  'muscovite biotite garnet gneiss',
#  'muscovite garnet gneiss',
#  'pyroxene gneiss',
#  'quartz biotite plagioclase gneiss',
#  'staurolite garnet plagioclase gneiss',
#  'metafelsic granulite',
#  'granulite',
#  'granulite gneiss',
#  'charnockite metamorphic affinity',
#  'acidic to intermediate hornfels',
#  'andalusite hornfels',
#  'biotite hornblende plagioclase hornfels',
#  'cordierite hornels',
#  'coround hercynite hornfels',
#  'metamafics',
#  'greenschist',
#  'actinolite schist',
#  'prasinite',
#  'amphibolite',
#  'biotite amphibolite',
#  'biotite pyroxene amphibolite',
#  'diopside amphibolite',
#  'epidote amphibolite',
#  'garnet amphibolite',
#  'carbonate silicate amphibolite',
#  'zoisite amphibolite',
#  'eklogite amphibolite',
#  'metamafic granulite',
#  'eclogite',
#  'metamafic hornfels',
#  'meta ultramafic',
#  'chlorite actinolite schist',
#  'talcum schist',
#  'serpentinite',
#  'ultra mafic hornfels',
#  'olivine fels',
#  'tectonite',
#  'cataclast',
#  'fault breccia',
#  'melange',
#  'schist',
#  'slate slaty metamudstone',
#  'black shale',
#  'alum shale',
#  'ribbon slate',
#  'silty schist',
#  'mylonite',
#  'migmatite',
#  'anatexite',
#  'metatexite',
#  'diatexite',
#  'syntexite',
#  'sedimentary',
#  'siliciclastic sedimentary',
#  'sandstone pelite alternation',
#  'sandstone dominated sandstone pelite alternation',
#  'pelite dominated sandstone pelite alternation',
#  'pelite gypsum alternation',
#  'pelite dominated pelite gypsum alternation',
#  'gypsum dominated pelite gypsum alternation',
#  'pelite',
#  'silicate claystone',
#  'silicate siltstone',
#  'sapropelite',
#  'psammitearenite',
#  'arenite sandstone',
#  'fine sandstone',
#  'medium sandstone',
#  'coarse sandstone',
#  'quartz arenite',
#  'fine quartz arenite',
#  'medium quartz arenite',
#  'coarse quartz arenite',
#  'subfeldspatic arenite  feldspatic sandstone',
#  'fine subfeldspatic arenite',
#  'medium subfeldspatic arenite',
#  'coarse subfeldspatic arenite',
#  'feldspatic arenite',
#  'fine feldspatic arenite',
#  'medium feldspatic arenite',
#  'coarse feldspatic arenite',
#  'arkose',
#  'fine arkose',
#  'medium arkose',
#  'coarse arkose',
#  'sublitharenite',
#  'fine sublitharenite',
#  'medium sublitharenite',
#  'coarse sublitharenite',
#  'litharenite',
#  'fine litharenite',
#  'medium litharenite',
#  'coarse litharenite',
#  'lithic arenite',
#  'fine lithic arenite',
#  'medium lithic arenite',
#  'coarse lithic arenite',
#  'graywacke wacke',
#  'fine graywacke',
#  'medium graywacke',
#  'coarse graywacke',
#  'quartz wacke',
#  'fine quartz wacke',
#  'medium quartz wacke',
#  'coarse quartz wacke',
#  'feldspathic wacke',
#  'fine feldspethic wacke',
#  'medium feldspethic wacke',
#  'coarse feldspethic wacke',
#  'lithic wacke',
#  'fine lithic wacke',
#  'medium lithic wacke',
#  'coarse lithic wacke',
#  'psephite',
#  'conglomerate',
#  'pebbly conglomerate',
#  'fine pebble granule',
#  'medium to coarse pebble',
#  'very coarse pebble',
#  'cobbles',
#  'boulders',
#  'breccia',
#  'grus breccia',
#  'fine grus breccia',
#  'medium grus breccia',
#  'coarse grud breccia',
#  'debris breccia',
#  'block debris breccia',
#  'carbonatic sedimentary',
#  'carbonatic siliciclastic sedimentary',
#  'limestone marl alteration',
#  'limestone dominated limestone marl alteration',
#  'marl dominated limestone marl alteration',
#  'pelite marl alteration',
#  'pelite dominated pelite marl alteration',
#  'marol dominated pelite marl alteration',
#  'carbonate bearing siliciclastic',
#  'carbonate bearing claystone',
#  'carbonate bearing mudstone',
#  'carbonate bearing sandstone',
#  'carbonate bearing fine sandstone',
#  'carbonate bearing medium sandstone',
#  'carbonate bearing coarse sandstone',
#  'carbonate bearing conglomerate',
#  'carbonate bearing breccia',
#  'dolomite bearing siliciclastic',
#  'dolomite bearing claystone',
#  'dolomite bearing mudstone',
#  'dolomite bearing sandstone',
#  'dolomite bearing fine sandstone',
#  'dolomite bearing medium sandstone',
#  'dolomite bearing coarse sandstone',
#  'dolomite bearing conglomerate',
#  'dolomite bearing breccia',
#  'carbonatic siliciclastic',
#  'carbonatic claystone',
#  'carbonatic mudstone',
#  'carbonatic sandstone',
#  'carbonatic fine sandstone',
#  'carbonatic medium sandstone',
#  'carbonatic coarse sandstone',
#  'carbonatic conglomerate',
#  'carbonatic breccia',
#  'dolomitic siliciclastic',
#  'dolomitic claystone',
#  'dolomitic mudstone',
#  'dolomitic sandstone',
#  'dolomitic fine sandstone',
#  'dolomitic medium sandstone',
#  'dolomitic coarse sandstone',
#  'dolomitic conglomerate',
#  'dolomitic breccia',
#  'siliciclastic limestone',
#  'clayey limestone',
#  'muddy limestone',
#  'sandy limestone',
#  'fine sandy limestone',
#  'medium sandy limestone',
#  'coarse sandy limestone',
#  'conglomeratic limestone',
#  'brecciatic limestone',
#  'siliciclastic dolimite',
#  'clayey dolomite',
#  'muddy dolomite',
#  'sandy dolomite',
#  'fine sandy dolomite',
#  'medium sandy dolomite',
#  'coarse sandy dolomite',
#  'conglomeratic dolomite',
#  'brecciatic dolomite',
#  'clay lime composite',
#  'marly claystone',
#  'marl claystone',
#  'clay marl',
#  'marl',
#  'lime marl',
#  'dolomite marl',
#  'marl limestone',
#  'marl dolomite',
#  'marly limestone',
#  'marly dolomite',
#  'carbonate',
#  'clastic sedimentary carbonate',
#  'lutite',
#  'siltite',
#  'arenite',
#  'fine grained arenite',
#  'medium grained arenite',
#  'coarse grained arenite',
#  'ooidlothic',
#  'oncolithic',
#  'rudite',
#  'dolomite',
#  'dolomitic lutite',
#  'dolomitic siltite',
#  'dolomitic arenite',
#  'fine grained dolomitic arenite',
#  'medium grained dolomitic arenite',
#  'coarse grained dolomitic arenite',
#  'dolomitic rudite',
#  'limestone',
#  'calcitic lutite',
#  'calcitic siltite',
#  'calcitic arenite',
#  'fine grained calcitic arenite',
#  'medium grained calcitic arenite',
#  'coarse grained calcitic arenite',
#  'calcitic rudite',
#  'carbonate of dunham  and embry & klovan',
#  'allothonous limestone',
#  'mud supported limestone',
#  'mudstone',
#  'wackstone',
#  ...]

# %%
with open('list_entities\list_petrography.txt','w') as f:
    for i in lis_petro:
        f.write(str(i) + '\n')
    f.close()

# %%
lis_meth = []

# %%
with open ('list_entities\list_methods.txt','r') as f:
    for i in f.readlines():
        lis_meth.append(re.sub(r'\n','',i))

# %%
tes = r"(\.*\b(?:{}))\b".format("|".join(lis_meth))

re.findall(tes, 'thermal conductivity')
# Out:
# ['thermal conductivity']

# %%
re.findall(r'\s','ryan bobby andika')
# Out:
# [' ', ' ']

# %% [markdown]
# # Ordering Entities

# %%
path='C:/Users/Ryan Bobby A/Documents/RWTH AACHEN/KULIAH/THESIS_BISMILLAH/Thesis Progress/list_entities/'
for filename in glob.glob(os.path.join(path, '*.txt')):
    gist_file = open(filename, "r")
    space_2 = []
    space_1 = []
    space_0 = []
    
    try:
        content = list(filter(None, gist_file.read().lower().split("\n")))
        for i in content:
            s = re.findall(r"\s",i)
            if len(s)>1:
                space_2.append(i)
            elif len(s)==1:
                space_1.append(i)
            else:
                space_0.append(i) 
        content_com = space_2 + space_1 + space_0
    
    finally:
        gist_file.close()
        
    with open(filename, 'w') as f:
        for i in content_com:
            f.write(str(i) + '\n')

# %%
lis_met_com
# Out:
# ['specific heat capacity',
#  'bulk thermal conductivity',
#  'matrix thermal conductivity',
#  'specific heat capacity',
#  'volumetric heat capacity',
#  'radiogenic heat production',
#  'uniaxial compressive strength',
#  'quality indice geographic uncertatiny',
#  'qualitiy indice petrography',
#  'quality indice stratigraphy',
#  'qualitiy indice measurement conditions',
#  'quality indice measurement parameter',
#  'value quality index',
#  'class quality index',
#  'standard deviation',
#  'thermal conductivity',
#  'youngs modulus',
#  'sampling point',
#  'grain density',
#  'bulk density',
#  'total porosity',
#  'effective porosity',
#  'apparent permeability',
#  'intrinsic permeability',
#  'thermal diffusivity',
#  'p-wave velocity',
#  's-wave velocity',
#  'youngs modulus',
#  'shear modulus',
#  'bulk modulus',
#  'lamé modulus',
#  'lame modulus',
#  'friction coefficient',
#  'triaxial experiments',
#  'poisson ratio',
#  'tensile strength',
#  'electrical conductivity',
#  'magnetic susceptibility',
#  'longitude',
#  'decimaldegree.minutes',
#  'latitude',
#  'elevation',
#  'a.s.l.',
#  'radius',
#  'uncertainty',
#  'km',
#  'igsn',
#  'length',
#  'height',
#  'width',
#  'diameter',
#  'decimaldegrees.minutes',
#  'depth',
#  'md',
#  'tvd',
#  'petrography',
#  'stratigraphy',
#  'temperature',
#  'pressure',
#  'pa',
#  'saturating',
#  'saturation',
#  'sigma1',
#  'mpa',
#  'sigma2',
#  'sigma3',
#  'pore',
#  'strain',
#  'rate',
#  'kn/s',
#  'mpa/s',
#  'mm/s',
#  '1/s',
#  'value',
#  'grain',
#  'density',
#  'kg/m³',
#  'min',
#  'max',
#  'porosity',
#  'permeability',
#  'm²',
#  'thermal',
#  'conductivity',
#  'w/m·k',
#  'inhomogenity',
#  'heat',
#  'capacity',
#  'j/kg·k',
#  'volumetric',
#  'j/m³·k',
#  'diffusivity',
#  'm²/s',
#  'radiogenic',
#  'w/m³',
#  'p-wave',
#  'velocity',
#  'm/s',
#  'frequency',
#  'khz',
#  's-wave',
#  'dyn',
#  'modulus',
#  'gpa',
#  'stat',
#  'shear',
#  'lame',
#  'cohesion',
#  'friction',
#  'coefficient',
#  'confining',
#  'porefluid',
#  'differential',
#  'stress',
#  'mean',
#  'compactive',
#  'yield',
#  'critical',
#  'onset',
#  'inelastic',
#  'hydrostatic',
#  'compaction',
#  'shear-enhanced',
#  'enhanced',
#  'poisson',
#  'ratio',
#  'dynamic',
#  'static',
#  'ucs',
#  'tensile',
#  'strength',
#  's/m',
#  'formation',
#  'resistivity',
#  'chronostratigraphy',
#  'petrography',
#  'stratigraphy',
#  'cohesion']
