# %%
#PDF Miner (PDF Scraping)
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.layout import LAParams
from pdfminer.converter import HTMLConverter, TextConverter, XMLConverter
from io import StringIO
from pdfminer.pdfpage import PDFPage


#PyPDF2 (PDF Scraping)
import PyPDF2 as pypdf


## Grobid(PDF-Scraping)
# import grobid_client
# from grobid_client.grobid_client.grobid_client import GrobidClient
# client = GrobidClient(config_path="C:/Users/Ryan Bobby A/Documents/GitHub/grobid_client_python/config.json")


#NLP Preprocessing
import nltk
import re
import regex
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer


#NLP Processing TensorFLow
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

#NLP Processing Spacy
import spacy
spc = spacy.load("en_core_web_lg")
# spc.add_pipe('sentencizer')

#Model Training and Evaluation
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

#Basic
import numpy as np
import pandas as pd
import pickle
import glob
import os
import docker

# %% [markdown]
# # PyPDF2

# %%
pdf_path = 'C:/Users/Ryan Bobby A/Documents/RWTH AACHEN/KULIAH/THESIS_BISMILLAH/Thesis Progress/PDF Data/Brehme2016_Article_PermeabilityDistributionInTheL.pdf'

# %%
text_pypdf = []
with open(pdf_path,'rb') as pdffile:
    reader = pypdf.PdfFileReader(pdffile)
    for i in range(len(reader.pages)):
        page = reader.pages[i]
        text_pypdf.append(page.extract_text())
# Out:
# C:\Users\Ryan Bobby A\anaconda3\lib\site-packages\PyPDF2\_reader.py:1358: PdfReadWarning: Xref table not zero-indexed. ID numbers for objects will be corrected.
#   warnings.warn(

# %%
text_pypdf
# Out:
# ['ORIGINAL ARTICLE\n\nPermeability distribution in the Lahendong geothermal ﬁeld:\n\nA blind fault captured by thermal–hydraulic simulation\nMaren Brehme1\n•\nGuido Blo\n¨\ncher1\n•\nMauro Cacace1\n•\nYustin Kamah2\n•\n\nMartin Sauter3\n•\nGu\n¨\nnter Zimmermann1\n\nReceived: 24 November 2015 / Accepted: 4 July 2016 / Published online: 19 July 2016\n\n\n/C211\n\nSpringer-Verlag Berlin Heidelberg 2016\n\nAbstract\nSubsurface ﬂuid ﬂow of reservoirs in active\n\ntectonic regions is mainly controlled by permeability of\n\nfault zones. Therefore, the characterization of fault zones is\nan important step toward performance assessment of a\n\nreservoir. The ﬂuid ﬂow is controlled also by pressure and\n\ntemperature conditions. In this context, we simulated\npressure and temperature ﬁelds to elaborate on the inﬂu-\n\nence of permeability on subsurface ﬂuid ﬂow in the\n\nLahendong geothermal reservoir. Thermal–hydraulic sim-\nulation is performed using a ﬁnite element approach.\n\nAdjusting the permeability through 370 different cases,\n\nmodeling results converged to the observed data within a\nmisﬁt range of 0–7 %. The best ﬁtting models identiﬁed a\n\ndeep-seated fault that has previously not been traced at the\n\nsurface. Simulated temperature distribution suggests a\nprominent convective heat ﬂow, driven by an upward\n\nmigrating and SW–NE oriented ﬂuid ﬂow. This hydraulic\n\ngradient causes a pressure drop along the reservoir. High-\npressure patterns are used to constrain recharge areas, in\n\naddition to inﬁltration measurements. Discharge ﬂow\n\noccurs from SW to NE migrating also upward toward the\n\nhot springs. In that frame, thermal–hydraulic simulations\n\nidentiﬁed previously unresolved subsurface faults, which\nnow allow a better understanding of the subsurface per-\n\nmeability and its inﬂuence on ﬂuid ﬂow.\n\n\nKeywords\n\nPermeable faults\n/C1\nHydrogeology\n/C1\nFluid ﬂow\n/C1\n\n\nGeothermal ﬁeld management\n\n/C1\nReservoir engineering\n/C1\n\n\nPressure drop\n\nIntroduction\n\nGeothermal energy is an essential component to supply\nfuture energy demands. It requires developing new\n\ngeothermal sites and improving the performance of exist-\ning systems to satisfy continuously growing demand. The\n\nproductivity of a geothermal ﬁeld mainly depends on\n\nsubsurface ﬂuid ﬂow, which in active tectonic regions is\ncontrolled by permeability of fault zones (Moeck\n2014). In\n\nthat frame, the primary focus is on locating and charac-\n\nterizing faulted areas in geothermal ﬁelds. This study\nemploys numerical modeling to allocate and quantify\n\npermeability anisotropies and discontinuities, e.g., faults, in\n\norder to understand their inﬂuence on subsurface ﬂuid ﬂow\nin geothermal reservoirs.\n\nNumerical models have been increasingly used to\n\nunderstand the setup and productivity of geothermal sys-\n\ntems. A general overview of geothermal models has been\n\ngiven by O’Sullivan et al. (\n2001). Additionally, there are\n\nseveral sites exemplifying similar characteristics as in\n\nLahendong. The underground movement of hot and cold\n\nﬂuids has been modeled for geothermal ﬁelds in New\nZealand (Kaya et al.\n2014). The Kakkonda geothermal site,\n\ne.g., consists of two reservoirs at various depths with dif-\n\nferent ﬂuid properties. There, results from ﬂuid ﬂow\nanalysis show the importance of fractures for ﬂuid transport\n\nenhancing the recharge or discharge in the reservoir\n&\n\nMaren Brehme\n\nbrehme@gfz-potsdam.de\n1Helmholtz Centre Potsdam – GFZ German Research Centre\n\nfor Geosciences, Telegrafenberg, 14473 Potsdam, Germany\n2Upstream Technology Center Pertamina, Jl. Medan Merdeka\nTimur no. 6, Jakarta, Indonesia\n3Applied Geology, University of Go\n¨\nttingen,\n\nGoldschmidtstraße. 3, 37077 Go\n¨\nttingen, Germany\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n123\nEnviron Earth Sci (2016) 75:1088\n\nDOI 10.1007/s12665-016-5878-9',
#  '(McGuinness et al.1995). Generally, faults acting aspreferential ﬂuid path ways signiﬁcantly change the pres-sure and temperature ﬁeld in the reservoir (Cherubini et al.2013). Models for the Seferihisar–Balc¸ova ﬁeld focus onthe ﬂuid ﬂow inside of faults. Results show an enhancedupward heat transport through ﬂuids from bottom of thegeothermal system (Magri et al.2011).Our test ground is the Lahendong geothermal ﬁeldlocated in Sulawesi, Indonesia. The ﬁeld is owned andoperated by P.T. Pertamina Geothermal Energy and hosts apower plant with a production capacity of 80 MWe. There,geothermal exploration started in the early 1970s includinggeophysical and geohydrochemical approaches. It is awater-dominated magmatic structurally controlled system.Faults generally act as across-fault ﬂuid barriers and along-fault ﬂuid conductors (Brehme et al.2014). As a result, hotsprings mainly appear on the top of vertically permeablefaults at the surface. Available numerous drilling and sur-face measurements allowed a detailed characterization ofthe geological and hydrogeological setting of the area(Fig.1; Brehme et al.2011,2013,2014,2016; Wiegandet al.2013). The model presented here is developed forinvestigating subsurface ﬂuid ﬂow and the permeabilitydistribution including the fault zones in the Lahendonggeothermal ﬁeld. Below, the geological structure of theﬁeld is presented followed by an introduction to the mod-eling approach.Detailed investigation of subsurface permeability dis-tribution is a crucial step for site selection and smart dril-ling strategies. The numerical simulations presented willprovide insight into understanding the subsurface ﬂuid ﬂowconsidering the hydraulic conductivity of faults. It ensuresproductive as well as sustainable operation of geothermalﬁelds avoiding risks, such as drilling into non-fractured orcold zones, and targeting highly corroding waters.Although the target area is Lahendong, the general work-ﬂow is applicable for other geothermal sites consisting ofsimilar constraints.\nReservoir characterization\nHydrogeologyThe overall driving force for the ﬂuid ﬂow is the SW–NEoriented natural hydraulic gradient in the Lahendonggeothermal system. The direction of ﬂuid ﬂow variesthrough the geothermal site due to horizontal partitioningof the reservoir by relatively less permeable fault zones(Brehme et al.2014). The basic sections are located in the\n\n\nFig. 1Topographic map of the study area with geological features, water and rock sample locations, and model cross section\n1088Page 2 of 11Environ Earth Sci (2016) 75:1088\n123',
#  'south, in the east, and beneath Lake Linau. Beneath LakeLinau, the direction of ﬂuid ﬂow is slightly rotated toWSW–ENE (Fig.1). Also, types of ﬂuid change from onesection to another, e.g., an acidic highly saline-typebeneath Lake Linau and a neutral low saline-type south andeast of Lake Linau (Fig.1). The impermeable structureacross faults prevent the ﬂuids from diluting each other(Brehme et al.2016). However, faults are rather permeablealong the vertical axis, which allows recharge of the systemthrough the faults. Rainwater inﬁltrates at a fault in the SW,at Mt. Lengkoan, and creek water inﬁltrates into the normalfaults at Lake Linau (Fig.2). The hydrothermal systemdischarges into Lake Linau and toward the NE, as drivenby the hydraulic gradient (Brehme et al.2014).The fracture network along the area is characterized bystrike slip faults and normal faults. The sinistral faultsstrike N 40/C176and steeply dip toward the SE. Left step overon the strike slip faults forms an extension basin in thecentral study area. Normal faults at the extension basinstrike NW and dip 70/C176–80/C176beneath Lake Linau (Brehmeet al.2014).LithologyLahendong area is mainly characterized by Pre-, Post- andTondano formation of Plio- to Pleistocene age (Koestonoet al.2010). The rocks are typically andesite, volcanicbreccia, and tuff. Those types have been sampled fromborehole cores and used to determine porosity, permeabil-ity, and thermal conductivity. Effective porosity and matrixpermeability have been analyzed using a cylindrical-shapedspecimen with a dimension of 5 cm x 5 cm92.5 cm ori-ented parallel to the coring (Brehme et al.2016). Thermalconductivity has been measured on plain sections of driedcores. The experimental setup consists of a gas perme-ameter for determining matrix permeability (Milsch et al.2011), of an helium pycnometry for effective porositymeasurements (Johnson-Maynard et al.1994) and of anoptical scanner for thermal conductivity measurements(Popov et al.1999). These parameters have been measuredand averaged for the three rock types (Brehme et al.2016;Table1). Andesite has an effective porosity of 3.7 %, apermeability of 2.1910\n-14m2, and a thermal conductiv-ity of 1.8 W m\n-1K-1(dry) or 2.2 W m-1K-1(saturated).Tuff has a porosity of 7.7 % but the lowest permeability of2.0910\n-15m2and a thermal conductivity of1.6 W m\n-1K-1(dry) or 2.1 W m-1K-1(saturated).Volcanic breccia is a permeable layer with an effectiveporosity of 10.5 %, a permeability of 2.3910\n-14m2, anda thermal conductivity of 1.6 W m\n-1K-1(dry) or2.5 W m\n-1K-1(saturated). Reservoir rocks reﬂect gener-ally low matrix permeability suggesting fracture-controlledﬂuid ﬂow throughout the aquifer (Brehme et al.2016).\nModel setup\nModel geometryNumerical models developed for the study area representthe initial conditions of the reservoir before production orinjection start. For simulation, the commercial ﬁnite\n\n\nFig. 2Cross section of the modeled area with geological structure, boundary conditions, and location of observation pointsEnviron Earth Sci (2016) 75:1088Page 3 of 111088\n123',
#  'element software FEFLOW is used to model pressure-driven and thermally induced ﬂuid ﬂow including viscositychanges. Governing equations for ﬂuid ﬂow and heattransport in saturated porous media are derived from con-servation principles of linear momentum, mass, and energy(DHI-Wasy2009). Details on the software and theparameterization can be found in Diersch (2014).The model geometry is a 2D vertical SW–NE trendingcross section extending 6 km in horizontal and 3 km invertical direction. The direction of the proﬁle has beenselected to cover all relevant processes in the Lahendonggeothermal ﬁeld: It cuts major faults and the productionand injection wells, which are used for temperature andpressure calibration. Furthermore, it is parallel to thegroundwater ﬂow direction, showing major ﬂuid ﬂowactivities. The homogeneous and isotropic geological lay-ers in the model are stratiﬁed nearly horizontally. Faults inthe middle of the model, striking perpendicular to the crosssection, dip with 84/C176toward a cooling pluton beneath LakeLinau. Details on structural and geological components ofthe modeled region have been presented in Brehme et al.(2014).The mesh used for the numerical simulation inFEFLOW consists of 45,264 nodes and 89,320 elementsthat are denser surrounding the faults because of expectedgradients due to parameter contrasts. Material properties ofelements are permeability, porosity, and thermal conduc-tivity and set according to laboratory measurements(Table1). However, properties of the faults and LakeLinau are slightly adapted to speciﬁc conditions. The def-initions for the modeled grids along the faults are as fol-lows: porosity is 30 % and thermal conductivity is1.8 W m\n-1K-1. Corresponding grids for Lake Linau aredeﬁned by a porosity of 100 % and a thermal conductivityof 0.6 W m\n-1K-1. The model simulates ﬂuid ﬂow andthermal transport in saturated media in steady state.Initial values and boundary conditionsFluid ﬂow boundary conditions in the model describegroundwater heads and recharge amounts (Table2; Fig.2).The hydraulic head at the SW model boundary is 837 mand 500 m at the NE boundary. The SW hydraulic headrepresents inﬁltration of surface water into a fault, strikingperpendicular to the model. Hydraulic head at the NEborder is adapted to borehole measurements in that area(Brehme et al.2014). Inﬁltration into the fault zones atLake Linau is described by ﬂuid ﬂux boundary conditions.The quantity is 3.0910\n-4ms-1for the SW and1.3910\n-6ms-1at the NE fault distributed over 40 mfault width. Groundwater recharge is set to 412 mm a\n-1atthe NE top surface (Table2; Fig.2). Fluid movement in\nTable 1Thermal and hydraulic parameters of the Lahendong reservoir rocks measured in laboratory (Brehme et al.2016)Sample (name, depth) Rock type Effectiveporosity (%)Thermal conductivitydry (W m\n-1K-1)Thermal conductivitysaturated (W m-1K-1)Matrix permeability(m2)LHD1 500–501 A 1.1 (LHD1 550) 2.0 (LHD1 550) 2.2LHD1 801–802 B 14.5 1.6 2.4 1.5910\n-14\nLHD1 1000–1001 T 5.0 1.8 2.2 8.9910-16\nLHD1 2100–2101 T 7.2 1.4 2.0 3.3910-15\nLHD2 300–302 A 12.5 6.1910-14\nLHD3 2201–2203 B 5.7 2.1 2.4 1.5910-14\nLHD4 652–653 B 6.3 1.3910-14\nLHD4 850–852 A 1.6 1.8 2.0 2.3910-14\nLHD4 1001–1002 B 16.4 1.4 2.7 6.8910-14\nLHD4 2304–2305 A 1.6 1.8 2.7 3.4910-16\nLHD5 602–603 B 16.3 1.4 2.3 1.1910-14\nLHD5 752–753 A 2.7 1.1910-16\nLHD5 1102–1103 A 5.2 7.9910-14\nLHD5 1404–1406 A 3.6 1.9 2.3 3.0910-15\nLHD5 1575–1576 A 0.6 7.9910-18\nLHD7 901–902,3 A 4.6 1.5 1.7 7.2910-16\nLHD7 1567.8–1568 T 11.0 1.6 2.2 1.7910-15\nLHD7 1756–1758 B 3.9 2.1 2.7 1.7910-14\nAverage values Andesite (A) 3.7 1.8 2.2 2.1910-14\nBreccia (B) 10.5 1.6 2.5 2.3910-14\nTuff (T) 7.7 1.6 2.1 2.0910-15\n1088Page 4 of 11Environ Earth Sci (2016) 75:1088\n123',
#  ' the model domain is constrained by no-ﬂow boundary atthe bottom, recharge through the surrounding fault zones,and the low hydraulic heads in the NE model area. Dis-charge of the system in the central study area is mainlytoward Lake Linau and across the NE model boundary.Initial hydraulic head for the whole model domain is500 m.The heat transport boundary conditions are time-in-variant, ﬁxed temperatures, and heat ﬂux (Table2; Fig.2).Thermal gradient is 116/C176Ckm\n-1at the SW modelboundary, and the temperature is constant 350/C176C at thepluton. Temperature of water inﬁltrating into faults andhere mixing with shallow warm groundwater is 70/C176C,while surface groundwater recharge is at 28/C176C. Temper-ature values are obtained from ﬁeld and bore log mea-surements (Brehme et al.2014). Heat ﬂux is set to100 mW m\n-2at the bottom model boundary (Table2;Fig.2). This value is ﬁxed based on the studies fromDelisle et al. (1998), Nagao and Uyeda (1995), and Nebenet al. (1998). Initial temperature for the model domain isset as 116/C176Ckm\n-1, according to the local thermalgradient.Permeability determinationInitial values for permeability are deﬁned based on labo-ratory measurements (Table1). After each simulation run,modeled and measured temperature and pressure valueshave been compared at indicated observation points. Incase of poor matching (errors[10 %), permeability hasbeen adjusted until satisfactory results have been achieved.Beneath lake Linau, simulation results showed locallystrong discrepancies between modeled and measuredpressure and temperature (errors[45 %). Adjustment ofpermeability in geological layers, inﬁltration rates intofaults, or hydraulic heads did not lead to acceptable results.Only the implementation of strong permeability anisotropythroughout whole depth, i.e., an additional fault, resulted inminimization of errors (0–7 %). Implementation has beenaccomplished by mesh adaptation to ensure appropriatebehavior around the fault. By this procedure, permeabilityanisotropies have been located and characterized in detailthroughout the model.In general, deﬁning a direction-dependent permeabilityimproves the data ﬁt rather than using similar permeabili-ties in all directions. This is probably due to the fracturesincreasing the permeability mostly in vertical direction.Porosity and thermal conductivity remained constantthroughout simulation. Variation in porosity is negligiblebecause it would directly be reﬂected in permeability,while thermal conductivity differences would only affectconductive heat transport, which is not dominant in theLahendong area (Ondrak et al.1998; Brehme et al.2014).\n\nTable 2Boundary condition speciﬁcations and respective references of databaseType of BoundaryconditionSW model boundary SW fault Lake Cooling pluton NE fault NE model surface NE modelboundaryBottomof modelFluid ﬂowHydraulic head (m) 837 bore logmeasurementa767 surfaceelevationa500 bore logmeasurementa\nFluid ﬂux (m s-1) 3.0 x 10-4ﬁeldmeasurementa1.3 x 10-4ﬁeldmeasurementa1.3 x 10-8calculationb\nHeat transportTemperature (/C176C) 116/C176Ckm-1borelog measurementa70 estimationa350 bore logmeasurementa70 estimationa28 ﬁeld measurementa\nHeat ﬂux (mW m-2)100c\nMaterial properties See Table1aBrehme et al. (2014)\nbDWD (2007), Ho¨lting and Coldewey (2005), Saghravani et al. (2013)\ncDelisle et al. (1998), Nagao and Uyeda (1995), Neben et al. (1998)Environ Earth Sci (2016) 75:1088Page 5 of 111088\n123',
#  'Results\nNumerical simulation is performed to obtain the best ﬁt tothe measured data changing the absolute and relativepermeability in geological elements. Relative permeabilityrefers to different permeabilities in horizontal and verticaldirection. As a main result, a blind fault has been rec-ognized beneath Lake Linau, which has not been knownfrom former studies. Simulated pressure and temperatureare measured at ﬁve selected observation points, whichrepresent boreholes with available bore logs for pressureand temperature. Details on data are given in Fig.6. Themodel with best data ﬁt, out of 370 different models, isconsidered to generate the ﬁnal model developed forLahendong.Permeability distribution and identiﬁcationof a blind faultDistribution of permeability patterns in the reservoir hasbeen conceived comparing temperature and pressure datain several wells. Especially beneath Lake Linau, closelylocated wells show high variations in temperature andpressure. A drop of 100/C176C and 18 bar along 300 m dis-tance has been observed between well LHD 24 andLHD 28. Models ﬁrst showed high discrepancies betweenmodeled and measured values in this area. However, afterimplementing another high anisotropic permeable structurebetween the observation points, models resulted in satis-factory results. The structure has ten times higher verticalpermeability than horizontal permeability. This structure isassumed to be another fault zone located between twoknown faults with vertical dip and NW strike. This faultshows no trace at surface, because it is covered by LakeLinau.Generally, modeled permeability distribution in theLahendong reservoir is direction-dependent and overprintsthe lithology. Modeled permeability is generally higherthan measured ones in the order of up to four magnitudes.This is due to fracture patterns, which are not detectable atcore-sample scale. Permeability patterns directly affectsubsurface ﬂuid ﬂow and temperature and pressuredistribution.Permeability in the faulted zones and surroundings islowest in the study area. Especially the middle and NEfault, the shallow area beneath SW Lake Linau and thedeep NE section of the NE fault show low permeabilitiesbetween 10\n-13and 10-14m2(Fig.3). The area betweenthe middle and NE fault, the deep section NE of the SWfault, the SW fault itself and the whole model area towardthe SW and NE boundary show higher permeabilities of10\n-10and 10-12m2(Fig.3).Permeability varies not only within the modeled area,but also in vertical and horizontal direction. In faults andthe deep reservoir section in the NE, permeability is by afactor of 10 higher in the vertical direction than in thehorizontal direction (Fig.3). In the areas between faults,permeability is in some parts by a factor of 10–100 lower inthe vertical direction. In the rest of the model, vertical andhorizontal permeability do not differ (Fig.3).\n\n\nFig. 3Final adapted permeability and anisotropy distribution throughout the model domain. Anisotropy shows the relation between vertical andhorizontal permeability, if anisotropy[1 vertical permeability is higher than horizontal permeability\n1088Page 6 of 11Environ Earth Sci (2016) 75:1088\n123',
#  'Pressure distributionThe pressure distribution in the study area is controlled bygroundwater ﬂow in low permeable rocks and verticallyhigh permeable fault zones. Isobars drop following thenatural hydraulic gradient from SW to NE. The SW sectionof the system shows higher pressures, which is caused byinﬁltration from higher elevations in the SW. Some wellsexisting in this region are of artesian-type. Overpressurereleases through high permeable zones beneath Lake Linauand discharges toward surface. The pressure drop is up to20 bars across the faults (Fig.4).Temperature distributionTemperature distribution along the Lahendong geothermalreservoir suggests that convective heat transport is thedominating process in the reservoir rocks. Isotherms gen-erally follow the SW–NE oriented ﬂow pattern, the rise andthe inﬁltration of ﬂuids. Upwelling of isotherms betweenthe faults veriﬁes water rise toward Lake Linau. Inﬁltrationof cold water causes down welling of isotherms particu-larly on the northeast section of the model. Temperature islocally increased at the bottom of the model surroundingthe pluton (Fig.4).Subsurface ﬂuid ﬂowThe absolute and horizontal/vertical permeability distri-bution controls local ﬂuid ﬂow in the Lahendong reservoir.The general ﬂuid ﬂow, driven by the natural pressuregradient, is oriented from SW to NE. Vertical inﬁltrationoccurs at faults at Lake Linau and at the SW boundary.Discharge is across the NE model boundary (Fig.5). Themore detailed ﬂow patterns can be observed with stream-lines, which show a ﬂuid ﬂow along highly permeableareas. Calculated streamlines describe particle ﬂow withinthe model domain. A forward calculation shows howinﬁltrating water at the SW model boundary distributesthrough the reservoir. The backward calculation shows thesource of ﬂuid particles arriving at the NE model boundary(Fig.5). Patterns show that hot groundwater ﬂows towardthe faults beneath Lake Linau, where the ﬂuid ﬂow isdisturbed by a rise in temperature and vertically high per-meable layers. This causes a rise of groundwater in thismodel area (red forward streamlines in Fig.5). At the sametime, cold water inﬁltrates into high permeable areas anddistributes over the NE model domain (blue backwardstreamlines in Fig.5). It is clearly seen that the composi-tion of the NE reservoir domain is dominated by coldwaterinﬁltration into faults, while the production areas arecharacterized by hot water ﬂow (Fig.5).\nDiscussion\nInvestigation of subsurface ﬂuid ﬂow in geothermalreservoirs is crucial for sustainable exploitation avoidingdrilling into less productive areas. Subsurface ﬂuid ﬂowmight be locally inﬂuenced by fault zones or physical\n\nFig. 4Modeled temperature and pressure distribution in the study area shows high-pressure ﬁelds in the SW and convective heat transport withrising hot ﬂuids and inﬁltration of cooler water through faultsEnviron Earth Sci (2016) 75:1088Page 7 of 111088\n123',
#  'properties of water (i.e. viscosity). The inﬂuence of theseparameters on the ﬂuid ﬂow has been investigated inLahendong geothermal reservoir using hydraulic–thermalsimulations. Simulation results show the detailed perme-ability distribution in the reservoir including location of anadditional fault zone.Matching of measured and simulated temperature andpressure has been used as a tool for resolving the perme-ability distribution. Temperature and pressure have beeniteratively determined at several observation points(Fig.2). Generally, modeled values are in good agreementwith observed ones (Fig.6). Nevertheless, some observa-tion points give slightly different values for both pressureand temperature (LHD 4 and LHD 7) or only temperature(LHD 24). This is probably due to the complicated ﬂowprocesses or strong small-scale structural variation infractured and faulted areas. Furthermore, density varia-tions, which could have not been included into simulationdue to high temperatures, could cause variation of ﬂuidpressure. However, the average deviation of simulatedpressure and temperature is 1 %.Implemented model parameters are porosity, perme-ability, and heat conductivity. From those parameters, onlypermeability has been tested in a speciﬁc range duringsimulation. The inﬂuence of porosity and heat conductivityon ﬂuid ﬂow is negligible due to dominating convectiveheat ﬂow (Ondrak et al.1998). Values implemented in themodel are based on measured permeabilities, which rep-resent matrix permeability of rocks.The measured matrix permeability, representing per-meability in horizontal direction, is 1.5910\n-14m2onaverage, which remains within typical permeability rangefor fractured igneous rocks (Scho¨n2004). Permeability forvolcanic breccias ranges typically between 3910-15and5910\n-12m2and tuff permeabilities range between7910\n-17and 7910-12m2(Klavetter and Peters1987).In the Wairakei geothermal ﬁeld, simulating the imper-meable layers resulted in permeabilities of 10\n-18and10\n-14m2, in horizontal and vertical axis, respectively(Mercer and Faust1979).However, permeability in reservoir rocks might belocally increased due to fracture formation. It might also bedecreased due to alteration and sealing in faults. InLahendong, modeled permeability can be up to four mag-nitudes higher than measured ones in faulted areas. This iscaused by fractures, which are not detectable in core scale.Moreover, in fault cores, it is by a factor of 10 higher invertical direction than in horizontal direction. However, inareas between faults (fault gauge), permeability is in someparts by a factor of 10–100 lower in the vertical direction.Adaptation of permeability ensures a ﬁt to measured tem-perature and pressure data.Permeability in fractured areas is the main factor inﬂu-encing subsurface ﬂuid ﬂow and temperature distribution inthe Lahendong reservoir area. Subsurface ﬂuid ﬂow isdriven by local hydraulic heads, which show high varia-tions at different sections of the study area. Consequently,convective heat distribution leads to high temperaturevariation along the reservoir. These phenomena areobserved in Lahendong as well as comparable ﬁelds. InNew Mexico, water level drops of 30–100 m are observedacross several fault zones (Haneberg1995). High\n\nFig. 5Model domain with calculated streamlines, inred: forward streamlines follow hydraulic gradient from SW model boundary towards NE,inblue: backward streamlines representing inﬁltrating cold water ﬂowing towards NE model boundary\n1088Page 8 of 11Environ Earth Sci (2016) 75:1088\n123',
#  'temperature drops and upwelling of isotherms indicate thatfault zones control the ﬂuid ﬂow in the Lake Long andValentine ﬁelds, USA (Hooper1991). The analysis of ﬂuidpressure differences at the Alpine fault, New Zealand,allowed to characterize the change in permeability betweenhanging and footwall blocks (Sutherland et al.2012).In summary, high pressure or temperature gradients areindicators for ﬂuid barriers between observation points. Inother words, reservoir sections of different properties areseparated by horizontally less permeable faults. In Lahen-dong, most signiﬁcant ﬂuid barriers are faults to the SWand to the NE of Lake Linau. Across these barriers, thepressure drops up to 20 bars. A similar pattern has beenmeasured in bore logs beneath Lake Linau, where no sur-face trace of a fault had been observed in former studies.However, only by implementing another fault, modeledand measured values could have been adapted. Therecently identiﬁed fault zone beneath Lake Linau remainsunder lake water and therefore is only traceable by thiskind of reservoir modeling.Additionally to fault identiﬁcation, the internal structureof known fault zones has been understood in detail. The NEfault, i.e., shows a displacement at 2 km depth. Thedetailed trend has been understood by permeability adap-tation in this area.Due to low permeability in horizontal direction in thefaults, ﬂuids propagate mostly vertically toward the hotsprings at surface. It also allows surface water to inﬁltrateinto the reservoir in case the pressure within the fault zoneis low enough (Fig.5). This vertical ﬂuid movementeventually controls the temperature distribution in thereservoir. Upward migration of deep hot water increasesthe temperature, while inﬁltration of cold surface watercauses local drop of temperature.In summary, the most important factors inﬂuencing thereliability of numerical reservoir models are absolute anddifferent horizontal and vertical permeability. However, apermeability adaptation has been done for each geologicallayer; the vertical permeability anomalies are overprintingthose layers and are constraining the regional groundwaterﬂow. Those permeabilities of fractures directly inﬂuencethe productivity of the reservoir (Cherubini et al.2013).Therefore, their permeability characteristics should beinvestigated in detail.In a previous study, a numerical model for the Lahen-dong site has been set up in TOUGH2 and aimed at fore-casting the reservoir behavior during exploitation until theyear 2036. With a production of 60 MWe, it predicts apressure drop of 10 bars. However, the forecast results areuncertain due to lack of measured pressure draw down data(Yani2006). Accordingly, the next steps of the presentedstudy should include a realistic production and injectionscenario in order to support sustainable reservoirexploitation. Furthermore, chemical characteristics couldbe considered to achieve reliable production setups,because hydrochemical processes play an important role inthe Lahendong reservoir (Brehme et al.2016). Presentedmodels from this study provide important information onﬂuid ﬂow in the water-dominated Lahendong reservoir.However, additional two-phase ﬂow models of the\nLHDLHDLHDLHDLHD\n100 150 200 250 300 350 400 100 110 120 130 140 150 100 150 200 250 300 350 400 measured temeprature  [°C] \nmodelled temperature  [°C]  100 110 120 130 140 400 \nmodelled pressure  [bar] modelled pressure  [bar] 2428574\nwell namedate drilling completed date of bore log  LHD 4Oct 1985 Jan 86  LHD 5May 1986 Jul 2000  LHD 7Oct 1987 Jul 96  LHD 24Jul 09 Jul 09  LHD 28Aug 09 Aug 09\n4524287\nwell namereservoir depth          [m] below surface  LHD 41400  LHD 51750  LHD 72100  LHD 241820  LHD 281800\n\nFig. 6Modeled versus measured temperature and pressure at selected observation points. Well speciﬁcations and measured data from Brehmeet al. (2014)Environ Earth Sci (2016) 75:1088Page 9 of 111088\n123',
#  'Lahendong area are in progress to understand the inﬂuenceof steam driven ﬂuid ﬂow in this high-temperature system.\nConclusion\nThe primary focus of this study is to understand theinﬂuence of fault zones and permeability patterns on sub-surface ﬂuid ﬂow in geothermal reservoirs. The ﬂuid ﬂowmainly depends on rock and fault zone permeability. Theseprocesses have been considered in numerical models,which simulate local temperature and pressure conditions.The numerical models represent the initial reservoirconditions, which refers to the case before productionstarts. Models are developed based on the conceptualmodels of the study area, which explain reservoir geome-try, geological structures, temperature, and hydraulic con-ditions. Temperature and pressure well-logs have beenused for model calibration.Vertical and horizontal ﬂuid ﬂow is mainly controlledby fault permeability. This characteristic is used to simu-late different reservoir sections, and vertical ﬂuid risetoward the surface. By stepwise adaptation of permeabilityﬁelds, based on observed temperature and pressure gradi-ents, an additional blind fault zone can be identiﬁedbeneath Lake Linau. Temperature and pressure signiﬁ-cantly drop across that ﬂuid barrier. This behavior has beenobserved in comparable ﬁelds in the USA as well. Theoverall shape of ﬂuid ﬂow direction trends in a SW–NEdirection. Main recharge occurs by inﬁltration of surfacewater into the faults, especially in the southwest and near toLake Linau. Discharge is enhanced in highly fracturedareas toward Lake Linau. Vertical permeability of faultsallows ﬂuids rising toward the hot springs at surface.Results show that permeability has to be considered forsimulation of a geothermal system. The geothermal systemis mainly controlled by ﬂuid ﬂow in fractures/faultsdepending on temperature and pressure conditions. Thelocally modiﬁed ﬂuid ﬂow can considerably inﬂuence theproductivity of a geothermal ﬁeld. Results also guidereservoir management in case of a potential for ﬁeldextension, as performed in Lahendong.\nAcknowledgmentsThe authors acknowledge the continuous supportwithin the team of the International Center for Geothermal Researchunder the direction of E. Huenges. Thanks to H. Milsch, B. Peters,and D. Otten for helping at the Gas-Permeameter. We thank A.Fo¨rster for giving access and introduction to the optical scanner forthermal conductivity measurements and S. Fuchs for assisting whileinterpretation of data. A special gratitude to F. Bulut, who carefullyreviewed the manuscript, took care of linguistic issues, and supportedthe analysis with helpful discussions. Prof. M. Hochstein is greatlyacknowledged for continuous fruitful discussions during the study.The support of the team of Pertamina Geothermal Energy in Jakartaas well as in Lahendong including the access to data, and the ﬁeld ishighly appreciated. The authors thank PGE for the permission topublish this paper. The German Federal Ministry for Education andResearch (BMBF) is funding this German project ‘‘Sustainabilityconcepts for exploitation of geothermal reservoirs in Indonesia—ca-pacity building and methodologies for site deployment’’ under Grant03G0753A.References\nBrehme M, Regenspurg S, Zimmermann G (2011) Hydraulic-hydrochemical modelling of a geothermal reservoir in Indonesia.Mineral Mag 75:577Brehme M, Haase C, Regenspurg S, Moeck I, Deon F, Wiegand BA,Kamah Y, Zimmermann G, Sauter M (2013) Hydrochemicalpatterns in a structurally controlled geothermal system. MinerMag 77:767. doi:10.1180/minmag.2013.077.5.2Brehme M, Moeck I, Kamah Y, Zimmermann G, Sauter M (2014) Ahydrotectonic model of a geothermal reservoir—a study inLahendong, Indonesia. Geothermics 51:228–239. doi:10.1016/j.geothermics.2014.01.010Brehme M, Deon F, Haase C, Wiegand B, Kamah Y, Sauter M,Regenspurg S (2016) Geochemical properties controlled by faultpermeability in a geothermal reservoir (Lahendong, Indonesia).Grundwasser 21:29–41. doi:10.1007/s00767–015–0313–9Cherubini Y,  ...
#  'Seferihisar–Balc¸ova geothermal system, western Turkey. Hydro-geol J 20:103–118. doi:10.1007/s10040-011-0797-zMcGuinness M, White S, Young R, Ishizaki H, Ikeuchi K, Yoshida Y(1995) A model of the Kakkonda geothermal reservoir. Geother-mics 24:1–48. doi:10.1016/0375-6505(94)00020-DMercer JW, Faust CR (1979) Geothermal reservoir simulation: 3.Application of liquid-and vapor-dominated hydrothermal mod-eling techniques to Wairakei, New Zealand. Water Resour Res15:653–671. doi:10.1029/WR015i003p00653Milsch H, Priegnitz M, Blo¨cher G (2011) Permeability of gypsumsamples dehydrated in air. Geophys Res Lett 38:6. doi:10.1029/2011GL048797Moeck IS (2014) Catalog of geothermal play types based on geologiccontrols. Renew Sustain Energy Rev 37:867–882. doi:10.1016/j.rser.2014.05.032Nagao T, Uyeda S (1995) Heat-ﬂow distribution in Southeast Asiawith consideration of volcanic heat. Tectonophysics251:153–159Neben S, Hinz K, Beiersdorf H (1998) Reﬂection characteristics,depth and geographical distribution of bottom simulatingreﬂectors within the accretionary wedge of Sulawesi. Geol SocLond Spec Publ 137:255–265. doi:10.1144/GSL.SP.1998.137.01.20O’Sullivan MJ, Pruess K, Lippmann MJ (2001) State of the art ofgeothermal reservoir simulation. Geothermics 30:395–429.doi:10.1016/S0375-6505(01)00005-0Ondrak R, Wenderoth F, Scheck M, Bayer U (1998) Integratedgeothermal modeling on different scales in the NortheastGerman basin. Geol Rundschau 87:32–42. doi:10.1007/s005310050187Popov Y, Pribnow D, Sass J (1999) Characterization of rock thermalconductivity by high-resolution optical scanning. Geothermics28:253–276Scho¨n JH (2004) Physical properties of rocks. Elsevier Ltd,AmsterdamSaghravani S, Yusoff I, Mustapha S, Saghravani S (2013) Estimatinggroundwater recharge using empirical method: a case study inthe tropical zone. Sains Malays 42:553–560Sutherland R, Toy VG, Townend J, Cox SC, Eccles JD, Faulkner DR,Prior DJ, Norris RJ, Mariani E, Boulton C, Carpenter BM,Menzies CD, Little TA, Hasting M, De Pascale GP, LangridgeRM, Scott HR, Reid Lindroos Z, Fleming B, Kopf J (2012)Drilling reveals ﬂuid control on architecture and rupture of theAlpine fault, New Zealand. Geology 40:1143–1146. doi:10.1130/G33614.1Wiegand BA, Brehme M, Teuku F, Amran IA, Prasetio R, Kamah Y,Sauter M (2013) Geochemical and isotopic investigation ofﬂuids from Lahendong geothermal ﬁeld. Miner Mag 77:2491.doi:10.1180/minmag.2013.077.5.23Yani A (2006) Numerical modelling of the Lahendong geothermalsystem, Indonesia, Report from United Nations UniversityEnviron Earth Sci (2016) 75:1088Page 11 of 111088\n123']

# %%
text_pypdf_join = ' '.join(text_pypdf)

# %% [markdown]
# # PDFMiner

# %%
def get_pdf_file_content_Text(path_to_pdf):
    
    '''
    path_to_pdf: is the parameter that will give access to the PDF File 
    we want to extract the content.
    '''
    
    '''
    PDFResourceManager is used to store shared resources such as fonts or images that 
    we might encounter in the files. 
    '''
    
    resource_manager = PDFResourceManager(caching=True)
    
    '''
    create a string object that will contain the final text the representation of the pdf. 
    '''
    out_text = StringIO()
    
    '''
    UTF-8 is one of the most commonly used encodings, and Python often defaults to using it.
    In our case, we are going to specify in order to avoid some encoding errors.
    '''
    codec = 'utf-8'
    
    """
    LAParams is the object containing the Layout parameters with a certain default value. 
    """
    laParams = LAParams(line_overlap=0.3, detect_vertical=True)
    
    '''
    Create a TextConverter Object, taking :
    - ressource_manager,
    - out_text 
    - layout parameters.
    '''
    text_converter = TextConverter(resource_manager, out_text, laparams=laParams)
    fp = open(path_to_pdf, 'rb')
    
    '''
    Create a PDF interpreter object taking: 
    - ressource_manager 
    - text_converter
    '''
    interpreter = PDFPageInterpreter(resource_manager, text_converter)

    '''
    We are going to process the content of each page of the original PDF File
    '''
    for page in PDFPage.get_pages(fp, pagenos=set(), maxpages=0, password="", caching=True, check_extractable=True):
        interpreter.process_page(page)

#Considering Vertical Written
#         if page.mediabox[2] - page.mediabox[0] > page.mediabox[3] - page.mediabox[1]:
#             orientation = 'Landscape'
#         else:
#             orientation = 'Portrait'

    '''
    Retrieve the entire contents of the “file” at any time 
    before the StringIO object’s close() method is called.
    '''
    text = out_text.getvalue()

    '''
    Closing all the ressources we previously opened
    '''
    fp.close()
    text_converter.close()
    out_text.close()
    
    '''
    Return the final variable containing all the text of the PDF
    '''
    return text

# %%
text_pdfmine = get_pdf_file_content_Text(pdf_path)

# %%
text_pdfmine
# Out:
# 'Environ Earth Sci (2016) 75:1088\nDOI 10.1007/s12665-016-5878-9\n\nO R I G I N A L A R T I C L E\n\nPermeability distribution in the Lahendong geothermal ﬁeld:\nA blind fault captured by thermal–hydraulic simulation\n\nMaren Brehme1 • Guido Blo¨cher1 • Mauro Cacace1 • Yustin Kamah2 •\nMartin Sauter3 • Gu¨ nter Zimmermann1\n\nReceived: 24 November 2015 / Accepted: 4 July 2016 / Published online: 19 July 2016\nÓ Springer-Verlag Berlin Heidelberg 2016\n\nAbstract Subsurface ﬂuid ﬂow of reservoirs in active\ntectonic regions is mainly controlled by permeability of\nfault zones. Therefore, the characterization of fault zones is\nan important step toward performance assessment of a\nreservoir. The ﬂuid ﬂow is controlled also by pressure and\ntemperature conditions.\nIn this context, we simulated\npressure and temperature ﬁelds to elaborate on the inﬂu-\nence of permeability on subsurface ﬂuid ﬂow in the\nLahendong geothermal reservoir. Thermal–hydraulic sim-\nulation is performed using a ﬁnite element approach.\nAdjusting the permeability through 370 different cases,\nmodeling results converged to the observed data within a\nmisﬁt range of 0–7 %. The best ﬁtting models identiﬁed a\ndeep-seated fault that has previously not been traced at the\nsurface. Simulated temperature distribution suggests a\nprominent convective heat ﬂow, driven by an upward\nmigrating and SW–NE oriented ﬂuid ﬂow. This hydraulic\ngradient causes a pressure drop along the reservoir. High-\npressure patterns are used to constrain recharge areas, in\naddition to inﬁltration measurements. Discharge ﬂow\noccurs from SW to NE migrating also upward toward the\nhot springs. In that frame, thermal–hydraulic simulations\nidentiﬁed previously unresolved subsurface faults, which\n\n& Maren Brehme\n\nbrehme@gfz-potsdam.de\n\n1 Helmholtz Centre Potsdam – GFZ German Research Centre\nfor Geosciences, Telegrafenberg, 14473 Potsdam, Germany\n\n2 Upstream Technology Center Pertamina, Jl. Medan Merdeka\n\nTimur no. 6, Jakarta, Indonesia\n\n3 Applied Geology, University of Go¨ttingen,\n\nGoldschmidtstraße. 3, 37077 Go¨ttingen, Germany\n\nnow allow a better understanding of the subsurface per-\nmeability and its inﬂuence on ﬂuid ﬂow.\nKeywords Permeable faults \x01 Hydrogeology \x01 Fluid ﬂow \x01\nGeothermal ﬁeld management \x01 Reservoir engineering \x01\nPressure drop\n\nIntroduction\n\nIt\n\nGeothermal energy is an essential component to supply\nfuture energy demands.\nrequires developing new\ngeothermal sites and improving the performance of exist-\ning systems to satisfy continuously growing demand. The\nproductivity of a geothermal ﬁeld mainly depends on\nsubsurface ﬂuid ﬂow, which in active tectonic regions is\ncontrolled by permeability of fault zones (Moeck 2014). In\nthat frame, the primary focus is on locating and charac-\nterizing faulted areas in geothermal ﬁelds. This study\nemploys numerical modeling to allocate and quantify\npermeability anisotropies and discontinuities, e.g., faults, in\norder to understand their inﬂuence on subsurface ﬂuid ﬂow\nin geothermal reservoirs.\n\nNumerical models have been increasingly used to\nunderstand the setup and productivity of geothermal sys-\ntems. A general overview of geothermal models has been\ngiven by O’Sullivan et al. (2001). Additionally, there are\nseveral sites exemplifying similar characteristics as in\nLahendong. The underground movement of hot and cold\nﬂuids has been modeled for geothermal ﬁelds in New\nZealand (Kaya et al. 2014). The Kakkonda geothermal site,\ne.g., consists of two reservoirs at various depths with dif-\nferent ﬂuid properties. There,\nresults from ﬂuid ﬂow\nanalysis show the importance of fractures for ﬂuid transport\nenhancing the recharge or discharge in the reservoir\n\n123\n\n\x0c1088 Page 2 of 11\n\nEnviron Earth Sci (2016) 75:1088\n\n(McGuinness et al. 1995). Generally, faults acting as\npreferential ﬂuid path ways signiﬁcantly change the pres-\nsure and temperature ﬁeld in the reservoir ( ...

# %% [markdown]
# # Grobid

# %%
# client.process("processFulltextDocument", pdf_path, output="PDF Data/", consolidate_citations=True, tei_coordinates=True, force=True)

# %% [markdown]
# ## Data Preprocessing (Conditioning, Stop Words, Stemmer)

# %% [markdown]
# ## Regex Conditioning & NLTK StopWord

# %%
def prepro(text.lower()):
    #Punctuation of '-' because make a newline 
    text_punew = re.sub(r'(-\n)','',text)
    
    #Remove spacing n dot '\n' & '•'
    text_punew_spdo = re.sub(r'[\n•]', ' ', text_punew)
    
    #Germany alphabetic umlaut
    text_punew_spdo_ger = re.sub(r'(?<=[OoUuAa])(¨)','e',text_punew_spdo)
    
    #Remove number and punctuations (except . ,)
    text_punew_spdo_ger_numpunc = regex.sub(r'(\d|[^\P{P}.,]+)','',text_punew_spdo_ger)
    
    #Over-Spacing
    text_punew_spdo_ger_numpunc_ovsp = re.sub(r'(\s)(?=\s+)','',text_punew_spdo_ger_numpunc)

# %%
#Punctuation of '-' because make a newline 
text_punew = re.sub(r'(-\n)','',text_pdfmine.lower())
text_punew
# Out:
# 'environ earth sci (2016) 75:1088\ndoi 10.1007/s12665-016-5878-9\n\no r i g i n a l a r t i c l e\n\npermeability distribution in the lahendong geothermal ﬁeld:\na blind fault captured by thermal–hydraulic simulation\n\nmaren brehme1 • guido blo¨cher1 • mauro cacace1 • yustin kamah2 •\nmartin sauter3 • gu¨ nter zimmermann1\n\nreceived: 24 november 2015 / accepted: 4 july 2016 / published online: 19 july 2016\nó springer-verlag berlin heidelberg 2016\n\nabstract subsurface ﬂuid ﬂow of reservoirs in active\ntectonic regions is mainly controlled by permeability of\nfault zones. therefore, the characterization of fault zones is\nan important step toward performance assessment of a\nreservoir. the ﬂuid ﬂow is controlled also by pressure and\ntemperature conditions.\nin this context, we simulated\npressure and temperature ﬁelds to elaborate on the inﬂuence of permeability on subsurface ﬂuid ﬂow in the\nlahendong geothermal reservoir. thermal–hydraulic simulation is performed using a ﬁnite element approach.\nadjusting the permeability through 370 different cases,\nmodeling results converged to the observed data within a\nmisﬁt range of 0–7 %. the best ﬁtting models identiﬁed a\ndeep-seated fault that has previously not been traced at the\nsurface. simulated temperature distribution suggests a\nprominent convective heat ﬂow, driven by an upward\nmigrating and sw–ne oriented ﬂuid ﬂow. this hydraulic\ngradient causes a pressure drop along the reservoir. highpressure patterns are used to constrain recharge areas, in\naddition to inﬁltration measurements. discharge ﬂow\noccurs from sw to ne migrating also upward toward the\nhot springs. in that frame, thermal–hydraulic simulations\nidentiﬁed previously unresolved subsurface faults, which\n\n& maren brehme\n\nbrehme@gfz-potsdam.de\n\n1 helmholtz centre potsdam – gfz german research centre\nfor geosciences, telegrafenberg, 14473 potsdam, germany\n\n2 upstream technology center pertamina, jl. medan merdeka\n\ntimur no. 6, jakarta, indonesia\n\n3 applied geology, university of go¨ttingen,\n\ngoldschmidtstraße. 3, 37077 go¨ttingen, germany\n\nnow allow a better understanding of the subsurface permeability and its inﬂuence on ﬂuid ﬂow.\nkeywords permeable faults \x01 hydrogeology \x01 fluid ﬂow \x01\ngeothermal ﬁeld management \x01 reservoir engineering \x01\npressure drop\n\nintroduction\n\nit\n\ngeothermal energy is an essential component to supply\nfuture energy demands.\nrequires developing new\ngeothermal sites and improving the performance of existing systems to satisfy continuously growing demand. the\nproductivity of a geothermal ﬁeld mainly depends on\nsubsurface ﬂuid ﬂow, which in active tectonic regions is\ncontrolled by permeability of fault zones (moeck 2014). in\nthat frame, the primary focus is on locating and characterizing faulted areas in geothermal ﬁelds. this study\nemploys numerical modeling to allocate and quantify\npermeability anisotropies and discontinuities, e.g., faults, in\norder to understand their inﬂuence on subsurface ﬂuid ﬂow\nin geothermal reservoirs.\n\nnumerical models have been increasingly used to\nunderstand the setup and productivity of geothermal systems. a general overview of geothermal models has been\ngiven by o’sullivan et al. (2001). additionally, there are\nseveral sites exemplifying similar characteristics as in\nlahendong. the underground movement of hot and cold\nﬂuids has been modeled for geothermal ﬁelds in new\nzealand (kaya et al. 2014). the kakkonda geothermal site,\ne.g., consists of two reservoirs at various depths with different ﬂuid properties. there,\nresults from ﬂuid ﬂow\nanalysis show the importance of fractures for ﬂuid transport\nenhancing the recharge or discharge in the reservoir\n\n123\n\n\x0c1088 page 2 of 11\n\nenviron earth sci (2016) 75:1088\n\n(mcguinness et al. 1995). generally, faults acting as\npreferential ﬂuid path ways signiﬁcantly change the pressure and temperature ﬁeld in the reservoir (cherubini et al.\n2013). mo ...

# %%
#Remove spacing n dot '\n' & '•'
text_punew_spdo = re.sub(r'[\n•]', ' ', text_punew)
text_punew_spdo
# Out:
# 'environ earth sci (2016) 75:1088 doi 10.1007/s12665-016-5878-9  o r i g i n a l a r t i c l e  permeability distribution in the lahendong geothermal ﬁeld: a blind fault captured by thermal–hydraulic simulation  maren brehme1   guido blo¨cher1   mauro cacace1   yustin kamah2   martin sauter3   gu¨ nter zimmermann1  received: 24 november 2015 / accepted: 4 july 2016 / published online: 19 july 2016 ó springer-verlag berlin heidelberg 2016  abstract subsurface ﬂuid ﬂow of reservoirs in active tectonic regions is mainly controlled by permeability of fault zones. therefore, the characterization of fault zones is an important step toward performance assessment of a reservoir. the ﬂuid ﬂow is controlled also by pressure and temperature conditions. in this context, we simulated pressure and temperature ﬁelds to elaborate on the inﬂuence of permeability on subsurface ﬂuid ﬂow in the lahendong geothermal reservoir. thermal–hydraulic simulation is performed using a ﬁnite element approach. adjusting the permeability through 370 different cases, modeling results converged to the observed data within a misﬁt range of 0–7 %. the best ﬁtting models identiﬁed a deep-seated fault that has previously not been traced at the surface. simulated temperature distribution suggests a prominent convective heat ﬂow, driven by an upward migrating and sw–ne oriented ﬂuid ﬂow. this hydraulic gradient causes a pressure drop along the reservoir. highpressure patterns are used to constrain recharge areas, in addition to inﬁltration measurements. discharge ﬂow occurs from sw to ne migrating also upward toward the hot springs. in that frame, thermal–hydraulic simulations identiﬁed previously unresolved subsurface faults, which  & maren brehme  brehme@gfz-potsdam.de  1 helmholtz centre potsdam – gfz german research centre for geosciences, telegrafenberg, 14473 potsdam, germany  2 upstream technology center pertamina, jl. medan merdeka  timur no. 6, jakarta, indonesia  3 applied geology, university of go¨ttingen,  goldschmidtstraße. 3, 37077 go¨ttingen, germany  now allow a better understanding of the subsurface permeability and its inﬂuence on ﬂuid ﬂow. keywords permeable faults \x01 hydrogeology \x01 fluid ﬂow \x01 geothermal ﬁeld management \x01 reservoir engineering \x01 pressure drop  introduction  it  geothermal energy is an essential component to supply future energy demands. requires developing new geothermal sites and improving the performance of existing systems to satisfy continuously growing demand. the productivity of a geothermal ﬁeld mainly depends on subsurface ﬂuid ﬂow, which in active tectonic regions is controlled by permeability of fault zones (moeck 2014). in that frame, the primary focus is on locating and characterizing faulted areas in geothermal ﬁelds. this study employs numerical modeling to allocate and quantify permeability anisotropies and discontinuities, e.g., faults, in order to understand their inﬂuence on subsurface ﬂuid ﬂow in geothermal reservoirs.  numerical models have been increasingly used to understand the setup and productivity of geothermal systems. a general overview of geothermal models has been given by o’sullivan et al. (2001). additionally, there are several sites exemplifying similar characteristics as in lahendong. the underground movement of hot and cold ﬂuids has been modeled for geothermal ﬁelds in new zealand (kaya et al. 2014). the kakkonda geothermal site, e.g., consists of two reservoirs at various depths with different ﬂuid properties. there, results from ﬂuid ﬂow analysis show the importance of fractures for ﬂuid transport enhancing the recharge or discharge in the reservoir  123  \x0c1088 page 2 of 11  environ earth sci (2016) 75:1088  (mcguinness et al. 1995). generally, faults acting as preferential ﬂuid path ways signiﬁcantly change the pressure and temperature ﬁeld in the reservoir (cherubini et al. 2013). models for the seferihisar–balc¸ova ﬁeld focus on the ﬂuid ﬂow inside of faults. results show a ...

# %%
#Germany alphabetic umlaut
text_punew_spdo_ger = re.sub(r'(?<=[OoUuAa])(¨)','e',text_punew_spdo)
text_punew_spdo_ger
# Out:
# 'environ earth sci (2016) 75:1088 doi 10.1007/s12665-016-5878-9  o r i g i n a l a r t i c l e  permeability distribution in the lahendong geothermal ﬁeld: a blind fault captured by thermal–hydraulic simulation  maren brehme1   guido bloecher1   mauro cacace1   yustin kamah2   martin sauter3   gue nter zimmermann1  received: 24 november 2015 / accepted: 4 july 2016 / published online: 19 july 2016 ó springer-verlag berlin heidelberg 2016  abstract subsurface ﬂuid ﬂow of reservoirs in active tectonic regions is mainly controlled by permeability of fault zones. therefore, the characterization of fault zones is an important step toward performance assessment of a reservoir. the ﬂuid ﬂow is controlled also by pressure and temperature conditions. in this context, we simulated pressure and temperature ﬁelds to elaborate on the inﬂuence of permeability on subsurface ﬂuid ﬂow in the lahendong geothermal reservoir. thermal–hydraulic simulation is performed using a ﬁnite element approach. adjusting the permeability through 370 different cases, modeling results converged to the observed data within a misﬁt range of 0–7 %. the best ﬁtting models identiﬁed a deep-seated fault that has previously not been traced at the surface. simulated temperature distribution suggests a prominent convective heat ﬂow, driven by an upward migrating and sw–ne oriented ﬂuid ﬂow. this hydraulic gradient causes a pressure drop along the reservoir. highpressure patterns are used to constrain recharge areas, in addition to inﬁltration measurements. discharge ﬂow occurs from sw to ne migrating also upward toward the hot springs. in that frame, thermal–hydraulic simulations identiﬁed previously unresolved subsurface faults, which  & maren brehme  brehme@gfz-potsdam.de  1 helmholtz centre potsdam – gfz german research centre for geosciences, telegrafenberg, 14473 potsdam, germany  2 upstream technology center pertamina, jl. medan merdeka  timur no. 6, jakarta, indonesia  3 applied geology, university of goettingen,  goldschmidtstraße. 3, 37077 goettingen, germany  now allow a better understanding of the subsurface permeability and its inﬂuence on ﬂuid ﬂow. keywords permeable faults \x01 hydrogeology \x01 fluid ﬂow \x01 geothermal ﬁeld management \x01 reservoir engineering \x01 pressure drop  introduction  it  geothermal energy is an essential component to supply future energy demands. requires developing new geothermal sites and improving the performance of existing systems to satisfy continuously growing demand. the productivity of a geothermal ﬁeld mainly depends on subsurface ﬂuid ﬂow, which in active tectonic regions is controlled by permeability of fault zones (moeck 2014). in that frame, the primary focus is on locating and characterizing faulted areas in geothermal ﬁelds. this study employs numerical modeling to allocate and quantify permeability anisotropies and discontinuities, e.g., faults, in order to understand their inﬂuence on subsurface ﬂuid ﬂow in geothermal reservoirs.  numerical models have been increasingly used to understand the setup and productivity of geothermal systems. a general overview of geothermal models has been given by o’sullivan et al. (2001). additionally, there are several sites exemplifying similar characteristics as in lahendong. the underground movement of hot and cold ﬂuids has been modeled for geothermal ﬁelds in new zealand (kaya et al. 2014). the kakkonda geothermal site, e.g., consists of two reservoirs at various depths with different ﬂuid properties. there, results from ﬂuid ﬂow analysis show the importance of fractures for ﬂuid transport enhancing the recharge or discharge in the reservoir  123  \x0c1088 page 2 of 11  environ earth sci (2016) 75:1088  (mcguinness et al. 1995). generally, faults acting as preferential ﬂuid path ways signiﬁcantly change the pressure and temperature ﬁeld in the reservoir (cherubini et al. 2013). models for the seferihisar–balc¸ova ﬁeld focus on the ﬂuid ﬂow inside of faults. results show a ...

# %%
#Remove number and punctuations (except . ,)
text_punew_spdo_ger_numpunc = regex.sub(r'(\d|[^\P{P}.,]+)','',text_punew_spdo_ger)
text_punew_spdo_ger_numpunc
# Out:
# 'environ earth sci   doi .s  o r i g i n a l a r t i c l e  permeability distribution in the lahendong geothermal ﬁeld a blind fault captured by thermalhydraulic simulation  maren brehme   guido bloecher   mauro cacace   yustin kamah   martin sauter   gue nter zimmermann  received  november   accepted  july   published online  july  ó springerverlag berlin heidelberg   abstract subsurface ﬂuid ﬂow of reservoirs in active tectonic regions is mainly controlled by permeability of fault zones. therefore, the characterization of fault zones is an important step toward performance assessment of a reservoir. the ﬂuid ﬂow is controlled also by pressure and temperature conditions. in this context, we simulated pressure and temperature ﬁelds to elaborate on the inﬂuence of permeability on subsurface ﬂuid ﬂow in the lahendong geothermal reservoir. thermalhydraulic simulation is performed using a ﬁnite element approach. adjusting the permeability through  different cases, modeling results converged to the observed data within a misﬁt range of  . the best ﬁtting models identiﬁed a deepseated fault that has previously not been traced at the surface. simulated temperature distribution suggests a prominent convective heat ﬂow, driven by an upward migrating and swne oriented ﬂuid ﬂow. this hydraulic gradient causes a pressure drop along the reservoir. highpressure patterns are used to constrain recharge areas, in addition to inﬁltration measurements. discharge ﬂow occurs from sw to ne migrating also upward toward the hot springs. in that frame, thermalhydraulic simulations identiﬁed previously unresolved subsurface faults, which   maren brehme  brehmegfzpotsdam.de   helmholtz centre potsdam  gfz german research centre for geosciences, telegrafenberg,  potsdam, germany   upstream technology center pertamina, jl. medan merdeka  timur no. , jakarta, indonesia   applied geology, university of goettingen,  goldschmidtstraße. ,  goettingen, germany  now allow a better understanding of the subsurface permeability and its inﬂuence on ﬂuid ﬂow. keywords permeable faults \x01 hydrogeology \x01 fluid ﬂow \x01 geothermal ﬁeld management \x01 reservoir engineering \x01 pressure drop  introduction  it  geothermal energy is an essential component to supply future energy demands. requires developing new geothermal sites and improving the performance of existing systems to satisfy continuously growing demand. the productivity of a geothermal ﬁeld mainly depends on subsurface ﬂuid ﬂow, which in active tectonic regions is controlled by permeability of fault zones moeck . in that frame, the primary focus is on locating and characterizing faulted areas in geothermal ﬁelds. this study employs numerical modeling to allocate and quantify permeability anisotropies and discontinuities, e.g., faults, in order to understand their inﬂuence on subsurface ﬂuid ﬂow in geothermal reservoirs.  numerical models have been increasingly used to understand the setup and productivity of geothermal systems. a general overview of geothermal models has been given by osullivan et al. . additionally, there are several sites exemplifying similar characteristics as in lahendong. the underground movement of hot and cold ﬂuids has been modeled for geothermal ﬁelds in new zealand kaya et al. . the kakkonda geothermal site, e.g., consists of two reservoirs at various depths with different ﬂuid properties. there, results from ﬂuid ﬂow analysis show the importance of fractures for ﬂuid transport enhancing the recharge or discharge in the reservoir    \x0c page  of   environ earth sci    mcguinness et al. . generally, faults acting as preferential ﬂuid path ways signiﬁcantly change the pressure and temperature ﬁeld in the reservoir cherubini et al. . models for the seferihisarbalc¸ova ﬁeld focus on the ﬂuid ﬂow inside of faults. results show an enhanced upward heat transport through ﬂuids from bottom of the geothermal system magri et al. .  our test ground is the lahendong geothermal ﬁeld located ...

# %%
#Over-Spacing
text_punew_spdo_ger_numpunc_ovsp = re.sub(r'(\s)(?=\s+)','',text_punew_spdo_ger_numpunc)
text_punew_spdo_ger_numpunc_ovsp
# Out:
# 'environ earth sci doi .s o r i g i n a l a r t i c l e permeability distribution in the lahendong geothermal ﬁeld a blind fault captured by thermalhydraulic simulation maren brehme guido bloecher mauro cacace yustin kamah martin sauter gue nter zimmermann received november accepted july published online july ó springerverlag berlin heidelberg abstract subsurface ﬂuid ﬂow of reservoirs in active tectonic regions is mainly controlled by permeability of fault zones. therefore, the characterization of fault zones is an important step toward performance assessment of a reservoir. the ﬂuid ﬂow is controlled also by pressure and temperature conditions. in this context, we simulated pressure and temperature ﬁelds to elaborate on the inﬂuence of permeability on subsurface ﬂuid ﬂow in the lahendong geothermal reservoir. thermalhydraulic simulation is performed using a ﬁnite element approach. adjusting the permeability through different cases, modeling results converged to the observed data within a misﬁt range of . the best ﬁtting models identiﬁed a deepseated fault that has previously not been traced at the surface. simulated temperature distribution suggests a prominent convective heat ﬂow, driven by an upward migrating and swne oriented ﬂuid ﬂow. this hydraulic gradient causes a pressure drop along the reservoir. highpressure patterns are used to constrain recharge areas, in addition to inﬁltration measurements. discharge ﬂow occurs from sw to ne migrating also upward toward the hot springs. in that frame, thermalhydraulic simulations identiﬁed previously unresolved subsurface faults, which maren brehme brehmegfzpotsdam.de helmholtz centre potsdam gfz german research centre for geosciences, telegrafenberg, potsdam, germany upstream technology center pertamina, jl. medan merdeka timur no. , jakarta, indonesia applied geology, university of goettingen, goldschmidtstraße. , goettingen, germany now allow a better understanding of the subsurface permeability and its inﬂuence on ﬂuid ﬂow. keywords permeable faults \x01 hydrogeology \x01 fluid ﬂow \x01 geothermal ﬁeld management \x01 reservoir engineering \x01 pressure drop introduction it geothermal energy is an essential component to supply future energy demands. requires developing new geothermal sites and improving the performance of existing systems to satisfy continuously growing demand. the productivity of a geothermal ﬁeld mainly depends on subsurface ﬂuid ﬂow, which in active tectonic regions is controlled by permeability of fault zones moeck . in that frame, the primary focus is on locating and characterizing faulted areas in geothermal ﬁelds. this study employs numerical modeling to allocate and quantify permeability anisotropies and discontinuities, e.g., faults, in order to understand their inﬂuence on subsurface ﬂuid ﬂow in geothermal reservoirs. numerical models have been increasingly used to understand the setup and productivity of geothermal systems. a general overview of geothermal models has been given by osullivan et al. . additionally, there are several sites exemplifying similar characteristics as in lahendong. the underground movement of hot and cold ﬂuids has been modeled for geothermal ﬁelds in new zealand kaya et al. . the kakkonda geothermal site, e.g., consists of two reservoirs at various depths with different ﬂuid properties. there, results from ﬂuid ﬂow analysis show the importance of fractures for ﬂuid transport enhancing the recharge or discharge in the reservoir page of environ earth sci mcguinness et al. . generally, faults acting as preferential ﬂuid path ways signiﬁcantly change the pressure and temperature ﬁeld in the reservoir cherubini et al. . models for the seferihisarbalc¸ova ﬁeld focus on the ﬂuid ﬂow inside of faults. results show an enhanced upward heat transport through ﬂuids from bottom of the geothermal system magri et al. . our test ground is the lahendong geothermal ﬁeld located in sulawesi, indonesia. the ﬁeld is owned and operated by p.t ...

# %%
#Revise et al. + lower
text_punew_spdo_ovsp_ger_etal = re.sub(r'et al.','et al',text_punew_spdo_ovsp)
text_punew_spdo_ovsp_ger_etal
# Out:
# 'environ earth sci (2016) 75:1088 doi 10.1007/s12665-016-5878-9 o r i g i n a l a r t i c l e permeability distribution in the lahendong geothermal ﬁeld: a blind fault captured by thermal–hydraulic simulation maren brehme1 guido blo¨cher1 mauro cacace1 yustin kamah2 martin sauter3 gu¨ nter zimmermann1 received: 24 november 2015 / accepted: 4 july 2016 / published online: 19 july 2016 ó springer-verlag berlin heidelberg 2016 abstract subsurface ﬂuid ﬂow of reservoirs in active tectonic regions is mainly controlled by permeability of fault zones. therefore, the characterization of fault zones is an important step toward performance assessment of a reservoir. the ﬂuid ﬂow is controlled also by pressure and temperature conditions. in this context, we simulated pressure and temperature ﬁelds to elaborate on the inﬂuence of permeability on subsurface ﬂuid ﬂow in the lahendong geothermal reservoir. thermal–hydraulic simulation is performed using a ﬁnite element approach. adjusting the permeability through 370 different cases, modeling results converged to the observed data within a misﬁt range of 0–7 %. the best ﬁtting models identiﬁed a deep-seated fault that has previously not been traced at the surface. simulated temperature distribution suggests a prominent convective heat ﬂow, driven by an upward migrating and sw–ne oriented ﬂuid ﬂow. this hydraulic gradient causes a pressure drop along the reservoir. highpressure patterns are used to constrain recharge areas, in addition to inﬁltration measurements. discharge ﬂow occurs from sw to ne migrating also upward toward the hot springs. in that frame, thermal–hydraulic simulations identiﬁed previously unresolved subsurface faults, which & maren brehme brehme@gfz-potsdam.de 1 helmholtz centre potsdam – gfz german research centre for geosciences, telegrafenberg, 14473 potsdam, germany 2 upstream technology center pertamina, jl. medan merdeka timur no. 6, jakarta, indonesia 3 applied geology, university of go¨ttingen, goldschmidtstraße. 3, 37077 go¨ttingen, germany now allow a better understanding of the subsurface permeability and its inﬂuence on ﬂuid ﬂow. keywords permeable faults \x01 hydrogeology \x01 fluid ﬂow \x01 geothermal ﬁeld management \x01 reservoir engineering \x01 pressure drop introduction it geothermal energy is an essential component to supply future energy demands. requires developing new geothermal sites and improving the performance of existing systems to satisfy continuously growing demand. the productivity of a geothermal ﬁeld mainly depends on subsurface ﬂuid ﬂow, which in active tectonic regions is controlled by permeability of fault zones (moeck 2014). in that frame, the primary focus is on locating and characterizing faulted areas in geothermal ﬁelds. this study employs numerical modeling to allocate and quantify permeability anisotropies and discontinuities, e.g., faults, in order to understand their inﬂuence on subsurface ﬂuid ﬂow in geothermal reservoirs. numerical models have been increasingly used to understand the setup and productivity of geothermal systems. a general overview of geothermal models has been given by o’sullivan et al (2001). additionally, there are several sites exemplifying similar characteristics as in lahendong. the underground movement of hot and cold ﬂuids has been modeled for geothermal ﬁelds in new zealand (kaya et al 2014). the kakkonda geothermal site, e.g., consists of two reservoirs at various depths with different ﬂuid properties. there, results from ﬂuid ﬂow analysis show the importance of fractures for ﬂuid transport enhancing the recharge or discharge in the reservoir 123\x0c1088 page 2 of 11 environ earth sci (2016) 75:1088 (mcguinness et al 1995). generally, faults acting as preferential ﬂuid path ways signiﬁcantly change the pressure and temperature ﬁeld in the reservoir (cherubini et al 2013). models for the seferihisar–balc¸ova ﬁeld focus on the ﬂuid ﬂow inside of faults. results show an enhanced upward heat transport thr ...

# %%
#Remove number
re.sub(r'\d','',text_punew_spdo_ovsp_ger_etal)
# Out:
# 'environ earth sci () : doi ./s--- o r i g i n a l a r t i c l e permeability distribution in the lahendong geothermal ﬁeld: a blind fault captured by thermal–hydraulic simulation maren brehme guido blo¨cher mauro cacace yustin kamah martin sauter gu¨ nter zimmermann received:  november  / accepted:  july  / published online:  july  ó springer-verlag berlin heidelberg  abstract subsurface ﬂuid ﬂow of reservoirs in active tectonic regions is mainly controlled by permeability of fault zones. therefore, the characterization of fault zones is an important step toward performance assessment of a reservoir. the ﬂuid ﬂow is controlled also by pressure and temperature conditions. in this context, we simulated pressure and temperature ﬁelds to elaborate on the inﬂuence of permeability on subsurface ﬂuid ﬂow in the lahendong geothermal reservoir. thermal–hydraulic simulation is performed using a ﬁnite element approach. adjusting the permeability through  different cases, modeling results converged to the observed data within a misﬁt range of – %. the best ﬁtting models identiﬁed a deep-seated fault that has previously not been traced at the surface. simulated temperature distribution suggests a prominent convective heat ﬂow, driven by an upward migrating and sw–ne oriented ﬂuid ﬂow. this hydraulic gradient causes a pressure drop along the reservoir. highpressure patterns are used to constrain recharge areas, in addition to inﬁltration measurements. discharge ﬂow occurs from sw to ne migrating also upward toward the hot springs. in that frame, thermal–hydraulic simulations identiﬁed previously unresolved subsurface faults, which & maren brehme brehme@gfz-potsdam.de  helmholtz centre potsdam – gfz german research centre for geosciences, telegrafenberg,  potsdam, germany  upstream technology center pertamina, jl. medan merdeka timur no. , jakarta, indonesia  applied geology, university of go¨ttingen, goldschmidtstraße. ,  go¨ttingen, germany now allow a better understanding of the subsurface permeability and its inﬂuence on ﬂuid ﬂow. keywords permeable faults \x01 hydrogeology \x01 fluid ﬂow \x01 geothermal ﬁeld management \x01 reservoir engineering \x01 pressure drop introduction it geothermal energy is an essential component to supply future energy demands. requires developing new geothermal sites and improving the performance of existing systems to satisfy continuously growing demand. the productivity of a geothermal ﬁeld mainly depends on subsurface ﬂuid ﬂow, which in active tectonic regions is controlled by permeability of fault zones (moeck ). in that frame, the primary focus is on locating and characterizing faulted areas in geothermal ﬁelds. this study employs numerical modeling to allocate and quantify permeability anisotropies and discontinuities, e.g., faults, in order to understand their inﬂuence on subsurface ﬂuid ﬂow in geothermal reservoirs. numerical models have been increasingly used to understand the setup and productivity of geothermal systems. a general overview of geothermal models has been given by o’sullivan et al (). additionally, there are several sites exemplifying similar characteristics as in lahendong. the underground movement of hot and cold ﬂuids has been modeled for geothermal ﬁelds in new zealand (kaya et al ). the kakkonda geothermal site, e.g., consists of two reservoirs at various depths with different ﬂuid properties. there, results from ﬂuid ﬂow analysis show the importance of fractures for ﬂuid transport enhancing the recharge or discharge in the reservoir \x0c page  of  environ earth sci () : (mcguinness et al ). generally, faults acting as preferential ﬂuid path ways signiﬁcantly change the pressure and temperature ﬁeld in the reservoir (cherubini et al ). models for the seferihisar–balc¸ova ﬁeld focus on the ﬂuid ﬂow inside of faults. results show an enhanced upward heat transport through ﬂuids from bottom of the geothermal system (magri et al ). our test ground is the lahendong geothermal ﬁeld loc ...

# %%
#Read the file Stopwords
gist_file = open("gist_stopwords.txt", "r")
try:
    content = gist_file.read()
    stopwords = content.split(",")
finally:
    gist_file.close()

#Apply the Stopwords
pattern = r",*(\s*\b(?:{}))\b".format("|".join(stopwords))
text_stw = re.sub(pattern,'', text_punew_spdo_ovsp_ger_etal)

#effect of e.g.
text_stw = re.sub(r'(\.\.)','',text_stw)
text_stw

#eliminate fig
text_stw_fig = re.sub(r'(figure|fig.)\s+\d', '', text_stw)
text_stw_fig = re.sub(r'\(\)', '', text_stw_fig)
text_stw_fig
# Out:
# 'environ earth sci (2016) 75:1088 doi 10.1007/s12665-016-5878-9 permeability distribution lahendong geothermal ﬁeld: blind fault captured thermal–hydraulic simulation maren brehme1 guido blo¨cher1 mauro cacace1 yustin kamah2 martin sauter3 gu¨ nter zimmermann1 received: 24 november 2015 / accepted: 4 july 2016 / published online: 19 july 2016 ó springer-verlag berlin heidelberg 2016 abstract subsurface ﬂuid ﬂow reservoirs active tectonic regions controlled permeability fault zones. characterization fault zones step performance assessment reservoir. ﬂuid ﬂow controlled pressure temperature conditions. context simulated pressure temperature ﬁelds elaborate inﬂuence permeability subsurface ﬂuid ﬂow lahendong geothermal reservoir. thermal–hydraulic simulation performed ﬁnite element approach. adjusting permeability 370 cases, modeling converged observed data misﬁt range 0–7 %. ﬁtting models identiﬁed deep-seated fault traced surface. simulated temperature distribution suggests prominent convective heat ﬂow, driven upward migrating sw– oriented ﬂuid ﬂow. hydraulic gradient pressure drop reservoir. highpressure patterns constrain recharge areas addition inﬁltration measurements. discharge ﬂow occurs sw migrating upward hot springs. frame, thermal–hydraulic simulations identiﬁed unresolved subsurface faults & maren brehme brehme@gfz-potsdam. 1 helmholtz centre potsdam – gfz german centre geosciences, telegrafenberg, 14473 potsdam, germany 2 upstream technology center pertamina, jl. medan merdeka timur. 6, jakarta, indonesia 3 applied geology, university¨ttingen, goldschmidtstraße. 3, 37077¨ttingen, germany understanding subsurface permeability inﬂuence ﬂuid ﬂow. keywords permeable faults \x01 hydrogeology \x01 fluid ﬂow \x01 geothermal ﬁeld management \x01 reservoir engineering \x01 pressure drop introduction geothermal energy essential component supply future energy demands. requires developing geothermal sites improving performance existing systems satisfy continuously growing demand. productivity geothermal ﬁeld depends subsurface ﬂuid ﬂow active tectonic regions controlled permeability fault zones (moeck 2014). frame primary focus locating characterizing faulted areas geothermal ﬁelds. study employs numerical modeling allocate quantify permeability anisotropies discontinuities, faults order understand inﬂuence subsurface ﬂuid ﬂow geothermal reservoirs. numerical models increasingly understand setup productivity geothermal systems. general overview geothermal models’sullivan (2001). additionally sites exemplifying characteristics lahendong. underground movement hot cold ﬂuids modeled geothermal ﬁelds zealand (kaya 2014). kakkonda geothermal site, consists reservoirs depths ﬂuid properties. ﬂuid ﬂow analysis fractures ﬂuid transport enhancing recharge discharge reservoir 123\x0c1088 2 11 environ earth sci (2016) 75:1088 (mcguinness 1995). generally, faults acting preferential ﬂuid path ways signiﬁcantly change pressure temperature ﬁeld reservoir (cherubini 2013). models seferihisar–balc¸ova ﬁeld focus ﬂuid ﬂow inside faults. enhanced upward heat transport ﬂuids geothermal (magri 2011). test ground lahendong geothermal ﬁeld located sulawesi, indonesia. ﬁeld owned operated pertamina geothermal energy hosts power plant production capacity 80 mwe., geothermal exploration started early 1970s including geophysical geohydrochemical approaches. water-dominated magmatic structurally controlled. faults generally-fault ﬂuid barriers alongfault ﬂuid conductors (brehme 2014). result, hot springs vertically permeable faults surface. numerous drilling surface measurements allowed detailed characterization geological hydrogeological setting area (; brehme 2011, 2013, 2014, 2016; wiegand 2013). model presented developed investigating subsurface ﬂuid ﬂow permeability distribution including fault zones lahendong geothermal ﬁeld. geological structure ﬁeld presented introduction modeling approach. detailed investigation subsurface permeability distribu ...

# %% [markdown]
# ## SpaCy Sentences with Conditioning & Lemmatizer

# %%
#Splitted into sentences by Spacy
spc_text = spc(text_stw_fig)

#Prep []
ready = []
col_intro = []

for i,j in enumerate(spc_text.sents):
    if bool(re.search('(^\d|doi)',j.text.lower())) == True:
        pass
    elif bool(re.search('(acknowledgments|acknowledgment)',j.text.lower())) == True:
        stop_ack_stc = i
    elif bool(re.search('(references|reference)',j.text.lower())) == True:
        stop_ref_stc = i
    elif bool(re.search('(introduction)',j.text.lower())) == True:
        col_intro.append(i)
    else: 
        ready.append(j.text.lower())

#Cut Parts before Introduction
ready = ready[col_intro[0]:]

#Cut parts after the acknowledgments        
ready = ready[:stop_ack_stc]

#Cut parts after the references        
ready = ready[:stop_ref_stc]

# %%
ready
# Out:
# ['study employs numerical modeling allocate quantify permeability anisotropies discontinuities, faults order understand inﬂuence subsurface ﬂuid ﬂow geothermal reservoirs.',
#  'numerical models increasingly understand setup productivity geothermal systems.',
#  'general overview geothermal models’sullivan (2001).',
#  'additionally sites exemplifying characteristics lahendong.',
#  'underground movement hot cold ﬂuids modeled geothermal ﬁelds zealand (kaya 2014).',
#  'kakkonda geothermal site, consists reservoirs depths ﬂuid properties.',
#  'ﬂuid ﬂow analysis fractures ﬂuid transport enhancing recharge discharge reservoir 123\x0c1088 2 11 environ earth sci (2016) 75:1088 (mcguinness 1995).',
#  'generally, faults acting preferential ﬂuid path ways signiﬁcantly change pressure temperature ﬁeld reservoir (cherubini 2013).',
#  'models seferihisar–balc¸ova ﬁeld focus ﬂuid ﬂow inside faults.',
#  'enhanced upward heat transport ﬂuids geothermal (magri 2011).',
#  'test ground lahendong geothermal ﬁeld located sulawesi, indonesia.',
#  'ﬁeld owned operated pertamina geothermal energy hosts power plant production capacity 80 mwe., geothermal exploration started early 1970s including geophysical geohydrochemical approaches.',
#  'water-dominated magmatic structurally controlled.',
#  'faults generally-fault ﬂuid barriers alongfault ﬂuid conductors (brehme 2014).',
#  'result, hot springs vertically permeable faults surface.',
#  'numerous drilling surface measurements allowed detailed characterization geological hydrogeological setting area (; brehme 2011, 2013, 2014, 2016; wiegand 2013).',
#  'model presented developed investigating subsurface ﬂuid ﬂow permeability distribution including fault zones lahendong geothermal ﬁeld.',
#  'detailed investigation subsurface permeability distribution crucial step site selection smart drilling strategies.',
#  'numerical simulations presented provide insight understanding subsurface ﬂuid ﬂow hydraulic conductivity faults.',
#  'ensures productive sustainable operation geothermal ﬁelds avoiding risks drilling-fractured cold zones targeting highly corroding waters.',
#  'target area lahendong general workﬂow applicable geothermal sites consisting constraints.',
#  'reservoir characterization hydrogeology driving force ﬂuid ﬂow sw– oriented natural hydraulic gradient lahendong geothermal.',
#  'direction ﬂuid',
#  'ﬂow varies geothermal site horizontal partitioning reservoir permeable fault zones (brehme 2014).',
#  'basic sections located  topographic map study area geological features, water rock sample locations model cross 123\x0cenviron earth sci (2016) 75:1088 3 11 1088 south east beneath lake linau.',
#  'beneath lake linau direction ﬂuid ﬂow rotated wsw–ene ., types ﬂuid change acidic highly saline-type beneath lake linau neutral low saline-type south east lake linau .',
#  'impermeable structure faults prevent ﬂuids diluting (brehme 2016).',
#  ', faults permeable vertical axis recharge faults.',
#  'rainwater inﬁltrates fault sw.',
#  'lengkoan creek water inﬁltrates normal faults lake linau .',
#  'hydrothermal discharges lake linau driven hydraulic gradient (brehme 2014).',
#  'fracture network area characterized strike slip faults normal faults.',
#  'sinistral faults strike 40° steeply dip.',
#  'left step strike slip faults forms extension basin central study area.',
#  'normal faults extension basin strike nw dip 70°–80° beneath lake linau (brehme 2014).',
#  'lithology lahendong area characterized pre-, post- tondano formation plio- pleistocene age (koestono 2010).',
#  'rocks typically andesite, volcanic breccia tuff.',
#  'types sampled borehole cores determine porosity, permeability thermal conductivity.',
#  'effective porosity matrix permeability analyzed cylindrical-shaped specimen dimension 5 5 9 2.5 oriented parallel coring (brehme 2016).',
#  'thermal conductivity measured plain sections dried cores.',
#  'experimental setup consists gas permeameter determining matrix permeability (milsch 2011) helium pycnometry effective porosity measurements (johnson-maynard 1994) optical scanner thermal conductivity measurements (popov 1999).',
#  'parameters measured averaged rock types (brehme 2016; table 1).',
#  'andesite effective porosity 3.7 % permeability 2.1 9 10-14 thermal conductivity 1.8-1-1 (dry) 2.2-1-1 (saturated).',
#  'tuff porosity 7.7 % lowest permeability 2.0 9 10-15 1.6-1-1 (saturated).',
#  'volcanic breccia permeable layer effective porosity 10.5 % permeability 2.3 9 10-14 thermal conductivity 1.6-1-1 (dry) 2.5-1-1 (saturated).',
#  'reservoir rocks reﬂect generally low matrix permeability suggesting fracture-controlled ﬂuid ﬂow aquifer (brehme 2016).',
#  '(dry) 2.1-1-1 thermal conductivity model setup model geometry numerical models developed study area represent initial conditions reservoir production commercial ﬁnite injection start.',
#  'simulation,  cross modeled area geological structure, boundary conditions location observation points 123\x0c1088 4 11 environ earth sci (2016) 75:1088 table 1 thermal hydraulic parameters lahendong reservoir rocks measured laboratory (brehme 2016) sample (, depth) rock type effective porosity (%) thermal conductivity dry (-1-1) thermal conductivity saturated (-1-1) matrix permeability  lhd1 500–501 lhd1 801–802 lhd1 1000–1001 lhd1 2100–2101 lhd2 300–302 lhd3 2201–2203 lhd4 652–653 lhd4 850–852 lhd4 1001–1002 lhd4 2304–2305 lhd5 602–603 lhd5 752–753 lhd5 1102–1103 lhd5 1404–1406 lhd5 1575–1576 lhd7 901–902,3 lhd7 1567.8–1568 lhd7 1756–1758 average values andesite  breccia  tuff  1.1 14.5 5.0 7.2 12.5 5.7 6.3 1.6 16.4 1.6 16.3 2.7 5.2 3.6 0.6 4.6 11.0 3.9 3.7 10.5 7.7 (lhd1 550) 2.0 (lhd1 550) 2.2 1.6 1.8 1.4 2.1 1.8 1.4 1.8 1.4 1.9 1.5 1.6 2.1 1.8 1.6 1.6 2.4 2.2 2.0 2.4 2.0 2.7 2.7 2.3 2.3 1.7 2.2 2.7 2.2 2.5 2.1 1.5 9 10-14 8.9 9 10-16 3.3 9 10-15 6.1 9 10-14 1.5 9 10-14 1.3 9 10-14 2.3 9 10-14 6.8 9 10-14 3.4 9 10-16 1.1 9 10-14 1.1 9 10-16 7.9 9 10-14 3.0 9 10-15 7.9 9 10-18 7.2 9 10-16 1.7 9 10-15 1.7 9 10-14 2.1 9 10-14 2.3 9 10-14 2.0 9 10-15 element software feflow model pressuredriven thermally induced ﬂuid ﬂow including viscosity.',
#  'governing equations ﬂuid ﬂow heat transport saturated porous media derived conservation principles linear momentum, mass energy (dhi-wasy 2009).',
#  'details software parameterization diersch (2014).',
#  'model geometry 2d vertical sw– trending cross extending 6 horizontal 3 vertical direction.',
#  'direction proﬁle selected cover relevant processes lahendong geothermal ﬁeld: cuts major faults production injection wells temperature pressure calibration.',
#  'groundwater ﬂow direction, showing major ﬂuid ﬂow activities.',
#  'homogeneous isotropic geological layers model stratiﬁed horizontally.',
#  'faults middle model, striking perpendicular cross, dip 84° cooling pluton beneath lake linau.',
#  'details structural geological components modeled region presented brehme (2014).',
#  'parallel numerical mesh simulation feflow consists 45,264 nodes 89,320 elements denser surrounding faults expected gradients parameter contrasts.',
#  'material properties 123 elements permeability, porosity thermal conductivity set laboratory measurements (table 1)., properties faults lake linau adapted speciﬁc conditions.',
#  'definitions modeled grids faults: porosity 30 % thermal conductivity 1.8-1-1.',
#  'grids lake linau deﬁned porosity 100 % thermal conductivity 0.6-1-1.',
#  'model simulates ﬂuid ﬂow thermal transport saturated media steady state.',
#  'initial values boundary conditions fluid ﬂow boundary conditions model groundwater heads recharge amounts (table 2; ).',
#  'hydraulic head sw model boundary 837 500 boundary.',
#  'sw hydraulic head represents inﬁltration surface water fault, striking perpendicular model.',
#  'hydraulic head border adapted borehole measurements area (brehme 2014).',
#  'inﬁltration fault zones lake linau ﬂuid ﬂux boundary conditions.',
#  'quantity 3.0 9 10-4-1 sw 1.3 9 10-6-1 fault distributed 40 fault width.',
#  'groundwater recharge set 412 mm-1 surface (table 2; ).',
#  'fluid movement model domain constrained-ﬂow boundary, recharge surrounding fault zones low hydraulic heads model area.',
#  'discharge central study area lake linau model boundary.',
#  'initial hydraulic head model domain 500.',
#  'heat 116 °-1 transport boundary conditions time-invariant, ﬁxed temperatures heat ﬂux (table 2; ).',
#  'thermal gradient sw model boundary temperature constant 350 ° pluton.',
#  'temperature water inﬁltrating faults mixing shallow warm groundwater 70 ° surface groundwater recharge 28 °.',
#  'temperature values ﬁeld bore log measurements (brehme 2014).',
#  'heat ﬂux set 100 mw-2 model boundary (table 2; ).',
#  'ﬁxed based studies delisle (1998), nagao uyeda (1995) neben (1998).',
#  'initial temperature model domain set 116 °-1 local thermal gradient.',
#  'permeability determination initial values permeability deﬁned based laboratory measurements (table 1).',
#  'simulation, modeled measured temperature pressure values compared observation points.',
#  'case poor matching (errors [10 %), permeability adjusted satisfactory achieved.',
#  'beneath lake linau, simulation locally strong discrepancies modeled measured pressure temperature (errors [45 %).',
#  'adjustment permeability geological inﬁltration rates faults hydraulic heads lead acceptable.',
#  'implementation strong permeability anisotropy depth additional fault minimization errors (0–7 %).',
#  'implementation accomplished mesh adaptation ensure behavior fault.',
#  'procedure, permeability anisotropies located characterized model.',
#  'layers general, deﬁning direction-dependent permeability improves data ﬁt permeabilities directions.',
#  'fractures increasing permeability vertical direction.',
#  'porosity thermal conductivity remained constant simulation.',
#  'variation porosity negligible directly reﬂected permeability thermal conductivity differences affect conductive heat transport dominant lahendong area (ondrak 1998; brehme 2014).',
#  'relative permeability refers permeabilities horizontal vertical direction.',
#  'main result blind fault recognized beneath lake linau studies.',
#  'simulated pressure temperature measured ﬁve selected observation points represent boreholes bore logs pressure temperature.',
#  'details data .',
#  'model data ﬁt 370 models considered generate ﬁnal model developed lahendong.',
#  'permeability distribution identiﬁcation blind fault distribution permeability patterns reservoir conceived comparing temperature pressure data wells.',
#  'beneath lake linau, closely located wells high variations temperature pressure.',
#  'drop 100 ° 18 bar 300 distance observed lhd 24 lhd 28.',
#  'models ﬁrst high discrepancies modeled measured values area.',
#  'implementing high anisotropic permeable structure observation points, models satisfactory.',
#  'structure times higher vertical environ earth sci (2016) 75:1088 permeability horizontal permeability.',
#  'structure assumed fault zone located faults vertical dip nw strike.',
#  'fault trace surface covered lake linau.',
#  'generally, modeled permeability distribution lahendong reservoir direction-dependent overprints lithology.',
#  'modeled permeability generally higher measured order magnitudes.',
#  'fracture patterns detectable core-sample scale.',
#  'permeability patterns directly affect subsurface ﬂuid ﬂow temperature pressure distribution.',
#  'permeability faulted zones surroundings lowest study area.',
#  'middle fault shallow area beneath sw lake linau deep fault low permeabilities 10-13 10-14 .',
#  'area middle fault deep sw fault sw fault model area sw boundary higher permeabilities 10-10 10-12 .',
#  'permeability varies modeled area vertical horizontal direction.',
#  'faults deep reservoir, permeability factor 10 higher vertical direction horizontal direction .',
#  'areas faults, permeability parts factor 10–100 lower vertical direction.',
#  'rest model, vertical horizontal permeability differ .',
#  ' final adapted permeability anisotropy distribution model domain.',
#  'anisotropy relation vertical horizontal permeability anisotropy [1 vertical permeability higher horizontal permeability 123\x0cenviron earth sci (2016) 75:1088 7 11 1088',
#  ' modeled temperature pressure distribution study area high-pressure ﬁelds sw convective heat transport rising hot ﬂuids inﬁltration cooler water faults pressure distribution pressure distribution study area controlled groundwater ﬂow low permeable rocks vertically high permeable fault zones.',
#  'isobars drop natural hydraulic gradient sw.',
#  'sw higher pressures caused inﬁltration higher elevations sw.',
#  'wells existing region artesian-type.',
#  'overpressure releases high permeable zones beneath lake linau discharges surface.',
#  'pressure drop 20 bars faults .',
#  'temperature distribution temperature distribution lahendong geothermal reservoir suggests convective heat transport dominating process reservoir rocks.',
#  'isotherms generally follow sw– oriented ﬂow pattern rise inﬁltration ﬂuids.',
#  'upwelling isotherms faults veriﬁes water rise lake linau.',
#  'inﬁltration cold water welling isotherms northeast model.',
#  'temperature locally increased model surrounding pluton .',
#  'subsurface ﬂuid ﬂow absolute horizontal/vertical permeability distribution controls local ﬂuid ﬂow lahendong reservoir.',
#  'general ﬂuid ﬂow, driven natural pressure gradient oriented sw.',
#  'vertical inﬁltration occurs faults lake linau sw boundary.',
#  'discharge model boundary .',
#  'detailed ﬂow patterns observed streamlines ﬂuid ﬂow highly permeable areas.',
#  'calculated streamlines particle ﬂow model domain.',
#  'forward calculation inﬁltrating water sw model boundary distributes reservoir.',
#  'backward calculation source ﬂuid particles arriving model boundary .',
#  'patterns hot groundwater ﬂows faults beneath lake linau ﬂuid ﬂow disturbed rise temperature vertically high permeable layers.',
#  'rise groundwater model area (red forward streamlines ).',
#  'time, cold water inﬁltrates high permeable areas distributes model domain (blue backward streamlines ).',
#  'composition reservoir domain dominated coldwater inﬁltration faults production areas characterized hot water ﬂow .',
#  'discussion investigation subsurface ﬂuid ﬂow geothermal reservoirs crucial sustainable exploitation avoiding drilling productive areas.',
#  'subsurface ﬂuid ﬂow locally inﬂuenced fault zones physical 123\x0c1088 8 11 environ earth sci (2016) 75:1088  model domain calculated streamlines red: forward streamlines follow hydraulic gradient sw model boundary blue: backward streamlines representing inﬁltrating cold water ﬂowing model boundary properties water ( viscosity).',
#  'inﬂuence parameters ﬂuid ﬂow investigated lahendong geothermal reservoir hydraulic–thermal simulations.',
#  'simulation detailed permeability distribution reservoir including location additional fault zone.',
#  'matching measured simulated temperature pressure tool resolving permeability distribution.',
#  'temperature pressure iteratively determined observation points .',
#  'generally, modeled values good agreement observed .',
#  'observation points values pressure temperature (lhd 4 lhd 7) temperature (lhd 24).',
#  'complicated ﬂow processes strong small-scale structural variation fractured faulted areas., density variations included simulation high temperatures variation ﬂuid pressure.',
#  'average deviation simulated pressure temperature 1 %.',
#  'implemented model parameters porosity, permeability heat conductivity.',
#  'parameters permeability tested speciﬁc range simulation.',
#  'inﬂuence porosity heat conductivity ﬂuid ﬂow negligible dominating convective heat ﬂow (ondrak 1998).',
#  'values implemented model based measured permeabilities represent matrix permeability rocks.',
#  'measured matrix permeability, representing permeability horizontal direction 1.5 9 10-14 123 average remains typical permeability range fractured igneous rocks (scho¨ 2004).',
#  'permeability volcanic breccias ranges typically 3 9 10-15 5 9 10-12 tuff permeabilities range 7 9 10-17 7 9 10-12 (klavetter peters 1987).',
#  'wairakei geothermal ﬁeld, simulating impermeable layers permeabilities 10-18 10-14 horizontal vertical axis (mercer faust 1979).',
#  ', permeability reservoir rocks locally increased fracture formation.',
#  'decreased alteration sealing faults.',
#  'lahendong, modeled permeability magnitudes higher measured faulted areas.',
#  'caused fractures detectable core scale.',
#  'fault cores factor 10 higher vertical direction horizontal direction.',
#  'areas faults (fault gauge), permeability parts factor 10–100 lower vertical direction.',
#  'adaptation permeability ensures ﬁt measured temperature pressure data.',
#  'permeability fractured areas main factor inﬂuencing subsurface ﬂuid ﬂow temperature distribution lahendong reservoir area.',
#  'subsurface ﬂuid ﬂow driven local hydraulic heads high variations sections study area., convective heat distribution leads high temperature variation reservoir.',
#  'phenomena observed lahendong comparable ﬁelds.',
#  'mexico, water level drops 30–100 observed (haneberg 1995).',
#  'high fault zones\x0c123 environ earth sci (2016) 75:1088 9 11 1088 7 24 4 28 5 lhd 4 lhd 5 lhd 7 lhd 24 lhd 28 reservoir depth [] surface 1400 1750 2100 1820 1800 110 120 130 140 400 modelled pressure [bar] 150 140 130 120 110 modelled pressure [bar] 100 100 lhd 5 lhd 28 lhd 7 lhd 4 lhd 24 drilling bore log completed oct 1985 jan 86 1986 jul 2000 jul 96 oct 1987 jul 09 jul 09 aug 09 aug 09 lhd 4 lhd 5 lhd 7 lhd 24 lhd 28 150 200 250 300 350 400 modelled temperature [°] 400 350 300 250 200 150 measured temeprature [°] 100 100  modeled versus measured temperature pressure selected observation points.',
#  'speciﬁcations measured data brehme (2014) temperature drops upwelling isotherms fault zones control ﬂuid ﬂow lake long valentine ﬁelds, usa (hooper 1991).',
#  'analysis ﬂuid pressure differences alpine fault zealand, allowed characterize change permeability hanging footwall blocks (sutherland 2012).',
#  'summary, high pressure temperature gradients indicators ﬂuid barriers observation points., reservoir sections properties separated horizontally permeable faults.',
#  'lahendong signiﬁcant ﬂuid barriers faults sw lake linau.',
#  'barriers pressure drops 20 bars.',
#  'pattern measured bore logs beneath lake linau surface trace fault observed studies.',
#  'implementing fault, modeled measured values adapted.',
#  'identiﬁed fault zone beneath lake linau remains lake water traceable kind reservoir modeling.',
#  'additionally fault identiﬁcation internal structure fault zones understood.',
#  'fault displacement 2 depth.',
#  'detailed trend understood permeability adaptation area.',
#  'low permeability horizontal direction faults, ﬂuids propagate vertically hot springs surface.',
#  'surface water inﬁltrate reservoir case pressure fault zone low .',
#  'vertical ﬂuid movement eventually controls temperature distribution reservoir.',
#  'upward migration deep hot water increases temperature inﬁltration cold surface water local drop temperature.',
#  'summary factors inﬂuencing reliability numerical reservoir models absolute horizontal vertical permeability.',
#  'permeability adaptation geological layer; vertical permeability anomalies overprinting layers constraining regional groundwater ﬂow.',
#  'permeabilities fractures directly inﬂuence productivity reservoir (cherubini 2013).',
#  'permeability characteristics investigated.',
#  'previous study numerical model lahendong site set tough2 aimed forecasting reservoir behavior exploitation year 2036.',
#  'production 60 mwe predicts pressure drop 10 bars.',
#  'forecast uncertain lack measured pressure draw data (yani 2006).',
#  'steps presented study include realistic production injection scenario order reservoir exploitation., chemical characteristics considered achieve reliable production setups hydrochemical processes play role lahendong reservoir (brehme 2016).',
#  'presented models study provide ﬂuid ﬂow water-dominated lahendong reservoir.',
#  ', additional-phase ﬂow models support sustainable\x0c1088 10 11 environ earth sci (2016) 75:1088 lahendong area progress understand inﬂuence steam driven ﬂuid ﬂow high-temperature.',
#  'conclusion primary focus study understand inﬂuence fault zones permeability patterns subsurface ﬂuid ﬂow geothermal reservoirs.',
#  'ﬂuid ﬂow depends rock fault zone permeability.',
#  'processes considered numerical models simulate local temperature pressure conditions.',
#  'initial reservoir conditions refers case production starts.',
#  'models developed based conceptual models study area explain reservoir geometry, geological structures, temperature hydraulic conditions.',
#  'temperature pressure-logs model calibration.',
#  'numerical models represent vertical horizontal ﬂuid ﬂow controlled fault permeability.',
#  'characteristic simulate reservoir sections vertical ﬂuid rise surface.',
#  'stepwise adaptation permeability ﬁelds, based observed temperature pressure gradients additional blind fault zone identiﬁed beneath lake linau.',
#  'temperature pressure signiﬁcantly drop ﬂuid barrier.',
#  'behavior observed comparable ﬁelds usa. shape ﬂuid ﬂow direction trends sw– direction.',
#  'main recharge occurs inﬁltration surface water faults southwest lake linau.',
#  'discharge enhanced highly fractured areas lake linau.',
#  'vertical permeability faults ﬂuids rising hot springs surface.',
#  'permeability considered simulation geothermal.',
#  'geothermal controlled ﬂuid ﬂow fractures/faults depending temperature pressure conditions.',
#  'locally modiﬁed ﬂuid ﬂow considerably inﬂuence productivity geothermal ﬁeld.',
#  'guide reservoir management case potential ﬁeld extension performed lahendong.',
#  'huenges milsch.',
#  'peters.',
#  'fuchs assisting interpretation data.',
#  'special gratitude.',
#  'bulut carefully reviewed manuscript care linguistic issues supported analysis helpful discussions.',
#  'prof hochstein greatly acknowledged continuous fruitful discussions study.',
#  'support team pertamina geothermal energy jakarta lahendong including access data ﬁeld 123 highly appreciated.',
#  'authors pge permission publish paper.',
#  'german federal ministry education (bmbf) funding german project ‘‘sustainability concepts exploitation geothermal reservoirs indonesia—capacity building methodologies site deployment’’ grant 03g0753a.',
#  'mineral mag 75:577 brehme, haase, regenspurg, moeck, deon, wiegand, kamah, zimmermann, sauter (2013) hydrochemical patterns structurally controlled geothermal.',
#  'geothermics 51:228–239.',
#  'grundwasser 21:29–41.',
#  'environ earth sci 70:3603–3618.',
#  'geol soc lond spec publ 137:267–274.',
#  'springer, berlin 996 dwd, deutscher wetterdienst (2007) offenbach/main.://. dwd./. accessed june 2012 haneberg wc (1995) steady state groundwater ﬂow idealized faults.',
#  'water resour res 31:1815–1820 hooper ecd (1991) fluid migration growth faults compacting sediments.',
#  'die allgemeine und angewandte hydrogeologie.',
#  'springer, berlin johnson-maynard, anderson, green, graham (1994) physical hydraulic properties weathered granitic rock southern california.',
#  'soil sci 158:375–380 kaya’sullivan mj, hochstein mp (2014) dimensional numerical model waiotapu, waikite reporoa geothermal areas zealand.',
#  'volcanol geotherm res 283:127–142.',
#  'project-report, nevada nuclear waste storage investigations project koestono, siahaan, silaban, franzson (2010) geothermal model: proceedings geothermal congress 2010, bali, indonesia, 25–29 april 2010 lahendong geothermal ﬁeld, indonesia.',
#  'magri, akar, gemici, pekdeger (2011) numerical fault-induced seawater circulation investigations\x0cenviron earth sci (2016) 75:1088 11 11 1088 seferihisar–balc¸ova geothermal, western turkey.',
#  'hydrogeol 20:103–118.',
#  'geothermics 24:1–48.',
#  'application liquid- vapor-dominated hydrothermal modeling techniques wairakei zealand.']

# %%
#Auto Read entities
dict_entities={}
path='C:/Users/Ryan Bobby A/Documents/RWTH AACHEN/KULIAH/THESIS_BISMILLAH/Thesis Progress/list_entities/'
for filename in glob.glob(os.path.join(path, '*.txt')):
    gist_file = open(filename, "r")
    try:
        content = gist_file.read().lower()
        dict_entities[re.search(r'(\w+).txt$',filename).group(1)] = content.split("\n")
    finally:
        gist_file.close()
dict_entities
# Out:
# {'list_chrono': ['precambrium',
#   'hadean',
#   'archean',
#   'eoarchean',
#   'paleoarchean',
#   'mesoarchean',
#   'neoarchean',
#   'proterozoic',
#   'paleoproterozoic',
#   'siderian',
#   'rhyacian',
#   'orosirian',
#   'satherian',
#   'mesoproterozoic',
#   'calymmian',
#   'ectasian',
#   'stenian',
#   'neoproterozoic',
#   'tonian',
#   'cryogenian',
#   'ediacaran',
#   'phanerozoic',
#   'paleozoic',
#   'cambrian',
#   'terreneuvian',
#   'fortunian',
#   'cambrian stage 2',
#   'cambrian series 2',
#   'cambrian stage 3',
#   'cambrian stage 4',
#   'cambrian series 3',
#   'cambrian stage 5',
#   'drumian',
#   'guzhangian',
#   'furongian',
#   'paibian',
#   'jingshanian',
#   'stage 10',
#   'ordovician',
#   'lower ordovician',
#   'tremadocian',
#   'floian',
#   'middle ordovician',
#   'dapingian',
#   'darriwilian',
#   'upper ordovician',
#   'sandbian',
#   'katian',
#   'hirnantian',
#   'silurian',
#   'llandovery',
#   'rhuddanian',
#   'aeronian',
#   'telychian',
#   'wenlock',
#   'sheinwoodian',
#   'homerian',
#   'ludlow',
#   'gorstian',
#   'ludfordian',
#   'pridoli',
#   'devonian',
#   'lower devonian',
#   'lochkovian',
#   'pragian',
#   'emsian',
#   'middle devonian',
#   'eifelian',
#   'givetian',
#   'upper devonian',
#   'frasnian',
#   'famennian',
#   'carboniferous',
#   'mississippian',
#   'lower mississippian',
#   'tournaisian',
#   'middle mississippian',
#   'visean',
#   'upper mississippian',
#   'serpukhovian',
#   'pennsylvanian',
#   'lower pennsylvanian',
#   'bashkirian',
#   'middle pennsylvanian',
#   'moscovian',
#   'upper pennsylvanian',
#   'kasimovian',
#   'gzhelian',
#   'permian',
#   'cisuralian',
#   'asselian',
#   'sakmarian',
#   'artinskian',
#   'kungurian',
#   'guadalupian',
#   'roadian',
#   'wordian',
#   'capitanian',
#   'lopingian',
#   'wuchiapingian',
#   'changhsingian',
#   'mesozoic',
#   'triassic',
#   'lower triassic',
#   'induan',
#   'olenekian',
#   'middle triassic',
#   'anisian',
#   'ladinian',
#   'upper triassic',
#   'carnian',
#   'norian',
#   'rhaetian',
#   'jurassic',
#   'lower jurassic',
#   'hettangian',
#   'sinemurian',
#   'pliensbachian',
#   'toarcian',
#   'middle jurassic',
#   'alenian',
#   'bajocian',
#   'bathonian',
#   'callovian',
#   'upper jurassic',
#   'oxfordian',
#   'kimmeridgian',
#   'tithonian',
#   'cretaceous',
#   'lower cretaceous',
#   'berriasian',
#   'valanginian',
#   'hauterivian',
#   'barremian',
#   'aptian',
#   'albian',
#   'upper cretaceous',
#   'cenomanian',
#   'turonian',
#   'coniacian',
#   'santonian',
#   'campanian',
#   'maastrichtian',
#   'cenozoic',
#   'paleogene',
#   'paleocene',
#   'danian',
#   'selandian',
#   'thanetian',
#   'eocene',
#   'ypresian',
#   'lutetian',
#   'bartonian',
#   'priabonian',
#   'oligocene',
#   'rupelian',
#   'chattian',
#   'neogene',
#   'miocene',
#   'aquitanian',
#   'burdigalian',
#   'langhian',
#   'serravallian',
#   'tortonian',
#   'messinian',
#   'pliocene',
#   'zanclean',
#   'piacenzian',
#   'quaternary',
#   'pleistocene',
#   'gelasian ',
#   'calabrian ',
#   'middle pleistocene',
#   'upper pleistocene',
#   'holocene'],
#  'list_countries': ['afghanistan',
#   'aland islands',
#   'albania',
#   'algeria',
#   'american samoa',
#   'andorra',
#   'angola',
#   'anguilla',
#   'antarctica',
#   'antigua and barbuda',
#   'argentina',
#   'armenia',
#   'aruba',
#   'australia',
#   'austria',
#   'azerbaijan',
#   'bahamas',
#   'bahrain',
#   'bangladesh',
#   'barbados',
#   'belarus',
#   'belgium',
#   'belize',
#   'benin',
#   'bermuda',
#   'bhutan',
#   'bolivia, plurinational state of',
#   'bonaire, sint eustatius and saba',
#   'bosnia and herzegovina',
#   'botswana',
#   'bouvet island',
#   'brazil',
#   'british indian ocean territory',
#   'brunei darussalam',
#   'bulgaria',
#   'burkina faso',
#   'burundi',
#   'cambodia',
#   'cameroon',
#   'canada',
#   'cape verde',
#   'cayman islands',
#   'central african republic',
#   'chad',
#   'chile',
#   'china',
#   'christmas island',
#   'cocos (keeling) islands',
#   'colombia',
#   'comoros',
#   'congo',
#   'congo, the democratic republic of the',
#   'cook islands',
#   'costa rica',
#   "côte d'ivoire",
#   'croatia',
#   'cuba',
#   'curaçao',
#   'cyprus',
#   'czech republic',
#   'denmark',
#   'djibouti',
#   'dominica',
#   'dominican republic',
#   'ecuador',
#   'egypt',
#   'el salvador',
#   'equatorial guinea',
#   'eritrea',
#   'estonia',
#   'ethiopia',
#   'falkland islands (malvinas)',
#   'faroe islands',
#   'fiji',
#   'finland',
#   'france',
#   'french guiana',
#   'french polynesia',
#   'french southern territories',
#   'gabon',
#   'gambia',
#   'georgia',
#   'germany',
#   'ghana',
#   'gibraltar',
#   'greece',
#   'greenland',
#   'grenada',
#   'guadeloupe',
#   'guam',
#   'guatemala',
#   'guernsey',
#   'guinea',
#   'guinea-bissau',
#   'guyana',
#   'haiti',
#   'heard island and mcdonald islands',
#   'holy see (vatican city state)',
#   'honduras',
#   'hong kong',
#   'hungary',
#   'iceland',
#   'india',
#   'indonesia',
#   'iran, islamic republic of',
#   'iraq',
#   'ireland',
#   'isle of man',
#   'israel',
#   'italy',
#   'jamaica',
#   'japan',
#   'jersey',
#   'jordan',
#   'kazakhstan',
#   'kenya',
#   'kiribati',
#   "korea, democratic people's republic of",
#   'korea, republic of',
#   'kuwait',
#   'kyrgyzstan',
#   "lao people's democratic republic",
#   'latvia',
#   'lebanon',
#   'lesotho',
#   'liberia',
#   'libya',
#   'liechtenstein',
#   'lithuania',
#   'luxembourg',
#   'macao',
#   'macedonia, republic of',
#   'madagascar',
#   'malawi',
#   'malaysia',
#   'maldives',
#   'mali',
#   'malta',
#   'marshall islands',
#   'martinique',
#   'mauritania',
#   'mauritius',
#   'mayotte',
#   'mexico',
#   'micronesia, federated states of',
#   'moldova, republic of',
#   'monaco',
#   'mongolia',
#   'montenegro',
#   'montserrat',
#   'morocco',
#   'mozambique',
#   'myanmar',
#   'namibia',
#   'nauru',
#   'nepal',
#   'netherlands',
#   'new caledonia',
#   'new zealand',
#   'nicaragua',
#   'niger',
#   'nigeria',
#   'niue',
#   'norfolk island',
#   'northern mariana islands',
#   'norway',
#   'oman',
#   'pakistan',
#   'palau',
#   'palestinian territory, occupied',
#   'panama',
#   'papua new guinea',
#   'paraguay',
#   'peru',
#   'philippines',
#   'pitcairn',
#   'poland',
#   'portugal',
#   'puerto rico',
#   'qatar',
#   'réunion',
#   'romania',
#   'russian federation',
#   'rwanda',
#   'saint barthélemy',
#   'saint helena, ascension and tristan da cunha',
#   'saint kitts and nevis',
#   'saint lucia',
#   'saint martin (french part)',
#   'saint pierre and miquelon',
#   'saint vincent and the grenadines',
#   'samoa',
#   'san marino',
#   'sao tome and principe',
#   'saudi arabia',
#   'senegal',
#   'serbia',
#   'seychelles',
#   'sierra leone',
#   'singapore',
#   'sint maarten (dutch part)',
#   'slovakia',
#   'slovenia',
#   'solomon islands',
#   'somalia',
#   'south africa',
#   'south georgia and the south sandwich islands',
#   'spain',
#   'sri lanka',
#   'sudan',
#   'suriname',
#   'south sudan',
#   'svalbard and jan mayen',
#   'swaziland',
#   'sweden',
#   'switzerland',
#   'syrian arab republic',
#   'taiwan, province of china',
#   'tajikistan',
#   'tanzania, united republic of',
#   'thailand',
#   'timor-leste',
#   'togo',
#   'tokelau',
#   'tonga',
#   'trinidad and tobago',
#   'tunisia',
#   'turkey',
#   'turkmenistan',
#   'turks and caicos islands',
#   'tuvalu',
#   'uganda',
#   'ukraine',
#   'united arab emirates',
#   'united kingdom',
#   'united states',
#   'united states minor outlying islands',
#   'uruguay',
#   'uzbekistan',
#   'vanuatu',
#   'venezuela, bolivarian republic of',
#   'viet nam',
#   'virgin islands, british',
#   'virgin islands, u.s.',
#   'wallis and futuna',
#   'yemen',
#   'zambia',
#   'zimbabwe'],
#  'list_eon': ['precambrium', 'phanerozoic', 'archaean', 'proterozoic'],
#  'list_era': ['hadean',
#   'archean',
#   'proterozoic',
#   'paleozoic',
#   'mesozoic',
#   'cenozoic'],
#  'list_geolocation': ['southern urals',
#   'kuznetsk alatau',
#   'berikul region',
#   'klyuchovsky volcano',
#   'kamchatka',
#   'rockport',
#   'belokurikhinsky massif',
#   'altai',
#   'val verde',
#   'porterville',
#   'frederick',
#   'maryland',
#   'westerly',
#   'westfield',
#   'peninsula station',
#   'ont.',
#   'vinal haven',
#   'maine',
#   'barre',
#   'farm doornspruit',
#   'sylmar',
#   'french creek',
#   'stillwater igneous complex',
#   'new glasgow',
#   'mellen',
#   'pilansberg',
#   'balsam gap',
#   'allentown',
#   'bethlehem',
#   'nazareth',
#   'pennsylvania',
#   'pelham',
#   'proctor',
#   'solnhofen',
#   'offshore louisiana',
#   'texas',
#   'kyushu',
#   'mie',
#   'aichi',
#   'kyoto',
#   'oklahoma',
#   'fukushima',
#   'colorado',
#   'iwate',
#   'utah',
#   'wyoming',
#   'hokkaido',
#   'oregon',
#   'twin sisters mountain',
#   'madneuli',
#   'shaori reservoir',
#   'akhalkalaki highlands',
#   'karatsu',
#   'ichinomegata',
#   'horoman',
#   'chiatura',
#   'central asia',
#   'dzirula massif',
#   'jraber',
#   'upper rhine graben',
#   'black forest',
#   'vosges',
#   'upper rhine graben',
#   'koytas',
#   'kandygatay mts.',
#   'kalbinsky massif',
#   'shindinsky massif',
#   'southwest german molasse basin',
#   'south arne',
#   'north sea',
#   'near freiburg',
#   'black forest',
#   'near offenburg',
#   'tyger-tysh ridge',
#   'ulen-tuimsky massif',
#   'uybatsky massif',
#   'karymsky volcano',
#   'kamtchatka',
#   'mid-atlantic ocean ridge',
#   'hawaii',
#   'cerro prieto',
#   'mexicali',
#   'ohio',
#   'kentucky',
#   'west virginia',
#   'idaho',
#   'higo metamorphic belt',
#   'hadaki metamorphic belt',
#   'beni bouchera massif (beni bouzere)',
#   'ivrea zone',
#   'lofoten-vesteralen region',
#   'austvagoya',
#   'langoya',
#   'salem',
#   'mysore',
#   'pallavaram',
#   'madras',
#   'chennai',
#   'tamil nadu',
#   'podili',
#   'kurnool',
#   'andhra pradesh',
#   'vinukonda',
#   'guntur',
#   'vijayawada',
#   'kondapalli',
#   'hyderabad',
#   'yellandalpad',
#   'yellandu',
#   'manditog',
#   'waltair',
#   'visakhapatnam',
#   'maharashtra',
#   'talchir',
#   'chaibasa',
#   'bundelkhand',
#   'south uttar',
#   'north madhya pradesh',
#   'bihar',
#   'kishengarh',
#   'rajasthan',
#   'rajputana',
#   'shahabad',
#   'sujarghar',
#   'halemaumau',
#   'hawaii island',
#   'hualai flow',
#   'india',
#   'maui island',
#   'salt lake crater',
#   'oahu island',
#   'honolulu',
#   'kauai',
#   'molokai or niihau island',
#   'scotland',
#   'sendai',
#   'miyagi prefecture',
#   'hagino',
#   'yamagata prefecture',
#   'nishimonai',
#   'akita prefecture',
#   'tanohata',
#   'iwate prefecture',
#   'transvaal',
#   'usa',
#   'south africa',
#   'hengill',
#   'nesja-vellir',
#   'krafla',
#   'kazakhstan',
#   'caucasus',
#   'pavlovsk',
#   'reunion island',
#   'oskoletsk',
#   'voronezh anteclise',
#   'saltykov',
#   'voronezh massif',
#   'north karelia',
#   'sakhalin island',
#   'mamonov complex',
#   'voronezh massif',
#   'gorky oblast',
#   'oblast of nishni novgorod',
#   'south ural mountains',
#   'ussr far east',
#   'ural',
#   'monchegorsk',
#   'kola peninsula',
#   'pechenga',
#   'seychelles',
#   'gegam plateau',
#   'bezumskiy ridge',
#   'sikhote-alin-ridge',
#   'gorky complex',
#   'udzha river',
#   'indian ocean ridge',
#   'indian ocean island',
#   'referred to as gondwana island',
#   'armenia',
#   'borisov volcano',
#   'baikal region',
#   'avachinsk volcano',
#   'lake baikal',
#   'obnazhennaya formation',
#   'southeast corner of þingvallavatn',
#   'surtsey',
#   'heimaey',
#   'reykjanes',
#   'sandfell',
#   'þrengsli',
#   'vigdísarvelli',
#   'tófubruna hyaloclastited',
#   'vigdísarvellir',
#   'reykjanes',
#   'krísuvík road',
#   'silfurberg',
#   'north of kögunarhóll',
#   'ingólfsfjall quarry',
#   'votuklettar-threngsli',
#   'slightly west of votuklettar',
#   'hyaloclastite',
#   'north of tindafjalla',
#   'west of kirkjufellsós',
#   'raudhnukar',
#   'bláfjalla',
#   'hafnarfjardar',
#   'west',
#   'hveradalaskálinn',
#   'dómadalur',
#   'þjórsárholt',
#   'vörðufell',
#   'hellisskarð',
#   'hengill',
#   'fossá',
#   'krókagiljabrún',
#   'lambafitjahraun',
#   'valahnúkar',
#   'valahnúkar on dómadalsroute',
#   'gaukshöfdi',
#   'idntaeknistofnun',
#   'hyaloclastite',
#   'reykholt',
#   'mosfellsbaer',
#   'reykholt biskupstungur',
#   'thjorsárdalur',
#   'miðfell',
#   'dolerite',
#   'kollafjordur',
#   'laugardalshellir',
#   'stora dímon',
#   'arnarfell',
#   'skefilsfjoll eldri',
#   'skefilsfjoll yngri',
#   'meðalfell',
#   'baejargil',
#   'blákollur',
#   'iceland',
#   'helgafell',
#   'arnarthufa',
#   'vifilfell',
#   'awibengkok',
#   'groß schönebeck',
#   'geitafell volcano',
#   'krafla',
#   'volcano',
#   'evrona',
#   'gerofit',
#   'ora',
#   'samar',
#   'zihor',
#   'well sinaf-1',
#   'tamardol',
#   'well ramon-1',
#   'well avdat-1',
#   'en yorq',
#   'hevyon',
#   'ghareb',
#   'avnon',
#   'mishash',
#   'nezer',
#   'shivta',
#   'well maka-36',
#   'menuha',
#   'tamar',
#   'well hmch-1',
#   'well hm-1',
#   'taqiye',
#   'well daya-1',
#   'well hltza-2',
#   'well hzrm-1',
#   'well bshev-1',
#   'well gurim-3',
#   'well zhrd-8',
#   'well zohar-1',
#   'well dshet-1',
#   'well hlz-2',
#   'well hlz-37',
#   'well negba-1',
#   'karnei-hitin volcano',
#   'weiss-kaul',
#   'west of rümelingen',
#   'belvaux',
#   'giele botter',
#   'profile kinett',
#   'east of moutfort',
#   'rebierg',
#   'züschschiefer',
#   'kirchberg',
#   'grouft',
#   'wasserbillig vormann',
#   'mersch',
#   'ell',
#   'rosswinkel',
#   'everlange',
#   'wartenstein',
#   'martelange',
#   'ingeldorf',
#   'radelange',
#   'reisdorf',
#   'stolzemburg',
#   'schüttburg',
#   'mirwart',
#   'ardennes',
#   'clerf',
#   'berlé',
#   'wiltz',
#   'sainthubert',
#   'villé',
#   'oignies',
#   'la gleize',
#   'bihain',
#   'fépin',
#   'meuville',
#   'colanhan',
#   'lierneux',
#   'les plattes',
#   'hour',
#   'grand halleux',
#   'wanne',
#   'la venne',
#   'spa',
#   'solwaster',
#   'belleaux',
#   'east pacific rise',
#   'schwerin',
#   'neubrandenburg',
#   'stralsund',
#   'pan-african damara',
#   'alps',
#   'lachlan fold belt',
#   'namaqua mobile belt',
#   'jequié',
#   'penokean orogen',
#   'jequie complex',
#   'new hampshire',
#   'galicia-tras-os-montes zone',
#   'naraku batholith',
#   'mount isa',
#   'superior province',
#   'canadian shield',
#   'variscan batholith of corsica',
#   'taiwan volcanic zone',
#   'zimbabwe',
#   'tethyan neyriz opholite complex',
#   'coso volcanic field',
#   'westasturian-leonese',
#   'norris creek',
#   'tarenga shale',
#   'biritish caledonian',
#   'burnside',
#   'pine creek',
#   'mount webb',
#   'arunta inlier',
#   'idaho batholith',
#   'variscan crust',
#   'corsica',
#   'njiri',
#   'dharwar craton',
#   'central african plateau',
#   'oulmès metamorphic aureole',
#   'sonhat basin',
#   'son valley',
#   'warrego',
#   'tennant creek',
#   'dawson',
#   'continental crust',
#   'sybella batholith',
#   'vosges',
#   'schwarzwald',
#   'bear lake',
#   'karnataka',
#   'sierra la primavera',
#   'sybella batholith',
#   'kong oscar fjord',
#   'tinemaha granodiorite',
#   'st. malo',
#   'provencal basin',
#   'langtang valley',
#   'natawahunan lake',
#   'damara belt',
#   'central-iberian zone',
#   'merced peak',
#   'cauchon lake',
#   'singhbhum trust belt',
#   'hidden bay pluton',
#   'sierra nevada batholith',
#   'turku area',
#   'chemehuevi mountains',
#   'shellenbarger lake',
#   'kaapvaal craton',
#   'kalkadoon',
#   'timber knob',
#   'betics',
#   'alpujárrides',
#   'red peak',
#   'southwark',
#   'arunta inlier',
#   'tennant creekt',
#   'kimberlite pipes',
#   'chintalapudi basin',
#   'godavari valley',
#   'trois segneurs massif',
#   'post peak',
#   'paperbark',
#   'kimberley',
#   'vredefort structure',
#   'bodrum volcanic complex',
#   'grandhalleux',
#   'kolar schist belt',
#   'west african kimberlites',
#   'ossa morena zone',
#   'westasturian-leonese zone',
#   'querigut complex',
#   'maláguides',
#   'belén',
#   'cordón tucúaro',
#   'iberian range',
#   'moresby strait area',
#   'oxford lake',
#   'shaler pluton',
#   'sally downs',
#   'kimberley',
#   'central eastern china',
#   'closepet granite',
#   'southwestern alaska',
#   'comte',
#   'strona valley',
#   'samrée',
#   'quebrada tajamar',
#   'gulf of mexico basin',
#   'nevado-filábrides',
#   'eastern virunga province',
#   'eastern australia',
#   'quebrada choja',
#   'urals',
#   'vivero massif',
#   'captains bay pluton',
#   'manaslu granite',
#   'arita',
#   'pam lin island',
#   'st. andrew strait',
#   'basotu',
#   'grenville province',
#   'jackass lakes',
#   'minarets complex',
#   'etendeka region',
#   'santa rosa de tastil',
#   'arcot-pallavaram',
#   'pyrenees',
#   'limpopo belt',
#   'trans-hudson orogen',
#   'tehachapi mts',
#   'salar de navidad',
#   'ochaquí',
#   'lamrômenil',
#   'longido',
#   'ghanzi-chobe fold belt',
#   'cantabrian zone',
#   'ebolowa area',
#   'ntem complex',
#   'pingo pingo',
#   'salar de diablillos',
#   'utik lake',
#   'sao paulo',
#   'cananéia-iguape lagoon',
#   'tuluman island',
#   'finger bay pluton',
#   'kirn',
#   'namaqua-natal belt',
#   'nanking',
#   'dodoma',
#   'kerguelen plateau',
#   'voisey bay',
#   'iowa',
#   'bp-1',
#   'bp-2',
#   'verril canyon',
#   'mic mac',
#   'bp-3',
#   'ne volcanic province',
#   'spain',
#   'kansas c',
#   'choschas',
#   'south atlantic',
#   'solya',
#   'bp-4',
#   'bp-5',
#   'sierra de macón',
#   'sinuyu',
#   'east african rift',
#   'merapi volcano',
#   'kansas',
#   'pikwitonei',
#   'sachigo',
#   'charmuria limestone',
#   'sierra nevada',
#   'plagidac',
#   'mississauga',
#   'champua thrust belt',
#   'logan canyon',
#   'kansas',
#   'cordón chinquilchoro',
#   'dawson canyon',
#   'kaiserstuhl',
#   'pacific ocean',
#   'kagalaska pluton',
#   'kanyemba',
#   'peninsula de mejillones',
#   'northern apennines',
#   'kastamonu',
#   'sesia–lanzo zone',
#   'redwig',
#   'tanlu fault',
#   'pikwitonei lake',
#   'garua harbour',
#   'mohican',
#   'renco',
#   'santa lucia mts',
#   'aleutian islands',
#   'paraná-etendeka province',
#   'jericho kimberlite pipe',
#   'zagros suture zone',
#   'sierra limón verde',
#   'banquereau',
#   'morbs & oibs',
#   'andean',
#   'goulet lake',
#   'saitoco',
#   'mount garbuna',
#   'new britain',
#   'columbia river basalt',
#   'mount welcker',
#   'luzon',
#   'holili',
#   'lau ridge',
#   'sugarloaf pluton',
#   'chinese peak',
#   "sana'a-amran volcanic field",
#   'garove island',
#   'lesser antilles',
#   'cordón de lila',
#   'nelson river',
#   'peninsula de majillones',
#   'abenaki',
#   'aleutian',
#   'bagana volcano',
#   'lolobau island',
#   'cape reilnitz',
#   'aleutian arc',
#   'sulu range',
#   'pikwitonei river',
#   'limpopo belt',
#   'atlantic ocean',
#   'kansa pathar',
#   'cascades',
#   'central america',
#   'kermadec',
#   'niuatoputapu',
#   'scotia',
#   'boninites',
#   'big creek',
#   'caribbean-columbian oceanic plateau',
#   'marianas',
#   'piñón oceanic plateau',
#   'late',
#   'burntwood river',
#   'cape hoskins volcanoes',
#   'ontong java plateau',
#   'deep sea drilling',
#   'site',
#   'mid ocean ridge',
#   'indian ocean',
#   'jijicao',
#   'xinchang',
#   'cuitzeo lake ',
#   'quinceo-tetillas',
#   'guadalajara',
#   'cuitzeo lake',
#   'los humeros geothermal field',
#   'ischia',
#   'solfatara',
#   'bolsena',
#   'vulsini volcanic zone',
#   'akranes',
#   'ferstikla',
#   'borgarfjarðarsveit',
#   'búlandshöfði',
#   'grundarfjarðarbær',
#   'gullbringusýsla',
#   'mfa-1',
#   'mfa-2',
#   'mfa-3',
#   'hafnarfjall',
#   'hoffell',
#   'dakeng',
#   'hrafnabjörg',
#   'hveragerði',
#   'innrihólmur',
#   'klafastaðir',
#   'kúludalsá',
#   'leirá',
#   'kolgrafir í eyrarsveit',
#   'leirár- og melahreppur',
#   'leirárdalur',
#   'demre',
#   'finike',
#   'mut',
#   'fethiye',
#   'korkuteli',
#   'meke',
#   'karaman',
#   'milas',
#   'yatagan',
#   'bucak',
#   'kolsuz',
#   'gödene',
#   'kilavuzkoy',
#   'ückapili',
#   'kavlaktepe',
#   'gümüsler',
#   'altinhisar',
#   'yesilburc',
#   'hazro',
#   'kemalpasa',
#   'ortaköy',
#   'bunyan',
#   'iscehisar',
#   'altintas',
#   'kozak',
#   'kaman',
#   'yildizeli',
#   'sögütalan',
#   'marmara island',
#   'porrino',
#   'mosfellsbær',
#   'lýsuhóll',
#   'reykjavík',
#   'seleyrargil',
#   'ytrihólmur',
#   'skilmannahreppur',
#   'þyrill',
#   'skorradalshreppur',
#   'stóra-drageyri',
#   'snæfellsbær',
#   'sandabotnaskarð',
#   'ek-105',
#   'kan-3',
#   'nc-99',
#   '98-46',
#   'ku5',
#   'mp-98',
#   'mp-101',
#   '98-78',
#   '98-89a',
#   '98-39',
#   '306i',
#   '316i',
#   '98-43b',
#   'ko2',
#   'klausturtunguhóll',
#   'western snókur',
#   'hafnarfjall caldera',
#   'leirárdalur',
#   'leirárdalur gully',
#   'east of klausturtunguhóll',
#   'nevada',
#   'north german basin',
#   'eulenflucht',
#   'groß buchholz',
#   'east of snókur',
#   'western canada sedimentary basin',
#   'alberta basin',
#   'well',
#   'hof trages',
#   'freigericht-somborn',
#   'lesesteine w stolzenberg',
#   'bad soden-salmünster',
#   'feldweg böschung',
#   'kinzig-stausee',
#   'ost',
#   'west',
#   'rothenberg',
#   'alzenau-kälberau',
#   '06-11-051-26w4',
#   'alter steinbruch',
#   'gap lake',
#   'alberta',
#   'canada',
#   'hohlweg rauher berg',
#   '15-23-036-10w5',
#   'grassi lakes',
#   'canmore',
#   'whitemans pond',
#   'maisenheimer hof',
#   'nigel peak',
#   'alberta canada',
#   'steinbruch ',
#   'niedermittlauer ',
#   'heiligenkopf',
#   'gelnhausen-meerholz',
#   'klosterruine',
#   'berg',
#   'gründau-breitenborn',
#   'steinbruch',
#   'schnepfenkopf',
#   'gelnhausen',
#   'kalkwerk firma hufgard',
#   'hösbach-rottenberg',
#   'kleiner aufschluss',
#   'freibad gelnhausen-roth',
#   'steinbruch',
#   'heiligenkopf',
#   'steinbruch',
#   'heinrichshöhe',
#   'lochmühle',
#   'biebergemünd-bieber',
#   'anschnitt b276',
#   'wächtersbach',
#   'altegrube',
#   'gelnhausen-höchst',
#   'steinbruch',
#   'altenhaßlau',
#   'linsengericht-altenhaßlau',
#   'steinbruch',
#   'nassbüchelbach',
#   'altenmittlau',
#   'anschnitt',
#   'kreuzung',
#   'burgfelsen',
#   'alzenau-burg',
#   'alzenau',
#   'steinbruch',
#   'gelnhausen-roth',
#   'steinbruch',
#   'neuenberg',
#   'penken',
#   'tauernfenster',
#   'nordrand',
#   'österreich',
#   'hohlweg',
#   'steinbrüche e bad orb',
#   'pfannköpfl',
#   'biebergemünd-kassel',
#   'tettensjoch',
#   'steinbruch kerkelberg',
#   'biebergemünd-roßbach',
#   'alter steinbruch am hirschberg',
#   'steinbruch wintersberg',
#   'bad orb',
#   'finkenberg',
#   'langenselbold',
#   'alter steinbruch herzberg',
#   'bahnhofstraße',
#   'alte tongrube',
#   'elsbach',
#   'alter kalksteinbruch',
#   'sonnenberg',
#   'gelnhausen-hailer',
#   'tongrube hailer',
#   'dornau am tuxbach',
#   'wasserfall am elsbach',
#   'altes kalkwerk firma ickes',
#   'elsalm',
#   'schraubenfall',
#   'acker auf dem mühlberg',
#   'langenselbold',
#   'steinbruch franzosenkopf',
#   'huckelheim',
#   'neuer steinbruch',
#   'sw hösbach-rottenberg',
#   'tuxer joch',
#   'weitental',
#   'lachtalscharte',
#   'schwarze pfanne',
#   'bahnhof mittelgründau',
#   'parkplatz hanauer straße',
#   'tongrube firma zeller',
#   'neuburg-ravolzhausen',
#   'tongrube bettenburger loch',
#   'schöneck-oberdorfelden',
#   '10-31-37-9w5',
#   'rosenthal',
#   'arbonne la foret',
#   'aura',
#   'sterbfritz',
#   'hessen',
#   'deutschland',
#   'piarere',
#   'te awamutu',
#   'waikat',
#   'waotu',
#   'cedar creek',
#   'mount tamborine',
#   'te puke',
#   'whakaari',
#   'the taupo volcanic zone',
#   'gonghe basin',
#   'zotzenbach',
#   'nieder-liebersbach',
#   'scharbach',
#   'campi flegrei',
#   'naples',
#   'caserta',
#   'monte san serverio',
#   'colli albani',
#   'mt. etna volcano',
#   'stromboli volcano',
#   'rhode island',
#   'bentheim',
#   'darley dale',
#   'seljadur',
#   'kirschhausen',
#   'wald-erlenbach',
#   'krumbach',
#   'bonsweiher',
#   'taupo',
#   'waihi',
#   'tauposees',
#   'papamoa',
#   'turangi',
#   'straßenaufschluss',
#   'pfalz',
#   'grabenschulter',
#   'oberrheingrabens',
#   'odenwald',
#   'grabenschulter',
#   'spessart',
#   'mainufer',
#   'triefnebachtales',
#   'kirchheimbolanden',
#   'tunnelbaustelle',
#   'widderstall',
#   'lhd4-653',
#   'lhd4-852',
#   'lhd4-1002',
#   'lhd4-2305',
#   'lhd5-603',
#   'lhd5-753',
#   'lhd5-1103',
#   'lhd5-1406',
#   'lhd5-1576',
#   'lhd1-2101',
#   'lhd1-501',
#   'lhd1-802',
#   'lhd1-1001',
#   'lhd1',
#   'lhd7-902',
#   'lhd7.8-1568',
#   'lhd7-1758',
#   'lhd2-302',
#   'lhd3-2203',
#   'mount st. helen',
#   'spine-forming eruption',
#   'mount meager volcano',
#   'cascade volcanic',
#   'st. augustine volcano',
#   'cinderblock lava',
#   'reykjanes',
#   'castle creek period',
#   'kid dome gulley',
#   'el zarco riverbed',
#   'kumamoto prefecture',
#   'mount etna volcano',
#   'rotokawa',
#   'volcán de colima',
#   'river harsit',
#   'kürtün dogankent',
#   'piesberg ',
#   'osnabrück',
#   'bruchsal',
#   'knittlingen',
#   'seebach',
#   'raumünzach',
#   'karlsruhe',
#   'wilferdingen',
#   'pforzheim',
#   'albersweiler',
#   'waldhambach',
#   'buntsandstein',
#   'göbel',
#   'palatinate forest',
#   'th18',
#   'tauhara geothermal field',
#   'thm12',
#   'thm19',
#   'thm14',
#   'thm18',
#   'thm17',
#   'thm13',
#   'kailash tila-2',
#   'bengal basin',
#   'titas-11',
#   'bakhrabad-10',
#   'shahbazpur-1',
#   'kwv-1',
#   'ecca pass',
#   'eastern cape',
#   'koksharovskoe plateau',
#   'ussr maritime region (primorskiy krai)',
#   'russian platform',
#   'lovozero formation',
#   'kurginsk formation',
#   'anabar bed',
#   'kimpersay massif',
#   'aldan',
#   'tanba belt',
#   'synnyr complex',
#   'khibiny mountains',
#   'caucasus',
#   'oboyansk',
#   'gorky region',
#   'nishni novgorod',
#   'oboyansk',
#   'nishni novgorod',
#   'escandorgue lava flow',
#   'lunas',
#   'dévés lava flow',
#   'senouire vallée',
#   'josat',
#   'norseman',
#   'broken hill',
#   'coolgardie',
#   'kalgoorlie',
#   'west-australien',
#   'south and west australia',
#   'heimersdorf',
#   'illfurth',
#   'michelbach',
#   'schweighouse',
#   'chalampe',
#   'staffelfelden',
#   'sainte croix en plaine',
#   'colmar-sud-1',
#   'muntzenheim',
#   'artzenheim',
#   'mackenheim',
#   'muttersholtz',
#   'saint-pierre r1',
#   'grunsbuhl',
#   'schaeffersheim',
#   'erstein',
#   'binnenweg',
#   'meistratzheim',
#   'eschau',
#   'lipsheim',
#   'holtzheim',
#   'cronenbourg',
#   'kilstett',
#   'schirrhein',
#   'schweighouse',
#   'moder',
#   'roeschwoog',
#   'rountzenheim',
#   'donau',
#   'soufflenheim',
#   'donau ',
#   'soufflenheim',
#   'beinheim',
#   'rohrlach',
#   'hitzeln',
#   'rittershoffen',
#   'oberbetschdorf',
#   'schaffhousse',
#   'kesseldorf',
#   'abwaender',
#   'reimerswiller',
#   'schelmenberg',
#   'soultzegs',
#   'knoeringue',
#   'steinsoultz',
#   'preuschdorf',
#   'soultz sous forêts',
#   'oberlauterbach',
#   'guckenberg',
#   'muenzfeld',
#   'neewiller nord',
#   'scheibenhard',
#   'marienbronn',
#   'niederlauterbach',
#   'salmbach',
#   'scheibenhard',
#   'niederlauterbach',
#   'niederlauterbach',
#   'pico da orizaba',
#   'miami',
#   'naples',
#   'west palm beach',
#   'tampa',
#   'plant city',
#   'beeville',
#   'orlando',
#   'daytona beach',
#   'san antonio',
#   'presidio',
#   'gainesville',
#   'apalachicola',
#   'transvaal',
#   'gerhardminnebron bore',
#   'dubbeldevei bore',
#   'dubbeldevlei bore',
#   ...],
#  'list_methods': ['longitude',
#   'decimaldegree.minutes',
#   'latitude',
#   'elevation',
#   'a.s.l.',
#   'radius',
#   'uncertainty',
#   'km',
#   'igsn',
#   'length',
#   'height',
#   'width',
#   'diameter',
#   'decimaldegrees.minutes',
#   'depth',
#   'md',
#   'tvd',
#   'petrography',
#   'stratigraphy',
#   'temperature',
#   'pressure',
#   'pa',
#   'saturating',
#   'saturation',
#   'sigma1',
#   'mpa',
#   'sigma2',
#   'sigma3',
#   'pore',
#   'strain',
#   'rate',
#   'kn/s',
#   'mpa/s',
#   'mm/s',
#   '1/s',
#   'value',
#   'grain',
#   'density',
#   'kg/m³',
#   'standard deviation',
#   'min',
#   'max',
#   'porosity',
#   'permeability',
#   'm²',
#   'thermal',
#   'conductivity',
#   'w/m·k',
#   'inhomogenity',
#   'specific heat capacity',
#   'heat',
#   'capacity',
#   'j/kg·k',
#   'volumetric',
#   'j/m³·k',
#   'diffusivity',
#   'm²/s',
#   'radiogenic',
#   'w/m³',
#   'p-wave',
#   'velocity',
#   'm/s',
#   'frequency',
#   'khz',
#   's-wave',
#   'dyn',
#   'youngs modulus',
#   'modulus',
#   'gpa',
#   'stat',
#   'shear',
#   'lame',
#   'cohesion',
#   'friction',
#   'coefficient',
#   'confining',
#   'porefluid',
#   'differential',
#   'stress',
#   'mean',
#   'compactive',
#   'yield',
#   'critical',
#   'onset',
#   'inelastic',
#   'hydrostatic',
#   'compaction',
#   'shear-enhanced',
#   'enhanced',
#   'poisson',
#   'ratio',
#   'dynamic',
#   'static',
#   'ucs',
#   'tensile',
#   'strength',
#   's/m',
#   'formation',
#   'resistivity',
#   'chronostratigraphy',
#   'sampling point',
#   'petrography',
#   'stratigraphy',
#   'grain density',
#   'bulk density',
#   'total porosity',
#   'effective porosity',
#   'apparent permeability',
#   'intrinsic permeability',
#   'bulk thermal conductivity',
#   'matrix thermal conductivity',
#   'specific heat capacity',
#   'volumetric heat capacity',
#   'thermal diffusivity',
#   'radiogenic heat production',
#   'p-wave velocity',
#   's-wave velocity',
#   'youngs modulus',
#   'shear modulus',
#   'bulk modulus',
#   'lamé modulus',
#   'cohesion',
#   'friction coefficient',
#   'triaxial experiments',
#   'poisson ratio',
#   'uniaxial compressive strength',
#   'tensile strength',
#   'electrical conductivity',
#   'magnetic susceptibility',
#   'quality indice geographic uncertatiny',
#   'qualitiy indice petrography',
#   'quality indice stratigraphy',
#   'qualitiy indice measurement conditions',
#   'quality indice measurement parameter',
#   'value quality index',
#   'class quality index'],
#  'list_petrography': ['consolidated',
#   'magmatic',
#   'plutonic',
#   'plutonic   field description',
#   'very quartz rich plutonic',
#   'quartz rich granitic plutonic',
#   'quartz rich plutonic',
#   'granitic plutonic',
#   'quartz bearing to foid bearing plutonic',
#   'syenitic plutonic',
#   'dioritic plutonic',
#   'gabbrotic plutonic',
#   'foid rich plutonic',
#   'foid syenitic plutonic',
#   'foid dioritic plutonic',
#   'foid gabbrodic plutonic',
#   'very foid rich plutonic foidolite',
#   'foidolitic plutonic',
#   'ultra mafic plutonic  ',
#   'plutonic    ',
#   'quartzolite  ',
#   'granite  ',
#   'alkali feldspar granite',
#   'syenogranite',
#   'monzogranite',
#   'granodiorite  ',
#   'tonalite  ',
#   'quartz alkali feldspar syenite  ',
#   'quartz syenite  ',
#   'quartz monzonite  ',
#   'quartz monzodiorite  ',
#   'quartz monzogabbro  ',
#   'quartz diorite  ',
#   'quartz gabbro  ',
#   'quartz anorthosite  ',
#   'alkali feldspar syenite  ',
#   'syenite  ',
#   'monzonite  ',
#   'monzodiorite  ',
#   'monzogabbro  ',
#   'diorite  ',
#   'gabbro  ',
#   'gabbronorite',
#   'norite',
#   'troctolite',
#   'olivine gabbro',
#   'olivine gabbronorite',
#   'olivine norite',
#   'orthopyroxene gabbro',
#   'clinopyroxene norite',
#   'hornblende gabbro',
#   'pyroxene hornblende gabbro',
#   'pyroxene hornblende gabbronorite',
#   'pyroxene hornblende norite',
#   'anorthosite  ',
#   'foid bearing alkali feldspar syenite  ',
#   'foid bearing syenite  ',
#   'foid bearing monzonite  ',
#   'foid bearing monzodiorite  ',
#   'foid bearing monzogabbro  ',
#   'foid bearing diorite  ',
#   'foid bearing gabbro  ',
#   'foid bearing anorthosite  ',
#   'foid syenite eg. nepheline syenite  ',
#   'malignite',
#   'shoncinite',
#   'foid monzosyenite  ',
#   'foid monzodiorite  ',
#   'foid monzogabbro  ',
#   'foid diorite  ',
#   'foid gabbro  ',
#   'nephelinolite  ',
#   'urtite',
#   'ijolite',
#   'melteigite',
#   'leucitolite  ',
#   'italite',
#   'fergustite',
#   'missourite',
#   'ultramafic plutonics',
#   'peridotite',
#   'dunite',
#   'harzburgite',
#   'lherzolite',
#   'wehrlite',
#   'pyroxene peridotite',
#   'pyroxene hornblende peridotite',
#   'hornblende peridotite',
#   'pyroxenite',
#   'orthopyroxenite',
#   'olivine orthopyroxenite',
#   'websterite',
#   'olivine websterite',
#   'klinopyroxenite',
#   'olivine klinopyroxenite',
#   'olivine pyroxenite',
#   'olivine hornblende pyroxenite',
#   'plagioclase bearing pyroxenite',
#   'plagioclase bearing hornblende pyroxenite',
#   'hornblendite',
#   'pyroxene hornblendite',
#   'olivine hornblendite',
#   'olivine pyroxene hornblendite',
#   'plagioclase bearing hornblendite',
#   'plagioclase bearing pyroxene hornblendite',
#   'ultramafic melilitic plutonic',
#   'melilolite',
#   'olivine melilitolite',
#   'pyroxene melilitolite',
#   'olivine pyroxene melilitolite',
#   'pyroxene olivine melililolite',
#   'carbonatite plutonic',
#   'calcite carbonatite  ',
#   'dolomite carbonatite  ',
#   'ferro carbonatite  ',
#   'charnockite plutonic',
#   'volcanic',
#   'volcanic  ',
#   'quartz rich volcanic',
#   'rhyolitic volcanic',
#   'dacitic volcanic',
#   'quartz to foid bearing volcanic',
#   'trachytic volcanic',
#   'latitic volcanic',
#   'basaltic volcanic',
#   'tholeiitic volcanic',
#   'olivine basaltic volcanic',
#   'alkali basaltic volcanic',
#   'andesitic volcanic',
#   'foid rich volcanic',
#   'phonolitic volcanic',
#   'tephritic volcanic',
#   'basanitic volcanic',
#   'very foid rich volcanic',
#   'foiditic volcanic',
#   'ultramafic volcanic  ',
#   'volcanic  normativ',
#   'alkali feldspar rhyolite  ',
#   'rhyolite  ',
#   'rhyodacite  ',
#   'dacite  ',
#   'obsidian',
#   'quartz alkali feldspar trachyte  ',
#   'quartz trachyte  ',
#   'alkali feldspar trachyte  ',
#   'trachyte  ',
#   'foid bearing alkali feldspar trachyte  ',
#   'foid bearing trachyte  ',
#   'quartz latite  ',
#   'latite  ',
#   'foid bearing latite  ',
#   'basalt  ',
#   'tholeitic basalt',
#   'olivine basalt',
#   'alkali basalt',
#   'alkali basalt amphibole bearing',
#   'leucobasalt  ',
#   'leuco alkali basalt',
#   'andesite  ',
#   'mela andesite  ',
#   'phonolite  ',
#   'tephritic phonolite  ',
#   'tephrite  ',
#   'phonolitic tephrite  ',
#   'basanite  ',
#   'limburgite',
#   'basanite analcim rich',
#   'basanite amphibole bearing',
#   'phonolitic basanite  ',
#   'phonolitic foidite  ',
#   'tephritic foidite  ',
#   'basanitic foidite  ',
#   'foidite  ',
#   'nephelinite  ',
#   'melilite nephelinite  ',
#   'analcimite  ',
#   'leucitite  ',
#   'ultramafic volcanic ',
#   'melilithite',
#   'olivine melilithite',
#   'melilithite bearing ultramafic',
#   'carbonatite',
#   'calcite carbonatite',
#   'dolomite carbonatite',
#   'ferro carbonatite',
#   'natro carbonatite',
#   'volcanic  ',
#   'acidic volcanic',
#   'intermediate volcanic',
#   'basic volcanics',
#   'ultra basic',
#   'sio oversaturated volcanic  ',
#   'rhyolite  ',
#   'comenditic rhyolite comendite',
#   'pantelleritic rhyolite pantellerite',
#   'trachydacite  ',
#   'dacite  ',
#   'high k dacite  ',
#   'medium k dacite  ',
#   'low k dacite  ',
#   'andesite  ',
#   'high k andesite  ',
#   'medium k andesite  ',
#   'low k andesite  ',
#   'basaltic andesite  ',
#   'high k basaltic andesite  ',
#   'medium k basaltic andesite  ',
#   'low k basaltic andesite  ',
#   'sio saturated volcanic  ',
#   'trachyte  ',
#   'trachite  ',
#   'peralkalic trachyte  ',
#   'comenditic trachyte  ',
#   'pantellitic trachyte  ',
#   'trachyandesite  ',
#   'benmoreite  ',
#   'latite  ',
#   'basaltic trachyandesite  ',
#   'mugearite  ',
#   'shoshonite  ',
#   'trachybasalt  ',
#   'hawaiite  ',
#   'k trachybasalt  ',
#   'sio saturated or slightly undersaturated volcanic  ',
#   'basalt  ',
#   'subalkali basalt  ',
#   'tholeitic basalt  ',
#   'high alumina basalt  ',
#   'alkali basalt  ',
#   'alkali olivine basalt  ',
#   'sio undersaturated volcanic  ',
#   'phonolite  ',
#   'tephri phonolite  ',
#   'phono tephrite  ',
#   'tephrite  ',
#   'basanite  ',
#   'picrobasalt  ',
#   'foidite  ',
#   'nephelinite  ',
#   'high mg volcanics  ',
#   'boninite  ',
#   'picritic volcanic  ',
#   'picrite  ',
#   'comatiite  ',
#   'meimechite  ',
#   'volcaniclastic',
#   'volcaniclastics  ',
#   'rhyolitic volcaniclast',
#   'dacitic volcaniclast',
#   'trachytic volcaniclast',
#   'andesitic volcaniclast',
#   'basaltic volcaniclast',
#   'alkali basaltic volcaniclast',
#   'tholeitic volcaniclast',
#   'phonolitic volcaniclast',
#   'tephritic volcaniclast',
#   'basanitic volcaniclast',
#   'foiditic volcaniclast',
#   'pyroclastics',
#   'pyroclastic undefined',
#   'ash tuff ',
#   'fine grained ash tuff',
#   'coarse grained ash tuff',
#   'crystal ash tuff',
#   'lapilli ash tuff',
#   'bomb ash tuff',
#   'block ash tuff',
#   'lapillistone',
#   'ash lapillistone',
#   'bomb lapillistone',
#   'block lapillistone',
#   'agglomerate',
#   'bomb tuff',
#   'lapilli bomb tuff',
#   'ash bomb tuff',
#   'agglutinate',
#   'pyroclastic breccia',
#   'block tuff',
#   'lapilli block tuff',
#   'ash block tuff',
#   'tuff breccia',
#   'lapilli tuff breccia',
#   'ash tuff breccia',
#   'air fall deposit consolidated',
#   'ash flow deposit consolidated',
#   'ignimbrite consolidated',
#   'ignimbrite welded',
#   'ignimbrite unwelded consolidated',
#   'surge deposit consolidated',
#   'peperite',
#   'pyroclastic rhyolitic',
#   'rhyolitic ash tuff',
#   'fine grained ash tuff rhyolitic',
#   'coarse grained ash tuff rhyolitic',
#   'rhyolitic crystal ash tuff',
#   'rhyolitic lapilli ash tuff',
#   'rhyolitic bomb ash tuff',
#   'rhyolitic block ash tuff',
#   'rhyolitic lapilli tuff',
#   'rhyolitic ash lapilli tuff',
#   'rhyolitic bomb lapilli tuff',
#   'rhyolitic block lapilli tuff',
#   'rhyolitic agglomerate',
#   'rhyolitic bomb tuff',
#   'rhyolitic lapilli bomb tuff',
#   'rhyolitic ash bomb tuff',
#   'rhyolitic agglutinate',
#   'pyroclastoc breccia rhyolitic',
#   'rhyolitic block tuff',
#   'rhyolitic lapilli block tuff',
#   'rhyolitic ash block tuff',
#   'rhyolitic tuff breccia',
#   'rhyolitic lapilli tuff breccia',
#   'rhyolitic ash tuff breccia',
#   'rhyolitic air fall deposit consolidated',
#   'rhyolitic ash flow deposit consolidated',
#   'rhyolitic ignimbrite consolidated',
#   'rhyolitic ignimbrite welded',
#   'rhyolitic ignimbrite unwelded consolidated',
#   'rhyolitic surge deposit',
#   'rhyolitic peperite',
#   'pyroclastic dacitic',
#   'dacitic ash tuff',
#   'fine grained ash tuff dacitic',
#   'coarse grained ash tuff dacitic',
#   'dacitic crystal ash tuff',
#   'dacitic lapilli ash tuff',
#   'dacitic bomb ash tuff',
#   'dacitic block ash tuff',
#   'dacitic lapilli tuff',
#   'dacitic ash lapilli tuff',
#   'dacitic bomb lapilli tuff',
#   'dacitic block lapilli tuff',
#   'dacitic agglomerate',
#   'dacitic bomb tuff',
#   'dacitic lapilli bomb tuff',
#   'dacitic ash bomb tuff',
#   'dacitic agglutinate',
#   'pyroclastic breccia dacitic',
#   'dacitic block tuff',
#   'dacitic lapilli block tuff',
#   'dacitic ash block tuff',
#   'dacitic tuff breccia',
#   'dacitic lapilli tuff breccia',
#   'dacitic ash tuff breccia',
#   'dacitic air fall deposit consolidated',
#   'dacitic ash flow deposit consolidated',
#   'dacitic ignimbrite consolidated',
#   'dacitic ignimbrite welded',
#   'dacitic ignimbrite unwelded consolidated',
#   'dacitic surge deposit consolidated',
#   'dacitic peperite',
#   'pyroclastic trachytic',
#   'trachytic ash tuff',
#   'fine grained trachytic ash tuff',
#   'coarse grained trachytic ash tuff',
#   'trachytic crystal ash tuff',
#   'trachytic lapilli ash tuff',
#   'trachytic bomb ash tuff',
#   'trachytic block ash tuff',
#   'trachytic lapilli tuff',
#   'trachytic ash lapilli tuff',
#   'trachytic bomb lapilli tuff',
#   'trachytic block lapilli tuff',
#   'trachytic agglomerate',
#   'trachytic bomb tuff',
#   'trachytic lapilli bomb tuff',
#   'trachytic ash bomb tuff',
#   'trachytic agglutinate',
#   'pyroclastic breccia trachytic',
#   'trachytic block tuff',
#   'trachytic lapilli block tuff',
#   'trachytic ash block tuff',
#   'trachytic tuff breccia',
#   'trachytic lapilli tuff breccia',
#   'trachytic ash tuff breccia',
#   'trachytic air fall deposit consolidated',
#   'trachytic ash flow deposit consolidated',
#   'trachytic ignimbrite consolidated',
#   'trachytic ignimbrite welded',
#   'trachytic ignimbrite unwelded consolidated',
#   'trachytic surge deposit consolidated',
#   'trachytic peperite',
#   'pyroclastic latitic ',
#   'latitic ash tuff',
#   'fine grained latitic ash tuff',
#   'coarse  grained latitic ash tuff',
#   'latitic crystal ash tuff',
#   'latitic lapilli ash tuff',
#   'latitic bomb ash tuff',
#   'latitic block ash tuff',
#   'latitic lapilli tuff',
#   'latitic ash lapilli tuff',
#   'latitic bomb lapilli tuff',
#   'latitic block lapilli tuff',
#   'latitic agglomerate',
#   'latitic bomb tuff',
#   'latitic lapilli bomb tuff',
#   'latitic ash bomb tuff',
#   'latitic aggglutinate',
#   'pyroclastic breccia latitic',
#   'latitic block tuff',
#   'latitic lapilli block tuff',
#   'latitic ash block tuff',
#   'latitic tuff breccia',
#   'latitic lapilli tuff breccia',
#   'latitic ash tuff breccia',
#   'latitic air flow deposit consolidated',
#   'latitic ash flow deposit consolidated',
#   'latitic ignimbrite consolidated',
#   'latitic ignimbrite welded',
#   'latitic ignimbrite unwelded consolidated',
#   'latitic surge deposit consolidated',
#   'latitic peperite',
#   'pyroclastic andesitic',
#   'andesitic ash tuff',
#   'fine grained andesitic ash tuff',
#   'coarse grained andesitic ash tuff',
#   'andesitic crystal ash tuff',
#   'andesitic lapilli ash tuff',
#   'andesitic bomb ash tuff',
#   'andesitic block ash tuff',
#   'andesitic lapilli tuff',
#   'andesitic ash lapilli tuff',
#   'andesitic bomb lapilli tuff',
#   'andesitic block lapilli tuff',
#   'andesitic agglomerate',
#   'andesitic bomb tuff',
#   'andesitic lapilli bomb tuff',
#   'andesitic ash bomb tuff',
#   'andesitic agglutinate',
#   'pyroclastic breccia andesitic',
#   'andesitic block tuff',
#   'andesitic lapilli block tuff',
#   'andesitic ash block tuff',
#   'andesitic tuff breccia',
#   'andesitic lapilli tuff breccia',
#   'andesitic ash tuff breccia',
#   'andesitic air flow deposit consolidated',
#   'andesitic ash flow deposit consolidated',
#   'andesitic ignimbrite consolidated',
#   'andesitic ignimbrite welded',
#   'andesitic ignimbrite unwelded consolidated',
#   'andesitic surge deposit consolidated',
#   'andesitic peperite',
#   'pyroclastic basaltic',
#   'basaltic ash tuff',
#   'fine grained ash tuff basaltic',
#   'coarse grained ah tuff basaltic',
#   'basaltic crystal ash tuff',
#   'basaltic lapilli ash tuff',
#   'basaltic bomb ash tuff',
#   'basaltic block ash tuff',
#   'basaltic lapilli tuff',
#   'basaltic crystal lapilli tuff',
#   'basaltic ash lapilli tuff',
#   'basaltic bomb lapilli tuff',
#   'basaltic block lapilli tuff',
#   'basaltic agglomerate',
#   'basaltic bomb tuff',
#   'basaltic lapilli bomb tuff',
#   'basaltic ash bomb tuff',
#   'basaltic agglutinate',
#   'pyroclastic breccia consolidated',
#   'basaltic block tuff',
#   'basaltic lapilli block tuff',
#   'basaltic ash block tuff',
#   'basaltic tuff breccia',
#   'basaltic lapilli tuff breccia',
#   'basaltic ash tuff breccia',
#   'basaltic air fall deposit consolidated',
#   'basaltic ash flow deposit consolidated',
#   'basaltic ignimbrite consolidated',
#   'basaltic surge deposit consolidated',
#   'basaltic peperite',
#   'pyroclastic phonolitic',
#   'phonolitic ash tuff',
#   'fine grained ash tuff phonolitic',
#   'coarse grained ash tuff phonolitic',
#   'phonolitic crystal ash tuff',
#   'phonolitic lapilli ash tuff',
#   'phonolitic bomb ash tuff',
#   'phonolitic block ash tuff',
#   'phonolitic lapilli tuff',
#   'phonlitic ash lapilli tuff',
#   'phonolitic bomb lapilli tuff',
#   'phonolitic block lapilli tuff',
#   'phonolitic agglomerate',
#   'phonolitic bomb tuff',
#   'phonolitic lapilli block tuff',
#   'phonolitic ash block tuff',
#   'phonolitic agglutinate',
#   'pyroclastic breccia phonolitic',
#   'phonolitic block tuff',
#   'phonolitic tuff breccia',
#   'phonolitic lapilli tuff breccia',
#   'phonolitic ash tuff breccia',
#   'phonolitic air fall deposit consolidated',
#   'phonolitic ash flow deposit consolidated',
#   'phonolitic ignimbrite consolidated',
#   'phonolitic ignimbrite welded',
#   'phonolitic ignimbrite unwelded consolidated',
#   'phonolitic surge deposit consolidated',
#   'phonolitic peperite',
#   'pyroclastic basanitic',
#   'basanitic ash tuff',
#   'fine  grained ash tuff basanitic',
#   'coarse grained ash tuff basanitic',
#   'basanitic crystall ash tuff',
#   'basanitic lapilli ash tuff',
#   'basanitic bomb ash tuff',
#   'basanitic block ash tuff',
#   'basanitic lapilli tuff',
#   'basanitic ash lapilli tuff',
#   'basanitic bomb lapilli tuff',
#   'basanitic block lapilli tuff',
#   'basanitic agglomerate',
#   'basanitic bomb tuff',
#   'basanitic lapilli bomb tuff',
#   'basanitic ash bomb tuff',
#   'basanitic agglutinate',
#   'pyroclastic breccia basanitic',
#   'basanitic block tuff',
#   'basanitic lapilli block tuff',
#   'basanitic ash block tuff',
#   'basanitic tuff breccia',
#   'basanitic lapilli tuff breccia',
#   'basanitic ash tuff breccia',
#   'basanitic air fall deposit consolidated',
#   'basanitic ash flow deposit consolidated',
#   'basanitic ignimbrite consolidated',
#   'basanitic ignimbrite unwelded consolidated',
#   'basanitic surhe deposit consolidated',
#   'basanitic peperite',
#   'autoclastic volcaniclast',
#   'top breccia',
#   'bottom breccia',
#   'tuffite',
#   'tuffaceous claystone',
#   'tuffaceous siltstone',
#   'tuffaceous sandstone',
#   'tuffaceous conglomerate',
#   'tuffaceous breccia',
#   'volcaniclastic sedimentary  ',
#   'volcaniclastic claystone',
#   'volcaniclastic siltstone',
#   'volcaniclastic sandstone',
#   'volcaniclastic conglomerate',
#   'volcaniclastic breccia',
#   'lahar consolidated',
#   'volcanic and volcaniclastic structureless',
#   'dyke ',
#   'dyke    ',
#   'quartz rich dyke',
#   'quartz bearing to foid bearing dyke',
#   'foid rich dyke',
#   'dolerite  ',
#   'lamprophyr  ',
#   'dyke   ',
#   'pegmatite granitoidic composition',
#   'quartz rich aplite',
#   'granite aplite',
#   'granodiorite aplite',
#   'tonalite aplite',
#   'dykes´ granite',
#   'dykes´ granodiorite',
#   'dykes´ tonalite',
#   'microgranite',
#   'microgranodiorite',
#   'microtonalite',
#   'granophyr',
#   'porphyritic granite',
#   'porphyritic granodiorite',
#   'porphyritic tonalite',
#   'pegmatite of nephelinitic composition',
#   'quartz bearing to quartz free aplite',
#   'syenite aplite',
#   'monzonite aplite',
#   'monzodiorite aplite',
#   'diorite aplite',
#   'gabbro aplite',
#   'dykes´ syenite',
#   'dykes´ monzonite',
#   'dykes´ monzodiorite',
#   'dykes´ diorite',
#   'dykes´ gabbro',
#   'microsyenite',
#   'micromonzonite',
#   'micromonzodiorite',
#   'microdiorite',
#   'microgabbro',
#   'porphyric syenite',
#   'porphyric monzonite',
#   'porphyric monzodiorite',
#   'porphyric diorite',
#   'porphyric gabbro',
#   'dolerite diabase',
#   'alkalibasaltic dolerite',
#   'leucite nepheline dolerite',
#   'theoleitic dolerite',
#   'fioditic dyke',
#   'lamprophyre',
#   'minette',
#   'kersanite',
#   'vogesite',
#   'spessartite',
#   'alkali lamprophyre',
#   'camptonite',
#   'sannaite',
#   'monchiquite',
#   'fourchite',
#   'ultrabasic alkali lamprophyr',
#   'quachitite',
#   'melilitic lamprophyr',
#   'alnoite',
#   'polzenite',
#   'lamprophyric carbonatic dyke',
#   'kimberlite',
#   'carbonatic kimberlite',
#   'hydrothermal gangue mineralization',
#   'quartz rich gangue mineralization',
#   'milky quartz mineral aggregate',
#   'capped quartz mineral aggregate',
#   'pseudomorphosic quartz mineral aggregate',
#   'carbonate rich gangue mineralization',
#   'calcite mineral aggregate',
#   'feldspar rich gangue mineralization',
#   'feldspar mineral aggregate',
#   'baryte rich gangue mineralization',
#   'baryte mineral aggregate',
#   'sulfide rich gangue mineralization',
#   'metamorphic',
#   'metamorphic after educt',
#   'meta sedimentary',
#   'meta pelite',
#   'hornfels',
#   'buchite',
#   'silicic',
#   'silicic schist',
#   'meta psammite',
#   'meta arkose',
#   'meta graywacke',
#   'meta psephite',
#   'meta conglomerate',
#   'meta igneous',
#   'meta plutonite',
#   'meta granite',
#   'meta granodiorite',
#   'meta diorite',
#   'meta gabbro',
#   'metamorphic dyke',
#   'meta aplite',
#   'garnet meta aplite',
#   'garnet turmaline meta aplite',
#   'meta pegmatite',
#   'meta dolerite',
#   'alkalibasaltic meta dolerite',
#   'tholeitic meta dolerite',
#   'meta volcanic',
#   'meta rhyolite',
#   'peralkaline meta rhyolite',
#   'meta rhyodacite',
#   'meta dacite',
#   'meta trachyte',
#   'meta basalt',
#   'meta basalt sorted',
#   'meta alkali basalt',
#   'tholeitic meta basalt',
#   'meta andesite',
#   'meta phonolite',
#   'meta basanite',
#   'meta pikrite',
#   'meta volcaniclastic',
#   'rhyolitic meta volcaniclastic',
#   'rhyodacitic meta volcaniclastic',
#   'dacitic meta volcaniclastic',
#   'trachytic meta volcaniclastic',
#   'andesitic meta volcaniclastic',
#   'basaltic meta volcaniclastic',
#   'alkali basaltic meta volcaniclastic',
#   'tholeitic meta volcaniclastic',
#   'phonolitic meta volcaniclastic',
#   'basanitic meta volcaniclastic',
#   'meta pyroclastic',
#   'rhyolitic meta pyroclastic',
#   'rhyodacitic meta pyroclastic',
#   'dacitic meta pyroclastic',
#   'trachytic meta pyroclastic',
#   'andesitic meta pyroclastic',
#   'basaltic meta pyroclastic',
#   'alkali basaltic meta pyroclastic',
#   'basanitic meta pyroclastic',
#   'meta tuffite',
#   'tuffitic meta pelite',
#   'tuffitic meta psammite',
#   'tuffitic meta conglomerate',
#   'autoclastic meta volcaniclastic',
#   'autoclastic hydroclastic meta volcaniclastic',
#   'pillow breccia',
#   'pillow fragment breccia',
#   'hydroclastic',
#   'volcaniclastic meta sedimentary  ',
#   'metamorphic after chemistry fabric mineral content',
#   'metacarbonate',
#   'marble',
#   'marble sorted',
#   'calcite marble',
#   'dolomite marble',
#   'carbonate silicate marble silica marble',
#   'metamorphic carbonate silicate',
#   'carbonate phyllite',
#   'carbonate silicate coarse',
#   'quartz rich metamorphic',
#   'quartzite',
#   'apatite quartzite',
#   'epidote quartzite',
#   'garnet quartzite',
#   'graphite quartzite',
#   'magnetite quartzite',
#   'muscovite quartzite',
#   'serictite quartzite',
#   'metafelsics',
#   'phyllite',
#   'albite phyllite',
#   'chloritoide phyllite',
#   'garnet albite phyllite',
#   'garnet phyllite',
#   'quartz phyllite',
#   'sericite phyllite',
#   'mica schist',
#   'albite mica schist',
#   'andalusite mica schist',
#   'apatite mica schist',
#   'biotite plagioclase mica schist',
#   'chlorite mica schist',
#   'garnet mica schist',
#   'graphite mica schist',
#   'muscovite chlorite mica schist',
#   'muscovite biotite mica schist two mica schist',
#   'sericite mica schist',
#   'staurolite biotite muscovite mica schist',
#   'gneiss',
#   'epidote hornblende plagioclase gneiss',
#   'albite gneiss',
#   'andalusite gneiss',
#   'biotite gneiss',
#   'biotite cordierit gneiss',
#   'biotite garnet gneiss',
#   'biotite plagioclase gneiss',
#   'biotite muscovite gneiss',
#   'biotite sillimanite gneiss',
#   'cordierit gneiss',
#   'disthene gneiss',
#   'disthene staurolite gneiss',
#   'disthene sillimanite gneiss',
#   'mica gneiss',
#   'garnet gneiss',
#   'garnet biotite gneiss',
#   'garnet cordierit sillimanite gneiss',
#   'garnet disthene gneiss',
#   'garnet disthene sillimanite gneiss',
#   'garnet disthene staurolite gneiss',
#   'garnet plagioclase gneis',
#   'graphite gneiss',
#   'hornblende biotite gneiss',
#   'muscovite gneiss',
#   'muscovite biotite gneiss',
#   'muscovite biotite garnet gneiss',
#   'muscovite garnet gneiss',
#   'pyroxene gneiss',
#   'quartz biotite plagioclase gneiss',
#   'staurolite garnet plagioclase gneiss',
#   'metafelsic granulite',
#   'granulite',
#   'granulite gneiss',
#   'charnockite metamorphic affinity',
#   'acidic to intermediate hornfels',
#   'andalusite hornfels',
#   'biotite hornblende plagioclase hornfels',
#   'cordierite hornels',
#   'coround hercynite hornfels',
#   'metamafics',
#   'greenschist',
#   'actinolite schist',
#   'prasinite',
#   'amphibolite',
#   'biotite amphibolite',
#   'biotite pyroxene amphibolite',
#   'diopside amphibolite',
#   'epidote amphibolite',
#   'garnet amphibolite',
#   'carbonate silicate amphibolite',
#   'zoisite amphibolite',
#   'eklogite amphibolite',
#   'metamafic granulite',
#   'eclogite',
#   'metamafic hornfels',
#   'meta ultramafic',
#   'chlorite actinolite schist',
#   'talcum schist',
#   'serpentinite',
#   'ultra mafic hornfels',
#   'olivine fels',
#   'tectonite',
#   'cataclast',
#   'fault breccia',
#   'melange',
#   'schist',
#   'slate slaty metamudstone',
#   'black shale',
#   'alum shale',
#   'ribbon slate',
#   'silty schist',
#   'mylonite',
#   'migmatite',
#   'anatexite',
#   'metatexite',
#   'diatexite',
#   'syntexite',
#   'sedimentary',
#   'siliciclastic sedimentary',
#   'sandstone pelite alternation',
#   'sandstone dominated sandstone pelite alternation',
#   'pelite dominated sandstone pelite alternation',
#   'pelite gypsum alternation',
#   'pelite dominated pelite gypsum alternation',
#   'gypsum dominated pelite gypsum alternation',
#   'pelite',
#   'silicate claystone',
#   'silicate siltstone',
#   'sapropelite',
#   'psammitearenite',
#   'arenite sandstone',
#   'fine sandstone',
#   'medium sandstone',
#   'coarse sandstone',
#   'quartz arenite',
#   'fine quartz arenite',
#   'medium quartz arenite',
#   'coarse quartz arenite',
#   'subfeldspatic arenite  feldspatic sandstone',
#   'fine subfeldspatic arenite',
#   'medium subfeldspatic arenite',
#   'coarse subfeldspatic arenite',
#   'feldspatic arenite',
#   'fine feldspatic arenite',
#   'medium feldspatic arenite',
#   'coarse feldspatic arenite',
#   'arkose',
#   'fine arkose',
#   'medium arkose',
#   'coarse arkose',
#   'sublitharenite',
#   'fine sublitharenite',
#   'medium sublitharenite',
#   'coarse sublitharenite',
#   'litharenite',
#   'fine litharenite',
#   'medium litharenite',
#   'coarse litharenite',
#   'lithic arenite',
#   'fine lithic arenite',
#   'medium lithic arenite',
#   'coarse lithic arenite',
#   'graywacke wacke',
#   'fine graywacke',
#   'medium graywacke',
#   'coarse graywacke',
#   'quartz wacke',
#   'fine quartz wacke',
#   'medium quartz wacke',
#   'coarse quartz wacke',
#   'feldspathic wacke',
#   'fine feldspethic wacke',
#   'medium feldspethic wacke',
#   'coarse feldspethic wacke',
#   'lithic wacke',
#   'fine lithic wacke',
#   'medium lithic wacke',
#   'coarse lithic wacke',
#   'psephite',
#   'conglomerate',
#   'pebbly conglomerate',
#   'fine pebble granule',
#   'medium to coarse pebble',
#   'very coarse pebble',
#   'cobbles',
#   'boulders',
#   'breccia',
#   'grus breccia',
#   'fine grus breccia',
#   'medium grus breccia',
#   'coarse grud breccia',
#   'debris breccia',
#   'block debris breccia',
#   'carbonatic sedimentary',
#   'carbonatic siliciclastic sedimentary',
#   'limestone marl alteration',
#   'limestone dominated limestone marl alteration',
#   'marl dominated limestone marl alteration',
#   'pelite marl alteration',
#   'pelite dominated pelite marl alteration',
#   'marol dominated pelite marl alteration',
#   'carbonate bearing siliciclastic',
#   'carbonate bearing claystone',
#   'carbonate bearing mudstone',
#   'carbonate bearing sandstone',
#   'carbonate bearing fine sandstone',
#   'carbonate bearing medium sandstone',
#   'carbonate bearing coarse sandstone',
#   'carbonate bearing conglomerate',
#   'carbonate bearing breccia',
#   'dolomite bearing siliciclastic',
#   'dolomite bearing claystone',
#   'dolomite bearing mudstone',
#   'dolomite bearing sandstone',
#   'dolomite bearing fine sandstone',
#   'dolomite bearing medium sandstone',
#   'dolomite bearing coarse sandstone',
#   'dolomite bearing conglomerate',
#   'dolomite bearing breccia',
#   'carbonatic siliciclastic',
#   'carbonatic claystone',
#   'carbonatic mudstone',
#   'carbonatic sandstone',
#   'carbonatic fine sandstone',
#   'carbonatic medium sandstone',
#   'carbonatic coarse sandstone',
#   'carbonatic conglomerate',
#   'carbonatic breccia',
#   'dolomitic siliciclastic',
#   'dolomitic claystone',
#   'dolomitic mudstone',
#   'dolomitic sandstone',
#   'dolomitic fine sandstone',
#   'dolomitic medium sandstone',
#   'dolomitic coarse sandstone',
#   'dolomitic conglomerate',
#   'dolomitic breccia',
#   'siliciclastic limestone',
#   'clayey limestone',
#   'muddy limestone',
#   'sandy limestone',
#   'fine sandy limestone',
#   'medium sandy limestone',
#   'coarse sandy limestone',
#   'conglomeratic limestone',
#   'brecciatic limestone',
#   'siliciclastic dolimite',
#   'clayey dolomite',
#   'muddy dolomite',
#   'sandy dolomite',
#   'fine sandy dolomite',
#   'medium sandy dolomite',
#   'coarse sandy dolomite',
#   'conglomeratic dolomite',
#   'brecciatic dolomite',
#   'clay lime composite',
#   'marly claystone',
#   'marl claystone',
#   'clay marl',
#   'marl',
#   'lime marl',
#   'dolomite marl',
#   'marl limestone',
#   'marl dolomite',
#   'marly limestone',
#   'marly dolomite',
#   'carbonate',
#   'clastic sedimentary carbonate',
#   'lutite',
#   'siltite',
#   'arenite',
#   'fine grained arenite',
#   'medium grained arenite',
#   'coarse grained arenite',
#   'ooidlothic',
#   'oncolithic',
#   'rudite',
#   'dolomite',
#   'dolomitic lutite',
#   'dolomitic siltite',
#   'dolomitic arenite',
#   'fine grained dolomitic arenite',
#   'medium grained dolomitic arenite',
#   'coarse grained dolomitic arenite',
#   'dolomitic rudite',
#   'limestone',
#   'calcitic lutite',
#   'calcitic siltite',
#   'calcitic arenite',
#   'fine grained calcitic arenite',
#   'medium grained calcitic arenite',
#   'coarse grained calcitic arenite',
#   'calcitic rudite',
#   'carbonate of dunham  and embry & klovan ',
#   'allothonous limestone',
#   'mud supported limestone',
#   'mudstone',
#   'wackstone',
#   ...],
#  'list_states': ['massachusetts',
#   'california',
#   'rhode island',
#   'vermont',
#   'transvaal',
#   'pennsylvania',
#   'montana',
#   'quebec',
#   'wisconsin',
#   'north carolina',
#   'bavaria',
#   'louisiana',
#   'texas',
#   'oklahoma',
#   'colorado',
#   'utah',
#   'wyoming',
#   'oregon',
#   'washington',
#   'kyushu',
#   'akita',
#   'hokkaido',
#   'atlantic ocean',
#   'hawaii',
#   'java',
#   'brandenburg',
#   'schleswig-holstein',
#   'western namibia',
#   'southeastern australia',
#   'western south africa',
#   'bahia',
#   'michigan',
#   'new hampshire',
#   'iberian peninsula',
#   'queensland',
#   'ontario',
#   'corsica',
#   'north taiwan',
#   'central',
#   'ávila',
#   'fars',
#   'inyo county',
#   'chhattisgarh',
#   'scotland',
#   'northern territory',
#   'central zimbabwe',
#   'idaho',
#   'singida',
#   'southern india',
#   'otjozondjupa',
#   'central zambia',
#   'khémisset',
#   'dawson strait',
#   'baden-württemberg',
#   'manitoba',
#   'karnataka',
#   'jalisco',
#   'east greenland',
#   'sierra nevada',
#   'bretagne',
#   'southern france',
#   'central northern nepal',
#   'karas',
#   'jharkand',
#   'alaska',
#   'southern finland',
#   'eastern south africa',
#   'scottland',
#   'andhra pradesh',
#   'pyrenees',
#   'western australia',
#   'central south africa',
#   'bodrum',
#   'parinacota',
#   'antofagasta',
#   'northeastern spain',
#   'moresby strait',
#   'central eastern china',
#   'ivrea-verbano',
#   'salta',
#   'virunga',
#   'eastern australia',
#   'tarapacá',
#   'khomas',
#   'vianden',
#   'western russia',
#   'galicia',
#   'central nepal',
#   'australia',
#   'bismarck archipelago',
#   'manyara',
#   'québec',
#   'erongo',
#   'tamil nadu',
#   'eastern canada',
#   'arusha',
#   'sud',
#   'iguape',
#   'rhineland-palatinate',
#   'north west',
#   'jiangsu',
#   'dodoma',
#   'heard island',
#   'mcdonald islands',
#   'labrador',
#   'iowa',
#   'banks peninsula, christchurch',
#   'nova scotia',
#   'garratoxa',
#   'kansas',
#   'tristan da cunha',
#   'gough',
#   'northern tanzania',
#   'chile & argentina',
#   'vogelsaug',
#   'mashonaland',
#   'apennines',
#   'kastamonu',
#   'piemonte',
#   'mutasa',
#   'oberbergau',
#   'ascension',
#   'masvingo',
#   'southern brazil',
#   'northwest territories',
#   'western iran',
#   'st. helena',
#   'kilimanjaro region',
#   'kunene',
#   'bouvet',
#   'viti levu, tavua',
#   'kamchatka',
#   "sana'a and amran",
#   'victoria',
#   'bougainville',
#   'norther pacific',
#   'new hebrides',
#   'kgalagadi',
#   'niuatoputapu',
#   'north-east',
#   'western cordillera',
#   'montechristi',
#   'new britain',
#   'santa isabel',
#   'malaita',
#   'gorgona island',
#   'gansu province',
#   'michoacán ',
#   'puebla',
#   'tushka',
#   'campanian',
#   'pozzuoli/ campanian',
#   'roman',
#   'red sea area',
#   'sinai',
#   'western desert',
#   'akranes',
#   'hvalfjarðarsveit',
#   'borgarbyggð',
#   'grundarfjörður',
#   'grundarfjarðarbær',
#   'gullbringusýsla',
#   'west tushka',
#   'hornafjörður',
#   'chelungpu fault',
#   'hvalfjarðarstrandarhreppur',
#   'hveragerði',
#   'antalya',
#   'icel',
#   'mugla',
#   'konya',
#   'burgur',
#   'nigde',
#   'diayarbakir',
#   'bursa',
#   'aksaray',
#   'kayseri',
#   'ayfonkarahisar',
#   'afyonkarahisar',
#   'kutahya',
#   'izmir',
#   'izmir or balikesir',
#   'kirsehir',
#   'sivas',
#   'marmara island',
#   'provinz pontevedra',
#   'mosfellsbær',
#   'snæfellsbær',
#   'reykjavík',
#   'skorradalshreppur',
#   'skútustaðahreppur',
#   'kerala',
#   'vesturland',
#   'nevada',
#   'north german basin',
#   'alberta',
#   'hessen',
#   'tirol',
#   'ile de france',
#   'campanian area',
#   'rome',
#   'sicily',
#   'messina',
#   'rhode island',
#   'niedersachsen',
#   'east midlands',
#   'south iceland',
#   'lahendong',
#   'washington state',
#   'british columbia',
#   'suðurnes',
#   'waikato',
#   'colima',
#   'jalisco ',
#   'giresun',
#   'gümüshane',
#   'lower saxonyniedersachsen',
#   'baden würtemberg',
#   'rheinland pfalz',
#   'bengal basin']}

# %% [markdown]
# ## NER Library

# %%
#Ready for NLP NER
ready_ner = {'text':[],'tag':[],'entity':[]}
for i in ready:
    for j in dict_entities:
        pattern = r"(\.*\b(?:{}))\b".format("|".join(dict_entities[j]))
        if bool(re.search(pattern, i)) == True:
            ready_ner['text'].append(i)
            ready_ner['tag'].append(re.search(pattern, i).group())
            ready_ner['entity'].append(re.search(r'list_(\w+)$',j).group(1))

# %%
ready_ner['text']
# Out:
# ['this study employs numerical modeling allocate quantify permeability anisotropies discontinuities.., faults order understand inﬂuence subsurface ﬂuid ﬂow geothermal reservoirs.',
#  'additionally sites exemplifying characteristics lahendong.',
#  'the underground movement hot cold ﬂuids modeled geothermal ﬁelds new zealand (kaya. 2014).',
#  'the kakkonda geothermal site.., consists reservoirs depths ﬂuid properties.',
#  'generally, faults acting preferential ﬂuid path ways signiﬁcantly change pressure temperature ﬁeld reservoir (cherubini. 2013).',
#  'results enhanced upward heat transport ﬂuids geothermal (magri. 2011).',
#  'our test ground lahendong geothermal ﬁeld located sulawesi, indonesia.',
#  'our test ground lahendong geothermal ﬁeld located sulawesi, indonesia.',
#  'the ﬁeld owned operated p.t. pertamina geothermal energy hosts power plant production capacity 80 mwe.',
#  'it water-dominated magmatic structurally controlled.',
#  'faults generally-fault ﬂuid barriers alongfault ﬂuid conductors (brehme. 2014).',
#  'as result, hot springs vertically permeable faults surface.',
#  'the model presented developed investigating subsurface ﬂuid ﬂow permeability distribution including fault zones lahendong geothermal ﬁeld.',
#  'the model presented developed investigating subsurface ﬂuid ﬂow permeability distribution including fault zones lahendong geothermal ﬁeld.',
#  'the model presented developed investigating subsurface ﬂuid ﬂow permeability distribution including fault zones lahendong geothermal ﬁeld.',
#  'detailed investigation subsurface permeability distribution crucial step site selection smart drilling strategies.',
#  'detailed investigation subsurface permeability distribution crucial step site selection smart drilling strategies.',
#  'the numerical simulations presented provide insight understanding subsurface ﬂuid ﬂow hydraulic conductivity faults.',
#  'although target area lahendong general workﬂow applicable geothermal sites consisting constraints.',
#  'reservoir characterization hydrogeology the driving force ﬂuid ﬂow sw–ne oriented natural hydraulic gradient lahendong geothermal.',
#  'the direction ﬂuid ﬂow varies geothermal site horizontal partitioning reservoir permeable fault zones (brehme. 2014).',
#  'the direction ﬂuid ﬂow varies geothermal site horizontal partitioning reservoir permeable fault zones (brehme. 2014).',
#  'the basic sections located fig. 1 topographic map study area geological features, water rock sample locations model cross 123\x0cenviron earth sci (2016)',
#  'also, types ﬂuid change.. acidic highly saline-type beneath lake linau neutral low saline-type south east',
#  'rainwater inﬁltrates fault sw mt. lengkoan creek water inﬁltrates normal faults lake linau (fig. 2).',
#  'the hydrothermal discharges lake linau ne driven hydraulic gradient (brehme. 2014).',
#  'left step strike slip faults forms extension basin central study area.',
#  'lithology lahendong area characterized pre-, post-',
#  'tondano formation plio-',
#  'pleistocene age (koestono. 2010).',
#  'the rocks typically andesite, volcanic breccia tuff.',
#  'those types sampled borehole cores determine porosity, permeability thermal conductivity.',
#  'effective porosity matrix permeability analyzed cylindrical-shaped specimen dimension 5 5 9 2.5 oriented parallel coring (brehme. 2016).',
#  'thermal conductivity measured plain sections dried cores.',
#  'the experimental setup consists gas permeameter determining matrix permeability (milsch. 2011) helium pycnometry effective porosity measurements (johnson-maynard. 1994) optical scanner thermal conductivity measurements (popov. 1999).',
#  'these parameters measured averaged rock types (brehme. 2016; table 1).',
#  'andesite effective porosity 3.7 % permeability 2.1 9 10-14 thermal conductivity 1.8 w-1 k-1 (dry) 2.2 w-1 k-1 (saturated).',
#  'andesite effective porosity 3.7 % permeability 2.1 9 10-14 thermal conductivity 1.8 w-1 k-1 (dry) 2.2 w-1 k-1 (saturated).',
#  'tuff porosity 7.7 % lowest permeability 2.0 9 10-15 1.6 w-1 k-1 (saturated).',
#  'tuff porosity 7.7 % lowest permeability 2.0 9 10-15 1.6 w-1 k-1 (saturated).',
#  'volcanic breccia permeable layer effective porosity 10.5 % permeability 2.3 9 10-14 thermal conductivity 1.6 w-1 k-1 (dry) 2.5 w-1 k-1 (saturated).',
#  'volcanic breccia permeable layer effective porosity 10.5 % permeability 2.3 9 10-14 thermal conductivity 1.6 w-1 k-1 (dry) 2.5 w-1 k-1 (saturated).',
#  'reservoir rocks reﬂect generally low matrix permeability suggesting fracture-controlled ﬂuid ﬂow aquifer (brehme. 2016).',
#  '(dry) 2.1 w-1 k-1 thermal conductivity model setup model geometry numerical models developed study area represent initial conditions reservoir production commercial ﬁnite injection start.',
#  'cross modeled area geological structure, boundary conditions location observation points 123\x0c1088 page 4 11 environ earth sci (2016) 75:1088 table 1 thermal hydraulic parameters lahendong reservoir rocks measured laboratory (brehme. 2016)',
#  'cross modeled area geological structure, boundary conditions location observation points 123\x0c1088 page 4 11 environ earth sci (2016) 75:1088 table 1 thermal hydraulic parameters lahendong reservoir rocks measured laboratory (brehme. 2016)',
#  'sample (, depth) rock type effective porosity (%)',
#  'sample (, depth) rock type effective porosity (%)',
#  'thermal conductivity dry (w-1 k-1) thermal conductivity saturated (w-1 k-1) matrix permeability () lhd1 500–501 lhd1 801–802 lhd1 1000–1001 lhd1 2100–2101 lhd2 300–302 lhd3 2201–2203 lhd4 652–653 lhd4 850–852 lhd4 1001–1002 lhd4 2304–2305 lhd5 602–603 lhd5 752–753 lhd5 1102–1103 lhd5 1404–1406 lhd5 1575–1576 lhd7 901–902,3 lhd7 1567.8–1568 lhd7 1756–1758 average values a b t t a b b a b a b a a a a a t b andesite (a) breccia (b) tuff (t) 1.1 14.5 5.0 7.2 12.5 5.7 6.3 1.6 16.4 1.6 16.3 2.7 5.2 3.6 0.6 4.6 11.0 3.9 3.7 10.5 7.7 (lhd1 550) 2.0 (lhd1 550) 2.2 1.6 1.8 1.4 2.1 1.8 1.4 1.8 1.4 1.9 1.5 1.6 2.1 1.8 1.6 1.6 2.4 2.2 2.0 2.4 2.0 2.7 2.7 2.3 2.3 1.7 2.2 2.7 2.2 2.5 2.1 1.5 9 10-14 8.9 9 10-16 3.3 9 10-15 6.1 9 10-14 1.5 9 10-14 1.3 9 10-14 2.3 9 10-14 6.8 9 10-14 3.4 9 10-16 1.1 9 10-14 1.1 9 10-16 7.9 9 10-14 3.0 9 10-15 7.9 9 10-18 7.2 9 10-16 1.7 9 10-15 1.7 9 10-14 2.1 9 10-14 2.3 9 10-14 2.0 9 10-15 element software feflow model pressuredriven thermally induced ﬂuid ﬂow including viscosity.',
#  'thermal conductivity dry (w-1 k-1) thermal conductivity saturated (w-1 k-1) matrix permeability () lhd1 500–501 lhd1 801–802 lhd1 1000–1001 lhd1 2100–2101 lhd2 300–302 lhd3 2201–2203 lhd4 652–653 lhd4 850–852 lhd4 1001–1002 lhd4 2304–2305 lhd5 602–603 lhd5 752–753 lhd5 1102–1103 lhd5 1404–1406 lhd5 1575–1576 lhd7 901–902,3 lhd7 1567.8–1568 lhd7 1756–1758 average values a b t t a b b a b a b a a a a a t b andesite (a) breccia (b) tuff (t) 1.1 14.5 5.0 7.2 12.5 5.7 6.3 1.6 16.4 1.6 16.3 2.7 5.2 3.6 0.6 4.6 11.0 3.9 3.7 10.5 7.7 (lhd1 550) 2.0 (lhd1 550) 2.2 1.6 1.8 1.4 2.1 1.8 1.4 1.8 1.4 1.9 1.5 1.6 2.1 1.8 1.6 1.6 2.4 2.2 2.0 2.4 2.0 2.7 2.7 2.3 2.3 1.7 2.2 2.7 2.2 2.5 2.1 1.5 9 10-14 8.9 9 10-16 3.3 9 10-15 6.1 9 10-14 1.5 9 10-14 1.3 9 10-14 2.3 9 10-14 6.8 9 10-14 3.4 9 10-16 1.1 9 10-14 1.1 9 10-16 7.9 9 10-14 3.0 9 10-15 7.9 9 10-18 7.2 9 10-16 1.7 9 10-15 1.7 9 10-14 2.1 9 10-14 2.3 9 10-14 2.0 9 10-15 element software feflow model pressuredriven thermally induced ﬂuid ﬂow including viscosity.',
#  'thermal conductivity dry (w-1 k-1) thermal conductivity saturated (w-1 k-1) matrix permeability () lhd1 500–501 lhd1 801–802 lhd1 1000–1001 lhd1 2100–2101 lhd2 300–302 lhd3 2201–2203 lhd4 652–653 lhd4 850–852 lhd4 1001–1002 lhd4 2304–2305 lhd5 602–603 lhd5 752–753 lhd5 1102–1103 lhd5 1404–1406 lhd5 1575–1576 lhd7 901–902,3 lhd7 1567.8–1568 lhd7 1756–1758 average values a b t t a b b a b a b a a a a a t b andesite (a) breccia (b) tuff (t) 1.1 14.5 5.0 7.2 12.5 5.7 6.3 1.6 16.4 1.6 16.3 2.7 5.2 3.6 0.6 4.6 11.0 3.9 3.7 10.5 7.7 (lhd1 550) 2.0 (lhd1 550) 2.2 1.6 1.8 1.4 2.1 1.8 1.4 1.8 1.4 1.9 1.5 1.6 2.1 1.8 1.6 1.6 2.4 2.2 2.0 2.4 2.0 2.7 2.7 2.3 2.3 1.7 2.2 2.7 2.2 2.5 2.1 1.5 9 10-14 8.9 9 10-16 3.3 9 10-15 6.1 9 10-14 1.5 9 10-14 1.3 9 10-14 2.3 9 10-14 6.8 9 10-14 3.4 9 10-16 1.1 9 10-14 1.1 9 10-16 7.9 9 10-14 3.0 9 10-15 7.9 9 10-18 7.2 9 10-16 1.7 9 10-15 1.7 9 10-14 2.1 9 10-14 2.3 9 10-14 2.0 9 10-15 element software feflow model pressuredriven thermally induced ﬂuid ﬂow including viscosity.',
#  'governing equations ﬂuid ﬂow heat transport saturated porous media derived conservation principles linear momentum, mass energy (dhi-wasy 2009).',
#  'the direction proﬁle selected cover relevant processes lahendong geothermal ﬁeld: it cuts major faults production injection wells temperature pressure calibration.',
#  'the direction proﬁle selected cover relevant processes lahendong geothermal ﬁeld: it cuts major faults production injection wells temperature pressure calibration.',
#  'the direction proﬁle selected cover relevant processes lahendong geothermal ﬁeld: it cuts major faults production injection wells temperature pressure calibration.',
#  'material properties 123 elements permeability, porosity thermal conductivity set laboratory measurements (table 1).',
#  'the definitions modeled grids faults: porosity 30 % thermal conductivity 1.8 w-1 k-1.',
#  'corresponding grids lake linau deﬁned porosity 100 % thermal conductivity 0.6 w-1 k-1.',
#  'the model simulates ﬂuid ﬂow thermal transport saturated media steady state.',
#  'the sw hydraulic head represents inﬁltration surface water fault, striking perpendicular model.',
#  'inﬁltration fault zones lake linau ﬂuid ﬂux boundary conditions.',
#  'the quantity 3.0 9 10-4-1 sw 1.3 9 10-6-1 ne fault distributed 40 fault width.',
#  'the quantity 3.0 9 10-4-1 sw 1.3 9 10-6-1 ne fault distributed 40 fault width.',
#  'fluid movement model domain constrained-ﬂow boundary, recharge surrounding fault zones low hydraulic heads ne model area.',
#  'discharge central study area lake linau ne model boundary.',
#  'the heat 116 °c-1 transport boundary conditions time-invariant, ﬁxed temperatures heat ﬂux (table 2; fig. 2).',
#  'thermal gradient sw model boundary temperature constant 350 °c pluton.',
#  'temperature water inﬁltrating faults mixing shallow warm groundwater 70 °c surface groundwater recharge 28 °c.',
#  'temperature values ﬁeld bore log measurements (brehme. 2014).',
#  'heat ﬂux set 100 mw-2 model boundary (table 2; fig. 2).',
#  'initial temperature model domain set 116 °c-1 local thermal gradient.',
#  'permeability determination initial values permeability deﬁned based laboratory measurements (table 1).',
#  'after simulation, modeled measured temperature pressure values compared observation points.',
#  'in case poor matching (errors [10 %), permeability adjusted satisfactory achieved.',
#  'beneath lake linau, simulation locally strong discrepancies modeled measured pressure temperature (errors [45 %).',
#  'adjustment permeability geological inﬁltration rates faults hydraulic heads lead acceptable.',
#  'adjustment permeability geological inﬁltration rates faults hydraulic heads lead acceptable.',
#  'adjustment permeability geological inﬁltration rates faults hydraulic heads lead acceptable.',
#  'only implementation strong permeability anisotropy depth.. additional fault minimization errors (0–7 %).',
#  'only implementation strong permeability anisotropy depth.. additional fault minimization errors (0–7 %).',
#  'implementation accomplished mesh adaptation ensure behavior fault.',
#  'by procedure, permeability anisotropies located characterized model.',
#  'in general, deﬁning direction-dependent permeability improves data ﬁt permeabilities directions.',
#  'this fractures increasing permeability vertical direction.',
#  'porosity thermal conductivity remained constant simulation.',
#  'variation porosity negligible directly reﬂected permeability thermal conductivity differences affect conductive heat transport dominant lahendong area (ondrak. 1998; brehme. 2014).',
#  'variation porosity negligible directly reﬂected permeability thermal conductivity differences affect conductive heat transport dominant lahendong area (ondrak. 1998; brehme. 2014).',
#  'nefault coolingpluton lake swfault swmodelboundary temperature(°c) heattransport fluidﬂux(-1)',
#  'page 5 11 1088\x0c1088 page 6 11 results numerical simulation performed ﬁt measured data changing absolute relative permeability geological elements.',
#  'relative permeability refers permeabilities horizontal vertical direction.',
#  'as main result blind fault recognized beneath lake linau studies.',
#  'simulated pressure temperature measured ﬁve selected observation points represent boreholes bore logs pressure temperature.',
#  'the model data ﬁt 370 models considered generate ﬁnal model developed lahendong.',
#  'permeability distribution identiﬁcation blind fault distribution permeability patterns reservoir conceived comparing temperature pressure data wells.',
#  'permeability distribution identiﬁcation blind fault distribution permeability patterns reservoir conceived comparing temperature pressure data wells.',
#  'permeability distribution identiﬁcation blind fault distribution permeability patterns reservoir conceived comparing temperature pressure data wells.',
#  'especially beneath lake linau, closely located wells high variations temperature pressure.',
#  'especially beneath lake linau, closely located wells high variations temperature pressure.',
#  'especially beneath lake linau, closely located wells high variations temperature pressure.',
#  'models ﬁrst high discrepancies modeled measured values area.',
#  'however implementing high anisotropic permeable structure observation points, models satisfactory.',
#  'this structure assumed fault zone located faults vertical dip nw strike.',
#  'this fault trace surface covered lake linau.',
#  'generally, modeled permeability distribution lahendong reservoir direction-dependent overprints lithology.',
#  'generally, modeled permeability distribution lahendong reservoir direction-dependent overprints lithology.',
#  'modeled permeability generally higher measured order magnitudes.',
#  'permeability patterns directly affect subsurface ﬂuid ﬂow temperature pressure distribution.',
#  'permeability faulted zones surroundings lowest study area.',
#  'especially middle ne fault shallow area beneath sw lake linau deep ne ne fault low permeabilities 10-13 10-14 (fig. 3).',
#  'the area middle ne fault deep ne sw fault sw fault model area sw ne boundary higher permeabilities 10-10 10-12 (fig. 3).',
#  'permeability varies modeled area vertical horizontal direction.',
#  'in faults deep reservoir ne, permeability factor 10 higher vertical direction horizontal direction (fig. 3).',
#  'in areas faults, permeability parts factor 10–100 lower vertical direction.',
#  'in rest model, vertical horizontal permeability differ (fig. 3).',
#  'fig. 3 final adapted permeability anisotropy distribution model domain.',
#  'anisotropy relation vertical horizontal permeability anisotropy [1 vertical permeability higher horizontal permeability 123\x0cenviron earth sci (2016)',
#  'page 7 11 1088 fig. 4 modeled temperature pressure distribution study area high-pressure ﬁelds sw convective heat transport rising hot ﬂuids inﬁltration cooler water faults pressure distribution',
#  'page 7 11 1088 fig. 4 modeled temperature pressure distribution study area high-pressure ﬁelds sw convective heat transport rising hot ﬂuids inﬁltration cooler water faults pressure distribution',
#  'the pressure distribution study area controlled groundwater ﬂow low permeable rocks vertically high permeable fault zones.',
#  'the pressure distribution study area controlled groundwater ﬂow low permeable rocks vertically high permeable fault zones.',
#  'some wells existing region artesian-type.',
#  'overpressure releases high permeable zones beneath lake linau discharges surface.',
#  'the pressure drop 20 bars faults (fig. 4).',
#  'temperature distribution temperature distribution lahendong geothermal reservoir suggests convective heat transport dominating process reservoir rocks.',
#  'temperature distribution temperature distribution lahendong geothermal reservoir suggests convective heat transport dominating process reservoir rocks.',
#  'temperature locally increased model surrounding pluton (fig. 4).',
#  'subsurface ﬂuid ﬂow the absolute horizontal/vertical permeability distribution controls local ﬂuid ﬂow lahendong reservoir.',
#  'subsurface ﬂuid ﬂow the absolute horizontal/vertical permeability distribution controls local ﬂuid ﬂow lahendong reservoir.',
#  'the general ﬂuid ﬂow, driven natural pressure gradient oriented sw ne.',
#  'patterns hot groundwater ﬂows faults beneath lake linau ﬂuid ﬂow disturbed rise temperature vertically high permeable layers.',
#  'patterns hot groundwater ﬂows faults beneath lake linau ﬂuid ﬂow disturbed rise temperature vertically high permeable layers.',
#  'this rise groundwater model area (red forward streamlines fig. 5).',
#  'at time, cold water inﬁltrates high permeable areas distributes ne model domain (blue backward streamlines fig. 5).',
#  'it composition ne reservoir domain dominated coldwater inﬁltration faults production areas characterized hot water ﬂow (fig. 5).',
#  'subsurface ﬂuid ﬂow locally inﬂuenced fault zones physical 123\x0c1088 page 8 11 environ earth sci (2016) 75:1088',
#  'fig. 5 model domain calculated streamlines red: forward streamlines follow hydraulic gradient sw model boundary ne blue: backward streamlines representing inﬁltrating cold water ﬂowing ne model boundary properties water (.. viscosity).',
#  'the inﬂuence parameters ﬂuid ﬂow investigated lahendong geothermal reservoir hydraulic–thermal simulations.',
#  'the inﬂuence parameters ﬂuid ﬂow investigated lahendong geothermal reservoir hydraulic–thermal simulations.',
#  'simulation detailed permeability distribution reservoir including location additional fault zone.',
#  'simulation detailed permeability distribution reservoir including location additional fault zone.',
#  'matching measured simulated temperature pressure tool resolving permeability distribution.',
#  'temperature pressure iteratively determined observation points (fig. 2).',
#  'nevertheless observation points values pressure temperature (lhd 4 lhd 7) temperature (lhd 24).',
#  'furthermore, density variations included simulation high temperatures variation ﬂuid pressure.',
#  'furthermore, density variations included simulation high temperatures variation ﬂuid pressure.',
#  'however average deviation simulated pressure temperature 1 %.',
#  'implemented model parameters porosity, permeability heat conductivity.',
#  'from parameters permeability tested speciﬁc range simulation.',
#  'the inﬂuence porosity heat conductivity ﬂuid ﬂow negligible dominating convective heat ﬂow (ondrak. 1998).',
#  'values implemented model based measured permeabilities represent matrix permeability rocks.',
#  'the measured matrix permeability, representing permeability horizontal direction 1.5 9 10-14 123 average remains typical permeability range fractured igneous rocks (schoen 2004).',
#  'the measured matrix permeability, representing permeability horizontal direction 1.5 9 10-14 123 average remains typical permeability range fractured igneous rocks (schoen 2004).',
#  'permeability volcanic breccias ranges typically 3 9 10-15 5 9 10-12 tuff permeabilities range 7 9 10-17 7 9 10-12 (klavetter peters 1987).',
#  'permeability volcanic breccias ranges typically 3 9 10-15 5 9 10-12 tuff permeabilities range 7 9 10-17 7 9 10-12 (klavetter peters 1987).',
#  'however, permeability reservoir rocks locally increased fracture formation.',
#  'in lahendong, modeled permeability magnitudes higher measured faulted areas.',
#  'in lahendong, modeled permeability magnitudes higher measured faulted areas.',
#  'moreover fault cores factor 10 higher vertical direction horizontal direction.',
#  'however areas faults (fault gauge), permeability parts factor 10–100 lower vertical direction.',
#  'however areas faults (fault gauge), permeability parts factor 10–100 lower vertical direction.',
#  'adaptation permeability ensures ﬁt measured temperature pressure data.',
#  'permeability fractured areas main factor inﬂuencing subsurface ﬂuid ﬂow temperature distribution lahendong reservoir area.',
#  'permeability fractured areas main factor inﬂuencing subsurface ﬂuid ﬂow temperature distribution lahendong reservoir area.',
#  'subsurface ﬂuid ﬂow driven local hydraulic heads high variations sections study area.',
#  'consequently, convective heat distribution leads high temperature variation reservoir.',
#  'consequently, convective heat distribution leads high temperature variation reservoir.',
#  'these phenomena observed lahendong comparable ﬁelds.',
#  'in new mexico, water level drops 30–100 observed (haneberg 1995).',
#  'high fault zones\x0c123 environ earth sci (2016) 75:1088',
#  'page 9 11 1088 7 24 4 28 5 lhd 4 lhd 5 lhd 7 lhd 24 lhd 28 reservoir depth [] surface 1400 1750 2100 1820 1800 110 120 130 140 400 modelled pressure [bar] 150 140 130 120 110 modelled pressure [bar] 100 100 lhd 5 lhd 28 lhd 7 lhd 4 lhd 24 drilling bore log completed oct 1985 jan 86',
#  'may 1986 jul 2000 jul 96 oct 1987 jul 09 jul 09 aug 09 aug 09 lhd 4 lhd 5 lhd 7 lhd 24 lhd 28 150 200 250 300 350 400 modelled temperature [°c] 400 350 300 250 200 150 measured temeprature [°c] 100 100 fig. 6 modeled versus measured temperature pressure selected observation points.',
#  'well speciﬁcations measured data brehme.',
#  '(2014) temperature drops upwelling isotherms fault zones control ﬂuid ﬂow lake long valentine ﬁelds, usa (hooper 1991).',
#  '(2014) temperature drops upwelling isotherms fault zones control ﬂuid ﬂow lake long valentine ﬁelds, usa (hooper 1991).',
#  '(2014) temperature drops upwelling isotherms fault zones control ﬂuid ﬂow lake long valentine ﬁelds, usa (hooper 1991).',
#  'the analysis ﬂuid pressure differences alpine fault, new zealand, allowed characterize change permeability hanging footwall blocks (sutherland. 2012).',
#  'the analysis ﬂuid pressure differences alpine fault, new zealand, allowed characterize change permeability hanging footwall blocks (sutherland. 2012).',
#  'the analysis ﬂuid pressure differences alpine fault, new zealand, allowed characterize change permeability hanging footwall blocks (sutherland. 2012).',
#  'in summary, high pressure temperature gradients indicators ﬂuid barriers observation points.',
#  'in summary, high pressure temperature gradients indicators ﬂuid barriers observation points.',
#  'in lahendong signiﬁcant ﬂuid barriers faults sw ne lake linau.',
#  'across barriers pressure drops 20 bars.',
#  'a pattern measured bore logs beneath lake linau surface trace fault observed studies.',
#  'however implementing fault, modeled measured values adapted.',
#  'the identiﬁed fault zone beneath lake linau remains lake water traceable kind reservoir modeling.',
#  'additionally fault identiﬁcation internal structure fault zones understood.',
#  'the ne fault.. displacement 2 depth.',
#  'the ne fault.. displacement 2 depth.',
#  'the detailed trend understood permeability adaptation area.',
#  'due low permeability horizontal direction faults, ﬂuids propagate vertically hot springs surface.',
#  'due low permeability horizontal direction faults, ﬂuids propagate vertically hot springs surface.',
#  'it surface water inﬁltrate reservoir case pressure fault zone low (fig. 5).',
#  'it surface water inﬁltrate reservoir case pressure fault zone low (fig. 5).',
#  'this vertical ﬂuid movement eventually controls temperature distribution reservoir.',
#  'upward migration deep hot water increases temperature inﬁltration cold surface water local drop temperature.',
#  'in summary factors inﬂuencing reliability numerical reservoir models absolute horizontal vertical permeability.',
#  'however permeability adaptation geological layer; vertical permeability anomalies overprinting layers constraining regional groundwater ﬂow.',
#  'therefore permeability characteristics investigated.',
#  'in previous study numerical model lahendong site set tough2 aimed forecasting reservoir behavior exploitation year 2036.',
#  'in previous study numerical model lahendong site set tough2 aimed forecasting reservoir behavior exploitation year 2036.',
#  'with production 60 mwe predicts pressure drop 10 bars.',
#  'however forecast uncertain lack measured pressure draw data (yani 2006).',
#  'furthermore, chemical characteristics considered achieve reliable production setups hydrochemical processes play role lahendong reservoir (brehme. 2016).',
#  'presented models study provide ﬂuid ﬂow water-dominated lahendong reservoir.',
#  'presented models study provide ﬂuid ﬂow water-dominated lahendong reservoir.',
#  'lahendong area progress understand inﬂuence steam driven ﬂuid ﬂow high-temperature.',
#  'lahendong area progress understand inﬂuence steam driven ﬂuid ﬂow high-temperature.',
#  'lahendong area progress understand inﬂuence steam driven ﬂuid ﬂow high-temperature.',
#  'conclusion the primary focus study understand inﬂuence fault zones permeability patterns subsurface ﬂuid ﬂow geothermal reservoirs.',
#  'conclusion the primary focus study understand inﬂuence fault zones permeability patterns subsurface ﬂuid ﬂow geothermal reservoirs.',
#  'the ﬂuid ﬂow depends rock fault zone permeability.',
#  'the ﬂuid ﬂow depends rock fault zone permeability.',
#  'these processes considered numerical models simulate local temperature pressure conditions.',
#  'models developed based conceptual models study area explain reservoir geometry, geological structures, temperature hydraulic conditions.',
#  'temperature pressure-logs model calibration.',
#  'the numerical models represent vertical horizontal ﬂuid ﬂow controlled fault permeability.',
#  'the numerical models represent vertical horizontal ﬂuid ﬂow controlled fault permeability.',
#  'by stepwise adaptation permeability ﬁelds, based observed temperature pressure gradients additional blind fault zone identiﬁed beneath lake linau.',
#  'by stepwise adaptation permeability ﬁelds, based observed temperature pressure gradients additional blind fault zone identiﬁed beneath lake linau.',
#  'temperature pressure signiﬁcantly drop ﬂuid barrier.',
#  'this behavior observed comparable ﬁelds usa.',
#  'discharge enhanced highly fractured areas lake linau.',
#  'vertical permeability faults ﬂuids rising hot springs surface.',
#  'vertical permeability faults ﬂuids rising hot springs surface.',
#  'results permeability considered simulation geothermal.',
#  'the geothermal controlled ﬂuid ﬂow fractures/faults depending temperature pressure conditions.',
#  'results guide reservoir management case potential ﬁeld extension performed lahendong.',
#  'the support team pertamina geothermal energy jakarta lahendong including access data ﬁeld 123 highly appreciated.',
#  'mineral mag 75:577 brehme m, haase c, regenspurg s, moeck i, deon f, wiegand ba, kamah y, zimmermann g, sauter m (2013) hydrochemical patterns structurally controlled geothermal.',
#  'finite element modeling ﬂow, mass heat transport porous fractured media.',
#  'water resour res 31:1815–1820 hooper ecd (1991) fluid migration growth faults compacting sediments.',
#  'physical hydraulic properties weathered granitic rock southern california.',
#  'physical hydraulic properties weathered granitic rock southern california.',
#  'soil sci 158:375–380 kaya e, o’sullivan mj, hochstein mp (2014) a dimensional numerical model waiotapu, waikite reporoa geothermal areas, new zealand.',
#  'an evaluation mercury porosimetry calculating hydrologic properties tuffs yucca mountain, nevada, nevada nuclear waste storage investigations project report.',
#  'an evaluation mercury porosimetry calculating hydrologic properties tuffs yucca mountain, nevada, nevada nuclear waste storage investigations project report.',
#  'project-report, nevada nuclear waste storage investigations project koestono h, siahaan ee, silaban m, franzson h (2010) geothermal model',
#  'project-report, nevada nuclear waste storage investigations project koestono h, siahaan ee, silaban m, franzson h (2010) geothermal model',
#  'in: proceedings world geothermal congress 2010, bali, indonesia, 25–29 april 2010 lahendong geothermal ﬁeld, indonesia.',
#  'in: proceedings world geothermal congress 2010, bali, indonesia, 25–29 april 2010 lahendong geothermal ﬁeld, indonesia.',
#  'magri f, akar t, gemici u, pekdeger a (2011) numerical fault-induced seawater circulation investigations\x0cenviron earth sci (2016)',
#  'page 11 11 1088 seferihisar–balc¸ova geothermal, western turkey.',
#  'application liquid- vapor-dominated hydrothermal modeling techniques wairakei, new zealand.',
#  'application liquid- vapor-dominated hydrothermal modeling techniques wairakei, new zealand.',
#  'permeability gypsum samples dehydrated air.',
#  'permeability gypsum samples dehydrated air.',
#  'neben s, hinz k, beiersdorf h (1998) reﬂection characteristics, depth geographical distribution simulating reﬂectors accretionary wedge sulawesi.']

# %%
ready_ner['tag']
# Out:
# ['permeability',
#  'lahendong',
#  'new zealand',
#  'site',
#  'pressure',
#  'enhanced',
#  'indonesia',
#  'lahendong',
#  'capacity',
#  'dominated',
#  'fault',
#  'hot springs',
#  'permeability',
#  'fault',
#  'lahendong',
#  'site',
#  'permeability',
#  'conductivity',
#  'lahendong',
#  'lahendong',
#  'site',
#  'fault',
#  'basic',
#  'acidic',
#  'fault',
#  'hydrothermal',
#  'central',
#  'lahendong',
#  'formation',
#  'pleistocene',
#  'andesite',
#  'porosity',
#  'effective porosity',
#  'thermal',
#  'permeability',
#  'rock',
#  'effective porosity',
#  'andesite',
#  'porosity',
#  'tuff',
#  'effective porosity',
#  'volcanic',
#  'permeability',
#  'thermal',
#  'thermal',
#  'lahendong',
#  'depth',
#  'rock',
#  'lhd1',
#  'thermal',
#  'andesite',
#  'heat',
#  'wells',
#  'temperature',
#  'lahendong',
#  'permeability',
#  'porosity',
#  'porosity',
#  'thermal',
#  'fault',
#  'fault',
#  'width',
#  'fault',
#  'fault',
#  'central',
#  'heat',
#  'thermal',
#  'temperature',
#  'temperature',
#  'heat',
#  'temperature',
#  'permeability',
#  'temperature',
#  'permeability',
#  'pressure',
#  'lead',
#  'permeability',
#  'lead',
#  'permeability',
#  'fault',
#  'fault',
#  'permeability',
#  'permeability',
#  'permeability',
#  'porosity',
#  'porosity',
#  'lahendong',
#  'temperature',
#  'permeability',
#  'permeability',
#  'fault',
#  'pressure',
#  'lahendong',
#  'wells',
#  'permeability',
#  'fault',
#  'wells',
#  'temperature',
#  'high',
#  'high',
#  'high',
#  'fault',
#  'fault',
#  'permeability',
#  'lahendong',
#  'permeability',
#  'permeability',
#  'permeability',
#  'fault',
#  'fault',
#  'permeability',
#  'permeability',
#  'permeability',
#  'permeability',
#  'permeability',
#  'permeability',
#  'temperature',
#  'high',
#  'pressure',
#  'high',
#  'wells',
#  'high',
#  'pressure',
#  'temperature',
#  'lahendong',
#  'temperature',
#  'permeability',
#  'lahendong',
#  'pressure',
#  'temperature',
#  'high',
#  'red',
#  'high',
#  'composition',
#  'fault',
#  'red',
#  'thermal',
#  'lahendong',
#  'permeability',
#  'fault',
#  'temperature',
#  'temperature',
#  'pressure',
#  'density',
#  'high',
#  'pressure',
#  'porosity',
#  'permeability',
#  'porosity',
#  'permeability',
#  'permeability',
#  'igneous',
#  'permeability',
#  'volcanic',
#  'permeability',
#  'permeability',
#  'lahendong',
#  'fault',
#  'permeability',
#  'fault',
#  'permeability',
#  'permeability',
#  'lahendong',
#  'high',
#  'heat',
#  'high',
#  'lahendong',
#  'mexico',
#  'high',
#  'depth',
#  'temperature',
#  'well',
#  'usa',
#  'temperature',
#  'fault',
#  'new zealand',
#  'pressure',
#  'fault',
#  'pressure',
#  'high',
#  'lahendong',
#  'pressure',
#  'fault',
#  'fault',
#  'fault',
#  'fault',
#  'depth',
#  'fault',
#  'permeability',
#  'hot springs',
#  'permeability',
#  'pressure',
#  'fault',
#  'temperature',
#  'temperature',
#  'permeability',
#  'permeability',
#  'permeability',
#  'site',
#  'lahendong',
#  'pressure',
#  'pressure',
#  'lahendong',
#  'dominated',
#  'lahendong',
#  'temperature',
#  'high',
#  'lahendong',
#  'permeability',
#  'fault',
#  'permeability',
#  'rock',
#  'temperature',
#  'temperature',
#  'temperature',
#  'permeability',
#  'fault',
#  'permeability',
#  'fault',
#  'temperature',
#  'usa',
#  'enhanced',
#  'hot springs',
#  'permeability',
#  'permeability',
#  'temperature',
#  'lahendong',
#  'lahendong',
#  'mineral',
#  'heat',
#  'sediments',
#  'granitic',
#  'california',
#  'new zealand',
#  'nevada',
#  'nevada',
#  'nevada',
#  'nevada',
#  'indonesia',
#  'lahendong',
#  'fault',
#  'turkey',
#  'new zealand',
#  'dominated',
#  'permeability',
#  'gypsum',
#  'depth']

# %%
ready_ner['entity']
# Out:
# ['methods',
#  'states',
#  'countries',
#  'geolocation',
#  'methods',
#  'methods',
#  'countries',
#  'states',
#  'methods',
#  'petrography',
#  'petrography',
#  'geolocation',
#  'methods',
#  'petrography',
#  'states',
#  'geolocation',
#  'methods',
#  'methods',
#  'states',
#  'states',
#  'geolocation',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'states',
#  'states',
#  'methods',
#  'chrono',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'petrography',
#  'methods',
#  'petrography',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'states',
#  'methods',
#  'petrography',
#  'geolocation',
#  'methods',
#  'petrography',
#  'methods',
#  'geolocation',
#  'methods',
#  'states',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'petrography',
#  'petrography',
#  'states',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'geolocation',
#  'methods',
#  'petrography',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'states',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'states',
#  'geolocation',
#  'methods',
#  'petrography',
#  'geolocation',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'methods',
#  'states',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'petrography',
#  'geolocation',
#  'petrography',
#  'methods',
#  'methods',
#  'states',
#  'methods',
#  'methods',
#  'states',
#  'methods',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'methods',
#  'states',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'states',
#  'petrography',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'states',
#  'petrography',
#  'methods',
#  'petrography',
#  'states',
#  'countries',
#  'petrography',
#  'methods',
#  'methods',
#  'geolocation',
#  'geolocation',
#  'methods',
#  'petrography',
#  'countries',
#  'methods',
#  'petrography',
#  'methods',
#  'petrography',
#  'states',
#  'methods',
#  'petrography',
#  'petrography',
#  'petrography',
#  'petrography',
#  'methods',
#  'petrography',
#  'methods',
#  'geolocation',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'geolocation',
#  'states',
#  'methods',
#  'methods',
#  'states',
#  'petrography',
#  'states',
#  'methods',
#  'petrography',
#  'states',
#  'methods',
#  'petrography',
#  'methods',
#  'petrography',
#  'methods',
#  'methods',
#  'methods',
#  'methods',
#  'petrography',
#  'methods',
#  'petrography',
#  'methods',
#  'geolocation',
#  'methods',
#  'geolocation',
#  'methods',
#  'methods',
#  'methods',
#  'states',
#  'states',
#  'petrography',
#  'methods',
#  'petrography',
#  'petrography',
#  'states',
#  'countries',
#  'geolocation',
#  'states',
#  'geolocation',
#  'states',
#  'countries',
#  'states',
#  'petrography',
#  'countries',
#  'countries',
#  'petrography',
#  'methods',
#  'petrography',
#  'methods']
